# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r
from scipy.stats import expon

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def collection_distribution_hev(n,collection,price):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n))
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes,price):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_hev_instance = collection_distribution_hev(n,whole_collection,price)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_hev_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes,price)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])
    
    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    #print(pd.DataFrame(curr_whole_instance))
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-6 or curr_choice_collection[y][x] >0.999:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes,price)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-6 or curr_choice_collection[y][x] >0.999:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:  
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples)    '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        ''' condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-3:
                    condition = True
        if condition == True:
            print('instance_generation error') '''
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        ''' df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst) '''
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.opt import SolverFactory

def mem_mle_pyo(data, collection,offertimes):
    n,m = data.shape
    model = pyo.ConcreteModel()
    model.v = pyo.Var(range(n), bounds=(-100,100))
    model.alpha = pyo.Var(range(n),domain=pyo.NonNegativeReals, bounds=(0.01,10))
    model.lam = pyo.Var(range(m), bounds=(0,50))
    
    def obj_rule(model):
        obj = 0
        for i in range(len(collection)):
            for j in collection[i]:
                obj += offertimes[i] * data[j][i] * model.alpha[j] * (model.v[j] - model.lam[i])
        return obj
    
    model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)
    
    model.assortment_constraints = pyo.ConstraintList()
    for i in range(m):
        model.assortment_constraints.add(sum(pyo.exp(model.alpha[j] * (model.v[j] - model.lam[i]) ) for j in collection[i])==1)
    
    # to scale the preference of the outside option to be 1 
    # to avoid overfitting   
    model.alpha_constraint = pyo.Constraint(expr=model.alpha[0] == 1)
    model.v_constraint = pyo.Constraint(expr=model.v[0] == 0)
    
    opt = pyo.SolverFactory('ipopt')  # use iterior point method to solve continuous optimizatio problem 
    results = opt.solve(model)
    #results = opt.solve(model)
    #model.pprint()
    if results.solver.status == pyo.SolverStatus.ok:
    #if (results.solver.status == pyo.SolverStatus.ok) and (results.solver.termination_condition == pyo.TerminationCondition.optimal):
        v_values = [model.v[i].value for i in range(n)]
        alpha_values = [model.alpha[i].value for i in range(n)]
        lam_values = [model.lam[i].value for i in range(m)]
        prob = np.zeros((n,m)) 
        for j in range(m):
            for i in collection[j]:
                prob[i,j] = np.exp(alpha_values[i]*(v_values[i]-lam_values[j]))       
        obj_value = model.obj()
        
        return v_values,alpha_values,lam_values,prob, obj_value,results.solver.time
    else:
        raise ValueError("MEM MLE: Solver failed to find an optimal solution.")

# Example usage:
# v_values, obj_value = mem_mle(data, collection)

# %%
def binarySearch(lb,ub,v,assortment,x,alpha):
    
    mid = (lb+ub)/2
    for j in assortment:
        x[j] = 1-expon.cdf(mid-v[j],scale=1/alpha[j]) # pdf = lambda * exp(-lambda * x). This parameterization corresponds to using scale = 1 / lambda.
    
    if np.abs(sum(x)-1)<0.000001:
        return x
    elif sum(x)>1:
        return binarySearch(mid,ub,v,assortment,x,alpha)
    else:
        return binarySearch(lb,mid,v,assortment,x,alpha)

# %%
def collection_distribution_mem(n,collection,v,alpha):
    
    collection_distribution = np.zeros((n,len(collection)))

    lb = -2000
    ub = 2000
    for i in range(len(collection)):
        prob = np.zeros(n)
        collection_distribution[:,i] = binarySearch(lb,ub,v,collection[i],prob,alpha)
        #collection_distribution[:,i] = bisection(prob,n,collection[i],v,alpha,lb,ub)

    return collection_distribution

# %%
## prediction for the current testing collection of assortments 
def mem_prediction(curr_test_instance,curr_test_collection,price,v_values,alpha_values):
    ''' true assortment ranking '''
    true_choice_prob = [] 
    true_revenue = []
    
    mem_revenue = []
    mem_sales = []
    
    mem_runtime = []
    
    
    # mle estimate
    start_time = time.time()
    estimated_oos_prob = collection_distribution_mem(len(v_values),curr_test_collection,v_values,alpha_values)
    used_t_1 = time.time() - start_time
    
    for k in range(len(curr_test_collection)):

        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        true_choice_prob.append(curr_test_instance[:,k])
        
        st_time_2 = time.time()
        curr_mem_rev = np.dot(estimated_oos_prob[:,k],price)
        used_t_2 = time.time() - st_time_2
        
        mem_sales.append(estimated_oos_prob[:,k])
        mem_revenue.append(curr_mem_rev)
        print(f'revenue of assortment {curr_test_collection[k]} is {curr_mem_rev}')
        
        ## record the runtime result
        mem_runtime.append(used_t_1+used_t_2)
        
    return true_revenue,true_choice_prob,mem_revenue,mem_sales,mem_runtime

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record representability of all instances

## record the kendall tau distance between the predicted ranking of mem and the truth
all_mem_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_rev_list = []
all_best_rev_mem_list = []  

## record the difference in best assortment
all_mem_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mem_revenue_list = []

all_true_prob_list = [] 
all_mem_sales_list = []

all_true_ranking = []
all_mem_ranking = []

## record the runtime of mem prediction
all_mem_pred_runtime = []

for i in range(len(all_full_collections)):
       
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mem_best_rev_collection = [] # a container for the best revenue predicted by robust mem
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mem_ranking_collection = [] # a container for ranking by robust mem
    
    mem_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mem
   
    
    true_choice_prob_collection = []
    mem_sales_frac_collection = []

    true_revenue_collection = []
    mem_revenue_collection = []
    
    mem_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        ## mle 
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        # v_values,alpha_values,lam_values,prob, obj_value,results.solver.time
        v_values,alpha_values,lambda_vaues,prob,ll_value,ll_time = mem_mle_pyo(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
        ########### mem prediction#################
        # mem_prediction(curr_test_instance,curr_test_collection,price,v_values)
        true_revenue,true_choice_prob,mem_revenue,mem_sales,mem_runtime = mem_prediction(all_test_instance[i][j],all_test_collection[i][j],price,v_values,alpha_values)
        # the following lists are of the same size as number of testing assortments
        
        for x in range(len(mem_runtime)):
            mem_runtime[x] = mem_runtime[x] + ll_time
        
        true_revenue_collection.append(true_revenue)
        true_choice_prob_collection.append(true_choice_prob)
        
        mem_revenue_collection.append(mem_revenue)   
        mem_sales_frac_collection.append(mem_sales)
        mem_runtime_collection.append(mem_runtime)
         
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_mem_rank  = np.argsort(-np.array(mem_revenue)) 
        mem_ranking_collection.append(curr_mem_rank)
        mem_best_rev_collection.append(true_revenue[curr_mem_rank[0]])
        
        
        #  mem kendallTau Distance for current instance [i][j]
        curr_mem_dist = kendall_tau_distance(curr_true_rank, curr_mem_rank)
        mem_distance_collection.append(curr_mem_dist)
    
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mem_distance_list.append(mem_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_rev_list.append(true_best_rev_collection) 
    all_best_rev_mem_list.append(mem_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_mem_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(mem_best_rev_collection))/ np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    
    all_mem_revenue_list.append(mem_revenue_collection)
    
    all_true_prob_list.append(true_choice_prob_collection)
    all_mem_sales_list.append(mem_sales_frac_collection)
 
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mem_ranking.append(mem_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mem_pred_runtime.append(mem_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# revenue of assortment [0, 5] is 0.3325922561362287
# revenue of assortment [0, 3, 7] is 0.2426221529309653
# revenue of assortment [0, 5, 6] is 0.30577499264316554
# revenue of assortment [0, 5, 8] is 0.37295061001882834
# revenue of assortment [0, 6, 8] is 0.2564792113598035
# testing for offertimes 20, 1th instance
# revenue of assortment [0, 3] is 0.1495540241557382
# revenue of assortment [0, 4] is 0.37361075938250043
# revenue of assortment [0, 1, 4] is 0.361783692245232
# revenue of assortment [0, 3, 4] is 0.1789297528786713
# revenue of assortment [0, 5, 6] is 0.23854978249703782
# testing for offertimes 20, 2th instance
# revenue of assortment [0, 1, 8] is 0.4787652080942115
# revenue of assortment [0, 2, 6] is 0.14771739237428122
# revenue of assortment [0, 3, 4] is 0.17285254665270644
# revenue of assortment [0, 4, 5] is 0.36571521451812616
# revenue of assortment [0, 5, 8] is 0.5101621302552872
# testing for offertimes 20, 3th instance
# revenue of assortment [0, 1] is 0.11227200351204597
# revenue of assortment [0, 4] is 0.2718137987982651
# revenue of assortment [0, 7] is 0.10789746772592956
# revenue of assortment [0, 3, 4] is 0.1558330137424957
# revenue of assortment [0, 8] is 0.41546837822133054
# testing for offertimes 20, 4th instance
# revenue of assortment [0, 1, 8] is 0.5983971523009345
# revenue of assortment [0, 2, 3, 6] is 0.16108696669803718
# revenue of assortment [0, 3, 8] is 0.6273955034451516
# revenue of assortment [0, 5, 6] is 0.2803770209383879
# revenue of assortment [0, 6, 7] is 0.23164746980190792
# testing for offertimes 20, 5th instance
# revenue of assortment [0, 1] is 0.12797848152167396
# revenue of assortment [0, 1, 4] is 0.40537257792301085
# revenue of assortment [0, 2, 6] is 0.15748161922425166
# revenue of assortment [0, 4, 7] is 0.32964857517816837
# revenue of assortment [0, 5, 6] is 0.2587348666858315
# testing for offertimes 20, 6th instance
# revenue of assortment [0, 4] is 0.44742292808496936
# revenue of assortment [0, 1, 3] is 0.20957644642590983
# revenue of assortment [0, 3, 7] is 0.23263653018826833
# revenue of assortment [0, 4, 8] is 0.5183971548330965
# revenue of assortment [0, 5, 8] is 0.4379797310780356
# testing for offertimes 20, 7th instance
# revenue of assortment [0, 1] is 0.12779320133174155
# revenue of assortment [0, 1, 6] is 0.1219976395249554
# revenue of assortment [0, 3, 6] is 0.1438889972152869
# revenue of assortment [0, 4, 5] is 0.31278466462311355
# revenue of assortment [0, 8] is 0.25894818488498
# testing for offertimes 20, 8th instance
# revenue of assortment [0, 1] is 0.13908220350610256
# revenue of assortment [0, 7] is 0.1447268052180285
# revenue of assortment [0, 1, 8] is 0.3513320201845114
# revenue of assortment [0, 4, 6] is 0.5039341102919904
# revenue of assortment [0, 8] is 0.3562411951340959
# testing for offertimes 20, 9th instance
# revenue of assortment [0, 1] is 0.30612277029947693
# revenue of assortment [0, 1, 3] is 0.22170723318321567
# revenue of assortment [0, 2, 3, 6] is 0.17807589707004282
# revenue of assortment [0, 3, 5] is 0.4149981593973685
# revenue of assortment [0, 4, 8] is 0.443849263805853
# testing for offertimes 20, 10th instance
# revenue of assortment [0, 1, 3] is 0.2553201788070875
# revenue of assortment [0, 2, 6] is 0.2025840420036584
# revenue of assortment [0, 3, 4] is 0.1709699974408802
# revenue of assortment [0, 3, 6] is 0.15598320991506603
# revenue of assortment [0, 5, 6] is 0.21397953083784238
# testing for offertimes 20, 11th instance
# revenue of assortment [0, 1, 3] is 0.19697921082606823
# revenue of assortment [0, 1, 7] is 0.2921354376740075
# revenue of assortment [0, 2, 6] is 0.16882585087615226
# revenue of assortment [0, 4, 6] is 0.3813816446634509
# revenue of assortment [0, 5, 6] is 0.22465863896750682
# testing for offertimes 20, 12th instance
# revenue of assortment [0, 1] is 0.15226610321508635
# revenue of assortment [0, 1, 5] is 0.3222395630307159
# revenue of assortment [0, 2, 3, 6] is 0.19969357643264324
# revenue of assortment [0, 3, 6] is 0.15328026115763427
# revenue of assortment [0, 6, 7] is 0.1811595811224625
# testing for offertimes 20, 13th instance
# revenue of assortment [0, 4] is 0.24485219638268824
# revenue of assortment [0, 6] is 0.12599466910885695
# revenue of assortment [0, 4, 5] is 0.33369961722023994
# revenue of assortment [0, 4, 8] is 0.29192205930712267
# revenue of assortment [0, 6, 8] is 0.15765412981202945
# testing for offertimes 20, 14th instance
# revenue of assortment [0, 4] is 0.2593967504714285
# revenue of assortment [0, 1, 5] is 0.32507677881597424
# revenue of assortment [0, 1, 6] is 0.18689488282150968
# revenue of assortment [0, 4, 8] is 0.2644188428098956
# revenue of assortment [0, 8] is 0.02910312676462984
# testing for offertimes 20, 15th instance
# revenue of assortment [0, 2, 3, 6] is 0.16769739242543047
# revenue of assortment [0, 3, 5] is 0.20985510109858602
# revenue of assortment [0, 4, 7] is 0.2873791238314293
# revenue of assortment [0, 4, 8] is 0.48184233942101135
# revenue of assortment [0, 6, 7] is 0.23127805042553612
# testing for offertimes 20, 16th instance
# revenue of assortment [0, 7] is 0.16130224627437514
# revenue of assortment [0, 1, 5] is 0.38015421040836145
# revenue of assortment [0, 3, 7] is 0.14699335999350713
# revenue of assortment [0, 4, 6] is 0.18528488836174323
# revenue of assortment [0, 8] is 0.20351740636747293
# testing for offertimes 20, 17th instance
# revenue of assortment [0, 1, 8] is 0.38570636098156874
# revenue of assortment [0, 3, 4] is 0.14988363556778259
# revenue of assortment [0, 3, 5] is 0.26691086884639137
# revenue of assortment [0, 3, 7] is 0.2493886459315422
# revenue of assortment [0, 6, 8] is 0.3194864572008436
# testing for offertimes 20, 18th instance
# revenue of assortment [0, 2] is 0.1260146012978279
# revenue of assortment [0, 1, 3] is 0.25523826465833205
# revenue of assortment [0, 3, 4] is 0.20136157076812933
# revenue of assortment [0, 4, 8] is 0.4533975095592642
# revenue of assortment [0, 6, 8] is 0.20807268646921354
# testing for offertimes 20, 19th instance
# revenue of assortment [0, 6] is 0.13348063340588978
# revenue of assortment [0, 1, 8] is 0.3148500063266295
# revenue of assortment [0, 2, 3, 6] is 0.14610522054230513
# revenue of assortment [0, 4, 6] is 0.1810796092932477
# revenue of assortment [0, 5, 8] is 0.34386939058477084
# testing for offertimes 20, 20th instance
# revenue of assortment [0, 1, 7] is 0.40416583828905006
# revenue of assortment [0, 3, 6] is 0.14119858601709787
# revenue of assortment [0, 4, 7] is 0.31372896536292194
# revenue of assortment [0, 5, 6] is 0.33629037825163133
# revenue of assortment [0, 8] is 5.797564650578124e-13
# testing for offertimes 20, 21th instance
# revenue of assortment [0, 3] is 0.12889631023757553
# revenue of assortment [0, 1, 7] is 0.2697901318357311
# revenue of assortment [0, 2, 6] is 0.20508968830297752
# revenue of assortment [0, 4, 6] is 0.23717350341587387
# revenue of assortment [0, 4, 8] is 0.45821476125883326
# testing for offertimes 20, 22th instance
# revenue of assortment [0, 4] is 0.4806244751748062
# revenue of assortment [0, 6] is 0.1686956280686296
# revenue of assortment [0, 3, 5] is 0.2625278144614761
# revenue of assortment [0, 4, 6] is 0.25412287657917676
# revenue of assortment [0, 5, 6] is 0.2766211844436548
# testing for offertimes 20, 23th instance
# revenue of assortment [0, 1, 7] is 0.3016444563145784
# revenue of assortment [0, 1, 8] is 0.3483806864152068
# revenue of assortment [0, 3, 4] is 0.18956204066985638
# revenue of assortment [0, 3, 5] is 0.39849552094202023
# revenue of assortment [0, 6, 7] is 0.1865973044978243
# testing for offertimes 20, 24th instance
# revenue of assortment [0, 1] is 0.36545471467139246
# revenue of assortment [0, 2] is 0.11730055616876377
# revenue of assortment [0, 1, 5] is 0.4305094877384203
# revenue of assortment [0, 3, 4] is 0.24856028081342507
# revenue of assortment [0, 4, 8] is 0.39310046852631364
# testing for offertimes 20, 25th instance
# revenue of assortment [0, 1, 8] is 0.40296321673111046
# revenue of assortment [0, 3, 7] is 0.23660149536239672
# revenue of assortment [0, 3, 8] is 0.2911849857201062
# revenue of assortment [0, 4, 7] is 0.38631320410560577
# revenue of assortment [0, 6, 8] is 0.2616149585341741
# testing for offertimes 20, 26th instance
# revenue of assortment [0, 1] is 0.32697408752894025
# revenue of assortment [0, 6] is 0.12648174279804236
# revenue of assortment [0, 1, 3] is 0.24467087850644398
# revenue of assortment [0, 3, 5] is 0.18945981320293376
# revenue of assortment [0, 4, 5] is 0.50786123243088
# testing for offertimes 20, 27th instance
# revenue of assortment [0, 7] is 0.1392918933354463
# revenue of assortment [0, 1, 3] is 0.16935150857040496
# revenue of assortment [0, 3, 6] is 0.18679379983755195
# revenue of assortment [0, 5, 6] is 0.4876922265525992
# revenue of assortment [0, 6, 8] is 0.1828656981833614
# testing for offertimes 20, 28th instance
# revenue of assortment [0, 1, 7] is 0.2579298715915543
# revenue of assortment [0, 1, 8] is 0.5196936961985714
# revenue of assortment [0, 3, 5] is 0.16530266477001207
# revenue of assortment [0, 3, 7] is 0.16713079640932563
# revenue of assortment [0, 6, 8] is 0.3419402958661017
# testing for offertimes 20, 29th instance
# revenue of assortment [0, 1, 4] is 0.3645940470538135
# revenue of assortment [0, 1, 7] is 0.23465170750479358
# revenue of assortment [0, 2, 6] is 0.17540054061702312
# revenue of assortment [0, 3, 6] is 0.1950355775271074
# revenue of assortment [0, 4, 6] is 0.2110602341967594
# testing for offertimes 20, 30th instance
# revenue of assortment [0, 1] is 0.14829900685705938
# revenue of assortment [0, 1, 8] is 0.48233406605549023
# revenue of assortment [0, 3, 8] is 0.40576091241931644
# revenue of assortment [0, 4, 8] is 0.5434518674628399
# revenue of assortment [0, 5, 8] is 0.5084441254838774
# testing for offertimes 20, 31th instance
# revenue of assortment [0, 3, 5] is 0.17033456174795814
# revenue of assortment [0, 4, 8] is 0.5910872427458822
# revenue of assortment [0, 6, 7] is 0.203762009317474
# revenue of assortment [0, 6, 8] is 0.4524575213755134
# revenue of assortment [0, 8] is 0.5596361449647016
# testing for offertimes 20, 32th instance
# revenue of assortment [0, 5] is 0.17405665956753916
# revenue of assortment [0, 3, 5] is 0.13053038519762145
# revenue of assortment [0, 3, 6] is 0.18964681267003355
# revenue of assortment [0, 5, 6] is 0.17002197188330695
# revenue of assortment [0, 5, 8] is 0.4179326390507567
# testing for offertimes 20, 33th instance
# revenue of assortment [0, 2] is 0.14614869021196866
# revenue of assortment [0, 7] is 0.16391968581784785
# revenue of assortment [0, 2, 3, 6] is 0.18811903735298943
# revenue of assortment [0, 3, 4] is 0.21208715539235337
# revenue of assortment [0, 6, 8] is 0.3243348360107404
# testing for offertimes 20, 34th instance
# revenue of assortment [0, 7] is 0.2171866863289597
# revenue of assortment [0, 1, 7] is 0.22949105230649908
# revenue of assortment [0, 3, 5] is 0.15921592387481973
# revenue of assortment [0, 3, 6] is 0.1435613028317199
# revenue of assortment [0, 3, 7] is 0.19505775569144987
# testing for offertimes 20, 35th instance
# revenue of assortment [0, 1] is 0.3633238353181708
# revenue of assortment [0, 1, 7] is 0.345944462429849
# revenue of assortment [0, 2, 3, 6] is 0.19644356641387742
# revenue of assortment [0, 3, 4] is 0.27370924975349675
# revenue of assortment [0, 6, 7] is 0.1964780672667554
# testing for offertimes 20, 36th instance
# revenue of assortment [0, 1, 6] is 0.34285788743878676
# revenue of assortment [0, 2, 6] is 0.17566445608917175
# revenue of assortment [0, 3, 6] is 0.1524129381896764
# revenue of assortment [0, 3, 8] is 0.390147992014789
# revenue of assortment [0, 5, 8] is 0.5055311355252592
# testing for offertimes 20, 37th instance
# revenue of assortment [0, 1] is 0.33880929978288976
# revenue of assortment [0, 1, 3] is 0.21446523699619435
# revenue of assortment [0, 3, 8] is 0.1885397447109391
# revenue of assortment [0, 4, 5] is 0.32650179358281184
# revenue of assortment [0, 5, 8] is 0.3742345977756242
# testing for offertimes 20, 38th instance
# revenue of assortment [0, 3] is 0.0781137830001119
# revenue of assortment [0, 6] is 0.11228553872118191
# revenue of assortment [0, 3, 6] is 0.11635597249630505
# revenue of assortment [0, 3, 7] is 0.18049633250460645
# revenue of assortment [0, 6, 8] is 0.37263577932021713
# testing for offertimes 20, 39th instance
# revenue of assortment [0, 1, 4] is 0.31029140240518394
# revenue of assortment [0, 3, 6] is 0.14014557954080184
# revenue of assortment [0, 5, 8] is 0.4832436924094062
# revenue of assortment [0, 6, 7] is 0.1707761485121178
# revenue of assortment [0, 6, 8] is 0.45196028597098903
# testing for offertimes 20, 40th instance
# revenue of assortment [0, 2] is 0.12802622066991334
# revenue of assortment [0, 3] is 0.1527929590344377
# revenue of assortment [0, 4, 6] is 0.20736672837111653
# revenue of assortment [0, 6, 7] is 0.23066923466134828
# revenue of assortment [0, 6, 8] is 0.2473105108539116
# testing for offertimes 20, 41th instance
# revenue of assortment [0, 1] is 0.36628217972162835
# revenue of assortment [0, 1, 3] is 0.3506017709067771
# revenue of assortment [0, 1, 4] is 0.42353374022564594
# revenue of assortment [0, 2, 6] is 0.17644398951663648
# revenue of assortment [0, 5, 6] is 0.31410804311966717
# testing for offertimes 20, 42th instance
# revenue of assortment [0, 4] is 0.6481945547382523
# revenue of assortment [0, 6] is 0.10221287818231876
# revenue of assortment [0, 1, 4] is 0.6376352240489354
# revenue of assortment [0, 3, 8] is 0.22063615614984403
# revenue of assortment [0, 5, 8] is 0.4054712144991264
# testing for offertimes 20, 43th instance
# revenue of assortment [0, 3] is 0.13178899196515867
# revenue of assortment [0, 6] is 0.1811235662526827
# revenue of assortment [0, 1, 4] is 0.3722530161619444
# revenue of assortment [0, 1, 5] is 0.38831427816946373
# revenue of assortment [0, 1, 7] is 0.33844446871293743
# testing for offertimes 20, 44th instance
# revenue of assortment [0, 6] is 0.1878263595796957
# revenue of assortment [0, 1, 4] is 0.3576427221835221
# revenue of assortment [0, 3, 5] is 0.18248161274676386
# revenue of assortment [0, 4, 5] is 0.36660266116606777
# revenue of assortment [0, 4, 6] is 0.20513163441002416
# testing for offertimes 20, 45th instance
# revenue of assortment [0, 1, 5] is 0.39149257151899847
# revenue of assortment [0, 1, 6] is 0.19621844728690263
# revenue of assortment [0, 2, 6] is 0.17041289950703192
# revenue of assortment [0, 3, 4] is 0.21894044780259656
# revenue of assortment [0, 4, 7] is 0.322976918793921
# testing for offertimes 20, 46th instance
# revenue of assortment [0, 1] is 0.42558666052141636
# revenue of assortment [0, 4] is 0.4322035913954532
# revenue of assortment [0, 1, 5] is 0.4423578761586346
# revenue of assortment [0, 1, 8] is 0.4339504763299265
# revenue of assortment [0, 3, 4] is 0.25324736887296023
# testing for offertimes 20, 47th instance
# revenue of assortment [0, 7] is 0.2366046968630442
# revenue of assortment [0, 1, 4] is 0.354425412383037
# revenue of assortment [0, 1, 6] is 0.22624456784491542
# revenue of assortment [0, 2, 3, 6] is 0.17314815595692373
# revenue of assortment [0, 5, 8] is 0.41026287252714166
# testing for offertimes 20, 48th instance
# revenue of assortment [0, 4] is 0.4295060575803282
# revenue of assortment [0, 1, 4] is 0.4123004831170322
# revenue of assortment [0, 3, 5] is 0.4249977447616907
# revenue of assortment [0, 4, 8] is 0.43783435585396685
# revenue of assortment [0, 8] is 0.2273318100283425
# testing for offertimes 20, 49th instance
# revenue of assortment [0, 1] is 0.33585327933029335
# revenue of assortment [0, 7] is 0.2659049915529245
# revenue of assortment [0, 2, 3, 6] is 0.1704903314848088
# revenue of assortment [0, 3, 8] is 0.17786157684135717
# revenue of assortment [0, 6, 7] is 0.26047063517068725
# testing for offertimes 30, 0th instance
# revenue of assortment [0, 1] is 0.4304807316969665
# revenue of assortment [0, 5] is 0.3636544332359074
# revenue of assortment [0, 1, 3] is 0.414975074187597
# revenue of assortment [0, 1, 8] is 0.43515498200523695
# testing for offertimes 30, 1th instance
# revenue of assortment [0, 2] is 0.14183773370448338
# revenue of assortment [0, 6] is 0.030773215220887513
# revenue of assortment [0, 3, 4] is 0.1784509014262541
# revenue of assortment [0, 8] is 0.2604815955644852
# testing for offertimes 30, 2th instance
# revenue of assortment [0, 2, 6] is 0.15096448479336083
# revenue of assortment [0, 3, 7] is 0.16696067963257216
# revenue of assortment [0, 6, 7] is 0.1845805380800601
# revenue of assortment [0, 6, 8] is 0.391008025737089
# testing for offertimes 30, 3th instance
# revenue of assortment [0, 1, 3] is 0.15715660452440536
# revenue of assortment [0, 4, 5] is 0.42970338934681385
# revenue of assortment [0, 5, 8] is 0.5329494568564378
# revenue of assortment [0, 6, 8] is 0.4644953134574744
# testing for offertimes 30, 4th instance
# revenue of assortment [0, 1, 3] is 0.20606806711101963
# revenue of assortment [0, 3, 4] is 0.1495976442121457
# revenue of assortment [0, 3, 7] is 0.3552733423458868
# revenue of assortment [0, 5, 8] is 0.8516061765004469
# testing for offertimes 30, 5th instance
# revenue of assortment [0, 1] is 0.12005007893274783
# revenue of assortment [0, 1, 8] is 0.27660587959076566
# revenue of assortment [0, 4, 6] is 0.23714445217462388
# revenue of assortment [0, 6, 7] is 0.17986458174213504
# testing for offertimes 30, 6th instance
# revenue of assortment [0, 1, 6] is 0.20137512813452563
# revenue of assortment [0, 2, 6] is 0.20943477669859953
# revenue of assortment [0, 5, 8] is 0.444708887235232
# revenue of assortment [0, 6, 7] is 0.35798285201057856
# testing for offertimes 30, 7th instance
# revenue of assortment [0, 2] is 0.16492567085372456
# revenue of assortment [0, 5] is 0.23154836574626197
# revenue of assortment [0, 1, 5] is 0.2827176894698555
# revenue of assortment [0, 8] is 0.3094282136781189
# testing for offertimes 30, 8th instance
# revenue of assortment [0, 2] is 0.17936600392451055
# revenue of assortment [0, 3] is 0.12360963735923067
# revenue of assortment [0, 7] is 0.10566896767051194
# revenue of assortment [0, 1, 5] is 0.35089174954188684
# testing for offertimes 30, 9th instance
# revenue of assortment [0, 3] is 0.13778323771827106
# revenue of assortment [0, 6] is 0.18497742842002254
# revenue of assortment [0, 1, 5] is 0.4491969495608624
# revenue of assortment [0, 8] is 0.20641199088490086
# testing for offertimes 30, 10th instance
# revenue of assortment [0, 5] is 0.2141890560510236
# revenue of assortment [0, 1, 4] is 0.33880681038950555
# revenue of assortment [0, 2, 6] is 0.17526147578187787
# revenue of assortment [0, 4, 6] is 0.18731527695829592
# testing for offertimes 30, 11th instance
# revenue of assortment [0, 1] is 0.28866889805640406
# revenue of assortment [0, 2] is 0.08039701992112346
# revenue of assortment [0, 4, 5] is 0.510618881239604
# revenue of assortment [0, 4, 6] is 0.34770695877904667
# testing for offertimes 30, 12th instance
# revenue of assortment [0, 6] is 0.15171583450340959
# revenue of assortment [0, 7] is 0.17297907230404191
# revenue of assortment [0, 3, 4] is 0.1602540147198671
# revenue of assortment [0, 4, 6] is 0.18586551400848028
# testing for offertimes 30, 13th instance
# revenue of assortment [0, 2] is 0.18004918361608058
# revenue of assortment [0, 3, 7] is 0.1308099083870843
# revenue of assortment [0, 5, 6] is 0.3025653581941476
# revenue of assortment [0, 6, 8] is 0.1595792903734406
# testing for offertimes 30, 14th instance
# revenue of assortment [0, 4] is 0.20868634209769796
# revenue of assortment [0, 7] is 0.1862172516055881
# revenue of assortment [0, 1, 7] is 0.22467000035011297
# revenue of assortment [0, 1, 8] is 0.2954569366848785
# testing for offertimes 30, 15th instance
# revenue of assortment [0, 7] is 0.19015799909381823
# revenue of assortment [0, 2, 6] is 0.18157312026856054
# revenue of assortment [0, 4, 6] is 0.27887151307720076
# revenue of assortment [0, 6, 7] is 0.20174663686730054
# testing for offertimes 30, 16th instance
# revenue of assortment [0, 4] is 3.9474985502607754e-12
# revenue of assortment [0, 7] is 0.12597408297503107
# revenue of assortment [0, 3, 6] is 0.18574072111875684
# revenue of assortment [0, 4, 6] is 0.16838352914136623
# testing for offertimes 30, 17th instance
# revenue of assortment [0, 1, 5] is 0.38257419875080084
# revenue of assortment [0, 1, 8] is 0.383212809550986
# revenue of assortment [0, 3, 7] is 0.26777859579458163
# revenue of assortment [0, 6, 7] is 0.2387321517958433
# testing for offertimes 30, 18th instance
# revenue of assortment [0, 1] is 0.39686631169883035
# revenue of assortment [0, 1, 6] is 0.3162307877357795
# revenue of assortment [0, 3, 6] is 0.18609652740860855
# revenue of assortment [0, 5, 6] is 0.2500868307177575
# testing for offertimes 30, 19th instance
# revenue of assortment [0, 1] is 0.18925332629023534
# revenue of assortment [0, 6] is 0.13088082705380857
# revenue of assortment [0, 1, 5] is 0.30390227555211013
# revenue of assortment [0, 1, 8] is 0.29062853052196386
# testing for offertimes 30, 20th instance
# revenue of assortment [0, 5] is 0.38745063682359254
# revenue of assortment [0, 7] is 0.1845446636381884
# revenue of assortment [0, 1, 6] is 0.37632704138280604
# revenue of assortment [0, 4, 6] is 0.3499570405456813
# testing for offertimes 30, 21th instance
# revenue of assortment [0, 7] is 0.18676325829725235
# revenue of assortment [0, 1, 4] is 0.4053530365988287
# revenue of assortment [0, 1, 6] is 0.21198614016558223
# revenue of assortment [0, 2, 6] is 0.2052041420275062
# testing for offertimes 30, 22th instance
# revenue of assortment [0, 4] is 0.4011910724153201
# revenue of assortment [0, 1, 8] is 0.37008313605404963
# revenue of assortment [0, 4, 5] is 0.4112309739750343
# revenue of assortment [0, 6, 7] is 0.20401179030686659
# testing for offertimes 30, 23th instance
# revenue of assortment [0, 1, 7] is 0.2997840438463
# revenue of assortment [0, 3, 6] is 0.1743384347594258
# revenue of assortment [0, 4, 5] is 0.43543099088650117
# revenue of assortment [0, 6, 7] is 0.1915957864375567
# testing for offertimes 30, 24th instance
# revenue of assortment [0, 3] is 0.0876257937330434
# revenue of assortment [0, 1, 3] is 0.30271669901708476
# revenue of assortment [0, 4, 5] is 0.3877567502464315
# revenue of assortment [0, 8] is 0.15223720764760149
# testing for offertimes 30, 25th instance
# revenue of assortment [0, 2] is 0.13918056674139342
# revenue of assortment [0, 3] is 0.07901376324213141
# revenue of assortment [0, 5] is 0.21880187799058412
# revenue of assortment [0, 6] is 0.14002374654178917
# testing for offertimes 30, 26th instance
# revenue of assortment [0, 6] is 0.1296785030632056
# revenue of assortment [0, 7] is 0.24080820249906934
# revenue of assortment [0, 1, 4] is 0.48176375037512287
# revenue of assortment [0, 4, 5] is 0.5106712221744765
# testing for offertimes 30, 27th instance
# revenue of assortment [0, 1, 4] is 0.3114471330479805
# revenue of assortment [0, 1, 6] is 0.19135005406129138
# revenue of assortment [0, 3, 7] is 0.1426737916586709
# revenue of assortment [0, 5, 6] is 0.49213223948540186
# testing for offertimes 30, 28th instance
# revenue of assortment [0, 4] is 0.2720432911086682
# revenue of assortment [0, 1, 5] is 0.3083379443484432
# revenue of assortment [0, 1, 6] is 0.2062501948512444
# revenue of assortment [0, 1, 7] is 0.25695510992697934
# testing for offertimes 30, 29th instance
# revenue of assortment [0, 1, 3] is 0.1561526616854587
# revenue of assortment [0, 3, 6] is 0.25598795933591556
# revenue of assortment [0, 5, 6] is 0.2302748674025662
# revenue of assortment [0, 6, 8] is 0.24064691760786816
# testing for offertimes 30, 30th instance
# revenue of assortment [0, 4] is 0.49758732980557807
# revenue of assortment [0, 5] is 0.42603652222396104
# revenue of assortment [0, 4, 5] is 0.4884651059111512
# revenue of assortment [0, 4, 6] is 0.36380522096362483
# testing for offertimes 30, 31th instance
# revenue of assortment [0, 4] is 0.3259725419631842
# revenue of assortment [0, 5] is 0.027312253198516722
# revenue of assortment [0, 1, 6] is 0.2947092199669375
# revenue of assortment [0, 1, 8] is 0.5414354344739017
# testing for offertimes 30, 32th instance
# revenue of assortment [0, 3] is 0.10436774957621228
# revenue of assortment [0, 1, 8] is 0.4296522455817283
# revenue of assortment [0, 4, 6] is 0.19097508679343134
# revenue of assortment [0, 5, 6] is 0.1848237869453158
# testing for offertimes 30, 33th instance
# revenue of assortment [0, 3] is 0.11233018028913633
# revenue of assortment [0, 1, 3] is 0.2598886922100699
# revenue of assortment [0, 4, 5] is 0.4221564201804705
# revenue of assortment [0, 4, 6] is 0.23002000679238035
# testing for offertimes 30, 34th instance
# revenue of assortment [0, 1, 4] is 0.3244227436441536
# revenue of assortment [0, 1, 5] is 0.25312648445292973
# revenue of assortment [0, 1, 7] is 0.20697788219369598
# revenue of assortment [0, 4, 6] is 0.20522698590807076
# testing for offertimes 30, 35th instance
# revenue of assortment [0, 4] is 1.5119629548365765e-11
# revenue of assortment [0, 1, 4] is 0.34060446552508117
# revenue of assortment [0, 3, 4] is 0.11810339865607211
# revenue of assortment [0, 4, 5] is 0.2391375635361019
# testing for offertimes 30, 36th instance
# revenue of assortment [0, 1] is 0.3100297526199712
# revenue of assortment [0, 2] is 0.11259523857942728
# revenue of assortment [0, 4] is 6.159113219439405e-13
# revenue of assortment [0, 1, 5] is 0.535837920615508
# testing for offertimes 30, 37th instance
# revenue of assortment [0, 1] is 0.3425528789277827
# revenue of assortment [0, 3] is 0.14802161362161362
# revenue of assortment [0, 5, 6] is 0.1808278322371738
# revenue of assortment [0, 6, 7] is 0.1851841670861583
# testing for offertimes 30, 38th instance
# revenue of assortment [0, 6] is 0.12390105692807057
# revenue of assortment [0, 1, 3] is 0.36542200975111455
# revenue of assortment [0, 2, 6] is 0.17049462580108174
# revenue of assortment [0, 4, 6] is 0.38593018769343634
# testing for offertimes 30, 39th instance
# revenue of assortment [0, 4] is 1.3144224597638753e-12
# revenue of assortment [0, 6] is 0.14386437640345484
# revenue of assortment [0, 3, 4] is 0.10037615168132939
# revenue of assortment [0, 6, 7] is 0.16917502235607157
# testing for offertimes 30, 40th instance
# revenue of assortment [0, 4] is 0.16625382251386
# revenue of assortment [0, 6] is 0.18400909894812023
# revenue of assortment [0, 1, 3] is 0.1713301846201487
# revenue of assortment [0, 8] is 0.34118314424928153
# testing for offertimes 30, 41th instance
# revenue of assortment [0, 1, 5] is 0.43624602226535153
# revenue of assortment [0, 1, 8] is 0.41522939236243317
# revenue of assortment [0, 2, 6] is 0.1561751388262454
# revenue of assortment [0, 4, 5] is 0.4525575648013705
# testing for offertimes 30, 42th instance
# revenue of assortment [0, 1, 4] is 0.5577629861088133
# revenue of assortment [0, 3, 6] is 0.14022445438088957
# revenue of assortment [0, 4, 5] is 0.6073296225759826
# revenue of assortment [0, 6, 8] is 0.2788685817934109
# testing for offertimes 30, 43th instance
# revenue of assortment [0, 4] is 4.7633051059037255e-11
# revenue of assortment [0, 7] is 0.13619585498143164
# revenue of assortment [0, 1, 6] is 0.26646530537678076
# revenue of assortment [0, 5, 8] is 0.3967114267902982
# testing for offertimes 30, 44th instance
# revenue of assortment [0, 1] is 0.3084789083212542
# revenue of assortment [0, 2] is 2.275874155799329e-11
# revenue of assortment [0, 1, 5] is 0.34850102410670913
# revenue of assortment [0, 1, 6] is 0.22464456342337413
# testing for offertimes 30, 45th instance
# revenue of assortment [0, 1, 6] is 0.1960059461234555
# revenue of assortment [0, 3, 4] is 0.23595388989536348
# revenue of assortment [0, 5, 6] is 0.3729802283924413
# revenue of assortment [0, 8] is 0.457452263894394
# testing for offertimes 30, 46th instance
# revenue of assortment [0, 3] is 0.15495631116391792
# revenue of assortment [0, 1, 6] is 0.36377766280102874
# revenue of assortment [0, 1, 8] is 0.39563918475534443
# revenue of assortment [0, 5, 6] is 0.28176708034004516
# testing for offertimes 30, 47th instance
# revenue of assortment [0, 4] is 2.179604940977242e-12
# revenue of assortment [0, 7] is 0.22761893255562027
# revenue of assortment [0, 1, 4] is 0.2822257585112444
# revenue of assortment [0, 3, 4] is 0.12405986246211492
# testing for offertimes 30, 48th instance
# revenue of assortment [0, 3, 6] is 0.14798446271514915
# revenue of assortment [0, 4, 5] is 0.51602929117831
# revenue of assortment [0, 5, 6] is 0.41135772339346993
# revenue of assortment [0, 6, 8] is 0.23309283788351715
# testing for offertimes 30, 49th instance
# revenue of assortment [0, 6] is 0.1296634111609016
# revenue of assortment [0, 1, 4] is 0.47509708347515756
# revenue of assortment [0, 1, 7] is 0.2927656747636397
# revenue of assortment [0, 6, 7] is 0.22894335626728105
# testing for offertimes 40, 0th instance
# revenue of assortment [0, 7] is 0.2892086281683269
# revenue of assortment [0, 1, 5] is 0.6050112430825083
# revenue of assortment [0, 5, 8] is 0.45714800174312453
# testing for offertimes 40, 1th instance
# revenue of assortment [0, 7] is 9.323259941851348e-12
# revenue of assortment [0, 1, 3] is 0.3963347991432118
# revenue of assortment [0, 2, 6] is 0.17656839018430345
# testing for offertimes 40, 2th instance
# revenue of assortment [0, 3] is 0.15224676629467662
# revenue of assortment [0, 1, 4] is 0.391495792256821
# revenue of assortment [0, 8] is 0.4352588029832545
# testing for offertimes 40, 3th instance
# revenue of assortment [0, 3] is 0.14787172020653047
# revenue of assortment [0, 1, 6] is 0.1789692491487186
# revenue of assortment [0, 3, 7] is 0.16828710126130553
# testing for offertimes 40, 4th instance
# revenue of assortment [0, 1, 3] is 0.3783867600995413
# revenue of assortment [0, 1, 5] is 0.4028435656768247
# revenue of assortment [0, 3, 4] is 0.14970376037638689
# testing for offertimes 40, 5th instance
# revenue of assortment [0, 2] is 0.05834709203572663
# revenue of assortment [0, 6] is 0.1615515487879349
# revenue of assortment [0, 1, 6] is 0.18212782945442538
# testing for offertimes 40, 6th instance
# revenue of assortment [0, 1, 3] is 0.21718703567306424
# revenue of assortment [0, 1, 5] is 0.32710811579496785
# revenue of assortment [0, 1, 6] is 0.20144339100030617
# testing for offertimes 40, 7th instance
# revenue of assortment [0, 3] is 0.14519324227065936
# revenue of assortment [0, 4] is 0.29332418016334283
# revenue of assortment [0, 1, 6] is 0.15845920294457178
# testing for offertimes 40, 8th instance
# revenue of assortment [0, 1] is 0.1287489237962117
# revenue of assortment [0, 1, 3] is 0.140131422121718
# revenue of assortment [0, 8] is 0.3403846781255008
# testing for offertimes 40, 9th instance
# revenue of assortment [0, 3] is 0.11725146754972605
# revenue of assortment [0, 1, 3] is 0.23615859617189444
# revenue of assortment [0, 3, 4] is 0.17490750229171836
# testing for offertimes 40, 10th instance
# revenue of assortment [0, 3] is 0.11617078111719001
# revenue of assortment [0, 1, 4] is 0.35075409560161586
# revenue of assortment [0, 5, 8] is 0.46729153981634153
# testing for offertimes 40, 11th instance
# revenue of assortment [0, 1] is 0.2844879272095524
# revenue of assortment [0, 3] is 0.14621753857737183
# revenue of assortment [0, 5, 8] is 0.46796854142950434
# testing for offertimes 40, 12th instance
# revenue of assortment [0, 1, 5] is 0.32767033999035156
# revenue of assortment [0, 2, 6] is 0.18997663903826592
# revenue of assortment [0, 4, 6] is 0.18821016491922543
# testing for offertimes 40, 13th instance
# revenue of assortment [0, 4] is 0.28613557320101324
# revenue of assortment [0, 5] is 0.322060785915355
# revenue of assortment [0, 4, 6] is 0.18590300850665634
# testing for offertimes 40, 14th instance
# revenue of assortment [0, 3] is 0.1140198307429855
# revenue of assortment [0, 1, 6] is 0.19248866598618675
# revenue of assortment [0, 5, 6] is 0.33663135231486463
# testing for offertimes 40, 15th instance
# revenue of assortment [0, 6] is 0.10878396322471942
# revenue of assortment [0, 5, 6] is 0.29194785399623446
# revenue of assortment [0, 5, 8] is 0.44745091810342746
# testing for offertimes 40, 16th instance
# revenue of assortment [0, 5] is 0.399603428878405
# revenue of assortment [0, 1, 6] is 0.20972511316123144
# revenue of assortment [0, 8] is 2.1968562524676828e-12
# testing for offertimes 40, 17th instance
# revenue of assortment [0, 4] is 0.1132984403231489
# revenue of assortment [0, 1, 5] is 0.3915267889510885
# revenue of assortment [0, 5, 6] is 0.3423716899408318
# testing for offertimes 40, 18th instance
# revenue of assortment [0, 5] is 0.3346105497533428
# revenue of assortment [0, 7] is 2.5436139416967765e-10
# revenue of assortment [0, 1, 5] is 0.38501115521515034
# testing for offertimes 40, 19th instance
# revenue of assortment [0, 2] is 0.06520944269461972
# revenue of assortment [0, 5] is 0.2539501786204958
# revenue of assortment [0, 5, 8] is 0.3707736848261399
# testing for offertimes 40, 20th instance
# revenue of assortment [0, 7] is 0.12185703037955682
# revenue of assortment [0, 1, 6] is 0.37444904642137194
# revenue of assortment [0, 5, 8] is 0.4447591515542402
# testing for offertimes 40, 21th instance
# revenue of assortment [0, 6] is 0.16095656963751262
# revenue of assortment [0, 1, 5] is 0.3389331789005609
# revenue of assortment [0, 3, 6] is 0.16864053886428343
# testing for offertimes 40, 22th instance
# revenue of assortment [0, 2] is 0.06438024505522767
# revenue of assortment [0, 6] is 0.16324636910238577
# revenue of assortment [0, 5, 8] is 0.44023968490236937
# testing for offertimes 40, 23th instance
# revenue of assortment [0, 3] is 0.15547011862928695
# revenue of assortment [0, 1, 3] is 0.22216481459426413
# revenue of assortment [0, 1, 4] is 0.3712662052894606
# testing for offertimes 40, 24th instance
# revenue of assortment [0, 1, 4] is 0.3625443731318242
# revenue of assortment [0, 3, 6] is 0.17450412409991145
# revenue of assortment [0, 3, 7] is 0.21260609211733977
# testing for offertimes 40, 25th instance
# revenue of assortment [0, 1] is 0.379317550916054
# revenue of assortment [0, 1, 6] is 0.3279529069456528
# revenue of assortment [0, 3, 4] is 0.45684156874647774
# testing for offertimes 40, 26th instance
# revenue of assortment [0, 6] is 0.12020882855060497
# revenue of assortment [0, 1, 4] is 0.4939270948647203
# revenue of assortment [0, 4, 6] is 0.46907231331154386
# testing for offertimes 40, 27th instance
# revenue of assortment [0, 1] is 0.2167365542169767
# revenue of assortment [0, 3, 6] is 0.2512098678815432
# revenue of assortment [0, 8] is 6.466709390196002e-13
# testing for offertimes 40, 28th instance
# revenue of assortment [0, 1, 4] is 0.37743554361136106
# revenue of assortment [0, 3, 4] is 0.2149351760053252
# revenue of assortment [0, 8] is 0.5542370676193608
# testing for offertimes 40, 29th instance
# revenue of assortment [0, 6] is 0.1909405200206921
# revenue of assortment [0, 3, 4] is 0.253221941037884
# revenue of assortment [0, 8] is 0.38947477018751087
# testing for offertimes 40, 30th instance
# revenue of assortment [0, 3] is 0.09501018290168782
# revenue of assortment [0, 1, 3] is 0.22109547628013237
# revenue of assortment [0, 4, 6] is 0.3653235439344308
# testing for offertimes 40, 31th instance
# revenue of assortment [0, 1] is 0.3628233405437689
# revenue of assortment [0, 6] is 0.09655124327535851
# revenue of assortment [0, 5, 6] is 0.22608591309528514
# testing for offertimes 40, 32th instance
# revenue of assortment [0, 1, 6] is 0.19969493413845812
# revenue of assortment [0, 3, 7] is 0.2038145912099282
# revenue of assortment [0, 5, 6] is 0.18643756334089612
# testing for offertimes 40, 33th instance
# revenue of assortment [0, 1, 3] is 0.34993811832396265
# revenue of assortment [0, 1, 6] is 0.37683732551573706
# revenue of assortment [0, 8] is 0.4143963514230429
# testing for offertimes 40, 34th instance
# revenue of assortment [0, 1, 3] is 0.1474091369539522
# revenue of assortment [0, 4, 6] is 0.19057455675610663
# revenue of assortment [0, 8] is 0.43561693339500357
# testing for offertimes 40, 35th instance
# revenue of assortment [0, 1, 4] is 0.43515180520291374
# revenue of assortment [0, 1, 6] is 0.31932121002880065
# revenue of assortment [0, 3, 6] is 0.17802563254104578
# testing for offertimes 40, 36th instance
# revenue of assortment [0, 2] is 0.1490413936521774
# revenue of assortment [0, 3] is 0.10469478996503796
# revenue of assortment [0, 1, 3] is 0.32469903174718273
# testing for offertimes 40, 37th instance
# revenue of assortment [0, 6] is 0.17871517024120478
# revenue of assortment [0, 2, 6] is 0.20389202706955853
# revenue of assortment [0, 5, 6] is 0.19150710554486955
# testing for offertimes 40, 38th instance
# revenue of assortment [0, 7] is 0.2628882246320733
# revenue of assortment [0, 1, 5] is 0.4005003171393925
# revenue of assortment [0, 5, 6] is 0.24963421673128627
# testing for offertimes 40, 39th instance
# revenue of assortment [0, 1, 5] is 0.31981488569121014
# revenue of assortment [0, 2, 6] is 0.19558511207154008
# revenue of assortment [0, 8] is 0.4546825776834024
# testing for offertimes 40, 40th instance
# revenue of assortment [0, 3] is 0.1495742113535164
# revenue of assortment [0, 6] is 0.19277591434545627
# revenue of assortment [0, 3, 7] is 0.20353674355946055
# testing for offertimes 40, 41th instance
# revenue of assortment [0, 4] is 0.41616160589711754
# revenue of assortment [0, 3, 4] is 0.32725359175204943
# revenue of assortment [0, 5, 6] is 0.3189239792860361
# testing for offertimes 40, 42th instance
# revenue of assortment [0, 5] is 0.2669280643609809
# revenue of assortment [0, 6] is 0.11213384316052143
# revenue of assortment [0, 1, 4] is 0.54533366448605
# testing for offertimes 40, 43th instance
# revenue of assortment [0, 2] is 0.08793449417361313
# revenue of assortment [0, 7] is 0.13895405104943745
# revenue of assortment [0, 3, 6] is 0.17642714108590524
# testing for offertimes 40, 44th instance
# revenue of assortment [0, 2, 6] is 0.19087394411617242
# revenue of assortment [0, 3, 4] is 0.1764132602737295
# revenue of assortment [0, 4, 6] is 0.20462727086218535
# testing for offertimes 40, 45th instance
# revenue of assortment [0, 6] is 0.17762023824783754
# revenue of assortment [0, 3, 4] is 0.23975890402589806
# revenue of assortment [0, 5, 6] is 0.3381481654312244
# testing for offertimes 40, 46th instance
# revenue of assortment [0, 2] is 0.14296713584062815
# revenue of assortment [0, 5, 6] is 0.27838445685852026
# revenue of assortment [0, 5, 8] is 0.4376516273162926
# testing for offertimes 40, 47th instance
# revenue of assortment [0, 3] is 0.1210614112283476
# revenue of assortment [0, 4] is 1.7842112121080334e-11
# revenue of assortment [0, 1, 4] is 0.285487660569444
# testing for offertimes 40, 48th instance
# revenue of assortment [0, 3] is 0.14511705867270255
# revenue of assortment [0, 5] is 0.43261423396992804
# revenue of assortment [0, 1, 4] is 0.48986034201026896
# testing for offertimes 40, 49th instance
# revenue of assortment [0, 3] is 0.16843637916496845
# revenue of assortment [0, 1, 3] is 0.2461007183416813
# revenue of assortment [0, 3, 7] is 0.21901573787928932
# testing for offertimes 50, 0th instance
# revenue of assortment [0, 3] is 0.09228954499934865
# revenue of assortment [0, 6] is 0.060476715088182996
# revenue of assortment [0, 1, 3] is 0.36778872116445516
# testing for offertimes 50, 1th instance
# revenue of assortment [0, 3] is 0.13395111637633958
# revenue of assortment [0, 1, 3] is 0.32947708948581517
# revenue of assortment [0, 1, 6] is 0.2810205620992127
# testing for offertimes 50, 2th instance
# revenue of assortment [0, 4] is 1.5250611884454202e-13
# revenue of assortment [0, 5] is 0.09117869989214746
# revenue of assortment [0, 8] is 0.38457047576522596
# testing for offertimes 50, 3th instance
# revenue of assortment [0, 1] is 0.16750020835636126
# revenue of assortment [0, 1, 3] is 0.16924968930033252
# revenue of assortment [0, 1, 6] is 0.18251854138447457
# testing for offertimes 50, 4th instance
# revenue of assortment [0, 1] is 0.3072473159139381
# revenue of assortment [0, 1, 6] is 0.272160636901091
# revenue of assortment [0, 2, 6] is 0.16559362485390583
# testing for offertimes 50, 5th instance
# revenue of assortment [0, 4] is 0.4916340983677242
# revenue of assortment [0, 5] is 0.12905221137058007
# revenue of assortment [0, 5, 8] is 0.3594790334798465
# testing for offertimes 50, 6th instance
# revenue of assortment [0, 3] is 0.06879916839282414
# revenue of assortment [0, 4] is 0.450467244011949
# revenue of assortment [0, 5] is 0.21596637426404652
# testing for offertimes 50, 7th instance
# revenue of assortment [0, 5] is 0.2537597030718271
# revenue of assortment [0, 1, 6] is 0.16260071439729068
# revenue of assortment [0, 8] is 0.16752554750083787
# testing for offertimes 50, 8th instance
# revenue of assortment [0, 5] is 0.3422139833626267
# revenue of assortment [0, 2, 6] is 0.20589825104898446
# revenue of assortment [0, 5, 6] is 0.3146502533352307
# testing for offertimes 50, 9th instance
# revenue of assortment [0, 1, 3] is 0.23467717644022462
# revenue of assortment [0, 5, 6] is 0.34379514826482027
# revenue of assortment [0, 5, 8] is 0.5609247832990434
# testing for offertimes 50, 10th instance
# revenue of assortment [0, 3] is 0.10966982773581936
# revenue of assortment [0, 1, 4] is 0.40063456109164625
# revenue of assortment [0, 5, 8] is 0.46928663621605987
# testing for offertimes 50, 11th instance
# revenue of assortment [0, 2] is 0.07979096375762762
# revenue of assortment [0, 5, 6] is 0.2753132648384805
# revenue of assortment [0, 5, 8] is 0.47853253744301644
# testing for offertimes 50, 12th instance
# revenue of assortment [0, 4] is 0.14257531476620344
# revenue of assortment [0, 5] is 0.3217972024128359
# revenue of assortment [0, 5, 6] is 0.2803330249189439
# testing for offertimes 50, 13th instance
# revenue of assortment [0, 1] is 0.19853586850963142
# revenue of assortment [0, 2] is 0.17741085897699557
# revenue of assortment [0, 5, 6] is 0.34410272228490757
# testing for offertimes 50, 14th instance
# revenue of assortment [0, 2] is 0.17746341481295813
# revenue of assortment [0, 1, 6] is 0.20020282235272013
# revenue of assortment [0, 3, 6] is 0.16292737626505285
# testing for offertimes 50, 15th instance
# revenue of assortment [0, 1] is 0.3893588826018888
# revenue of assortment [0, 5] is 0.1792340728350838
# revenue of assortment [0, 1, 4] is 0.501567864722649
# testing for offertimes 50, 16th instance
# revenue of assortment [0, 2, 6] is 0.1889413966413774
# revenue of assortment [0, 3, 6] is 0.1854557558205257
# revenue of assortment [0, 5, 6] is 0.5310678744871096
# testing for offertimes 50, 17th instance
# revenue of assortment [0, 6] is 0.09600193158212839
# revenue of assortment [0, 1, 4] is 0.3738276560484044
# revenue of assortment [0, 1, 6] is 0.28745620318881376
# testing for offertimes 50, 18th instance
# revenue of assortment [0, 6] is 0.1804646781127149
# revenue of assortment [0, 1, 4] is 0.4693750247574977
# revenue of assortment [0, 2, 6] is 0.19304499874680692
# testing for offertimes 50, 19th instance
# revenue of assortment [0, 6] is 0.1316664393598474
# revenue of assortment [0, 1, 4] is 0.3706902578997002
# revenue of assortment [0, 5, 6] is 0.3004529993346674
# testing for offertimes 50, 20th instance
# revenue of assortment [0, 1] is 0.4035482077557359
# revenue of assortment [0, 2] is 0.17413933519332847
# revenue of assortment [0, 1, 3] is 0.4396590801603977
# testing for offertimes 50, 21th instance
# revenue of assortment [0, 6] is 0.16016262636299625
# revenue of assortment [0, 1, 3] is 0.21640709015394827
# revenue of assortment [0, 3, 6] is 0.1616097265740788
# testing for offertimes 50, 22th instance
# revenue of assortment [0, 6] is 0.1584594422634571
# revenue of assortment [0, 3, 6] is 0.22163954858037987
# revenue of assortment [0, 5, 6] is 0.307907235131242
# testing for offertimes 50, 23th instance
# revenue of assortment [0, 1, 3] is 0.37916872933021084
# revenue of assortment [0, 1, 6] is 0.36026573645719157
# revenue of assortment [0, 2, 6] is 0.19612514708712311
# testing for offertimes 50, 24th instance
# revenue of assortment [0, 1] is 0.3653095597232421
# revenue of assortment [0, 5] is 0.40088874890463305
# revenue of assortment [0, 2, 6] is 0.19413428349583398
# testing for offertimes 50, 25th instance
# revenue of assortment [0, 1, 6] is 0.312717940158194
# revenue of assortment [0, 3, 6] is 0.15455862833174525
# revenue of assortment [0, 5, 8] is 0.4378286158078495
# testing for offertimes 50, 26th instance
# revenue of assortment [0, 1, 4] is 0.5228667473892538
# revenue of assortment [0, 3, 6] is 0.1565659137632133
# revenue of assortment [0, 5, 8] is 0.4783815140303963
# testing for offertimes 50, 27th instance
# revenue of assortment [0, 4] is 0.185134583337377
# revenue of assortment [0, 1, 3] is 0.28459668461313864
# revenue of assortment [0, 1, 6] is 0.40290174456853123
# testing for offertimes 50, 28th instance
# revenue of assortment [0, 3] is 0.1312170776297974
# revenue of assortment [0, 5] is 0.018390513874414822
# revenue of assortment [0, 3, 6] is 0.2044520212218351
# testing for offertimes 50, 29th instance
# revenue of assortment [0, 1] is 0.005706307336255608
# revenue of assortment [0, 1, 4] is 0.38686567799650523
# revenue of assortment [0, 2, 6] is 0.18327438167577
# testing for offertimes 50, 30th instance
# revenue of assortment [0, 2] is 0.17505161531414007
# revenue of assortment [0, 3, 6] is 0.14897705635430591
# revenue of assortment [0, 8] is 0.37739802949601414
# testing for offertimes 50, 31th instance
# revenue of assortment [0, 4] is 0.3436005637362171
# revenue of assortment [0, 1, 3] is 0.24591093132676334
# revenue of assortment [0, 3, 6] is 0.16214850659458585
# testing for offertimes 50, 32th instance
# revenue of assortment [0, 5] is 0.12116526545716254
# revenue of assortment [0, 2, 6] is 0.1949968536338503
# revenue of assortment [0, 8] is 0.36356001848074776
# testing for offertimes 50, 33th instance
# revenue of assortment [0, 3] is 0.10705003869840053
# revenue of assortment [0, 2, 6] is 0.19204760333849205
# revenue of assortment [0, 3, 6] is 0.1838325551877996
# testing for offertimes 50, 34th instance
# revenue of assortment [0, 3] is 0.10601260778607274
# revenue of assortment [0, 5] is 0.09670081198056622
# revenue of assortment [0, 5, 6] is 0.1538503656937767
# testing for offertimes 50, 35th instance
# revenue of assortment [0, 2] is 0.10399645115852905
# revenue of assortment [0, 5, 6] is 0.19282712311200229
# revenue of assortment [0, 8] is 0.45256175831043405
# testing for offertimes 50, 36th instance
# revenue of assortment [0, 1] is 0.3860636128583248
# revenue of assortment [0, 6] is 0.14542191684300992
# revenue of assortment [0, 1, 6] is 0.34904443851911326
# testing for offertimes 50, 37th instance
# revenue of assortment [0, 5] is 0.14946620050684578
# revenue of assortment [0, 5, 6] is 0.18249170098056583
# revenue of assortment [0, 8] is 0.36382233333584646
# testing for offertimes 50, 38th instance
# revenue of assortment [0, 3] is 0.09013659458070986
# revenue of assortment [0, 5] is 0.22975386094821404
# revenue of assortment [0, 1, 4] is 0.4887273669364992
# testing for offertimes 50, 39th instance
# revenue of assortment [0, 5] is 0.0685259676354563
# revenue of assortment [0, 1, 3] is 0.20336818185858743
# revenue of assortment [0, 5, 8] is 0.4047517555197481
# testing for offertimes 50, 40th instance
# revenue of assortment [0, 3] is 0.1219634466298579
# revenue of assortment [0, 1, 3] is 0.1997195939468439
# revenue of assortment [0, 8] is 0.050111233665575676
# testing for offertimes 50, 41th instance
# revenue of assortment [0, 2] is 0.17092613403082793
# revenue of assortment [0, 1, 4] is 0.47125629521517404
# revenue of assortment [0, 3, 6] is 0.14275320670314973
# testing for offertimes 50, 42th instance
# revenue of assortment [0, 1] is 0.27725220254729144
# revenue of assortment [0, 3] is 0.13164687071844677
# revenue of assortment [0, 1, 3] is 0.18569501708867986
# testing for offertimes 50, 43th instance
# revenue of assortment [0, 3] is 0.10930967818803772
# revenue of assortment [0, 1, 4] is 0.42392652452312896
# revenue of assortment [0, 3, 6] is 0.1727649510981411
# testing for offertimes 50, 44th instance
# revenue of assortment [0, 5] is 0.30964715801776477
# revenue of assortment [0, 2, 6] is 0.20493951114167594
# revenue of assortment [0, 3, 6] is 0.297168614782838
# testing for offertimes 50, 45th instance
# revenue of assortment [0, 4] is 0.4347773383018111
# revenue of assortment [0, 5] is 0.3754637972225022
# revenue of assortment [0, 1, 6] is 0.20055722576451235
# testing for offertimes 50, 46th instance
# revenue of assortment [0, 5] is 0.27589564405100897
# revenue of assortment [0, 6] is 0.09757139718305952
# revenue of assortment [0, 8] is 0.14328393527419822
# testing for offertimes 50, 47th instance
# revenue of assortment [0, 1, 4] is 0.44883809715063205
# revenue of assortment [0, 2, 6] is 0.1580100845386144
# revenue of assortment [0, 5, 8] is 0.43538347815166534
# testing for offertimes 50, 48th instance
# revenue of assortment [0, 6] is 0.13051750355965075
# revenue of assortment [0, 1, 3] is 0.15918481176732152
# revenue of assortment [0, 1, 4] is 0.5254791546017616
# testing for offertimes 50, 49th instance
# revenue of assortment [0, 1] is 0.3266180752058448
# revenue of assortment [0, 1, 4] is 0.5166624084574818
# revenue of assortment [0, 3, 6] is 0.16163192711780977
# testing for offertimes 60, 0th instance
# revenue of assortment [0, 3] is 0.11196091018664696
# revenue of assortment [0, 5] is 0.3825678707379906
# testing for offertimes 60, 1th instance
# revenue of assortment [0, 5, 6] is 0.2699161705977544
# revenue of assortment [0, 5, 8] is 0.38088379216361823
# testing for offertimes 60, 2th instance
# revenue of assortment [0, 2, 6] is 0.15106941143195146
# revenue of assortment [0, 5, 8] is 0.5199479995474341
# testing for offertimes 60, 3th instance
# revenue of assortment [0, 5] is 0.16668167675517395
# revenue of assortment [0, 6] is 0.1577054065353507
# testing for offertimes 60, 4th instance
# revenue of assortment [0, 3, 6] is 0.14375303046360477
# revenue of assortment [0, 5, 8] is 0.5729998244507124
# testing for offertimes 60, 5th instance
# revenue of assortment [0, 3] is 0.17569871727890418
# revenue of assortment [0, 1, 6] is 0.22092079744753607
# testing for offertimes 60, 6th instance
# revenue of assortment [0, 5] is 0.20508836306960973
# revenue of assortment [0, 8] is 0.4125493788147073
# testing for offertimes 60, 7th instance
# revenue of assortment [0, 6] is 0.08487061336983504
# revenue of assortment [0, 3, 6] is 0.1414573840030052
# testing for offertimes 60, 8th instance
# revenue of assortment [0, 5] is 0.3734059290493794
# revenue of assortment [0, 3, 6] is 0.12924461699563583
# testing for offertimes 60, 9th instance
# revenue of assortment [0, 1] is 0.16093295720758496
# revenue of assortment [0, 5, 6] is 0.4733561641056033
# testing for offertimes 60, 10th instance
# revenue of assortment [0, 1, 6] is 0.2916756314270236
# revenue of assortment [0, 3, 6] is 0.15465135659673385
# testing for offertimes 60, 11th instance
# revenue of assortment [0, 3] is 0.13216740239598299
# revenue of assortment [0, 5, 8] is 0.4678381475303578
# testing for offertimes 60, 12th instance
# revenue of assortment [0, 1, 6] is 0.22899197886513442
# revenue of assortment [0, 2, 6] is 0.1882453158825113
# testing for offertimes 60, 13th instance
# revenue of assortment [0, 3] is 0.1018643626121982
# revenue of assortment [0, 8] is 6.828317911100612e-13
# testing for offertimes 60, 14th instance
# revenue of assortment [0, 1, 6] is 0.2298189526170264
# revenue of assortment [0, 5, 8] is 0.4005715583852312
# testing for offertimes 60, 15th instance
# revenue of assortment [0, 2] is 0.15010465437802142
# revenue of assortment [0, 5] is 0.17948266401144417
# testing for offertimes 60, 16th instance
# revenue of assortment [0, 2] is 3.138822535220243e-14
# revenue of assortment [0, 1, 6] is 0.24991979289199467
# testing for offertimes 60, 17th instance
# revenue of assortment [0, 1] is 0.28845472706206976
# revenue of assortment [0, 3] is 0.1113597886949801
# testing for offertimes 60, 18th instance
# revenue of assortment [0, 1] is 0.24259943974680073
# revenue of assortment [0, 3, 6] is 0.17834856342250371
# testing for offertimes 60, 19th instance
# revenue of assortment [0, 6] is 0.13109924575257045
# revenue of assortment [0, 5, 6] is 0.3003083481451962
# testing for offertimes 60, 20th instance
# revenue of assortment [0, 2] is 0.17367543606038746
# revenue of assortment [0, 3] is 0.12105505213372077
# testing for offertimes 60, 21th instance
# revenue of assortment [0, 5] is 0.2940396823455589
# revenue of assortment [0, 1, 6] is 0.3432332575172526
# testing for offertimes 60, 22th instance
# revenue of assortment [0, 2, 6] is 0.19616400317772534
# revenue of assortment [0, 3, 6] is 0.20377500516119149
# testing for offertimes 60, 23th instance
# revenue of assortment [0, 1] is 0.2809328772892131
# revenue of assortment [0, 2] is 0.0364677446673292
# testing for offertimes 60, 24th instance
# revenue of assortment [0, 1] is 0.16803579993429935
# revenue of assortment [0, 8] is 0.07472643935553655
# testing for offertimes 60, 25th instance
# revenue of assortment [0, 6] is 0.15919400032127823
# revenue of assortment [0, 1, 6] is 0.2841429694424066
# testing for offertimes 60, 26th instance
# revenue of assortment [0, 5, 6] is 0.28381565228639055
# revenue of assortment [0, 8] is 0.5296352417135155
# testing for offertimes 60, 27th instance
# revenue of assortment [0, 3] is 0.05682054413975394
# revenue of assortment [0, 5, 6] is 0.48658835985015525
# testing for offertimes 60, 28th instance
# revenue of assortment [0, 1] is 1.3156968847738425e-12
# revenue of assortment [0, 2, 6] is 0.16968162070277157
# testing for offertimes 60, 29th instance
# revenue of assortment [0, 5] is 0.2509075092916099
# revenue of assortment [0, 5, 6] is 0.23002115247824562
# testing for offertimes 60, 30th instance
# revenue of assortment [0, 3] is 0.0804655121770636
# revenue of assortment [0, 2, 6] is 0.15990434746055607
# testing for offertimes 60, 31th instance
# revenue of assortment [0, 1] is 0.3245939251241676
# revenue of assortment [0, 5] is 0.09864018426047852
# testing for offertimes 60, 32th instance
# revenue of assortment [0, 2] is 2.8162325804714785e-12
# revenue of assortment [0, 8] is 0.4662757887972846
# testing for offertimes 60, 33th instance
# revenue of assortment [0, 1, 6] is 0.3494360353328019
# revenue of assortment [0, 5, 6] is 0.27801201075594534
# testing for offertimes 60, 34th instance
# revenue of assortment [0, 3, 6] is 0.14161764650996592
# revenue of assortment [0, 8] is 0.4270294654290923
# testing for offertimes 60, 35th instance
# revenue of assortment [0, 3] is 7.982613459134314e-13
# revenue of assortment [0, 6] is 0.15795818735778203
# testing for offertimes 60, 36th instance
# revenue of assortment [0, 2, 6] is 0.17380993169710868
# revenue of assortment [0, 5, 6] is 0.3996903253534962
# testing for offertimes 60, 37th instance
# revenue of assortment [0, 1] is 0.24658441176352572
# revenue of assortment [0, 6] is 0.17811360296188444
# testing for offertimes 60, 38th instance
# revenue of assortment [0, 2] is 0.1782954751298651
# revenue of assortment [0, 5, 8] is 0.427904987351454
# testing for offertimes 60, 39th instance
# revenue of assortment [0, 5] is 0.06789375121214267
# revenue of assortment [0, 5, 8] is 0.4047125964217972
# testing for offertimes 60, 40th instance
# revenue of assortment [0, 2] is 0.14681178577968107
# revenue of assortment [0, 6] is 0.18694076089966505
# testing for offertimes 60, 41th instance
# revenue of assortment [0, 1] is 0.34850768475376903
# revenue of assortment [0, 5, 8] is 0.5025401682193176
# testing for offertimes 60, 42th instance
# revenue of assortment [0, 6] is 0.12036166490390171
# revenue of assortment [0, 8] is 0.2511275653738641
# testing for offertimes 60, 43th instance
# revenue of assortment [0, 2, 6] is 0.18605292955979474
# revenue of assortment [0, 8] is 0.1427459531127192
# testing for offertimes 60, 44th instance
# revenue of assortment [0, 6] is 0.18348868840275093
# revenue of assortment [0, 2, 6] is 0.18948254528124064
# testing for offertimes 60, 45th instance
# revenue of assortment [0, 2] is 2.842578439299359e-11
# revenue of assortment [0, 3, 6] is 0.19720535940981052
# testing for offertimes 60, 46th instance
# revenue of assortment [0, 6] is 0.10853336820500273
# revenue of assortment [0, 5, 8] is 0.42876944473323597
# testing for offertimes 60, 47th instance
# revenue of assortment [0, 1, 6] is 0.26953215579393175
# revenue of assortment [0, 8] is 0.4004636268534479
# testing for offertimes 60, 48th instance
# revenue of assortment [0, 3, 6] is 0.14667003293476033
# revenue of assortment [0, 5, 6] is 0.4082226624966565
# testing for offertimes 60, 49th instance
# revenue of assortment [0, 5] is 0.3063231847000624
# revenue of assortment [0, 2, 6] is 0.16377394255867353

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mem_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mem_dist':all_mem_distance_list[i],
                                    'true_best_rev':all_best_true_rev_list[i],'mem_best_rev':all_best_rev_mem_list[i],
                                    'mem_best_rev_diff':all_mem_best_rev_diff[i]})
    df_mem_details1.to_csv('prediction/mem/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        mem_rank = all_mem_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'mem_rank':mem_rank})
        df_rank.to_csv('prediction/mem/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        mem_rev = all_mem_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'mem_rev':mem_rev})
        df_rev.to_csv('prediction/mem/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
    
        mem_runtime = all_mem_pred_runtime[i][j]
        df_runtime = pd.DataFrame({'mem_runtime':mem_runtime})
        df_runtime.to_csv('prediction/mem/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ## using sales fraction prediction
        ## record the choice probability prediction interval
        ''' true_prob = all_true_prob_list[i][j]
        df_true_prob = pd.DataFrame(true_prob)
        
        mem_sales = all_mem_sales_list[i][j]
        df_mem_sales = pd.DataFrame(mem_sales).T
 
        df_true_prob.to_csv('prediction/mem/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_mem_sales.to_csv('prediction/mem/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mem/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## avg prediction mem runtime 
all_mem_pred_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    avg_mem_pred_runtime_collection = []
    
    for j in range(pred_instance_size[i]): 
        avg_mem_pred_runtime_collection.append(np.mean(np.array(all_mem_pred_runtime[i][j]))) 
        
    all_mem_pred_avg_runtime.append(np.mean(np.array(avg_mem_pred_runtime_collection)))

avg_mem_dist = []
avg_mem_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    
    avg_mem_dist.append(np.mean(all_mem_distance_list[i]))
    avg_mem_best_rev_diff.append(np.mean(all_mem_best_rev_diff[i]))
    

df_mem_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'avg_mem_dist':avg_mem_dist,'avg_mem_best_rev_diff':avg_mem_best_rev_diff,
                                   'avg_mem_pred_runtime':all_mem_pred_avg_runtime})
df_mem_jd_summary.to_csv('prediction/mem/jd_mem_summary.csv')

# %%
df_mem_jd_summary
# Out:
#    offertimes  avg_mem_dist  avg_mem_best_rev_diff  avg_mem_pred_runtime
# 0          20          2.38               0.090435              0.407493
# 1          30          1.42               0.119020              0.411118
# 2          40          0.54               0.032551              0.398281
# 3          50          0.72               0.096726              0.380967
# 4          60          0.20               0.053270              0.402031

# %%
def mem_limit(data,collection,offertimes):
    #v,ll = mem_mle(curr_instance, collection, binary_collection)
    start_time = time.time()
    v_values,alpha_values,lambda_vaues,mem_limit_prob,ll_value,ll_time = mem_mle_pyo(data,collection,offertimes)
    #return v_values,alpha_values,lam_values,prob, obj_value,results.solver.time

    mem_limit_loss = 0
    for i in range(len(collection)):
        for j in range(n):
            weight = data[j][i] * offertimes[i]
            mem_limit_loss = mem_limit_loss + weight*np.abs(data[j][i] - mem_limit_prob[j][i])       
    runtime = time.time() - start_time 
    
    return mem_limit_loss, mem_limit_prob, ll_time

# %%
## record the limit loss of all instances
all_mem_limit_loss = []
all_mem_limit_prob = []
all_mem_limit_runtime = []

for i in range(len(pred_offer_times_list)):

    
    ## define container for mem limit 
    mem_limit_loss_collection =[]
    mem_limit_runtime_collection =[]
    mem_limit_probability_collection =[]
    
    for j in range(pred_instance_size[i]):
        

        mem_limit_loss, mem_limit_prob,mem_limit_runtime = mem_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])  
        mem_limit_probability_collection.append(mem_limit_prob)
        mem_limit_loss_collection.append(mem_limit_loss)
        mem_limit_runtime_collection.append(mem_limit_runtime)

    
    ## for each train instance [i][j] limit loss result is a number
    all_mem_limit_loss.append(mem_limit_loss_collection)
    all_mem_limit_runtime.append(mem_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mem_limit_prob.append(mem_limit_probability_collection)

# %%
## adding limit results
ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    df_mem_loss = pd.DataFrame({'ins_idx':ins_idx,'mem_loss':all_mem_limit_loss[i],'avg_loss':all_mem_limit_loss[i]/sum(all_full_offertimes[i]),  'mem_limit_time':all_mem_limit_runtime[i]})
    df_mem_loss.to_csv('limit/mem/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_mem_limit_prob[i][j])
        df_limit_prob.to_csv('limit/mem/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
for i in range(len(pred_offer_times_list)):
    all_avg_loss.append(all_mem_limit_loss[i]/sum(all_full_offertimes[i]))

# %%
avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_mem_limit_runtime = []

#avg_loss = []
avg_loss_se = []

for i in range(len(pred_offer_times_list)):

    
    avg_total_limit_loss.append(np.mean(all_mem_limit_loss[i]))
    avg_mem_limit_runtime.append(np.sum(all_mem_limit_runtime[i]))
    avg_toal_limit_loss_se.append(np.std(all_mem_limit_loss[i])/np.sqrt(len(all_mem_limit_loss[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))

# %%
avg_loss = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))

# %%
df_mem_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'total_mem_loss':avg_total_limit_loss,'total_mem_loss_se':avg_toal_limit_loss_se,
                                   'avg_mem_loss':avg_loss,'avg_mem_loss_se':avg_loss_se,
                                   'avg_mem_limit_runtime':avg_mem_limit_runtime
                                   })
df_mem_limit.to_csv('limit/mem/mem_limit_summary.csv')
df_mem_limit
# Out:
#    offertimes  total_mem_loss  total_mem_loss_se  avg_mem_loss  \
# 0          20      160.624446           3.699478      0.020983
# 1          30      143.274501           3.772938      0.019030
# 2          40      118.568490           3.460304      0.016108
# 3          50       93.713502           3.239242      0.013034
# 4          60       78.311537           3.064029      0.011058
#
#    avg_mem_loss_se  avg_mem_limit_runtime
# 0         0.000483              17.222261
# 1         0.000501              15.762197
# 2         0.000470              16.703084
# 3         0.000451              17.822589
# 4         0.000433              19.899487

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.020982945296492597
# 0.019029685394349193
# 0.01610766071062363
# 0.01303386673703028
# 0.011057827817302199
