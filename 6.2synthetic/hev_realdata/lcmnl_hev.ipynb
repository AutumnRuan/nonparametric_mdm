# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.opt import SolverFactory

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def collection_distribution_hev(n,collection,price):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n))
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes,price):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_hev_instance = collection_distribution_hev(n,whole_collection,price)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_hev_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes,price)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])
    
    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    #print(pd.DataFrame(curr_whole_instance))
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-6 or curr_choice_collection[y][x] >0.999:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes,price)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-6 or curr_choice_collection[y][x] >0.999:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:  
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples)    '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        ''' condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-3:
                    condition = True
        if condition == True:
            print('instance_generation error') '''
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
pd.DataFrame(all_train_instances[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.680921  0.679487  0.730894  0.762222  0.786255  0.686813  0.649123
# 1  0.319079  0.000000  0.000000  0.000000  0.000000  0.000000  0.350877
# 2  0.000000  0.320513  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.269106  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.237778  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.213745  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.313187  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...    14        15        16        17  \
# 0  0.647059  0.521739  0.677419  ...  0.75  0.615385  0.764228  0.791667
# 1  0.352941  0.478261  0.322581  ...  0.00  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.20  0.038462  0.211382  0.208333
# 4  0.000000  0.000000  0.000000  ...  0.05  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  ...  0.00  0.346154  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.024390  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
#
#         18        19        20        21        22        23
# 0  0.78125  0.600000  0.652174  0.785714  0.571429  0.777989
# 1  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.00000  0.088889  0.000000  0.071429  0.000000  0.000000
# 5  0.21875  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.00000  0.311111  0.000000  0.000000  0.000000  0.000000
# 7  0.00000  0.000000  0.347826  0.000000  0.428571  0.000000
# 8  0.00000  0.000000  0.000000  0.142857  0.000000  0.222011
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_test_instance[0][0])
# Out:
#           0     1         2         3         4
# 0  0.694021  0.65  0.731343  0.763819  0.696970
# 1  0.000000  0.00  0.000000  0.000000  0.000000
# 2  0.000000  0.00  0.000000  0.000000  0.000000
# 3  0.000000  0.00  0.000000  0.000000  0.000000
# 4  0.000000  0.00  0.000000  0.000000  0.000000
# 5  0.305979  0.00  0.253731  0.236181  0.000000
# 6  0.000000  0.00  0.014925  0.000000  0.181818
# 7  0.000000  0.35  0.000000  0.000000  0.000000
# 8  0.000000  0.00  0.000000  0.000000  0.121212

# %%
pd.DataFrame(all_train_lb[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.637595  0.531162  0.695398  0.705889  0.758484  0.631098  0.471683
# 1  0.275753  0.000000  0.000000  0.000000  0.000000  0.000000  0.173437
# 2  0.000000  0.172188  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.233609  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.181444  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.185974  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.257472  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.459220  0.314998  0.559582  ...  0.557816  0.347562  0.656791  0.558969
# 1  0.165102  0.271519  0.204743  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.022468 -0.067405  0.108044 -0.024365
# 4  0.000000  0.000000  0.000000  ... -0.046731  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  ...  0.000000  0.084255  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  ...  0.000000  0.000000 -0.014653  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#          18        19        20        21        22        23
# 0  0.576114  0.395003  0.373404  0.568045  0.336624  0.727171
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000 -0.030194  0.000000 -0.065191  0.000000  0.000000
# 5  0.013614  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.117391  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.069056  0.000000  0.193767  0.000000
# 8  0.000000  0.000000  0.000000 -0.042772  0.000000  0.171194
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_train_ub[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.724247  0.827812  0.766391  0.818556  0.814026  0.742528  0.826563
# 1  0.362405  0.000000  0.000000  0.000000  0.000000  0.000000  0.528317
# 2  0.000000  0.468838  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.304602  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.294111  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.241516  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.368902  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.834898  0.728481  0.795257  ...  0.942184  0.883207  0.871664  1.024365
# 1  0.540780  0.685002  0.440418  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.377532  0.144328  0.314721  0.441031
# 4  0.000000  0.000000  0.000000  ...  0.146731  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  ...  0.000000  0.608053  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.063433  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#          18        19        20        21        22        23
# 0  0.986386  0.804997  0.930944  1.003384  0.806233  0.828806
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.207972  0.000000  0.208048  0.000000  0.000000
# 5  0.423886  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.504831  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.626596  0.000000  0.663376  0.000000
# 8  0.000000  0.000000  0.000000  0.328486  0.000000  0.272829
#
# [9 rows x 24 columns]

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
def expectation_step(v_values,data,collections,L,offer_times):
    n,m = data.shape

    # Pyomo model
    model = pyo.ConcreteModel()

    # Variables
    model.w = pyo.Var(range(L), domain=pyo.NonNegativeReals,bounds=(0.001,1))

    # Objective function
    model.obj = pyo.Objective(
        expr=sum(sum(offer_times[i] * data[j, i] * pyo.log(
            sum(model.w[l] * np.exp(v_values[l, j]) / sum(np.exp(v_values[l, k]) for k in collections[i]) for l in range(L))
        ) for j in collections[i]) for i in range(m)),
        sense=pyo.maximize
    )

    # Constraint: Sum of weights equals 1
    model.sum_weights_constraint = pyo.Constraint(expr=sum(model.w[l] for l in range(L)) == 1)

    # Solve the optimization problem
    solver = pyo.SolverFactory('ipopt')
    results = solver.solve(model)
    
    # Print optimization status
    #print("Optimization Status:", results.solver.status)
    if results.solver.status == pyo.SolverStatus.ok:
        #print('Optimal solution found!')
       
        #model.pprint()
    
        w_values = [model.w[l]() for l in range(L)]
        w_values = np.array(w_values)
        
        ''' print("Variable w =", [ model.w[l]() for l in range(L)])
        print("Objective Value =", model.obj()) '''
        
        return w_values,pyo.value(model.obj())
    else:
        print('No solution found or an error occurred.')

# %%
def maximization_step(weights,data,collections,offer_times):
    # Given data
    L = len(weights)
    n,m = data.shape
    
    # Create a ConcreteModel
    model = pyo.ConcreteModel()

    # Define decision variables
    model.v = pyo.Var(range(L), range(n), bounds=(-100, 100))

    # Define the objective function
    model.obj = pyo.Objective(
        expr=sum(sum(data[j][i] * offer_times[i] * pyo.log(sum(weights[l] * pyo.exp(model.v[l, j]) / sum(pyo.exp(model.v[l, k]) for k in collections[i]) for l in range(L))) for j in collections[i]) for i in range(m)),
        sense=pyo.maximize
    )
    
    # preference parameter of outside option 
    model.outsideopt_constraint = pyo.ConstraintList()
    for l in range(L):
        model.outsideopt_constraint.add(model.v[l,0] == 0)

    # Solve the model
    solver = pyo.SolverFactory('ipopt')
    results = solver.solve(model)

    # Print optimization status
    #print("Optimization Status:", results.solver.status)
    if results.solver.status == pyo.SolverStatus.ok:
        #print('Optimal solution found!')
        #model.write('lcmnl_maximizatioin.mps', io_options={'symbolic_solver_labels': True})
        #model.pprint()
    
        v_values = [[model.v[l, i]() for i in range(n)] for l in range(L)]
        v_values = np.array(v_values)

        # Print variable values and objective value
        ''' print("Variable v =", [[model.v[l, i]() for i in range(n)] for l in range(L)])
        print("Objective Value =", model.obj()) '''
        
        return v_values,model.obj()
    else:
        print('No solution found or an error occurred.')

# %%
# EM algorithm for solving the MLE of LC-MNL
def expectation_maximization(data, collections,offer_times, num_class, max_iterations):
    
    weights = np.ones(num_class)/num_class
    v_values,ll = maximization_step(weights,data,collections,offer_times)
    #print('initial loglikelihood values',ll)
    #print('intitial preference parameters',v_values)

    for i in range(max_iterations):
        curr_ll = ll
        weights,ll = expectation_step(v_values,data,collections,num_class,offer_times)
        #print(f'the loglikelihood after expectation at iteration {i} is {ll}')
        v_values,ll = maximization_step(weights,data,collections,offer_times)
        #print(f'the loglikelihood after maximization at iteration {i} is {ll}')
        
        ''' if ll - curr_ll < 0.001:
            print(f'{ll} at current iteration and {curr_ll} at last iteration  ')
            return weights, v_values,ll '''
        
    return   weights, v_values,ll

# %%
def collection_distribution_lcmnl(n,collection,num_mix,weights,parameters_v):
    
    
    collection_distribution = np.zeros((n,len(collection)))
    
    for i in range(len(collection)): 
        curr_total_v = np.zeros(num_mix) # the denominator for each class
        
        for j in range(len(collection[i])): 
            for k in range(num_mix):
                curr_total_v[k] = curr_total_v[k] + math.exp(parameters_v[k][collection[i][j]])
        #print('checking the weights of denominators',curr_total_v)
        
        for j in range(len(collection[i])):
            for k in range(num_mix):
                collection_distribution[collection[i][j]][i] = collection_distribution[collection[i][j]][i] + weights[k]*math.exp(parameters_v[k][collection[i][j]])/curr_total_v[k]
    
    return collection_distribution

# %%
## prediction for the current testing collection of assortments 
def lcmnl_prediction(curr_test_instance,curr_test_collection,price,weights,v_values,n):
    ''' true assortment ranking '''
    true_choice_prob = [] 
    true_revenue = []
    
    lcmnl_revenue = []
    lcmnl_sales = []
    
    # lc- mnl outofsample choice probability using EM estimators 
    
    estimated_oos_prob = collection_distribution_lcmnl(n,curr_test_collection,len(weights),weights,v_values)
    
    
    for k in range(len(curr_test_collection)):

        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        true_choice_prob.append(curr_test_instance[:,k])
        curr_lcmnl_rev = np.dot(estimated_oos_prob[:,k],price)
        
        lcmnl_sales.append(estimated_oos_prob[:,k])
        lcmnl_revenue.append(curr_lcmnl_rev)
        print(f'revenue of assortment {curr_test_collection[k]} is {curr_lcmnl_rev}')
        
        ## record the runtime result
        
        
    return true_revenue,true_choice_prob,lcmnl_revenue,lcmnl_sales

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record representability of all instances

## record the kendall tau distance between the predicted ranking of lcmnl and the truth
all_lcmnl_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_rev_list = []
all_best_rev_lcmnl_list = []  

## record the difference in best assortment
all_lcmnl_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_lcmnl_revenue_list = []

all_true_prob_list = [] 
all_lcmnl_sales_list = []

all_true_ranking = []
all_lcmnl_ranking = []

## record the runtime of lcmnl prediction
all_lcmnl_pred_runtime = []

num_class = 10
max_iterations = 50

for i in range(len(all_full_collections)):
       
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    lcmnl_best_rev_collection = [] # a container for the best revenue predicted by robust lcmnl
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    lcmnl_ranking_collection = [] # a container for ranking by robust lcmnl
    
    lcmnl_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust lcmnl
   
    
    true_choice_prob_collection = []
    lcmnl_sales_frac_collection = []

    true_revenue_collection = []
    lcmnl_revenue_collection = []
    
    lcmnl_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        
        starttime = time.time()
        weights, v_values,ll = expectation_maximization(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j], num_class, max_iterations)
        #lcmnl_choiceprob_100 = collection_distribution_lcmnl(n,collection_100,num_class,weights,v_values)
        lcmnl_mle_runtime = time.time()-starttime
        
        true_revenue,true_choice_prob,lcmnl_revenue,lcmnl_sales = lcmnl_prediction(all_test_instance[i][j],all_test_collection[i][j],price,weights,v_values,n)
        # the following lists are of the same size as number of testing assortments
        
        ll_timelst = [lcmnl_mle_runtime]* len(all_test_collection[i][j])
        #tolruntime = [x + y for x, y in zip(ll_timelst, lcmnl_runtime)]
        
        true_revenue_collection.append(true_revenue)
        true_choice_prob_collection.append(true_choice_prob)
        
        lcmnl_revenue_collection.append(lcmnl_revenue)   
        lcmnl_sales_frac_collection.append(lcmnl_sales)
        lcmnl_runtime_collection.append(ll_timelst)
         
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_lcmnl_rank  = np.argsort(-np.array(lcmnl_revenue)) 
        lcmnl_ranking_collection.append(curr_lcmnl_rank)
        lcmnl_best_rev_collection.append(true_revenue[curr_lcmnl_rank[0]])
        
        
        #  lcmnl kendallTau Distance for current instance [i][j]
        curr_lcmnl_dist = kendall_tau_distance(curr_true_rank, curr_lcmnl_rank)
        lcmnl_distance_collection.append(curr_lcmnl_dist)
    
    
    # for each test instance [i][j] kendall tau distance is a number
    all_lcmnl_distance_list.append(lcmnl_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_rev_list.append(true_best_rev_collection) 
    all_best_rev_lcmnl_list.append(lcmnl_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_lcmnl_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(lcmnl_best_rev_collection))/ np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    
    all_lcmnl_revenue_list.append(lcmnl_revenue_collection)
    
    all_true_prob_list.append(true_choice_prob_collection)
    all_lcmnl_sales_list.append(lcmnl_sales_frac_collection)
 
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_lcmnl_ranking.append(lcmnl_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_lcmnl_pred_runtime.append(lcmnl_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# revenue of assortment [0, 5] is 0.32357663265393405
# revenue of assortment [0, 3, 7] is 0.21842518853363882
# revenue of assortment [0, 5, 6] is 0.3435196526298222
# revenue of assortment [0, 5, 8] is 0.32737482887789365
# revenue of assortment [0, 6, 8] is 0.17467650276989805
# testing for offertimes 20, 1th instance
# revenue of assortment [0, 3] is 0.121654394950483
# revenue of assortment [0, 4] is 0.34788953854769367
# revenue of assortment [0, 1, 4] is 0.27555268153189466
# revenue of assortment [0, 3, 4] is 0.12165439499187554
# revenue of assortment [0, 5, 6] is 0.2570406086590604
# testing for offertimes 20, 2th instance
# revenue of assortment [0, 1, 8] is 0.44884338400907586
# revenue of assortment [0, 2, 6] is 0.15656710974031526
# revenue of assortment [0, 3, 4] is 0.13509706159767879
# revenue of assortment [0, 4, 5] is 0.3117967527487508
# revenue of assortment [0, 5, 8] is 0.5021564624364255
# testing for offertimes 20, 3th instance
# revenue of assortment [0, 1] is 0.09051260904116007
# revenue of assortment [0, 4] is 0.38238539829992496
# revenue of assortment [0, 7] is 0.11397805814746473
# revenue of assortment [0, 3, 4] is 0.13843194893287822
# revenue of assortment [0, 8] is 0.4458860782900841
# testing for offertimes 20, 4th instance
# revenue of assortment [0, 1, 8] is 0.5086337637448538
# revenue of assortment [0, 2, 3, 6] is 0.13599987698246468
# revenue of assortment [0, 3, 8] is 0.34168954465323764
# revenue of assortment [0, 5, 6] is 0.26749542905217244
# revenue of assortment [0, 6, 7] is 0.22431731301631405
# testing for offertimes 20, 5th instance
# revenue of assortment [0, 1] is 0.11753441707950803
# revenue of assortment [0, 1, 4] is 0.4431778917370244
# revenue of assortment [0, 2, 6] is 0.17502057328858328
# revenue of assortment [0, 4, 7] is 0.46683031252225665
# revenue of assortment [0, 5, 6] is 0.3053588595537212
# testing for offertimes 20, 6th instance
# revenue of assortment [0, 4] is 0.4400392583186572
# revenue of assortment [0, 1, 3] is 0.2506959326161745
# revenue of assortment [0, 3, 7] is 0.22479949354551207
# revenue of assortment [0, 4, 8] is 0.4781582516608149
# revenue of assortment [0, 5, 8] is 0.457201558766111
# testing for offertimes 20, 7th instance
# revenue of assortment [0, 1] is 0.14614818536285792
# revenue of assortment [0, 1, 6] is 0.1306034339537567
# revenue of assortment [0, 3, 6] is 0.13577815556515196
# revenue of assortment [0, 4, 5] is 0.3116253044172985
# revenue of assortment [0, 8] is 0.283146240112428
# testing for offertimes 20, 8th instance
# revenue of assortment [0, 1] is 0.09099938086864819
# revenue of assortment [0, 7] is 0.1321725961173465
# revenue of assortment [0, 1, 8] is 0.27359340768624507
# revenue of assortment [0, 4, 6] is 0.5094205657170665
# revenue of assortment [0, 8] is 0.2842901160010214
# testing for offertimes 20, 9th instance
# revenue of assortment [0, 1] is 0.3056328518857345
# revenue of assortment [0, 1, 3] is 0.18851383290339935
# revenue of assortment [0, 2, 3, 6] is 0.16410809041540989
# revenue of assortment [0, 3, 5] is 0.32619555839422937
# revenue of assortment [0, 4, 8] is 0.46529268470651275
# testing for offertimes 20, 10th instance
# revenue of assortment [0, 1, 3] is 0.22988997712483628
# revenue of assortment [0, 2, 6] is 0.2666967782899347
# revenue of assortment [0, 3, 4] is 0.13187661595146105
# revenue of assortment [0, 3, 6] is 0.14338550885822554
# revenue of assortment [0, 5, 6] is 0.1632995501198063
# testing for offertimes 20, 11th instance
# revenue of assortment [0, 1, 3] is 0.1414045160699683
# revenue of assortment [0, 1, 7] is 0.29258660470611564
# revenue of assortment [0, 2, 6] is 0.17673183618661473
# revenue of assortment [0, 4, 6] is 0.29598383762563707
# revenue of assortment [0, 5, 6] is 0.1869150095330527
# testing for offertimes 20, 12th instance
# revenue of assortment [0, 1] is 0.22959829180949648
# revenue of assortment [0, 1, 5] is 0.3168720456104265
# revenue of assortment [0, 2, 3, 6] is 0.15087341843083357
# revenue of assortment [0, 3, 6] is 0.13490970795500332
# revenue of assortment [0, 6, 7] is 0.16044202863316784
# testing for offertimes 20, 13th instance
# revenue of assortment [0, 4] is 0.22882827438656392
# revenue of assortment [0, 6] is 0.11195658531971031
# revenue of assortment [0, 4, 5] is 0.29684791116134746
# revenue of assortment [0, 4, 8] is 0.26116269301973544
# revenue of assortment [0, 6, 8] is 0.11195658534310045
# testing for offertimes 20, 14th instance
# revenue of assortment [0, 4] is 0.31132528363259593
# revenue of assortment [0, 1, 5] is 0.33283335332738156
# revenue of assortment [0, 1, 6] is 0.15058716562663527
# revenue of assortment [0, 4, 8] is 0.3103283974684702
# revenue of assortment [0, 8] is 0.1403356175940608
# testing for offertimes 20, 15th instance
# revenue of assortment [0, 2, 3, 6] is 0.15152109873571143
# revenue of assortment [0, 3, 5] is 0.16594836748760866
# revenue of assortment [0, 4, 7] is 0.4699420127683948
# revenue of assortment [0, 4, 8] is 0.4861414585761009
# revenue of assortment [0, 6, 7] is 0.2093648864082554
# testing for offertimes 20, 16th instance
# revenue of assortment [0, 7] is 0.1810620265442222
# revenue of assortment [0, 1, 5] is 0.3651103262316639
# revenue of assortment [0, 3, 7] is 0.15234051713423746
# revenue of assortment [0, 4, 6] is 0.16180342172867676
# revenue of assortment [0, 8] is 0.3206931600330604
# testing for offertimes 20, 17th instance
# revenue of assortment [0, 1, 8] is 0.337298911449295
# revenue of assortment [0, 3, 4] is 0.13083025849281033
# revenue of assortment [0, 3, 5] is 0.213528487942865
# revenue of assortment [0, 3, 7] is 0.21441090676792368
# revenue of assortment [0, 6, 8] is 0.33166154907850653
# testing for offertimes 20, 18th instance
# revenue of assortment [0, 2] is 0.09331855939208604
# revenue of assortment [0, 1, 3] is 0.21320138735925817
# revenue of assortment [0, 3, 4] is 0.13583788278046485
# revenue of assortment [0, 4, 8] is 0.5310924213699453
# revenue of assortment [0, 6, 8] is 0.1605060371035727
# testing for offertimes 20, 19th instance
# revenue of assortment [0, 6] is 0.11848362411440048
# revenue of assortment [0, 1, 8] is 0.26004840733798906
# revenue of assortment [0, 2, 3, 6] is 0.119169822297855
# revenue of assortment [0, 4, 6] is 0.11848362416241137
# revenue of assortment [0, 5, 8] is 0.36951196937674025
# testing for offertimes 20, 20th instance
# revenue of assortment [0, 1, 7] is 0.3848492871272478
# revenue of assortment [0, 3, 6] is 0.1298649361682774
# revenue of assortment [0, 4, 7] is 0.39114763369115196
# revenue of assortment [0, 5, 6] is 0.35752219564089777
# revenue of assortment [0, 8] is 0.001012870629643199
# testing for offertimes 20, 21th instance
# revenue of assortment [0, 3] is 0.10800303881815143
# revenue of assortment [0, 1, 7] is 0.24893410167107602
# revenue of assortment [0, 2, 6] is 0.17429563839056125
# revenue of assortment [0, 4, 6] is 0.17854642029332018
# revenue of assortment [0, 4, 8] is 0.47553800886023734
# testing for offertimes 20, 22th instance
# revenue of assortment [0, 4] is 0.4353415978535876
# revenue of assortment [0, 6] is 0.16829269266281133
# revenue of assortment [0, 3, 5] is 0.22354536736470806
# revenue of assortment [0, 4, 6] is 0.24753400584477733
# revenue of assortment [0, 5, 6] is 0.2007348625625706
# testing for offertimes 20, 23th instance
# revenue of assortment [0, 1, 7] is 0.3183744770739735
# revenue of assortment [0, 1, 8] is 0.3081401310532478
# revenue of assortment [0, 3, 4] is 0.13120890050343292
# revenue of assortment [0, 3, 5] is 0.30499031141568683
# revenue of assortment [0, 6, 7] is 0.16500845498843103
# testing for offertimes 20, 24th instance
# revenue of assortment [0, 1] is 0.3845501056704314
# revenue of assortment [0, 2] is 0.08901676777359477
# revenue of assortment [0, 1, 5] is 0.4667341084458955
# revenue of assortment [0, 3, 4] is 0.18832322074015162
# revenue of assortment [0, 4, 8] is 0.4010498559836814
# testing for offertimes 20, 25th instance
# revenue of assortment [0, 1, 8] is 0.3669122241692361
# revenue of assortment [0, 3, 7] is 0.21780046462941205
# revenue of assortment [0, 3, 8] is 0.1999051210872847
# revenue of assortment [0, 4, 7] is 0.32947015518572953
# revenue of assortment [0, 6, 8] is 0.1955130049494455
# testing for offertimes 20, 26th instance
# revenue of assortment [0, 1] is 0.27982114630258653
# revenue of assortment [0, 6] is 0.125893057864758
# revenue of assortment [0, 1, 3] is 0.29011406730262157
# revenue of assortment [0, 3, 5] is 0.2796356613538953
# revenue of assortment [0, 4, 5] is 0.6033656133874491
# testing for offertimes 20, 27th instance
# revenue of assortment [0, 7] is 0.1650772465866134
# revenue of assortment [0, 1, 3] is 0.10508457583616007
# revenue of assortment [0, 3, 6] is 0.15865712674299517
# revenue of assortment [0, 5, 6] is 0.2039596999367072
# revenue of assortment [0, 6, 8] is 0.16004920658659968
# testing for offertimes 20, 28th instance
# revenue of assortment [0, 1, 7] is 0.22736834161346126
# revenue of assortment [0, 1, 8] is 0.4873541258181511
# revenue of assortment [0, 3, 5] is 0.13671505143521595
# revenue of assortment [0, 3, 7] is 0.15059233245186116
# revenue of assortment [0, 6, 8] is 0.30966768914146886
# testing for offertimes 20, 29th instance
# revenue of assortment [0, 1, 4] is 0.4125055507501483
# revenue of assortment [0, 1, 7] is 0.23603325552571391
# revenue of assortment [0, 2, 6] is 0.167978125064568
# revenue of assortment [0, 3, 6] is 0.1684583071054634
# revenue of assortment [0, 4, 6] is 0.16758492642562056
# testing for offertimes 20, 30th instance
# revenue of assortment [0, 1] is 0.11092285824333425
# revenue of assortment [0, 1, 8] is 0.4922302242832738
# revenue of assortment [0, 3, 8] is 0.3889167961938368
# revenue of assortment [0, 4, 8] is 0.5390156726030966
# revenue of assortment [0, 5, 8] is 0.4462607250046372
# testing for offertimes 20, 31th instance
# revenue of assortment [0, 3, 5] is 0.14146013871895421
# revenue of assortment [0, 4, 8] is 0.5814810942221869
# revenue of assortment [0, 6, 7] is 0.2118397292060345
# revenue of assortment [0, 6, 8] is 0.369463368949125
# revenue of assortment [0, 8] is 0.5213752487476687
# testing for offertimes 20, 32th instance
# revenue of assortment [0, 5] is 0.23620868033776093
# revenue of assortment [0, 3, 5] is 0.10041742062201614
# revenue of assortment [0, 3, 6] is 0.16324641331459352
# revenue of assortment [0, 5, 6] is 0.15123146409923782
# revenue of assortment [0, 5, 8] is 0.4453142361868567
# testing for offertimes 20, 33th instance
# revenue of assortment [0, 2] is 0.11712889316043193
# revenue of assortment [0, 7] is 0.15396335446200027
# revenue of assortment [0, 2, 3, 6] is 0.18589510785906535
# revenue of assortment [0, 3, 4] is 0.2831070692945872
# revenue of assortment [0, 6, 8] is 0.29864257342126244
# testing for offertimes 20, 34th instance
# revenue of assortment [0, 7] is 0.19323807732986922
# revenue of assortment [0, 1, 7] is 0.19329521071295436
# revenue of assortment [0, 3, 5] is 0.10282027023126687
# revenue of assortment [0, 3, 6] is 0.1312169232882667
# revenue of assortment [0, 3, 7] is 0.16682833036496547
# testing for offertimes 20, 35th instance
# revenue of assortment [0, 1] is 0.3337357869346237
# revenue of assortment [0, 1, 7] is 0.33222442521722945
# revenue of assortment [0, 2, 3, 6] is 0.1760647183703824
# revenue of assortment [0, 3, 4] is 0.13925377022690247
# revenue of assortment [0, 6, 7] is 0.1519604067527193
# testing for offertimes 20, 36th instance
# revenue of assortment [0, 1, 6] is 0.3115078660573741
# revenue of assortment [0, 2, 6] is 0.23448922090562765
# revenue of assortment [0, 3, 6] is 0.1433227448344896
# revenue of assortment [0, 3, 8] is 0.34488107434693904
# revenue of assortment [0, 5, 8] is 0.4140789156325779
# testing for offertimes 20, 37th instance
# revenue of assortment [0, 1] is 0.32195828561761286
# revenue of assortment [0, 1, 3] is 0.22553668276135852
# revenue of assortment [0, 3, 8] is 0.1443865993504913
# revenue of assortment [0, 4, 5] is 0.27894865893923054
# revenue of assortment [0, 5, 8] is 0.33168369344500853
# testing for offertimes 20, 38th instance
# revenue of assortment [0, 3] is 0.07684840174680425
# revenue of assortment [0, 6] is 0.11556024022024627
# revenue of assortment [0, 3, 6] is 0.1095042528804945
# revenue of assortment [0, 3, 7] is 0.1643278581727502
# revenue of assortment [0, 6, 8] is 0.38550808063312697
# testing for offertimes 20, 39th instance
# revenue of assortment [0, 1, 4] is 0.272853157267791
# revenue of assortment [0, 3, 6] is 0.12498593786829983
# revenue of assortment [0, 5, 8] is 0.40317705758218214
# revenue of assortment [0, 6, 7] is 0.165030796071985
# revenue of assortment [0, 6, 8] is 0.32214090914186366
# testing for offertimes 20, 40th instance
# revenue of assortment [0, 2] is 0.12587298024127433
# revenue of assortment [0, 3] is 0.1395529367036583
# revenue of assortment [0, 4, 6] is 0.15764798064110683
# revenue of assortment [0, 6, 7] is 0.18530196154581807
# revenue of assortment [0, 6, 8] is 0.19414749659082503
# testing for offertimes 20, 41th instance
# revenue of assortment [0, 1] is 0.3619927752812008
# revenue of assortment [0, 1, 3] is 0.3555126688099855
# revenue of assortment [0, 1, 4] is 0.4383685233393302
# revenue of assortment [0, 2, 6] is 0.23196484377249724
# revenue of assortment [0, 5, 6] is 0.25480067882683244
# testing for offertimes 20, 42th instance
# revenue of assortment [0, 4] is 0.6070317594252411
# revenue of assortment [0, 6] is 0.09881552321874237
# revenue of assortment [0, 1, 4] is 0.6035426066671916
# revenue of assortment [0, 3, 8] is 0.17894648597680984
# revenue of assortment [0, 5, 8] is 0.4111217306548965
# testing for offertimes 20, 43th instance
# revenue of assortment [0, 3] is 0.13693099565611988
# revenue of assortment [0, 6] is 0.1640684925125271
# revenue of assortment [0, 1, 4] is 0.35067585061624906
# revenue of assortment [0, 1, 5] is 0.38235000309704587
# revenue of assortment [0, 1, 7] is 0.31807471239871454
# testing for offertimes 20, 44th instance
# revenue of assortment [0, 6] is 0.1599255730516352
# revenue of assortment [0, 1, 4] is 0.3333340969360464
# revenue of assortment [0, 3, 5] is 0.13192176066005618
# revenue of assortment [0, 4, 5] is 0.4192786989871372
# revenue of assortment [0, 4, 6] is 0.15992557309664723
# testing for offertimes 20, 45th instance
# revenue of assortment [0, 1, 5] is 0.4183276320202712
# revenue of assortment [0, 1, 6] is 0.1659619606398893
# revenue of assortment [0, 2, 6] is 0.16596196061843418
# revenue of assortment [0, 3, 4] is 0.19685971640361039
# revenue of assortment [0, 4, 7] is 0.23973443046155585
# testing for offertimes 20, 46th instance
# revenue of assortment [0, 1] is 0.3860617204010341
# revenue of assortment [0, 4] is 0.3950054596377481
# revenue of assortment [0, 1, 5] is 0.4042152409861226
# revenue of assortment [0, 1, 8] is 0.39187995610419835
# revenue of assortment [0, 3, 4] is 0.24176601723925345
# testing for offertimes 20, 47th instance
# revenue of assortment [0, 7] is 0.21917054161310368
# revenue of assortment [0, 1, 4] is 0.4410410442063134
# revenue of assortment [0, 1, 6] is 0.23412973182334645
# revenue of assortment [0, 2, 3, 6] is 0.14639053211842046
# revenue of assortment [0, 5, 8] is 0.3723112863732666
# testing for offertimes 20, 48th instance
# revenue of assortment [0, 4] is 0.36105592074694726
# revenue of assortment [0, 1, 4] is 0.40726393994021415
# revenue of assortment [0, 3, 5] is 0.17201051677749968
# revenue of assortment [0, 4, 8] is 0.3887510238625099
# revenue of assortment [0, 8] is 0.26523338972482385
# testing for offertimes 20, 49th instance
# revenue of assortment [0, 1] is 0.3586638223881229
# revenue of assortment [0, 7] is 0.23084036239962324
# revenue of assortment [0, 2, 3, 6] is 0.14019475009593704
# revenue of assortment [0, 3, 8] is 0.14977317384692151
# revenue of assortment [0, 6, 7] is 0.23446994720314668
# testing for offertimes 30, 0th instance
# revenue of assortment [0, 1] is 0.3473958640926076
# revenue of assortment [0, 5] is 0.29272773397568036
# revenue of assortment [0, 1, 3] is 0.3473958627822304
# revenue of assortment [0, 1, 8] is 0.3473958642434772
# testing for offertimes 30, 1th instance
# revenue of assortment [0, 2] is 0.13715623928690793
# revenue of assortment [0, 6] is 0.03200749394966713
# revenue of assortment [0, 3, 4] is 0.1318390001059447
# revenue of assortment [0, 8] is 0.2772055842490799
# testing for offertimes 30, 2th instance
# revenue of assortment [0, 2, 6] is 0.21212275854123852
# revenue of assortment [0, 3, 7] is 0.14734677598208362
# revenue of assortment [0, 6, 7] is 0.16546108297851153
# revenue of assortment [0, 6, 8] is 0.3831721267225036
# testing for offertimes 30, 3th instance
# revenue of assortment [0, 1, 3] is 0.14626377776488692
# revenue of assortment [0, 4, 5] is 0.3774036844914131
# revenue of assortment [0, 5, 8] is 0.5505546908007743
# revenue of assortment [0, 6, 8] is 0.31623794352414025
# testing for offertimes 30, 4th instance
# revenue of assortment [0, 1, 3] is 0.1694159252061246
# revenue of assortment [0, 3, 4] is 0.1288883969583738
# revenue of assortment [0, 3, 7] is 0.21503172202700419
# revenue of assortment [0, 5, 8] is 0.5116182427466666
# testing for offertimes 30, 5th instance
# revenue of assortment [0, 1] is 0.09488990268707377
# revenue of assortment [0, 1, 8] is 0.34559461246347656
# revenue of assortment [0, 4, 6] is 0.19211693624530957
# revenue of assortment [0, 6, 7] is 0.20625519051471528
# testing for offertimes 30, 6th instance
# revenue of assortment [0, 1, 6] is 0.2017837011179483
# revenue of assortment [0, 2, 6] is 0.24182054583205914
# revenue of assortment [0, 5, 8] is 0.48309639238020285
# revenue of assortment [0, 6, 7] is 0.19592894052651694
# testing for offertimes 30, 7th instance
# revenue of assortment [0, 2] is 0.14071875062488667
# revenue of assortment [0, 5] is 0.21844073891802232
# revenue of assortment [0, 1, 5] is 0.21844074788023857
# revenue of assortment [0, 8] is 0.3363873701953352
# testing for offertimes 30, 8th instance
# revenue of assortment [0, 2] is 0.14249999889555234
# revenue of assortment [0, 3] is 0.10567020799546012
# revenue of assortment [0, 7] is 0.2070654118518786
# revenue of assortment [0, 1, 5] is 0.3570588857967765
# testing for offertimes 30, 9th instance
# revenue of assortment [0, 3] is 0.1366344508402997
# revenue of assortment [0, 6] is 0.16024063026855442
# revenue of assortment [0, 1, 5] is 0.3951638323288595
# revenue of assortment [0, 8] is 0.33348474270395534
# testing for offertimes 30, 10th instance
# revenue of assortment [0, 5] is 0.29350000138889154
# revenue of assortment [0, 1, 4] is 0.31691527070788283
# revenue of assortment [0, 2, 6] is 0.241014392877302
# revenue of assortment [0, 4, 6] is 0.1501363497521865
# testing for offertimes 30, 11th instance
# revenue of assortment [0, 1] is 0.2504601530446374
# revenue of assortment [0, 2] is 0.08538446632022763
# revenue of assortment [0, 4, 5] is 0.5465181189233786
# revenue of assortment [0, 4, 6] is 0.30656935594580453
# testing for offertimes 30, 12th instance
# revenue of assortment [0, 6] is 0.13542652632672644
# revenue of assortment [0, 7] is 0.177687146168338
# revenue of assortment [0, 3, 4] is 0.17228519284970045
# revenue of assortment [0, 4, 6] is 0.1839733654423833
# testing for offertimes 30, 13th instance
# revenue of assortment [0, 2] is 0.14243806914310794
# revenue of assortment [0, 3, 7] is 0.11403452706254646
# revenue of assortment [0, 5, 6] is 0.23714453309952616
# revenue of assortment [0, 6, 8] is 0.12362018118272375
# testing for offertimes 30, 14th instance
# revenue of assortment [0, 4] is 0.15106493788599834
# revenue of assortment [0, 7] is 0.15173429653125559
# revenue of assortment [0, 1, 7] is 0.19585104133163964
# revenue of assortment [0, 1, 8] is 0.323745576818586
# testing for offertimes 30, 15th instance
# revenue of assortment [0, 7] is 0.15963284916077677
# revenue of assortment [0, 2, 6] is 0.25152368367127514
# revenue of assortment [0, 4, 6] is 0.2576740784845052
# revenue of assortment [0, 6, 7] is 0.19759265723938518
# testing for offertimes 30, 16th instance
# revenue of assortment [0, 4] is 0.024195690546358967
# revenue of assortment [0, 7] is 0.1208362873986849
# revenue of assortment [0, 3, 6] is 0.16313675043246734
# revenue of assortment [0, 4, 6] is 0.16288440995866307
# testing for offertimes 30, 17th instance
# revenue of assortment [0, 1, 5] is 0.33892390630318875
# revenue of assortment [0, 1, 8] is 0.3657895621930807
# revenue of assortment [0, 3, 7] is 0.23655440264365662
# revenue of assortment [0, 6, 7] is 0.24598166046507008
# testing for offertimes 30, 18th instance
# revenue of assortment [0, 1] is 0.37359956827672963
# revenue of assortment [0, 1, 6] is 0.3010606487864075
# revenue of assortment [0, 3, 6] is 0.14579510753074162
# revenue of assortment [0, 5, 6] is 0.24676666532807984
# testing for offertimes 30, 19th instance
# revenue of assortment [0, 1] is 0.2446637822889669
# revenue of assortment [0, 6] is 0.12087874791075313
# revenue of assortment [0, 1, 5] is 0.32661995727395676
# revenue of assortment [0, 1, 8] is 0.28988915264769183
# testing for offertimes 30, 20th instance
# revenue of assortment [0, 5] is 0.3371441339388341
# revenue of assortment [0, 7] is 0.20550261274806547
# revenue of assortment [0, 1, 6] is 0.3661428306769799
# revenue of assortment [0, 4, 6] is 0.31978388061523344
# testing for offertimes 30, 21th instance
# revenue of assortment [0, 7] is 0.21374993860907554
# revenue of assortment [0, 1, 4] is 0.4837435289660008
# revenue of assortment [0, 1, 6] is 0.2164116669079635
# revenue of assortment [0, 2, 6] is 0.26088418309590333
# testing for offertimes 30, 22th instance
# revenue of assortment [0, 4] is 0.23616403836248417
# revenue of assortment [0, 1, 8] is 0.3932388623717541
# revenue of assortment [0, 4, 5] is 0.4286904071023173
# revenue of assortment [0, 6, 7] is 0.17147581616993127
# testing for offertimes 30, 23th instance
# revenue of assortment [0, 1, 7] is 0.31837884423902424
# revenue of assortment [0, 3, 6] is 0.1485044760565712
# revenue of assortment [0, 4, 5] is 0.4473151669025287
# revenue of assortment [0, 6, 7] is 0.1580592811977369
# testing for offertimes 30, 24th instance
# revenue of assortment [0, 3] is 0.09222836102047256
# revenue of assortment [0, 1, 3] is 0.2560852973958301
# revenue of assortment [0, 4, 5] is 0.4602753975861137
# revenue of assortment [0, 8] is 0.05481488135424708
# testing for offertimes 30, 25th instance
# revenue of assortment [0, 2] is 0.10582025098471257
# revenue of assortment [0, 3] is 0.061133972105719435
# revenue of assortment [0, 5] is 0.18177413448319868
# revenue of assortment [0, 6] is 0.14234674913137266
# testing for offertimes 30, 26th instance
# revenue of assortment [0, 6] is 0.12142460027375739
# revenue of assortment [0, 7] is 0.22959742825953738
# revenue of assortment [0, 1, 4] is 0.5820865902548229
# revenue of assortment [0, 4, 5] is 0.5977206181047054
# testing for offertimes 30, 27th instance
# revenue of assortment [0, 1, 4] is 0.30513507206194534
# revenue of assortment [0, 1, 6] is 0.15989665248270254
# revenue of assortment [0, 3, 7] is 0.14173359166529134
# revenue of assortment [0, 5, 6] is 0.2956924569206206
# testing for offertimes 30, 28th instance
# revenue of assortment [0, 4] is 0.30632925720334
# revenue of assortment [0, 1, 5] is 0.3161003602115841
# revenue of assortment [0, 1, 6] is 0.15338849956743567
# revenue of assortment [0, 1, 7] is 0.31288617623453713
# testing for offertimes 30, 29th instance
# revenue of assortment [0, 1, 3] is 0.1484094257640025
# revenue of assortment [0, 3, 6] is 0.16942901939143193
# revenue of assortment [0, 5, 6] is 0.17407970510064594
# revenue of assortment [0, 6, 8] is 0.21031392197436008
# testing for offertimes 30, 30th instance
# revenue of assortment [0, 4] is 0.4264225480420455
# revenue of assortment [0, 5] is 0.3746878189721398
# revenue of assortment [0, 4, 5] is 0.3746878197652977
# revenue of assortment [0, 4, 6] is 0.28541396168280075
# testing for offertimes 30, 31th instance
# revenue of assortment [0, 4] is 0.3137357315093914
# revenue of assortment [0, 5] is 0.040324288949567896
# revenue of assortment [0, 1, 6] is 0.3341630080130805
# revenue of assortment [0, 1, 8] is 0.5380195801006374
# testing for offertimes 30, 32th instance
# revenue of assortment [0, 3] is 0.09911911699370557
# revenue of assortment [0, 1, 8] is 0.3293851186444279
# revenue of assortment [0, 4, 6] is 0.15235266118144666
# revenue of assortment [0, 5, 6] is 0.15235266118489102
# testing for offertimes 30, 33th instance
# revenue of assortment [0, 3] is 0.11935046748361994
# revenue of assortment [0, 1, 3] is 0.30873846321749776
# revenue of assortment [0, 4, 5] is 0.46540224736687663
# revenue of assortment [0, 4, 6] is 0.16416305587972382
# testing for offertimes 30, 34th instance
# revenue of assortment [0, 1, 4] is 0.33315681766032856
# revenue of assortment [0, 1, 5] is 0.28016188878871195
# revenue of assortment [0, 1, 7] is 0.19833275903155426
# revenue of assortment [0, 4, 6] is 0.13278377130623623
# testing for offertimes 30, 35th instance
# revenue of assortment [0, 4] is 0.26582133231379684
# revenue of assortment [0, 1, 4] is 0.3301619550032778
# revenue of assortment [0, 3, 4] is 0.12435427998887552
# revenue of assortment [0, 4, 5] is 0.33649768044336287
# testing for offertimes 30, 36th instance
# revenue of assortment [0, 1] is 0.31508582098769305
# revenue of assortment [0, 2] is 0.14965511806867557
# revenue of assortment [0, 4] is 0.0007394129090358248
# revenue of assortment [0, 1, 5] is 0.3896229549821642
# testing for offertimes 30, 37th instance
# revenue of assortment [0, 1] is 0.3040260015644802
# revenue of assortment [0, 3] is 0.1483146474464778
# revenue of assortment [0, 5, 6] is 0.1493231391945452
# revenue of assortment [0, 6, 7] is 0.19405589600529385
# testing for offertimes 30, 38th instance
# revenue of assortment [0, 6] is 0.14145720135376214
# revenue of assortment [0, 1, 3] is 0.3332474994580798
# revenue of assortment [0, 2, 6] is 0.24481238708972014
# revenue of assortment [0, 4, 6] is 0.469587482448871
# testing for offertimes 30, 39th instance
# revenue of assortment [0, 4] is 0.015243455392715599
# revenue of assortment [0, 6] is 0.1386708336643967
# revenue of assortment [0, 3, 4] is 0.09982880398577429
# revenue of assortment [0, 6, 7] is 0.1743842677870019
# testing for offertimes 30, 40th instance
# revenue of assortment [0, 4] is 0.19648473332495697
# revenue of assortment [0, 6] is 0.15378405839664966
# revenue of assortment [0, 1, 3] is 0.2398910653585375
# revenue of assortment [0, 8] is 0.43730462112320667
# testing for offertimes 30, 41th instance
# revenue of assortment [0, 1, 5] is 0.3606152100554388
# revenue of assortment [0, 1, 8] is 0.36684318827523543
# revenue of assortment [0, 2, 6] is 0.2040092152473404
# revenue of assortment [0, 4, 5] is 0.4223318015177052
# testing for offertimes 30, 42th instance
# revenue of assortment [0, 1, 4] is 0.5474625741542547
# revenue of assortment [0, 3, 6] is 0.14464740378992524
# revenue of assortment [0, 4, 5] is 0.49587100266553097
# revenue of assortment [0, 6, 8] is 0.3952043436774207
# testing for offertimes 30, 43th instance
# revenue of assortment [0, 4] is 0.0019497678106985671
# revenue of assortment [0, 7] is 0.06350050299246923
# revenue of assortment [0, 1, 6] is 0.23553854016478012
# revenue of assortment [0, 5, 8] is 0.4137097044655802
# testing for offertimes 30, 44th instance
# revenue of assortment [0, 1] is 0.3256685408863874
# revenue of assortment [0, 2] is 0.04948864944248076
# revenue of assortment [0, 1, 5] is 0.34831398433388955
# revenue of assortment [0, 1, 6] is 0.16552338616295764
# testing for offertimes 30, 45th instance
# revenue of assortment [0, 1, 6] is 0.16393654369308622
# revenue of assortment [0, 3, 4] is 0.24662026626005662
# revenue of assortment [0, 5, 6] is 0.20170847684793997
# revenue of assortment [0, 8] is 0.47909290675297955
# testing for offertimes 30, 46th instance
# revenue of assortment [0, 3] is 0.13909181069507975
# revenue of assortment [0, 1, 6] is 0.34767179095492945
# revenue of assortment [0, 1, 8] is 0.3873394629366234
# revenue of assortment [0, 5, 6] is 0.23178848639266658
# testing for offertimes 30, 47th instance
# revenue of assortment [0, 4] is 0.00033638229001441784
# revenue of assortment [0, 7] is 0.20283935798868205
# revenue of assortment [0, 1, 4] is 0.29946117654970605
# revenue of assortment [0, 3, 4] is 0.12397489027804769
# testing for offertimes 30, 48th instance
# revenue of assortment [0, 3, 6] is 0.14313330554880987
# revenue of assortment [0, 4, 5] is 0.48008585506989915
# revenue of assortment [0, 5, 6] is 0.38399779262601436
# revenue of assortment [0, 6, 8] is 0.21078238138048191
# testing for offertimes 30, 49th instance
# revenue of assortment [0, 6] is 0.07760920392665432
# revenue of assortment [0, 1, 4] is 0.6139608444294066
# revenue of assortment [0, 1, 7] is 0.40731115745654684
# revenue of assortment [0, 6, 7] is 0.25626482384630583
# testing for offertimes 40, 0th instance
# revenue of assortment [0, 7] is 0.23450000410781485
# revenue of assortment [0, 1, 5] is 0.3546031966713234
# revenue of assortment [0, 5, 8] is 0.5400880821058728
# testing for offertimes 40, 1th instance
# revenue of assortment [0, 7] is 0.04829832913346803
# revenue of assortment [0, 1, 3] is 0.20223086819415537
# revenue of assortment [0, 2, 6] is 0.22057068551821085
# testing for offertimes 40, 2th instance
# revenue of assortment [0, 3] is 0.13482758698596048
# revenue of assortment [0, 1, 4] is 0.3439320510874974
# revenue of assortment [0, 8] is 0.3954799758521105
# testing for offertimes 40, 3th instance
# revenue of assortment [0, 3] is 0.12150280865224393
# revenue of assortment [0, 1, 6] is 0.14731936283968486
# revenue of assortment [0, 3, 7] is 0.206979590375796
# testing for offertimes 40, 4th instance
# revenue of assortment [0, 1, 3] is 0.25081454428311584
# revenue of assortment [0, 1, 5] is 0.3354787019046421
# revenue of assortment [0, 3, 4] is 0.12848161952418413
# testing for offertimes 40, 5th instance
# revenue of assortment [0, 2] is 0.07659824908094269
# revenue of assortment [0, 6] is 0.14941304180889556
# revenue of assortment [0, 1, 6] is 0.1494130439561343
# testing for offertimes 40, 6th instance
# revenue of assortment [0, 1, 3] is 0.21725083618103558
# revenue of assortment [0, 1, 5] is 0.44146547690164434
# revenue of assortment [0, 1, 6] is 0.25360660423202047
# testing for offertimes 40, 7th instance
# revenue of assortment [0, 3] is 0.13083461695954277
# revenue of assortment [0, 4] is 0.3247185373886514
# revenue of assortment [0, 1, 6] is 0.1180864564676411
# testing for offertimes 40, 8th instance
# revenue of assortment [0, 1] is 0.2596645233968578
# revenue of assortment [0, 1, 3] is 0.12990917367373764
# revenue of assortment [0, 8] is 0.31580906936164793
# testing for offertimes 40, 9th instance
# revenue of assortment [0, 3] is 0.07923551830079258
# revenue of assortment [0, 1, 3] is 0.31921365097626386
# revenue of assortment [0, 3, 4] is 0.370944219858978
# testing for offertimes 40, 10th instance
# revenue of assortment [0, 3] is 0.12043083152502743
# revenue of assortment [0, 1, 4] is 0.32063556107257063
# revenue of assortment [0, 5, 8] is 0.6143706534386955
# testing for offertimes 40, 11th instance
# revenue of assortment [0, 1] is 0.21837474950413116
# revenue of assortment [0, 3] is 0.1300702890684124
# revenue of assortment [0, 5, 8] is 0.619540664661002
# testing for offertimes 40, 12th instance
# revenue of assortment [0, 1, 5] is 0.31430214306546034
# revenue of assortment [0, 2, 6] is 0.2671852365516272
# revenue of assortment [0, 4, 6] is 0.14073332287300405
# testing for offertimes 40, 13th instance
# revenue of assortment [0, 4] is 0.18718423041312446
# revenue of assortment [0, 5] is 0.26547738675081894
# revenue of assortment [0, 4, 6] is 0.12323534618650148
# testing for offertimes 40, 14th instance
# revenue of assortment [0, 3] is 0.11694944754864892
# revenue of assortment [0, 1, 6] is 0.16297587930255333
# revenue of assortment [0, 5, 6] is 0.17016591819089097
# testing for offertimes 40, 15th instance
# revenue of assortment [0, 6] is 0.0970968648600575
# revenue of assortment [0, 5, 6] is 0.20898762906099858
# revenue of assortment [0, 5, 8] is 0.5876160493536524
# testing for offertimes 40, 16th instance
# revenue of assortment [0, 5] is 0.4010648305571611
# revenue of assortment [0, 1, 6] is 0.16192908324704985
# revenue of assortment [0, 8] is 0.013722956252146706
# testing for offertimes 40, 17th instance
# revenue of assortment [0, 4] is 0.039412292143291894
# revenue of assortment [0, 1, 5] is 0.6099508257123357
# revenue of assortment [0, 5, 6] is 0.43578605411731897
# testing for offertimes 40, 18th instance
# revenue of assortment [0, 5] is 0.25344242550491547
# revenue of assortment [0, 7] is 0.0660500203068683
# revenue of assortment [0, 1, 5] is 0.40415540751542334
# testing for offertimes 40, 19th instance
# revenue of assortment [0, 2] is 0.08960566581651928
# revenue of assortment [0, 5] is 0.32591026740779017
# revenue of assortment [0, 5, 8] is 0.5250609037110251
# testing for offertimes 40, 20th instance
# revenue of assortment [0, 7] is 0.10347039432102532
# revenue of assortment [0, 1, 6] is 0.3596368146901429
# revenue of assortment [0, 5, 8] is 0.5819411227261551
# testing for offertimes 40, 21th instance
# revenue of assortment [0, 6] is 0.13121023553955485
# revenue of assortment [0, 1, 5] is 0.33560336643532673
# revenue of assortment [0, 3, 6] is 0.13123956896731476
# testing for offertimes 40, 22th instance
# revenue of assortment [0, 2] is 0.06715951205015416
# revenue of assortment [0, 6] is 0.14686260881311117
# revenue of assortment [0, 5, 8] is 0.5719066826101515
# testing for offertimes 40, 23th instance
# revenue of assortment [0, 3] is 0.13801636907029535
# revenue of assortment [0, 1, 3] is 0.20758049557696406
# revenue of assortment [0, 1, 4] is 0.41365593673170187
# testing for offertimes 40, 24th instance
# revenue of assortment [0, 1, 4] is 0.31474970352120357
# revenue of assortment [0, 3, 6] is 0.167386817659929
# revenue of assortment [0, 3, 7] is 0.24824579028863664
# testing for offertimes 40, 25th instance
# revenue of assortment [0, 1] is 0.2945298976006526
# revenue of assortment [0, 1, 6] is 0.2704868234900891
# revenue of assortment [0, 3, 4] is 0.41745443792516607
# testing for offertimes 40, 26th instance
# revenue of assortment [0, 6] is 0.1267925471939685
# revenue of assortment [0, 1, 4] is 0.5582757595127363
# revenue of assortment [0, 4, 6] is 0.40858327908026704
# testing for offertimes 40, 27th instance
# revenue of assortment [0, 1] is 0.28448526472685165
# revenue of assortment [0, 3, 6] is 0.15815666651899274
# revenue of assortment [0, 8] is 0.041229943703702386
# testing for offertimes 40, 28th instance
# revenue of assortment [0, 1, 4] is 0.29510581408621445
# revenue of assortment [0, 3, 4] is 0.11817662381291219
# revenue of assortment [0, 8] is 0.49587790145350835
# testing for offertimes 40, 29th instance
# revenue of assortment [0, 6] is 0.16908589809798336
# revenue of assortment [0, 3, 4] is 0.21453674775652065
# revenue of assortment [0, 8] is 0.26605012093122193
# testing for offertimes 40, 30th instance
# revenue of assortment [0, 3] is 0.0692386037102659
# revenue of assortment [0, 1, 3] is 0.2495944149492761
# revenue of assortment [0, 4, 6] is 0.36717553980712814
# testing for offertimes 40, 31th instance
# revenue of assortment [0, 1] is 0.2963675017235927
# revenue of assortment [0, 6] is 0.10864981476095097
# revenue of assortment [0, 5, 6] is 0.2797439715885125
# testing for offertimes 40, 32th instance
# revenue of assortment [0, 1, 6] is 0.1507679290528284
# revenue of assortment [0, 3, 7] is 0.21332132155323666
# revenue of assortment [0, 5, 6] is 0.16086763981335153
# testing for offertimes 40, 33th instance
# revenue of assortment [0, 1, 3] is 0.3329363488061456
# revenue of assortment [0, 1, 6] is 0.25999780444270215
# revenue of assortment [0, 8] is 0.36402324587280926
# testing for offertimes 40, 34th instance
# revenue of assortment [0, 1, 3] is 0.12629931906965153
# revenue of assortment [0, 4, 6] is 0.13371039906953602
# revenue of assortment [0, 8] is 0.35942499645436865
# testing for offertimes 40, 35th instance
# revenue of assortment [0, 1, 4] is 0.4788555211909125
# revenue of assortment [0, 1, 6] is 0.31700156902651727
# revenue of assortment [0, 3, 6] is 0.18582953563290364
# testing for offertimes 40, 36th instance
# revenue of assortment [0, 2] is 0.15430008577019189
# revenue of assortment [0, 3] is 0.10752500108226272
# revenue of assortment [0, 1, 3] is 0.3052219684491996
# testing for offertimes 40, 37th instance
# revenue of assortment [0, 6] is 0.15556171363262425
# revenue of assortment [0, 2, 6] is 0.2709444314171626
# revenue of assortment [0, 5, 6] is 0.15556171511610142
# testing for offertimes 40, 38th instance
# revenue of assortment [0, 7] is 0.20562070616316264
# revenue of assortment [0, 1, 5] is 0.49142827037753756
# revenue of assortment [0, 5, 6] is 0.28380776275570396
# testing for offertimes 40, 39th instance
# revenue of assortment [0, 1, 5] is 0.29400319045737283
# revenue of assortment [0, 2, 6] is 0.21939534930380622
# revenue of assortment [0, 8] is 0.3678457956282594
# testing for offertimes 40, 40th instance
# revenue of assortment [0, 3] is 0.14044825954862705
# revenue of assortment [0, 6] is 0.15631617522236982
# revenue of assortment [0, 3, 7] is 0.2613739829888039
# testing for offertimes 40, 41th instance
# revenue of assortment [0, 4] is 0.2578292346615896
# revenue of assortment [0, 3, 4] is 0.27783721561814145
# revenue of assortment [0, 5, 6] is 0.2792710530475415
# testing for offertimes 40, 42th instance
# revenue of assortment [0, 5] is 0.26149910966056134
# revenue of assortment [0, 6] is 0.07011983688763526
# revenue of assortment [0, 1, 4] is 0.559632246487631
# testing for offertimes 40, 43th instance
# revenue of assortment [0, 2] is 0.061177792716707605
# revenue of assortment [0, 7] is 0.12560075425006556
# revenue of assortment [0, 3, 6] is 0.1623743339366723
# testing for offertimes 40, 44th instance
# revenue of assortment [0, 2, 6] is 0.22955153338583456
# revenue of assortment [0, 3, 4] is 0.13553450759896937
# revenue of assortment [0, 4, 6] is 0.16430526575914822
# testing for offertimes 40, 45th instance
# revenue of assortment [0, 6] is 0.15168000555014355
# revenue of assortment [0, 3, 4] is 0.15347735642480168
# revenue of assortment [0, 5, 6] is 0.1967154549597412
# testing for offertimes 40, 46th instance
# revenue of assortment [0, 2] is 0.13350536187179504
# revenue of assortment [0, 5, 6] is 0.24900860948484066
# revenue of assortment [0, 5, 8] is 0.5397544432637784
# testing for offertimes 40, 47th instance
# revenue of assortment [0, 3] is 0.11532980849394027
# revenue of assortment [0, 4] is 0.007363199562226545
# revenue of assortment [0, 1, 4] is 0.29942252094189686
# testing for offertimes 40, 48th instance
# revenue of assortment [0, 3] is 0.12526650093214742
# revenue of assortment [0, 5] is 0.3410942496601571
# revenue of assortment [0, 1, 4] is 0.48089255799192887
# testing for offertimes 40, 49th instance
# revenue of assortment [0, 3] is 0.13896528160389068
# revenue of assortment [0, 1, 3] is 0.25562702682020094
# revenue of assortment [0, 3, 7] is 0.2726287699265401
# testing for offertimes 50, 0th instance
# revenue of assortment [0, 3] is 0.09210681601164696
# revenue of assortment [0, 6] is 0.04633273137193019
# revenue of assortment [0, 1, 3] is 0.33540292047132253
# testing for offertimes 50, 1th instance
# revenue of assortment [0, 3] is 0.11126016405124711
# revenue of assortment [0, 1, 3] is 0.28362013507716954
# revenue of assortment [0, 1, 6] is 0.26472315538486735
# testing for offertimes 50, 2th instance
# revenue of assortment [0, 4] is 0.01584925706163092
# revenue of assortment [0, 5] is 0.14911784384568505
# revenue of assortment [0, 8] is 0.4111706683547952
# testing for offertimes 50, 3th instance
# revenue of assortment [0, 1] is 0.09588039813126649
# revenue of assortment [0, 1, 3] is 0.17173240726635797
# revenue of assortment [0, 1, 6] is 0.1903061296376129
# testing for offertimes 50, 4th instance
# revenue of assortment [0, 1] is 0.28576470592987047
# revenue of assortment [0, 1, 6] is 0.2974657067456392
# revenue of assortment [0, 2, 6] is 0.22975641265122118
# testing for offertimes 50, 5th instance
# revenue of assortment [0, 4] is 0.3754206902080316
# revenue of assortment [0, 5] is 0.16012060720786966
# revenue of assortment [0, 5, 8] is 0.4383630905658206
# testing for offertimes 50, 6th instance
# revenue of assortment [0, 3] is 0.05691541225978267
# revenue of assortment [0, 4] is 0.4735603231560299
# revenue of assortment [0, 5] is 0.11531558755482371
# testing for offertimes 50, 7th instance
# revenue of assortment [0, 5] is 0.21845844468775574
# revenue of assortment [0, 1, 6] is 0.15629183228647847
# revenue of assortment [0, 8] is 0.10523004590987163
# testing for offertimes 50, 8th instance
# revenue of assortment [0, 5] is 0.32693516517070925
# revenue of assortment [0, 2, 6] is 0.2670885790870264
# revenue of assortment [0, 5, 6] is 0.1909878866764843
# testing for offertimes 50, 9th instance
# revenue of assortment [0, 1, 3] is 0.28243199855449597
# revenue of assortment [0, 5, 6] is 0.38342139186163526
# revenue of assortment [0, 5, 8] is 0.6442420485290508
# testing for offertimes 50, 10th instance
# revenue of assortment [0, 3] is 0.10564224127221553
# revenue of assortment [0, 1, 4] is 0.5295876925172668
# revenue of assortment [0, 5, 8] is 0.6190532399884867
# testing for offertimes 50, 11th instance
# revenue of assortment [0, 2] is 0.0719325497542418
# revenue of assortment [0, 5, 6] is 0.34631149448572873
# revenue of assortment [0, 5, 8] is 0.5934967049534283
# testing for offertimes 50, 12th instance
# revenue of assortment [0, 4] is 0.26055387024215204
# revenue of assortment [0, 5] is 0.2652028151305758
# revenue of assortment [0, 5, 6] is 0.40272531240418263
# testing for offertimes 50, 13th instance
# revenue of assortment [0, 1] is 0.19551127030200718
# revenue of assortment [0, 2] is 0.14247693353604002
# revenue of assortment [0, 5, 6] is 0.39349219306143335
# testing for offertimes 50, 14th instance
# revenue of assortment [0, 2] is 0.15112128242491865
# revenue of assortment [0, 1, 6] is 0.2832243918398536
# revenue of assortment [0, 3, 6] is 0.19332049731608242
# testing for offertimes 50, 15th instance
# revenue of assortment [0, 1] is 0.3626045783298424
# revenue of assortment [0, 5] is 0.25722118596473303
# revenue of assortment [0, 1, 4] is 0.6147176854979641
# testing for offertimes 50, 16th instance
# revenue of assortment [0, 2, 6] is 0.20663673434602284
# revenue of assortment [0, 3, 6] is 0.16367443887276875
# revenue of assortment [0, 5, 6] is 0.17841911209371475
# testing for offertimes 50, 17th instance
# revenue of assortment [0, 6] is 0.0460757464186403
# revenue of assortment [0, 1, 4] is 0.4852404576380141
# revenue of assortment [0, 1, 6] is 0.27634312659524685
# testing for offertimes 50, 18th instance
# revenue of assortment [0, 6] is 0.1434165651794993
# revenue of assortment [0, 1, 4] is 0.6614682569026122
# revenue of assortment [0, 2, 6] is 0.2504138775374864
# testing for offertimes 50, 19th instance
# revenue of assortment [0, 6] is 0.1127528848830393
# revenue of assortment [0, 1, 4] is 0.48151254774947894
# revenue of assortment [0, 5, 6] is 0.1271204017944763
# testing for offertimes 50, 20th instance
# revenue of assortment [0, 1] is 0.3569143377437149
# revenue of assortment [0, 2] is 0.14781465821517725
# revenue of assortment [0, 1, 3] is 0.28200380230975597
# testing for offertimes 50, 21th instance
# revenue of assortment [0, 6] is 0.13101675406364108
# revenue of assortment [0, 1, 3] is 0.36592474802634
# revenue of assortment [0, 3, 6] is 0.2072801921636892
# testing for offertimes 50, 22th instance
# revenue of assortment [0, 6] is 0.15238300822553152
# revenue of assortment [0, 3, 6] is 0.16353114157721807
# revenue of assortment [0, 5, 6] is 0.2565331899181692
# testing for offertimes 50, 23th instance
# revenue of assortment [0, 1, 3] is 0.2632380278512345
# revenue of assortment [0, 1, 6] is 0.28294076608852087
# revenue of assortment [0, 2, 6] is 0.26888764618116645
# testing for offertimes 50, 24th instance
# revenue of assortment [0, 1] is 0.3589655139197904
# revenue of assortment [0, 5] is 0.34480302696185033
# revenue of assortment [0, 2, 6] is 0.2213252791266144
# testing for offertimes 50, 25th instance
# revenue of assortment [0, 1, 6] is 0.42202314129905694
# revenue of assortment [0, 3, 6] is 0.2531699201525267
# revenue of assortment [0, 5, 8] is 0.6031020614692602
# testing for offertimes 50, 26th instance
# revenue of assortment [0, 1, 4] is 0.6721645518661303
# revenue of assortment [0, 3, 6] is 0.16917736309375295
# revenue of assortment [0, 5, 8] is 0.6385796773066519
# testing for offertimes 50, 27th instance
# revenue of assortment [0, 4] is 0.06665468978387296
# revenue of assortment [0, 1, 3] is 0.25050647540432724
# revenue of assortment [0, 1, 6] is 0.1633312379627837
# testing for offertimes 50, 28th instance
# revenue of assortment [0, 3] is 0.10847548503067479
# revenue of assortment [0, 5] is 0.08957335637503937
# revenue of assortment [0, 3, 6] is 0.15288909859515917
# testing for offertimes 50, 29th instance
# revenue of assortment [0, 1] is 0.013944992044331738
# revenue of assortment [0, 1, 4] is 0.39132772645217734
# revenue of assortment [0, 2, 6] is 0.2076776293403976
# testing for offertimes 50, 30th instance
# revenue of assortment [0, 2] is 0.12485092450391932
# revenue of assortment [0, 3, 6] is 0.14893662422974555
# revenue of assortment [0, 8] is 0.32652485337224163
# testing for offertimes 50, 31th instance
# revenue of assortment [0, 4] is 0.5239241965704199
# revenue of assortment [0, 1, 3] is 0.43622840770809446
# revenue of assortment [0, 3, 6] is 0.24310542922926115
# testing for offertimes 50, 32th instance
# revenue of assortment [0, 5] is 0.035961050883101184
# revenue of assortment [0, 2, 6] is 0.22126169317505326
# revenue of assortment [0, 8] is 0.36272218591811667
# testing for offertimes 50, 33th instance
# revenue of assortment [0, 3] is 0.10171498322610466
# revenue of assortment [0, 2, 6] is 0.24998680183368477
# revenue of assortment [0, 3, 6] is 0.15855385806065778
# testing for offertimes 50, 34th instance
# revenue of assortment [0, 3] is 0.11295555772042341
# revenue of assortment [0, 5] is 0.06810760202393225
# revenue of assortment [0, 5, 6] is 0.20342748137120448
# testing for offertimes 50, 35th instance
# revenue of assortment [0, 2] is 0.09342555151804666
# revenue of assortment [0, 5, 6] is 0.16887123975248552
# revenue of assortment [0, 8] is 0.3461439488847987
# testing for offertimes 50, 36th instance
# revenue of assortment [0, 1] is 0.30617647441094104
# revenue of assortment [0, 6] is 0.13331043073349924
# revenue of assortment [0, 1, 6] is 0.2974019459376571
# testing for offertimes 50, 37th instance
# revenue of assortment [0, 5] is 0.09890113058141349
# revenue of assortment [0, 5, 6] is 0.19860643140543624
# revenue of assortment [0, 8] is 0.34486857426543494
# testing for offertimes 50, 38th instance
# revenue of assortment [0, 3] is 0.06113412008009742
# revenue of assortment [0, 5] is 0.15188209144525328
# revenue of assortment [0, 1, 4] is 0.6043127130432068
# testing for offertimes 50, 39th instance
# revenue of assortment [0, 5] is 0.1477633123618699
# revenue of assortment [0, 1, 3] is 0.2816281955987259
# revenue of assortment [0, 5, 8] is 0.47121635849367205
# testing for offertimes 50, 40th instance
# revenue of assortment [0, 3] is 0.11362976405069765
# revenue of assortment [0, 1, 3] is 0.34786008865675866
# revenue of assortment [0, 8] is 0.012463574303841447
# testing for offertimes 50, 41th instance
# revenue of assortment [0, 2] is 0.16639713303188838
# revenue of assortment [0, 1, 4] is 0.6195456113924287
# revenue of assortment [0, 3, 6] is 0.16376737415293277
# testing for offertimes 50, 42th instance
# revenue of assortment [0, 1] is 0.17992913626316412
# revenue of assortment [0, 3] is 0.13309538394186277
# revenue of assortment [0, 1, 3] is 0.21603357914010834
# testing for offertimes 50, 43th instance
# revenue of assortment [0, 3] is 0.09305922125543514
# revenue of assortment [0, 1, 4] is 0.5456675772187679
# revenue of assortment [0, 3, 6] is 0.15743521744443378
# testing for offertimes 50, 44th instance
# revenue of assortment [0, 5] is 0.2653393276056876
# revenue of assortment [0, 2, 6] is 0.2346384606116067
# revenue of assortment [0, 3, 6] is 0.15456598700502855
# testing for offertimes 50, 45th instance
# revenue of assortment [0, 4] is 0.45386718816753363
# revenue of assortment [0, 5] is 0.31466174430942984
# revenue of assortment [0, 1, 6] is 0.16632210579028955
# testing for offertimes 50, 46th instance
# revenue of assortment [0, 5] is 0.2723205246122806
# revenue of assortment [0, 6] is 0.07801622413084486
# revenue of assortment [0, 8] is 0.07305147521170434
# testing for offertimes 50, 47th instance
# revenue of assortment [0, 1, 4] is 0.6007292151589594
# revenue of assortment [0, 2, 6] is 0.20905590927037287
# revenue of assortment [0, 5, 8] is 0.5982090127059001
# testing for offertimes 50, 48th instance
# revenue of assortment [0, 6] is 0.12093249501078367
# revenue of assortment [0, 1, 3] is 0.14273256590611094
# revenue of assortment [0, 1, 4] is 0.6207660290683501
# testing for offertimes 50, 49th instance
# revenue of assortment [0, 1] is 0.28845785415826525
# revenue of assortment [0, 1, 4] is 0.6347084336994919
# revenue of assortment [0, 3, 6] is 0.1736012812593165
# testing for offertimes 60, 0th instance
# revenue of assortment [0, 3] is 0.08632456869848955
# revenue of assortment [0, 5] is 0.28246671406082835
# testing for offertimes 60, 1th instance
# revenue of assortment [0, 5, 6] is 0.3193956338643218
# revenue of assortment [0, 5, 8] is 0.48605702325823397
# testing for offertimes 60, 2th instance
# revenue of assortment [0, 2, 6] is 0.21690442137330843
# revenue of assortment [0, 5, 8] is 0.6754090207255105
# testing for offertimes 60, 3th instance
# revenue of assortment [0, 5] is 0.2200032982879431
# revenue of assortment [0, 6] is 0.14641884720751128
# testing for offertimes 60, 4th instance
# revenue of assortment [0, 3, 6] is 0.21162099207312463
# revenue of assortment [0, 5, 8] is 0.6746031658907363
# testing for offertimes 60, 5th instance
# revenue of assortment [0, 3] is 0.15238400052663123
# revenue of assortment [0, 1, 6] is 0.28280838701107314
# testing for offertimes 60, 6th instance
# revenue of assortment [0, 5] is 0.061573600980805915
# revenue of assortment [0, 8] is 0.3953745925132642
# testing for offertimes 60, 7th instance
# revenue of assortment [0, 6] is 0.08383961768377479
# revenue of assortment [0, 3, 6] is 0.19124803606406632
# testing for offertimes 60, 8th instance
# revenue of assortment [0, 5] is 0.324756938649512
# revenue of assortment [0, 3, 6] is 0.18975627983406862
# testing for offertimes 60, 9th instance
# revenue of assortment [0, 1] is 0.13009821993452278
# revenue of assortment [0, 5, 6] is 0.1803935732952473
# testing for offertimes 60, 10th instance
# revenue of assortment [0, 1, 6] is 0.37165483535310695
# revenue of assortment [0, 3, 6] is 0.2265843973898159
# testing for offertimes 60, 11th instance
# revenue of assortment [0, 3] is 0.11729999109494255
# revenue of assortment [0, 5, 8] is 0.624488359045099
# testing for offertimes 60, 12th instance
# revenue of assortment [0, 1, 6] is 0.29791214487896633
# revenue of assortment [0, 2, 6] is 0.26225342774279126
# testing for offertimes 60, 13th instance
# revenue of assortment [0, 3] is 0.10807061727805581
# revenue of assortment [0, 8] is 0.0003492896112624059
# testing for offertimes 60, 14th instance
# revenue of assortment [0, 1, 6] is 0.27972285502652183
# revenue of assortment [0, 5, 8] is 0.523062999410766
# testing for offertimes 60, 15th instance
# revenue of assortment [0, 2] is 0.11835180749099267
# revenue of assortment [0, 5] is 0.21672202833325274
# testing for offertimes 60, 16th instance
# revenue of assortment [0, 2] is 0.04583423157448239
# revenue of assortment [0, 1, 6] is 0.3084481017931683
# testing for offertimes 60, 17th instance
# revenue of assortment [0, 1] is 0.24338648428087262
# revenue of assortment [0, 3] is 0.10627933103146783
# testing for offertimes 60, 18th instance
# revenue of assortment [0, 1] is 0.2721236111939287
# revenue of assortment [0, 3, 6] is 0.2432503914386993
# testing for offertimes 60, 19th instance
# revenue of assortment [0, 6] is 0.10868308898434162
# revenue of assortment [0, 5, 6] is 0.12460781175018046
# testing for offertimes 60, 20th instance
# revenue of assortment [0, 2] is 0.14933205683124898
# revenue of assortment [0, 3] is 0.12572954683644505
# testing for offertimes 60, 21th instance
# revenue of assortment [0, 5] is 0.24345197540737235
# revenue of assortment [0, 1, 6] is 0.3233532955444044
# testing for offertimes 60, 22th instance
# revenue of assortment [0, 2, 6] is 0.233576957197426
# revenue of assortment [0, 3, 6] is 0.23759003240568538
# testing for offertimes 60, 23th instance
# revenue of assortment [0, 1] is 0.2627578895946906
# revenue of assortment [0, 2] is 0.06976577906394013
# testing for offertimes 60, 24th instance
# revenue of assortment [0, 1] is 0.17563320903813112
# revenue of assortment [0, 8] is 0.13473945784751779
# testing for offertimes 60, 25th instance
# revenue of assortment [0, 6] is 0.14539299104818124
# revenue of assortment [0, 1, 6] is 0.3293231297684874
# testing for offertimes 60, 26th instance
# revenue of assortment [0, 5, 6] is 0.21892462728537423
# revenue of assortment [0, 8] is 0.4999608160822798
# testing for offertimes 60, 27th instance
# revenue of assortment [0, 3] is 0.09041175369818663
# revenue of assortment [0, 5, 6] is 0.35156033441642004
# testing for offertimes 60, 28th instance
# revenue of assortment [0, 1] is 0.09022213496869132
# revenue of assortment [0, 2, 6] is 0.23120513781982965
# testing for offertimes 60, 29th instance
# revenue of assortment [0, 5] is 0.17108168751992434
# revenue of assortment [0, 5, 6] is 0.18631901159453718
# testing for offertimes 60, 30th instance
# revenue of assortment [0, 3] is 0.0870213995902821
# revenue of assortment [0, 2, 6] is 0.21404380571644088
# testing for offertimes 60, 31th instance
# revenue of assortment [0, 1] is 0.3287317865792341
# revenue of assortment [0, 5] is 0.1808776105071053
# testing for offertimes 60, 32th instance
# revenue of assortment [0, 2] is 0.03763172133934786
# revenue of assortment [0, 8] is 0.3630192838787809
# testing for offertimes 60, 33th instance
# revenue of assortment [0, 1, 6] is 0.3685570130766495
# revenue of assortment [0, 5, 6] is 0.31929305923551565
# testing for offertimes 60, 34th instance
# revenue of assortment [0, 3, 6] is 0.20256458917934955
# revenue of assortment [0, 8] is 0.35468225659992453
# testing for offertimes 60, 35th instance
# revenue of assortment [0, 3] is 0.019966464626523548
# revenue of assortment [0, 6] is 0.14923642046062122
# testing for offertimes 60, 36th instance
# revenue of assortment [0, 2, 6] is 0.2505029439600788
# revenue of assortment [0, 5, 6] is 0.3461290356703588
# testing for offertimes 60, 37th instance
# revenue of assortment [0, 1] is 0.21599691340768332
# revenue of assortment [0, 6] is 0.15634559708209533
# testing for offertimes 60, 38th instance
# revenue of assortment [0, 2] is 0.14962392960851095
# revenue of assortment [0, 5, 8] is 0.5873987543859193
# testing for offertimes 60, 39th instance
# revenue of assortment [0, 5] is 0.017846118124056363
# revenue of assortment [0, 5, 8] is 0.41013355267180474
# testing for offertimes 60, 40th instance
# revenue of assortment [0, 2] is 0.16163090208035774
# revenue of assortment [0, 6] is 0.1490764843148788
# testing for offertimes 60, 41th instance
# revenue of assortment [0, 1] is 0.37118516260703033
# revenue of assortment [0, 5, 8] is 0.6063429021505804
# testing for offertimes 60, 42th instance
# revenue of assortment [0, 6] is 0.07807554218237615
# revenue of assortment [0, 8] is 0.1761616499157068
# testing for offertimes 60, 43th instance
# revenue of assortment [0, 2, 6] is 0.24045845353391498
# revenue of assortment [0, 8] is 0.15220043584846069
# testing for offertimes 60, 44th instance
# revenue of assortment [0, 6] is 0.15298655078684475
# revenue of assortment [0, 2, 6] is 0.22693063863003388
# testing for offertimes 60, 45th instance
# revenue of assortment [0, 2] is 0.0018249403874349565
# revenue of assortment [0, 3, 6] is 0.24470771848454254
# testing for offertimes 60, 46th instance
# revenue of assortment [0, 6] is 0.07963525924927066
# revenue of assortment [0, 5, 8] is 0.5565355399862976
# testing for offertimes 60, 47th instance
# revenue of assortment [0, 1, 6] is 0.32138341963036393
# revenue of assortment [0, 8] is 0.29740620211111013
# testing for offertimes 60, 48th instance
# revenue of assortment [0, 3, 6] is 0.2227978556907512
# revenue of assortment [0, 5, 6] is 0.3615631659660435
# testing for offertimes 60, 49th instance
# revenue of assortment [0, 5] is 0.29392615772639813
# revenue of assortment [0, 2, 6] is 0.228982913576563

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_lcmnl_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'lcmnl_dist':all_lcmnl_distance_list[i],
                                    'true_best_rev':all_best_true_rev_list[i],'lcmnl_best_rev':all_best_rev_lcmnl_list[i],
                                    'lcmnl_best_rev_diff':all_lcmnl_best_rev_diff[i]})
    df_lcmnl_details1.to_csv('prediction/lcmnl/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        lcmnl_rank = all_lcmnl_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'lcmnl_rank':lcmnl_rank})
        df_rank.to_csv('prediction/lcmnl/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        lcmnl_rev = all_lcmnl_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'lcmnl_rev':lcmnl_rev})
        df_rev.to_csv('prediction/lcmnl/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
    
        lcmnl_runtime = all_lcmnl_pred_runtime[i][j]
        df_runtime = pd.DataFrame({'lcmnl_runtime':lcmnl_runtime})
        df_runtime.to_csv('prediction/lcmnl/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ## using sales fraction prediction
        ''' ## record the choice probability prediction interval
        true_prob = all_true_prob_list[i][j]
        df_true_prob = pd.DataFrame(true_prob)
        
        lcmnl_sales = all_lcmnl_sales_list[i][j]
        df_lcmnl_sales = pd.DataFrame(lcmnl_sales).T
 
        df_true_prob.to_csv('prediction/lcmnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lcmnl_sales.to_csv('prediction/lcmnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/lcmnl/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## avg prediction lcmnl runtime 
all_lcmnl_pred_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    avg_lcmnl_pred_runtime_collection = []
    
    for j in range(pred_instance_size[i]): 
        avg_lcmnl_pred_runtime_collection.append(np.mean(np.array(all_lcmnl_pred_runtime[i][j]))) 
        
    all_lcmnl_pred_avg_runtime.append(np.mean(np.array(avg_lcmnl_pred_runtime_collection)))

# %%
avg_lcmnl_dist = []
avg_lcmnl_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    
    avg_lcmnl_dist.append(np.mean(all_lcmnl_distance_list[i]))
    avg_lcmnl_best_rev_diff.append(np.mean(all_lcmnl_best_rev_diff[i]))
    

df_lcmnl_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'avg_lcmnl_dist':avg_lcmnl_dist,'avg_lcmnl_best_rev_diff':avg_lcmnl_best_rev_diff,
                                   'avg_lcmnl_pred_runtime':all_lcmnl_pred_avg_runtime})
df_lcmnl_jd_summary.to_csv('prediction/lcmnl/jd_lcmnl_summary.csv')

# %%
df_lcmnl_jd_summary
# Out:
#    offertimes  avg_lcmnl_dist  avg_lcmnl_best_rev_diff  avg_lcmnl_pred_runtime
# 0          20            2.12                 0.091575               47.469597
# 1          30            1.56                 0.115497               42.037897
# 2          40            0.58                 0.050153               42.979164
# 3          50            0.84                 0.119916               43.564705
# 4          60            0.22                 0.066682               42.560170

# %%
## record the limit loss of all instances
all_lcmnl_limit_loss = []
all_lcmnl_limit_prob = []
all_lcmnl_limit_runtime = []
all_lcmnl_kl_loss = []

for i in range(len(pred_offer_times_list)):

    
    ## define container for lcmnl limit 
    lcmnl_limit_loss_collection =[]
    lcmnl_limit_runtime_collection =[]
    lcmnl_limit_probability_collection =[]
    lcmnl_kl_loss_collection =[]
    
    for j in range(pred_instance_size[i]):
        starttime = time.time()
        weights, v_values,ll = expectation_maximization(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i], num_class, max_iterations)
        lcmnl_limit_prob = collection_distribution_lcmnl(n,all_full_collections[i],num_class,weights,v_values)
        lcmnl_limit_runtime = time.time()-starttime
        
        lcmnl_limit_loss = 0
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                lcmnl_limit_loss = lcmnl_limit_loss + all_full_offertimes[i][x]*all_full_instances[i][j][y][x]*np.abs(all_full_instances[i][j][y][x] -lcmnl_limit_prob[y][x])
                 
        lcmnl_limit_probability_collection.append(lcmnl_limit_prob)
        lcmnl_limit_loss_collection.append(lcmnl_limit_loss)
        lcmnl_limit_runtime_collection.append(lcmnl_limit_runtime)
        lcmnl_kl_loss_collection.append(ll)

    
    ## for each train instance [i][j] limit loss result is a number
    all_lcmnl_kl_loss.append(lcmnl_kl_loss_collection)
    all_lcmnl_limit_loss.append(lcmnl_limit_loss_collection)
    all_lcmnl_limit_runtime.append(lcmnl_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_lcmnl_limit_prob.append(lcmnl_limit_probability_collection)

# %%
## adding limit results
ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    df_lcmnl_loss = pd.DataFrame({'ins_idx':ins_idx,'lcmnl_loss':all_lcmnl_limit_loss[i],'avg_loss':all_lcmnl_limit_loss[i]/sum(all_full_offertimes[i]), 'lcmnl_total_kl':all_lcmnl_kl_loss[i],'avg_kl':all_lcmnl_kl_loss[i]/sum(all_full_offertimes[i]) , 'lcmnl_limit_time':all_lcmnl_limit_runtime[i]})
    df_lcmnl_loss.to_csv('limit/lcmnl/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_lcmnl_limit_prob[i][j])
        df_limit_prob.to_csv('limit/lcmnl/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
all_avg_kl = []
for i in range(len(pred_offer_times_list)):
    all_avg_loss.append(all_lcmnl_limit_loss[i]/np.sum(all_full_offertimes[i]))
    all_avg_kl.append(all_lcmnl_kl_loss[i]/np.sum(all_full_offertimes[i]))

# %%
avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_lcmnl_limit_runtime = []
avg_total_kl = []
avg_total_kl_se = []

#avg_loss = []
avg_loss_se = []
avg_kl_se = []

for i in range(len(pred_offer_times_list)):

    
    avg_total_limit_loss.append(np.mean(all_lcmnl_limit_loss[i]))
    avg_lcmnl_limit_runtime.append(np.sum(all_lcmnl_limit_runtime[i]))
    avg_toal_limit_loss_se.append(np.std(all_lcmnl_limit_loss[i])/np.sqrt(len(all_lcmnl_limit_loss[i])))
    avg_total_kl.append(np.mean(all_lcmnl_kl_loss[i]))
    avg_total_kl_se.append(np.std(all_lcmnl_kl_loss[i])/np.sqrt(len(all_avg_kl[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))
    avg_kl_se.append(np.std(all_avg_kl[i])/np.sqrt(len(all_avg_kl[i])))

# %%
avg_loss = []
avg_kl = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
    avg_kl.append(avg_total_kl[i]/sum(all_full_offertimes[i]))

# %%
df_lcmnl_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'total_lcmnl_loss':avg_total_limit_loss,'total_lcmnl_loss_se':avg_toal_limit_loss_se,
                                   'avg_lcmnl_loss':avg_loss,'avg_lcmnl_loss_se':avg_loss_se,
                                   'total_lcmnl_kl':avg_total_kl,'total_lcmnl_kl_se':avg_total_kl_se,
                                   'avg_lcmnl_kl':avg_kl,'avg_lcmnl_kl_se':avg_kl_se,
                                   'avg_lcmnl_limit_runtime':avg_lcmnl_limit_runtime
                                   })
df_lcmnl_limit.to_csv('limit/lcmnl/lcmnl_limit_summary.csv')
df_lcmnl_limit
# Out:
#    offertimes  total_lcmnl_loss  total_lcmnl_loss_se  avg_lcmnl_loss  \
# 0          20         67.733787             2.313626        0.008848
# 1          30         55.069060             2.076380        0.007314
# 2          40         42.194244             2.179398        0.005732
# 3          50         33.063531             3.572216        0.004599
# 4          60         26.377373             3.155740        0.003725
#
#    avg_lcmnl_loss_se  total_lcmnl_kl  total_lcmnl_kl_se  avg_lcmnl_kl  \
# 0           0.000302    -4764.018862          26.975817     -0.622341
# 1           0.000276    -4672.233323          26.390426     -0.620565
# 2           0.000296    -4552.449552          25.374116     -0.618455
# 3           0.000497    -4430.070322          24.873517     -0.616143
# 4           0.000446    -4351.286538          24.318495     -0.614415
#
#    avg_lcmnl_kl_se  avg_lcmnl_limit_runtime
# 0         0.003524              2061.637942
# 1         0.003505              2024.746183
# 2         0.003447              2145.736397
# 3         0.003459              2032.442390
# 4         0.003434              1663.410437

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.008848306548854783
# 0.007314259580751285
# 0.005732134713056204
# 0.004598543974889965
# 0.003724565486752089
