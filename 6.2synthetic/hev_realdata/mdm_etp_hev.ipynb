# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def collection_distribution_hev(n,collection,price):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n))
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
''' def collection_distribution_hev(n,collection):
    # generate mean 
    mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1)
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = np.random.uniform(9,10)
    scale_1n = np.random.uniform(0.04,2,n-1)
    scales = np.hstack((scale_0,scale_1n))
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])

    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution '''
# Out:
# ' def collection_distribution_hev(n,collection):\n    # generate mean \n    mu_0 = np.random.uniform(2,3)\n    mu_1n = np.random.uniform(-3,-2,n-1)\n    # np.random.uniform(-2,2,n-1)\n    mu = np.hstack((mu_0,mu_1n))\n    \n    scale_0 = np.random.uniform(9,10)\n    scale_1n = np.random.uniform(0.04,2,n-1)\n    scales = np.hstack((scale_0,scale_1n))\n    \n    sample_size = 10000\n    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])\n\n    \n    collection_distribution = np.zeros((n,len(collection)))\n    for i in range(len(collection)):\n        curr_assortment = collection[i]\n        curr_population = [[] for _ in range(sample_size)] \n\n        for j in range(sample_size):\n            for k in curr_assortment:\n                curr_population[j].append(utility_samples[j][k])\n                # each sub list records only the utilities of products in the current assortment\n                \n        frequency = [0]*len(curr_assortment)\n        for j in range(sample_size):\n            max_index = np.argmax(np.array(curr_population[j]))\n            # product is chosen iff the utility of the product is max in the assortment\n            frequency[max_index] = frequency[max_index] +1 \n            # update the frequency of product to be chosen\n            \n        prob = np.array(frequency)/np.sum(frequency)\n        for j in range(len(curr_assortment)):\n            collection_distribution[curr_assortment[j]][i] = prob[j]\n            \n    return collection_distribution '

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes,price):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_hev_instance = collection_distribution_hev(n,whole_collection,price)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_hev_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes,price)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])
    
    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    #print(pd.DataFrame(curr_whole_instance))
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-6 or curr_choice_collection[y][x] >0.999:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes,price)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-6 or curr_choice_collection[y][x] >0.999:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:  
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples)    '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        ''' condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-3:
                    condition = True
        if condition == True:
            print('instance_generation error') '''
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm_feasibility')
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    lam_values = [lam[i].x for i in range(data.shape[1])]
    lam_values = np.array(lam_values)

    if (model.objVal> 0):
        #model.write("mdmfeas_out.sol")
        #model.write("mdmfeas_model.lp") 
        return [1,model.Runtime,lam_values]
    else:
        #model.write("mdminfeas_model.lp")
        #return [0, used_time]
        return [0,model.Runtime,lam_values]

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.001

    model = gp.Model('mdm_limit')
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{i}_{j}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}")

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    if model.Status == GRB.OPTIMAL:
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
        
        lam_values = [lam[i].x for i in range(m)]
        lam_values = np.array(lam_values)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print('mdm limit computation error')
        #model.write("mdmlimit_out.sol")
        #model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,x_values]

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
def robust_prediction_lp(lambda_S_lst,lambda_A,prod_in_ass,assortment_A,limit_prob,price):
    # robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
    
    model = gp.Model('robust_rev_lp')
    model.setParam('OutputFlag', 0)
    x = model.addVars(len(assortment_A),vtype=GRB.CONTINUOUS, lb=0, name='x')
    
    model.addConstr(gp.quicksum(x[i] for i in range(len(assortment_A))) == 1, name="Normalization")
    
    ## MDM consistency
    for i in range(len(assortment_A)):
        for j in range(len(prod_in_ass[assortment_A[i]])):
            if lambda_A >= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]<= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
            if lambda_A <= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]>= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
    
    # Objective
    obj = gp.quicksum(price[assortment_A[i]] * x[i] for i in range(len(assortment_A)))
    model.setObjective(obj, GRB.MINIMIZE)

    # Optimize the model
    model.optimize()
    
    if model.Status == GRB.OPTIMAL :
        return [model.objVal, [x[i].x for i in range(len(assortment_A))], model.Runtime]
    else:
        return [100000,[-1 for i in range(len(assortment_A))], model.Runtime]

# %%
def best_case_prediction_lp(lambda_S_lst,lambda_A,prod_in_ass,assortment_A,limit_prob,price):
    
    model = gp.Model('best_case_rev_lp')
    model.setParam('OutputFlag', 0)
    x = model.addVars(len(assortment_A),vtype=GRB.CONTINUOUS, lb=0, name='x')
    
    model.addConstr(gp.quicksum(x[i] for i in range(len(assortment_A))) == 1, name="Normalization")
    
    ## MDM consistency
    for i in range(len(assortment_A)):
        for j in range(len(prod_in_ass[assortment_A[i]])):
            if lambda_A >= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]<= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
            if lambda_A <= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]>= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
    
    # Objective
    obj = gp.quicksum(price[assortment_A[i]] * x[i] for i in range(len(assortment_A)))
    model.setObjective(obj, GRB.MAXIMIZE)

    # Optimize the model
    model.optimize()
    
    if model.Status == GRB.OPTIMAL :
        return [model.objVal, [x[i].x for i in range(len(assortment_A))], model.Runtime]
    else:
        return [-100000,[-1 for i in range(len(assortment_A))], model.Runtime]

# %%
## mdm milp for the worst case revenue
def mdm_revenue(curr_limit_prob, curr_lam, prod_in_ass,lambda_A_lst, assortment_A, price):
    
    robust_revenue_lst = []
    best_case_revenue_lst = []
    robust_pred_runtime = 0
    best_case_pred_runtime = 0
    #robust_prob_lst = []
    #best_case_prob_lst = []

    for j in range(len(lambda_A_lst)):
        lambda_A = lambda_A_lst[j]
        curr_robust_revenue,curr_robust_prob,curr_robust_runtime = robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
        
        robust_revenue_lst.append(curr_robust_revenue)
        robust_pred_runtime = robust_pred_runtime + curr_robust_runtime
        #robust_prob_lst.append(curr_robust_prob)
        
        curr_best_case_revenue,curr_bestcase_prob,curr_best_case_runtime = best_case_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
        best_case_revenue_lst.append(curr_best_case_revenue)
        best_case_pred_runtime = best_case_pred_runtime + curr_best_case_runtime
        #best_case_prob_lst.append(curr_bestcase_prob)
    
    robust_revenue_A = np.min(robust_revenue_lst)
    best_case_revenue_A = np.max(best_case_revenue_lst)
    
    ''' robust_prob_A = robust_prob_lst[np.argmin(robust_revenue_lst)]
    bestcase_prob_A = best_case_prob_lst[np.argmax(best_case_revenue_lst)] '''
    
    print(f'the robust revenue for assortment {assortment_A} is {robust_revenue_A} with runtime {robust_pred_runtime}')
    if robust_revenue_A>100:
        print('robust MDM prediction error ')
    print(f'the best-case revenue for assortment {assortment_A} is {best_case_revenue_A} with runtime {best_case_pred_runtime}\n')
    if best_case_revenue_A<0:
        print('best-case MDM prediction error ')
    
    ''' lb_sales_A = np.zeros(len(price))
    ub_sales_A = np.zeros(len(price))
    
    for k in range(len(assortment_A)):
        unit_price = np.zeros(n)
        unit_price[assortment_A[k]] = 1
        
        robust_product_prob_lst = []
        bestcase_product_prob_lst = []
        
        for j in range(len(lambda_A_lst)):
            if best_case_revenue_lst[j]>0:
                lambda_A = lambda_A_lst[j]
                curr_robust_prob = robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,unit_price)[0]
                
                robust_product_prob_lst.append(curr_robust_prob)
                
                curr_bestcase_prob = best_case_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,unit_price)[0]
                bestcase_product_prob_lst.append(curr_bestcase_prob)
        
        lb_sales_A[assortment_A[k]] = np.min(robust_product_prob_lst)
        ub_sales_A[assortment_A[k]] = np.max(bestcase_product_prob_lst)
        print(f'the sales lb for product {assortment_A[k]} in assortment {assortment_A} is {lb_sales_A[assortment_A[k]]}')
        print(f'the sales ub for product {assortment_A[k]} in assortment {assortment_A} is {ub_sales_A[assortment_A[k]]}\n')
     '''
    #return [robust_revenue_A,robust_pred_runtime,robust_prob_A,lb_sales_A, best_case_revenue_A,best_case_pred_runtime, bestcase_prob_A,ub_sales_A]
    return [robust_revenue_A,robust_pred_runtime, best_case_revenue_A,best_case_pred_runtime]

# %%
def mdm_prediction(curr_test_collection,curr_test_instance,price,curr_limit_prob, curr_lam, curr_train_collection):
    ''' true assortment ranking '''
    #true_choice_prob = [] 
    true_revenue = []
    
    ''' lb_mdm_rev_prob = []
    ub_mdm_rev_prob = []
    
    lb_mdm_sales = []
    ub_mdm_sales = [] '''
    
    lb_mdm_revenue = [] 
    ub_mdm_revenue = []
    
    lb_mdm_runtime = []
    ub_mdm_runtime = []
    
    prod_in_ass = [[] for _ in range(len(price))]
    for i, assort in enumerate(curr_train_collection):
        for j in assort:
            prod_in_ass[j].append(i)
    
    dec_lam = np.abs(np.sort(-curr_lam)) # multipliers in decreasing order, probabilities in increasing order
    lambda_A_lst = [np.max(curr_lam)+1]
    for i in range(len(dec_lam)-1):
        lambda_A_lst.append((dec_lam[i] + dec_lam[i+1])/2)
    lambda_A_lst.append(np.min(curr_lam)-1)
    
    for k in range(len(curr_test_collection)):
            
            assortment_A = curr_test_collection[k]
            
            # true revenue and true choice probabilities for current testing assortment
            curr_revenue = np.dot(curr_test_instance[:,k],price)
            true_revenue.append(curr_revenue)
            #true_choice_prob.append(curr_test_instance[:,k])
            
            # MDM revenue prediction
            print(f'revenue prediction for unseen assortment {assortment_A}')
            mdm_prediction_result = mdm_revenue(curr_limit_prob, curr_lam, prod_in_ass,lambda_A_lst, assortment_A, price)
            
            # return [robust_revenue_A,robust_pred_runtime, best_case_revenue_A,best_case_pred_runtime]
            
            ## record the revenue result
            lb_mdm_revenue.append(mdm_prediction_result[0])
            ub_mdm_revenue.append(mdm_prediction_result[2])
            
            ## record the choice probability result
            ''' lb_prob = np.zeros(n)
            lb_prob_result = mdm_prediction_result[2]
            
            ub_prob = np.zeros(n)
            ub_prob_result = mdm_prediction_result[6]
            
            for l in range(len(assortment_A)):
                lb_prob[assortment_A[l]] = lb_prob_result[l]
                ub_prob[assortment_A[l]] = ub_prob_result[l]
            
            lb_mdm_rev_prob.append(lb_prob)
            ub_mdm_rev_prob.append(ub_prob) '''
            
            ## record the runtime result
            lb_mdm_runtime.append(mdm_prediction_result[1])
            ub_mdm_runtime.append(mdm_prediction_result[3])
            
            
            ## MDM choice probability interval prediction
            ''' lb_sales_frac = mdm_prediction_result[3]
            ub_sales_frac = mdm_prediction_result[-1] '''
            
            ''' lb_mdm_sales.append(lb_sales_frac)
            ub_mdm_sales.append(ub_sales_frac) '''
    return true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime       
    #return true_choice_prob,true_revenue,lb_mdm_rev_prob,ub_mdm_rev_prob,lb_mdm_sales,ub_mdm_sales,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime

# %%
## record representability of all instances
''' all_mdm_rep = []
all_mdm_rep_time = [] '''

## record the limit loss of all instances
''' all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_runtime = [] '''

## record the kendall tau distance between the predicted ranking of MDM and the truth
all_mdm_lb_distance_list = []  
all_mdm_ub_distance_list = []

## record the true revenue of the predicted best assortment
all_best_true_revenue_list = []
all_best_revenue_mdm_lb = []  
all_best_revenue_mdm_ub =[]

## record the difference in best assortment
all_mdm_lb_best_rev_diff = []
all_mdm_ub_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mdm_lb_revenue_list = []
all_mdm_ub_revenue_list = []

## choice probability under the revenue prediction 
''' all_true_choice_prob_list = [] 
all_mdm_lb_rev_prob_list = []
all_mdm_ub_rev_prob_list = []

all_mdm_lb_sales_list = []
all_mdm_ub_sales_list = [] '''

all_true_ranking = []
all_mdm_lb_ranking = []
all_mdm_ub_ranking = []

## record the runtime of MDM prediction
all_mdm_rev_lb_runtime = []
all_mdm_rev_ub_runtime = []

for i in range(len(all_full_collections)):
    ## define container for mdm representability check
    ''' mdm_rep_collection =[]
    mdm_rep_runtime_collection =[] '''
    
    ## define container for mdm limit 
    ''' mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[] '''
    
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mdm_lb_best_rev_collection = [] # a container for the best revenue predicted by robust MDM
    mdm_ub_best_rev_collection = [] # a container for the best revenue predicted by best-case MDM
    
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mdm_lb_ranking_collection = [] # a container for ranking by robust mdm
    mdm_ub_ranking_collection = [] # a container for ranking by best-case mdm
    
    mdm_lb_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mdm
    mdm_ub_distance_collection = [] # kendall tau distance between true ranking and the ranking by best-case mdm
    
    ''' true_choice_prob_collection = []
    mdm_lb_rev_prob_collection = []
    mdm_ub_rev_prob_collection = []
    mdm_lb_sales_frac_collection = []
    mdm_ub_sales_frac_collection = [] '''
    
    true_revenue_collection = []
    mdm_lb_revenue_collection = []
    mdm_ub_revenue_collection = []
    
    mdm_lb_runtime_collection = []
    mdm_ub_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')

        # the following lists are of the same size as number of testing assortments
        
        row_data = row_assortment_data(all_train_instances[i][j],all_train_collection[i][j])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_train_instances[i][j],rank,equal)
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        ''' mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_runtime_collection.append(curr_rep_result[1]) '''
        
                # check if representable
        if curr_rep_result[0] > 0:
            # representable and then do prediction 
            # mdm_prediction(curr_test_instance,curr_test_collection,price,curr_train_instance,curr_train_collection,curr_train_perm_collection,unseen_assortment_perm_collection) mdm_prediction(curr_test_collection,curr_test_instance,price,curr_limit_prob, curr_lam, curr_train_collection)
            true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime = mdm_prediction(all_test_collection[i][j],all_test_instance[i][j],price,all_train_instances[i][j],curr_rep_result[-1], all_train_collection[i][j])
            #return true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime 
            ## just keeping the same length as other lists
            ''' mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(0)
            mdm_limit_probability_collection.append(all_train_instances[i][j]) '''
        else:
            #produts_notin_collection = find_product_notin_assortment(all_train_collection[i][j],n)
            # mdm_limit(data, collection,offer_times)
            curr_limit_result = mdm_limit(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            
            curr_limit_prob = curr_limit_result[-1]
            ''' mdm_limit_probability_collection.append(curr_limit_prob)
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_runtime_collection.append(curr_limit_result[1]) '''
            
            curr_lam = curr_limit_result[2]
            curr_loss = curr_limit_result[0]
            #feasbile_mdm_limit_prob_result = feas_limit_mdm_prob(curr_limit_prob,all_train_collection[i][j],curr_lam,0.01,curr_loss,all_train_instances[i][j],all_train_offertimes[i][j])
            #feasbile_mdm_limit_prob = feasbile_mdm_limit_prob_result[0]
            ## test if feasbile_mdm_limit_prob is feasible
            
            
            true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime = mdm_prediction(all_test_collection[i][j],all_test_instance[i][j],price,curr_limit_prob,curr_lam, all_train_collection[i][j])
            
        true_revenue_collection.append(true_revenue)
        #true_choice_prob_collection.append(true_choice_prob)
        
        mdm_lb_revenue_collection.append(lb_mdm_revenue)   
        mdm_ub_revenue_collection.append(ub_mdm_revenue)
        ''' mdm_lb_rev_prob_collection.append(lb_mdm_rev_prob)
        mdm_ub_rev_prob_collection.append(ub_mdm_rev_prob) '''
        
        mdm_lb_runtime_collection.append(lb_mdm_runtime)
        mdm_ub_runtime_collection.append(ub_mdm_runtime)
        
        ## sales fraction record
        ''' mdm_lb_sales_frac_collection.append(lb_mdm_sales)
        mdm_ub_sales_frac_collection.append(ub_mdm_sales) '''
        
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_mdm_lb_rank  = np.argsort(-np.array(lb_mdm_revenue)) 
        mdm_lb_ranking_collection.append(curr_mdm_lb_rank)
        mdm_lb_best_rev_collection.append(true_revenue[curr_mdm_lb_rank[0]])
        
        # ub mdm assortment ranking for test instance [i][j]
        curr_mdm_ub_rank = np.argsort(-np.array(ub_mdm_revenue)) 
        mdm_ub_ranking_collection.append(curr_mdm_ub_rank)
        mdm_ub_best_rev_collection.append(true_revenue[curr_mdm_ub_rank[0]])
        
        #  MDM kendallTau Distance for current instance [i][j]
        curr_mdm_lb_dist = kendall_tau_distance(curr_true_rank, curr_mdm_lb_rank)
        mdm_lb_distance_collection.append(curr_mdm_lb_dist)
        
        curr_mdm_ub_dist = kendall_tau_distance(curr_true_rank, curr_mdm_ub_rank)
        mdm_ub_distance_collection.append(curr_mdm_ub_dist)
    
    ## for each train instance [i][j] representability result is a number
    ''' all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_runtime_collection)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection) '''
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mdm_lb_distance_list.append(mdm_lb_distance_collection)
    all_mdm_ub_distance_list.append(mdm_ub_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_revenue_list.append(true_best_rev_collection) 
    all_best_revenue_mdm_lb.append(mdm_lb_best_rev_collection)
    all_best_revenue_mdm_ub.append(mdm_ub_best_rev_collection)

    # for each test instance [i][j] best revenue difference is a number
    with np.errstate(divide='ignore', invalid='ignore'):
        result = (np.array(true_best_rev_collection) - np.array(mdm_lb_best_rev_collection))/ np.array(true_best_rev_collection)
        # Replace NaN values (0/0) with 0 values with a large number or zero
        result = np.where(np.isnan(result), 0.0, result)
        result = np.where(np.isinf(result), 0.0, result)
        
    all_mdm_lb_best_rev_diff.append(result)
    
    with np.errstate(divide='ignore', invalid='ignore'):
        result2 = (np.array(true_best_rev_collection) - np.array(mdm_ub_best_rev_collection))/np.array(true_best_rev_collection)
        # Replace NaN values (0/0) with 0 values with a large number or zero
        result2 = np.where(np.isnan(result), 0.0, result2)
        result2 = np.where(np.isinf(result), 0.0, result2)
    
    # for each test instance [i][j] best revenue difference is a number
    
    all_mdm_ub_best_rev_diff.append(result2)
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    #all_true_choice_prob_list.append(true_choice_prob_collection)
    all_mdm_lb_revenue_list.append(mdm_lb_revenue_collection)
    all_mdm_ub_revenue_list.append(mdm_ub_revenue_collection)
    ''' all_mdm_lb_rev_prob_list.append(mdm_lb_rev_prob_collection)
    all_mdm_ub_rev_prob_list.append(mdm_ub_rev_prob_collection)
    
    all_mdm_lb_sales_list.append(mdm_lb_sales_frac_collection)
    all_mdm_ub_sales_list.append(mdm_ub_sales_frac_collection) '''
    
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mdm_lb_ranking.append(mdm_lb_ranking_collection)
    all_mdm_ub_ranking.append(mdm_ub_ranking_collection)
    
    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mdm_rev_lb_runtime.append(mdm_lb_runtime_collection)
    all_mdm_rev_ub_runtime.append(mdm_ub_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.27526357389517536 with runtime 0.0014410018920898438
# the best-case revenue for assortment [0, 5] is 0.31593008130081307 with runtime 0.0011022090911865234
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.22457210333526123 with runtime 0.0010967254638671875
# the best-case revenue for assortment [0, 3, 7] is 0.22457210333526123 with runtime 0.0009760856628417969
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.29168258966201716 with runtime 0.0012602806091308594
# the best-case revenue for assortment [0, 5, 6] is 0.30262454950493145 with runtime 0.001130819320678711
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3279845485726716 with runtime 0.0013256072998046875
# the best-case revenue for assortment [0, 5, 8] is 0.36775910235045783 with runtime 0.0013856887817382812
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.19124552845528311 with runtime 0.0010285377502441406
# the best-case revenue for assortment [0, 6, 8] is 0.2772703832752614 with runtime 0.0010094642639160156
#
# testing for offertimes 20, 1th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.11760546875 with runtime 0.0012636184692382812
# the best-case revenue for assortment [0, 3] is 0.11760546875 with runtime 0.001039266586303711
#
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.2305767307175282 with runtime 0.0009906291961669922
# the best-case revenue for assortment [0, 4] is 0.31653814793244034 with runtime 0.0010983943939208984
#
# revenue prediction for unseen assortment [0, 1, 4]
# the robust revenue for assortment [0, 1, 4] is 0.2591085526315789 with runtime 0.00167083740234375
# the best-case revenue for assortment [0, 1, 4] is 0.4662335526315784 with runtime 0.0015978813171386719
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.11760546875 with runtime 0.0015342235565185547
# the best-case revenue for assortment [0, 3, 4] is 0.3183851626016255 with runtime 0.001596212387084961
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.24720726929978812 with runtime 0.0011250972747802734
# the best-case revenue for assortment [0, 5, 6] is 0.24720726929978812 with runtime 0.0010161399841308594
#
# testing for offertimes 20, 2th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.3873197088906372 with runtime 0.001222848892211914
# the best-case revenue for assortment [0, 1, 8] is 0.5141483253588517 with runtime 0.0010175704956054688
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15044482409801047 with runtime 0.0015866756439208984
# the best-case revenue for assortment [0, 2, 6] is 0.16315818815331007 with runtime 0.0014791488647460938
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.13637317073170732 with runtime 0.001110076904296875
# the best-case revenue for assortment [0, 3, 4] is 0.15032395519970065 with runtime 0.0011739730834960938
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.3602717467760844 with runtime 0.0012600421905517578
# the best-case revenue for assortment [0, 4, 5] is 0.4867318014994776 with runtime 0.0011463165283203125
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.5140721062618601 with runtime 0.0012056827545166016
# the best-case revenue for assortment [0, 5, 8] is 0.5270090896468738 with runtime 0.0012159347534179688
#
# testing for offertimes 20, 3th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.08675 with runtime 0.0010523796081542969
# the best-case revenue for assortment [0, 1] is 0.26025000000000065 with runtime 0.0008704662322998047
#
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.3704455354542781 with runtime 0.0010235309600830078
# the best-case revenue for assortment [0, 4] is 0.4142500000000011 with runtime 0.001085042953491211
#
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.11166666666666714 with runtime 0.0010094642639160156
# the best-case revenue for assortment [0, 7] is 0.16750000000000045 with runtime 0.0010211467742919922
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.1392341463414661 with runtime 0.0011990070343017578
# the best-case revenue for assortment [0, 3, 4] is 0.1392341463414661 with runtime 0.0011851787567138672
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.46569988276670565 with runtime 0.0013952255249023438
# the best-case revenue for assortment [0, 8] is 0.46569988276670904 with runtime 0.0011444091796875
#
# testing for offertimes 20, 4th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.48777085324721436 with runtime 0.001272439956665039
# the best-case revenue for assortment [0, 1, 8] is 0.5546782568132742 with runtime 0.0011272430419921875
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.13280294263305717 with runtime 0.0014417171478271484
# the best-case revenue for assortment [0, 2, 3, 6] is 0.1678391357284524 with runtime 0.001386404037475586
#
# revenue prediction for unseen assortment [0, 3, 8]
# the robust revenue for assortment [0, 3, 8] is 0.20688482890375495 with runtime 0.0011816024780273438
# the best-case revenue for assortment [0, 3, 8] is 0.5808571608040202 with runtime 0.0011556148529052734
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2550516304347826 with runtime 0.0012073516845703125
# the best-case revenue for assortment [0, 5, 6] is 0.32851952721878225 with runtime 0.0011217594146728516
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.22465990038046704 with runtime 0.0011310577392578125
# the best-case revenue for assortment [0, 6, 7] is 0.22885223568335522 with runtime 0.0009636878967285156
#
# testing for offertimes 20, 5th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.13527587734845806 with runtime 0.0012164115905761719
# the best-case revenue for assortment [0, 1] is 0.2370398481973435 with runtime 0.0009179115295410156
#
# revenue prediction for unseen assortment [0, 1, 4]
# the robust revenue for assortment [0, 1, 4] is 0.35813647091260004 with runtime 0.0011081695556640625
# the best-case revenue for assortment [0, 1, 4] is 0.3862434837545875 with runtime 0.0011286735534667969
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.1808217636022514 with runtime 0.0010254383087158203
# the best-case revenue for assortment [0, 2, 6] is 0.18295902439024392 with runtime 0.0010256767272949219
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.19804543055037022 with runtime 0.0009582042694091797
# the best-case revenue for assortment [0, 4, 7] is 0.2204453034402783 with runtime 0.0010120868682861328
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.14658940011648222 with runtime 0.001310110092163086
# the best-case revenue for assortment [0, 5, 6] is 0.19680394240284876 with runtime 0.0013546943664550781
#
# testing for offertimes 20, 6th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.372825 with runtime 0.0014472007751464844
# the best-case revenue for assortment [0, 4] is 0.4971000000000001 with runtime 0.0010917186737060547
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.1674418880455409 with runtime 0.001360177993774414
# the best-case revenue for assortment [0, 1, 3] is 0.19550806451612895 with runtime 0.0013775825500488281
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.21319109026963656 with runtime 0.0011749267578125
# the best-case revenue for assortment [0, 3, 7] is 0.22749758852125 with runtime 0.001270294189453125
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4751340132827325 with runtime 0.0012302398681640625
# the best-case revenue for assortment [0, 4, 8] is 0.547642156862745 with runtime 0.0011432170867919922
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3484776533765191 with runtime 0.0013988018035888672
# the best-case revenue for assortment [0, 5, 8] is 0.4518478260869565 with runtime 0.0012385845184326172
#
# testing for offertimes 20, 7th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.12163408316334465 with runtime 0.001219034194946289
# the best-case revenue for assortment [0, 1] is 0.19518749999999999 with runtime 0.0010280609130859375
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.15771793751365512 with runtime 0.001207113265991211
# the best-case revenue for assortment [0, 1, 6] is 0.16748968724218188 with runtime 0.0011637210845947266
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.14186550138758597 with runtime 0.0010645389556884766
# the best-case revenue for assortment [0, 3, 6] is 0.14186550138758589 with runtime 0.0011429786682128906
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.3328716917922952 with runtime 0.0010683536529541016
# the best-case revenue for assortment [0, 4, 5] is 0.35156961478182835 with runtime 0.0009541511535644531
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.10753919349220886 with runtime 0.0009801387786865234
# the best-case revenue for assortment [0, 8] is 0.285375 with runtime 0.0009374618530273438
#
# testing for offertimes 20, 8th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.08408357870955677 with runtime 0.0011718273162841797
# the best-case revenue for assortment [0, 1] is 0.2313333333333333 with runtime 0.0008778572082519531
#
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.09477169605949116 with runtime 0.0009799003601074219
# the best-case revenue for assortment [0, 7] is 0.14888888888888888 with runtime 0.0009121894836425781
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.2483327453762236 with runtime 0.001142740249633789
# the best-case revenue for assortment [0, 1, 8] is 0.348704462574005 with runtime 0.001238107681274414
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.5412866666666667 with runtime 0.0010292530059814453
# the best-case revenue for assortment [0, 4, 6] is 0.5412866666666667 with runtime 0.0010361671447753906
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.16424916666666683 with runtime 0.0009887218475341797
# the best-case revenue for assortment [0, 8] is 0.38205125218404196 with runtime 0.0009515285491943359
#
# testing for offertimes 20, 9th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.3071223816355809 with runtime 0.0013365745544433594
# the best-case revenue for assortment [0, 1] is 0.3265882352941176 with runtime 0.001177072525024414
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.23055989583333328 with runtime 0.0009751319885253906
# the best-case revenue for assortment [0, 1, 3] is 0.2959975228658537 with runtime 0.0009522438049316406
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.15719500265014844 with runtime 0.0013446807861328125
# the best-case revenue for assortment [0, 2, 3, 6] is 0.16544371443956113 with runtime 0.0013816356658935547
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.3795175879396985 with runtime 0.0011401176452636719
# the best-case revenue for assortment [0, 3, 5] is 0.3967874270908112 with runtime 0.0010061264038085938
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4732758133938076 with runtime 0.0011548995971679688
# the best-case revenue for assortment [0, 4, 8] is 0.502968137254902 with runtime 0.0010497570037841797
#
# testing for offertimes 20, 10th instance
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.2372344322344322 with runtime 0.0015294551849365234
# the best-case revenue for assortment [0, 1, 3] is 0.2788548387096773 with runtime 0.001220703125
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.19092082111436956 with runtime 0.0010442733764648438
# the best-case revenue for assortment [0, 2, 6] is 0.1909208211143695 with runtime 0.0009307861328125
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.21805033936651586 with runtime 0.000997304916381836
# the best-case revenue for assortment [0, 3, 4] is 0.21816091628959278 with runtime 0.0009970664978027344
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.15466424435779275 with runtime 0.0012347698211669922
# the best-case revenue for assortment [0, 3, 6] is 0.15882258064516133 with runtime 0.0012590885162353516
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.15155853232382063 with runtime 0.0016951560974121094
# the best-case revenue for assortment [0, 5, 6] is 0.17239741401504677 with runtime 0.0013892650604248047
#
# testing for offertimes 20, 11th instance
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.14145934959349596 with runtime 0.0011928081512451172
# the best-case revenue for assortment [0, 1, 3] is 0.17876000318826724 with runtime 0.001081228256225586
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.2646575063256613 with runtime 0.001516580581665039
# the best-case revenue for assortment [0, 1, 7] is 0.2978706034286293 with runtime 0.0019428730010986328
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.16167019901416255 with runtime 0.0015265941619873047
# the best-case revenue for assortment [0, 2, 6] is 0.18525365853658537 with runtime 0.0014739036560058594
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.3482235294117647 with runtime 0.0011298656463623047
# the best-case revenue for assortment [0, 4, 6] is 0.4119349593495934 with runtime 0.0011081695556640625
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.1650856144437973 with runtime 0.001386404037475586
# the best-case revenue for assortment [0, 5, 6] is 0.1903575295750089 with runtime 0.0013015270233154297
#
# testing for offertimes 20, 12th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.20411764705882351 with runtime 0.0012679100036621094
# the best-case revenue for assortment [0, 1] is 0.24494117647058816 with runtime 0.0010843276977539062
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.3146340340807619 with runtime 0.0010058879852294922
# the best-case revenue for assortment [0, 1, 5] is 0.3155002679855712 with runtime 0.0010046958923339844
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.13484375000000004 with runtime 0.0011332035064697266
# the best-case revenue for assortment [0, 2, 3, 6] is 0.22646562500000003 with runtime 0.001157522201538086
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.1271924669715447 with runtime 0.0012052059173583984
# the best-case revenue for assortment [0, 3, 6] is 0.1428740088619403 with runtime 0.0010995864868164062
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.16603219644776523 with runtime 0.0013997554779052734
# the best-case revenue for assortment [0, 6, 7] is 0.19538970189701896 with runtime 0.0012409687042236328
#
# testing for offertimes 20, 13th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.20226562137050283 with runtime 0.001241445541381836
# the best-case revenue for assortment [0, 4] is 0.36021739130434777 with runtime 0.0012645721435546875
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.08125714285714285 with runtime 0.0013375282287597656
# the best-case revenue for assortment [0, 6] is 0.11070394736842104 with runtime 0.0011882781982421875
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.37710165870000395 with runtime 0.0010237693786621094
# the best-case revenue for assortment [0, 4, 5] is 0.3800936597500304 with runtime 0.0009937286376953125
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.3674827266336608 with runtime 0.001123666763305664
# the best-case revenue for assortment [0, 4, 8] is 0.3719461993398131 with runtime 0.0011143684387207031
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.1758099624060149 with runtime 0.0011811256408691406
# the best-case revenue for assortment [0, 6, 8] is 0.2146711103667726 with runtime 0.0012004375457763672
#
# testing for offertimes 20, 14th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.14557786896041133 with runtime 0.00141143798828125
# the best-case revenue for assortment [0, 4] is 0.48735294117647054 with runtime 0.001161336898803711
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.33825687259828546 with runtime 0.0009877681732177734
# the best-case revenue for assortment [0, 1, 5] is 0.36081724411531346 with runtime 0.0010194778442382812
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.1712077191882077 with runtime 0.0011916160583496094
# the best-case revenue for assortment [0, 1, 6] is 0.1852110971385593 with runtime 0.0010547637939453125
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.22453497571340267 with runtime 0.0014154911041259766
# the best-case revenue for assortment [0, 4, 8] is 0.48735294117647054 with runtime 0.0013246536254882812
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.07895710675299134 with runtime 0.0011088848114013672
# the best-case revenue for assortment [0, 8] is 0.4460726846424385 with runtime 0.0010654926300048828
#
# testing for offertimes 20, 15th instance
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.13438211382113824 with runtime 0.0016255378723144531
# the best-case revenue for assortment [0, 2, 3, 6] is 0.18315301568517328 with runtime 0.0014657974243164062
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.19235884681215204 with runtime 0.001203775405883789
# the best-case revenue for assortment [0, 3, 5] is 0.26090161429859926 with runtime 0.0011463165283203125
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.23805860805860812 with runtime 0.0011417865753173828
# the best-case revenue for assortment [0, 4, 7] is 0.25651470561958367 with runtime 0.001161336898803711
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.45174417521304044 with runtime 0.001199960708618164
# the best-case revenue for assortment [0, 4, 8] is 0.5189890497262433 with runtime 0.0011556148529052734
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.228497632448852 with runtime 0.0011415481567382812
# the best-case revenue for assortment [0, 6, 7] is 0.2284976324488519 with runtime 0.0009634494781494141
#
# testing for offertimes 20, 16th instance
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.13552542675778462 with runtime 0.0016295909881591797
# the best-case revenue for assortment [0, 7] is 0.19119512195121954 with runtime 0.0012979507446289062
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.37664097374114736 with runtime 0.0014982223510742188
# the best-case revenue for assortment [0, 1, 5] is 0.4001730143568112 with runtime 0.0013723373413085938
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.1423701219512195 with runtime 0.0011997222900390625
# the best-case revenue for assortment [0, 3, 7] is 0.15987640850092713 with runtime 0.0010807514190673828
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.26282789075318125 with runtime 0.0011315345764160156
# the best-case revenue for assortment [0, 4, 6] is 0.26282789075318125 with runtime 0.0010373592376708984
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.2663500000000001 with runtime 0.0011386871337890625
# the best-case revenue for assortment [0, 8] is 0.43432682926829275 with runtime 0.001119375228881836
#
# testing for offertimes 20, 17th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.37690678357018303 with runtime 0.0010685920715332031
# the best-case revenue for assortment [0, 1, 8] is 0.37690678357018303 with runtime 0.0010743141174316406
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.12160430101437267 with runtime 0.0010552406311035156
# the best-case revenue for assortment [0, 3, 4] is 0.1769258429573226 with runtime 0.0010747909545898438
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.20568979041549218 with runtime 0.001115560531616211
# the best-case revenue for assortment [0, 3, 5] is 0.2401994181433484 with runtime 0.0011708736419677734
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.22004280505952378 with runtime 0.0010378360748291016
# the best-case revenue for assortment [0, 3, 7] is 0.22578754578754573 with runtime 0.0009629726409912109
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.24303059198431182 with runtime 0.0010607242584228516
# the best-case revenue for assortment [0, 6, 8] is 0.3606055749128919 with runtime 0.0009245872497558594
#
# testing for offertimes 20, 18th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.044738733983692505 with runtime 0.0015082359313964844
# the best-case revenue for assortment [0, 2] is 0.1569574839836925 with runtime 0.0013363361358642578
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.1893771929824561 with runtime 0.00115203857421875
# the best-case revenue for assortment [0, 1, 3] is 0.25213125802310665 with runtime 0.0012428760528564453
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.17937411210954224 with runtime 0.001190185546875
# the best-case revenue for assortment [0, 3, 4] is 0.24050126035823405 with runtime 0.0011267662048339844
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.43301623257782984 with runtime 0.0012776851654052734
# the best-case revenue for assortment [0, 4, 8] is 0.4687315035884826 with runtime 0.0010983943939208984
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.2340848814580167 with runtime 0.0013010501861572266
# the best-case revenue for assortment [0, 6, 8] is 0.2547367190636814 with runtime 0.0011637210845947266
#
# testing for offertimes 20, 19th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.09072656249999998 with runtime 0.0012600421905517578
# the best-case revenue for assortment [0, 6] is 0.11294531249999999 with runtime 0.001026153564453125
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.31697886677013937 with runtime 0.0011630058288574219
# the best-case revenue for assortment [0, 1, 8] is 0.31697886677013937 with runtime 0.0010170936584472656
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.1338434199946395 with runtime 0.0012891292572021484
# the best-case revenue for assortment [0, 2, 3, 6] is 0.14084429302912535 with runtime 0.0012955665588378906
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.1553899771341462 with runtime 0.0012226104736328125
# the best-case revenue for assortment [0, 4, 6] is 0.17567543321365772 with runtime 0.00109100341796875
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3314593637413148 with runtime 0.001104593276977539
# the best-case revenue for assortment [0, 5, 8] is 0.3314593637413148 with runtime 0.001016855239868164
#
# testing for offertimes 20, 20th instance
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.3638693548387097 with runtime 0.001314401626586914
# the best-case revenue for assortment [0, 1, 7] is 0.3844016129032258 with runtime 0.0011343955993652344
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.12910090193089432 with runtime 0.0011088848114013672
# the best-case revenue for assortment [0, 3, 6] is 0.13009141260162602 with runtime 0.0010526180267333984
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.2720550788553635 with runtime 0.0010802745819091797
# the best-case revenue for assortment [0, 4, 7] is 0.2825591081593928 with runtime 0.0010762214660644531
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.33831786128768104 with runtime 0.0011475086212158203
# the best-case revenue for assortment [0, 5, 6] is 0.3538052645076202 with runtime 0.0009970664978027344
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.06340060207249612 with runtime 0.001047372817993164
# the best-case revenue for assortment [0, 8] is 0.45660000000000006 with runtime 0.0009140968322753906
#
# testing for offertimes 20, 21th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.12707499999999994 with runtime 0.0012874603271484375
# the best-case revenue for assortment [0, 3] is 0.127075 with runtime 0.0010595321655273438
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.2798945770121956 with runtime 0.0011982917785644531
# the best-case revenue for assortment [0, 1, 7] is 0.30504411764705874 with runtime 0.0011203289031982422
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.17621988742964353 with runtime 0.0011165142059326172
# the best-case revenue for assortment [0, 2, 6] is 0.17870769230769232 with runtime 0.001146078109741211
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.22363828843337508 with runtime 0.001125335693359375
# the best-case revenue for assortment [0, 4, 6] is 0.22363823529411755 with runtime 0.0011751651763916016
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4723207234146699 with runtime 0.0011262893676757812
# the best-case revenue for assortment [0, 4, 8] is 0.4723207234146699 with runtime 0.0010001659393310547
#
# testing for offertimes 20, 22th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.3235491744436467 with runtime 0.001394033432006836
# the best-case revenue for assortment [0, 4] is 0.4734285714285714 with runtime 0.001140594482421875
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.14901848937844214 with runtime 0.0010056495666503906
# the best-case revenue for assortment [0, 6] is 0.1567258064516129 with runtime 0.0011432170867919922
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.22866920731707321 with runtime 0.0014467239379882812
# the best-case revenue for assortment [0, 3, 5] is 0.33596875000000004 with runtime 0.0012745857238769531
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.31271093750000034 with runtime 0.0013279914855957031
# the best-case revenue for assortment [0, 4, 6] is 0.31271093749999984 with runtime 0.0013480186462402344
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.26365625 with runtime 0.0013213157653808594
# the best-case revenue for assortment [0, 5, 6] is 0.3839832317073171 with runtime 0.0014719963073730469
#
# testing for offertimes 20, 23th instance
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.2521083244712277 with runtime 0.0018100738525390625
# the best-case revenue for assortment [0, 1, 7] is 0.3211702534672406 with runtime 0.0016782283782958984
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.31196467806345235 with runtime 0.0012733936309814453
# the best-case revenue for assortment [0, 1, 8] is 0.31535354090354095 with runtime 0.0011134147644042969
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.1322406504065041 with runtime 0.0013823509216308594
# the best-case revenue for assortment [0, 3, 4] is 0.1327322054443609 with runtime 0.0011668205261230469
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.234998697143295 with runtime 0.0013649463653564453
# the best-case revenue for assortment [0, 3, 5] is 0.3996041742506977 with runtime 0.0012743473052978516
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.1607734728279141 with runtime 0.0013363361358642578
# the best-case revenue for assortment [0, 6, 7] is 0.1855048518227118 with runtime 0.0013360977172851562
#
# testing for offertimes 20, 24th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.3652631578947367 with runtime 0.0015072822570800781
# the best-case revenue for assortment [0, 1] is 0.3652631578947368 with runtime 0.0011529922485351562
#
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.02204206100757136 with runtime 0.0018649101257324219
# the best-case revenue for assortment [0, 2] is 0.17634375 with runtime 0.001689910888671875
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.381143754909662 with runtime 0.0011341571807861328
# the best-case revenue for assortment [0, 1, 5] is 0.3902006578947367 with runtime 0.0010883808135986328
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.24477593786635404 with runtime 0.0012683868408203125
# the best-case revenue for assortment [0, 3, 4] is 0.36218252322121025 with runtime 0.0012576580047607422
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.36742923244757053 with runtime 0.0014872550964355469
# the best-case revenue for assortment [0, 4, 8] is 0.4933313012895664 with runtime 0.001325368881225586
#
# testing for offertimes 20, 25th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.35678732664995827 with runtime 0.0016710758209228516
# the best-case revenue for assortment [0, 1, 8] is 0.4331294660113755 with runtime 0.0013484954833984375
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.21004201465201464 with runtime 0.0012176036834716797
# the best-case revenue for assortment [0, 3, 7] is 0.21004201465201464 with runtime 0.0011913776397705078
#
# revenue prediction for unseen assortment [0, 3, 8]
# the robust revenue for assortment [0, 3, 8] is 0.2074719548872181 with runtime 0.0011878013610839844
# the best-case revenue for assortment [0, 3, 8] is 0.33601370889535387 with runtime 0.0010800361633300781
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.531105347985348 with runtime 0.0011067390441894531
# the best-case revenue for assortment [0, 4, 7] is 0.6542001595712861 with runtime 0.0010859966278076172
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.23422697321833028 with runtime 0.0011105537414550781
# the best-case revenue for assortment [0, 6, 8] is 0.35333551274134206 with runtime 0.0010373592376708984
#
# testing for offertimes 20, 26th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.310806456241033 with runtime 0.0017626285552978516
# the best-case revenue for assortment [0, 1] is 0.3878235294117647 with runtime 0.0013818740844726562
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.0848955223880597 with runtime 0.0012156963348388672
# the best-case revenue for assortment [0, 6] is 0.148125 with runtime 0.0011093616485595703
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.312347980937687 with runtime 0.0011146068572998047
# the best-case revenue for assortment [0, 1, 3] is 0.32395750474721086 with runtime 0.0011208057403564453
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.23741201944682766 with runtime 0.001130819320678711
# the best-case revenue for assortment [0, 3, 5] is 0.2446544919720553 with runtime 0.0010366439819335938
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.48790329601990057 with runtime 0.0011010169982910156
# the best-case revenue for assortment [0, 4, 5] is 0.5093105107418626 with runtime 0.001125335693359375
#
# testing for offertimes 20, 27th instance
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.17144589728444515 with runtime 0.001501321792602539
# the best-case revenue for assortment [0, 7] is 0.19705882352941181 with runtime 0.0010449886322021484
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.1677984910267059 with runtime 0.0012359619140625
# the best-case revenue for assortment [0, 1, 3] is 0.1784481073949925 with runtime 0.001070261001586914
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.15785075030940593 with runtime 0.0011069774627685547
# the best-case revenue for assortment [0, 3, 6] is 0.15785075030940596 with runtime 0.0011484622955322266
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.15873616773442048 with runtime 0.0013413429260253906
# the best-case revenue for assortment [0, 5, 6] is 0.26105211531803274 with runtime 0.0012590885162353516
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.15873616773442048 with runtime 0.00124359130859375
# the best-case revenue for assortment [0, 6, 8] is 0.19224367979441476 with runtime 0.0012578964233398438
#
# testing for offertimes 20, 28th instance
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.22300235908721155 with runtime 0.0013763904571533203
# the best-case revenue for assortment [0, 1, 7] is 0.2796996931687429 with runtime 0.0011506080627441406
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.5038862090668269 with runtime 0.001161813735961914
# the best-case revenue for assortment [0, 1, 8] is 0.5169601518026564 with runtime 0.0011014938354492188
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.13663968427472362 with runtime 0.0010349750518798828
# the best-case revenue for assortment [0, 3, 5] is 0.16642652183215195 with runtime 0.0010175704956054688
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.1456335465458823 with runtime 0.0016603469848632812
# the best-case revenue for assortment [0, 3, 7] is 0.1840043467761411 with runtime 0.0013949871063232422
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.30395202172135516 with runtime 0.001131296157836914
# the best-case revenue for assortment [0, 6, 8] is 0.42713693963925875 with runtime 0.0011212825775146484
#
# testing for offertimes 20, 29th instance
# revenue prediction for unseen assortment [0, 1, 4]
# the robust revenue for assortment [0, 1, 4] is 0.35749510242487814 with runtime 0.0014066696166992188
# the best-case revenue for assortment [0, 1, 4] is 0.46835935912465804 with runtime 0.0011572837829589844
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.23824319799413274 with runtime 0.0011646747589111328
# the best-case revenue for assortment [0, 1, 7] is 0.23824319799413274 with runtime 0.0009582042694091797
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.16757018054746647 with runtime 0.0011746883392333984
# the best-case revenue for assortment [0, 2, 6] is 0.1833186484583489 with runtime 0.0011456012725830078
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.1716513432835821 with runtime 0.001068115234375
# the best-case revenue for assortment [0, 3, 6] is 0.1716513432835821 with runtime 0.0009913444519042969
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.16757018054746647 with runtime 0.0016274452209472656
# the best-case revenue for assortment [0, 4, 6] is 0.2572819651741294 with runtime 0.0013439655303955078
#
# testing for offertimes 20, 30th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.08975673940949937 with runtime 0.001245260238647461
# the best-case revenue for assortment [0, 1] is 0.30891463414634146 with runtime 0.001085042953491211
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.47996623007975814 with runtime 0.0010335445404052734
# the best-case revenue for assortment [0, 1, 8] is 0.4867293379717479 with runtime 0.0010676383972167969
#
# revenue prediction for unseen assortment [0, 3, 8]
# the robust revenue for assortment [0, 3, 8] is 0.3955974915536633 with runtime 0.0012950897216796875
# the best-case revenue for assortment [0, 3, 8] is 0.4313578955170778 with runtime 0.0011105537414550781
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.49753532331046574 with runtime 0.0010972023010253906
# the best-case revenue for assortment [0, 4, 8] is 0.5117438330170778 with runtime 0.0010614395141601562
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.385369284876905 with runtime 0.001344919204711914
# the best-case revenue for assortment [0, 5, 8] is 0.6620965576041777 with runtime 0.0011730194091796875
#
# testing for offertimes 20, 31th instance
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.15783381541855626 with runtime 0.0013041496276855469
# the best-case revenue for assortment [0, 3, 5] is 0.1596389120667523 with runtime 0.0012302398681640625
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.5531170731707317 with runtime 0.0013210773468017578
# the best-case revenue for assortment [0, 4, 8] is 0.5635075836499572 with runtime 0.001428842544555664
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.20703273013375292 with runtime 0.0010478496551513672
# the best-case revenue for assortment [0, 6, 7] is 0.20703273013375292 with runtime 0.001064300537109375
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.36339855532580306 with runtime 0.0011601448059082031
# the best-case revenue for assortment [0, 6, 8] is 0.38791510397516044 with runtime 0.0011014938354492188
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.5277286432160804 with runtime 0.0013260841369628906
# the best-case revenue for assortment [0, 8] is 0.558321608040201 with runtime 0.0012927055358886719
#
# testing for offertimes 20, 32th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.12995527777777788 with runtime 0.0011191368103027344
# the best-case revenue for assortment [0, 5] is 0.24001777777777789 with runtime 0.0009396076202392578
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.10013414634146342 with runtime 0.0011699199676513672
# the best-case revenue for assortment [0, 3, 5] is 0.13164390255530134 with runtime 0.0010502338409423828
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.17191390051688993 with runtime 0.0010297298431396484
# the best-case revenue for assortment [0, 3, 6] is 0.1821169481654048 with runtime 0.0011591911315917969
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.14686546301688994 with runtime 0.0014629364013671875
# the best-case revenue for assortment [0, 5, 6] is 0.18643535241429657 with runtime 0.0012786388397216797
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.420693919379166 with runtime 0.0011906623840332031
# the best-case revenue for assortment [0, 5, 8] is 0.4652658918406072 with runtime 0.001155853271484375
#
# testing for offertimes 20, 33th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.07619226849155504 with runtime 0.001836538314819336
# the best-case revenue for assortment [0, 2] is 0.15456726849155505 with runtime 0.0015881061553955078
#
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.08739130434782609 with runtime 0.00095367431640625
# the best-case revenue for assortment [0, 7] is 0.18462222222222224 with runtime 0.0009393692016601562
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.15584413709035908 with runtime 0.0011658668518066406
# the best-case revenue for assortment [0, 2, 3, 6] is 0.16622006220080357 with runtime 0.0011687278747558594
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.1287393515462417 with runtime 0.001077890396118164
# the best-case revenue for assortment [0, 3, 4] is 0.15736007777428307 with runtime 0.0010142326354980469
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.1606686080372743 with runtime 0.0013039112091064453
# the best-case revenue for assortment [0, 6, 8] is 0.326142292247801 with runtime 0.001359701156616211
#
# testing for offertimes 20, 34th instance
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.19000000000000003 with runtime 0.0012874603271484375
# the best-case revenue for assortment [0, 7] is 0.19000000000000042 with runtime 0.001047372817993164
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.19000000000000042 with runtime 0.0012307167053222656
# the best-case revenue for assortment [0, 1, 7] is 0.20019676010192988 with runtime 0.001302957534790039
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.10075666566099864 with runtime 0.001112222671508789
# the best-case revenue for assortment [0, 3, 5] is 0.13240098289042665 with runtime 0.0010771751403808594
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.11316181288678587 with runtime 0.0010528564453125
# the best-case revenue for assortment [0, 3, 6] is 0.1131618128867856 with runtime 0.0009653568267822266
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.11854878048780529 with runtime 0.001224517822265625
# the best-case revenue for assortment [0, 3, 7] is 0.15756271777003486 with runtime 0.0011043548583984375
#
# testing for offertimes 20, 35th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.2715652173913044 with runtime 0.0012650489807128906
# the best-case revenue for assortment [0, 1] is 0.2715652173913044 with runtime 0.0010526180267333984
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.27512223035072514 with runtime 0.0013375282287597656
# the best-case revenue for assortment [0, 1, 7] is 0.3149130688004862 with runtime 0.0013153553009033203
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.158370144797837 with runtime 0.0012958049774169922
# the best-case revenue for assortment [0, 2, 3, 6] is 0.16625028173549072 with runtime 0.00107574462890625
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.20779095650691617 with runtime 0.001178741455078125
# the best-case revenue for assortment [0, 3, 4] is 0.3104993495934961 with runtime 0.0011916160583496094
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.15431916132789747 with runtime 0.0015003681182861328
# the best-case revenue for assortment [0, 6, 7] is 0.24111356707317083 with runtime 0.0014388561248779297
#
# testing for offertimes 20, 36th instance
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.31386315789473684 with runtime 0.0012693405151367188
# the best-case revenue for assortment [0, 1, 6] is 0.3198060714506078 with runtime 0.0011036396026611328
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.18725383422862243 with runtime 0.0011343955993652344
# ...
# the robust revenue for assortment [0, 3] is 0.09536585365853659 with runtime 0.0005934238433837891
# the best-case revenue for assortment [0, 3] is 0.12715447154471546 with runtime 0.0005652904510498047
#
# testing for offertimes 60, 21th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.1946834170854271 with runtime 0.0004968643188476562
# the best-case revenue for assortment [0, 5] is 0.31410626185958257 with runtime 0.0004107952117919922
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.15238672102504364 with runtime 0.0005998611450195312
# the best-case revenue for assortment [0, 1, 6] is 0.3410622966829383 with runtime 0.00058746337890625
#
# testing for offertimes 60, 22th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.1560532234218897 with runtime 0.0005509853363037109
# the best-case revenue for assortment [0, 2, 6] is 0.2301171067738232 with runtime 0.0005278587341308594
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.1343515348665426 with runtime 0.0005400180816650391
# the best-case revenue for assortment [0, 3, 6] is 0.2371696396068438 with runtime 0.0005304813385009766
#
# testing for offertimes 60, 23th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.14271774193548384 with runtime 0.0009088516235351562
# the best-case revenue for assortment [0, 1] is 0.360991935483871 with runtime 0.0006124973297119141
#
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.009677052999417584 with runtime 0.0005841255187988281
# the best-case revenue for assortment [0, 2] is 0.15217705299941758 with runtime 0.0006258487701416016
#
# testing for offertimes 60, 24th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.0 with runtime 0.0006155967712402344
# the best-case revenue for assortment [0, 1] is 0.3522545136866627 with runtime 0.0005629062652587891
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.02618155254584764 with runtime 0.0006949901580810547
# the best-case revenue for assortment [0, 8] is 0.46213130128956625 with runtime 0.00057220458984375
#
# testing for offertimes 60, 25th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.1556417910447761 with runtime 0.00047969818115234375
# the best-case revenue for assortment [0, 6] is 0.1556417910447761 with runtime 0.0004088878631591797
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.1556417910447761 with runtime 0.0006096363067626953
# the best-case revenue for assortment [0, 1, 6] is 0.3845204917026709 with runtime 0.0005543231964111328
#
# testing for offertimes 60, 26th instance
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.21921203571731687 with runtime 0.0006697177886962891
# the best-case revenue for assortment [0, 5, 6] is 0.3692487543962489 with runtime 0.0005669593811035156
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.40535678391959806 with runtime 0.0006520748138427734
# the best-case revenue for assortment [0, 8] is 0.5812663316582914 with runtime 0.0007064342498779297
#
# testing for offertimes 60, 27th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.012715447154471527 with runtime 0.0008146762847900391
# the best-case revenue for assortment [0, 3] is 0.13669105691056913 with runtime 0.0007486343383789062
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.15873616773442048 with runtime 0.0006234645843505859
# the best-case revenue for assortment [0, 5, 6] is 0.46271706745203434 with runtime 0.0005893707275390625
#
# testing for offertimes 60, 28th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.028295165047814052 with runtime 0.0006330013275146484
# the best-case revenue for assortment [0, 1] is 0.3389161327897495 with runtime 0.0005376338958740234
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.14947300748174364 with runtime 0.0008611679077148438
# the best-case revenue for assortment [0, 2, 6] is 0.21911069418386486 with runtime 0.0006871223449707031
#
# testing for offertimes 60, 29th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.20358303853232002 with runtime 0.0005190372467041016
# the best-case revenue for assortment [0, 5] is 0.3274724857685009 with runtime 0.0004706382751464844
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.1675701805474665 with runtime 0.0005350112915039062
# the best-case revenue for assortment [0, 5, 6] is 0.3711532190797865 with runtime 0.0005161762237548828
#
# testing for offertimes 60, 30th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.03496747967479675 with runtime 0.0005586147308349609
# the best-case revenue for assortment [0, 3] is 0.12715447154471546 with runtime 0.0005178451538085938
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.14093693050519474 with runtime 0.0007913112640380859
# the best-case revenue for assortment [0, 2, 6] is 0.2293650073283575 with runtime 0.0008637905120849609
#
# testing for offertimes 60, 31th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.17025413014759153 with runtime 0.0005865097045898438
# the best-case revenue for assortment [0, 1] is 0.3395224228305185 with runtime 0.0005574226379394531
#
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.029564654391502132 with runtime 0.0005471706390380859
# the best-case revenue for assortment [0, 5] is 0.38290040768782774 with runtime 0.0005130767822265625
#
# testing for offertimes 60, 32th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.011899206464764112 with runtime 0.0006654262542724609
# the best-case revenue for assortment [0, 2] is 0.1531875 with runtime 0.0006101131439208984
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.35181909547738693 with runtime 0.0004444122314453125
# the best-case revenue for assortment [0, 8] is 0.3824120603015075 with runtime 0.00044727325439453125
#
# testing for offertimes 60, 33th instance
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.1606686080372743 with runtime 0.0005435943603515625
# the best-case revenue for assortment [0, 1, 6] is 0.3987911184210526 with runtime 0.0004951953887939453
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.1606686080372743 with runtime 0.0005664825439453125
# the best-case revenue for assortment [0, 5, 6] is 0.2697138341679276 with runtime 0.0004966259002685547
#
# testing for offertimes 60, 34th instance
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.1131618128867856 with runtime 0.000759124755859375
# the best-case revenue for assortment [0, 3, 6] is 0.134373899286329 with runtime 0.0005519390106201172
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.3135778894472362 with runtime 0.0004799365997314453
# the best-case revenue for assortment [0, 8] is 0.3594673366834171 with runtime 0.00047206878662109375
#
# testing for offertimes 60, 35th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.0 with runtime 0.0005338191986083984
# the best-case revenue for assortment [0, 3] is 0.12079674796747969 with runtime 0.0004892349243164062
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.1464390243902439 with runtime 0.0005331039428710938
# the best-case revenue for assortment [0, 6] is 0.1464390243902439 with runtime 0.0004918575286865234
#
# testing for offertimes 60, 36th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15303947368421053 with runtime 0.0006349086761474609
# the best-case revenue for assortment [0, 2, 6] is 0.22312011884550084 with runtime 0.0005702972412109375
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.3175001831148231 with runtime 0.0005064010620117188
# the best-case revenue for assortment [0, 5, 6] is 0.4225298944900352 with runtime 0.0005030632019042969
#
# testing for offertimes 60, 37th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.0 with runtime 0.0005500316619873047
# the best-case revenue for assortment [0, 1] is 0.31311328125 with runtime 0.0005064010620117188
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.1425703125 with runtime 0.0007612705230712891
# the best-case revenue for assortment [0, 6] is 0.1425703125 with runtime 0.0007681846618652344
#
# testing for offertimes 60, 38th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.14250000000000002 with runtime 0.0005340576171875
# the best-case revenue for assortment [0, 2] is 0.149625 with runtime 0.000499725341796875
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.32343493552168817 with runtime 0.0007765293121337891
# the best-case revenue for assortment [0, 5, 8] is 0.5005227801339602 with runtime 0.0007071495056152344
#
# testing for offertimes 60, 39th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.02566616538739035 with runtime 0.0007987022399902344
# the best-case revenue for assortment [0, 5] is 0.3504477611940298 with runtime 0.0005543231964111328
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.30965085388994296 with runtime 0.0005178451538085938
# the best-case revenue for assortment [0, 5, 8] is 0.4422352374748647 with runtime 0.0004825592041015625
#
# testing for offertimes 60, 40th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.060562500000000005 with runtime 0.0006039142608642578
# the best-case revenue for assortment [0, 2] is 0.16209375 with runtime 0.0005660057067871094
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.14143548387096772 with runtime 0.00044918060302734375
# the best-case revenue for assortment [0, 6] is 0.14143548387096774 with runtime 0.00044608116149902344
#
# testing for offertimes 60, 41th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.26864516129032256 with runtime 0.000659942626953125
# the best-case revenue for assortment [0, 1] is 0.38630859375 with runtime 0.0006186962127685547
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3534700432228255 with runtime 0.0007383823394775391
# the best-case revenue for assortment [0, 5, 8] is 0.6886969785943384 with runtime 0.0006742477416992188
#
# testing for offertimes 60, 42th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.06498387096774193 with runtime 0.000553131103515625
# the best-case revenue for assortment [0, 6] is 0.14143548387096772 with runtime 0.00046753883361816406
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.1070753768844221 with runtime 0.0005254745483398438
# the best-case revenue for assortment [0, 8] is 0.4435979899497488 with runtime 0.0005218982696533203
#
# testing for offertimes 60, 43th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15728768504594096 with runtime 0.0008330345153808594
# the best-case revenue for assortment [0, 2, 6] is 0.2634934333958724 with runtime 0.0005831718444824219
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.06213635587079597 with runtime 0.0004734992980957031
# the best-case revenue for assortment [0, 8] is 0.4139554513481829 with runtime 0.00046944618225097656
#
# testing for offertimes 60, 44th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.15332236842105262 with runtime 0.0005283355712890625
# the best-case revenue for assortment [0, 6] is 0.15332236842105262 with runtime 0.00047206878662109375
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15071951219512195 with runtime 0.0007495880126953125
# the best-case revenue for assortment [0, 2, 6] is 0.21339587242026267 with runtime 0.0008213520050048828
#
# testing for offertimes 60, 45th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.007941449475829965 with runtime 0.0008225440979003906
# the best-case revenue for assortment [0, 2] is 0.15934769947582997 with runtime 0.0006020069122314453
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.15893217082902322 with runtime 0.0005948543548583984
# the best-case revenue for assortment [0, 3, 6] is 0.2599018201674554 with runtime 0.0005824565887451172
#
# testing for offertimes 60, 46th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.059526352611940316 with runtime 0.0005629062652587891
# the best-case revenue for assortment [0, 6] is 0.144421875 with runtime 0.00047659873962402344
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3165533411488862 with runtime 0.0008106231689453125
# the best-case revenue for assortment [0, 5, 8] is 0.605930895805602 with runtime 0.0008401870727539062
#
# testing for offertimes 60, 47th instance
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.13941176470588232 with runtime 0.0007724761962890625
# the best-case revenue for assortment [0, 1, 6] is 0.333742137355584 with runtime 0.0006122589111328125
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.27533668341708545 with runtime 0.0007562637329101562
# the best-case revenue for assortment [0, 8] is 0.45124623115577883 with runtime 0.0007004737854003906
#
# testing for offertimes 60, 48th instance
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.12590825711382114 with runtime 0.0006082057952880859
# the best-case revenue for assortment [0, 3, 6] is 0.15515625000000002 with runtime 0.00047087669372558594
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.19798241500586175 with runtime 0.0006096363067626953
# the best-case revenue for assortment [0, 5, 6] is 0.36204491500586156 with runtime 0.0005741119384765625
#
# testing for offertimes 60, 49th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.2418793969849246 with runtime 0.0006337165832519531
# the best-case revenue for assortment [0, 5] is 0.3126733668341709 with runtime 0.00041604042053222656
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.14327656894896318 with runtime 0.0007908344268798828
# the best-case revenue for assortment [0, 2, 6] is 0.17465459259398425 with runtime 0.0008080005645751953

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mdm_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_lb_dist':all_mdm_lb_distance_list[i],'mdm_ub_dist':all_mdm_ub_distance_list[i],
                                    'true_best_rev':all_best_true_revenue_list[i],'mdm_lb_best_rev':all_best_revenue_mdm_lb[i],'mdm_ub_best_rev':all_best_revenue_mdm_ub[i],
                                    'mdm_lb_best_rev_diff':all_mdm_lb_best_rev_diff[i],'mdm_ub_best_rev_diff':all_mdm_ub_best_rev_diff[i]})
    df_mdm_details1.to_csv('prediction/etp_mdm/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        lb_rank = all_mdm_lb_ranking[i][j]
        ub_rank = all_mdm_ub_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'lb_rank':lb_rank,'ub_rank':ub_rank})
        df_rank.to_csv('prediction/etp_mdm/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        lb_rev = all_mdm_lb_revenue_list[i][j]
        ub_rev = all_mdm_ub_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'lb_rev':lb_rev,'ub_rev':ub_rev})
        df_rev.to_csv('prediction/etp_mdm/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ''' true_prob = all_true_choice_prob_list[i][j]
        lb_prob = all_mdm_lb_rev_prob_list[i][j]
        ub_prob = all_mdm_ub_rev_prob_list[i][j]
        
        df_true_prob = pd.DataFrame(true_prob).T
        df_lb_prob = pd.DataFrame(lb_prob).T
        df_ub_prob = pd.DataFrame(ub_prob).T
        
        df_true_prob.to_csv('prediction/etp_mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_prob.to_csv('prediction/etp_mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/mdm_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_ub_prob.to_csv('prediction/etp_mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/mdm_ub/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''
        lb_runtime = all_mdm_rev_lb_runtime[i][j]
        ub_runtime = all_mdm_rev_ub_runtime[i][j]
        df_runtime = pd.DataFrame({'lb_runtime':lb_runtime,'ub_runtime':ub_runtime})
        df_runtime.to_csv('prediction/etp_mdm/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        
        ## using sales fraction prediction
        ## record the choice probability prediction interval
        ''' lb_sales = all_mdm_lb_sales_list[i][j]
        ub_sales = all_mdm_ub_sales_list[i][j]
        df_lb_sales = pd.DataFrame(lb_sales).T
        df_ub_sales = pd.DataFrame(ub_sales).T
        
        df_true_prob.to_csv('prediction/etp_mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_sales.to_csv('prediction/etp_mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mdm_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_ub_sales.to_csv('prediction/etp_mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mdm_ub/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## adding details 2 about runtime 
all_lb_avg_runtime = []
all_ub_avg_runtime =[]

for i in range(len(pred_offer_times_list)):
    
    avg_lb_runtime_collection = []
    avg_ub_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        avg_lb_runtime_collection.append(np.mean(np.array(all_mdm_rev_lb_runtime[i][j])))
        avg_ub_runtime_collection.append(np.mean(np.array(all_mdm_rev_ub_runtime[i][j])))
    
    all_lb_avg_runtime.append(np.mean(np.array(avg_lb_runtime_collection)))
    all_ub_avg_runtime.append(np.mean(np.array(avg_ub_runtime_collection)))

# %%
avg_mdm_lb_dist = []
avg_mdm_ub_dist = []

avg_mdm_lb_best_rev_diff = []
avg_mdm_ub_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_lb_dist.append(np.mean(all_mdm_lb_distance_list[i]))
    avg_mdm_ub_dist.append(np.mean(all_mdm_ub_distance_list[i]))
    
    avg_mdm_lb_best_rev_diff.append(np.mean(all_mdm_lb_best_rev_diff[i]))
    avg_mdm_ub_best_rev_diff.append(np.mean(all_mdm_ub_best_rev_diff[i]))

df_mdm_etp_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'train_size':pred_train_collection_size,'test_size':pred_test_collection_size,
                                   'avg_lb_dist':avg_mdm_lb_dist,'avg_ub_dist':avg_mdm_ub_dist,
                                   'avg_lb_best_rev_diff':avg_mdm_lb_best_rev_diff,'avg_ub_best_rev_diff':avg_mdm_ub_best_rev_diff,
                                   'avg_lb_runtime':all_lb_avg_runtime,'avg_ub_runtime':all_ub_avg_runtime})
df_mdm_etp_summary.to_csv('prediction/etp_mdm/jd_etp_mdm_summary.csv')

# %%
df_mdm_etp_summary
# Out:
#    offertimes  train_size  test_size  avg_lb_dist  avg_ub_dist  \
# 0          20          24          5         2.54         2.24
# 1          30          20          4         1.40         1.06
# 2          40          16          3         0.78         0.48
# 3          50          12          3         0.78         0.44
# 4          60          11          2         0.20         0.14
#
#    avg_lb_best_rev_diff  avg_ub_best_rev_diff  avg_lb_runtime  avg_ub_runtime
# 0              0.111870              0.107233        0.001233        0.001153
# 1              0.118594              0.085966        0.000951        0.000878
# 2              0.080059              0.036935        0.000814        0.000731
# 3              0.103155              0.052747        0.000659        0.000613
# 4              0.077181              0.026959        0.000629        0.000563

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
## record representability of all instances
all_mdm_rep = []
all_mdm_rep_time = []

## record the limit loss of all instances
all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_runtime = []


for i in range(len(pred_offer_times_list)):

    ## define container for mdm representability check
    mdm_rep_collection =[]
    mdm_rep_runtime_collection =[]
    
    ## define container for mdm limit 
    mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[]
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        ####### mdm representability check ##########
        
        row_data = row_assortment_data(all_full_instances[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_full_instances[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_runtime_collection.append(curr_rep_result[1])
        
        # check if representable
        if curr_rep_result[0] > 0:
            
            mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(0)
            mdm_limit_probability_collection.append(all_full_instances[i][j])
        else:
            # not representable # limit and prediction
            #mdm_limit(data,collection,perm_collection,produts_notin_collection)
            curr_limit_result = mdm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            curr_limit_prob = curr_limit_result[-1]
            mdm_limit_probability_collection.append(curr_limit_prob)
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_runtime_collection.append(curr_limit_result[1])
            
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_runtime_collection)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection)
# Out:
# testing instance with offertimes 20 : 0th
# testing instance with offertimes 20 : 1th
# mdm limit computation error
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-f46f5d53ab79> in <module>
#      45             curr_limit_result = mdm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
#      46             # return [model.objVal, model.Runtime,lam_values,x_values]
# ---> 47             curr_limit_prob = curr_limit_result[-1]
#      48             mdm_limit_probability_collection.append(curr_limit_prob)
#      49             mdm_limit_loss_collection.append(curr_limit_result[0])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
## adding rep results
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep[i], 'mdm_rep_time':all_mdm_rep_time[i]})
    df_mdm_rep.to_csv('limit/mdm/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding limit results
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_loss':all_mdm_limit_loss[i], 'mdm_limit_time':all_mdm_limit_runtime[i]})
    df_mdm_loss.to_csv('limit/mdm/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
            df_limit_prob = pd.DataFrame(all_mdm_limit_prob[i][j])
            df_limit_prob.to_csv('limit/mdm/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
for i in range(len(pred_offer_times_list)):
    avg_loss_collection = []
    for j in range(pred_instance_size[i]):
        avg_loss_collection.append(all_mdm_limit_loss[i][j]/sum(all_full_offertimes[i]))
    all_avg_loss.append(avg_loss_collection)

# %%
avg_mdm_rep = []
avg_mdm_rep_runtime = []

avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_mdm_limit_runtime = []

#avg_loss = []
avg_loss_se = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_rep.append(np.mean(all_mdm_rep[i]))
    avg_mdm_rep_runtime.append(np.mean(all_mdm_rep_time[i]))
    
    avg_total_limit_loss.append(np.mean(all_mdm_limit_loss[i]))
    avg_mdm_limit_runtime.append(np.mean(all_mdm_limit_runtime[i]))
    avg_toal_limit_loss_se.append(np.std(all_mdm_limit_loss[i])/np.sqrt(len(all_mdm_limit_loss[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))

avg_loss = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))

df_mdm_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'mdm_rep':avg_mdm_rep,'mdm_rep_runtime':avg_mdm_rep_runtime,
                                   'total_mdm_loss':avg_total_limit_loss,'total_mdm_loss_se':avg_toal_limit_loss_se,
                                   'avg_mdm_loss':avg_loss,'avg_mdm_loss_se':avg_loss_se,
                                   'avg_mdm_limit_runtime':avg_mdm_limit_runtime
                                   })
df_mdm_limit.to_csv('limit/mdm/mdm_limit_summary.csv')
df_mdm_limit
# Out:
#    offertimes  mdm_rep  mdm_rep_runtime  total_mdm_loss  total_mdm_loss_se  \
# 0          20      0.0         0.000351       40.753405           1.257701
# 1          30      0.0         0.000435       32.082157           1.213662
# 2          40      0.0         0.000410       23.462034           1.174360
# 3          50      0.0         0.000282       15.898627           0.982048
# 4          60      0.0         0.000249       12.962716           0.912903
#
#    avg_mdm_loss  avg_mdm_loss_se  avg_mdm_limit_runtime
# 0      0.005324         0.000164              25.662055
# 1      0.004261         0.000161               3.627036
# 2      0.003187         0.000160               0.802010
# 3      0.002211         0.000137               0.189040
# 4      0.001830         0.000129               0.089078

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.005323762866249596
# 0.0042611444884547425
# 0.0031873433507385966
# 0.00221121374521646
# 0.001830375006097433

# %%
all_mdm_kl_loss = []
all_mdm_avg_kl_loss = []
for i in range(len(pred_offer_times_list)):
    mdm_kl_loss_collection = []
    mdm_avg_kl_loss_collection = []
    for j in range(pred_instance_size[i]):
        mdm_prob = pd.read_csv('limit/mdm/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        mdm_prob = mdm_prob.drop(mdm_prob.columns[0],axis=1)
        mdm_prob = np.array(mdm_prob)
        data = all_full_instances[i][j]
        curr_kl_loss = 0
        for x in range(data.shape[0]):
            for y in range(data.shape[1]):
                if data[x][y]>0 and mdm_prob[x][y]>0:
                    curr_kl_loss = curr_kl_loss + all_full_offertimes[i][y]* data[x][y]*np.log(mdm_prob[x][y])
        mdm_kl_loss_collection.append(-curr_kl_loss)
        mdm_avg_kl_loss_collection.append(-curr_kl_loss/sum(all_full_offertimes[i]))
        
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_loss':mdm_kl_loss_collection,'avg_loss':mdm_avg_kl_loss_collection})
    df_mdm_loss.to_csv('limit/mdm/limit_kl/'+str(pred_offer_times_list[i])+'.csv')
    
    all_mdm_kl_loss.append(mdm_kl_loss_collection) 
    all_mdm_avg_kl_loss.append(mdm_avg_kl_loss_collection)

# %%
avg_total_kl_loss = []
avg_total_kl_loss_se = []
avg_avg_kl_loss = []
avg_avg_kl_loss_se = []

for i in range(len(pred_offer_times_list)):
    avg_total_kl_loss.append(np.mean(all_mdm_kl_loss[i]))
    avg_total_kl_loss_se.append(np.std(all_mdm_kl_loss[i])/np.sqrt(len(all_mdm_kl_loss[i])))
    
    avg_avg_kl_loss.append(np.mean(all_mdm_avg_kl_loss[i]))
    avg_avg_kl_loss_se.append(np.std(all_mdm_avg_kl_loss[i])/np.sqrt(len(all_mdm_avg_kl_loss[i])))
    
df_mdm_kl = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'total_mdm_kl_loss':avg_total_kl_loss,'total_mdm_kl_loss_se':avg_total_kl_loss_se,
                                   'avg_mdm_kl_loss':avg_avg_kl_loss,'avg_mdm_kl_loss_se':avg_avg_kl_loss_se
                                   })
df_mdm_kl.to_csv('limit/mdm/mdm_kl_summary.csv')
df_mdm_kl
# Out:
#    offertimes  total_mdm_kl_loss  total_mdm_kl_loss_se  avg_mdm_kl_loss  \
# 0          20        4779.729029             26.278709         0.624393
# 1          30        4685.014592             25.941775         0.622263
# 2          40        4561.990365             24.975902         0.619751
# 3          50        4434.386687             24.380031         0.616744
# 4          60        4356.741439             23.817791         0.615185
#
#    avg_mdm_kl_loss_se
# 0            0.003433
# 1            0.003446
# 2            0.003393
# 3            0.003391
# 4            0.003363
