# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
import sys

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def generate_negatively_correlated_covariance_matrix(n):
    # Generate a random correlation matrix with negative correlations
    correlation_matrix = np.random.uniform(low=-0.9, high=-0.1, size=(n, n))
    np.fill_diagonal(correlation_matrix, 1)  # Set diagonal elements to 1
    correlation_matrix = (correlation_matrix + correlation_matrix.T) / 2  # Ensure symmetry

    # Ensure the correlation matrix is valid for Cholesky decomposition
    cholesky_success = False
    while not cholesky_success:
        try:
            # Perform Cholesky decomposition
            cholesky_matrix = np.linalg.cholesky(correlation_matrix)
            cholesky_success = True
        except np.linalg.LinAlgError:
            # If Cholesky decomposition fails, adjust the correlation matrix slightly
            correlation_matrix += np.eye(n) * 0.01  # Adjust diagonal elements slightly

    # Generate random standard deviations
    #standard_deviations = np.random.uniform(0.5, 2, size=n)
    
    variance_outsideopt = np.random.uniform(30,40)
    variance_products = np.random.uniform(0.5,2,size=n-1)
    
    ''' variance_outsideopt = np.random.uniform(0.5,2)
    variance_products = np.random.uniform(30,40,size=n-1) '''
    
    standard_deviations = np.hstack((variance_outsideopt,variance_products))
    # Construct diagonal matrix from standard deviations
    diagonal_matrix = np.diag(standard_deviations)
    #diagonal_matrix = np.eye(n)

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix

# %%
def is_positive_semidefinite(matrix):
    """
    Check if a matrix is positive semidefinite.
    
    Args:
        matrix (numpy.ndarray): The matrix to check.
        
    Returns:
        bool: True if the matrix is positive semidefinite, False otherwise.
    """
    # Check if the matrix is symmetric
    if not np.allclose(matrix, matrix.T):
        return False
    
    # Check if all eigenvalues are non-negative
    eigvals, _ = np.linalg.eig(matrix)
    return np.all(eigvals >= 0)

# %%
def collection_distribution_prob_neg(n,collection):
    # generate mean 
    mu_0 = np.random.uniform(6,10)
    mu_1n = np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    # generate covariance matrix with positive correlation
    neg_cov = generate_negatively_correlated_covariance_matrix(n)
    if is_positive_semidefinite(neg_cov): 
        sample_size = 10000
        utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    else:
        print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 
        
        
        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_instance = collection_distribution_prob_neg(n,whole_collection)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-11:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(jd_collection,jd_offertimes)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-11:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:

            
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples) '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-3:
                    condition = True
        if condition == True:
            print('instance_generation error')
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 30
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 40
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 50
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 60
# instance_generation error
# instance_generation error

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
## RUM limit formulation
def find_element_permutation_indexes(n, partial_lists):
    perm_collection = []
    
    elements = list(range(n))
    perms = list(permutations(elements))
    #index_permutations = {perm: idx for idx, perm in enumerate(perms)}
    result = {}

    for partial_list in partial_lists:
        partial_result = {}
        perm_element = []
        for element in partial_list:
            element_indexes = [idx for idx, perm in enumerate(perms) if perm.index(element) == min(perm.index(e) for e in partial_list)]
            partial_result[element] = element_indexes
            perm_element.append(element_indexes)
        result[tuple(partial_list)] = partial_result
        perm_collection.append(perm_element)
    return result,perm_collection

def find_product_notin_assortment(collection,n):
    notin_collection = []
    for i in range(len(collection)):
        notin_assortment = []
        for j in range(n):
            if j not in collection[i]:
                notin_assortment.append(j)
        notin_collection.append(notin_assortment)
    return notin_collection

# %%
def rum_feasiblity(data,collection,perm_collection):
    n = data.shape[0]
    
    fact = math.factorial(n)
    
    # the RUM feasibility LP
    model = gp.Model('rum_feasibility')
    model.setParam('OutputFlag', 0)
    lam = model.addVars(fact,lb=0.0, vtype=gp.GRB.CONTINUOUS, name='lam')
    
    #model.addConstrs(lam[i]>=0 for i in range(fact))
    model.addConstr(sum(lam[i] for i in range(fact))==1)
    
    # caculate RUM choice probability for each product in the assortment
    for i in range(len(collection)):
        for j in range(len(collection[i])):
            model.addConstr(sum(lam[k] for k in perm_collection[i][j])- data[collection[i][j]][i]==0)
    
    model.setObjective(0)
    #model.write("model.lp")
    model.optimize()
    # Access the optimal solution

    if model.Status == 2: #optimal
        return [1,model.Runtime]
        #return [1, used_time]
    
    if model.Status == 3: #infeasible
        return [0,model.Runtime]

# %%
def robust_rum_prediction(data,collection,perm_collection,unseen_assortment,unseen_assortment_perm,price):
    start_time = time.time()
    
    n = data.shape[0]
    
    fact = math.factorial(n)
    
    model = gp.Model('rum')
    #model.Params.FeasibilityTol = 1e-5
    model.setParam('OutputFlag', 0)
    lam = model.addVars(fact,lb=0.0, vtype=gp.GRB.CONTINUOUS, name='lam')
    x = model.addVars(len(unseen_assortment),lb=0.0,vtype=gp.GRB.CONTINUOUS,name='x')
    
    #model.addConstrs(lam[i]>=0 for i in range(fact))
    model.addConstr(sum(lam[i] for i in range(fact))==1)
    #model.addConstr(sum(x[i] for i in range(len(unseen_assortment))) == 1)
    
    # caculate RUM choice probability for each product in the assortment
    for i in range(len(collection)):
        for j in range(len(collection[i])):
            model.addConstr(sum(lam[k] for k in perm_collection[i][j])- data[collection[i][j]][i]==0)
    
    # calculate RUM choice probability for the unseen assortment
    for i in range(len(unseen_assortment)):
        model.addConstr(sum(lam[k] for k in unseen_assortment_perm[i]) - x[i] == 0)
    
    # minimize the revenue within all possible rums
    model.setObjective(gp.quicksum(price[unseen_assortment[i]]*x[i] for i in range(len(unseen_assortment))),sense=gp.GRB.MINIMIZE)
   
    model.optimize()
    used_time = time.time() - start_time
    #status = model.status
    #print("Gurobi optimization status:", status)
    
    # Check if the optimization was successful
    if model.status == gp.GRB.OPTIMAL:
        # Access the objective value
        #obj_value = model.objVal
        #print(f"Optimal Objective Value: {obj_value}")  
        #print(f'current testing assortment',unseen_assortment)
        return [model.objVal,[x[i].x for i in range(len(unseen_assortment))], model.Runtime,used_time]
    if model.status == gp.GRB.INFEASIBLE:
        print("Optimization was not successful.")
        #print(f'current testing assortment',unseen_assortment)
        # Compute the Infeasibility Proof (IIS)
        ''' model.computeIIS()
        infeas_constraints = [c.constrName for c in model.getConstrs() if c.IISConstr]
        print("The following constraints contribute to infeasibility:")
        print(infeas_constraints) '''
        model.write("rumPre_infeas_model_1e-6.lp")
        return [-1, [ 0 for _ in range(len(unseen_assortment))],model.Runtime,used_time]

# %%
def robust_rum_prediction_tol(data,collection,perm_collection,unseen_assortment,unseen_assortment_perm,price,tol):
    start_time = time.time()
    n = data.shape[0]
    
    fact = math.factorial(n)
    
    model = gp.Model('rum')
    model.Params.FeasibilityTol = tol
    model.setParam('OutputFlag', 0)
    lam = model.addVars(fact,lb=0.0, vtype=gp.GRB.CONTINUOUS, name='lam')
    x = model.addVars(len(unseen_assortment),lb=0.0,vtype=gp.GRB.CONTINUOUS,name='x')
    
    #model.addConstrs(lam[i]>=0 for i in range(fact))
    model.addConstr(sum(lam[i] for i in range(fact))==1)
    #model.addConstr(sum(x[i] for i in range(len(unseen_assortment))) == 1)
    
    # caculate RUM choice probability for each product in the assortment
    for i in range(len(collection)):
        for j in range(len(collection[i])):
            model.addConstr(sum(lam[k] for k in perm_collection[i][j])- data[collection[i][j]][i]==0)
    
    # calculate RUM choice probability for the unseen assortment
    for i in range(len(unseen_assortment)):
        model.addConstr(sum(lam[k] for k in unseen_assortment_perm[i]) - x[i] == 0)
    
    # minimize the revenue within all possible rums
    model.setObjective(gp.quicksum(price[unseen_assortment[i]]*x[i] for i in range(len(unseen_assortment))),sense=gp.GRB.MINIMIZE)
   
    model.optimize()
    #status = model.status
    #print("Gurobi optimization status:", status)
    used_time= time.time() - start_time
    # Check if the optimization was successful
    if model.status == gp.GRB.OPTIMAL:
        # Access the objective value
        #obj_value = model.objVal
        #print(f"Optimal Objective Value: {obj_value}")  
        #print(f'current testing assortment',unseen_assortment)
        return [model.objVal,[x[i].x for i in range(len(unseen_assortment))], model.Runtime,used_time]
    if model.status == gp.GRB.INFEASIBLE:
        print("Optimization was not successful.")
        #print(f'current testing assortment',unseen_assortment)
        # Compute the Infeasibility Proof (IIS)
        ''' model.computeIIS()
        infeas_constraints = [c.constrName for c in model.getConstrs() if c.IISConstr]
        print("The following constraints contribute to infeasibility:")
        print(infeas_constraints) '''
        #model.write("rumPre_infeas_model_tol.lp")
        return [-1, [ 0 for _ in range(len(unseen_assortment))],model.Runtime,used_time]
    
    #return [-2, [ 0 for _ in range(len(unseen_assortment))],model.Runtime]

# %%
## prediction for the current testing collection of assortments 
def rum_prediction(curr_test_instance,curr_test_collection,price,curr_train_instance,curr_train_collection,curr_train_perm_collection,curr_test_perm_collection):
    ''' true assortment ranking '''

    true_revenue = []

    lb_rum_revenue = [] 

    lb_rum_runtime = []
    actual_run_runtime = []
    
    for k in range(len(curr_test_collection)):
        
        unseen_assortment = curr_test_collection[k]
        unseen_perm_collection = curr_test_perm_collection[k]
        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        #true_choice_prob.append(curr_test_instance[:,k])
        
        # be careful for the output sequence
        
        curr_rum_lb_result = robust_rum_prediction(curr_train_instance,curr_train_collection,curr_train_perm_collection,unseen_assortment,unseen_perm_collection,price)
        if curr_rum_lb_result[0] == -1:
            tol = 1e-5
            curr_rum_lb_result = robust_rum_prediction_tol(curr_train_instance,curr_train_collection,curr_train_perm_collection,unseen_assortment,unseen_perm_collection,price,tol)
            while(curr_rum_lb_result[0] == -1 and tol <1e-2):
                print('current prediction needs a significant tolerence')
                tol = tol*10
                curr_rum_lb_result = robust_rum_prediction_tol(curr_train_instance,curr_train_collection,curr_train_perm_collection,unseen_assortment,unseen_perm_collection,price,tol)
            
        lb_rum_revenue.append(curr_rum_lb_result[0])
        
        ## record the runtime result
        lb_rum_runtime.append(curr_rum_lb_result[2])
        actual_run_runtime.append(curr_rum_lb_result[-1])
        print(f'robust RUM revenue prediction of {unseen_assortment} is {curr_rum_lb_result[0]} with actual runtime {curr_rum_lb_result[3]}')
       
    return true_revenue,lb_rum_revenue,lb_rum_runtime,actual_run_runtime

# %%
def robust_rum_prediction_w_ci(lb,ub,data,collection,perm_collection,produts_notin_collection,unseen_assortment,unseen_assortment_perm,price):
    start_time = time.time()
    n,m = data.shape # number of products
    fact = math.factorial(n) # number of permutations
    
    model = gp.Model('rum_ci') #define a model
    model.setParam('OutputFlag', 0)
    
    # define nonnegative continuous variables for lambda, the probability of each permutation
    lam = model.addVars(fact,lb=0.0, vtype=gp.GRB.CONTINUOUS, name='lam') 
    # define nonnegative continuous variables for choice probability of each product in each train assortment
    x = model.addVars(n, m, vtype=gp.GRB.CONTINUOUS, lb=0.0, name="x") 
    # define nonnegative continuous variables for choice probability of each product in the test assortment 
    y = model.addVars(len(unseen_assortment),lb=0.0,vtype=gp.GRB.CONTINUOUS,name='y')
    
    #normalization constraint of lambda
    model.addConstr(sum(lam[i] for i in range(fact))==1,name="Normalization")
    
    # caculate RUM choice probability for each product in the train assortment
    for i in range(len(collection)):
        # normalization constraint for each assortment. 
        #model.addConstr(gp.quicksum(x[k, i] for k in collection[i]) == 1)
        for j in range(len(collection[i])):
            # constraints for RUM choice probabilities 
            model.addConstr(sum(lam[k] for k in perm_collection[i][j])- x[collection[i][j],i]==0,name=f"prob_product{collection[i][j]}_assortment_{i}")
            
            # constraints for the lower bound and upper bound values
            model.addConstr(x[collection[i][j],i]>= lb[collection[i][j],i],name=f"lb_product{collection[i][j]}_assortment_{i}")
            model.addConstr(x[collection[i][j],i]<= ub[collection[i][j],i],name=f"ub_product{collection[i][j]}_assortment_{i}")
        
        for k in produts_notin_collection[i]:
            # constraints for products that are not in the assortments
            model.addConstr(x[k,i] == 0,name=f"prob_product{k}_assortment_{i}")
    
    # calculate RUM choice probability for the unseen assortment
    for i in range(len(unseen_assortment)):
        model.addConstr(sum(lam[k] for k in unseen_assortment_perm[i]) - y[i] == 0,name=f'unseen_prob_product{unseen_assortment[i]}')
    
    # Objective
    obj = gp.quicksum(price[unseen_assortment[i]] * y[i] for i in range(len(unseen_assortment)))
    model.setObjective(obj, GRB.MINIMIZE)
    #model.setObjective(0)
    model.optimize()
    used_time = time.time() - start_time
    #status = model.status
    #print("Gurobi optimization status:", status)
    # Access the optimal solution
    if model.status == gp.GRB.OPTIMAL:
        print(f"RUM robust prediction revenue of assortment {unseen_assortment} is : {model.objVal} with runtime {used_time}")  
        #model.write("rum_ci.sol")
        #model.write("rum_ci.lp")
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
        #print(f'current testing assortment',unseen_assortment)
        return [model.objVal,[y[i].x for i in range(len(unseen_assortment))], model.Runtime,used_time]
    else:
        print('RUM CI: No solution found or an error occurred.')
        return [-1]

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record the kendall tau distance between the predicted ranking of rum and the truth
all_rum_lb_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_revenue_list = []
all_best_revenue_rum_lb = []  

## record the difference in best assortment
all_rum_lb_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_rum_lb_revenue_list = []

## choice probability under the revenue prediction 
''' all_true_choice_prob_list = [] 
all_rum_lb_rev_prob_list = []

all_rum_lb_sales_list = [] '''

all_true_ranking = []
all_rum_lb_ranking = []

## record the runtime of rum prediction
all_rum_rev_lb_runtime = []
all_rum_actual_runtime = []

all_infeasible_collection = []

for i in range(len(all_full_collections)):
    
    
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    rum_lb_best_rev_collection = [] # a container for the best revenue predicted by robust rum
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    rum_lb_ranking_collection = [] # a container for ranking by robust rum
    
    rum_lb_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust rum
   
    ''' true_choice_prob_collection = []
    rum_lb_rev_prob_collection = []
   
    rum_lb_sales_frac_collection = [] '''

    true_revenue_collection = []
    rum_lb_revenue_collection = []
   
    rum_lb_runtime_collection = []
    rum_actual_runtime_collection = []
    
    infeasible_collection = []
    
    for j in range(pred_instance_size[i]):
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        # the following lists are of the same size as number of testing assortments
        ''' true assortment ranking '''
        #true_choice_prob = [] 
        true_revenue = []
        
        ''' lb_rum_rev_prob = []
        lb_rum_sales = [] '''
        lb_rum_revenue = [] 
        lb_rum_runtime = []
        actual_runtime = [] 
        
        produts_notin_collection = find_product_notin_assortment(all_train_collection[i][j],n)
        train_element_indexes,train_perm_collection = find_element_permutation_indexes(n, all_train_collection[i][j])
        test_element_indexes, test_perm_collection = find_element_permutation_indexes(n, all_test_collection[i][j])
        
        flag = 0
        for k in range(len(all_test_collection[i][j])):
            
            unseen_assortment = all_test_collection[i][j][k]
            
            
            
            # rum revenue prediction
            # robust_rum_prediction_w_ci(lb,ub,data,collection,perm_collection,produts_notin_collection,unseen_assortment,unseen_assortment_perm,price)
            curr_rum_lb_result = robust_rum_prediction_w_ci(all_train_lb[i][j],all_train_ub[i][j],all_train_instances[i][j],all_train_collection[i][j],train_perm_collection,produts_notin_collection,unseen_assortment,test_perm_collection[k],price)

            if curr_rum_lb_result[0]<0:
                flag=1
                break
            else:
                ## record the revenue result
                lb_rum_revenue.append(curr_rum_lb_result[0])
            
                ''' ## record the choice probability result
                lb_prob = np.zeros(n)
                lb_prob_result = curr_rum_lb_result[1]
                
                for l in range(len(unseen_assortment)):
                    lb_prob[unseen_assortment[l]] = lb_prob_result[l]
            
                lb_rum_rev_prob.append(lb_prob) '''
        
                ## record the runtime result
                lb_rum_runtime.append(curr_rum_lb_result[2])
                actual_runtime.append(curr_rum_lb_result[-1])
                
                
                ''' ## rum choice probability interval prediction
                lb_sales_frac = np.zeros(n)

                for l in range(len(unseen_assortment)):
                    unit_price = np.zeros(n)
                    unit_price[unseen_assortment[l]] = 1
                    ## unit price is a vector that takes value 1 only at unseen_assortment[l] and all zeros for other n-1 elements
                    lb_sales_frac[unseen_assortment[l]] = robust_rum_prediction_w_ci(all_train_lb[i][j],all_train_ub[i][j],all_train_instances[i][j],all_train_collection[i][j],train_perm_collection,produts_notin_collection,unseen_assortment,test_perm_collection[k],unit_price)[0]
                
                lb_rum_sales.append(lb_sales_frac) '''
            # true revenue and true choice probabilities for current testing assortment
            curr_revenue = np.dot(all_test_instance[i][j][:,k],price)
            true_revenue.append(curr_revenue)
            #true_choice_prob.append(all_test_instance[i][j][:,k])
        if flag ==0:          
            true_revenue_collection.append(true_revenue)
            #true_choice_prob_collection.append(true_choice_prob)
            
            rum_lb_revenue_collection.append(lb_rum_revenue)   
            #rum_lb_rev_prob_collection.append(lb_rum_rev_prob)
            
            rum_lb_runtime_collection.append(lb_rum_runtime)
            rum_actual_runtime_collection.append(actual_runtime)
            ## sales fraction record
            #rum_lb_sales_frac_collection.append(lb_rum_sales)
            
            # true assortment ranking for test instance [i][j]
            curr_true_rank = np.argsort(-np.array(true_revenue))  
            true_ranking_collection.append(curr_true_rank)
            # true best assortment revenue for test instance [i][j]
            true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
            
            # lb rum assortment ranking for test instance [i][j] 
            curr_rum_lb_rank  = np.argsort(-np.array(lb_rum_revenue)) 
            rum_lb_ranking_collection.append(curr_rum_lb_rank)
            rum_lb_best_rev_collection.append(true_revenue[curr_rum_lb_rank[0]])
            
            #  rum kendallTau Distance for current instance [i][j]
            curr_rum_lb_dist = kendall_tau_distance(curr_true_rank, curr_rum_lb_rank)
            rum_lb_distance_collection.append(curr_rum_lb_dist)
        else:
            infeasible_collection.append(flag)
    # for each test instance [i][j] kendall tau distance is a number
    all_rum_lb_distance_list.append(rum_lb_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_revenue_list.append(true_best_rev_collection) 
    all_best_revenue_rum_lb.append(rum_lb_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_rum_lb_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(rum_lb_best_rev_collection))/ np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    #all_true_choice_prob_list.append(true_choice_prob_collection)
    all_rum_lb_revenue_list.append(rum_lb_revenue_collection)
    #all_rum_lb_rev_prob_list.append(rum_lb_rev_prob_collection)
    
    #all_rum_lb_sales_list.append(rum_lb_sales_frac_collection)
    
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_rum_lb_ranking.append(rum_lb_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_rum_rev_lb_runtime.append(rum_lb_runtime_collection)
    all_rum_actual_runtime.append(rum_actual_runtime_collection)

    all_infeasible_collection.append(infeasible_collection)
# Out:
# testing for offertimes 20, 0th instance
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# RUM robust prediction revenue of assortment [0, 5] is : 0.12687040188257984 with runtime 101.55412697792053
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.0837442414615872 with runtime 97.27589821815491
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.10055459006615598 with runtime 100.05411124229431
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.2153428821508243 with runtime 96.96647071838379
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.10055459006615601 with runtime 97.09717798233032
# testing for offertimes 20, 1th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.10672523995058557 with runtime 84.45496129989624
# RUM robust prediction revenue of assortment [0, 4] is : 0.0323204100286846 with runtime 86.86626410484314
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.2552754123551033 with runtime 85.08863687515259
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.10672523995058557 with runtime 84.46233773231506
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.12938046991452054 with runtime 85.60343027114868
# testing for offertimes 20, 2th instance
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.3046815255399226 with runtime 88.25993871688843
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12313384793586314 with runtime 87.69469213485718
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.10594332881283491 with runtime 86.74336409568787
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.3181009412436526 with runtime 88.64480590820312
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3436081757770117 with runtime 87.81441307067871
# testing for offertimes 20, 3th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.08583885315385821 with runtime 83.83595895767212
# RUM robust prediction revenue of assortment [0, 4] is : 0.22547645259461266 with runtime 82.94404101371765
# RUM robust prediction revenue of assortment [0, 7] is : 0.06530964651281775 with runtime 83.75207018852234
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.07498213975230993 with runtime 82.93590211868286
# RUM robust prediction revenue of assortment [0, 8] is : 0.13975168820203135 with runtime 84.12215495109558
# testing for offertimes 20, 4th instance
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.25636713948134887 with runtime 88.91361379623413
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.10714771767923398 with runtime 88.49931311607361
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.10602941857887076 with runtime 88.07915997505188
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.10877799068689749 with runtime 87.58304810523987
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.10877799068689749 with runtime 88.88825607299805
# testing for offertimes 20, 5th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.1570665562559856 with runtime 87.06154417991638
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.22746792837383903 with runtime 87.76142477989197
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12107248660896681 with runtime 85.25247001647949
# RUM robust prediction revenue of assortment [0, 4, 7] is : 0.1585430426156863 with runtime 85.34124302864075
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.12670854710305532 with runtime 86.07070064544678
# testing for offertimes 20, 6th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.4208582020808321 with runtime 87.1892740726471
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.10480058701942738 with runtime 85.88438415527344
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.10480058701942738 with runtime 86.58440709114075
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.40948191254177274 with runtime 88.06700611114502
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3158552991616564 with runtime 86.79872608184814
# testing for offertimes 20, 7th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.1491794149329159 with runtime 86.639328956604
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.10214368255606002 with runtime 84.51831412315369
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.08425776345869088 with runtime 85.89687609672546
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.24301674556266217 with runtime 83.93386006355286
# RUM robust prediction revenue of assortment [0, 8] is : 0.07329257253119693 with runtime 87.38213896751404
# testing for offertimes 20, 8th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.07137462724922213 with runtime 86.47891020774841
# RUM robust prediction revenue of assortment [0, 7] is : 0.045714908041306235 with runtime 84.45583820343018
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.15788320388182772 with runtime 81.06366991996765
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.13443332657473595 with runtime 82.48618197441101
# RUM robust prediction revenue of assortment [0, 8] is : 0.2308340406418269 with runtime 82.81395506858826
# testing for offertimes 20, 9th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.11584827174474217 with runtime 86.19440793991089
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.07920505024605219 with runtime 85.8446741104126
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.12306790383922303 with runtime 85.80876088142395
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.0948626431845586 with runtime 100.74523115158081
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.3437940514617066 with runtime 99.77674698829651
# testing for offertimes 20, 10th instance
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.08648373301508769 with runtime 97.07274436950684
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.11258825443807634 with runtime 98.11789989471436
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.08381478003804226 with runtime 100.2708249092102
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.09653949009931546 with runtime 98.60425305366516
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.11703252763957933 with runtime 96.77001714706421
# testing for offertimes 20, 11th instance
# RUM CI: No solution found or an error occurred.
# testing for offertimes 20, 12th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.05351457817523951 with runtime 87.16044592857361
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.27124735594408994 with runtime 85.87852787971497
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.13544745637038325 with runtime 85.05796003341675
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.13544745637038325 with runtime 86.0686411857605
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.12558395049248422 with runtime 86.7553551197052
# testing for offertimes 20, 13th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.12729590612419908 with runtime 84.66917610168457
# RUM robust prediction revenue of assortment [0, 6] is : 0.02733940598421954 with runtime 84.59635996818542
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.3098648643061615 with runtime 84.67016696929932
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.3628494343975534 with runtime 83.89474296569824
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.11435820908195007 with runtime 84.83499193191528
# testing for offertimes 20, 14th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.010536559725486453 with runtime 86.80508303642273
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.31479438717152125 with runtime 82.97320008277893
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.13773339876325846 with runtime 83.28263092041016
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.36623519809564414 with runtime 84.14109301567078
# RUM robust prediction revenue of assortment [0, 8] is : 0.36623519809564403 with runtime 84.02462196350098
# testing for offertimes 20, 15th instance
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.11840240638126112 with runtime 86.3529257774353
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.07769531668763259 with runtime 89.60658812522888
# RUM robust prediction revenue of assortment [0, 4, 7] is : 0.19007374166963675 with runtime 86.93825507164001
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.4317794549569957 with runtime 88.14798736572266
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1280971078007465 with runtime 89.7568531036377
# testing for offertimes 20, 16th instance
# RUM robust prediction revenue of assortment [0, 7] is : 0.00684061785894373 with runtime 85.26953387260437
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.27007687023491794 with runtime 85.13300824165344
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.0950011491904603 with runtime 83.59342908859253
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.11596574778835099 with runtime 85.96543979644775
# RUM robust prediction revenue of assortment [0, 8] is : 0.12726619074871118 with runtime 87.87437629699707
# testing for offertimes 20, 17th instance
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.19682123280665012 with runtime 85.09079217910767
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.10020008622237961 with runtime 86.80842924118042
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.10020008622237961 with runtime 86.94562101364136
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.10020008622237961 with runtime 87.90638899803162
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.08289959215278028 with runtime 88.94214391708374
# testing for offertimes 20, 18th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.05122316653475983 with runtime 86.55722618103027
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.10328016691661072 with runtime 85.39656114578247
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.10050640682448045 with runtime 85.58789587020874
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.31673005186392333 with runtime 86.02580308914185
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.11410006341426546 with runtime 85.65538001060486
# testing for offertimes 20, 19th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.07003935738912663 with runtime 87.75343680381775
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.2302546446769981 with runtime 87.39063882827759
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.1045418830312543 with runtime 85.97287201881409
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.0725629782714014 with runtime 85.85521984100342
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.24639174436746014 with runtime 86.92198014259338
# testing for offertimes 20, 20th instance
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.15275532441394107 with runtime 85.0535159111023
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.11622663439880776 with runtime 86.78443193435669
# RUM robust prediction revenue of assortment [0, 4, 7] is : 0.15756844105705253 with runtime 87.58358764648438
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.13550801864782158 with runtime 86.75032591819763
# RUM robust prediction revenue of assortment [0, 8] is : 0.14605089603417518 with runtime 87.92700386047363
# testing for offertimes 20, 21th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.03964709627771952 with runtime 86.79579901695251
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.13290014613325724 with runtime 86.26962471008301
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.10976714961372373 with runtime 85.48635220527649
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.11410006341426546 with runtime 85.78689694404602
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.31673005186392333 with runtime 88.42533111572266
# testing for offertimes 20, 22th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.023060271794443536 with runtime 86.09673810005188
# RUM robust prediction revenue of assortment [0, 6] is : 0.06605791115241498 with runtime 86.575927734375
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.21179135219988848 with runtime 84.55049920082092
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.06605791115241498 with runtime 85.36797165870667
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.12938046991452057 with runtime 87.15315675735474
# testing for offertimes 20, 23th instance
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.17627026111826263 with runtime 86.49767208099365
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.2738766295882259 with runtime 86.15221500396729
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.08950504571356738 with runtime 86.17358613014221
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.1001228701634966 with runtime 87.17494201660156
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.12204162562660766 with runtime 86.2317910194397
# testing for offertimes 20, 24th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.205566320332827 with runtime 85.40907502174377
# RUM robust prediction revenue of assortment [0, 2] is : 0.09065353435209622 with runtime 84.5146050453186
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.24441782085032357 with runtime 83.7142641544342
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.11218604352264915 with runtime 85.4115822315216
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.37387989269845856 with runtime 86.43440389633179
# testing for offertimes 20, 25th instance
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.2793641316729369 with runtime 86.61696100234985
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.12549015051734294 with runtime 86.05097913742065
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.12549015051734294 with runtime 86.94580388069153
# RUM robust prediction revenue of assortment [0, 4, 7] is : 0.23327550742052272 with runtime 103.31555891036987
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.11555472204150226 with runtime 100.34645390510559
# testing for offertimes 20, 26th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.0 with runtime 89.29402184486389
# RUM robust prediction revenue of assortment [0, 6] is : 0.08249136718862742 with runtime 93.81599473953247
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.09347517143964215 with runtime 88.04707884788513
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.09347517143964215 with runtime 89.9059829711914
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.2467964343445376 with runtime 90.67930221557617
# testing for offertimes 20, 27th instance
# RUM robust prediction revenue of assortment [0, 7] is : 0.02180136195759817 with runtime 88.73200011253357
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.08981879339613535 with runtime 89.06968688964844
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.1252076333339517 with runtime 88.94235110282898
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.1376586962959668 with runtime 87.96873307228088
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.13765869629596686 with runtime 94.10287308692932
# testing for offertimes 20, 28th instance
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.11054549881947888 with runtime 92.6389639377594
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.17119512485441996 with runtime 94.81582808494568
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.08788052330101566 with runtime 92.52607488632202
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.08071646821564658 with runtime 104.72677803039551
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.11090529697457308 with runtime 97.42201495170593
# testing for offertimes 20, 29th instance
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.19789411607871119 with runtime 103.15740323066711
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.12736701034845002 with runtime 103.97214579582214
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.09241121503868047 with runtime 105.43242073059082
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.0792385637722019 with runtime 107.38562607765198
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.09605902615862837 with runtime 95.69010424613953
# testing for offertimes 20, 30th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.14882711729852335 with runtime 93.3549211025238
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.28384671743311196 with runtime 99.44290614128113
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.10661293613481922 with runtime 95.91535782814026
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.41499971559384874 with runtime 102.52169680595398
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3201114757603008 with runtime 101.1070122718811
# testing for offertimes 20, 31th instance
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.19378672873914699 with runtime 101.28068089485168
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.3294119975227762 with runtime 106.46777009963989
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1330905729178019 with runtime 102.70509815216064
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.13309057291780194 with runtime 89.82449102401733
# RUM robust prediction revenue of assortment [0, 8] is : 0.014922391408645666 with runtime 92.767737865448
# testing for offertimes 20, 32th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.0 with runtime 98.07318186759949
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.10326574112365315 with runtime 98.35482001304626
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.12066416940896948 with runtime 109.36862373352051
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.1462783025571651 with runtime 96.45941829681396
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.2401535692453337 with runtime 94.49266600608826
# testing for offertimes 20, 33th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.019431417587292308 with runtime 91.29295802116394
# RUM robust prediction revenue of assortment [0, 7] is : 0.0 with runtime 89.7863450050354
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.10850602500267612 with runtime 90.03738713264465
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.10142569671006088 with runtime 88.99894618988037
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.11489945750262406 with runtime 102.31554985046387
# testing for offertimes 20, 34th instance
# RUM robust prediction revenue of assortment [0, 7] is : 0.023470185474822377 with runtime 102.21951007843018
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.1481946320207385 with runtime 102.62776494026184
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.1279750659777157 with runtime 104.54274797439575
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.12797506597771569 with runtime 104.6691222190857
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.12797506597771574 with runtime 103.65976428985596
# testing for offertimes 20, 35th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.0026793143917913462 with runtime 101.24864792823792
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.13779539296416254 with runtime 99.9634428024292
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.09039199156979313 with runtime 97.63007593154907
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.08677841692087604 with runtime 102.49483609199524
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.09748509890300454 with runtime 99.90957903862
# testing for offertimes 20, 36th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.1355080186478215 with runtime 99.78898692131042
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.13036214452195485 with runtime 95.5321729183197
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.11177982128965866 with runtime 90.84894299507141
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.10020008622237965 with runtime 92.67697191238403
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.2808913623432344 with runtime 95.59236121177673
# testing for offertimes 20, 37th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.058673948886344425 with runtime 99.96103811264038
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.07588590309826271 with runtime 101.68055176734924
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.09742934951787248 with runtime 104.88575005531311
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.2350946869139226 with runtime 104.97791123390198
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.29253722847565794 with runtime 108.79347586631775
# testing for offertimes 20, 38th instance
# RUM CI: No solution found or an error occurred.
# testing for offertimes 20, 39th instance
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.2694919733822735 with runtime 89.2961061000824
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.09195064698823066 with runtime 89.75124406814575
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.26517331278476625 with runtime 93.30091285705566
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.09500275545128165 with runtime 92.22856903076172
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.09500275545128165 with runtime 88.86841797828674
# testing for offertimes 20, 40th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.009134971340277081 with runtime 89.01771330833435
# RUM robust prediction revenue of assortment [0, 3] is : 0.03887964309954334 with runtime 86.59814596176147
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.14466009855093492 with runtime 85.50086903572083
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.14466009855093495 with runtime 85.43472695350647
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.14466009855093492 with runtime 89.01353907585144
# testing for offertimes 20, 41th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.034484827657621724 with runtime 87.33768129348755
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.10633675810158628 with runtime 86.2877209186554
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.2038096770898317 with runtime 86.48700881004333
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.0845510850695239 with runtime 86.39794111251831
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.0878886279012157 with runtime 85.55708980560303
# testing for offertimes 20, 42th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.0 with runtime 88.14506387710571
# RUM robust prediction revenue of assortment [0, 6] is : 0.03926703269741117 with runtime 84.37911081314087
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.22700406664169043 with runtime 83.82048606872559
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.09602297649154665 with runtime 84.26658916473389
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.28831451253472085 with runtime 84.96919298171997
# testing for offertimes 20, 43th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.05010715617066918 with runtime 85.4397451877594
# RUM robust prediction revenue of assortment [0, 6] is : 0.08082931352661844 with runtime 85.7358660697937
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.26228477672487294 with runtime 84.80802488327026
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.2270040666416904 with runtime 84.31768608093262
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.14610252127755294 with runtime 84.67665696144104
# testing for offertimes 20, 44th instance
# RUM CI: No solution found or an error occurred.
# testing for offertimes 20, 45th instance
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.3029802184874513 with runtime 86.29449105262756
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.1083987283578187 with runtime 85.61584210395813
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.07697942389159877 with runtime 86.50766491889954
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.07167386162832559 with runtime 88.31226587295532
# RUM robust prediction revenue of assortment [0, 4, 7] is : 0.13894147345599375 with runtime 88.09972286224365
# testing for offertimes 20, 46th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.011665073428433563 with runtime 85.67188310623169
# RUM robust prediction revenue of assortment [0, 4] is : 0.13524773374194218 with runtime 84.97648501396179
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.27007687023491794 with runtime 85.15550684928894
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.33473166027351997 with runtime 83.9374840259552
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.08556399173535105 with runtime 85.88764905929565
# testing for offertimes 20, 47th instance
# RUM robust prediction revenue of assortment [0, 7] is : 0.09181352627782843 with runtime 87.59600305557251
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.27387662958822584 with runtime 85.56066584587097
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.1247046324926216 with runtime 86.22699904441833
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.12797506597771569 with runtime 86.67882919311523
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.39654062798550366 with runtime 86.90768480300903
# testing for offertimes 20, 48th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.19790662098483333 with runtime 86.65400910377502
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.23459353039421033 with runtime 83.7095890045166
# RUM robust prediction revenue of assortment [0, 3, 5] is : 0.10674014118421365 with runtime 85.24718713760376
# RUM robust prediction revenue of assortment [0, 4, 8] is : 0.18402309155426202 with runtime 83.92788982391357
# RUM robust prediction revenue of assortment [0, 8] is : 0.061905549093665906 with runtime 88.03397297859192
# testing for offertimes 20, 49th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.05911669381438006 with runtime 87.94148921966553
# RUM robust prediction revenue of assortment [0, 7] is : 0.051471488897533724 with runtime 86.95183110237122
# RUM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.0898208045457137 with runtime 87.15462398529053
# RUM robust prediction revenue of assortment [0, 3, 8] is : 0.06568208984411096 with runtime 87.50748586654663
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1029386927427936 with runtime 86.29561185836792
# testing for offertimes 30, 0th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.10961590176264517 with runtime 75.92858791351318
# RUM robust prediction revenue of assortment [0, 5] is : 0.12687040188257984 with runtime 75.27137684822083
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.0837442414615872 with runtime 73.8087010383606
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.1909471382615061 with runtime 76.22082209587097
# testing for offertimes 30, 1th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.09065353435209621 with runtime 75.35499596595764
# RUM robust prediction revenue of assortment [0, 6] is : 0.041409484256454195 with runtime 74.48063397407532
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.12704287378140505 with runtime 73.14464712142944
# RUM robust prediction revenue of assortment [0, 8] is : 0.36219674505928773 with runtime 74.08145189285278
# testing for offertimes 30, 2th instance
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12313384793586318 with runtime 77.96896886825562
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.10408369326953232 with runtime 76.88361024856567
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1279943945649104 with runtime 75.46198391914368
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.16048862647489942 with runtime 77.72435188293457
# testing for offertimes 30, 3th instance
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.08282450389655148 with runtime 78.25371408462524
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.27609753701638756 with runtime 77.25344896316528
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.2625597910757602 with runtime 77.61937308311462
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.10116229772900005 with runtime 78.32644391059875
# testing for offertimes 30, 4th instance
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.10602941857887076 with runtime 83.48043322563171
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.10602941857887076 with runtime 76.09815502166748
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.10602941857887077 with runtime 78.67859196662903
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.2693793009627367 with runtime 79.2796790599823
# testing for offertimes 30, 5th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.15706655625598562 with runtime 77.54683089256287
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.23143174295210178 with runtime 76.29087686538696
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.12585166371195233 with runtime 77.51335000991821
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.12585166371195233 with runtime 76.54705381393433
# testing for offertimes 30, 6th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.1527602602985287 with runtime 77.55332684516907
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.1469592377555467 with runtime 77.61623787879944
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3158552991616564 with runtime 77.64105486869812
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1527602602985287 with runtime 78.06265902519226
# testing for offertimes 30, 7th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.023521090930125506 with runtime 72.43124604225159
# RUM robust prediction revenue of assortment [0, 5] is : 0.09816721940800718 with runtime 72.70244574546814
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.19789411607871113 with runtime 71.86288213729858
# RUM robust prediction revenue of assortment [0, 8] is : 0.07329257253119693 with runtime 72.73050284385681
# testing for offertimes 30, 8th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.02078316874758306 with runtime 74.66770100593567
# RUM robust prediction revenue of assortment [0, 3] is : 0.018085807511055534 with runtime 75.94728302955627
# RUM robust prediction revenue of assortment [0, 7] is : 0.045714908041306235 with runtime 75.41607117652893
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.25745917945780883 with runtime 74.09351801872253
# testing for offertimes 30, 9th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.009401465334696765 with runtime 74.23104619979858
# RUM robust prediction revenue of assortment [0, 6] is : 0.09100587251380067 with runtime 74.26918482780457
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.25256268939929793 with runtime 73.1841630935669
# RUM robust prediction revenue of assortment [0, 8] is : 0.13975168820203135 with runtime 72.64885902404785
# testing for offertimes 30, 10th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.1988856697106935 with runtime 76.73434090614319
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.2302546446769981 with runtime 76.65565419197083
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.11258825443807634 with runtime 75.1168429851532
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.11703252763957936 with runtime 76.58531975746155
# testing for offertimes 30, 11th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.02530803607803874 with runtime 75.16106796264648
# RUM robust prediction revenue of assortment [0, 2] is : 0.040720282255340634 with runtime 75.67269492149353
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.3032627382646523 with runtime 74.39605617523193
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.10368607079491933 with runtime 73.215402841568
# testing for offertimes 30, 12th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.025889261759645565 with runtime 76.47900390625
# RUM robust prediction revenue of assortment [0, 7] is : 0.033345391955646904 with runtime 76.21337008476257
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.13544745637038325 with runtime 74.69327306747437
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.09866329923716505 with runtime 73.61110019683838
# testing for offertimes 30, 13th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.06354938288080428 with runtime 77.81784701347351
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.11960321733415874 with runtime 76.09055185317993
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.12510727911509414 with runtime 76.58948612213135
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.11300304330120914 with runtime 77.5820951461792
# testing for offertimes 30, 14th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.010536559725486453 with runtime 77.2082040309906
# RUM robust prediction revenue of assortment [0, 7] is : 0.03873640890219674 with runtime 75.78221893310547
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.1946864497286566 with runtime 74.90689992904663
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.3024904390560171 with runtime 74.54325199127197
# testing for offertimes 30, 15th instance
# RUM robust prediction revenue of assortment [0, 7] is : 0.13313519739313 with runtime 78.89130806922913
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.09495404702556931 with runtime 76.36314296722412
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.16104097518161958 with runtime 75.46042823791504
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.10310451159601346 with runtime 76.78550291061401
# testing for offertimes 30, 16th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.03722880733515139 with runtime 78.25149989128113
# RUM robust prediction revenue of assortment [0, 7] is : 0.00684061785894373 with runtime 76.07840490341187
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.09565950925157223 with runtime 73.72302913665771
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.115965747788351 with runtime 74.13994288444519
# testing for offertimes 30, 17th instance
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.21663824849509572 with runtime 78.27966213226318
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.19682123280665012 with runtime 76.95391607284546
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.10020008622237962 with runtime 77.04000401496887
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.10424865539791212 with runtime 81.93376398086548
# testing for offertimes 30, 18th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.19364572510834452 with runtime 77.79556202888489
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.11410006341426547 with runtime 76.77541780471802
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.10050640682448043 with runtime 76.85644698143005
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.11410006341426547 with runtime 75.46008491516113
# testing for offertimes 30, 19th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.08703026343193837 with runtime 75.23191809654236
# RUM robust prediction revenue of assortment [0, 6] is : 0.07256297827140137 with runtime 75.26231408119202
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.20973051330050657 with runtime 73.75321412086487
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.21847853993741567 with runtime 73.87073397636414
# testing for offertimes 30, 20th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.0746559206465115 with runtime 75.65088415145874
# RUM robust prediction revenue of assortment [0, 7] is : 0.0 with runtime 74.67959332466125
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.13550801864782147 with runtime 73.92950797080994
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.13550801864782144 with runtime 74.43233013153076
# testing for offertimes 30, 21th instance
# RUM robust prediction revenue of assortment [0, 7] is : 0.01857440213063272 with runtime 78.23407793045044
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.20649112257421015 with runtime 75.75787425041199
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.11410006341426546 with runtime 77.26311302185059
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.10976714961372375 with runtime 77.6177818775177
# testing for offertimes 30, 22th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.023060271794443536 with runtime 78.23979806900024
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.23328738074617247 with runtime 75.36196494102478
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.32044867442963537 with runtime 76.29464077949524
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1151659839650422 with runtime 76.97947311401367
# testing for offertimes 30, 23th instance
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.17627026111826266 with runtime 76.5481641292572
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.09653949009931552 with runtime 78.17198204994202
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.3006246792121354 with runtime 79.42066478729248
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.12204162562660766 with runtime 77.70005488395691
# testing for offertimes 30, 24th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.037074276255797824 with runtime 76.09767007827759
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.11278624753808407 with runtime 73.99239087104797
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.2883935571800199 with runtime 75.44045424461365
# RUM robust prediction revenue of assortment [0, 8] is : 0.11494121810152405 with runtime 75.3880090713501
# testing for offertimes 30, 25th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.03924468496980512 with runtime 73.94834518432617
# RUM robust prediction revenue of assortment [0, 3] is : 0.08368183659199525 with runtime 75.20581293106079
# RUM robust prediction revenue of assortment [0, 5] is : 0.22225707080748636 with runtime 73.68868708610535
# RUM robust prediction revenue of assortment [0, 6] is : 0.027339405984219536 with runtime 72.63406491279602
# testing for offertimes 30, 26th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.08249136718862742 with runtime 75.85208129882812
# RUM robust prediction revenue of assortment [0, 7] is : 0.03177125747612025 with runtime 76.78973889350891
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.21883738343497752 with runtime 75.13556504249573
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.24679643434453755 with runtime 74.62153911590576
# testing for offertimes 30, 27th instance
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.2032643694659105 with runtime 77.59700608253479
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.1376586962959668 with runtime 77.97856879234314
# RUM robust prediction revenue of assortment [0, 3, 7] is : 0.08981879339613535 with runtime 77.72078895568848
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.13765869629596683 with runtime 77.65995478630066
# testing for offertimes 30, 28th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.0033064049896273087 with runtime 77.82104969024658
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.23397346485001863 with runtime 76.48637890815735
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.11090529697457308 with runtime 74.68773698806763
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.1105454988194789 with runtime 74.19521117210388
# testing for offertimes 30, 29th instance
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.07739357477799495 with runtime 77.02462911605835
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.07923856377220191 with runtime 75.90085196495056
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.0960590261586284 with runtime 76.80384421348572
# RUM robust prediction revenue of assortment [0, 6, 8] is : 0.21147023186199043 with runtime 75.75874614715576
# testing for offertimes 30, 30th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.023060271794443536 with runtime 75.33723378181458
# RUM robust prediction revenue of assortment [0, 5] is : 0.10779795134637633 with runtime 75.29688239097595
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.10779795134637633 with runtime 73.67241787910461
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.13577675926627916 with runtime 74.37566494941711
# testing for offertimes 30, 31th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.330540255147 with runtime 75.8497040271759
# RUM robust prediction revenue of assortment [0, 5] is : 0.2377307432614882 with runtime 75.18077802658081
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.133090572917802 with runtime 74.6003110408783
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.21551467179779038 with runtime 73.21180987358093
# testing for offertimes 30, 32th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.04287796138072802 with runtime 77.79273390769958
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.2618304469248642 with runtime 75.59348917007446
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.14627830255716504 with runtime 75.6368498802185
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.14627830255716504 with runtime 78.21954393386841
# testing for offertimes 30, 33th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.02260587444889392 with runtime 76.23319411277771
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.11477168614543296 with runtime 75.19882416725159
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.25864288226626225 with runtime 75.56614589691162
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.11489945750262406 with runtime 74.85742211341858
# testing for offertimes 30, 34th instance
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.26666846150439694 with runtime 78.44666528701782
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.27124735594409 with runtime 77.27071619033813
# RUM robust prediction revenue of assortment [0, 1, 7] is : 0.1736741620418311 with runtime 78.77351212501526
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.13631432134512203 with runtime 77.34433889389038
# testing for offertimes 30, 35th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.0 with runtime 77.49152088165283
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.18718324762736133 with runtime 76.83053636550903
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.08677841692087604 with runtime 75.57327485084534
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.257338153347319 with runtime 76.99688911437988
# testing for offertimes 30, 36th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.09109099438416425 with runtime 75.18843483924866
# RUM robust prediction revenue of assortment [0, 2] is : 0.011608546562453331 with runtime 74.97756886482239
# RUM robust prediction revenue of assortment [0, 4] is : 0.0033064049896273087 with runtime 75.1402280330658
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.24906976848322573 with runtime 73.68104219436646
# testing for offertimes 30, 37th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.05867394888634438 with runtime 76.14300680160522
# RUM robust prediction revenue of assortment [0, 3] is : 0.0067269992037230116 with runtime 75.98076605796814
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.10771511208289086 with runtime 75.23008990287781
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.1322629010497975 with runtime 75.7610650062561
# testing for offertimes 30, 38th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.03280394544376316 with runtime 79.86838674545288
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.08648373301508769 with runtime 76.83263492584229
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.03155822599653165 with runtime 76.47456097602844
# RUM robust prediction revenue of assortment [0, 4, 6] is : 0.06498267720864392 with runtime 76.4947361946106
# testing for offertimes 30, 39th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.17942549712746714 with runtime 76.54709911346436
# RUM robust prediction revenue of assortment [0, 6] is : 0.02897362828201831 with runtime 75.21752715110779
# RUM robust prediction revenue of assortment [0, 3, 4] is : 0.09195064698823066 with runtime 75.03950786590576
# RUM robust prediction revenue of assortment [0, 6, 7] is : 0.08860470746722306 with runtime 74.56545805931091
# testing for offertimes 30, 40th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.023060271794443536 with runtime 74.9416172504425
# RUM robust prediction revenue of assortment [0, 6] is : 0.07917122961891518 with runtime 75.47997426986694
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.10492927520088213 with runtime 73.80592107772827
# RUM robust prediction revenue of assortment [0, 8] is : 0.09678561433048595 with runtime 74.95510196685791
# testing for offertimes 30, 41th instance
# RUM robust prediction revenue of assortment [0, 1, 5] is : 0.18932218850829582 with runtime 78.98386406898499
# RUM robust prediction revenue of assortment [0, 1, 8] is : 0.18932218850829582 with runtime 78.29110908508301
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.08455108506952393 with runtime 78.96491503715515
# RUM robust prediction revenue of assortment [0, 4, 5] is : 0.22984876167479568 with runtime 78.17650818824768
# testing for offertimes 30, 42th instance
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.22700406664169048 with runtime 78.3674008846283
# ...
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.20380967708983172 with runtime 55.77149224281311
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.10633675810158633 with runtime 55.84588408470154
# testing for offertimes 50, 42th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.1541111953387943 with runtime 55.3046989440918
# RUM robust prediction revenue of assortment [0, 3] is : 0.0067269992037230116 with runtime 54.9458270072937
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.05788422418584878 with runtime 53.260077238082886
# testing for offertimes 50, 43th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.05010715617066918 with runtime 57.87449383735657
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.262284776724873 with runtime 55.370492935180664
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.10735089009243882 with runtime 55.03277111053467
# testing for offertimes 50, 44th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.00796010384844513 with runtime 57.189905881881714
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.0939365005819567 with runtime 55.88955020904541
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.08054642922707253 with runtime 55.5753858089447
# testing for offertimes 50, 45th instance
# RUM robust prediction revenue of assortment [0, 4] is : 0.0 with runtime 55.201958894729614
# RUM robust prediction revenue of assortment [0, 5] is : 0.2146964379031012 with runtime 54.85267496109009
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.10839872835781877 with runtime 53.21412396430969
# testing for offertimes 50, 46th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.1369442449642222 with runtime 53.975425004959106
# RUM robust prediction revenue of assortment [0, 6] is : 0.03163937106641083 with runtime 53.95632481575012
# RUM robust prediction revenue of assortment [0, 8] is : 0.3551018633126342 with runtime 53.84666895866394
# testing for offertimes 50, 47th instance
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.2738766295882259 with runtime 56.772244930267334
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12690109615804526 with runtime 56.477192878723145
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.39654062798550366 with runtime 57.7319278717041
# testing for offertimes 50, 48th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.060831074135120136 with runtime 56.927642822265625
# RUM robust prediction revenue of assortment [0, 1, 3] is : 0.09220184013250736 with runtime 55.37777495384216
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.24917494679444113 with runtime 55.6956000328064
# testing for offertimes 50, 49th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.05911669381438009 with runtime 56.95687508583069
# RUM robust prediction revenue of assortment [0, 1, 4] is : 0.19526752673963702 with runtime 54.9568817615509
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.08491356300091203 with runtime 54.914549112319946
# testing for offertimes 60, 0th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.0222412982731598 with runtime 52.996752977371216
# RUM robust prediction revenue of assortment [0, 5] is : 0.07928786195671747 with runtime 51.88150906562805
# testing for offertimes 60, 1th instance
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.12938046991452057 with runtime 54.07895612716675
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.378040592230905 with runtime 54.834128856658936
# testing for offertimes 60, 2th instance
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12313384793586318 with runtime 53.711623191833496
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.34360817577701164 with runtime 53.304773807525635
# testing for offertimes 60, 3th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.1369442449642222 with runtime 52.99105715751648
# RUM robust prediction revenue of assortment [0, 6] is : 0.010770885159482988 with runtime 52.476463079452515
# testing for offertimes 60, 4th instance
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.10602941857887076 with runtime 53.83641314506531
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.26937930096273677 with runtime 53.37966012954712
# testing for offertimes 60, 5th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.04224501971085321 with runtime 54.0137300491333
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.13974553661320727 with runtime 53.63551378250122
# testing for offertimes 60, 6th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.13236015029252465 with runtime 52.34698510169983
# RUM robust prediction revenue of assortment [0, 8] is : 0.15875569648113785 with runtime 52.506197929382324
# testing for offertimes 60, 7th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.04232766181805144 with runtime 54.03432607650757
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.08162411527173496 with runtime 52.7699408531189
# testing for offertimes 60, 8th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.022850105885158328 with runtime 54.11282515525818
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.11089331369350582 with runtime 52.7683219909668
# testing for offertimes 60, 9th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.0 with runtime 54.053139209747314
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.13282210412169845 with runtime 52.5174880027771
# testing for offertimes 60, 10th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.11703252763957935 with runtime 54.08516001701355
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.09653949009931545 with runtime 53.36124801635742
# testing for offertimes 60, 11th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.00474243694556661 with runtime 54.39204812049866
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3032627382646523 with runtime 52.448721170425415
# testing for offertimes 60, 12th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.12558395049248428 with runtime 57.432425022125244
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12081493971428864 with runtime 58.22817611694336
# testing for offertimes 60, 13th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.033815017393525736 with runtime 58.74485516548157
# RUM robust prediction revenue of assortment [0, 8] is : 0.17806189251132803 with runtime 59.23828411102295
# testing for offertimes 60, 14th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.13773339876325846 with runtime 60.2429358959198
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3550130744854622 with runtime 59.227794885635376
# testing for offertimes 60, 15th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.054274829528425085 with runtime 56.89408206939697
# RUM robust prediction revenue of assortment [0, 5] is : 0.0 with runtime 57.00705003738403
# testing for offertimes 60, 16th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.052746368222433275 with runtime 58.73599600791931
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.11772663381606743 with runtime 58.00305986404419
# testing for offertimes 60, 17th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.08846773631820631 with runtime 52.37666296958923
# RUM robust prediction revenue of assortment [0, 3] is : 0.03811420976814819 with runtime 51.52519702911377
# testing for offertimes 60, 18th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.12534586213121962 with runtime 53.486948013305664
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.10050640682448045 with runtime 51.147486209869385
# testing for offertimes 60, 19th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.07003935738912663 with runtime 52.758849143981934
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.0954968907823632 with runtime 51.33457088470459
# testing for offertimes 60, 20th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.014155420860493529 with runtime 51.64957070350647
# RUM robust prediction revenue of assortment [0, 3] is : 0.027059794659306746 with runtime 51.34442710876465
# testing for offertimes 60, 21th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.07928786195671747 with runtime 53.38630127906799
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.11410006341426544 with runtime 51.572158336639404
# testing for offertimes 60, 22th instance
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.1107925921689013 with runtime 54.21731901168823
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.09591742522708775 with runtime 53.2167432308197
# testing for offertimes 60, 23th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.21313726724345916 with runtime 52.08734393119812
# RUM robust prediction revenue of assortment [0, 2] is : 0.08096148034115715 with runtime 51.75669813156128
# testing for offertimes 60, 24th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.20556632033282693 with runtime 51.94566583633423
# RUM robust prediction revenue of assortment [0, 8] is : 0.11494121810152406 with runtime 51.93718099594116
# testing for offertimes 60, 25th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.02733940598421954 with runtime 53.47778677940369
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.1272032645657753 with runtime 51.85352802276611
# testing for offertimes 60, 26th instance
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.10957548972935748 with runtime 52.14238095283508
# RUM robust prediction revenue of assortment [0, 8] is : 0.165158949049467 with runtime 54.14434099197388
# testing for offertimes 60, 27th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.017571419727830825 with runtime 53.73048400878906
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.13765869629596678 with runtime 52.62164497375488
# testing for offertimes 60, 28th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.034484827657621724 with runtime 53.497037172317505
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.1066937034185766 with runtime 52.1794376373291
# testing for offertimes 60, 29th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.0 with runtime 54.215965032577515
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.09605902615862837 with runtime 52.23938989639282
# testing for offertimes 60, 30th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.00878209640268029 with runtime 53.91847467422485
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.1306206798004711 with runtime 52.35601496696472
# testing for offertimes 60, 31th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.0 with runtime 52.67452383041382
# RUM robust prediction revenue of assortment [0, 5] is : 0.18323452933821158 with runtime 52.58706593513489
# testing for offertimes 60, 32th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.014155420860493529 with runtime 53.464597940444946
# RUM robust prediction revenue of assortment [0, 8] is : 0.15875569648113785 with runtime 53.24233675003052
# testing for offertimes 60, 33th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.13421702482503856 with runtime 54.07475519180298
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.11489945750262406 with runtime 54.36777687072754
# testing for offertimes 60, 34th instance
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.1279750659777157 with runtime 53.127931118011475
# RUM robust prediction revenue of assortment [0, 8] is : 0.02962339110494973 with runtime 54.442867040634155
# testing for offertimes 60, 35th instance
# RUM robust prediction revenue of assortment [0, 3] is : 0.03452774246669333 with runtime 52.40345501899719
# RUM robust prediction revenue of assortment [0, 6] is : 0.03665539740527407 with runtime 52.185877084732056
# testing for offertimes 60, 36th instance
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.1303621445219549 with runtime 53.4246461391449
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.13550801864782153 with runtime 53.595783948898315
# testing for offertimes 60, 37th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.058673948886344425 with runtime 52.05557298660278
# RUM robust prediction revenue of assortment [0, 6] is : 0.058011387811343504 with runtime 52.222851037979126
# testing for offertimes 60, 38th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.03054233396565635 with runtime 54.10420799255371
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.24015356924533374 with runtime 52.761975049972534
# testing for offertimes 60, 39th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.0 with runtime 53.57283592224121
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.2297876130544349 with runtime 51.885315895080566
# testing for offertimes 60, 40th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.009134971340277081 with runtime 52.19819116592407
# RUM robust prediction revenue of assortment [0, 6] is : 0.07917122961891518 with runtime 52.0643470287323
# testing for offertimes 60, 41th instance
# RUM robust prediction revenue of assortment [0, 1] is : 0.034484827657621724 with runtime 54.76035118103027
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.18379804372454436 with runtime 52.15618705749512
# testing for offertimes 60, 42th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.03926703269741117 with runtime 52.5296471118927
# RUM robust prediction revenue of assortment [0, 8] is : 0.07329257253119693 with runtime 52.22670316696167
# testing for offertimes 60, 43th instance
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.12519694599015885 with runtime 53.49299478530884
# RUM robust prediction revenue of assortment [0, 8] is : 0.23754936426981094 with runtime 53.592604875564575
# testing for offertimes 60, 44th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.038803518625831014 with runtime 53.86260485649109
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.05363825382713366 with runtime 52.244948863983154
# testing for offertimes 60, 45th instance
# RUM robust prediction revenue of assortment [0, 2] is : 0.02770586520991999 with runtime 54.2524139881134
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.0716738616283256 with runtime 51.83196210861206
# testing for offertimes 60, 46th instance
# RUM robust prediction revenue of assortment [0, 6] is : 0.03163937106641085 with runtime 54.70602083206177
# RUM robust prediction revenue of assortment [0, 5, 8] is : 0.3158552991616564 with runtime 52.37643790245056
# testing for offertimes 60, 47th instance
# RUM robust prediction revenue of assortment [0, 1, 6] is : 0.12470463249262155 with runtime 52.754700899124146
# RUM robust prediction revenue of assortment [0, 8] is : 0.12108283019912422 with runtime 53.22546720504761
# testing for offertimes 60, 48th instance
# RUM robust prediction revenue of assortment [0, 3, 6] is : 0.08054642922707253 with runtime 54.575039863586426
# RUM robust prediction revenue of assortment [0, 5, 6] is : 0.11234985481059512 with runtime 54.498169898986816
# testing for offertimes 60, 49th instance
# RUM robust prediction revenue of assortment [0, 5] is : 0.204138639632176 with runtime 54.253554821014404
# RUM robust prediction revenue of assortment [0, 2, 6] is : 0.09902962846142169 with runtime 52.71804094314575

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_rum_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i]-len(all_infeasible_collection[i]))),'rum_lb_dist':all_rum_lb_distance_list[i],
                                    'true_best_rev':all_best_true_revenue_list[i],'rum_lb_best_rev':all_best_revenue_rum_lb[i],
                                    'rum_lb_best_rev_diff':all_rum_lb_best_rev_diff[i]})
    df_rum_details1.to_csv('prediction/rum/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]-len(all_infeasible_collection[i])):
        
        true_rank = all_true_ranking[i][j]
        lb_rank = all_rum_lb_ranking[i][j]
        
        df_rank = pd.DataFrame({'true_rank':true_rank,'lb_rank':lb_rank})
        df_rank.to_csv('prediction/rum/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        lb_rev = all_rum_lb_revenue_list[i][j]
        
        df_rev = pd.DataFrame({'true_rev':true_rev,'lb_rev':lb_rev})
        df_rev.to_csv('prediction/rum/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ''' true_prob = all_true_choice_prob_list[i][j]
        lb_prob = all_rum_lb_rev_prob_list[i][j]
        
        
        df_true_prob = pd.DataFrame(true_prob).T
        df_lb_prob = pd.DataFrame(lb_prob).T
       
        
        df_true_prob.to_csv('prediction/rum/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_prob.to_csv('prediction/rum/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/rum_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        '''
        lb_runtime = all_rum_rev_lb_runtime[i][j]
       
        df_runtime = pd.DataFrame({'lb_runtime':lb_runtime})
        df_runtime.to_csv('prediction/rum/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        actual_runtime = all_rum_actual_runtime[i][j]
        df_actual_runtime = pd.DataFrame({'rum_runtime':actual_runtime})
        df_actual_runtime.to_csv('prediction/rum/revenue_prediction/details2/actual_runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ''' ## using sales fraction prediction
        ## record the choice probability prediction interval
        lb_sales = all_rum_lb_sales_list[i][j]
     
        df_lb_sales = pd.DataFrame(lb_sales).T
      
        
        df_true_prob.to_csv('prediction/rum/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_sales.to_csv('prediction/rum/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/rum_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''

# %%
## adding details 2 about runtime 
all_lb_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    
    avg_lb_runtime_collection = []

    for j in range(pred_instance_size[i]-len(all_infeasible_collection[i])):
        avg_lb_runtime_collection.append(np.mean(np.array(all_rum_rev_lb_runtime[i][j])))
   
    all_lb_avg_runtime.append(np.mean(np.array(avg_lb_runtime_collection)))

# %%
## adding details 2 about runtime 
all_actual_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    
    avg_actual_runtime_collection = []

    for j in range(pred_instance_size[i]-len(all_infeasible_collection[i])):
        avg_actual_runtime_collection.append(np.mean(np.array(all_rum_actual_runtime[i][j])))
   
    all_actual_avg_runtime.append(np.mean(np.array(avg_actual_runtime_collection)))

# %%
avg_rum_lb_dist = []

avg_rum_lb_best_rev_diff = []

avg_infeasible_prop = []

for i in range(len(pred_offer_times_list)):
    avg_rum_lb_dist.append(np.mean(all_rum_lb_distance_list[i]))
 
    avg_rum_lb_best_rev_diff.append(np.mean(all_rum_lb_best_rev_diff[i]))
    
    avg_infeasible_prop.append(len(all_infeasible_collection[i])/pred_instance_size[i])

df_rum_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'train_size':pred_train_collection_size,'test_size':pred_test_collection_size,
                                  'infeas_prop':avg_infeasible_prop,
                                   'avg_lb_dist':avg_rum_lb_dist,
                                   'avg_lb_best_rev_diff':avg_rum_lb_best_rev_diff,
                                   'avg_lb_runtime':all_lb_avg_runtime,
                                   'rum_actual_runtime':all_actual_avg_runtime})
df_rum_jd_summary.to_csv('prediction/rum/jd_rum_summary.csv')

# %%
df_rum_jd_summary
# Out:
#    offertimes  train_size  test_size  infeas_prop  avg_lb_dist  \
# 0          20          24          5         0.06      3.06383
# 1          30          20          4         0.00      1.52000
# 2          40          16          3         0.00      0.80000
# 3          50          12          3         0.00      0.86000
# 4          60          11          2         0.00      0.18000
#
#    avg_lb_best_rev_diff  avg_lb_runtime  rum_actual_runtime
# 0              0.099892        2.030445           89.889210
# 1              0.105559        1.684892           76.252391
# 2              0.096695        1.429148           66.123443
# 3              0.098517        1.212501           55.720892
# 4              0.070209        1.179737           53.569260

# %%
def rum_limit(data,collection,perm_collection,produts_notin_collection,offer_times):
    
    start_time = time.time()
    n,m = data.shape # number of products
    fact = math.factorial(n) # number of permutations
    
    model = gp.Model('rum') #define a model
    model.setParam('OutputFlag', 0)
    
    # define nonnegative continuous variables for lambda, the probability of each permutation
    lam = model.addVars(fact,lb=0.0, vtype=gp.GRB.CONTINUOUS, name='lam') 
    # define nonnegative continuous variables for choice probability of each product in each assortment
    x = model.addVars(n, m, vtype=gp.GRB.CONTINUOUS, lb=0, name="x") 
    # define the variables for absolute value
    y = model.addVars(n, m, vtype=gp.GRB.CONTINUOUS, lb=0, name="y")
    #normalization constraint of lambda
    model.addConstr(sum(lam[i] for i in range(fact))==1)
    
    # caculate RUM choice probability for each product in the assortment
    for i in range(len(collection)):
        # normalization constraint for each assortment. 
        model.addConstr(gp.quicksum(x[k, i] for k in collection[i]) == 1)
        for j in range(len(collection[i])):
            # constraints for RUM choice probabilities 
            model.addConstr(sum(lam[k] for k in perm_collection[i][j])- x[collection[i][j],i]==0)
            # constraints for the absolute value
            model.addConstr(x[collection[i][j],i] - data[collection[i][j]][i] - y[collection[i][j],i] <=0)
            model.addConstr(data[collection[i][j]][i] - x[collection[i][j],i] -  y[collection[i][j],i] <=0)
        for k in produts_notin_collection[i]:
            # constraints for products that are not in the assortments
            model.addConstr(x[k,i] == 0)
            model.addConstr(y[k,i] == 0)
    
    #model.setObjective(gp.quicksum(offer_times[j]*data[i][j] * y[i, j] for i in range(n) for j in range(m)/sum(offer_times)), sense=gp.GRB.MINIMIZE)
    #model.setObjective(0)
    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] *  y[i, j]  for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)
    
    model.optimize()
    status = model.status
    
    # Access the optimal solution
    used_time = time.time() - start_time
    if model.status == gp.GRB.OPTIMAL:
        print('Optimal solution found!')
        print(f'RUM L1 Norm Loss = {model.objVal}')
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
            
        return [model.objVal,x_values,model.Runtime,used_time]
    else:
        print("Gurobi optimization status:", status)
        print('No solution found or an error occurred.')

# %%
## record the limit loss of all instances
all_rum_limit_loss = []
all_rum_limit_prob = []
all_rum_limit_runtime = []


for i in range(len(pred_offer_times_list)):


    ## define container for rum limit 
    rum_limit_loss_collection =[]
    rum_limit_runtime_collection =[]
    rum_limit_probability_collection =[]
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        ####### rum representability check ##########
        

        element_indexes,perm_collection = find_element_permutation_indexes(n, all_full_collections[i])
        products_notin_collection = find_product_notin_assortment(all_full_collections[i] ,n)
        curr_limit_result = rum_limit(all_full_instances[i][j],all_full_collections[i],perm_collection,products_notin_collection,all_full_offertimes[i])
        # return [model.objVal,x_values,model.Runtime,used_time]
        
        curr_limit_prob = curr_limit_result[1]
        rum_limit_probability_collection.append(curr_limit_prob)
        rum_limit_loss_collection.append(curr_limit_result[0])
        rum_limit_runtime_collection.append(curr_limit_result[-1])
    
    ## for each train instance [i][j] limit loss result is a number
    all_rum_limit_loss.append(rum_limit_loss_collection)
    all_rum_limit_runtime.append(rum_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_rum_limit_prob.append(rum_limit_probability_collection)
# Out:
# testing instance with offertimes 20 : 0th
# Optimal solution found!
# RUM L1 Norm Loss = 37.69894147894689
# testing instance with offertimes 20 : 1th
# Optimal solution found!
# RUM L1 Norm Loss = 33.31455434352572
# testing instance with offertimes 20 : 2th
# Optimal solution found!
# RUM L1 Norm Loss = 35.79849253361443
# testing instance with offertimes 20 : 3th
# Optimal solution found!
# RUM L1 Norm Loss = 34.34958518412771
# testing instance with offertimes 20 : 4th
# Optimal solution found!
# RUM L1 Norm Loss = 15.539003168239148
# testing instance with offertimes 20 : 5th
# Optimal solution found!
# RUM L1 Norm Loss = 41.8923335718916
# testing instance with offertimes 20 : 6th
# Optimal solution found!
# RUM L1 Norm Loss = 21.268741214485296
# testing instance with offertimes 20 : 7th
# Optimal solution found!
# RUM L1 Norm Loss = 24.871679867633038
# testing instance with offertimes 20 : 8th
# Optimal solution found!
# RUM L1 Norm Loss = 37.86092527263568
# testing instance with offertimes 20 : 9th
# Optimal solution found!
# RUM L1 Norm Loss = 34.99249442293055
# testing instance with offertimes 20 : 10th
# Optimal solution found!
# RUM L1 Norm Loss = 22.853621907447398
# testing instance with offertimes 20 : 11th
# Optimal solution found!
# RUM L1 Norm Loss = 41.64174297861895
# testing instance with offertimes 20 : 12th
# Optimal solution found!
# RUM L1 Norm Loss = 24.982470424128895
# testing instance with offertimes 20 : 13th
# Optimal solution found!
# RUM L1 Norm Loss = 27.703503167999248
# testing instance with offertimes 20 : 14th
# Optimal solution found!
# RUM L1 Norm Loss = 28.169730376402278
# testing instance with offertimes 20 : 15th
# Optimal solution found!
# RUM L1 Norm Loss = 36.73782079113299
# testing instance with offertimes 20 : 16th
# Optimal solution found!
# RUM L1 Norm Loss = 34.70903443337016
# testing instance with offertimes 20 : 17th
# Optimal solution found!
# RUM L1 Norm Loss = 41.37748126089349
# testing instance with offertimes 20 : 18th
# Optimal solution found!
# RUM L1 Norm Loss = 31.101620834964447
# testing instance with offertimes 20 : 19th
# Optimal solution found!
# RUM L1 Norm Loss = 32.60478381134702
# testing instance with offertimes 20 : 20th
# Optimal solution found!
# RUM L1 Norm Loss = 18.89077885388819
# testing instance with offertimes 20 : 21th
# Optimal solution found!
# RUM L1 Norm Loss = 26.470540172593047
# testing instance with offertimes 20 : 22th
# Optimal solution found!
# RUM L1 Norm Loss = 23.859185961706014
# testing instance with offertimes 20 : 23th
# Optimal solution found!
# RUM L1 Norm Loss = 26.540136037063803
# testing instance with offertimes 20 : 24th
# Optimal solution found!
# RUM L1 Norm Loss = 23.669752721452426
# testing instance with offertimes 20 : 25th
# Optimal solution found!
# RUM L1 Norm Loss = 30.35504297721426
# testing instance with offertimes 20 : 26th
# Optimal solution found!
# RUM L1 Norm Loss = 23.306556977442263
# testing instance with offertimes 20 : 27th
# Optimal solution found!
# RUM L1 Norm Loss = 27.47420933902817
# testing instance with offertimes 20 : 28th
# Optimal solution found!
# RUM L1 Norm Loss = 34.716165360659346
# testing instance with offertimes 20 : 29th
# Optimal solution found!
# RUM L1 Norm Loss = 35.32560611366244
# testing instance with offertimes 20 : 30th
# Optimal solution found!
# RUM L1 Norm Loss = 20.836534015207253
# testing instance with offertimes 20 : 31th
# Optimal solution found!
# RUM L1 Norm Loss = 29.972444759261805
# testing instance with offertimes 20 : 32th
# Optimal solution found!
# RUM L1 Norm Loss = 27.33690657945978
# testing instance with offertimes 20 : 33th
# Optimal solution found!
# RUM L1 Norm Loss = 25.526576502685494
# testing instance with offertimes 20 : 34th
# Optimal solution found!
# RUM L1 Norm Loss = 28.82699128797422
# testing instance with offertimes 20 : 35th
# Optimal solution found!
# RUM L1 Norm Loss = 33.19528955992582
# testing instance with offertimes 20 : 36th
# Optimal solution found!
# RUM L1 Norm Loss = 17.33136577857831
# testing instance with offertimes 20 : 37th
# Optimal solution found!
# RUM L1 Norm Loss = 22.791483715032495
# testing instance with offertimes 20 : 38th
# Optimal solution found!
# RUM L1 Norm Loss = 20.92608216464794
# testing instance with offertimes 20 : 39th
# Optimal solution found!
# RUM L1 Norm Loss = 26.708986360232572
# testing instance with offertimes 20 : 40th
# Optimal solution found!
# RUM L1 Norm Loss = 24.350889806385435
# testing instance with offertimes 20 : 41th
# Optimal solution found!
# RUM L1 Norm Loss = 23.844964112573688
# testing instance with offertimes 20 : 42th
# Optimal solution found!
# RUM L1 Norm Loss = 36.1905985626883
# testing instance with offertimes 20 : 43th
# Optimal solution found!
# RUM L1 Norm Loss = 40.04718377897019
# testing instance with offertimes 20 : 44th
# Optimal solution found!
# RUM L1 Norm Loss = 23.13724876689744
# testing instance with offertimes 20 : 45th
# Optimal solution found!
# RUM L1 Norm Loss = 32.97485376476831
# testing instance with offertimes 20 : 46th
# Optimal solution found!
# RUM L1 Norm Loss = 36.516370046605445
# testing instance with offertimes 20 : 47th
# Optimal solution found!
# RUM L1 Norm Loss = 38.84100315754609
# testing instance with offertimes 20 : 48th
# Optimal solution found!
# RUM L1 Norm Loss = 22.614840938087582
# testing instance with offertimes 20 : 49th
# Optimal solution found!
# RUM L1 Norm Loss = 24.010349592470103
# testing instance with offertimes 30 : 0th
# Optimal solution found!
# RUM L1 Norm Loss = 29.163085626825186
# testing instance with offertimes 30 : 1th
# Optimal solution found!
# RUM L1 Norm Loss = 28.63652376695072
# testing instance with offertimes 30 : 2th
# Optimal solution found!
# RUM L1 Norm Loss = 23.544631860556596
# testing instance with offertimes 30 : 3th
# Optimal solution found!
# RUM L1 Norm Loss = 24.16249755975432
# testing instance with offertimes 30 : 4th
# Optimal solution found!
# RUM L1 Norm Loss = 10.87111482929524
# testing instance with offertimes 30 : 5th
# Optimal solution found!
# RUM L1 Norm Loss = 37.49131953035196
# testing instance with offertimes 30 : 6th
# Optimal solution found!
# RUM L1 Norm Loss = 15.88743496029937
# testing instance with offertimes 30 : 7th
# Optimal solution found!
# RUM L1 Norm Loss = 17.954154521808942
# testing instance with offertimes 30 : 8th
# Optimal solution found!
# RUM L1 Norm Loss = 35.689687098148276
# testing instance with offertimes 30 : 9th
# Optimal solution found!
# RUM L1 Norm Loss = 26.122447003665275
# testing instance with offertimes 30 : 10th
# Optimal solution found!
# RUM L1 Norm Loss = 17.728928095618095
# testing instance with offertimes 30 : 11th
# Optimal solution found!
# RUM L1 Norm Loss = 34.00122188209049
# testing instance with offertimes 30 : 12th
# Optimal solution found!
# RUM L1 Norm Loss = 21.035125834806607
# testing instance with offertimes 30 : 13th
# Optimal solution found!
# RUM L1 Norm Loss = 22.1291858958205
# testing instance with offertimes 30 : 14th
# Optimal solution found!
# RUM L1 Norm Loss = 18.69344358412985
# testing instance with offertimes 30 : 15th
# Optimal solution found!
# RUM L1 Norm Loss = 25.134001325654065
# testing instance with offertimes 30 : 16th
# Optimal solution found!
# RUM L1 Norm Loss = 28.81966818638065
# testing instance with offertimes 30 : 17th
# Optimal solution found!
# RUM L1 Norm Loss = 30.21009911873572
# testing instance with offertimes 30 : 18th
# Optimal solution found!
# RUM L1 Norm Loss = 20.775982342750762
# testing instance with offertimes 30 : 19th
# Optimal solution found!
# RUM L1 Norm Loss = 19.138986325538063
# testing instance with offertimes 30 : 20th
# Optimal solution found!
# RUM L1 Norm Loss = 14.058202026798915
# testing instance with offertimes 30 : 21th
# Optimal solution found!
# RUM L1 Norm Loss = 16.931527540126783
# testing instance with offertimes 30 : 22th
# Optimal solution found!
# RUM L1 Norm Loss = 17.930237892241365
# testing instance with offertimes 30 : 23th
# Optimal solution found!
# RUM L1 Norm Loss = 19.53294027938876
# testing instance with offertimes 30 : 24th
# Optimal solution found!
# RUM L1 Norm Loss = 21.146083707833082
# testing instance with offertimes 30 : 25th
# Optimal solution found!
# RUM L1 Norm Loss = 21.4753700157163
# testing instance with offertimes 30 : 26th
# Optimal solution found!
# RUM L1 Norm Loss = 16.338152781747375
# testing instance with offertimes 30 : 27th
# Optimal solution found!
# RUM L1 Norm Loss = 20.06271517870771
# testing instance with offertimes 30 : 28th
# Optimal solution found!
# RUM L1 Norm Loss = 24.911885210540916
# testing instance with offertimes 30 : 29th
# Optimal solution found!
# RUM L1 Norm Loss = 31.375197383632116
# testing instance with offertimes 30 : 30th
# Optimal solution found!
# RUM L1 Norm Loss = 12.364920805712142
# testing instance with offertimes 30 : 31th
# Optimal solution found!
# RUM L1 Norm Loss = 24.578135041137106
# testing instance with offertimes 30 : 32th
# Optimal solution found!
# RUM L1 Norm Loss = 23.417459050617627
# testing instance with offertimes 30 : 33th
# Optimal solution found!
# RUM L1 Norm Loss = 17.15316424535059
# testing instance with offertimes 30 : 34th
# Optimal solution found!
# RUM L1 Norm Loss = 21.080738012561877
# testing instance with offertimes 30 : 35th
# Optimal solution found!
# RUM L1 Norm Loss = 25.322119105748058
# testing instance with offertimes 30 : 36th
# Optimal solution found!
# RUM L1 Norm Loss = 12.965152092417355
# testing instance with offertimes 30 : 37th
# Optimal solution found!
# RUM L1 Norm Loss = 13.659354747868868
# testing instance with offertimes 30 : 38th
# Optimal solution found!
# RUM L1 Norm Loss = 11.708277823443256
# testing instance with offertimes 30 : 39th
# Optimal solution found!
# RUM L1 Norm Loss = 22.155482893558766
# testing instance with offertimes 30 : 40th
# Optimal solution found!
# RUM L1 Norm Loss = 17.858685544144453
# testing instance with offertimes 30 : 41th
# Optimal solution found!
# RUM L1 Norm Loss = 18.386821669748063
# testing instance with offertimes 30 : 42th
# Optimal solution found!
# RUM L1 Norm Loss = 27.07311856413392
# testing instance with offertimes 30 : 43th
# Optimal solution found!
# RUM L1 Norm Loss = 28.757641812264186
# testing instance with offertimes 30 : 44th
# Optimal solution found!
# RUM L1 Norm Loss = 17.31380369454216
# testing instance with offertimes 30 : 45th
# Optimal solution found!
# RUM L1 Norm Loss = 29.271192520697713
# testing instance with offertimes 30 : 46th
# Optimal solution found!
# RUM L1 Norm Loss = 31.67091033443219
# testing instance with offertimes 30 : 47th
# Optimal solution found!
# RUM L1 Norm Loss = 33.27173522474444
# testing instance with offertimes 30 : 48th
# Optimal solution found!
# RUM L1 Norm Loss = 10.452845279518455
# testing instance with offertimes 30 : 49th
# Optimal solution found!
# RUM L1 Norm Loss = 19.94478020730042
# testing instance with offertimes 40 : 0th
# Optimal solution found!
# RUM L1 Norm Loss = 11.7661073181722
# testing instance with offertimes 40 : 1th
# Optimal solution found!
# RUM L1 Norm Loss = 18.274342539172945
# testing instance with offertimes 40 : 2th
# Optimal solution found!
# RUM L1 Norm Loss = 17.277743347160055
# testing instance with offertimes 40 : 3th
# Optimal solution found!
# RUM L1 Norm Loss = 14.97369289204509
# testing instance with offertimes 40 : 4th
# Optimal solution found!
# RUM L1 Norm Loss = 4.598203422778992
# testing instance with offertimes 40 : 5th
# Optimal solution found!
# RUM L1 Norm Loss = 28.278619134191196
# testing instance with offertimes 40 : 6th
# Optimal solution found!
# RUM L1 Norm Loss = 12.671408266490507
# testing instance with offertimes 40 : 7th
# Optimal solution found!
# RUM L1 Norm Loss = 10.433674373044036
# testing instance with offertimes 40 : 8th
# Optimal solution found!
# RUM L1 Norm Loss = 23.22927441872688
# testing instance with offertimes 40 : 9th
# Optimal solution found!
# RUM L1 Norm Loss = 17.204920534676035
# testing instance with offertimes 40 : 10th
# Optimal solution found!
# RUM L1 Norm Loss = 7.941453333307746
# testing instance with offertimes 40 : 11th
# Optimal solution found!
# RUM L1 Norm Loss = 31.415507560798556
# testing instance with offertimes 40 : 12th
# Optimal solution found!
# RUM L1 Norm Loss = 16.938203811802044
# testing instance with offertimes 40 : 13th
# Optimal solution found!
# RUM L1 Norm Loss = 13.95306327816511
# testing instance with offertimes 40 : 14th
# Optimal solution found!
# RUM L1 Norm Loss = 13.34336541240784
# testing instance with offertimes 40 : 15th
# Optimal solution found!
# RUM L1 Norm Loss = 17.466163376427424
# testing instance with offertimes 40 : 16th
# Optimal solution found!
# RUM L1 Norm Loss = 20.586573761613156
# testing instance with offertimes 40 : 17th
# Optimal solution found!
# RUM L1 Norm Loss = 20.61612471654104
# testing instance with offertimes 40 : 18th
# Optimal solution found!
# RUM L1 Norm Loss = 11.683608805570127
# testing instance with offertimes 40 : 19th
# Optimal solution found!
# RUM L1 Norm Loss = 10.73809945504044
# testing instance with offertimes 40 : 20th
# Optimal solution found!
# RUM L1 Norm Loss = 6.880598153949237
# testing instance with offertimes 40 : 21th
# Optimal solution found!
# RUM L1 Norm Loss = 12.569481999785346
# testing instance with offertimes 40 : 22th
# Optimal solution found!
# RUM L1 Norm Loss = 11.167707352904918
# testing instance with offertimes 40 : 23th
# Optimal solution found!
# RUM L1 Norm Loss = 11.999088487972227
# testing instance with offertimes 40 : 24th
# Optimal solution found!
# RUM L1 Norm Loss = 16.172101049228278
# testing instance with offertimes 40 : 25th
# Optimal solution found!
# RUM L1 Norm Loss = 12.940675264937765
# testing instance with offertimes 40 : 26th
# Optimal solution found!
# RUM L1 Norm Loss = 6.50160706989184
# testing instance with offertimes 40 : 27th
# Optimal solution found!
# RUM L1 Norm Loss = 13.706567049769063
# testing instance with offertimes 40 : 28th
# Optimal solution found!
# RUM L1 Norm Loss = 21.61591003998627
# testing instance with offertimes 40 : 29th
# Optimal solution found!
# RUM L1 Norm Loss = 18.771501502227075
# testing instance with offertimes 40 : 30th
# Optimal solution found!
# RUM L1 Norm Loss = 10.704951902336486
# testing instance with offertimes 40 : 31th
# Optimal solution found!
# RUM L1 Norm Loss = 17.806609284521954
# testing instance with offertimes 40 : 32th
# Optimal solution found!
# RUM L1 Norm Loss = 8.415078869928063
# testing instance with offertimes 40 : 33th
# Optimal solution found!
# RUM L1 Norm Loss = 12.033064102598052
# testing instance with offertimes 40 : 34th
# Optimal solution found!
# RUM L1 Norm Loss = 9.395690110515282
# testing instance with offertimes 40 : 35th
# Optimal solution found!
# RUM L1 Norm Loss = 18.841715054188885
# testing instance with offertimes 40 : 36th
# Optimal solution found!
# RUM L1 Norm Loss = 7.7815390352892155
# testing instance with offertimes 40 : 37th
# Optimal solution found!
# RUM L1 Norm Loss = 7.258741274542956
# testing instance with offertimes 40 : 38th
# Optimal solution found!
# RUM L1 Norm Loss = 5.093278590802004
# testing instance with offertimes 40 : 39th
# Optimal solution found!
# RUM L1 Norm Loss = 14.377033312252026
# testing instance with offertimes 40 : 40th
# Optimal solution found!
# RUM L1 Norm Loss = 13.932714306858513
# testing instance with offertimes 40 : 41th
# Optimal solution found!
# RUM L1 Norm Loss = 15.56695076848285
# testing instance with offertimes 40 : 42th
# Optimal solution found!
# RUM L1 Norm Loss = 21.61942904871828
# testing instance with offertimes 40 : 43th
# Optimal solution found!
# RUM L1 Norm Loss = 18.15036502587319
# testing instance with offertimes 40 : 44th
# Optimal solution found!
# RUM L1 Norm Loss = 13.916318383309044
# testing instance with offertimes 40 : 45th
# Optimal solution found!
# RUM L1 Norm Loss = 20.064005884732435
# testing instance with offertimes 40 : 46th
# Optimal solution found!
# RUM L1 Norm Loss = 21.31586583449484
# testing instance with offertimes 40 : 47th
# Optimal solution found!
# RUM L1 Norm Loss = 26.041376633409644
# testing instance with offertimes 40 : 48th
# Optimal solution found!
# RUM L1 Norm Loss = 2.320079830553451
# testing instance with offertimes 40 : 49th
# Optimal solution found!
# RUM L1 Norm Loss = 8.844725220962502
# testing instance with offertimes 50 : 0th
# Optimal solution found!
# RUM L1 Norm Loss = 4.9360435600386205
# testing instance with offertimes 50 : 1th
# Optimal solution found!
# RUM L1 Norm Loss = 5.468018169289759
# testing instance with offertimes 50 : 2th
# Optimal solution found!
# RUM L1 Norm Loss = 7.54205173819796
# testing instance with offertimes 50 : 3th
# Optimal solution found!
# RUM L1 Norm Loss = 9.927271177972552
# testing instance with offertimes 50 : 4th
# Optimal solution found!
# RUM L1 Norm Loss = 1.5445480717408815
# testing instance with offertimes 50 : 5th
# Optimal solution found!
# RUM L1 Norm Loss = 22.700912515261635
# testing instance with offertimes 50 : 6th
# Optimal solution found!
# RUM L1 Norm Loss = 8.319925468368291
# testing instance with offertimes 50 : 7th
# Optimal solution found!
# RUM L1 Norm Loss = 3.1586608229085407
# testing instance with offertimes 50 : 8th
# Optimal solution found!
# RUM L1 Norm Loss = 16.942935667556934
# testing instance with offertimes 50 : 9th
# Optimal solution found!
# RUM L1 Norm Loss = 8.2496160905319
# testing instance with offertimes 50 : 10th
# Optimal solution found!
# RUM L1 Norm Loss = 4.525073200917654
# testing instance with offertimes 50 : 11th
# Optimal solution found!
# RUM L1 Norm Loss = 25.35314597548364
# testing instance with offertimes 50 : 12th
# Optimal solution found!
# RUM L1 Norm Loss = 8.880007844326245
# testing instance with offertimes 50 : 13th
# Optimal solution found!
# RUM L1 Norm Loss = 6.132627929941704
# testing instance with offertimes 50 : 14th
# Optimal solution found!
# RUM L1 Norm Loss = 9.886447661809262
# testing instance with offertimes 50 : 15th
# Optimal solution found!
# RUM L1 Norm Loss = 11.086908424666758
# testing instance with offertimes 50 : 16th
# Optimal solution found!
# RUM L1 Norm Loss = 12.759638774217482
# testing instance with offertimes 50 : 17th
# Optimal solution found!
# RUM L1 Norm Loss = 18.30417654838207
# testing instance with offertimes 50 : 18th
# Optimal solution found!
# RUM L1 Norm Loss = 9.65926314771
# testing instance with offertimes 50 : 19th
# Optimal solution found!
# RUM L1 Norm Loss = 2.422149122807019
# testing instance with offertimes 50 : 20th
# Optimal solution found!
# RUM L1 Norm Loss = 5.631376572114517
# testing instance with offertimes 50 : 21th
# Optimal solution found!
# RUM L1 Norm Loss = 8.110426936943803
# testing instance with offertimes 50 : 22th
# Optimal solution found!
# RUM L1 Norm Loss = 7.958088253585818
# testing instance with offertimes 50 : 23th
# Optimal solution found!
# RUM L1 Norm Loss = 5.2832130730050935
# testing instance with offertimes 50 : 24th
# Optimal solution found!
# RUM L1 Norm Loss = 10.984770641400482
# testing instance with offertimes 50 : 25th
# Optimal solution found!
# RUM L1 Norm Loss = 3.3184089894641
# testing instance with offertimes 50 : 26th
# Optimal solution found!
# RUM L1 Norm Loss = 2.8622560409044433
# testing instance with offertimes 50 : 27th
# Optimal solution found!
# RUM L1 Norm Loss = 7.269541307534727
# testing instance with offertimes 50 : 28th
# Optimal solution found!
# RUM L1 Norm Loss = 9.869026867744394
# testing instance with offertimes 50 : 29th
# Optimal solution found!
# RUM L1 Norm Loss = 14.412328315276904
# testing instance with offertimes 50 : 30th
# Optimal solution found!
# RUM L1 Norm Loss = 2.4075643070557184
# testing instance with offertimes 50 : 31th
# Optimal solution found!
# RUM L1 Norm Loss = 12.947190849488042
# testing instance with offertimes 50 : 32th
# Optimal solution found!
# RUM L1 Norm Loss = 1.881629397227387
# testing instance with offertimes 50 : 33th
# Optimal solution found!
# RUM L1 Norm Loss = 4.868626511037576
# testing instance with offertimes 50 : 34th
# Optimal solution found!
# RUM L1 Norm Loss = 1.9815017944879163
# testing instance with offertimes 50 : 35th
# Optimal solution found!
# RUM L1 Norm Loss = 10.891447373077051
# testing instance with offertimes 50 : 36th
# Optimal solution found!
# RUM L1 Norm Loss = 0.831300575343712
# testing instance with offertimes 50 : 37th
# Optimal solution found!
# RUM L1 Norm Loss = 5.331308359013765
# testing instance with offertimes 50 : 38th
# Optimal solution found!
# RUM L1 Norm Loss = 1.2302631578947372
# testing instance with offertimes 50 : 39th
# Optimal solution found!
# RUM L1 Norm Loss = 6.1708066874338785
# testing instance with offertimes 50 : 40th
# Optimal solution found!
# RUM L1 Norm Loss = 8.926964860402803
# testing instance with offertimes 50 : 41th
# Optimal solution found!
# RUM L1 Norm Loss = 12.402830730223657
# testing instance with offertimes 50 : 42th
# Optimal solution found!
# RUM L1 Norm Loss = 14.50137231544472
# testing instance with offertimes 50 : 43th
# Optimal solution found!
# RUM L1 Norm Loss = 14.381660255451813
# testing instance with offertimes 50 : 44th
# Optimal solution found!
# RUM L1 Norm Loss = 3.356773869637152
# testing instance with offertimes 50 : 45th
# Optimal solution found!
# RUM L1 Norm Loss = 16.272799882253988
# testing instance with offertimes 50 : 46th
# Optimal solution found!
# RUM L1 Norm Loss = 10.402942276829473
# testing instance with offertimes 50 : 47th
# Optimal solution found!
# RUM L1 Norm Loss = 21.591740835309043
# testing instance with offertimes 50 : 48th
# Optimal solution found!
# RUM L1 Norm Loss = 0.07510903237045588
# testing instance with offertimes 50 : 49th
# Optimal solution found!
# RUM L1 Norm Loss = 5.332103485361067
# testing instance with offertimes 60 : 0th
# Optimal solution found!
# RUM L1 Norm Loss = 2.045628183361633
# testing instance with offertimes 60 : 1th
# Optimal solution found!
# RUM L1 Norm Loss = 1.4150870610313087
# testing instance with offertimes 60 : 2th
# Optimal solution found!
# RUM L1 Norm Loss = 3.6026875457944283
# testing instance with offertimes 60 : 3th
# Optimal solution found!
# RUM L1 Norm Loss = 7.354938792729184
# testing instance with offertimes 60 : 4th
# Optimal solution found!
# RUM L1 Norm Loss = 1.5445480717408842
# testing instance with offertimes 60 : 5th
# Optimal solution found!
# RUM L1 Norm Loss = 16.160019842403
# testing instance with offertimes 60 : 6th
# Optimal solution found!
# RUM L1 Norm Loss = 7.608301994323656
# testing instance with offertimes 60 : 7th
# Optimal solution found!
# RUM L1 Norm Loss = 0.0
# testing instance with offertimes 60 : 8th
# Optimal solution found!
# RUM L1 Norm Loss = 16.942935667556934
# testing instance with offertimes 60 : 9th
# Optimal solution found!
# RUM L1 Norm Loss = 7.407564314750984
# testing instance with offertimes 60 : 10th
# Optimal solution found!
# RUM L1 Norm Loss = 4.525073200917664
# testing instance with offertimes 60 : 11th
# Optimal solution found!
# RUM L1 Norm Loss = 19.171623601588678
# testing instance with offertimes 60 : 12th
# Optimal solution found!
# RUM L1 Norm Loss = 5.466496714839819
# testing instance with offertimes 60 : 13th
# Optimal solution found!
# RUM L1 Norm Loss = 4.929651285244843
# testing instance with offertimes 60 : 14th
# Optimal solution found!
# RUM L1 Norm Loss = 6.3772367193677715
# testing instance with offertimes 60 : 15th
# Optimal solution found!
# RUM L1 Norm Loss = 8.441335669248799
# testing instance with offertimes 60 : 16th
# Optimal solution found!
# RUM L1 Norm Loss = 10.321125508130079
# testing instance with offertimes 60 : 17th
# Optimal solution found!
# RUM L1 Norm Loss = 14.941927309790648
# testing instance with offertimes 60 : 18th
# Optimal solution found!
# RUM L1 Norm Loss = 5.3818675300239285
# testing instance with offertimes 60 : 19th
# Optimal solution found!
# RUM L1 Norm Loss = 0.0
# testing instance with offertimes 60 : 20th
# Optimal solution found!
# RUM L1 Norm Loss = 2.269374004720417
# testing instance with offertimes 60 : 21th
# Optimal solution found!
# RUM L1 Norm Loss = 0.12337555090013153
# testing instance with offertimes 60 : 22th
# Optimal solution found!
# RUM L1 Norm Loss = 3.3209579586128384
# testing instance with offertimes 60 : 23th
# Optimal solution found!
# RUM L1 Norm Loss = 0.7996604414261386
# testing instance with offertimes 60 : 24th
# Optimal solution found!
# RUM L1 Norm Loss = 8.779844048004414
# testing instance with offertimes 60 : 25th
# Optimal solution found!
# RUM L1 Norm Loss = 2.4713501659346955
# testing instance with offertimes 60 : 26th
# Optimal solution found!
# RUM L1 Norm Loss = 1.518465191231294
# testing instance with offertimes 60 : 27th
# Optimal solution found!
# RUM L1 Norm Loss = 6.101959608188322
# testing instance with offertimes 60 : 28th
# Optimal solution found!
# RUM L1 Norm Loss = 9.869026867744394
# testing instance with offertimes 60 : 29th
# Optimal solution found!
# RUM L1 Norm Loss = 14.412328315276895
# testing instance with offertimes 60 : 30th
# Optimal solution found!
# RUM L1 Norm Loss = 1.658725297767799
# testing instance with offertimes 60 : 31th
# Optimal solution found!
# RUM L1 Norm Loss = 12.262980323172256
# testing instance with offertimes 60 : 32th
# Optimal solution found!
# RUM L1 Norm Loss = 1.8816293972274074
# testing instance with offertimes 60 : 33th
# Optimal solution found!
# RUM L1 Norm Loss = 4.868626511037583
# testing instance with offertimes 60 : 34th
# Optimal solution found!
# RUM L1 Norm Loss = 0.12945736890784226
# testing instance with offertimes 60 : 35th
# Optimal solution found!
# RUM L1 Norm Loss = 5.197195483189745
# testing instance with offertimes 60 : 36th
# Optimal solution found!
# RUM L1 Norm Loss = 0.21498796060466907
# testing instance with offertimes 60 : 37th
# Optimal solution found!
# RUM L1 Norm Loss = 0.18049531028607768
# testing instance with offertimes 60 : 38th
# Optimal solution found!
# RUM L1 Norm Loss = 1.2302631578947372
# testing instance with offertimes 60 : 39th
# Optimal solution found!
# RUM L1 Norm Loss = 6.1708066874338785
# testing instance with offertimes 60 : 40th
# Optimal solution found!
# RUM L1 Norm Loss = 8.478225726710097
# testing instance with offertimes 60 : 41th
# Optimal solution found!
# RUM L1 Norm Loss = 8.424726071158476
# testing instance with offertimes 60 : 42th
# Optimal solution found!
# RUM L1 Norm Loss = 10.048229923053421
# testing instance with offertimes 60 : 43th
# Optimal solution found!
# RUM L1 Norm Loss = 6.381121381810615
# testing instance with offertimes 60 : 44th
# Optimal solution found!
# RUM L1 Norm Loss = 2.7715700512676964
# testing instance with offertimes 60 : 45th
# Optimal solution found!
# RUM L1 Norm Loss = 14.864195651087835
# testing instance with offertimes 60 : 46th
# Optimal solution found!
# RUM L1 Norm Loss = 2.815987659295689
# testing instance with offertimes 60 : 47th
# Optimal solution found!
# RUM L1 Norm Loss = 20.48513577351538
# testing instance with offertimes 60 : 48th
# Optimal solution found!
# RUM L1 Norm Loss = 0.0751090323704548
# testing instance with offertimes 60 : 49th
# Optimal solution found!
# RUM L1 Norm Loss = 1.767704683478315

# %%
## adding limit results
for i in range(len(pred_offer_times_list)):
    df_rum_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'rum_loss':all_rum_limit_loss[i], 'rum_limit_time':all_rum_limit_runtime[i]})
    df_rum_loss.to_csv('limit/rum/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
            df_limit_prob = pd.DataFrame(all_rum_limit_prob[i][j])
            df_limit_prob.to_csv('limit/rum/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
for i in range(len(pred_offer_times_list)):
    all_avg_loss.append(all_rum_limit_loss[i]/sum(all_full_offertimes[i]))

# %%
avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_rum_limit_runtime = []

#avg_loss = []
avg_loss_se = []

for i in range(len(pred_offer_times_list)):

    
    avg_total_limit_loss.append(np.mean(all_rum_limit_loss[i]))
    avg_rum_limit_runtime.append(np.sum(all_rum_limit_runtime[i]))
    avg_toal_limit_loss_se.append(np.std(all_rum_limit_loss[i])/np.sqrt(len(all_rum_limit_loss[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))

avg_loss = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))

df_rum_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'total_rum_loss':avg_total_limit_loss,'total_rum_loss_se':avg_toal_limit_loss_se,
                                   'avg_rum_loss':avg_loss,'avg_rum_loss_se':avg_loss_se,
                                   'avg_rum_limit_runtime':avg_rum_limit_runtime
                                   })
df_rum_limit.to_csv('limit/rum/rum_limit_summary.csv')
df_rum_limit
# Out:
#    offertimes  total_rum_loss  total_rum_loss_se  avg_rum_loss  \
# 0          20       29.321150           0.958511      0.003830
# 1          30       22.187164           0.938804      0.002947
# 2          40       14.583898           0.857137      0.001981
# 3          50        8.585696           0.820120      0.001194
# 4          60        6.064231           0.760626      0.000856
#
#    avg_rum_loss_se  avg_rum_limit_runtime
# 0         0.000125            5355.872401
# 1         0.000125            4331.737159
# 2         0.000116            3644.840216
# 3         0.000114            3108.806945
# 4         0.000107            2863.829743

# %%
all_rum_rep = []
avg_rep = []
for i in range(len(pred_offer_times_list)):
    rum_rep_collection = []

    for j in range(pred_instance_size[i]):
        if all_rum_limit_loss[i][j] <1e-6:
            rum_rep_collection.append(1)
        else:
            rum_rep_collection.append(0)
    all_rum_rep.append(rum_rep_collection)
    avg_rep.append(np.mean(rum_rep_collection))
    df_rum_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'rum_rep':rum_rep_collection})
    df_rum_rep.to_csv('limit/rum/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
avg_rep
# Out:
# [0.0, 0.0, 0.0, 0.0, 0.04]

# %%
df_rum_limit['rum_rep'] = avg_rep
df_rum_limit
# Out:
#    offertimes  total_rum_loss  total_rum_loss_se  avg_rum_loss  \
# 0          20       29.321150           0.958511      0.003830
# 1          30       22.187164           0.938804      0.002947
# 2          40       14.583898           0.857137      0.001981
# 3          50        8.585696           0.820120      0.001194
# 4          60        6.064231           0.760626      0.000856
#
#    avg_rum_loss_se  avg_rum_limit_runtime  rum_rep
# 0         0.000125            5355.872401     0.00
# 1         0.000125            4331.737159     0.00
# 2         0.000116            3644.840216     0.00
# 3         0.000114            3108.806945     0.00
# 4         0.000107            2863.829743     0.04

# %%
df_rum_limit.to_csv('limit/rum/rum_limit_summary.csv')

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.003830326580820491
# 0.0029468938505401933
# 0.001981238745287741
# 0.0011941162599873355
# 0.0008562879542958309
