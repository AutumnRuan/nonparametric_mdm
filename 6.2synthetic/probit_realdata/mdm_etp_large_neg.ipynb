# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def generate_negatively_correlated_covariance_matrix(n):
    # Generate a random correlation matrix with negative correlations
    correlation_matrix = np.random.uniform(low=-0.9, high=-0.1, size=(n, n))
    np.fill_diagonal(correlation_matrix, 1)  # Set diagonal elements to 1
    correlation_matrix = (correlation_matrix + correlation_matrix.T) / 2  # Ensure symmetry

    # Ensure the correlation matrix is valid for Cholesky decomposition
    cholesky_success = False
    while not cholesky_success:
        try:
            # Perform Cholesky decomposition
            cholesky_matrix = np.linalg.cholesky(correlation_matrix)
            cholesky_success = True
        except np.linalg.LinAlgError:
            # If Cholesky decomposition fails, adjust the correlation matrix slightly
            correlation_matrix += np.eye(n) * 0.01  # Adjust diagonal elements slightly

    # Generate random standard deviations
    #standard_deviations = np.random.uniform(0.5, 2, size=n)
    
    variance_outsideopt = np.random.uniform(30,40)
    variance_products = np.random.uniform(0.5,2,size=n-1)
    standard_deviations = np.hstack((variance_outsideopt,variance_products))
    # Construct diagonal matrix from standard deviations
    diagonal_matrix = np.diag(standard_deviations)
    #diagonal_matrix = np.eye(n)

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix

# %%
def is_positive_semidefinite(matrix):
    """
    Check if a matrix is positive semidefinite.
    
    Args:
        matrix (numpy.ndarray): The matrix to check.
        
    Returns:
        bool: True if the matrix is positive semidefinite, False otherwise.
    """
    # Check if the matrix is symmetric
    if not np.allclose(matrix, matrix.T):
        return False
    
    # Check if all eigenvalues are non-negative
    eigvals, _ = np.linalg.eig(matrix)
    return np.all(eigvals >= 0)

# %%
def collection_distribution_prob_neg(n,collection):
    # generate mean 
    #mu = np.random.uniform(-2,2,n)
    mu_0 = np.random.uniform(6,10)
    mu_1n = np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    # generate covariance matrix with positive correlation
    neg_cov = generate_negatively_correlated_covariance_matrix(n)
    if is_positive_semidefinite(neg_cov): 
        sample_size = 10000
        utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    else:
        print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 
        
        
        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_instance = collection_distribution_prob_neg(n,whole_collection)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-11:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(jd_collection,jd_offertimes)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-11:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:

            
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples) '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        ''' condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-3:
                    condition = True
        if condition == True:
            print('instance_generation error') '''
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm_feasibility')
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    lam_values = [lam[i].x for i in range(data.shape[1])]
    lam_values = np.array(lam_values)

    if (model.objVal> 0):
        #model.write("mdmfeas_out.sol")
        #model.write("mdmfeas_model.lp") 
        return [1,model.Runtime,lam_values]
    else:
        #model.write("mdminfeas_model.lp")
        #return [0, used_time]
        return [0,model.Runtime,lam_values]

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.001

    model = gp.Model('mdm_limit')
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{i}_{j}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}")

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    if model.Status == GRB.OPTIMAL:
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
        
        lam_values = [lam[i].x for i in range(m)]
        lam_values = np.array(lam_values)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print('mdm limit computation error')
        #model.write("mdmlimit_out.sol")
        #model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,x_values]

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
def robust_prediction_lp(lambda_S_lst,lambda_A,prod_in_ass,assortment_A,limit_prob,price):
    # robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
    
    model = gp.Model('robust_rev_lp')
    model.setParam('OutputFlag', 0)
    x = model.addVars(len(assortment_A),vtype=GRB.CONTINUOUS, lb=0, name='x')
    
    model.addConstr(gp.quicksum(x[i] for i in range(len(assortment_A))) == 1, name="Normalization")
    
    ## MDM consistency
    for i in range(len(assortment_A)):
        for j in range(len(prod_in_ass[assortment_A[i]])):
            if lambda_A >= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]<= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
            if lambda_A <= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]>= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
    
    # Objective
    obj = gp.quicksum(price[assortment_A[i]] * x[i] for i in range(len(assortment_A)))
    model.setObjective(obj, GRB.MINIMIZE)

    # Optimize the model
    model.optimize()
    
    if model.Status == GRB.OPTIMAL :
        return [model.objVal, [x[i].x for i in range(len(assortment_A))], model.Runtime]
    else:
        return [100000,[-1 for i in range(len(assortment_A))], model.Runtime]

# %%
def best_case_prediction_lp(lambda_S_lst,lambda_A,prod_in_ass,assortment_A,limit_prob,price):
    
    model = gp.Model('best_case_rev_lp')
    model.setParam('OutputFlag', 0)
    x = model.addVars(len(assortment_A),vtype=GRB.CONTINUOUS, lb=0, name='x')
    
    model.addConstr(gp.quicksum(x[i] for i in range(len(assortment_A))) == 1, name="Normalization")
    
    ## MDM consistency
    for i in range(len(assortment_A)):
        for j in range(len(prod_in_ass[assortment_A[i]])):
            if lambda_A >= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]<= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
            if lambda_A <= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]>= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
    
    # Objective
    obj = gp.quicksum(price[assortment_A[i]] * x[i] for i in range(len(assortment_A)))
    model.setObjective(obj, GRB.MAXIMIZE)

    # Optimize the model
    model.optimize()
    
    if model.Status == GRB.OPTIMAL :
        return [model.objVal, [x[i].x for i in range(len(assortment_A))], model.Runtime]
    else:
        return [-100000,[-1 for i in range(len(assortment_A))], model.Runtime]

# %%
## mdm milp for the worst case revenue
def mdm_revenue(curr_limit_prob, curr_lam, prod_in_ass,lambda_A_lst, assortment_A, price):
    
    robust_revenue_lst = []
    best_case_revenue_lst = []
    robust_pred_runtime = 0
    best_case_pred_runtime = 0
    #robust_prob_lst = []
    #best_case_prob_lst = []

    for j in range(len(lambda_A_lst)):
        lambda_A = lambda_A_lst[j]
        curr_robust_revenue,curr_robust_prob,curr_robust_runtime = robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
        
        robust_revenue_lst.append(curr_robust_revenue)
        robust_pred_runtime = robust_pred_runtime + curr_robust_runtime
        #robust_prob_lst.append(curr_robust_prob)
        
        curr_best_case_revenue,curr_bestcase_prob,curr_best_case_runtime = best_case_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
        best_case_revenue_lst.append(curr_best_case_revenue)
        best_case_pred_runtime = best_case_pred_runtime + curr_best_case_runtime
        #best_case_prob_lst.append(curr_bestcase_prob)
    
    robust_revenue_A = np.min(robust_revenue_lst)
    best_case_revenue_A = np.max(best_case_revenue_lst)
    
    ''' robust_prob_A = robust_prob_lst[np.argmin(robust_revenue_lst)]
    bestcase_prob_A = best_case_prob_lst[np.argmax(best_case_revenue_lst)] '''
    
    print(f'the robust revenue for assortment {assortment_A} is {robust_revenue_A} with runtime {robust_pred_runtime}')
    if robust_revenue_A>100:
        print('robust MDM prediction error ')
    print(f'the best-case revenue for assortment {assortment_A} is {best_case_revenue_A} with runtime {best_case_pred_runtime}\n')
    if best_case_revenue_A<0:
        print('best-case MDM prediction error ')
    
    ''' lb_sales_A = np.zeros(len(price))
    ub_sales_A = np.zeros(len(price))
    
    for k in range(len(assortment_A)):
        unit_price = np.zeros(n)
        unit_price[assortment_A[k]] = 1
        
        robust_product_prob_lst = []
        bestcase_product_prob_lst = []
        
        for j in range(len(lambda_A_lst)):
            if best_case_revenue_lst[j]>0:
                lambda_A = lambda_A_lst[j]
                curr_robust_prob = robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,unit_price)[0]
                
                robust_product_prob_lst.append(curr_robust_prob)
                
                curr_bestcase_prob = best_case_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,unit_price)[0]
                bestcase_product_prob_lst.append(curr_bestcase_prob)
        
        lb_sales_A[assortment_A[k]] = np.min(robust_product_prob_lst)
        ub_sales_A[assortment_A[k]] = np.max(bestcase_product_prob_lst)
        print(f'the sales lb for product {assortment_A[k]} in assortment {assortment_A} is {lb_sales_A[assortment_A[k]]}')
        print(f'the sales ub for product {assortment_A[k]} in assortment {assortment_A} is {ub_sales_A[assortment_A[k]]}\n')
     '''
    #return [robust_revenue_A,robust_pred_runtime,robust_prob_A,lb_sales_A, best_case_revenue_A,best_case_pred_runtime, bestcase_prob_A,ub_sales_A]
    return [robust_revenue_A,robust_pred_runtime, best_case_revenue_A,best_case_pred_runtime]

# %%
def mdm_prediction(curr_test_collection,curr_test_instance,price,curr_limit_prob, curr_lam, curr_train_collection):
    ''' true assortment ranking '''
    #true_choice_prob = [] 
    true_revenue = []
    
    ''' lb_mdm_rev_prob = []
    ub_mdm_rev_prob = []
    
    lb_mdm_sales = []
    ub_mdm_sales = [] '''
    
    lb_mdm_revenue = [] 
    ub_mdm_revenue = []
    
    lb_mdm_runtime = []
    ub_mdm_runtime = []
    
    prod_in_ass = [[] for _ in range(len(price))]
    for i, assort in enumerate(curr_train_collection):
        for j in assort:
            prod_in_ass[j].append(i)
    
    dec_lam = np.abs(np.sort(-curr_lam)) # multipliers in decreasing order, probabilities in increasing order
    lambda_A_lst = [np.max(curr_lam)+1]
    for i in range(len(dec_lam)-1):
        lambda_A_lst.append((dec_lam[i] + dec_lam[i+1])/2)
    lambda_A_lst.append(np.min(curr_lam)-1)
    
    for k in range(len(curr_test_collection)):
            
            assortment_A = curr_test_collection[k]
            
            # true revenue and true choice probabilities for current testing assortment
            curr_revenue = np.dot(curr_test_instance[:,k],price)
            true_revenue.append(curr_revenue)
            #true_choice_prob.append(curr_test_instance[:,k])
            
            # MDM revenue prediction
            print(f'revenue prediction for unseen assortment {assortment_A}')
            mdm_prediction_result = mdm_revenue(curr_limit_prob, curr_lam, prod_in_ass,lambda_A_lst, assortment_A, price)
            
            # return [robust_revenue_A,robust_pred_runtime, best_case_revenue_A,best_case_pred_runtime]
            
            ## record the revenue result
            lb_mdm_revenue.append(mdm_prediction_result[0])
            ub_mdm_revenue.append(mdm_prediction_result[2])
            
            ## record the choice probability result
            ''' lb_prob = np.zeros(n)
            lb_prob_result = mdm_prediction_result[2]
            
            ub_prob = np.zeros(n)
            ub_prob_result = mdm_prediction_result[6]
            
            for l in range(len(assortment_A)):
                lb_prob[assortment_A[l]] = lb_prob_result[l]
                ub_prob[assortment_A[l]] = ub_prob_result[l]
            
            lb_mdm_rev_prob.append(lb_prob)
            ub_mdm_rev_prob.append(ub_prob) '''
            
            ## record the runtime result
            lb_mdm_runtime.append(mdm_prediction_result[1])
            ub_mdm_runtime.append(mdm_prediction_result[3])
            
            
            ## MDM choice probability interval prediction
            ''' lb_sales_frac = mdm_prediction_result[3]
            ub_sales_frac = mdm_prediction_result[-1] '''
            
            ''' lb_mdm_sales.append(lb_sales_frac)
            ub_mdm_sales.append(ub_sales_frac) '''
    return true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime       
    #return true_choice_prob,true_revenue,lb_mdm_rev_prob,ub_mdm_rev_prob,lb_mdm_sales,ub_mdm_sales,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime

# %%
## record representability of all instances
''' all_mdm_rep = []
all_mdm_rep_time = [] '''

## record the limit loss of all instances
''' all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_runtime = [] '''

## record the kendall tau distance between the predicted ranking of MDM and the truth
all_mdm_lb_distance_list = []  
all_mdm_ub_distance_list = []

## record the true revenue of the predicted best assortment
all_best_true_revenue_list = []
all_best_revenue_mdm_lb = []  
all_best_revenue_mdm_ub =[]

## record the difference in best assortment
all_mdm_lb_best_rev_diff = []
all_mdm_ub_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mdm_lb_revenue_list = []
all_mdm_ub_revenue_list = []

## choice probability under the revenue prediction 
''' all_true_choice_prob_list = [] 
all_mdm_lb_rev_prob_list = []
all_mdm_ub_rev_prob_list = []

all_mdm_lb_sales_list = []
all_mdm_ub_sales_list = [] '''

all_true_ranking = []
all_mdm_lb_ranking = []
all_mdm_ub_ranking = []

## record the runtime of MDM prediction
all_mdm_rev_lb_runtime = []
all_mdm_rev_ub_runtime = []

for i in range(len(all_full_collections)):
    ## define container for mdm representability check
    ''' mdm_rep_collection =[]
    mdm_rep_runtime_collection =[] '''
    
    ## define container for mdm limit 
    ''' mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[] '''
    
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mdm_lb_best_rev_collection = [] # a container for the best revenue predicted by robust MDM
    mdm_ub_best_rev_collection = [] # a container for the best revenue predicted by best-case MDM
    
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mdm_lb_ranking_collection = [] # a container for ranking by robust mdm
    mdm_ub_ranking_collection = [] # a container for ranking by best-case mdm
    
    mdm_lb_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mdm
    mdm_ub_distance_collection = [] # kendall tau distance between true ranking and the ranking by best-case mdm
    
    ''' true_choice_prob_collection = []
    mdm_lb_rev_prob_collection = []
    mdm_ub_rev_prob_collection = []
    mdm_lb_sales_frac_collection = []
    mdm_ub_sales_frac_collection = [] '''
    
    true_revenue_collection = []
    mdm_lb_revenue_collection = []
    mdm_ub_revenue_collection = []
    
    mdm_lb_runtime_collection = []
    mdm_ub_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')

        # the following lists are of the same size as number of testing assortments
        
        row_data = row_assortment_data(all_train_instances[i][j],all_train_collection[i][j])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_train_instances[i][j],rank,equal)
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        ''' mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_runtime_collection.append(curr_rep_result[1]) '''
        
                # check if representable
        if curr_rep_result[0] > 0:
            # representable and then do prediction 
            # mdm_prediction(curr_test_instance,curr_test_collection,price,curr_train_instance,curr_train_collection,curr_train_perm_collection,unseen_assortment_perm_collection) mdm_prediction(curr_test_collection,curr_test_instance,price,curr_limit_prob, curr_lam, curr_train_collection)
            true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime = mdm_prediction(all_test_collection[i][j],all_test_instance[i][j],price,all_train_instances[i][j],curr_rep_result[-1], all_train_collection[i][j])
            #return true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime 
            ## just keeping the same length as other lists
            ''' mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(0)
            mdm_limit_probability_collection.append(all_train_instances[i][j]) '''
        else:
            #produts_notin_collection = find_product_notin_assortment(all_train_collection[i][j],n)
            # mdm_limit(data, collection,offer_times)
            curr_limit_result = mdm_limit(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            
            curr_limit_prob = curr_limit_result[-1]
            ''' mdm_limit_probability_collection.append(curr_limit_prob)
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_runtime_collection.append(curr_limit_result[1]) '''
            
            curr_lam = curr_limit_result[2]
            curr_loss = curr_limit_result[0]
            #feasbile_mdm_limit_prob_result = feas_limit_mdm_prob(curr_limit_prob,all_train_collection[i][j],curr_lam,0.01,curr_loss,all_train_instances[i][j],all_train_offertimes[i][j])
            #feasbile_mdm_limit_prob = feasbile_mdm_limit_prob_result[0]
            ## test if feasbile_mdm_limit_prob is feasible
            
            
            true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime = mdm_prediction(all_test_collection[i][j],all_test_instance[i][j],price,curr_limit_prob,curr_lam, all_train_collection[i][j])
            
        true_revenue_collection.append(true_revenue)
        #true_choice_prob_collection.append(true_choice_prob)
        
        mdm_lb_revenue_collection.append(lb_mdm_revenue)   
        mdm_ub_revenue_collection.append(ub_mdm_revenue)
        ''' mdm_lb_rev_prob_collection.append(lb_mdm_rev_prob)
        mdm_ub_rev_prob_collection.append(ub_mdm_rev_prob) '''
        
        mdm_lb_runtime_collection.append(lb_mdm_runtime)
        mdm_ub_runtime_collection.append(ub_mdm_runtime)
        
        ## sales fraction record
        ''' mdm_lb_sales_frac_collection.append(lb_mdm_sales)
        mdm_ub_sales_frac_collection.append(ub_mdm_sales) '''
        
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_mdm_lb_rank  = np.argsort(-np.array(lb_mdm_revenue)) 
        mdm_lb_ranking_collection.append(curr_mdm_lb_rank)
        mdm_lb_best_rev_collection.append(true_revenue[curr_mdm_lb_rank[0]])
        
        # ub mdm assortment ranking for test instance [i][j]
        curr_mdm_ub_rank = np.argsort(-np.array(ub_mdm_revenue)) 
        mdm_ub_ranking_collection.append(curr_mdm_ub_rank)
        mdm_ub_best_rev_collection.append(true_revenue[curr_mdm_ub_rank[0]])
        
        #  MDM kendallTau Distance for current instance [i][j]
        curr_mdm_lb_dist = kendall_tau_distance(curr_true_rank, curr_mdm_lb_rank)
        mdm_lb_distance_collection.append(curr_mdm_lb_dist)
        
        curr_mdm_ub_dist = kendall_tau_distance(curr_true_rank, curr_mdm_ub_rank)
        mdm_ub_distance_collection.append(curr_mdm_ub_dist)
    
    ## for each train instance [i][j] representability result is a number
    ''' all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_runtime_collection)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection) '''
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mdm_lb_distance_list.append(mdm_lb_distance_collection)
    all_mdm_ub_distance_list.append(mdm_ub_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_revenue_list.append(true_best_rev_collection) 
    all_best_revenue_mdm_lb.append(mdm_lb_best_rev_collection)
    all_best_revenue_mdm_ub.append(mdm_ub_best_rev_collection)

    # for each test instance [i][j] best revenue difference is a number
    with np.errstate(divide='ignore', invalid='ignore'):
        result = (np.array(true_best_rev_collection) - np.array(mdm_lb_best_rev_collection))/ np.array(true_best_rev_collection)
        # Replace NaN values (0/0) with 0 values with a large number or zero
        result = np.where(np.isnan(result), 0.0, result)
        result = np.where(np.isinf(result), 0.0, result)
        
    all_mdm_lb_best_rev_diff.append(result)
    
    with np.errstate(divide='ignore', invalid='ignore'):
        result2 = (np.array(true_best_rev_collection) - np.array(mdm_ub_best_rev_collection))/np.array(true_best_rev_collection)
        # Replace NaN values (0/0) with 0 values with a large number or zero
        result2 = np.where(np.isnan(result), 0.0, result2)
        result2 = np.where(np.isinf(result), 0.0, result2)
    
    # for each test instance [i][j] best revenue difference is a number
    
    all_mdm_ub_best_rev_diff.append(result2)
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    #all_true_choice_prob_list.append(true_choice_prob_collection)
    all_mdm_lb_revenue_list.append(mdm_lb_revenue_collection)
    all_mdm_ub_revenue_list.append(mdm_ub_revenue_collection)
    ''' all_mdm_lb_rev_prob_list.append(mdm_lb_rev_prob_collection)
    all_mdm_ub_rev_prob_list.append(mdm_ub_rev_prob_collection)
    
    all_mdm_lb_sales_list.append(mdm_lb_sales_frac_collection)
    all_mdm_ub_sales_list.append(mdm_ub_sales_frac_collection) '''
    
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mdm_lb_ranking.append(mdm_lb_ranking_collection)
    all_mdm_ub_ranking.append(mdm_ub_ranking_collection)
    
    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mdm_rev_lb_runtime.append(mdm_lb_runtime_collection)
    all_mdm_rev_ub_runtime.append(mdm_ub_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.35730434782608694 with runtime 0.001077413558959961
# the best-case revenue for assortment [0, 5] is 0.35730434782608694 with runtime 0.0008151531219482422
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.12233366495507056 with runtime 0.0012450218200683594
# the best-case revenue for assortment [0, 3, 7] is 0.1299390243902439 with runtime 0.0011589527130126953
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.276619847432696 with runtime 0.0010340213775634766
# the best-case revenue for assortment [0, 5, 6] is 0.276619847432696 with runtime 0.0010428428649902344
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.35730434782608694 with runtime 0.0010311603546142578
# the best-case revenue for assortment [0, 5, 8] is 0.35730434782608694 with runtime 0.0010480880737304688
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.15348914218084966 with runtime 0.0012555122375488281
# the best-case revenue for assortment [0, 6, 8] is 0.28220651476251624 with runtime 0.0012004375457763672
#
# testing for offertimes 20, 1th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.1017235772357724 with runtime 0.001631021499633789
# the best-case revenue for assortment [0, 3] is 0.1324354838709678 with runtime 0.001486063003540039
#
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.24489057245383006 with runtime 0.0011878013610839844
# the best-case revenue for assortment [0, 4] is 0.48542283051834595 with runtime 0.0011343955993652344
#
# revenue prediction for unseen assortment [0, 1, 4]
# the robust revenue for assortment [0, 1, 4] is 0.3597049291288429 with runtime 0.0017380714416503906
# the best-case revenue for assortment [0, 1, 4] is 0.413937587657784 with runtime 0.001936197280883789
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.21249372375591918 with runtime 0.002347707748413086
# the best-case revenue for assortment [0, 3, 4] is 0.23187608182533453 with runtime 0.0025894641876220703
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2960322580645162 with runtime 0.0021359920501708984
# the best-case revenue for assortment [0, 5, 6] is 0.29603225806451633 with runtime 0.0020096302032470703
#
# testing for offertimes 20, 2th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.4927129008711445 with runtime 0.0015079975128173828
# the best-case revenue for assortment [0, 1, 8] is 0.5342884250474389 with runtime 0.0014624595642089844
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.16048030018761728 with runtime 0.003004789352416992
# the best-case revenue for assortment [0, 2, 6] is 0.16271004766973682 with runtime 0.002613544464111328
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.3243622437173145 with runtime 0.002238035202026367
# the best-case revenue for assortment [0, 3, 4] is 0.3243622437173145 with runtime 0.002237558364868164
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.47799323352474477 with runtime 0.003706693649291992
# the best-case revenue for assortment [0, 4, 5] is 0.5102959688989683 with runtime 0.003276348114013672
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.49912523719165136 with runtime 0.0016360282897949219
# the best-case revenue for assortment [0, 5, 8] is 0.5540073510127894 with runtime 0.0016558170318603516
#
# testing for offertimes 20, 3th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.14278724905382037 with runtime 0.0011487007141113281
# the best-case revenue for assortment [0, 1] is 0.14458333333333326 with runtime 0.001001119613647461
#
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.3629017266983816 with runtime 0.001489400863647461
# the best-case revenue for assortment [0, 4] is 0.3629017266983816 with runtime 0.0013759136199951172
#
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.0011559812365740986 with runtime 0.001444101333618164
# the best-case revenue for assortment [0, 7] is 0.09305555555555553 with runtime 0.001356363296508789
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.39982054659121524 with runtime 0.0015349388122558594
# the best-case revenue for assortment [0, 3, 4] is 0.39982054659121524 with runtime 0.0015685558319091797
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.46121212121212124 with runtime 0.0013654232025146484
# the best-case revenue for assortment [0, 8] is 0.477044776119403 with runtime 0.0013637542724609375
#
# testing for offertimes 20, 4th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.4275473661533851 with runtime 0.0014128684997558594
# the best-case revenue for assortment [0, 1, 8] is 0.5034987702398033 with runtime 0.0014412403106689453
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.15839837398373985 with runtime 0.0017495155334472656
# the best-case revenue for assortment [0, 2, 3, 6] is 0.22972269469405218 with runtime 0.0017440319061279297
#
# revenue prediction for unseen assortment [0, 3, 8]
# the robust revenue for assortment [0, 3, 8] is 0.20335191637630673 with runtime 0.001538991928100586
# the best-case revenue for assortment [0, 3, 8] is 0.39691329471454856 with runtime 0.0013484954833984375
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.16473587939698492 with runtime 0.0013744831085205078
# the best-case revenue for assortment [0, 5, 6] is 0.25829170731707324 with runtime 0.001287221908569336
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.15213000677523936 with runtime 0.0015099048614501953
# the best-case revenue for assortment [0, 6, 7] is 0.18638458819370804 with runtime 0.0014472007751464844
#
# testing for offertimes 20, 5th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.22630434782608702 with runtime 0.0013575553894042969
# the best-case revenue for assortment [0, 1] is 0.3086016307513104 with runtime 0.0010251998901367188
#
# revenue prediction for unseen assortment [0, 1, 4]
# the robust revenue for assortment [0, 1, 4] is 0.4534785314768962 with runtime 0.0013124942779541016
# the best-case revenue for assortment [0, 1, 4] is 0.4534785314768962 with runtime 0.0012271404266357422
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.17680762315853854 with runtime 0.0014951229095458984
# the best-case revenue for assortment [0, 2, 6] is 0.19436474666723322 with runtime 0.0015823841094970703
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.43945076062964544 with runtime 0.001373291015625
# the best-case revenue for assortment [0, 4, 7] is 0.43945076062964544 with runtime 0.00138092041015625
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.3107616294249365 with runtime 0.0015022754669189453
# the best-case revenue for assortment [0, 5, 6] is 0.3107616294249365 with runtime 0.0014202594757080078
#
# testing for offertimes 20, 6th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.38988235294117646 with runtime 0.0015094280242919922
# the best-case revenue for assortment [0, 4] is 0.5128809523809524 with runtime 0.001451730728149414
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.16989130434782604 with runtime 0.0016510486602783203
# the best-case revenue for assortment [0, 1, 3] is 0.23583333333333334 with runtime 0.0016226768493652344
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.141733893557423 with runtime 0.0016252994537353516
# the best-case revenue for assortment [0, 3, 7] is 0.17005653766523332 with runtime 0.0016131401062011719
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.6620203200483092 with runtime 0.0009963512420654297
# the best-case revenue for assortment [0, 4, 8] is 0.7328740559090399 with runtime 0.0009963512420654297
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.5133335411865995 with runtime 0.0012552738189697266
# the best-case revenue for assortment [0, 5, 8] is 0.5635340758278173 with runtime 0.00116729736328125
#
# testing for offertimes 20, 7th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.14086812763616346 with runtime 0.0012788772583007812
# the best-case revenue for assortment [0, 1] is 0.19828571428571426 with runtime 0.0009813308715820312
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.2122085542396216 with runtime 0.0010764598846435547
# the best-case revenue for assortment [0, 1, 6] is 0.21220855423962148 with runtime 0.001089334487915039
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.13109347996857804 with runtime 0.0011150836944580078
# the best-case revenue for assortment [0, 3, 6] is 0.1310934799685781 with runtime 0.0012340545654296875
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.3144600182362902 with runtime 0.0011603832244873047
# the best-case revenue for assortment [0, 4, 5] is 0.35580915418627873 with runtime 0.0011320114135742188
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.3805 with runtime 0.0013425350189208984
# the best-case revenue for assortment [0, 8] is 0.39910222222222225 with runtime 0.0013093948364257812
#
# testing for offertimes 20, 8th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.22095947126939045 with runtime 0.0014264583587646484
# the best-case revenue for assortment [0, 1] is 0.2941956521739132 with runtime 0.0014748573303222656
#
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.18611111111111114 with runtime 0.0013260841369628906
# the best-case revenue for assortment [0, 7] is 0.234321493527062 with runtime 0.0014319419860839844
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.41290479652285106 with runtime 0.001430511474609375
# the best-case revenue for assortment [0, 1, 8] is 0.42598508947207486 with runtime 0.0010142326354980469
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.27344615526922883 with runtime 0.0012822151184082031
# the best-case revenue for assortment [0, 4, 6] is 0.2734461552692288 with runtime 0.0012001991271972656
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.35946733668341707 with runtime 0.0012812614440917969
# the best-case revenue for assortment [0, 8] is 0.46654271356783905 with runtime 0.0011370182037353516
#
# testing for offertimes 20, 9th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.2891666666666667 with runtime 0.0016849040985107422
# the best-case revenue for assortment [0, 1] is 0.31808333333333333 with runtime 0.0013327598571777344
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.26933333333333337 with runtime 0.0016243457794189453
# the best-case revenue for assortment [0, 1, 3] is 0.31636285282043264 with runtime 0.0015180110931396484
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.14582538179127022 with runtime 0.0012240409851074219
# the best-case revenue for assortment [0, 2, 3, 6] is 0.14703236504339745 with runtime 0.0011730194091796875
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.2627405672523141 with runtime 0.0013616085052490234
# the best-case revenue for assortment [0, 3, 5] is 0.3458082365094656 with runtime 0.0012505054473876953
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4909921010483401 with runtime 0.0013225078582763672
# the best-case revenue for assortment [0, 4, 8] is 0.49391766637497336 with runtime 0.001283407211303711
#
# testing for offertimes 20, 10th instance
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.21018264381304305 with runtime 0.0016257762908935547
# the best-case revenue for assortment [0, 1, 3] is 0.21971160991548505 with runtime 0.0014963150024414062
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15943101736972648 with runtime 0.0012443065643310547
# the best-case revenue for assortment [0, 2, 6] is 0.1857387096774194 with runtime 0.0012171268463134766
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.3217938363544477 with runtime 0.0015330314636230469
# the best-case revenue for assortment [0, 3, 4] is 0.4015796289137981 with runtime 0.0013289451599121094
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.12914598001696184 with runtime 0.0013470649719238281
# the best-case revenue for assortment [0, 3, 6] is 0.13474937124938527 with runtime 0.0010776519775390625
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.19162432546087155 with runtime 0.0015990734100341797
# the best-case revenue for assortment [0, 5, 6] is 0.23740320832498993 with runtime 0.0014965534210205078
#
# testing for offertimes 20, 11th instance
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.10179088054816227 with runtime 0.0019059181213378906
# the best-case revenue for assortment [0, 1, 3] is 0.18832527471016458 with runtime 0.0014300346374511719
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.17535425411190117 with runtime 0.0014657974243164062
# the best-case revenue for assortment [0, 1, 7] is 0.19002908299421664 with runtime 0.0014193058013916016
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.1091175184933858 with runtime 0.0019638538360595703
# the best-case revenue for assortment [0, 2, 6] is 0.14853340269299659 with runtime 0.0019495487213134766
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.4595490196078431 with runtime 0.0013518333435058594
# the best-case revenue for assortment [0, 4, 6] is 0.48845026184386797 with runtime 0.0012617111206054688
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2082725681417848 with runtime 0.0012710094451904297
# the best-case revenue for assortment [0, 5, 6] is 0.22895082912108727 with runtime 0.0012176036834716797
#
# testing for offertimes 20, 12th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.14271774193548384 with runtime 0.001756429672241211
# the best-case revenue for assortment [0, 1] is 0.3079953407105416 with runtime 0.0013022422790527344
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.346759574052364 with runtime 0.0014111995697021484
# the best-case revenue for assortment [0, 1, 5] is 0.37440920398009936 with runtime 0.0016894340515136719
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.15067804878048782 with runtime 0.001974344253540039
# the best-case revenue for assortment [0, 2, 3, 6] is 0.24241340718013146 with runtime 0.0016951560974121094
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.15067804878048782 with runtime 0.0016989707946777344
# the best-case revenue for assortment [0, 3, 6] is 0.18085090718013147 with runtime 0.0016863346099853516
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.21564062500000003 with runtime 0.0012714862823486328
# the best-case revenue for assortment [0, 6, 7] is 0.21564062500000003 with runtime 0.0013513565063476562
#
# testing for offertimes 20, 13th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.35861642512077274 with runtime 0.0016179084777832031
# the best-case revenue for assortment [0, 4] is 0.47868888888888883 with runtime 0.001359701156616211
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.05366702037351445 with runtime 0.0012044906616210938
# the best-case revenue for assortment [0, 6] is 0.12177560975609758 with runtime 0.001298666000366211
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.4274275447270503 with runtime 0.0017502307891845703
# the best-case revenue for assortment [0, 4, 5] is 0.46253731343283605 with runtime 0.0019669532775878906
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.519072463768116 with runtime 0.001870870590209961
# the best-case revenue for assortment [0, 4, 8] is 0.5498905396547957 with runtime 0.0017132759094238281
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.3886771363893605 with runtime 0.0011789798736572266
# the best-case revenue for assortment [0, 6, 8] is 0.4313913043478258 with runtime 0.0010864734649658203
#
# testing for offertimes 20, 14th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.11460032032615025 with runtime 0.0014977455139160156
# the best-case revenue for assortment [0, 4] is 0.5288503203261503 with runtime 0.0016140937805175781
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.3991422726862375 with runtime 0.00208282470703125
# the best-case revenue for assortment [0, 1, 5] is 0.474058566557257 with runtime 0.002248525619506836
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.3046768292682926 with runtime 0.0015118122100830078
# the best-case revenue for assortment [0, 1, 6] is 0.4111533366094352 with runtime 0.0013988018035888672
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4295932186015858 with runtime 0.0015676021575927734
# the best-case revenue for assortment [0, 4, 8] is 0.5009107399929151 with runtime 0.0014984607696533203
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.31499289827543553 with runtime 0.0013549327850341797
# the best-case revenue for assortment [0, 8] is 0.48576354105998837 with runtime 0.001332998275756836
#
# testing for offertimes 20, 15th instance
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.16997853987982206 with runtime 0.0016896724700927734
# the best-case revenue for assortment [0, 2, 3, 6] is 0.170671875 with runtime 0.0012359619140625
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.12411752013798491 with runtime 0.0010755062103271484
# the best-case revenue for assortment [0, 3, 5] is 0.17605370496156986 with runtime 0.001169443130493164
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.45195407774374124 with runtime 0.0014863014221191406
# the best-case revenue for assortment [0, 4, 7] is 0.5744266666666666 with runtime 0.0013012886047363281
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.5666266666666666 with runtime 0.0014126300811767578
# the best-case revenue for assortment [0, 4, 8] is 0.6014279886071887 with runtime 0.0013654232025146484
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.1826674288617887 with runtime 0.001031637191772461
# the best-case revenue for assortment [0, 6, 7] is 0.1913913871952314 with runtime 0.0010516643524169922
#
# testing for offertimes 20, 16th instance
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.13961994055424434 with runtime 0.0016410350799560547
# the best-case revenue for assortment [0, 7] is 0.20472222222222225 with runtime 0.0013799667358398438
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.3458743781094527 with runtime 0.0015616416931152344
# the best-case revenue for assortment [0, 1, 5] is 0.3822042483946038 with runtime 0.0014967918395996094
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.17849024390243903 with runtime 0.001405477523803711
# the best-case revenue for assortment [0, 3, 7] is 0.19217317073170728 with runtime 0.0013709068298339844
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.3936844739716055 with runtime 0.0015783309936523438
# the best-case revenue for assortment [0, 4, 6] is 0.3936844739716055 with runtime 0.0016946792602539062
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.24441726927319465 with runtime 0.001552581787109375
# the best-case revenue for assortment [0, 8] is 0.4424010091105931 with runtime 0.001493692398071289
#
# testing for offertimes 20, 17th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.27051500421835223 with runtime 0.0017442703247070312
# the best-case revenue for assortment [0, 1, 8] is 0.3277713186197055 with runtime 0.0012221336364746094
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.2551415396341464 with runtime 0.0016493797302246094
# the best-case revenue for assortment [0, 3, 4] is 0.3381724214638711 with runtime 0.001489400863647461
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.20255270579268295 with runtime 0.0014731884002685547
# the best-case revenue for assortment [0, 3, 5] is 0.24027531151943 with runtime 0.0016129016876220703
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.1386998939554613 with runtime 0.0016376972198486328
# the best-case revenue for assortment [0, 3, 7] is 0.14767740091463416 with runtime 0.0018315315246582031
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.17374058269484632 with runtime 0.0015835762023925781
# the best-case revenue for assortment [0, 6, 8] is 0.2736164273153577 with runtime 0.0019702911376953125
#
# testing for offertimes 20, 18th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.08193750000000011 with runtime 0.0018897056579589844
# the best-case revenue for assortment [0, 2] is 0.14250000000000002 with runtime 0.002058267593383789
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.281984527349264 with runtime 0.0011668205261230469
# the best-case revenue for assortment [0, 1, 3] is 0.28753419633152233 with runtime 0.0011773109436035156
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.21873785956995756 with runtime 0.0012447834014892578
# the best-case revenue for assortment [0, 3, 4] is 0.25570063651591324 with runtime 0.001180410385131836
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4200408598548303 with runtime 0.0020570755004882812
# the best-case revenue for assortment [0, 4, 8] is 0.4661512562814067 with runtime 0.0021848678588867188
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.30004860238693454 with runtime 0.0016298294067382812
# the best-case revenue for assortment [0, 6, 8] is 0.3120587311557787 with runtime 0.0016252994537353516
#
# testing for offertimes 20, 19th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.12734328358208954 with runtime 0.0013194084167480469
# the best-case revenue for assortment [0, 6] is 0.12734328358208954 with runtime 0.0010197162628173828
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.4725117039255219 with runtime 0.0012209415435791016
# the best-case revenue for assortment [0, 1, 8] is 0.4784377001304555 with runtime 0.0011878013610839844
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.1522535569105691 with runtime 0.001499176025390625
# the best-case revenue for assortment [0, 2, 3, 6] is 0.18834327465250456 with runtime 0.0013217926025390625
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.12734328358208954 with runtime 0.0011293888092041016
# the best-case revenue for assortment [0, 4, 6] is 0.12734328358208954 with runtime 0.0013422966003417969
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.40719046135546183 with runtime 0.0010082721710205078
# the best-case revenue for assortment [0, 5, 8] is 0.40719046135546183 with runtime 0.0008971691131591797
#
# testing for offertimes 20, 20th instance
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.1990253105590811 with runtime 0.0016262531280517578
# the best-case revenue for assortment [0, 1, 7] is 0.24409645226956175 with runtime 0.0015592575073242188
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.1507409375 with runtime 0.0012347698211669922
# the best-case revenue for assortment [0, 3, 6] is 0.1572253125 with runtime 0.0013587474822998047
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.48920224423308933 with runtime 0.001367330551147461
# the best-case revenue for assortment [0, 4, 7] is 0.48920224423308933 with runtime 0.0014431476593017578
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.1695719277810134 with runtime 0.0014216899871826172
# the best-case revenue for assortment [0, 5, 6] is 0.18595089285714295 with runtime 0.0015015602111816406
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.26004020100502523 with runtime 0.0015802383422851562
# the best-case revenue for assortment [0, 8] is 0.3889753810082066 with runtime 0.0014619827270507812
#
# testing for offertimes 20, 21th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.09820900384129841 with runtime 0.001173257827758789
# the best-case revenue for assortment [0, 3] is 0.1058910891089109 with runtime 0.0010268688201904297
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.2074219733001686 with runtime 0.0010302066802978516
# the best-case revenue for assortment [0, 1, 7] is 0.20770816062504616 with runtime 0.0010881423950195312
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15716133966105283 with runtime 0.0014505386352539062
# the best-case revenue for assortment [0, 2, 6] is 0.18488421265153115 with runtime 0.0014197826385498047
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.23763959171735244 with runtime 0.0014197826385498047
# the best-case revenue for assortment [0, 4, 6] is 0.28172104041992163 with runtime 0.00127410888671875
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4145823075880206 with runtime 0.0013556480407714844
# the best-case revenue for assortment [0, 4, 8] is 0.4145823075880206 with runtime 0.001074075698852539
#
# testing for offertimes 20, 22th instance
# revenue prediction for unseen assortment [0, 4]
# the robust revenue for assortment [0, 4] is 0.28191600861450117 with runtime 0.0017969608306884766
# the best-case revenue for assortment [0, 4] is 0.4734285714285714 with runtime 0.0014905929565429688
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.099984375 with runtime 0.00125885009765625
# the best-case revenue for assortment [0, 6] is 0.13542857142857143 with runtime 0.0013861656188964844
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.21408009153318075 with runtime 0.0011909008026123047
# the best-case revenue for assortment [0, 3, 5] is 0.36343277792471124 with runtime 0.0011444091796875
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.33669992821249106 with runtime 0.0011827945709228516
# the best-case revenue for assortment [0, 4, 6] is 0.33669992821249106 with runtime 0.0011107921600341797
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.3694736430760372 with runtime 0.0011987686157226562
# the best-case revenue for assortment [0, 5, 6] is 0.3753583548554858 with runtime 0.001192331314086914
#
# testing for offertimes 20, 23th instance
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.27163122171945703 with runtime 0.0017046928405761719
# the best-case revenue for assortment [0, 1, 7] is 0.42844245524296676 with runtime 0.00138092041015625
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.45242191994544456 with runtime 0.0018498897552490234
# the best-case revenue for assortment [0, 1, 8] is 0.5419513317101506 with runtime 0.0020618438720703125
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.40953714935194213 with runtime 0.001844167709350586
# the best-case revenue for assortment [0, 3, 4] is 0.45888744313673635 with runtime 0.0017862319946289062
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.2826047065548776 with runtime 0.0017445087432861328
# the best-case revenue for assortment [0, 3, 5] is 0.3064200413833875 with runtime 0.0016205310821533203
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.23156225422950494 with runtime 0.0012354850769042969
# the best-case revenue for assortment [0, 6, 7] is 0.23156225422950494 with runtime 0.0012328624725341797
#
# testing for offertimes 20, 24th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.35784374999999996 with runtime 0.001341104507446289
# the best-case revenue for assortment [0, 1] is 0.376643216080402 with runtime 0.0010223388671875
#
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.12646875 with runtime 0.0014960765838623047
# the best-case revenue for assortment [0, 2] is 0.14792195121951224 with runtime 0.001352548599243164
#
# revenue prediction for unseen assortment [0, 1, 5]
# the robust revenue for assortment [0, 1, 5] is 0.4046036019826327 with runtime 0.0011725425720214844
# the best-case revenue for assortment [0, 1, 5] is 0.4053819095477386 with runtime 0.001210927963256836
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.4257528820573455 with runtime 0.0013957023620605469
# the best-case revenue for assortment [0, 3, 4] is 0.43135422209084623 with runtime 0.0014624595642089844
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.5809881761749927 with runtime 0.0012257099151611328
# the best-case revenue for assortment [0, 4, 8] is 0.5893220901573416 with runtime 0.0012173652648925781
#
# testing for offertimes 20, 25th instance
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.36366757172961583 with runtime 0.0021245479583740234
# the best-case revenue for assortment [0, 1, 8] is 0.4250121667159325 with runtime 0.00159454345703125
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.14050569105691058 with runtime 0.002285003662109375
# the best-case revenue for assortment [0, 3, 7] is 0.2119292756778824 with runtime 0.002753734588623047
#
# revenue prediction for unseen assortment [0, 3, 8]
# the robust revenue for assortment [0, 3, 8] is 0.24165125628140705 with runtime 0.0013873577117919922
# the best-case revenue for assortment [0, 3, 8] is 0.24505695142378559 with runtime 0.0013365745544433594
#
# revenue prediction for unseen assortment [0, 4, 7]
# the robust revenue for assortment [0, 4, 7] is 0.5545863650075417 with runtime 0.0015227794647216797
# the best-case revenue for assortment [0, 4, 7] is 0.6848933333333334 with runtime 0.0015878677368164062
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.33759244544592026 with runtime 0.001873016357421875
# the best-case revenue for assortment [0, 6, 8] is 0.47617098776615524 with runtime 0.0017523765563964844
#
# testing for offertimes 20, 26th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.1357826086956522 with runtime 0.0013699531555175781
# the best-case revenue for assortment [0, 1] is 0.2263043478260869 with runtime 0.0010864734649658203
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.12026865671641791 with runtime 0.0012140274047851562
# the best-case revenue for assortment [0, 6] is 0.12734328358208954 with runtime 0.0013849735260009766
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.11521275898242851 with runtime 0.0013344287872314453
# the best-case revenue for assortment [0, 1, 3] is 0.13858562811434563 with runtime 0.0011997222900390625
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.10744552845528454 with runtime 0.0017695426940917969
# the best-case revenue for assortment [0, 3, 5] is 0.12496791651498595 with runtime 0.0017285346984863281
#
# revenue prediction for unseen assortment [0, 4, 5]
# the robust revenue for assortment [0, 4, 5] is 0.43833993366500823 with runtime 0.0017728805541992188
# the best-case revenue for assortment [0, 4, 5] is 0.4455488888888888 with runtime 0.001965045928955078
#
# testing for offertimes 20, 27th instance
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.07444444444444444 with runtime 0.0015208721160888672
# the best-case revenue for assortment [0, 7] is 0.15721491228070184 with runtime 0.0013344287872314453
#
# revenue prediction for unseen assortment [0, 1, 3]
# the robust revenue for assortment [0, 1, 3] is 0.149658217324961 with runtime 0.0011336803436279297
# the best-case revenue for assortment [0, 1, 3] is 0.149658217324961 with runtime 0.0010573863983154297
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.13857599913769142 with runtime 0.0010170936584472656
# the best-case revenue for assortment [0, 3, 6] is 0.13857599913769147 with runtime 0.0010304450988769531
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.28281353769429557 with runtime 0.0011115074157714844
# the best-case revenue for assortment [0, 5, 6] is 0.2828135376942956 with runtime 0.0011086463928222656
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.15266278392545135 with runtime 0.0014815330505371094
# the best-case revenue for assortment [0, 6, 8] is 0.2895874070410293 with runtime 0.0014154911041259766
#
# testing for offertimes 20, 28th instance
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.21435947712418296 with runtime 0.0013108253479003906
# the best-case revenue for assortment [0, 1, 7] is 0.25161849513124684 with runtime 0.0011627674102783203
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.29842950044339345 with runtime 0.0016660690307617188
# the best-case revenue for assortment [0, 1, 8] is 0.3128239916428617 with runtime 0.001703023910522461
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.31827381045854286 with runtime 0.001819610595703125
# the best-case revenue for assortment [0, 3, 5] is 0.33034673366834166 with runtime 0.00174713134765625
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.09409430894308946 with runtime 0.0022809505462646484
# the best-case revenue for assortment [0, 3, 7] is 0.11970300459526342 with runtime 0.0024328231811523438
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.20405146875905444 with runtime 0.0018420219421386719
# the best-case revenue for assortment [0, 6, 8] is 0.2082310970592856 with runtime 0.0017447471618652344
#
# testing for offertimes 20, 29th instance
# revenue prediction for unseen assortment [0, 1, 4]
# the robust revenue for assortment [0, 1, 4] is 0.3461862745098042 with runtime 0.001474618911743164
# the best-case revenue for assortment [0, 1, 4] is 0.369484162895928 with runtime 0.0010573863983154297
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.2420904304029304 with runtime 0.0013859272003173828
# the best-case revenue for assortment [0, 1, 7] is 0.2861116585207396 with runtime 0.0012581348419189453
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.15475806451612906 with runtime 0.0009729862213134766
# the best-case revenue for assortment [0, 2, 6] is 0.15475806451612917 with runtime 0.0009531974792480469
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.12728494623655914 with runtime 0.0011551380157470703
# the best-case revenue for assortment [0, 3, 6] is 0.1277700578990902 with runtime 0.001085042953491211
#
# revenue prediction for unseen assortment [0, 4, 6]
# the robust revenue for assortment [0, 4, 6] is 0.21602027602603946 with runtime 0.0009980201721191406
# the best-case revenue for assortment [0, 4, 6] is 0.2189003422455849 with runtime 0.0010578632354736328
#
# testing for offertimes 20, 30th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.3287368421052631 with runtime 0.002325773239135742
# the best-case revenue for assortment [0, 1] is 0.365263157894737 with runtime 0.0020825862884521484
#
# revenue prediction for unseen assortment [0, 1, 8]
# the robust revenue for assortment [0, 1, 8] is 0.44856874699254623 with runtime 0.0017116069793701172
# the best-case revenue for assortment [0, 1, 8] is 0.4603577712609972 with runtime 0.0014014244079589844
#
# revenue prediction for unseen assortment [0, 3, 8]
# the robust revenue for assortment [0, 3, 8] is 0.42707461159867194 with runtime 0.0018186569213867188
# the best-case revenue for assortment [0, 3, 8] is 0.5156049680869416 with runtime 0.0015997886657714844
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.5509937930764414 with runtime 0.0014290809631347656
# the best-case revenue for assortment [0, 4, 8] is 0.5704132508116884 with runtime 0.0014324188232421875
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.45077478922287395 with runtime 0.0021715164184570312
# the best-case revenue for assortment [0, 5, 8] is 0.541808521649129 with runtime 0.002475261688232422
#
# testing for offertimes 20, 31th instance
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.354108946528865 with runtime 0.0011096000671386719
# the best-case revenue for assortment [0, 3, 5] is 0.354108946528865 with runtime 0.000972747802734375
#
# revenue prediction for unseen assortment [0, 4, 8]
# the robust revenue for assortment [0, 4, 8] is 0.4904667397660819 with runtime 0.0010776519775390625
# the best-case revenue for assortment [0, 4, 8] is 0.4956620390280171 with runtime 0.0010976791381835938
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.14796971461852065 with runtime 0.0015060901641845703
# the best-case revenue for assortment [0, 6, 7] is 0.20559796843654943 with runtime 0.0014333724975585938
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.23059493921748264 with runtime 0.0013709068298339844
# the best-case revenue for assortment [0, 6, 8] is 0.27092585496939786 with runtime 0.001631021499633789
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.25366666666666665 with runtime 0.0011529922485351562
# the best-case revenue for assortment [0, 8] is 0.3688179824561405 with runtime 0.001169443130493164
#
# testing for offertimes 20, 32th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.10074370709382158 with runtime 0.002129793167114258
# the best-case revenue for assortment [0, 5] is 0.37828888888888884 with runtime 0.001967906951904297
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.18480896169373595 with runtime 0.0021178722381591797
# the best-case revenue for assortment [0, 3, 5] is 0.22718362573099418 with runtime 0.001856088638305664
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.16480263157894737 with runtime 0.0015401840209960938
# the best-case revenue for assortment [0, 3, 6] is 0.16674794407894739 with runtime 0.0013582706451416016
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.22670927488558354 with runtime 0.0011909008026123047
# the best-case revenue for assortment [0, 5, 6] is 0.23035308209382158 with runtime 0.0011138916015625
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3351506687647521 with runtime 0.0014369487762451172
# the best-case revenue for assortment [0, 5, 8] is 0.42797469814515066 with runtime 0.0013265609741210938
#
# testing for offertimes 20, 33th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.04275 with runtime 0.0022063255310058594
# the best-case revenue for assortment [0, 2] is 0.14250000000000002 with runtime 0.002062559127807617
#
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.08285246415770604 with runtime 0.0012121200561523438
# the best-case revenue for assortment [0, 7] is 0.1578222222222222 with runtime 0.0011758804321289062
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.14105826005025124 with runtime 0.0017349720001220703
# the best-case revenue for assortment [0, 2, 3, 6] is 0.14933245359863836 with runtime 0.0016055107116699219
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.25954872142972935 with runtime 0.0009763240814208984
# the best-case revenue for assortment [0, 3, 4] is 0.2595487214297293 with runtime 0.0009779930114746094
#
# revenue prediction for unseen assortment [0, 6, 8]
# the robust revenue for assortment [0, 6, 8] is 0.229644472361809 with runtime 0.0010960102081298828
# the best-case revenue for assortment [0, 6, 8] is 0.26807017543859657 with runtime 0.0010979175567626953
#
# testing for offertimes 20, 34th instance
# revenue prediction for unseen assortment [0, 7]
# the robust revenue for assortment [0, 7] is 0.14912903225806456 with runtime 0.0015811920166015625
# the best-case revenue for assortment [0, 7] is 0.21612903225806457 with runtime 0.0013918876647949219
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.22272321597398184 with runtime 0.0013651847839355469
# the best-case revenue for assortment [0, 1, 7] is 0.25322903225806453 with runtime 0.001405477523803711
#
# revenue prediction for unseen assortment [0, 3, 5]
# the robust revenue for assortment [0, 3, 5] is 0.22566180904522604 with runtime 0.0011754035949707031
# the best-case revenue for assortment [0, 3, 5] is 0.3641623115577889 with runtime 0.0011630058288574219
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.16584227779522606 with runtime 0.0014965534210205078
# the best-case revenue for assortment [0, 3, 6] is 0.17579687500000002 with runtime 0.0013496875762939453
#
# revenue prediction for unseen assortment [0, 3, 7]
# the robust revenue for assortment [0, 3, 7] is 0.14304878048780487 with runtime 0.0014307498931884766
# the best-case revenue for assortment [0, 3, 7] is 0.17524071529522603 with runtime 0.0012867450714111328
#
# testing for offertimes 20, 35th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.0882787635974224 with runtime 0.0012018680572509766
# the best-case revenue for assortment [0, 1] is 0.23099650553290624 with runtime 0.0009806156158447266
#
# revenue prediction for unseen assortment [0, 1, 7]
# the robust revenue for assortment [0, 1, 7] is 0.19787611381739284 with runtime 0.0009496212005615234
# the best-case revenue for assortment [0, 1, 7] is 0.20055713427197808 with runtime 0.0008549690246582031
#
# revenue prediction for unseen assortment [0, 2, 3, 6]
# the robust revenue for assortment [0, 2, 3, 6] is 0.13196096925813006 with runtime 0.0010578632354736328
# the best-case revenue for assortment [0, 2, 3, 6] is 0.1562253948672369 with runtime 0.0010356903076171875
#
# revenue prediction for unseen assortment [0, 3, 4]
# the robust revenue for assortment [0, 3, 4] is 0.2699639594397457 with runtime 0.001046895980834961
# the best-case revenue for assortment [0, 3, 4] is 0.2699639594397457 with runtime 0.0008890628814697266
#
# revenue prediction for unseen assortment [0, 6, 7]
# the robust revenue for assortment [0, 6, 7] is 0.15847510302197798 with runtime 0.0009372234344482422
# the best-case revenue for assortment [0, 6, 7] is 0.158475103021978 with runtime 0.0008609294891357422
#
# testing for offertimes 20, 36th instance
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.24992796493271616 with runtime 0.001168966293334961
# the best-case revenue for assortment [0, 1, 6] is 0.24992796493271624 with runtime 0.0011398792266845703
#
# revenue prediction for unseen assortment [0, 2, 6]
# ...
#
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.07070483993902438 with runtime 0.0009801387786865234
# the best-case revenue for assortment [0, 3] is 0.1374609375 with runtime 0.0007781982421875
#
# testing for offertimes 60, 21th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.15928643216080393 with runtime 0.0007638931274414062
# the best-case revenue for assortment [0, 5] is 0.318572864321608 with runtime 0.0007328987121582031
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.12836924868957486 with runtime 0.0007920265197753906
# the best-case revenue for assortment [0, 1, 6] is 0.32916282894736837 with runtime 0.0008111000061035156
#
# testing for offertimes 60, 22th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.12896088657179935 with runtime 0.0006327629089355469
# the best-case revenue for assortment [0, 2, 6] is 0.15384908413032908 with runtime 0.0006380081176757812
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.11152125653985617 with runtime 0.0005714893341064453
# the best-case revenue for assortment [0, 3, 6] is 0.14172677905657322 with runtime 0.0005602836608886719
#
# testing for offertimes 60, 23th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.3358064516129032 with runtime 0.0007004737854003906
# the best-case revenue for assortment [0, 1] is 0.40296774193548385 with runtime 0.0006558895111083984
#
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.11578125 with runtime 0.0008263587951660156
# the best-case revenue for assortment [0, 2] is 0.15140625 with runtime 0.0007383823394775391
#
# testing for offertimes 60, 24th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.3274112903225806 with runtime 0.0006296634674072266
# the best-case revenue for assortment [0, 1] is 0.40296774193548385 with runtime 0.0006194114685058594
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.22179899497487437 with runtime 0.0007410049438476562
# the best-case revenue for assortment [0, 8] is 0.5506733668341709 with runtime 0.0006737709045410156
#
# testing for offertimes 60, 25th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.053695312499999995 with runtime 0.0007190704345703125
# the best-case revenue for assortment [0, 6] is 0.1240546875 with runtime 0.0006229877471923828
#
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.25994058388157887 with runtime 0.0009527206420898438
# the best-case revenue for assortment [0, 1, 6] is 0.3468974967907574 with runtime 0.0010209083557128906
#
# testing for offertimes 60, 26th instance
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.12367617938264415 with runtime 0.0007240772247314453
# the best-case revenue for assortment [0, 5, 6] is 0.19183159700943742 with runtime 0.0007269382476806641
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.28298492462311564 with runtime 0.0005621910095214844
# the best-case revenue for assortment [0, 8] is 0.3900603015075377 with runtime 0.0005178451538085938
#
# testing for offertimes 60, 27th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.055995733719713434 with runtime 0.0011057853698730469
# the best-case revenue for assortment [0, 3] is 0.12593069306930693 with runtime 0.0008685588836669922
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.15266278392545135 with runtime 0.0006747245788574219
# the best-case revenue for assortment [0, 5, 6] is 0.30306189484005397 with runtime 0.0006427764892578125
#
# testing for offertimes 60, 28th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.14872196911341987 with runtime 0.0009467601776123047
# the best-case revenue for assortment [0, 1] is 0.2746493884682586 with runtime 0.0007011890411376953
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.1219788548877962 with runtime 0.0011501312255859375
# the best-case revenue for assortment [0, 2, 6] is 0.1532849613923275 with runtime 0.0011186599731445312
#
# testing for offertimes 60, 29th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.09161572568725984 with runtime 0.0007781982421875
# the best-case revenue for assortment [0, 5] is 0.34529411764705875 with runtime 0.0006670951843261719
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.16422304299599336 with runtime 0.0008823871612548828
# the best-case revenue for assortment [0, 5, 6] is 0.2629688488298544 with runtime 0.0007808208465576172
#
# testing for offertimes 60, 30th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.03814634146341465 with runtime 0.0013124942779541016
# the best-case revenue for assortment [0, 3] is 0.1462276422764228 with runtime 0.0011601448059082031
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.14998201627910285 with runtime 0.0008256435394287109
# the best-case revenue for assortment [0, 2, 6] is 0.21248759305210912 with runtime 0.0007517337799072266
#
# testing for offertimes 60, 31th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.031140816690777225 with runtime 0.0008008480072021484
# the best-case revenue for assortment [0, 1] is 0.3249714618520675 with runtime 0.0008411407470703125
#
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.2831758793969849 with runtime 0.0005400180816650391
# the best-case revenue for assortment [0, 5] is 0.3480703517587939 with runtime 0.0005702972412109375
#
# testing for offertimes 60, 32th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.035625000000000004 with runtime 0.0006811618804931641
# the best-case revenue for assortment [0, 2] is 0.1603125 with runtime 0.0006783008575439453
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.27533668341708545 with runtime 0.000728607177734375
# the best-case revenue for assortment [0, 8] is 0.49713567839195977 with runtime 0.0006947517395019531
#
# testing for offertimes 60, 33th instance
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.21612006578947363 with runtime 0.0006928443908691406
# the best-case revenue for assortment [0, 1, 6] is 0.4438388157894736 with runtime 0.0005950927734375
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2008448492462311 with runtime 0.0006699562072753906
# the best-case revenue for assortment [0, 5, 6] is 0.27477292713567836 with runtime 0.0006225109100341797
#
# testing for offertimes 60, 34th instance
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.1603450838414634 with runtime 0.000675201416015625
# the best-case revenue for assortment [0, 3, 6] is 0.24858784298780484 with runtime 0.0005602836608886719
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.1097024984241254 with runtime 0.0008101463317871094
# the best-case revenue for assortment [0, 8] is 0.5736180904522613 with runtime 0.0008108615875244141
#
# testing for offertimes 60, 35th instance
# revenue prediction for unseen assortment [0, 3]
# the robust revenue for assortment [0, 3] is 0.06634632240853658 with runtime 0.0007214546203613281
# the best-case revenue for assortment [0, 3] is 0.09536585365853659 with runtime 0.0005571842193603516
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.06498387096774193 with runtime 0.0005526542663574219
# the best-case revenue for assortment [0, 6] is 0.10342763157894735 with runtime 0.0005612373352050781
#
# testing for offertimes 60, 36th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.1483993636092447 with runtime 0.0007097721099853516
# the best-case revenue for assortment [0, 2, 6] is 0.20664143920595532 with runtime 0.0006153583526611328
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2529899088940638 with runtime 0.0005481243133544922
# the best-case revenue for assortment [0, 5, 6] is 0.34334341060139406 with runtime 0.0006577968597412109
#
# testing for offertimes 60, 37th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.15111290322580645 with runtime 0.0007774829864501953
# the best-case revenue for assortment [0, 1] is 0.3106209677419354 with runtime 0.0005502700805664062
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.0907265625 with runtime 0.0006785392761230469
# the best-case revenue for assortment [0, 6] is 0.12645520571608035 with runtime 0.0007512569427490234
#
# testing for offertimes 60, 38th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.057 with runtime 0.0007300376892089844
# the best-case revenue for assortment [0, 2] is 0.12825 with runtime 0.0007278919219970703
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.3266827515788677 with runtime 0.0010614395141601562
# the best-case revenue for assortment [0, 5, 8] is 0.4901656245512675 with runtime 0.0008542537689208984
#
# testing for offertimes 60, 39th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.08761194029850745 with runtime 0.0005686283111572266
# the best-case revenue for assortment [0, 5] is 0.2978805970149253 with runtime 0.0006322860717773438
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.2918292220113851 with runtime 0.000797271728515625
# the best-case revenue for assortment [0, 5, 8] is 0.46594590614290965 with runtime 0.0008022785186767578
#
# testing for offertimes 60, 40th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.0285 with runtime 0.0006246566772460938
# the best-case revenue for assortment [0, 2] is 0.1389375 with runtime 0.0005090236663818359
#
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.11479687499999999 with runtime 0.0005373954772949219
# the best-case revenue for assortment [0, 6] is 0.144421875 with runtime 0.00045943260192871094
#
# testing for offertimes 60, 41th instance
# revenue prediction for unseen assortment [0, 1]
# the robust revenue for assortment [0, 1] is 0.21578188004032256 with runtime 0.0006814002990722656
# the best-case revenue for assortment [0, 1] is 0.26864516129032256 with runtime 0.0005743503570556641
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.22846893317702222 with runtime 0.0006418228149414062
# the best-case revenue for assortment [0, 5, 8] is 0.3228466555977229 with runtime 0.0006413459777832031
#
# testing for offertimes 60, 42th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.07321951219512192 with runtime 0.0007452964782714844
# the best-case revenue for assortment [0, 6] is 0.11560975609756097 with runtime 0.0006425380706787109
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.16826130653266338 with runtime 0.0007441043853759766
# the best-case revenue for assortment [0, 8] is 0.458894472361809 with runtime 0.0006814002990722656
#
# testing for offertimes 60, 43th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.14077917656018996 with runtime 0.0007040500640869141
# the best-case revenue for assortment [0, 2, 6] is 0.17459662288930583 with runtime 0.0006692409515380859
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.36711557788944715 with runtime 0.0006616115570068359
# the best-case revenue for assortment [0, 8] is 0.45124623115577883 with runtime 0.0006604194641113281
#
# testing for offertimes 60, 44th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.08478048780487804 with runtime 0.0006248950958251953
# the best-case revenue for assortment [0, 6] is 0.1216951934349355 with runtime 0.0005650520324707031
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.12014258911819886 with runtime 0.0008363723754882812
# the best-case revenue for assortment [0, 2, 6] is 0.18572952853598018 with runtime 0.0008988380432128906
#
# testing for offertimes 60, 45th instance
# revenue prediction for unseen assortment [0, 2]
# the robust revenue for assortment [0, 2] is 0.0534375 with runtime 0.0006291866302490234
# the best-case revenue for assortment [0, 2] is 0.09975 with runtime 0.0005834102630615234
#
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.0889044460950764 with runtime 0.0006620883941650391
# the best-case revenue for assortment [0, 3, 6] is 0.11261060855263158 with runtime 0.0006456375122070312
#
# testing for offertimes 60, 46th instance
# revenue prediction for unseen assortment [0, 6]
# the robust revenue for assortment [0, 6] is 0.07262903225806451 with runtime 0.0008625984191894531
# the best-case revenue for assortment [0, 6] is 0.11018421052631576 with runtime 0.0006647109985351562
#
# revenue prediction for unseen assortment [0, 5, 8]
# the robust revenue for assortment [0, 5, 8] is 0.39107912023864877 with runtime 0.0005228519439697266
# the best-case revenue for assortment [0, 5, 8] is 0.8401415708902122 with runtime 0.0005190372467041016
#
# testing for offertimes 60, 47th instance
# revenue prediction for unseen assortment [0, 1, 6]
# the robust revenue for assortment [0, 1, 6] is 0.16259660553903693 with runtime 0.0008080005645751953
# the best-case revenue for assortment [0, 1, 6] is 0.36601973684210526 with runtime 0.0007073879241943359
#
# revenue prediction for unseen assortment [0, 8]
# the robust revenue for assortment [0, 8] is 0.27931771400967315 with runtime 0.0007462501525878906
# the best-case revenue for assortment [0, 8] is 0.5852473622508793 with runtime 0.0007526874542236328
#
# testing for offertimes 60, 48th instance
# revenue prediction for unseen assortment [0, 3, 6]
# the robust revenue for assortment [0, 3, 6] is 0.10441680847772278 with runtime 0.0009629726409912109
# the best-case revenue for assortment [0, 3, 6] is 0.13423463070416994 with runtime 0.0007085800170898438
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2818749949343492 with runtime 0.0005869865417480469
# the best-case revenue for assortment [0, 5, 6] is 0.3461916027971039 with runtime 0.0005943775177001953
#
# testing for offertimes 60, 49th instance
# revenue prediction for unseen assortment [0, 5]
# the robust revenue for assortment [0, 5] is 0.3067738693467337 with runtime 0.0007202625274658203
# the best-case revenue for assortment [0, 5] is 0.3539698492462311 with runtime 0.0005116462707519531
#
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.11541329886216742 with runtime 0.0008296966552734375
# the best-case revenue for assortment [0, 2, 6] is 0.16890241102181397 with runtime 0.0007698535919189453

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mdm_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_lb_dist':all_mdm_lb_distance_list[i],'mdm_ub_dist':all_mdm_ub_distance_list[i],
                                    'true_best_rev':all_best_true_revenue_list[i],'mdm_lb_best_rev':all_best_revenue_mdm_lb[i],'mdm_ub_best_rev':all_best_revenue_mdm_ub[i],
                                    'mdm_lb_best_rev_diff':all_mdm_lb_best_rev_diff[i],'mdm_ub_best_rev_diff':all_mdm_ub_best_rev_diff[i]})
    df_mdm_details1.to_csv('prediction/etp_mdm/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        lb_rank = all_mdm_lb_ranking[i][j]
        ub_rank = all_mdm_ub_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'lb_rank':lb_rank,'ub_rank':ub_rank})
        df_rank.to_csv('prediction/etp_mdm/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        lb_rev = all_mdm_lb_revenue_list[i][j]
        ub_rev = all_mdm_ub_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'lb_rev':lb_rev,'ub_rev':ub_rev})
        df_rev.to_csv('prediction/etp_mdm/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ''' true_prob = all_true_choice_prob_list[i][j]
        lb_prob = all_mdm_lb_rev_prob_list[i][j]
        ub_prob = all_mdm_ub_rev_prob_list[i][j]
        
        df_true_prob = pd.DataFrame(true_prob).T
        df_lb_prob = pd.DataFrame(lb_prob).T
        df_ub_prob = pd.DataFrame(ub_prob).T
        
        df_true_prob.to_csv('prediction/etp_mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_prob.to_csv('prediction/etp_mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/mdm_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_ub_prob.to_csv('prediction/etp_mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/mdm_ub/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''
        lb_runtime = all_mdm_rev_lb_runtime[i][j]
        ub_runtime = all_mdm_rev_ub_runtime[i][j]
        df_runtime = pd.DataFrame({'lb_runtime':lb_runtime,'ub_runtime':ub_runtime})
        df_runtime.to_csv('prediction/etp_mdm/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        
        ## using sales fraction prediction
        ## record the choice probability prediction interval
        ''' lb_sales = all_mdm_lb_sales_list[i][j]
        ub_sales = all_mdm_ub_sales_list[i][j]
        df_lb_sales = pd.DataFrame(lb_sales).T
        df_ub_sales = pd.DataFrame(ub_sales).T
        
        df_true_prob.to_csv('prediction/etp_mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_sales.to_csv('prediction/etp_mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mdm_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_ub_sales.to_csv('prediction/etp_mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mdm_ub/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## adding details 2 about runtime 
all_lb_avg_runtime = []
all_ub_avg_runtime =[]

for i in range(len(pred_offer_times_list)):
    
    avg_lb_runtime_collection = []
    avg_ub_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        avg_lb_runtime_collection.append(np.mean(np.array(all_mdm_rev_lb_runtime[i][j])))
        avg_ub_runtime_collection.append(np.mean(np.array(all_mdm_rev_ub_runtime[i][j])))
    
    all_lb_avg_runtime.append(np.mean(np.array(avg_lb_runtime_collection)))
    all_ub_avg_runtime.append(np.mean(np.array(avg_ub_runtime_collection)))

# %%
avg_mdm_lb_dist = []
avg_mdm_ub_dist = []

avg_mdm_lb_best_rev_diff = []
avg_mdm_ub_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_lb_dist.append(np.mean(all_mdm_lb_distance_list[i]))
    avg_mdm_ub_dist.append(np.mean(all_mdm_ub_distance_list[i]))
    
    avg_mdm_lb_best_rev_diff.append(np.mean(all_mdm_lb_best_rev_diff[i]))
    avg_mdm_ub_best_rev_diff.append(np.mean(all_mdm_ub_best_rev_diff[i]))

df_mdm_etp_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'train_size':pred_train_collection_size,'test_size':pred_test_collection_size,
                                   'avg_lb_dist':avg_mdm_lb_dist,'avg_ub_dist':avg_mdm_ub_dist,
                                   'avg_lb_best_rev_diff':avg_mdm_lb_best_rev_diff,'avg_ub_best_rev_diff':avg_mdm_ub_best_rev_diff,
                                   'avg_lb_runtime':all_lb_avg_runtime,'avg_ub_runtime':all_ub_avg_runtime})
df_mdm_etp_summary.to_csv('prediction/etp_mdm/jd_etp_mdm_summary_mu0_610_mu1n_minus2pos2.csv')

# %%
df_mdm_etp_summary
# Out:
#    offertimes  train_size  test_size  avg_lb_dist  avg_ub_dist  \
# 0          20          24          5         1.96         1.78
# 1          30          20          4         1.00         0.90
# 2          40          16          3         0.60         0.38
# 3          50          12          3         0.62         0.30
# 4          60          11          2         0.16         0.08
#
#    avg_lb_best_rev_diff  avg_ub_best_rev_diff  avg_lb_runtime  avg_ub_runtime
# 0              0.092116              0.073268        0.001481        0.001419
# 1              0.040104              0.036925        0.001108        0.001031
# 2              0.079464              0.050297        0.001005        0.000921
# 3              0.079724              0.015214        0.000775        0.000717
# 4              0.050682              0.015762        0.000758        0.000694

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
## record representability of all instances
all_mdm_rep = []
all_mdm_rep_time = []

## record the limit loss of all instances
all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_runtime = []

all_mdm_limit_lam = []


for i in range(len(pred_offer_times_list)):

    ## define container for mdm representability check
    mdm_rep_collection =[]
    mdm_rep_runtime_collection =[]
    
    ## define container for mdm limit 
    mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[]
    mdm_limit_lam_collection = []
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        ####### mdm representability check ##########
        
        row_data = row_assortment_data(all_full_instances[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_full_instances[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_runtime_collection.append(curr_rep_result[1])
        
        # check if representable
        if curr_rep_result[0] > 0:
            
            mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(0)
            mdm_limit_probability_collection.append(all_full_instances[i][j])
        else:
            # not representable # limit and prediction
            #mdm_limit(data,collection,perm_collection,produts_notin_collection)
            curr_limit_result = mdm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            curr_limit_prob = curr_limit_result[-1]
            mdm_limit_probability_collection.append(curr_limit_prob)
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_runtime_collection.append(curr_limit_result[1])
            mdm_limit_lam_collection.append(curr_limit_result[2])
            
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_runtime_collection)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection)
    
    all_mdm_limit_lam.append(mdm_limit_lam_collection)
# Out:
# testing instance with offertimes 20 : 0th
# testing instance with offertimes 20 : 1th
# testing instance with offertimes 20 : 2th
# testing instance with offertimes 20 : 3th
# testing instance with offertimes 20 : 4th
# testing instance with offertimes 20 : 5th
# testing instance with offertimes 20 : 6th
# testing instance with offertimes 20 : 7th
# testing instance with offertimes 20 : 8th
# testing instance with offertimes 20 : 9th
# testing instance with offertimes 20 : 10th
# testing instance with offertimes 20 : 11th
# testing instance with offertimes 20 : 12th
# testing instance with offertimes 20 : 13th
# testing instance with offertimes 20 : 14th
# testing instance with offertimes 20 : 15th
# testing instance with offertimes 20 : 16th
# testing instance with offertimes 20 : 17th
# testing instance with offertimes 20 : 18th
# testing instance with offertimes 20 : 19th
# testing instance with offertimes 20 : 20th
# testing instance with offertimes 20 : 21th
# testing instance with offertimes 20 : 22th
# testing instance with offertimes 20 : 23th
# testing instance with offertimes 20 : 24th
# testing instance with offertimes 20 : 25th
# testing instance with offertimes 20 : 26th
# testing instance with offertimes 20 : 27th
# testing instance with offertimes 20 : 28th
# testing instance with offertimes 20 : 29th
# testing instance with offertimes 20 : 30th
# testing instance with offertimes 20 : 31th
# testing instance with offertimes 20 : 32th
# testing instance with offertimes 20 : 33th
# testing instance with offertimes 20 : 34th
# testing instance with offertimes 20 : 35th
# testing instance with offertimes 20 : 36th
# testing instance with offertimes 20 : 37th
# testing instance with offertimes 20 : 38th
# testing instance with offertimes 20 : 39th
# testing instance with offertimes 20 : 40th
# testing instance with offertimes 20 : 41th
# testing instance with offertimes 20 : 42th
# testing instance with offertimes 20 : 43th
# testing instance with offertimes 20 : 44th
# testing instance with offertimes 20 : 45th
# testing instance with offertimes 20 : 46th
# testing instance with offertimes 20 : 47th
# testing instance with offertimes 20 : 48th
# testing instance with offertimes 20 : 49th
# testing instance with offertimes 30 : 0th
# testing instance with offertimes 30 : 1th
# testing instance with offertimes 30 : 2th
# testing instance with offertimes 30 : 3th
# testing instance with offertimes 30 : 4th
# testing instance with offertimes 30 : 5th
# testing instance with offertimes 30 : 6th
# testing instance with offertimes 30 : 7th
# testing instance with offertimes 30 : 8th
# testing instance with offertimes 30 : 9th
# testing instance with offertimes 30 : 10th
# testing instance with offertimes 30 : 11th
# testing instance with offertimes 30 : 12th
# testing instance with offertimes 30 : 13th
# testing instance with offertimes 30 : 14th
# testing instance with offertimes 30 : 15th
# testing instance with offertimes 30 : 16th
# testing instance with offertimes 30 : 17th
# testing instance with offertimes 30 : 18th
# testing instance with offertimes 30 : 19th
# testing instance with offertimes 30 : 20th
# testing instance with offertimes 30 : 21th
# testing instance with offertimes 30 : 22th
# testing instance with offertimes 30 : 23th
# testing instance with offertimes 30 : 24th
# testing instance with offertimes 30 : 25th
# testing instance with offertimes 30 : 26th
# testing instance with offertimes 30 : 27th
# testing instance with offertimes 30 : 28th
# testing instance with offertimes 30 : 29th
# testing instance with offertimes 30 : 30th
# testing instance with offertimes 30 : 31th
# testing instance with offertimes 30 : 32th
# testing instance with offertimes 30 : 33th
# testing instance with offertimes 30 : 34th
# testing instance with offertimes 30 : 35th
# testing instance with offertimes 30 : 36th
# testing instance with offertimes 30 : 37th
# testing instance with offertimes 30 : 38th
# testing instance with offertimes 30 : 39th
# testing instance with offertimes 30 : 40th
# testing instance with offertimes 30 : 41th
# testing instance with offertimes 30 : 42th
# testing instance with offertimes 30 : 43th
# testing instance with offertimes 30 : 44th
# testing instance with offertimes 30 : 45th
# testing instance with offertimes 30 : 46th
# testing instance with offertimes 30 : 47th
# testing instance with offertimes 30 : 48th
# testing instance with offertimes 30 : 49th
# testing instance with offertimes 40 : 0th
# testing instance with offertimes 40 : 1th
# testing instance with offertimes 40 : 2th
# testing instance with offertimes 40 : 3th
# testing instance with offertimes 40 : 4th
# testing instance with offertimes 40 : 5th
# testing instance with offertimes 40 : 6th
# testing instance with offertimes 40 : 7th
# testing instance with offertimes 40 : 8th
# testing instance with offertimes 40 : 9th
# testing instance with offertimes 40 : 10th
# testing instance with offertimes 40 : 11th
# testing instance with offertimes 40 : 12th
# testing instance with offertimes 40 : 13th
# testing instance with offertimes 40 : 14th
# testing instance with offertimes 40 : 15th
# testing instance with offertimes 40 : 16th
# testing instance with offertimes 40 : 17th
# testing instance with offertimes 40 : 18th
# testing instance with offertimes 40 : 19th
# testing instance with offertimes 40 : 20th
# testing instance with offertimes 40 : 21th
# testing instance with offertimes 40 : 22th
# testing instance with offertimes 40 : 23th
# testing instance with offertimes 40 : 24th
# testing instance with offertimes 40 : 25th
# testing instance with offertimes 40 : 26th
# testing instance with offertimes 40 : 27th
# testing instance with offertimes 40 : 28th
# testing instance with offertimes 40 : 29th
# testing instance with offertimes 40 : 30th
# testing instance with offertimes 40 : 31th
# testing instance with offertimes 40 : 32th
# testing instance with offertimes 40 : 33th
# testing instance with offertimes 40 : 34th
# testing instance with offertimes 40 : 35th
# testing instance with offertimes 40 : 36th
# testing instance with offertimes 40 : 37th
# testing instance with offertimes 40 : 38th
# testing instance with offertimes 40 : 39th
# testing instance with offertimes 40 : 40th
# testing instance with offertimes 40 : 41th
# testing instance with offertimes 40 : 42th
# testing instance with offertimes 40 : 43th
# testing instance with offertimes 40 : 44th
# testing instance with offertimes 40 : 45th
# testing instance with offertimes 40 : 46th
# testing instance with offertimes 40 : 47th
# testing instance with offertimes 40 : 48th
# testing instance with offertimes 40 : 49th
# testing instance with offertimes 50 : 0th
# testing instance with offertimes 50 : 1th
# testing instance with offertimes 50 : 2th
# testing instance with offertimes 50 : 3th
# testing instance with offertimes 50 : 4th
# testing instance with offertimes 50 : 5th
# testing instance with offertimes 50 : 6th
# testing instance with offertimes 50 : 7th
# testing instance with offertimes 50 : 8th
# testing instance with offertimes 50 : 9th
# testing instance with offertimes 50 : 10th
# testing instance with offertimes 50 : 11th
# testing instance with offertimes 50 : 12th
# testing instance with offertimes 50 : 13th
# testing instance with offertimes 50 : 14th
# testing instance with offertimes 50 : 15th
# testing instance with offertimes 50 : 16th
# testing instance with offertimes 50 : 17th
# testing instance with offertimes 50 : 18th
# testing instance with offertimes 50 : 19th
# testing instance with offertimes 50 : 20th
# testing instance with offertimes 50 : 21th
# testing instance with offertimes 50 : 22th
# testing instance with offertimes 50 : 23th
# testing instance with offertimes 50 : 24th
# testing instance with offertimes 50 : 25th
# testing instance with offertimes 50 : 26th
# testing instance with offertimes 50 : 27th
# testing instance with offertimes 50 : 28th
# testing instance with offertimes 50 : 29th
# testing instance with offertimes 50 : 30th
# testing instance with offertimes 50 : 31th
# testing instance with offertimes 50 : 32th
# testing instance with offertimes 50 : 33th
# testing instance with offertimes 50 : 34th
# testing instance with offertimes 50 : 35th
# testing instance with offertimes 50 : 36th
# testing instance with offertimes 50 : 37th
# testing instance with offertimes 50 : 38th
# testing instance with offertimes 50 : 39th
# testing instance with offertimes 50 : 40th
# testing instance with offertimes 50 : 41th
# testing instance with offertimes 50 : 42th
# testing instance with offertimes 50 : 43th
# testing instance with offertimes 50 : 44th
# testing instance with offertimes 50 : 45th
# testing instance with offertimes 50 : 46th
# testing instance with offertimes 50 : 47th
# testing instance with offertimes 50 : 48th
# testing instance with offertimes 50 : 49th
# testing instance with offertimes 60 : 0th
# testing instance with offertimes 60 : 1th
# testing instance with offertimes 60 : 2th
# testing instance with offertimes 60 : 3th
# testing instance with offertimes 60 : 4th
# testing instance with offertimes 60 : 5th
# testing instance with offertimes 60 : 6th
# testing instance with offertimes 60 : 7th
# testing instance with offertimes 60 : 8th
# testing instance with offertimes 60 : 9th
# testing instance with offertimes 60 : 10th
# testing instance with offertimes 60 : 11th
# testing instance with offertimes 60 : 12th
# testing instance with offertimes 60 : 13th
# testing instance with offertimes 60 : 14th
# testing instance with offertimes 60 : 15th
# testing instance with offertimes 60 : 16th
# testing instance with offertimes 60 : 17th
# testing instance with offertimes 60 : 18th
# testing instance with offertimes 60 : 19th
# testing instance with offertimes 60 : 20th
# testing instance with offertimes 60 : 21th
# testing instance with offertimes 60 : 22th
# testing instance with offertimes 60 : 23th
# testing instance with offertimes 60 : 24th
# testing instance with offertimes 60 : 25th
# testing instance with offertimes 60 : 26th
# testing instance with offertimes 60 : 27th
# testing instance with offertimes 60 : 28th
# testing instance with offertimes 60 : 29th
# testing instance with offertimes 60 : 30th
# testing instance with offertimes 60 : 31th
# testing instance with offertimes 60 : 32th
# testing instance with offertimes 60 : 33th
# testing instance with offertimes 60 : 34th
# testing instance with offertimes 60 : 35th
# testing instance with offertimes 60 : 36th
# testing instance with offertimes 60 : 37th
# testing instance with offertimes 60 : 38th
# testing instance with offertimes 60 : 39th
# testing instance with offertimes 60 : 40th
# testing instance with offertimes 60 : 41th
# testing instance with offertimes 60 : 42th
# testing instance with offertimes 60 : 43th
# testing instance with offertimes 60 : 44th
# testing instance with offertimes 60 : 45th
# testing instance with offertimes 60 : 46th
# testing instance with offertimes 60 : 47th
# testing instance with offertimes 60 : 48th
# testing instance with offertimes 60 : 49th

# %%
## adding rep results
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep[i], 'mdm_rep_time':all_mdm_rep_time[i]})
    df_mdm_rep.to_csv('limit/mdm/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding limit results
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_loss':all_mdm_limit_loss[i], 'mdm_limit_time':all_mdm_limit_runtime[i]})
    df_mdm_loss.to_csv('limit/mdm/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
            df_limit_prob = pd.DataFrame(all_mdm_limit_prob[i][j])
            df_limit_prob.to_csv('limit/mdm/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
for i in range(len(pred_offer_times_list)):
    avg_loss_collection = []
    for j in range(pred_instance_size[i]):
        avg_loss_collection.append(all_mdm_limit_loss[i][j]/sum(all_full_offertimes[i]))
    all_avg_loss.append(avg_loss_collection)

# %%
avg_mdm_rep = []
avg_mdm_rep_runtime = []

avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_mdm_limit_runtime = []

#avg_loss = []
avg_loss_se = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_rep.append(np.mean(all_mdm_rep[i]))
    avg_mdm_rep_runtime.append(np.mean(all_mdm_rep_time[i]))
    
    avg_total_limit_loss.append(np.mean(all_mdm_limit_loss[i]))
    avg_mdm_limit_runtime.append(np.mean(all_mdm_limit_runtime[i]))
    avg_toal_limit_loss_se.append(np.std(all_mdm_limit_loss[i])/np.sqrt(len(all_mdm_limit_loss[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))

avg_loss = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))

df_mdm_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'mdm_rep':avg_mdm_rep,'mdm_rep_runtime':avg_mdm_rep_runtime,
                                   'total_mdm_loss':avg_total_limit_loss,'total_mdm_loss_se':avg_toal_limit_loss_se,
                                   'avg_mdm_loss':avg_loss,'avg_mdm_loss_se':avg_loss_se,
                                   'avg_mdm_limit_runtime':avg_mdm_limit_runtime
                                   })
df_mdm_limit.to_csv('limit/mdm/mdm_limit_summary.csv')
df_mdm_limit
# Out:
#    offertimes  mdm_rep  mdm_rep_runtime  total_mdm_loss  total_mdm_loss_se  \
# 0          20      0.0         0.000439       35.089511           1.029803
# 1          30      0.0         0.000472       27.217377           0.974042
# 2          40      0.0         0.000433       18.465862           0.870235
# 3          50      0.0         0.000301       11.890351           0.892916
# 4          60      0.0         0.000253        8.507300           0.825931
#
#    avg_mdm_loss  avg_mdm_loss_se  avg_mdm_limit_runtime
# 0      0.004584         0.000135              97.730743
# 1      0.003615         0.000129               5.358292
# 2      0.002509         0.000118               0.836701
# 3      0.001654         0.000124               0.201675
# 4      0.001201         0.000117               0.068891

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.0045838681956339436
# 0.0036150056176147438
# 0.002508607795225441
# 0.001653734481982281
# 0.001201256648075848
