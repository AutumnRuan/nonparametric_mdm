# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
import pyomo.environ as pyo
from pyomo.environ import *
import sys

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def generate_negatively_correlated_covariance_matrix(n):
    # Generate a random correlation matrix with negative correlations
    correlation_matrix = np.random.uniform(low=-0.9, high=-0.1, size=(n, n))
    np.fill_diagonal(correlation_matrix, 1)  # Set diagonal elements to 1
    correlation_matrix = (correlation_matrix + correlation_matrix.T) / 2  # Ensure symmetry

    # Ensure the correlation matrix is valid for Cholesky decomposition
    cholesky_success = False
    while not cholesky_success:
        try:
            # Perform Cholesky decomposition
            cholesky_matrix = np.linalg.cholesky(correlation_matrix)
            cholesky_success = True
        except np.linalg.LinAlgError:
            # If Cholesky decomposition fails, adjust the correlation matrix slightly
            correlation_matrix += np.eye(n) * 0.01  # Adjust diagonal elements slightly

    # Generate random standard deviations
    #standard_deviations = np.random.uniform(0.5, 2, size=n)
    
    variance_outsideopt = np.random.uniform(30,40)
    variance_products = np.random.uniform(0.5,2,size=n-1)
    standard_deviations = np.hstack((variance_outsideopt,variance_products))
    # Construct diagonal matrix from standard deviations
    diagonal_matrix = np.diag(standard_deviations)
    #diagonal_matrix = np.eye(n)

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix

# %%
def is_positive_semidefinite(matrix):
    """
    Check if a matrix is positive semidefinite.
    
    Args:
        matrix (numpy.ndarray): The matrix to check.
        
    Returns:
        bool: True if the matrix is positive semidefinite, False otherwise.
    """
    # Check if the matrix is symmetric
    if not np.allclose(matrix, matrix.T):
        return False
    
    # Check if all eigenvalues are non-negative
    eigvals, _ = np.linalg.eig(matrix)
    return np.all(eigvals >= 0)

# %%
def collection_distribution_prob_neg(n,collection):
    # generate mean 
    #mu = np.random.uniform(-2,2,n)
    mu_0 = np.random.uniform(6,10)
    mu_1n = np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    # generate covariance matrix with positive correlation
    neg_cov = generate_negatively_correlated_covariance_matrix(n)
    if is_positive_semidefinite(neg_cov): 
        sample_size = 10000
        utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    else:
        print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 
        
        
        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_instance = collection_distribution_prob_neg(n,whole_collection)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-11:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(jd_collection,jd_offertimes)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-11:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:

            
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples) '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
       

        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        ''' df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst) '''
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
def mnl_mle_pyo(data, collection,offertimes):
    n = data.shape[0]
    model = pyo.ConcreteModel()
    model.v = pyo.Var(range(n), bounds=(-50,50))
    
    def obj_rule(model):
        obj = 0
        for i in range(len(collection)):
            for j in collection[i]:
                obj += offertimes[i]*data[j][i] * model.v[j]
            obj -= offertimes[i]*pyo.log(sum([pyo.exp(model.v[k]) for k in collection[i]]))
        return obj
    
    model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)
    
    # scale the preference of the outside option to be 1
    model.outsideopt_constraint = pyo.Constraint(expr=model.v[0] == 0)
    
    opt = pyo.SolverFactory('ipopt')  # use iterior point method to solve convex optimizatio problem 
    results = opt.solve(model)
    
    if (results.solver.status == pyo.SolverStatus.ok) and (results.solver.termination_condition == pyo.TerminationCondition.optimal):
        v_values = [model.v[i].value for i in range(n)]
        obj_value = model.obj()
        #model.pprint()
        return v_values, obj_value,results.solver.time
    else:
        raise ValueError("Solver failed to find an optimal solution.")

# %%
def mnl_distribution(v, collection):
    collection_distribution = np.zeros((len(v), len(collection)))
    for i, curr_collection in enumerate(collection):
        curr_total_v = np.sum([np.exp(v[j]) for j in curr_collection])
        for k, idx in enumerate(curr_collection):
            collection_distribution[idx][i] = np.exp(v[idx]) / curr_total_v
    
    return collection_distribution

# %%
def compute_collection(n):
    collection = []
    for i in range(n):
        subset = set(range(n)) - {i}
        collection.append(list(subset))
    return collection

# %%
compute_collection(3)
# Out:
# [[1, 2], [0, 2], [0, 1]]

# %%
def mccm_w_mnl(v_values,collection):
    probability_collection = mnl_distribution(v_values,collection)
    
    lam = np.zeros(len(v_values))
    rho = np.zeros((len(v_values),len(v_values)))
    u_values = np.zeros(len(v_values))
    ## compute u_values
    for i in range(len(v_values)):
        u_values[i] = np.exp(v_values[i])

    # compute lambda (initial probabilities)
    for i in range(len(v_values)):
        lam[i] = u_values[i]/np.sum(u_values)
        
    # compute transition matrix
    rho[0,0] = 1
    
    transition_collection = compute_collection(len(v_values))
    transition_collection_prob = mnl_distribution(v_values,transition_collection)
    for i in range(1,len(v_values)):
        rho[0,i] = 0
        for j in range(len(v_values)):
            if i !=j:
                rho[i,j] = (transition_collection_prob[j,i] - lam[j])/lam[i]
                if rho[i,j]<0:
                    print('transition matrix computation error')
                    sys.exit()
    
    return lam,rho,probability_collection

# %%
def mccm_mle_w_mnl_intial(data, collection,x_intial, lam_intial, rho_initial,offertimes):
    
    model = pyo.ConcreteModel(name="mccm_mle_w_initial")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    for i in range(n):
        model.lam[i] = lam_intial[i]
        for j in range(m):
            model.x[i,j] = x_intial[i,j]
    
    for i in range(n):
        for j in range(n):
            model.rho[i,j] = rho_initial[i,j]

    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]* data[i, j] * pyo.log(model.x[i, j]) for i in collection[j] ) for j in range(m)), sense=pyo.maximize)
    #model.obj = Objective(expr=0,sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                #model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    #solver_options = {'max_iter': 15000, 'tol': 1e-4} 
    solver.options['max_iter'] = 10000
    #solver.options['tol'] = 1e-6
    
    try:
        # Your optimization solve code here
        #results = solver.solve(model)
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            y_values = [[model.y[i, j].value for j in range(m)] for i in range(n)]
            y_values = np.array(y_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values,lam_values,rho_values,y_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM MLE with MNL initial solution: No solution found or an error occurred.')
        #model.pprint()
        return [-100000, np.zeros((n,m)), np.zeros(n), np.zeros((n,n)), np.zeros((n,m)), -1]

# %%
def mccm_mle(data, collection,offertimes):
    
    model = pyo.ConcreteModel(name="mccm_mle")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals, name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    #model.abs_var = Var(range(n), range(m), within=NonNegativeReals, initialize=0, name="abs_val")
    
    for i in range(n):
        for j in range(n):
            if i != j:
                model.rho[i,j].setlb(0.00001) 
    
    for i in range(m):
        for j in collection[i]:
            model.x[j,i].setlb(0.00001)
    
    #model.obj = Objective(expr=sum(offer_times[j] * data[i, j] * model.abs_var[i, j] for i in range(n) for j in range(m)), sense=minimize)
    model.obj = pyo.Objective(expr= sum( sum(offertimes[j] * data[i, j] * pyo.log(model.x[i, j]) for i in collection[j]) for j in range(m)),sense=pyo.maximize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                #model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                #model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
                #model.norm_constraint.add(model.x[j, i] == model.lam[j] + sum(model.y[k, i] * model.rho[k, j] for k in not_in_assortment[i]))
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                #model.norm_constraint.add(model.y[j, i] == model.lam[j] + sum(model.y[k, i] * model.rho[k, j] for k in not_in_assortment[i]))
                #model.norm_constraint.add(model.abs_var[j, i] == 0)
            
    
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    

    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    #solver.options['tol'] = 1e-9
    
    try:
        # Your optimization solve code here
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            
            y_values = [[model.y[i, j].value for j in range(m)] for i in range(n)]
            y_values = np.array(y_values)
            
            # Retrieve the solver runtime
            #model.pprint()
            return [pyo.value(model.obj), x_values, lam_values, rho_values, y_values, results.solver.time]
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM MLE with LB: No solution found or an error occurred.')
        #model.pprint()
        return [-100000, np.zeros((n,m)), np.zeros(n), np.zeros((n,n)), np.zeros((n,m)), -1]

# %%
def mccm_mle_nolb(data, collection,offertimes):
    model = pyo.ConcreteModel(name="mccm_mle")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals,bounds=(0.0001,1), name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals, name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    #model.abs_var = Var(range(n), range(m), within=NonNegativeReals, initialize=0, name="abs_val")
    
    #model.obj = Objective(expr=sum(offer_times[j] * data[i, j] * model.abs_var[i, j] for i in range(n) for j in range(m)), sense=minimize)
    model.obj = pyo.Objective(expr= sum( sum(offertimes[j] *data[i, j] * pyo.log(model.x[i, j]) for i in collection[j]) for j in range(m)),sense=pyo.maximize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                #model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                #model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
                #model.norm_constraint.add(model.x[j, i] == model.lam[j] + sum(model.y[k, i] * model.rho[k, j] for k in not_in_assortment[i]))
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                #model.norm_constraint.add(model.y[j, i] == model.lam[j] + sum(model.y[k, i] * model.rho[k, j] for k in not_in_assortment[i]))
                #model.norm_constraint.add(model.abs_var[j, i] == 0)
            
    
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    

    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    
    try:
        # Your optimization solve code here
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            
            y_values = [[model.y[i, j].value for j in range(m)] for i in range(n)]
            y_values = np.array(y_values)
            
            # Retrieve the solver runtime
            #model.pprint()
            return [pyo.value(model.obj), x_values, lam_values, rho_values, y_values, results.solver.time]
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('Directly solve MCCM MLE: No solution found or an error occurred.')
        #model.pprint()
        return [-100000, np.zeros((n,m)), np.zeros(n), np.zeros((n,n)), np.zeros((n,m)), -1]

# %%
def mccm_mle_tol(data, collection,offertimes):
    model = pyo.ConcreteModel(name="mccm_mle_tol")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
            
    #model.obj = Objective(expr=sum(offer_times[j] * data[i, j] * model.abs_var[i, j] for i in range(n) for j in range(m)), sense=minimize)
    model.obj = pyo.Objective(expr= sum( sum(offertimes[j]* data[i, j] * pyo.log(model.x[i, j]) for i in collection[j]) for j in range(m)),sense=pyo.maximize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)

    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
  

    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    solver.options['tol'] = 1e-6
    #solver.options['print_level'] = 5
    
    
    try:
        # Your optimization solve code here
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            
            y_values = [[model.y[i, j].value for j in range(m)] for i in range(n)]
            y_values = np.array(y_values)
            
            # Retrieve the solver runtime
            
            #model.pprint()
            #print("Solver runtime:", runtime)
            #print('model objective', value(model.obj))
            return [pyo.value(model.obj), x_values, lam_values, rho_values, y_values, results.solver.time]
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM MLE with tolerence 1e-6: No solution found or an error occurred.')
        #model.pprint()
        return [-100000, np.zeros((n,m)), np.zeros(n), np.zeros((n,n)), np.zeros((n,m)), -1]

# %%
def mccm_revenue_prediction(lam, trans_matrix, assortment,price):
    # Model
    model = gp.Model()
    #model.Params.FeasibilityTol = 1e-4
    model.setParam('OutputFlag', 0)

    # Variables
    x = model.addVars(len(lam), vtype=GRB.CONTINUOUS,lb =0.0,name='x')
    y = model.addVars(len(lam), vtype=GRB.CONTINUOUS,lb=0.0, name='y')

    # Constraints
    model.addConstr(sum(x[i] for i in assortment)==1, 'normalization')
    
    not_in_assortment = []
    for i in range(len(lam)):
        if i not in assortment:
            not_in_assortment.append(i)
    #print('current assortment',assortment)
    #print('current compliment',not_in_assortment)

    for i in range(len(lam)):
        if i in assortment:
            model.addConstr(y[i] == 0, f'y_{i}_equals_0')
            model.addConstr(x[i] - lam[i] - sum(y[j] * trans_matrix[j][i] for j in not_in_assortment) == 0, f'balance_{i}')
        else:
            model.addConstr(x[i] == 0, f'x_{i}_equals_0')
            model.addConstr(y[i] - lam[i] -sum(y[j] * trans_matrix[j][i] for j in not_in_assortment) == 0, f'balance_{i}' )
            
    # Objective
    model.setObjective(sum(price[i]*x[i] for i in assortment), GRB.MAXIMIZE)
    #model.setObjective(0, GRB.MAXIMIZE)

    # Solve
    model.optimize()
    #print('MCCM LP solver status',model.status)
    if model.status == gp.GRB.OPTIMAL:
        # Extract variable values
        x_values = [x[i].x for i in range(len(lam))]

        # Check probability constraint
        if abs(sum(x_values) - 1) > 0.00001:
            print('Probability error')

        return model.objVal,x_values,model.Runtime

    if model.status == gp.GRB.INFEASIBLE:
        print("The model is infeasible.")
    if model.status == gp.GRB.UNBOUNDED:
        print("The model is unbounded.")
    # Check solution
    if model.status != GRB.OPTIMAL:
        print("Optimization failed to find an optimal solution")
        ''' model.computeIIS()
        infeas_constraints = [c.constrName for c in model.getConstrs() if c.IISConstr]
        print("The following constraints contribute to infeasibility:")
        print(infeas_constraints) '''
        return 0,np.zeros(n),-1

# %%
def mccm_prediction_tol(lam, trans_matrix, assortment,price):
    # Model
    
    model = gp.Model()
    model.Params.FeasibilityTol = 1e-3
    
    #model.setParam('DualReductions', 0)
    model.setParam('outputFlag',0)
    #model.setParam('BarHomogeneous', 1)

    #model.setParam('OutputFlag', 0)

    # Variables
    x = model.addVars(len(lam), vtype=GRB.CONTINUOUS,lb=0.0, name='x')
    y = model.addVars(len(lam), vtype=GRB.CONTINUOUS,lb=0.0, name='y')

    # Constraints
    model.addConstr(sum(x[i] for i in assortment)==1, 'normalization')
    
    not_in_assortment = []
    for i in range(len(lam)):
        if i not in assortment:
            not_in_assortment.append(i)
    #print('current assortment',assortment)
    #print('current compliment',not_in_assortment)

    for i in range(len(lam)):
        if i in assortment:
            model.addConstr(y[i] == 0, f'y_{i}_equals_0')
            model.addConstr(x[i] - lam[i] - sum(y[j] * trans_matrix[j][i] for j in not_in_assortment) == 0, f'balance_{i}')
        else:
            model.addConstr(x[i] == 0, f'x_{i}_equals_0')
            model.addConstr(y[i] - lam[i] -sum(y[j] * trans_matrix[j][i] for j in not_in_assortment) == 0, f'balance_{i}' )
    
    ''' for i in range(len(lam)):
        model.addConstr(x[i]+y[i] == lam[i] + sum(y[j]* trans_matrix[j][i] for j in range(len(lam))),f'balance_{i}' )
        if i in assortment:
            model.addConstr(y[i]==0, f'y_{i}_equals_0')
        else:
            model.addConstr(x[i]==0, f'x_{i}_equals_0') '''
            
    # Objective
    model.setObjective(sum(price[i]*x[i] for i in assortment), GRB.MAXIMIZE)
    #model.setObjective(0, GRB.MAXIMIZE)

    # Solve
    model.optimize()
    #print('MCCM LP solver status',model.status)
    #model.write("mccm_revenue.lp")
    if model.status == gp.GRB.OPTIMAL:
        # Extract variable values
        x_values = [x[i].x for i in range(len(lam))]

        # Check probability constraint
        if abs(sum(x_values) - 1) > 0.00001:
            print('Probability error')

        return model.objVal,x_values,model.Runtime
    
    ''' if model.status == gp.GRB.INFEASIBLE:
        print("The model is infeasible.")
        model.computeIIS()
        infeas_constraints = [c.constrName for c in model.getConstrs() if c.IISConstr]
        print("The following constraints contribute to infeasibility:")
        print(infeas_constraints)
    # Check dual information
        dual_values = model.getAttr("Pi", model.getConstrs())
        for constr, dual_value in zip(model.getConstrs(), dual_values):
            print(f"Dual value for constraint {constr.ConstrName}: {dual_value}")
    elif model.status == gp.GRB.UNBOUNDED:
        print("The model is unbounded.")
        # Check reduced costs
        reduced_costs = model.getAttr("RC", model.getVars())
        for var, reduced_cost in zip(model.getVars(), reduced_costs):
            print(f"Reduced cost for variable {var.VarName}: {reduced_cost}") '''

    # Check solution
    if model.status != GRB.OPTIMAL:
        print("Optimization failed to find an optimal solution")
        
        return 0,np.zeros(n),-1

# %%
def mccm_distribution(collection, lam_values, rho_values,price):
    prob = np.zeros((len(lam_values),len(collection)))
    revenue = []
    runtime = []
    
    for i in range(len(collection)):
        #prob[:,i]  = mccm_balance(lam_values, rho_values, collection[i])
        curr_assortment = collection[i]
        print(f'solve assortment {curr_assortment}')
        curr_rev,curr_prob,curr_runtime = mccm_revenue_prediction(lam_values, rho_values, collection[i],price)
        if curr_runtime <0:
            curr_rev,curr_prob,curr_runtime = mccm_prediction_tol(lam_values, rho_values, collection[i],price)
        print('optimal reveue is ',curr_rev)  
        prob[:,i] = curr_prob
        revenue.append(curr_rev)
        runtime.append(curr_runtime)
        #print('probability comparison:\n ',prob[:,i])
        #print(curr_prob)
    return revenue,prob,runtime

# %%
## prediction for the current testing collection of assortments 
def mccm_prediction(curr_test_instance,curr_test_collection,price,lam_values, rho_values):
    ''' true assortment ranking '''
    true_choice_prob = [] 
    true_revenue = []
    
    #mccm_revenue = []
    #mccm_sales = []
    
    #mccm_runtime = []
    
    
    for k in range(len(curr_test_collection)):

        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        true_choice_prob.append(curr_test_instance[:,k])
        
    mccm_revenue,mccm_sales,mccm_runtime = mccm_distribution(curr_test_collection,lam_values,rho_values,price)
        
    return true_revenue,true_choice_prob,mccm_revenue,mccm_sales,mccm_runtime

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record representability of all instances

## record the kendall tau distance between the predicted ranking of mccm and the truth
all_mccm_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_rev_list = []
all_best_rev_mccm_list = []  

## record the difference in best assortment
all_mccm_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mccm_revenue_list = []

all_true_prob_list = [] 
all_mccm_sales_list = []

all_true_ranking = []
all_mccm_ranking = []

## record the runtime of mccm prediction
all_mccm_pred_runtime = []

for i in range(len(all_full_collections)):
       
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mccm_best_rev_collection = [] # a container for the best revenue predicted by robust mccm
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mccm_ranking_collection = [] # a container for ranking by robust mccm
    
    mccm_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mccm
   
    
    true_choice_prob_collection = []
    mccm_sales_frac_collection = []

    true_revenue_collection = []
    mccm_revenue_collection = []
    
    mccm_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        
        ########### mccm prediction#################
        v_values, obj_value,runtime = mnl_mle_pyo(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
        mnl_lam,mnl_rho,initial_probability = mccm_w_mnl(v_values,all_train_collection[i][j])
        ll, choice_prob, lam_values, rho_values, y_values, ll_time = mccm_mle_w_mnl_intial(all_train_instances[i][j],all_train_collection[i][j],initial_probability,mnl_lam,mnl_rho,all_train_offertimes[i][j])
        
        if ll_time>0:
            true_revenue,true_choice_prob,mccm_revenue,mccm_sales,mccm_runtime = mccm_prediction(all_test_instance[i][j],all_test_collection[i][j],price,lam_values, rho_values)
        
        if ll_time<0 or np.any(np.array(mccm_runtime)<0):
            print('MLE:cannot solve MLE with mnl initial soluntion')
            ll, choice_prob, lam_values, rho_values, y_values, ll_time = mccm_mle(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
            if ll_time>0:
                true_revenue,true_choice_prob,mccm_revenue,mccm_sales,mccm_runtime = mccm_prediction(all_test_instance[i][j],all_test_collection[i][j],price,lam_values, rho_values)
        
        if ll_time<0 or np.any(np.array(mccm_runtime)<0):
            
            print(f'MLE:adjust mle lb ')
            
            ll, choice_prob, lam_values, rho_values, y_values, ll_time = mccm_mle_nolb(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
            if ll_time>0:
                true_revenue,true_choice_prob,mccm_revenue,mccm_sales,mccm_runtime = mccm_prediction(all_test_instance[i][j],all_test_collection[i][j],price,lam_values, rho_values)
        
        if ll_time<0 or np.any(np.array(mccm_runtime)<0):
            print(f'MLE:adjust tolerence parameters ')
            
            ll, choice_prob, lam_values, rho_values, y_values, ll_time = mccm_mle_tol(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
            if ll_time>0:
                true_revenue,true_choice_prob,mccm_revenue,mccm_sales,mccm_runtime = mccm_prediction(all_test_instance[i][j],all_test_collection[i][j],price,lam_values, rho_values)
        
        
    ### compute mle with mnl mle 
        ll_w_mnl = 0
        for x in range(len(all_train_collection[i][j])):
            for y in all_train_collection[i][j][x]:
                ll_w_mnl = ll_w_mnl + all_train_instances[i][j][y][x] * math.log(initial_probability[y][x])
        if ll < ll_w_mnl:
            lam_values = mnl_lam
            rho_values = mnl_rho
        if ll_time<0 or np.any(np.array(mccm_runtime)<0):
            true_revenue,true_choice_prob,mccm_revenue,mccm_sales,mccm_runtime = mccm_prediction(all_test_instance[i][j],all_test_collection[i][j],price,lam_values, rho_values)
        
        # the following lists are of the same size as number of testing assortments
        if np.any(np.array(mccm_runtime)<0):
            print('Prediction error to check')
            print('the current instances is offertimes {i} and instance {j}')
            sys.exit()
        
        total_runtime = []
        for x in range(len(mccm_runtime)):
            total_runtime.append(ll_time+mccm_runtime[x])
        
        true_revenue_collection.append(true_revenue)
        true_choice_prob_collection.append(true_choice_prob)
        
        mccm_revenue_collection.append(mccm_revenue)   
        mccm_sales_frac_collection.append(mccm_sales)
        mccm_runtime_collection.append(total_runtime)
         
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_mccm_rank  = np.argsort(-np.array(mccm_revenue)) 
        mccm_ranking_collection.append(curr_mccm_rank)
        mccm_best_rev_collection.append(true_revenue[curr_mccm_rank[0]])
        
        
        #  mccm kendallTau Distance for current instance [i][j]
        curr_mccm_dist = kendall_tau_distance(curr_true_rank, curr_mccm_rank)
        mccm_distance_collection.append(curr_mccm_dist)
    
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mccm_distance_list.append(mccm_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_rev_list.append(true_best_rev_collection) 
    all_best_rev_mccm_list.append(mccm_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_mccm_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(mccm_best_rev_collection))/ np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    
    all_mccm_revenue_list.append(mccm_revenue_collection)
    
    all_true_prob_list.append(true_choice_prob_collection)
    all_mccm_sales_list.append(mccm_sales_frac_collection)
 
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mccm_ranking.append(mccm_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mccm_pred_runtime.append(mccm_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# solve assortment [0, 5]
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# optimal reveue is  0.3323555665662381
# solve assortment [0, 3, 7]
# optimal reveue is  0.1484435092249938
# solve assortment [0, 5, 6]
# optimal reveue is  0.2932774747998774
# solve assortment [0, 5, 8]
# optimal reveue is  0.41133779710468305
# solve assortment [0, 6, 8]
# optimal reveue is  0.30474786869074666
# testing for offertimes 20, 1th instance
# solve assortment [0, 3]
# optimal reveue is  0.13801312016826917
# solve assortment [0, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.286823034204653
# solve assortment [0, 1, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.38278001512231163
# solve assortment [0, 3, 4]
# optimal reveue is  0.2286064633192352
# solve assortment [0, 5, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2950955504624333
# testing for offertimes 20, 2th instance
# solve assortment [0, 1, 8]
# optimal reveue is  0.5135173461485311
# solve assortment [0, 2, 6]
# optimal reveue is  0.15127439104820717
# solve assortment [0, 3, 4]
# optimal reveue is  0.4424276095365845
# solve assortment [0, 4, 5]
# optimal reveue is  0.5641475951825207
# solve assortment [0, 5, 8]
# optimal reveue is  0.5308592426599419
# testing for offertimes 20, 3th instance
# solve assortment [0, 1]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1739943703433152
# solve assortment [0, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3524404395868355
# solve assortment [0, 7]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1425225760369448
# solve assortment [0, 3, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.325535291967535
# solve assortment [0, 8]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3693513066307953
# testing for offertimes 20, 4th instance
# solve assortment [0, 1, 8]
# optimal reveue is  0.447574391471397
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.15966408428490447
# solve assortment [0, 3, 8]
# optimal reveue is  0.3202680997814955
# solve assortment [0, 5, 6]
# optimal reveue is  0.27062078012091406
# solve assortment [0, 6, 7]
# optimal reveue is  0.2180056866997626
# testing for offertimes 20, 5th instance
# solve assortment [0, 1]
# optimal reveue is  0.3025523761060152
# solve assortment [0, 1, 4]
# optimal reveue is  0.45020920654121704
# solve assortment [0, 2, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1587611621818938
# solve assortment [0, 4, 7]
# optimal reveue is  0.3781308500104654
# solve assortment [0, 5, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.29538726240785956
# testing for offertimes 20, 6th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 4]
# optimal reveue is  0.5198488340916609
# solve assortment [0, 1, 3]
# optimal reveue is  0.19264724597730976
# solve assortment [0, 3, 7]
# optimal reveue is  0.1999132704468008
# solve assortment [0, 4, 8]
# optimal reveue is  0.6740157369344482
# solve assortment [0, 5, 8]
# optimal reveue is  0.5626597486010303
# testing for offertimes 20, 7th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1]
# optimal reveue is  0.23912442942966705
# solve assortment [0, 1, 6]
# optimal reveue is  0.16070399728556642
# solve assortment [0, 3, 6]
# optimal reveue is  0.11161550638714315
# solve assortment [0, 4, 5]
# optimal reveue is  0.40574158968856866
# solve assortment [0, 8]
# optimal reveue is  0.3563170249259921
# testing for offertimes 20, 8th instance
# solve assortment [0, 1]
# optimal reveue is  0.2903270717720458
# solve assortment [0, 7]
# optimal reveue is  0.19364652364589596
# solve assortment [0, 1, 8]
# optimal reveue is  0.3477709209896406
# solve assortment [0, 4, 6]
# optimal reveue is  0.2813498350016048
# solve assortment [0, 8]
# optimal reveue is  0.4244676220096219
# testing for offertimes 20, 9th instance
# solve assortment [0, 1]
# optimal reveue is  0.3002191079462993
# solve assortment [0, 1, 3]
# optimal reveue is  0.28960307198250185
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.1591119208142856
# solve assortment [0, 3, 5]
# optimal reveue is  0.3223577911315023
# solve assortment [0, 4, 8]
# optimal reveue is  0.5193257789755519
# testing for offertimes 20, 10th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1, 3]
# optimal reveue is  0.20228947188264634
# solve assortment [0, 2, 6]
# optimal reveue is  0.17399025978688182
# solve assortment [0, 3, 4]
# optimal reveue is  0.32751349673655406
# solve assortment [0, 3, 6]
# optimal reveue is  0.12917427898134956
# solve assortment [0, 5, 6]
# optimal reveue is  0.2693796026212666
# testing for offertimes 20, 11th instance
# solve assortment [0, 1, 3]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.22020685311782576
# solve assortment [0, 1, 7]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2666970463918923
# solve assortment [0, 2, 6]
# optimal reveue is  0.10687861760925904
# solve assortment [0, 4, 6]
# optimal reveue is  0.3284037896856201
# solve assortment [0, 5, 6]
# optimal reveue is  0.289453987689988
# testing for offertimes 20, 12th instance
# solve assortment [0, 1]
# optimal reveue is  0.27295815433586784
# solve assortment [0, 1, 5]
# optimal reveue is  0.41978494755564244
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.18018697965424693
# solve assortment [0, 3, 6]
# optimal reveue is  0.18225227845196276
# solve assortment [0, 6, 7]
# optimal reveue is  0.2592154414266406
# testing for offertimes 20, 13th instance
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle_w_initial;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 4]
# optimal reveue is  0.4823948154934671
# solve assortment [0, 6]
# optimal reveue is  0.08585129520870716
# solve assortment [0, 4, 5]
# optimal reveue is  0.5044904281066814
# solve assortment [0, 4, 8]
# optimal reveue is  0.5096541462901849
# solve assortment [0, 6, 8]
# optimal reveue is  0.4516666475504192
# testing for offertimes 20, 14th instance
# solve assortment [0, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.46429547013231254
# solve assortment [0, 1, 5]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.361998953782689
# solve assortment [0, 1, 6]
# optimal reveue is  0.27323766561549473
# solve assortment [0, 4, 8]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.5285812175004467
# solve assortment [0, 8]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.5187239398296097
# testing for offertimes 20, 15th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.16575282741749908
# solve assortment [0, 3, 5]
# optimal reveue is  0.25796367021359917
# solve assortment [0, 4, 7]
# optimal reveue is  0.2207546106685349
# solve assortment [0, 4, 8]
# optimal reveue is  0.5500333274956535
# solve assortment [0, 6, 7]
# optimal reveue is  0.21094214577056514
# testing for offertimes 20, 16th instance
# solve assortment [0, 7]
# optimal reveue is  0.43599179792284554
# solve assortment [0, 1, 5]
# optimal reveue is  0.8478957585049958
# solve assortment [0, 3, 7]
# optimal reveue is  0.45069695955744865
# solve assortment [0, 4, 6]
# optimal reveue is  0.8476510486791768
# solve assortment [0, 8]
# optimal reveue is  0.9036368281227091
# testing for offertimes 20, 17th instance
# solve assortment [0, 1, 8]
# optimal reveue is  0.44952467614758906
# solve assortment [0, 3, 4]
# optimal reveue is  0.45836545702518083
# solve assortment [0, 3, 5]
# optimal reveue is  0.3187819001510089
# solve assortment [0, 3, 7]
# optimal reveue is  0.23979623933355715
# solve assortment [0, 6, 8]
# optimal reveue is  0.33577302784250296
# testing for offertimes 20, 18th instance
# solve assortment [0, 2]
# optimal reveue is  0.1340138352677376
# solve assortment [0, 1, 3]
# optimal reveue is  0.2572183602597228
# solve assortment [0, 3, 4]
# optimal reveue is  0.2414513471617389
# solve assortment [0, 4, 8]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.5042818997861037
# solve assortment [0, 6, 8]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3367382044525312
# testing for offertimes 20, 19th instance
# solve assortment [0, 6]
# optimal reveue is  0.1510157176483915
# solve assortment [0, 1, 8]
# optimal reveue is  0.40185203006457604
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.15677930194268755
# solve assortment [0, 4, 6]
# optimal reveue is  0.2570327063664638
# solve assortment [0, 5, 8]
# optimal reveue is  0.41635425213831345
# testing for offertimes 20, 20th instance
# solve assortment [0, 1, 7]
# optimal reveue is  0.23770590834652844
# solve assortment [0, 3, 6]
# optimal reveue is  0.14725421500166008
# solve assortment [0, 4, 7]
# optimal reveue is  0.4386649435403082
# solve assortment [0, 5, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1780771366362386
# solve assortment [0, 8]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.382903123777581
# testing for offertimes 20, 21th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 3]
# optimal reveue is  0.10667702725331457
# solve assortment [0, 1, 7]
# optimal reveue is  0.23591796135516652
# solve assortment [0, 2, 6]
# optimal reveue is  0.12708808466072485
# solve assortment [0, 4, 6]
# optimal reveue is  0.2873120135706377
# solve assortment [0, 4, 8]
# optimal reveue is  0.41011007165252666
# testing for offertimes 20, 22th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 4]
# optimal reveue is  0.4294770588209781
# solve assortment [0, 6]
# optimal reveue is  0.12500212314349307
# solve assortment [0, 3, 5]
# optimal reveue is  0.3027105275861851
# solve assortment [0, 4, 6]
# optimal reveue is  0.30942607414731815
# solve assortment [0, 5, 6]
# optimal reveue is  0.32660841016346925
# testing for offertimes 20, 23th instance
# solve assortment [0, 1, 7]
# optimal reveue is  0.12138776555752345
# solve assortment [0, 1, 8]
# optimal reveue is  0.18973330629888807
# solve assortment [0, 3, 4]
# optimal reveue is  0.13595838653026815
# solve assortment [0, 3, 5]
# optimal reveue is  0.09282359549410994
# solve assortment [0, 6, 7]
# optimal reveue is  0.07610113993412741
# testing for offertimes 20, 24th instance
# solve assortment [0, 1]
# optimal reveue is  0.36553007586592806
# solve assortment [0, 2]
# optimal reveue is  0.1298111259642959
# solve assortment [0, 1, 5]
# optimal reveue is  0.4133016478788646
# solve assortment [0, 3, 4]
# optimal reveue is  0.49399900036527045
# solve assortment [0, 4, 8]
# optimal reveue is  0.6445686821709573
# testing for offertimes 20, 25th instance
# solve assortment [0, 1, 8]
# optimal reveue is  0.49903947332224996
# solve assortment [0, 3, 7]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.17631341385142552
# solve assortment [0, 3, 8]
# optimal reveue is  0.2501490154390225
# solve assortment [0, 4, 7]
# optimal reveue is  0.4649829415870358
# solve assortment [0, 6, 8]
# optimal reveue is  0.4511174836980637
# testing for offertimes 20, 26th instance
# solve assortment [0, 1]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.14168683513412525
# solve assortment [0, 6]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1306404032916583
# solve assortment [0, 1, 3]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.13276896314672687
# solve assortment [0, 3, 5]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.19862934177040287
# solve assortment [0, 4, 5]
# optimal reveue is  0.451959294158272
# testing for offertimes 20, 27th instance
# solve assortment [0, 7]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.17351915680472615
# solve assortment [0, 1, 3]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1810938137168142
# solve assortment [0, 3, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.1464377178109585
# solve assortment [0, 5, 6]
# optimal reveue is  0.2638634380563567
# solve assortment [0, 6, 8]
# optimal reveue is  0.31209277118821116
# testing for offertimes 20, 28th instance
# solve assortment [0, 1, 7]
# optimal reveue is  0.25068457172399233
# solve assortment [0, 1, 8]
# optimal reveue is  0.3474658074039658
# solve assortment [0, 3, 5]
# optimal reveue is  0.29203720856030174
# solve assortment [0, 3, 7]
# optimal reveue is  0.1477936011172879
# solve assortment [0, 6, 8]
# optimal reveue is  0.26311411860227685
# testing for offertimes 20, 29th instance
# solve assortment [0, 1, 4]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.31443526369161645
# solve assortment [0, 1, 7]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2548932838664377
# solve assortment [0, 2, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.13340051627057364
# solve assortment [0, 3, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.12319780072390199
# solve assortment [0, 4, 6]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.266678468849874
# testing for offertimes 20, 30th instance
# solve assortment [0, 1]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.32467469259311754
# solve assortment [0, 1, 8]
# optimal reveue is  0.4628907153490758
# solve assortment [0, 3, 8]
# optimal reveue is  0.4190890964797362
# solve assortment [0, 4, 8]
# optimal reveue is  0.5381856423594747
# solve assortment [0, 5, 8]
# optimal reveue is  0.5197673157003538
# testing for offertimes 20, 31th instance
# solve assortment [0, 3, 5]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.33097744491586767
# solve assortment [0, 4, 8]
# optimal reveue is  0.5410317767412652
# solve assortment [0, 6, 7]
# optimal reveue is  0.17046595790817592
# solve assortment [0, 6, 8]
# optimal reveue is  0.347397557697962
# solve assortment [0, 8]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.48045580409241234
# testing for offertimes 20, 32th instance
# solve assortment [0, 5]
# optimal reveue is  0.13844573338842864
# solve assortment [0, 3, 5]
# optimal reveue is  0.1794305812280368
# solve assortment [0, 3, 6]
# optimal reveue is  0.14918718235234682
# solve assortment [0, 5, 6]
# optimal reveue is  0.2099475247044562
# solve assortment [0, 5, 8]
# optimal reveue is  0.4142149878916611
# testing for offertimes 20, 33th instance
# solve assortment [0, 2]
# optimal reveue is  0.016420407626339603
# solve assortment [0, 7]
# optimal reveue is  0.026777403009602924
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.06160689088419445
# solve assortment [0, 3, 4]
# optimal reveue is  0.14327887759844352
# solve assortment [0, 6, 8]
# optimal reveue is  0.11641660505889892
# testing for offertimes 20, 34th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 7]
# optimal reveue is  0.21803285544558945
# solve assortment [0, 1, 7]
# optimal reveue is  0.26876330978513574
# solve assortment [0, 3, 5]
# optimal reveue is  0.2433927027750537
# solve assortment [0, 3, 6]
# optimal reveue is  0.15407158989593372
# solve assortment [0, 3, 7]
# optimal reveue is  0.18167482777612198
# testing for offertimes 20, 35th instance
# solve assortment [0, 1]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.15126587129920985
# solve assortment [0, 1, 7]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.24250994054880395
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.15697628051522372
# solve assortment [0, 3, 4]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2830663258005288
# solve assortment [0, 6, 7]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.18217189484735324
# testing for offertimes 20, 36th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1, 6]
# optimal reveue is  0.2275340902557924
# solve assortment [0, 2, 6]
# optimal reveue is  0.14866062746880265
# solve assortment [0, 3, 6]
# optimal reveue is  0.1380001220652038
# solve assortment [0, 3, 8]
# optimal reveue is  0.25636542300302245
# solve assortment [0, 5, 8]
# optimal reveue is  0.42560948046615277
# testing for offertimes 20, 37th instance
# solve assortment [0, 1]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2577519721148288
# solve assortment [0, 1, 3]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.24472134359435788
# solve assortment [0, 3, 8]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3845604445266326
# solve assortment [0, 4, 5]
# optimal reveue is  0.49460065543739146
# solve assortment [0, 5, 8]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.46777692799172554
# testing for offertimes 20, 38th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 3]
# optimal reveue is  0.07460254258958018
# solve assortment [0, 6]
# optimal reveue is  0.10166069374767424
# solve assortment [0, 3, 6]
# optimal reveue is  0.12788075298787155
# solve assortment [0, 3, 7]
# optimal reveue is  0.1783348167639521
# solve assortment [0, 6, 8]
# optimal reveue is  0.4194537186520457
# testing for offertimes 20, 39th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1, 4]
# optimal reveue is  0.36726637510003934
# solve assortment [0, 3, 6]
# optimal reveue is  0.13535669858114768
# solve assortment [0, 5, 8]
# optimal reveue is  0.420730563451126
# solve assortment [0, 6, 7]
# optimal reveue is  0.17287483629793737
# solve assortment [0, 6, 8]
# optimal reveue is  0.3165882229504288
# testing for offertimes 20, 40th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# Directly solve MCCM MLE: No solution found or an error occurred.
# MLE:adjust tolerence parameters
# solve assortment [0, 2]
# optimal reveue is  0.15133730779671492
# solve assortment [0, 3]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 4, 6]
# optimal reveue is  0.2429651887981042
# solve assortment [0, 6, 7]
# optimal reveue is  0.23427073003848173
# solve assortment [0, 6, 8]
# optimal reveue is  0.40286170596756254
# solve assortment [0, 2]
# optimal reveue is  0.456
# solve assortment [0, 3]
# optimal reveue is  0.391
# solve assortment [0, 4, 6]
# optimal reveue is  1.0655
# solve assortment [0, 6, 7]
# optimal reveue is  0.5720000000000002
# solve assortment [0, 6, 8]
# optimal reveue is  0.9980000000000002
# testing for offertimes 20, 41th instance
# solve assortment [0, 1]
# optimal reveue is  0.5611322545656964
# solve assortment [0, 1, 3]
# optimal reveue is  0.5109711377761418
# solve assortment [0, 1, 4]
# optimal reveue is  1.0128835076256246
# solve assortment [0, 2, 6]
# optimal reveue is  0.36197058854881253
# solve assortment [0, 5, 6]
# optimal reveue is  0.611136168826578
# testing for offertimes 20, 42th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 4]
# optimal reveue is  0.1528994627985171
# solve assortment [0, 6]
# optimal reveue is  0.08876226213230248
# solve assortment [0, 1, 4]
# optimal reveue is  0.320277632317142
# solve assortment [0, 3, 8]
# optimal reveue is  0.22568481342381944
# solve assortment [0, 5, 8]
# optimal reveue is  0.47127355679158833
# testing for offertimes 20, 43th instance
# solve assortment [0, 3]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.0993274449411478
# solve assortment [0, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.13322073616071664
# solve assortment [0, 1, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.516789397742182
# solve assortment [0, 1, 5]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3782892443609367
# solve assortment [0, 1, 7]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2606744803631865
# testing for offertimes 20, 44th instance
# solve assortment [0, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.12175713067199054
# solve assortment [0, 1, 4]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3926277882657346
# solve assortment [0, 3, 5]
# optimal reveue is  0.270486238921137
# solve assortment [0, 4, 5]
# optimal reveue is  0.4087643161125535
# solve assortment [0, 4, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.2887913649917284
# testing for offertimes 20, 45th instance
# solve assortment [0, 1, 5]
# optimal reveue is  0.1310580323505933
# solve assortment [0, 1, 6]
# optimal reveue is  0.1259977014909221
# solve assortment [0, 2, 6]
# optimal reveue is  0.08834851972383895
# solve assortment [0, 3, 4]
# optimal reveue is  0.15263202444601565
# solve assortment [0, 4, 7]
# optimal reveue is  0.17914581727374276
# testing for offertimes 20, 46th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1]
# optimal reveue is  0.1554851943604949
# solve assortment [0, 4]
# optimal reveue is  0.47531336561546866
# solve assortment [0, 1, 5]
# optimal reveue is  0.3795543917762876
# solve assortment [0, 1, 8]
# optimal reveue is  0.5193007865956223
# solve assortment [0, 3, 4]
# optimal reveue is  0.34291271238916254
# testing for offertimes 20, 47th instance
# solve assortment [0, 7]
# optimal reveue is  0.2527239211550291
# solve assortment [0, 1, 4]
# optimal reveue is  0.43229492204578235
# solve assortment [0, 1, 6]
# optimal reveue is  0.2821457207563608
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.17847312585101546
# solve assortment [0, 5, 8]
# optimal reveue is  0.5632008106937658
# testing for offertimes 20, 48th instance
# solve assortment [0, 4]
# optimal reveue is  0.6898241560761199
# solve assortment [0, 1, 4]
# optimal reveue is  0.7991344807915979
# solve assortment [0, 3, 5]
# optimal reveue is  0.5045138950322694
# solve assortment [0, 4, 8]
# optimal reveue is  1.0062866516004445
# solve assortment [0, 8]
# optimal reveue is  0.6725519125798363
# testing for offertimes 20, 49th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1]
# optimal reveue is  0.22511731418508898
# solve assortment [0, 7]
# optimal reveue is  0.18623422075418672
# solve assortment [0, 2, 3, 6]
# optimal reveue is  0.12302879015069494
# solve assortment [0, 3, 8]
# optimal reveue is  0.20577404633511423
# solve assortment [0, 6, 7]
# optimal reveue is  0.16637040788252014
# testing for offertimes 30, 0th instance
# solve assortment [0, 1]
# optimal reveue is  0.25925605139830227
# solve assortment [0, 5]
# optimal reveue is  0.2923743608384214
# solve assortment [0, 1, 3]
# optimal reveue is  0.23114548436127286
# solve assortment [0, 1, 8]
# optimal reveue is  0.35480880156514466
# testing for offertimes 30, 1th instance
# solve assortment [0, 2]
# optimal reveue is  0.15707914473322768
# solve assortment [0, 6]
# optimal reveue is  0.12972983160276155
# solve assortment [0, 3, 4]
# optimal reveue is  0.24008704661433078
# solve assortment [0, 8]
# optimal reveue is  0.5244456683363868
# testing for offertimes 30, 2th instance
# solve assortment [0, 2, 6]
# optimal reveue is  0.18479587603670816
# solve assortment [0, 3, 7]
# optimal reveue is  0.19835275057521495
# solve assortment [0, 6, 7]
# optimal reveue is  0.20646125606085042
# solve assortment [0, 6, 8]
# optimal reveue is  0.5171247878115325
# testing for offertimes 30, 3th instance
# solve assortment [0, 1, 3]
# optimal reveue is  0.20225193447298312
# solve assortment [0, 4, 5]
# optimal reveue is  0.48726457586476773
# solve assortment [0, 5, 8]
# optimal reveue is  0.4575516568788259
# solve assortment [0, 6, 8]
# optimal reveue is  0.4260061326841155
# testing for offertimes 30, 4th instance
# solve assortment [0, 1, 3]
# optimal reveue is  0.49688777695649233
# solve assortment [0, 3, 4]
# optimal reveue is  0.7218172402005782
# solve assortment [0, 3, 7]
# optimal reveue is  0.3812106792608459
# solve assortment [0, 5, 8]
# optimal reveue is  0.9886365608589414
# testing for offertimes 30, 5th instance
# solve assortment [0, 1]
# optimal reveue is  0.3166735159806018
# solve assortment [0, 1, 8]
# optimal reveue is  0.46226868350303674
# solve assortment [0, 4, 6]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.3260285619908746
# solve assortment [0, 6, 7]
# optimal reveue is  0.20353720926136565
# testing for offertimes 30, 6th instance
# solve assortment [0, 1, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.20285493173557134
# solve assortment [0, 2, 6]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.17741258827056344
# solve assortment [0, 5, 8]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.4842035189709504
# solve assortment [0, 6, 7]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.20262541355923008
# testing for offertimes 30, 7th instance
# solve assortment [0, 2]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.10270576440108833
# solve assortment [0, 5]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.22609959180082162
# solve assortment [0, 1, 5]
# optimal reveue is  0.3508393135176091
# solve assortment [0, 8]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.29315139839718946
# testing for offertimes 30, 8th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 2]
# optimal reveue is  0.14313898440829748
# solve assortment [0, 3]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 7]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 1, 5]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# MLE:adjust tolerence parameters
# solve assortment [0, 2]
# optimal reveue is  0.14277602199325912
# solve assortment [0, 3]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 7]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 1, 5]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 2]
# optimal reveue is  0.456
# solve assortment [0, 3]
# optimal reveue is  0.391
# solve assortment [0, 7]
# optimal reveue is  0.67
# solve assortment [0, 1, 5]
# optimal reveue is  1.1075
# testing for offertimes 30, 9th instance
# solve assortment [0, 3]
# The model is infeasible.
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.10064053317719555
# solve assortment [0, 6]
# optimal reveue is  0.14073439590956557
# solve assortment [0, 1, 5]
# optimal reveue is  0.36220804814092566
# solve assortment [0, 8]
# optimal reveue is  0.38269045334217916
# testing for offertimes 30, 10th instance
# solve assortment [0, 5]
# optimal reveue is  0.31163385561275714
# solve assortment [0, 1, 4]
# optimal reveue is  0.41546810452154687
# solve assortment [0, 2, 6]
# optimal reveue is  0.1547087661605422
# solve assortment [0, 4, 6]
# optimal reveue is  0.2981156922814139
# testing for offertimes 30, 11th instance
# solve assortment [0, 1]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimization failed to find an optimal solution
# optimal reveue is  0
# solve assortment [0, 2]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.10574962192350251
# solve assortment [0, 4, 5]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.500196894149965
# solve assortment [0, 4, 6]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.4224794448536571
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 1]
# optimal reveue is  0.13933055425262278
# solve assortment [0, 2]
# optimal reveue is  0.10015197191674574
# solve assortment [0, 4, 5]
# optimal reveue is  0.50650900916915
# solve assortment [0, 4, 6]
# optimal reveue is  0.3678642465266485
# testing for offertimes 30, 12th instance
# solve assortment [0, 6]
# optimal reveue is  0.11954242787117889
# solve assortment [0, 7]
# optimal reveue is  0.25106674270864027
# solve assortment [0, 3, 4]
# optimal reveue is  0.33146425110008
# solve assortment [0, 4, 6]
# optimal reveue is  0.41419198182175465
# testing for offertimes 30, 13th instance
# solve assortment [0, 2]
# optimal reveue is  0.14905259325393752
# solve assortment [0, 3, 7]
# optimal reveue is  0.2024556917595558
# solve assortment [0, 5, 6]
# optimal reveue is  0.32438490719846075
# solve assortment [0, 6, 8]
# optimal reveue is  0.39188977682393583
# testing for offertimes 30, 14th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 4]
# optimal reveue is  0.42008257945866306
# solve assortment [0, 7]
# optimal reveue is  0.20239907837445842
# solve assortment [0, 1, 7]
# optimal reveue is  0.31473931329772115
# solve assortment [0, 1, 8]
# optimal reveue is  0.4169938926787523
# testing for offertimes 30, 15th instance
# solve assortment [0, 7]
# optimal reveue is  0.22669433385721735
# solve assortment [0, 2, 6]
# optimal reveue is  0.16006157199689217
# solve assortment [0, 4, 6]
# optimal reveue is  0.43016093433300473
# solve assortment [0, 6, 7]
# optimal reveue is  0.20819558428246107
# testing for offertimes 30, 16th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# Error: Cannot load a SolverResults object with bad status: error
# Directly solve MCCM MLE: No solution found or an error occurred.
# MLE:adjust tolerence parameters
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with tolerence 1e-6: No solution found or an error occurred.
# solve assortment [0, 4]
# optimal reveue is  1.657
# solve assortment [0, 7]
# optimal reveue is  0.67
# solve assortment [0, 3, 6]
# optimal reveue is  0.4325
# solve assortment [0, 4, 6]
# optimal reveue is  1.0655
# testing for offertimes 30, 17th instance
# solve assortment [0, 1, 5]
# optimal reveue is  0.29997299427040336
# solve assortment [0, 1, 8]
# optimal reveue is  0.3398135792997127
# solve assortment [0, 3, 7]
# optimal reveue is  0.1391922890858689
# solve assortment [0, 6, 7]
# optimal reveue is  0.1816356741435078
# testing for offertimes 30, 18th instance
# solve assortment [0, 1]
# optimal reveue is  0.3078746731554592
# solve assortment [0, 1, 6]
# optimal reveue is  0.288784702820889
# solve assortment [0, 3, 6]
# optimal reveue is  0.15491115281388368
# solve assortment [0, 5, 6]
# optimal reveue is  0.23654265234495092
# testing for offertimes 30, 19th instance
# solve assortment [0, 1]
# optimal reveue is  0.24689028736230287
# solve assortment [0, 6]
# optimal reveue is  0.15034759129011174
# solve assortment [0, 1, 5]
# optimal reveue is  0.3521006192712497
# solve assortment [0, 1, 8]
# optimal reveue is  0.4106832075353049
# testing for offertimes 30, 20th instance
# solve assortment [0, 5]
# optimal reveue is  0.2583256663437008
# solve assortment [0, 7]
# optimal reveue is  0.12696586067360005
# solve assortment [0, 1, 6]
# optimal reveue is  0.21088265444451193
# solve assortment [0, 4, 6]
# ...
# solve assortment [0, 1, 6]
# optimal reveue is  0.32571787915146944
# solve assortment [0, 2, 6]
# optimal reveue is  0.19115879632722022
# testing for offertimes 50, 24th instance
# solve assortment [0, 1]
# optimal reveue is  0.01437086283552131
# solve assortment [0, 5]
# optimal reveue is  0.00967553982799529
# solve assortment [0, 2, 6]
# optimal reveue is  0.02548966157285936
# testing for offertimes 50, 25th instance
# solve assortment [0, 1, 6]
# optimal reveue is  0.29960143807741896
# solve assortment [0, 3, 6]
# optimal reveue is  0.17327552634276067
# solve assortment [0, 5, 8]
# optimal reveue is  0.5377973354971535
# testing for offertimes 50, 26th instance
# solve assortment [0, 1, 4]
# optimal reveue is  0.4403770670910043
# solve assortment [0, 3, 6]
# optimal reveue is  0.13267841925097623
# solve assortment [0, 5, 8]
# optimal reveue is  0.4124611282175227
# testing for offertimes 50, 27th instance
# solve assortment [0, 4]
# optimal reveue is  0.629306377902579
# solve assortment [0, 1, 3]
# optimal reveue is  0.2935531790287327
# solve assortment [0, 1, 6]
# optimal reveue is  0.3176956788298785
# testing for offertimes 50, 28th instance
# solve assortment [0, 3]
# optimal reveue is  0.0632427681419714
# solve assortment [0, 5]
# optimal reveue is  0.3279660264414941
# solve assortment [0, 3, 6]
# optimal reveue is  0.13496860203754632
# testing for offertimes 50, 29th instance
# solve assortment [0, 1]
# optimal reveue is  0.2857864693307884
# solve assortment [0, 1, 4]
# optimal reveue is  0.47137218521808
# solve assortment [0, 2, 6]
# optimal reveue is  0.17863262246804934
# testing for offertimes 50, 30th instance
# solve assortment [0, 2]
# optimal reveue is  0.13706137145844638
# solve assortment [0, 3, 6]
# optimal reveue is  0.15779291703675205
# solve assortment [0, 8]
# optimal reveue is  0.45747328077556143
# testing for offertimes 50, 31th instance
# solve assortment [0, 4]
# optimal reveue is  0.5188248002425857
# solve assortment [0, 1, 3]
# optimal reveue is  0.23726131786377402
# solve assortment [0, 3, 6]
# optimal reveue is  0.15089573341492307
# testing for offertimes 50, 32th instance
# solve assortment [0, 5]
# optimal reveue is  0.40328432327362995
# solve assortment [0, 2, 6]
# optimal reveue is  0.208969097370569
# solve assortment [0, 8]
# optimal reveue is  0.6347900861292434
# testing for offertimes 50, 33th instance
# solve assortment [0, 3]
# optimal reveue is  0.12764687966809288
# solve assortment [0, 2, 6]
# optimal reveue is  0.1450158635379148
# solve assortment [0, 3, 6]
# optimal reveue is  0.1371412417276543
# testing for offertimes 50, 34th instance
# solve assortment [0, 3]
# optimal reveue is  0.1432967989110934
# solve assortment [0, 5]
# optimal reveue is  0.4200311030257168
# solve assortment [0, 5, 6]
# optimal reveue is  0.4176329416297013
# testing for offertimes 50, 35th instance
# solve assortment [0, 2]
# optimal reveue is  0.13398134387838256
# solve assortment [0, 5, 6]
# optimal reveue is  0.29029634240639235
# solve assortment [0, 8]
# optimal reveue is  0.451893053288378
# testing for offertimes 50, 36th instance
# solve assortment [0, 1]
# optimal reveue is  0.3192965722220354
# solve assortment [0, 6]
# optimal reveue is  0.14380566493780247
# solve assortment [0, 1, 6]
# optimal reveue is  0.2674491200069208
# testing for offertimes 50, 37th instance
# solve assortment [0, 5]
# optimal reveue is  0.37679905331632313
# solve assortment [0, 5, 6]
# optimal reveue is  0.2813630189088929
# solve assortment [0, 8]
# optimal reveue is  0.48844660981003585
# testing for offertimes 50, 38th instance
# solve assortment [0, 3]
# optimal reveue is  0.08861328977565412
# solve assortment [0, 5]
# optimal reveue is  0.1835292516011216
# solve assortment [0, 1, 4]
# optimal reveue is  0.3947921099891626
# testing for offertimes 50, 39th instance
# solve assortment [0, 5]
# optimal reveue is  0.009604314193461751
# solve assortment [0, 1, 3]
# optimal reveue is  0.012751574885401077
# solve assortment [0, 5, 8]
# optimal reveue is  0.06840611625226299
# testing for offertimes 50, 40th instance
# solve assortment [0, 3]
# optimal reveue is  0.001914546958501509
# solve assortment [0, 1, 3]
# optimal reveue is  0.005800071862060195
# solve assortment [0, 8]
# optimal reveue is  0.006806923836017212
# testing for offertimes 50, 41th instance
# solve assortment [0, 2]
# optimal reveue is  0.09968197996195233
# solve assortment [0, 1, 4]
# optimal reveue is  0.4392045657894702
# solve assortment [0, 3, 6]
# optimal reveue is  0.1445270314942304
# testing for offertimes 50, 42th instance
# solve assortment [0, 1]
# optimal reveue is  0.3791134636630524
# solve assortment [0, 3]
# optimal reveue is  0.0969663632364145
# solve assortment [0, 1, 3]
# optimal reveue is  0.3286894298292788
# testing for offertimes 50, 43th instance
# solve assortment [0, 3]
# optimal reveue is  0.14083971812665505
# solve assortment [0, 1, 4]
# optimal reveue is  0.4720273656127396
# solve assortment [0, 3, 6]
# optimal reveue is  0.16613677399488613
# testing for offertimes 50, 44th instance
# solve assortment [0, 5]
# optimal reveue is  0.04989449107412696
# solve assortment [0, 2, 6]
# optimal reveue is  0.04043366825867486
# solve assortment [0, 3, 6]
# optimal reveue is  0.03442899420190954
# testing for offertimes 50, 45th instance
# solve assortment [0, 4]
# optimal reveue is  0.43787714286634255
# solve assortment [0, 5]
# Optimization failed to find an optimal solution
# Changed value of parameter FeasibilityTol to 0.001
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# optimal reveue is  0.33998330939319404
# solve assortment [0, 1, 6]
# optimal reveue is  0.25438853404621997
# testing for offertimes 50, 46th instance
# solve assortment [0, 5]
# optimal reveue is  0.4021188088741679
# solve assortment [0, 6]
# optimal reveue is  0.0989518028992958
# solve assortment [0, 8]
# optimal reveue is  0.5342826292303066
# testing for offertimes 50, 47th instance
# solve assortment [0, 1, 4]
# optimal reveue is  0.44369635134342067
# solve assortment [0, 2, 6]
# optimal reveue is  0.20131884104291672
# solve assortment [0, 5, 8]
# optimal reveue is  0.5368625514452916
# testing for offertimes 50, 48th instance
# solve assortment [0, 6]
# optimal reveue is  0.11802875765587871
# solve assortment [0, 1, 3]
# optimal reveue is  0.2921294906492352
# solve assortment [0, 1, 4]
# optimal reveue is  0.5471338939852366
# testing for offertimes 50, 49th instance
# solve assortment [0, 1]
# optimal reveue is  0.0051131547818592275
# solve assortment [0, 1, 4]
# optimal reveue is  0.04958451381350215
# solve assortment [0, 3, 6]
# optimal reveue is  0.01685378204061396
# testing for offertimes 60, 0th instance
# solve assortment [0, 3]
# optimal reveue is  0.0984358835353182
# solve assortment [0, 5]
# optimal reveue is  0.2587298657638441
# testing for offertimes 60, 1th instance
# solve assortment [0, 5, 6]
# optimal reveue is  0.33124082216696754
# solve assortment [0, 5, 8]
# optimal reveue is  0.5747996050088681
# testing for offertimes 60, 2th instance
# solve assortment [0, 2, 6]
# optimal reveue is  0.1835578106271572
# solve assortment [0, 5, 8]
# optimal reveue is  0.5488679259798632
# testing for offertimes 60, 3th instance
# Error: Cannot load a SolverResults object with bad status: error
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 5]
# optimal reveue is  0.32390183601994477
# solve assortment [0, 6]
# optimal reveue is  0.11582888061882281
# testing for offertimes 60, 4th instance
# solve assortment [0, 3, 6]
# optimal reveue is  0.1405943816167763
# solve assortment [0, 5, 8]
# optimal reveue is  0.4390242392549927
# testing for offertimes 60, 5th instance
# solve assortment [0, 3]
# optimal reveue is  0.13047433168043035
# solve assortment [0, 1, 6]
# optimal reveue is  0.28793331867962657
# testing for offertimes 60, 6th instance
# solve assortment [0, 5]
# optimal reveue is  0.4161963803239597
# solve assortment [0, 8]
# optimal reveue is  0.5395663941050581
# testing for offertimes 60, 7th instance
# solve assortment [0, 6]
# optimal reveue is  0.10716745964980587
# solve assortment [0, 3, 6]
# optimal reveue is  0.13343048415460063
# testing for offertimes 60, 8th instance
# solve assortment [0, 5]
# optimal reveue is  0.0044474396273451846
# solve assortment [0, 3, 6]
# optimal reveue is  0.013185635030493434
# testing for offertimes 60, 9th instance
# solve assortment [0, 1]
# optimal reveue is  0.28198261451483786
# solve assortment [0, 5, 6]
# optimal reveue is  0.23598689664744543
# testing for offertimes 60, 10th instance
# solve assortment [0, 1, 6]
# optimal reveue is  0.26107849931002525
# solve assortment [0, 3, 6]
# optimal reveue is  0.14988032938754037
# testing for offertimes 60, 11th instance
# solve assortment [0, 3]
# optimal reveue is  0.10371310627301117
# solve assortment [0, 5, 8]
# optimal reveue is  0.4491170118582244
# testing for offertimes 60, 12th instance
# solve assortment [0, 1, 6]
# optimal reveue is  0.27837409621057
# solve assortment [0, 2, 6]
# optimal reveue is  0.17238015608506033
# testing for offertimes 60, 13th instance
# solve assortment [0, 3]
# optimal reveue is  0.10799891582419184
# solve assortment [0, 8]
# optimal reveue is  0.5089109930426924
# testing for offertimes 60, 14th instance
# solve assortment [0, 1, 6]
# optimal reveue is  0.3181146027486617
# solve assortment [0, 5, 8]
# optimal reveue is  0.5684503903891864
# testing for offertimes 60, 15th instance
# solve assortment [0, 2]
# optimal reveue is  0.11677493684055475
# solve assortment [0, 5]
# optimal reveue is  0.08608643034978805
# testing for offertimes 60, 16th instance
# solve assortment [0, 2]
# optimal reveue is  0.13100301407771728
# solve assortment [0, 1, 6]
# optimal reveue is  0.25814028607950273
# testing for offertimes 60, 17th instance
# solve assortment [0, 1]
# optimal reveue is  0.24462389096523834
# solve assortment [0, 3]
# optimal reveue is  0.09188082643860043
# testing for offertimes 60, 18th instance
# solve assortment [0, 1]
# optimal reveue is  0.28042380645050063
# solve assortment [0, 3, 6]
# optimal reveue is  0.12256910495307016
# testing for offertimes 60, 19th instance
# solve assortment [0, 6]
# optimal reveue is  0.14169088164999818
# solve assortment [0, 5, 6]
# optimal reveue is  0.2956288367867106
# testing for offertimes 60, 20th instance
# solve assortment [0, 2]
# optimal reveue is  0.14653572760966
# solve assortment [0, 3]
# optimal reveue is  0.12563834727936793
# testing for offertimes 60, 21th instance
# solve assortment [0, 5]
# optimal reveue is  0.28918873761985464
# solve assortment [0, 1, 6]
# optimal reveue is  0.23797112323835012
# testing for offertimes 60, 22th instance
# solve assortment [0, 2, 6]
# optimal reveue is  0.15857412440836316
# solve assortment [0, 3, 6]
# optimal reveue is  0.14504195494375027
# testing for offertimes 60, 23th instance
# solve assortment [0, 1]
# optimal reveue is  0.08963647028721065
# solve assortment [0, 2]
# optimal reveue is  0.03901253577978853
# testing for offertimes 60, 24th instance
# solve assortment [0, 1]
# optimal reveue is  0.39313616404375257
# solve assortment [0, 8]
# optimal reveue is  0.4664771235355558
# testing for offertimes 60, 25th instance
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle_w_initial;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM MLE with MNL initial solution: No solution found or an error occurred.
# MLE:cannot solve MLE with mnl initial soluntion
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_mle;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM MLE with LB: No solution found or an error occurred.
# MLE:adjust mle lb
# solve assortment [0, 6]
# optimal reveue is  0.08972215498076758
# solve assortment [0, 1, 6]
# optimal reveue is  0.30207299894887063
# testing for offertimes 60, 26th instance
# solve assortment [0, 5, 6]
# optimal reveue is  0.07929727704938862
# solve assortment [0, 8]
# optimal reveue is  0.00894713376811164
# testing for offertimes 60, 27th instance
# solve assortment [0, 3]
# optimal reveue is  0.11816904834825724
# solve assortment [0, 5, 6]
# optimal reveue is  0.283436998747277
# testing for offertimes 60, 28th instance
# solve assortment [0, 1]
# optimal reveue is  0.22492607301252746
# solve assortment [0, 2, 6]
# optimal reveue is  0.13237298180058438
# testing for offertimes 60, 29th instance
# solve assortment [0, 5]
# optimal reveue is  0.32461878865672394
# solve assortment [0, 5, 6]
# optimal reveue is  0.2941961200050887
# testing for offertimes 60, 30th instance
# solve assortment [0, 3]
# optimal reveue is  0.10350010189628854
# solve assortment [0, 2, 6]
# optimal reveue is  0.17298435902674067
# testing for offertimes 60, 31th instance
# solve assortment [0, 1]
# optimal reveue is  0.2817161550283335
# solve assortment [0, 5]
# optimal reveue is  0.3301593090607559
# testing for offertimes 60, 32th instance
# solve assortment [0, 2]
# optimal reveue is  0.139813840100113
# solve assortment [0, 8]
# optimal reveue is  0.41129466612454235
# testing for offertimes 60, 33th instance
# solve assortment [0, 1, 6]
# optimal reveue is  0.33866380803793866
# solve assortment [0, 5, 6]
# optimal reveue is  0.30095693950504704
# testing for offertimes 60, 34th instance
# solve assortment [0, 3, 6]
# optimal reveue is  0.1829387886490801
# solve assortment [0, 8]
# optimal reveue is  0.2813045837365415
# testing for offertimes 60, 35th instance
# solve assortment [0, 3]
# optimal reveue is  0.08966524366018042
# solve assortment [0, 6]
# optimal reveue is  0.09229128086601061
# testing for offertimes 60, 36th instance
# solve assortment [0, 2, 6]
# optimal reveue is  0.1803448390301089
# solve assortment [0, 5, 6]
# optimal reveue is  0.32467998703382167
# testing for offertimes 60, 37th instance
# solve assortment [0, 1]
# optimal reveue is  0.24729961504501727
# solve assortment [0, 6]
# optimal reveue is  0.1139615858089908
# testing for offertimes 60, 38th instance
# solve assortment [0, 2]
# optimal reveue is  0.09695349714000336
# solve assortment [0, 5, 8]
# optimal reveue is  0.4268492486785318
# testing for offertimes 60, 39th instance
# solve assortment [0, 5]
# optimal reveue is  0.16010619062021839
# solve assortment [0, 5, 8]
# optimal reveue is  0.3827922517864988
# testing for offertimes 60, 40th instance
# solve assortment [0, 2]
# optimal reveue is  0.13633892913430554
# solve assortment [0, 6]
# optimal reveue is  0.1428242916389758
# testing for offertimes 60, 41th instance
# solve assortment [0, 1]
# optimal reveue is  0.16873825761602465
# solve assortment [0, 5, 8]
# optimal reveue is  0.4036873207821312
# testing for offertimes 60, 42th instance
# solve assortment [0, 6]
# optimal reveue is  0.09804967705984872
# solve assortment [0, 8]
# optimal reveue is  0.4119655475275177
# testing for offertimes 60, 43th instance
# solve assortment [0, 2, 6]
# optimal reveue is  0.1587690522403314
# solve assortment [0, 8]
# optimal reveue is  0.40898967377462453
# testing for offertimes 60, 44th instance
# solve assortment [0, 6]
# optimal reveue is  0.10110387119790178
# solve assortment [0, 2, 6]
# optimal reveue is  0.12191874969734616
# testing for offertimes 60, 45th instance
# solve assortment [0, 2]
# optimal reveue is  0.08661233209150386
# solve assortment [0, 3, 6]
# optimal reveue is  0.11879065165413595
# testing for offertimes 60, 46th instance
# solve assortment [0, 6]
# optimal reveue is  0.09375494734871734
# solve assortment [0, 5, 8]
# optimal reveue is  0.5124034935321863
# testing for offertimes 60, 47th instance
# solve assortment [0, 1, 6]
# optimal reveue is  0.30245580135786254
# solve assortment [0, 8]
# optimal reveue is  0.4819582402743852
# testing for offertimes 60, 48th instance
# solve assortment [0, 3, 6]
# optimal reveue is  0.013024006176323735
# solve assortment [0, 5, 6]
# optimal reveue is  0.022635226094273285
# testing for offertimes 60, 49th instance
# solve assortment [0, 5]
# optimal reveue is  0.3426890967815324
# solve assortment [0, 2, 6]
# optimal reveue is  0.15287884981234523

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mccm_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mccm_dist':all_mccm_distance_list[i],
                                    'true_best_rev':all_best_true_rev_list[i],'mccm_best_rev':all_best_rev_mccm_list[i],
                                    'mccm_best_rev_diff':all_mccm_best_rev_diff[i]})
    df_mccm_details1.to_csv('prediction/mccm/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)): 
    for j in range(pred_instance_size[i]):
            true_rank = all_true_ranking[i][j]
            mccm_rank = all_mccm_ranking[i][j]
            df_rank = pd.DataFrame({'true_rank':true_rank,'mccm_rank':mccm_rank})
            df_rank.to_csv('prediction/mccm/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
            
            true_rev = all_true_revenue_list[i][j]
            mccm_rev = all_mccm_revenue_list[i][j]
            df_rev = pd.DataFrame({'true_rev':true_rev,'mccm_rev':mccm_rev})
            df_rev.to_csv('prediction/mccm/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
            
        
            mccm_runtime = all_mccm_pred_runtime[i][j]
            df_runtime = pd.DataFrame({'mccm_runtime':mccm_runtime})
            df_runtime.to_csv('prediction/mccm/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
            
            ## using sales fraction prediction
            ## record the choice probability prediction interval
            ''' true_prob = all_true_prob_list[i][j]
            df_true_prob = pd.DataFrame(true_prob)
            
            mccm_sales = all_mccm_sales_list[i][j]
            df_mccm_sales = pd.DataFrame(mccm_sales).T
    
            df_true_prob.to_csv('prediction/mccm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
            df_mccm_sales.to_csv('prediction/mccm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mccm/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## avg prediction mccm runtime 
all_mccm_pred_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    avg_mccm_pred_runtime_collection = []
    
    for j in range(pred_instance_size[i]): 
        avg_mccm_pred_runtime_collection.append(np.mean(np.array(all_mccm_pred_runtime[i][j]))) 
        
    all_mccm_pred_avg_runtime.append(np.mean(np.array(avg_mccm_pred_runtime_collection)))

# %%
avg_mccm_dist = []
avg_mccm_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    
    avg_mccm_dist.append(np.mean(all_mccm_distance_list[i]))
    avg_mccm_best_rev_diff.append(np.mean(all_mccm_best_rev_diff[i]))
    

df_mccm_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'avg_mccm_dist':avg_mccm_dist,'avg_mccm_best_rev_diff':avg_mccm_best_rev_diff,
                                   'avg_mccm_pred_runtime':all_mccm_pred_avg_runtime})
df_mccm_jd_summary.to_csv('prediction/mccm/jd_mccm_summary.csv')

# %%
df_mccm_jd_summary
# Out:
#    offertimes  avg_mccm_dist  avg_mccm_best_rev_diff  avg_mccm_pred_runtime
# 0          20           1.90                0.073108              10.352619
# 1          30           0.84                0.046535              10.605934
# 2          40           0.46                0.061864               8.496874
# 3          50           0.32                0.035253               6.834068
# 4          60           0.12                0.039283               7.451829

# %%
def mnl_mle_pyo(data, collection,offertimes):
    n = data.shape[0]
    model = pyo.ConcreteModel()
    model.v = pyo.Var(range(n), bounds=(-100,100))
    
    def obj_rule(model):
        obj = 0
        for i in range(len(collection)):
            for j in collection[i]:
                obj += offertimes[i]*data[j][i] * model.v[j]
            obj -= offertimes[i]*pyo.log(sum([pyo.exp(model.v[k]) for k in collection[i]]))
        return obj
    
    model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)
    
    # scale the preference of the outside option to be 1
    model.outsideopt_constraint = pyo.Constraint(expr=model.v[0] == 0)
    
    opt = pyo.SolverFactory('ipopt')  # use iterior point method to solve convex optimizatio problem 
    results = opt.solve(model)
    
    if (results.solver.status == pyo.SolverStatus.ok) and (results.solver.termination_condition == pyo.TerminationCondition.optimal):
        v_values = [model.v[i].value for i in range(n)]
        obj_value = model.obj()
        #model.pprint()
        return v_values, obj_value,results.solver.time
    else:
        raise ValueError("Solver failed to find an optimal solution.")

# %%
def mccm_limit(data, collection,offertimes):
    
    model = pyo.ConcreteModel(name="mccm_limit")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    
    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]* data[i, j] * model.abs_var[i, j] for i in collection[j] ) for j in range(m)), sense=pyo.minimize)
    #model.obj = Objective(expr=-sum(data[i, j] * log(model.x[i, j]) for i in range(n) for j in range(m)),sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    #solver.options['tol'] = 1e-5
    
    
    try:
        # Your optimization solve code here
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM limit: No solution found or an error occurred.')
        #model.pprint()
        return [100000, np.zeros((n,m)), 0]

# %%
def mccm_limit_tol(data, collection,offertimes):
    
    model = pyo.ConcreteModel(name="mccm_limit")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]* data[i, j] * model.abs_var[i, j] for i in collection[j] ) for j in range(m)), sense=pyo.minimize)
    #model.obj = Objective(expr=-sum(data[i, j] * log(model.x[i, j]) for i in range(n) for j in range(m)),sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    solver.options['tol'] = 1e-6
    solver.options['dual_inf_tol'] = 1e-3  # Reduce tolerance for dual infeasibility
    solver.options['constr_viol_tol'] = 1e-8  # Tighten constraint violation tolerance
    
    
    try:
        # Your optimization solve code here
        results = solver.solve(model,tee=True)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM limit: No solution found or an error occurred.')
        #model.pprint()
        return [100000, np.zeros((n,m)), 0]

# %%
def mccm_limit_w_lb(data, collection,offertimes):
    
    model = pyo.ConcreteModel(name="mccm_limit_lb")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    for i in range(n):
        model.lam[i].setlb(1e-5)
        for j in range(n):
            if i != j:
                model.rho[i,j].setlb(1e-5)
    
    for i in range(m):
        for j in collection[i]:
            model.x[j,i].setlb(1e-5)
    
    
    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]*data[i, j] * model.abs_var[i, j] for i in collection[j] ) for j in range(m)), sense=pyo.minimize)
    #model.obj = Objective(expr=-sum(data[i, j] * log(model.x[i, j]) for i in range(n) for j in range(m)),sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    #solver.options['tol'] = 1e-5
    
    
    try:
        # Your optimization solve code here
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM limit: No solution found or an error occurred.')
        #model.pprint()
        return [100000, np.zeros((n,m)), 0]

# %%
def mccm_limit_w_intial(data, collection,offertimes,x_intial, lam_intial, rho_initial):
    
    model = pyo.ConcreteModel(name="mccm_limit")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    for i in range(n):
        model.lam[i] = lam_intial[i]
        for j in range(m):
            model.x[i,j] = x_intial[i,j]
    
    for i in range(n):
        for j in range(n):
            if i != j:
                model.rho[i,j] = rho_initial[i,j]
    
    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]* data[i, j] * model.abs_var[i, j] for i in range(n) ) for j in range(m)), sense=pyo.minimize)
    #model.obj = Objective(expr=0,sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                #model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    #solver_options = {'max_iter': 15000, 'tol': 1e-4} 
    solver.options['max_iter'] = 10000  
    
    try:
        # Your optimization solve code here
        #results = solver.solve(model)
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM limit: No solution found or an error occurred.')
        #model.pprint()
        return [100000, np.zeros((n,m)), 0]

# %%
def mccm_limit_w_intial_relax(data, collection,offertimes,x_intial, lam_intial, rho_initial):
    
    model = pyo.ConcreteModel(name="mccm_limit")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    for i in range(n):
        model.lam[i] = lam_intial[i]
        for j in range(m):
            model.x[i,j] = x_intial[i,j]
    
    for i in range(n):
        for j in range(n):
            if i != j:
                model.rho[i,j] = rho_initial[i,j]
    
    ''' for i in range(n):
        model.lam[i].setlb(1e-5)
        for j in range(n):
            if i != j:
                model.rho[i,j].setlb(1e-5)
    
    for i in range(m):
        for j in collection[i]:
            model.x[j,i].setlb(1e-5) '''
    
    
    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]* data[i, j] * model.abs_var[i, j] for i in range(n) ) for j in range(m)), sense=pyo.minimize)
    #model.obj = Objective(expr=0,sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                #model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    #solver_options = {'max_iter': 15000, 'tol': 1e-4} 
    solver.options['max_iter'] = 10000
    solver.options['tol'] = 1e-4
    solver.options['mu_strategy'] = 'adaptive'  # Change mu strategy
    solver.options['hessian_approximation'] = 'limited-memory'
    solver.options['dual_inf_tol'] = 1.0  # Adjust dual infeasibility tolerance
    solver.options['constr_viol_tol'] = 1e-4  # Adjust constraint violation tolerance   
    
    try:
        # Your optimization solve code here
        #results = solver.solve(model)
        results = solver.solve(model)
        status = str(results.solver.status)
        #print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM limit: No solution found or an error occurred.')
        #model.pprint()
        return [100000, np.zeros((n,m)), 0]

# %%
''' all_mccm_limit_loss = []
all_mccm_limit_prob = []
all_mccm_limit_runtime = []

 '''
## record the limit loss of all instances
all_mccm_limit_loss = []
all_mccm_limit_prob = []
all_mccm_limit_runtime = []

for i in range(len(pred_offer_times_list)):

    
    ## define container for mccm limit 
    mccm_limit_loss_collection =[]
    mccm_limit_runtime_collection =[]
    mccm_limit_probability_collection =[]
    
    for j in range(pred_instance_size[i]):
        print(f'testing mccm limit for offertimes {pred_offer_times_list[i]} instance {j}')
        
        v_values, obj_value,runtime = mnl_mle_pyo(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
        mnl_lam,mnl_rho,initial_probability = mccm_w_mnl(v_values,all_full_collections[i])
        mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime =mccm_limit_w_intial(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i],initial_probability,mnl_lam,mnl_rho)
        if mccm_limit_runtime == 0:
            mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime =mccm_limit_w_intial_relax(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i],initial_probability,mnl_lam,mnl_rho)
            if mccm_limit_runtime == 0:
                print('cannot solve with initial solution and try directly solve the mccm limit')
                mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime = mccm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])  
                
                if mccm_limit_runtime == 0:
                    print('cannot directly solve the mccm limit and try adding lb to solve')
                    mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime = mccm_limit_w_lb(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
                    
                    ''' if mccm_limit_runtime == 0: 
                        print('cannot solve the mccm limit by adding lb and try with accept with higher tolerence ')
                        mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime = mccm_limit_tol(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
                        
                        if mccm_limit_runtime == 0:
                            print('cannot solve with above 4 methods and accept MNL solution')
                            mccm_limit_prob = mnl_distribution(v_values,all_full_collections[i])
                            mccm_limit_runtime = runtime
                            
                            mccm_limit_loss = 0
                            for x in range(len(all_full_collections[i])):
                                for y in all_full_collections[i][x]:
                                    mccm_limit_loss = mccm_limit_loss + all_full_offertimes[i][x] * all_full_instances[i][j][y][x] * np.abs(all_full_instances[i][j][y][x] - mccm_limit_prob[y][x]) '''
        
        print(f'the limit of offertimes {pred_offer_times_list[i]} instance {j} is {mccm_limit_loss} with runtime {mccm_limit_runtime}')   
        mccm_limit_probability_collection.append(mccm_limit_prob)
        mccm_limit_loss_collection.append(mccm_limit_loss)
        mccm_limit_runtime_collection.append(mccm_limit_runtime)

    
    ## for each train instance [i][j] limit loss result is a number
    all_mccm_limit_loss.append(mccm_limit_loss_collection)
    all_mccm_limit_runtime.append(mccm_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mccm_limit_prob.append(mccm_limit_probability_collection)
# Out:
# testing mccm limit for offertimes 20 instance 0
# the limit of offertimes 20 instance 0 is 41.454057606337706 with runtime 5.392797946929932
# testing mccm limit for offertimes 20 instance 1
# the limit of offertimes 20 instance 1 is 42.74139432761034 with runtime 10.082550048828125
# testing mccm limit for offertimes 20 instance 2
# the limit of offertimes 20 instance 2 is 44.01800907988928 with runtime 8.497473955154419
# testing mccm limit for offertimes 20 instance 3
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 3 is 41.637151501600364 with runtime 5.834878921508789
# testing mccm limit for offertimes 20 instance 4
# the limit of offertimes 20 instance 4 is 26.318956288294256 with runtime 9.637028932571411
# testing mccm limit for offertimes 20 instance 5
# the limit of offertimes 20 instance 5 is 45.740765036023284 with runtime 7.990963935852051
# testing mccm limit for offertimes 20 instance 6
# the limit of offertimes 20 instance 6 is 26.82674075856914 with runtime 12.277697086334229
# testing mccm limit for offertimes 20 instance 7
# the limit of offertimes 20 instance 7 is 28.71543736737042 with runtime 11.315716028213501
# testing mccm limit for offertimes 20 instance 8
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 8 is 44.50269252779633 with runtime 9.043633699417114
# testing mccm limit for offertimes 20 instance 9
# the limit of offertimes 20 instance 9 is 41.88047588387961 with runtime 9.451424837112427
# testing mccm limit for offertimes 20 instance 10
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 10 is 29.15227221843677 with runtime 19.82970118522644
# testing mccm limit for offertimes 20 instance 11
# the limit of offertimes 20 instance 11 is 49.20011687796343 with runtime 8.672065019607544
# testing mccm limit for offertimes 20 instance 12
# the limit of offertimes 20 instance 12 is 34.50484678682416 with runtime 74.16703486442566
# testing mccm limit for offertimes 20 instance 13
# the limit of offertimes 20 instance 13 is 36.017922802551176 with runtime 23.488279819488525
# testing mccm limit for offertimes 20 instance 14
# the limit of offertimes 20 instance 14 is 36.23008143553224 with runtime 10.186940908432007
# testing mccm limit for offertimes 20 instance 15
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 15 is 43.715570518178076 with runtime 51.14848065376282
# testing mccm limit for offertimes 20 instance 16
# the limit of offertimes 20 instance 16 is 37.00095373491696 with runtime 7.198957204818726
# testing mccm limit for offertimes 20 instance 17
# the limit of offertimes 20 instance 17 is 48.09751073177269 with runtime 7.852148056030273
# testing mccm limit for offertimes 20 instance 18
# the limit of offertimes 20 instance 18 is 37.67713188686179 with runtime 16.005464792251587
# testing mccm limit for offertimes 20 instance 19
# the limit of offertimes 20 instance 19 is 40.351470970038115 with runtime 9.486963987350464
# testing mccm limit for offertimes 20 instance 20
# the limit of offertimes 20 instance 20 is 26.269797692038157 with runtime 8.476610660552979
# testing mccm limit for offertimes 20 instance 21
# the limit of offertimes 20 instance 21 is 32.193250992679815 with runtime 13.57768702507019
# testing mccm limit for offertimes 20 instance 22
# the limit of offertimes 20 instance 22 is 31.096093850235185 with runtime 7.106749057769775
# testing mccm limit for offertimes 20 instance 23
# the limit of offertimes 20 instance 23 is 35.23655452014393 with runtime 6.925037145614624
# testing mccm limit for offertimes 20 instance 24
# the limit of offertimes 20 instance 24 is 35.02955102724745 with runtime 5.401170969009399
# testing mccm limit for offertimes 20 instance 25
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 25 is 35.256490257175905 with runtime 4.91843318939209
# testing mccm limit for offertimes 20 instance 26
# the limit of offertimes 20 instance 26 is 30.51382542281317 with runtime 10.545944213867188
# testing mccm limit for offertimes 20 instance 27
# the limit of offertimes 20 instance 27 is 32.171908608657574 with runtime 8.830235719680786
# testing mccm limit for offertimes 20 instance 28
# the limit of offertimes 20 instance 28 is 39.99491524604326 with runtime 4.838769912719727
# testing mccm limit for offertimes 20 instance 29
# the limit of offertimes 20 instance 29 is 41.602769360557986 with runtime 11.43179702758789
# testing mccm limit for offertimes 20 instance 30
# the limit of offertimes 20 instance 30 is 26.613255759364552 with runtime 3.3249258995056152
# testing mccm limit for offertimes 20 instance 31
# the limit of offertimes 20 instance 31 is 41.871904206695 with runtime 9.712637901306152
# testing mccm limit for offertimes 20 instance 32
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 32 is 35.73038482783212 with runtime 9.04962420463562
# testing mccm limit for offertimes 20 instance 33
# the limit of offertimes 20 instance 33 is 30.771065991706244 with runtime 5.837960958480835
# testing mccm limit for offertimes 20 instance 34
# the limit of offertimes 20 instance 34 is 42.55232266324217 with runtime 11.128061056137085
# testing mccm limit for offertimes 20 instance 35
# the limit of offertimes 20 instance 35 is 39.24723219806433 with runtime 6.857999801635742
# testing mccm limit for offertimes 20 instance 36
# the limit of offertimes 20 instance 36 is 22.97544212041701 with runtime 10.994670867919922
# testing mccm limit for offertimes 20 instance 37
# the limit of offertimes 20 instance 37 is 31.64724491220416 with runtime 14.36990213394165
# testing mccm limit for offertimes 20 instance 38
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 38 is 25.4764630282257 with runtime 6.654446840286255
# testing mccm limit for offertimes 20 instance 39
# the limit of offertimes 20 instance 39 is 35.56607948976254 with runtime 10.764068841934204
# testing mccm limit for offertimes 20 instance 40
# the limit of offertimes 20 instance 40 is 34.039142583968996 with runtime 30.87997794151306
# testing mccm limit for offertimes 20 instance 41
# the limit of offertimes 20 instance 41 is 30.7697912647426 with runtime 8.744439125061035
# testing mccm limit for offertimes 20 instance 42
# the limit of offertimes 20 instance 42 is 51.422810795429555 with runtime 5.743038892745972
# testing mccm limit for offertimes 20 instance 43
# the limit of offertimes 20 instance 43 is 48.38256402198747 with runtime 12.103365182876587
# testing mccm limit for offertimes 20 instance 44
# the limit of offertimes 20 instance 44 is 28.979212571819428 with runtime 7.474010944366455
# testing mccm limit for offertimes 20 instance 45
# the limit of offertimes 20 instance 45 is 41.223675795632 with runtime 7.800097942352295
# testing mccm limit for offertimes 20 instance 46
# the limit of offertimes 20 instance 46 is 48.78267048648102 with runtime 15.215091943740845
# testing mccm limit for offertimes 20 instance 47
# the limit of offertimes 20 instance 47 is 47.0198933173141 with runtime 5.456518888473511
# testing mccm limit for offertimes 20 instance 48
# the limit of offertimes 20 instance 48 is 29.84793498845617 with runtime 12.428279161453247
# testing mccm limit for offertimes 20 instance 49
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 20 instance 49 is 27.724757947116462 with runtime 4.931431770324707
# testing mccm limit for offertimes 30 instance 0
# the limit of offertimes 30 instance 0 is 33.379891579165864 with runtime 6.236429214477539
# testing mccm limit for offertimes 30 instance 1
# the limit of offertimes 30 instance 1 is 36.46243332219535 with runtime 11.425302028656006
# testing mccm limit for offertimes 30 instance 2
# the limit of offertimes 30 instance 2 is 29.819233508393637 with runtime 7.52976393699646
# testing mccm limit for offertimes 30 instance 3
# the limit of offertimes 30 instance 3 is 31.230911321434274 with runtime 5.382147789001465
# testing mccm limit for offertimes 30 instance 4
# the limit of offertimes 30 instance 4 is 20.27005948756588 with runtime 3.391265869140625
# testing mccm limit for offertimes 30 instance 5
# the limit of offertimes 30 instance 5 is 39.21754305837036 with runtime 4.831233024597168
# testing mccm limit for offertimes 30 instance 6
# the limit of offertimes 30 instance 6 is 20.687475389913526 with runtime 6.143156051635742
# testing mccm limit for offertimes 30 instance 7
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 30 instance 7 is 20.852404389682732 with runtime 3.904949903488159
# testing mccm limit for offertimes 30 instance 8
# the limit of offertimes 30 instance 8 is 40.229714787836066 with runtime 21.687137126922607
# testing mccm limit for offertimes 30 instance 9
# the limit of offertimes 30 instance 9 is 31.20281888862634 with runtime 9.405327081680298
# testing mccm limit for offertimes 30 instance 10
# the limit of offertimes 30 instance 10 is 22.618408622478512 with runtime 14.36877703666687
# testing mccm limit for offertimes 30 instance 11
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 30 instance 11 is 39.22902589871948 with runtime 3.8966331481933594
# testing mccm limit for offertimes 30 instance 12
# the limit of offertimes 30 instance 12 is 24.265432358235067 with runtime 4.195770025253296
# testing mccm limit for offertimes 30 instance 13
# the limit of offertimes 30 instance 13 is 28.65526064848024 with runtime 5.499398946762085
# testing mccm limit for offertimes 30 instance 14
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 30 instance 14 is 23.797393524913115 with runtime 2.7816097736358643
# testing mccm limit for offertimes 30 instance 15
# the limit of offertimes 30 instance 15 is 29.655733878834994 with runtime 11.95757794380188
# testing mccm limit for offertimes 30 instance 16
# the limit of offertimes 30 instance 16 is 30.51423337471749 with runtime 5.259544134140015
# testing mccm limit for offertimes 30 instance 17
# the limit of offertimes 30 instance 17 is 35.03975690587965 with runtime 18.07794713973999
# testing mccm limit for offertimes 30 instance 18
# the limit of offertimes 30 instance 18 is 26.584311123245424 with runtime 5.363680124282837
# testing mccm limit for offertimes 30 instance 19
# the limit of offertimes 30 instance 19 is 26.015605929028663 with runtime 7.477894067764282
# testing mccm limit for offertimes 30 instance 20
# the limit of offertimes 30 instance 20 is 20.420543861917093 with runtime 5.475510835647583
# testing mccm limit for offertimes 30 instance 21
# the limit of offertimes 30 instance 21 is 22.37389451641006 with runtime 6.124470949172974
# testing mccm limit for offertimes 30 instance 22
# the limit of offertimes 30 instance 22 is 24.09697583326741 with runtime 4.9991559982299805
# testing mccm limit for offertimes 30 instance 23
# the limit of offertimes 30 instance 23 is 27.58089975364105 with runtime 17.61124086380005
# testing mccm limit for offertimes 30 instance 24
# the limit of offertimes 30 instance 24 is 29.486115976304585 with runtime 4.421597957611084
# testing mccm limit for offertimes 30 instance 25
# the limit of offertimes 30 instance 25 is 24.535884994603045 with runtime 7.249522924423218
# testing mccm limit for offertimes 30 instance 26
# the limit of offertimes 30 instance 26 is 21.890645673497183 with runtime 5.973811149597168
# testing mccm limit for offertimes 30 instance 27
# the limit of offertimes 30 instance 27 is 23.101855715790663 with runtime 5.184902906417847
# testing mccm limit for offertimes 30 instance 28
# the limit of offertimes 30 instance 28 is 28.877137880676166 with runtime 8.15361499786377
# testing mccm limit for offertimes 30 instance 29
# the limit of offertimes 30 instance 29 is 36.04704036940753 with runtime 36.422115087509155
# testing mccm limit for offertimes 30 instance 30
# the limit of offertimes 30 instance 30 is 17.267108119478625 with runtime 5.63091516494751
# testing mccm limit for offertimes 30 instance 31
# the limit of offertimes 30 instance 31 is 34.82578219122402 with runtime 92.72441983222961
# testing mccm limit for offertimes 30 instance 32
# the limit of offertimes 30 instance 32 is 28.907010920361905 with runtime 6.14332914352417
# testing mccm limit for offertimes 30 instance 33
# the limit of offertimes 30 instance 33 is 21.01968116201666 with runtime 5.231979131698608
# testing mccm limit for offertimes 30 instance 34
# the limit of offertimes 30 instance 34 is 30.72986604155105 with runtime 36.7735550403595
# testing mccm limit for offertimes 30 instance 35
# the limit of offertimes 30 instance 35 is 28.679794610000172 with runtime 2.536311149597168
# testing mccm limit for offertimes 30 instance 36
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 30 instance 36 is 18.738373856399097 with runtime 4.850927829742432
# testing mccm limit for offertimes 30 instance 37
# the limit of offertimes 30 instance 37 is 20.694329391552337 with runtime 81.07820272445679
# testing mccm limit for offertimes 30 instance 38
# the limit of offertimes 30 instance 38 is 15.788190966341922 with runtime 163.86625790596008
# testing mccm limit for offertimes 30 instance 39
# the limit of offertimes 30 instance 39 is 29.064594440717638 with runtime 6.353698015213013
# testing mccm limit for offertimes 30 instance 40
# the limit of offertimes 30 instance 40 is 26.415835602542447 with runtime 4.778255224227905
# testing mccm limit for offertimes 30 instance 41
# the limit of offertimes 30 instance 41 is 24.87297144701918 with runtime 3.193438768386841
# testing mccm limit for offertimes 30 instance 42
# the limit of offertimes 30 instance 42 is 35.32815696262795 with runtime 6.314034938812256
# testing mccm limit for offertimes 30 instance 43
# the limit of offertimes 30 instance 43 is 35.61162924624917 with runtime 8.717581033706665
# testing mccm limit for offertimes 30 instance 44
# the limit of offertimes 30 instance 44 is 21.15496067571876 with runtime 10.154732942581177
# testing mccm limit for offertimes 30 instance 45
# the limit of offertimes 30 instance 45 is 33.698742298841715 with runtime 33.0702908039093
# testing mccm limit for offertimes 30 instance 46
# the limit of offertimes 30 instance 46 is 35.18472898222996 with runtime 5.7629640102386475
# testing mccm limit for offertimes 30 instance 47
# the limit of offertimes 30 instance 47 is 38.996735864770194 with runtime 9.530303001403809
# testing mccm limit for offertimes 30 instance 48
# the limit of offertimes 30 instance 48 is 16.047750576026374 with runtime 10.111752986907959
# testing mccm limit for offertimes 30 instance 49
# the limit of offertimes 30 instance 49 is 22.406098096388494 with runtime 3.851483106613159
# testing mccm limit for offertimes 40 instance 0
# the limit of offertimes 40 instance 0 is 12.847729275725966 with runtime 33.11296200752258
# testing mccm limit for offertimes 40 instance 1
# the limit of offertimes 40 instance 1 is 25.570737466065903 with runtime 8.302239894866943
# testing mccm limit for offertimes 40 instance 2
# the limit of offertimes 40 instance 2 is 20.999394095805663 with runtime 3.7822530269622803
# testing mccm limit for offertimes 40 instance 3
# the limit of offertimes 40 instance 3 is 38.85006002138937 with runtime 63.639790296554565
# testing mccm limit for offertimes 40 instance 4
# the limit of offertimes 40 instance 4 is 10.035708184283868 with runtime 4.7572009563446045
# testing mccm limit for offertimes 40 instance 5
# the limit of offertimes 40 instance 5 is 28.921889680694694 with runtime 4.108642816543579
# testing mccm limit for offertimes 40 instance 6
# the limit of offertimes 40 instance 6 is 14.725253935665801 with runtime 6.174739122390747
# testing mccm limit for offertimes 40 instance 7
# the limit of offertimes 40 instance 7 is 11.337369282433478 with runtime 9.97504711151123
# testing mccm limit for offertimes 40 instance 8
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 40 instance 8 is 25.86604625977474 with runtime 7.499469041824341
# testing mccm limit for offertimes 40 instance 9
# the limit of offertimes 40 instance 9 is 21.09650910197672 with runtime 6.697813034057617
# testing mccm limit for offertimes 40 instance 10
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 40 instance 10 is 9.604228757363447 with runtime 3.2303411960601807
# testing mccm limit for offertimes 40 instance 11
# the limit of offertimes 40 instance 11 is 34.022161298389456 with runtime 8.153808355331421
# testing mccm limit for offertimes 40 instance 12
# the limit of offertimes 40 instance 12 is 19.56076123689364 with runtime 7.184844970703125
# testing mccm limit for offertimes 40 instance 13
# the limit of offertimes 40 instance 13 is 16.99373819620413 with runtime 9.227933168411255
# testing mccm limit for offertimes 40 instance 14
# the limit of offertimes 40 instance 14 is 14.860052791994546 with runtime 2.332312822341919
# testing mccm limit for offertimes 40 instance 15
# the limit of offertimes 40 instance 15 is 21.681962441069373 with runtime 3.0839033126831055
# testing mccm limit for offertimes 40 instance 16
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 40 instance 16 is 21.42070061245069 with runtime 2.3563809394836426
# testing mccm limit for offertimes 40 instance 17
# the limit of offertimes 40 instance 17 is 23.82442739088448 with runtime 6.990680932998657
# testing mccm limit for offertimes 40 instance 18
# the limit of offertimes 40 instance 18 is 12.450598858436498 with runtime 45.3340802192688
# testing mccm limit for offertimes 40 instance 19
# the limit of offertimes 40 instance 19 is 14.28786985364584 with runtime 3.2074899673461914
# testing mccm limit for offertimes 40 instance 20
# the limit of offertimes 40 instance 20 is 11.150498519845188 with runtime 3.9600272178649902
# testing mccm limit for offertimes 40 instance 21
# the limit of offertimes 40 instance 21 is 14.309449594941004 with runtime 10.447045087814331
# testing mccm limit for offertimes 40 instance 22
# the limit of offertimes 40 instance 22 is 13.323780022270206 with runtime 4.638859033584595
# testing mccm limit for offertimes 40 instance 23
# the limit of offertimes 40 instance 23 is 17.67561292158782 with runtime 5.279760122299194
# testing mccm limit for offertimes 40 instance 24
# the limit of offertimes 40 instance 24 is 20.942559696655632 with runtime 3.9828453063964844
# testing mccm limit for offertimes 40 instance 25
# the limit of offertimes 40 instance 25 is 15.88355497014159 with runtime 4.113753795623779
# testing mccm limit for offertimes 40 instance 26
# the limit of offertimes 40 instance 26 is 9.957852024213734 with runtime 8.13630199432373
# testing mccm limit for offertimes 40 instance 27
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 40 instance 27 is 15.560377293885098 with runtime 1.488158941268921
# testing mccm limit for offertimes 40 instance 28
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 40 instance 28 is 25.633193350355693 with runtime 3.9549639225006104
# testing mccm limit for offertimes 40 instance 29
# the limit of offertimes 40 instance 29 is 21.31867411112947 with runtime 5.40759801864624
# testing mccm limit for offertimes 40 instance 30
# the limit of offertimes 40 instance 30 is 16.56824483816368 with runtime 28.832617044448853
# testing mccm limit for offertimes 40 instance 31
# the limit of offertimes 40 instance 31 is 24.149533426710853 with runtime 35.2491979598999
# testing mccm limit for offertimes 40 instance 32
# the limit of offertimes 40 instance 32 is 9.711432771252897 with runtime 5.345879077911377
# testing mccm limit for offertimes 40 instance 33
# the limit of offertimes 40 instance 33 is 15.01061435674322 with runtime 3.364405870437622
# testing mccm limit for offertimes 40 instance 34
# the limit of offertimes 40 instance 34 is 12.165826158631512 with runtime 5.179166316986084
# testing mccm limit for offertimes 40 instance 35
# the limit of offertimes 40 instance 35 is 19.84996772823866 with runtime 4.4239091873168945
# testing mccm limit for offertimes 40 instance 36
# the limit of offertimes 40 instance 36 is 9.94805213997625 with runtime 4.857619047164917
# testing mccm limit for offertimes 40 instance 37
# the limit of offertimes 40 instance 37 is 9.620997998586695 with runtime 5.183568954467773
# testing mccm limit for offertimes 40 instance 38
# the limit of offertimes 40 instance 38 is 6.957063473763851 with runtime 56.53567886352539
# testing mccm limit for offertimes 40 instance 39
# the limit of offertimes 40 instance 39 is 19.748396276898042 with runtime 7.015800952911377
# testing mccm limit for offertimes 40 instance 40
# the limit of offertimes 40 instance 40 is 19.110530466252094 with runtime 5.569218873977661
# testing mccm limit for offertimes 40 instance 41
# the limit of offertimes 40 instance 41 is 19.434960130802725 with runtime 14.03313684463501
# testing mccm limit for offertimes 40 instance 42
# the limit of offertimes 40 instance 42 is 25.763012968311287 with runtime 7.464344263076782
# testing mccm limit for offertimes 40 instance 43
# the limit of offertimes 40 instance 43 is 21.50047229347875 with runtime 4.371776103973389
# testing mccm limit for offertimes 40 instance 44
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 40 instance 44 is 15.326419255413914 with runtime 3.089945077896118
# testing mccm limit for offertimes 40 instance 45
# the limit of offertimes 40 instance 45 is 23.17960071859296 with runtime 2.5092709064483643
# testing mccm limit for offertimes 40 instance 46
# the limit of offertimes 40 instance 46 is 22.338939090883084 with runtime 6.806660890579224
# testing mccm limit for offertimes 40 instance 47
# the limit of offertimes 40 instance 47 is 29.515042689376788 with runtime 5.118768215179443
# testing mccm limit for offertimes 40 instance 48
# the limit of offertimes 40 instance 48 is 5.150260725006301 with runtime 7.029069900512695
# testing mccm limit for offertimes 40 instance 49
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# cannot solve with initial solution and try directly solve the mccm limit
# the limit of offertimes 40 instance 49 is 9.694781509409271 with runtime 11.899555206298828
# testing mccm limit for offertimes 50 instance 0
# the limit of offertimes 50 instance 0 is 5.1092902074365005 with runtime 21.790712118148804
# testing mccm limit for offertimes 50 instance 1
# the limit of offertimes 50 instance 1 is 5.795100611811493 with runtime 5.600088119506836
# testing mccm limit for offertimes 50 instance 2
# the limit of offertimes 50 instance 2 is 8.290635053160576 with runtime 3.8011980056762695
# testing mccm limit for offertimes 50 instance 3
# the limit of offertimes 50 instance 3 is 11.22489611447725 with runtime 3.718581199645996
# testing mccm limit for offertimes 50 instance 4
# the limit of offertimes 50 instance 4 is 3.050411217966175 with runtime 6.649693012237549
# testing mccm limit for offertimes 50 instance 5
# the limit of offertimes 50 instance 5 is 22.706667035726078 with runtime 5.150716781616211
# testing mccm limit for offertimes 50 instance 6
# the limit of offertimes 50 instance 6 is 10.41701890416075 with runtime 3.0528969764709473
# testing mccm limit for offertimes 50 instance 7
# the limit of offertimes 50 instance 7 is 3.443756668804861 with runtime 5.772698879241943
# testing mccm limit for offertimes 50 instance 8
# the limit of offertimes 50 instance 8 is 18.818952555319324 with runtime 4.195995092391968
# testing mccm limit for offertimes 50 instance 9
# the limit of offertimes 50 instance 9 is 9.456778809843742 with runtime 4.543075084686279
# testing mccm limit for offertimes 50 instance 10
# the limit of offertimes 50 instance 10 is 4.976971771728851 with runtime 14.243993997573853
# testing mccm limit for offertimes 50 instance 11
# the limit of offertimes 50 instance 11 is 26.97226081001332 with runtime 7.061604261398315
# testing mccm limit for offertimes 50 instance 12
# the limit of offertimes 50 instance 12 is 9.106813854459773 with runtime 7.630403757095337
# testing mccm limit for offertimes 50 instance 13
# the limit of offertimes 50 instance 13 is 6.322664939874004 with runtime 11.612586975097656
# testing mccm limit for offertimes 50 instance 14
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 50 instance 14 is 912.6831151625132 with runtime 10.356677770614624
# testing mccm limit for offertimes 50 instance 15
# the limit of offertimes 50 instance 15 is 14.54230280709512 with runtime 5.912412881851196
# testing mccm limit for offertimes 50 instance 16
# the limit of offertimes 50 instance 16 is 13.06512400783095 with runtime 8.584727048873901
# testing mccm limit for offertimes 50 instance 17
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# cannot solve with initial solution and try directly solve the mccm limit
# the limit of offertimes 50 instance 17 is 19.358855473054987 with runtime 3.192920207977295
# testing mccm limit for offertimes 50 instance 18
# the limit of offertimes 50 instance 18 is 10.724937826370518 with runtime 2.98945689201355
# testing mccm limit for offertimes 50 instance 19
# the limit of offertimes 50 instance 19 is 4.122353960545951 with runtime 2.877581834793091
# testing mccm limit for offertimes 50 instance 20
# the limit of offertimes 50 instance 20 is 6.326490052446862 with runtime 3.844787836074829
# testing mccm limit for offertimes 50 instance 21
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 50 instance 21 is 8.271382936242215 with runtime 2.1225078105926514
# testing mccm limit for offertimes 50 instance 22
# the limit of offertimes 50 instance 22 is 8.973176291472223 with runtime 3.1009740829467773
# testing mccm limit for offertimes 50 instance 23
# the limit of offertimes 50 instance 23 is 8.558095330520537 with runtime 4.672729253768921
# testing mccm limit for offertimes 50 instance 24
# the limit of offertimes 50 instance 24 is 14.039940396401791 with runtime 6.914378881454468
# testing mccm limit for offertimes 50 instance 25
# the limit of offertimes 50 instance 25 is 4.357237559360867 with runtime 4.309788942337036
# testing mccm limit for offertimes 50 instance 26
# the limit of offertimes 50 instance 26 is 2.91709924608161 with runtime 4.9561567306518555
# testing mccm limit for offertimes 50 instance 27
# the limit of offertimes 50 instance 27 is 7.4507554843184955 with runtime 5.627943992614746
# testing mccm limit for offertimes 50 instance 28
# the limit of offertimes 50 instance 28 is 9.869023312453024 with runtime 20.559679985046387
# testing mccm limit for offertimes 50 instance 29
# the limit of offertimes 50 instance 29 is 15.263480923047897 with runtime 3.084644317626953
# testing mccm limit for offertimes 50 instance 30
# the limit of offertimes 50 instance 30 is 2.982655629548508 with runtime 8.838041067123413
# testing mccm limit for offertimes 50 instance 31
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 50 instance 31 is 12.96043414432594 with runtime 10.152602195739746
# testing mccm limit for offertimes 50 instance 32
# the limit of offertimes 50 instance 32 is 4.887400008783761 with runtime 5.472372055053711
# testing mccm limit for offertimes 50 instance 33
# the limit of offertimes 50 instance 33 is 5.71035755117001 with runtime 44.2738311290741
# testing mccm limit for offertimes 50 instance 34
# the limit of offertimes 50 instance 34 is 4.1291347612727956 with runtime 5.721318244934082
# testing mccm limit for offertimes 50 instance 35
# the limit of offertimes 50 instance 35 is 11.136624836721714 with runtime 3.8531980514526367
# testing mccm limit for offertimes 50 instance 36
# the limit of offertimes 50 instance 36 is 0.8567523109363073 with runtime 4.46408486366272
# testing mccm limit for offertimes 50 instance 37
# the limit of offertimes 50 instance 37 is 6.658382332403206 with runtime 1.8201649188995361
# testing mccm limit for offertimes 50 instance 38
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 50 instance 38 is 1.40543856496441 with runtime 1.4772911071777344
# testing mccm limit for offertimes 50 instance 39
# the limit of offertimes 50 instance 39 is 8.882493142421797 with runtime 2.8453779220581055
# testing mccm limit for offertimes 50 instance 40
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 50 instance 40 is 1203.9637130258754 with runtime 15.306912899017334
# testing mccm limit for offertimes 50 instance 41
# the limit of offertimes 50 instance 41 is 13.41606598171322 with runtime 2.7181379795074463
# testing mccm limit for offertimes 50 instance 42
# the limit of offertimes 50 instance 42 is 15.845079396368147 with runtime 4.900585174560547
# testing mccm limit for offertimes 50 instance 43
# the limit of offertimes 50 instance 43 is 15.793905292243684 with runtime 5.128997087478638
# testing mccm limit for offertimes 50 instance 44
# the limit of offertimes 50 instance 44 is 3.3567726376713893 with runtime 6.134040117263794
# testing mccm limit for offertimes 50 instance 45
# the limit of offertimes 50 instance 45 is 16.272788403163947 with runtime 9.83063292503357
# testing mccm limit for offertimes 50 instance 46
# the limit of offertimes 50 instance 46 is 10.818781264518245 with runtime 7.514679908752441
# testing mccm limit for offertimes 50 instance 47
# the limit of offertimes 50 instance 47 is 23.049859509622646 with runtime 7.357656002044678
# testing mccm limit for offertimes 50 instance 48
# the limit of offertimes 50 instance 48 is 1.507491280213112 with runtime 6.118870973587036
# testing mccm limit for offertimes 50 instance 49
# the limit of offertimes 50 instance 49 is 5.672689565006312 with runtime 4.963791847229004
# testing mccm limit for offertimes 60 instance 0
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 0 is 2.045627325895201 with runtime 1.194509744644165
# testing mccm limit for offertimes 60 instance 1
# the limit of offertimes 60 instance 1 is 1.4150854173790357 with runtime 5.0248308181762695
# testing mccm limit for offertimes 60 instance 2
# the limit of offertimes 60 instance 2 is 3.6026860850377216 with runtime 7.48747992515564
# testing mccm limit for offertimes 60 instance 3
# the limit of offertimes 60 instance 3 is 7.354933729101007 with runtime 9.264070987701416
# testing mccm limit for offertimes 60 instance 4
# the limit of offertimes 60 instance 4 is 1.5445468126918802 with runtime 4.119363069534302
# testing mccm limit for offertimes 60 instance 5
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# cannot solve with initial solution and try directly solve the mccm limit
# the limit of offertimes 60 instance 5 is 16.160014379464783 with runtime 4.405206680297852
# testing mccm limit for offertimes 60 instance 6
# the limit of offertimes 60 instance 6 is 7.608298959109827 with runtime 5.258264064788818
# testing mccm limit for offertimes 60 instance 7
# the limit of offertimes 60 instance 7 is 0.0 with runtime 6.7930097579956055
# testing mccm limit for offertimes 60 instance 8
# the limit of offertimes 60 instance 8 is 21.919316523818242 with runtime 22.32922601699829
# testing mccm limit for offertimes 60 instance 9
# the limit of offertimes 60 instance 9 is 7.4075599619685635 with runtime 10.373871088027954
# testing mccm limit for offertimes 60 instance 10
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# cannot solve with initial solution and try directly solve the mccm limit
# the limit of offertimes 60 instance 10 is 4.538848595925732 with runtime 4.71162486076355
# testing mccm limit for offertimes 60 instance 11
# the limit of offertimes 60 instance 11 is 24.429332794774187 with runtime 6.841428279876709
# testing mccm limit for offertimes 60 instance 12
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 12 is 5.4664931981719835 with runtime 1.1202328205108643
# testing mccm limit for offertimes 60 instance 13
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 13 is 4.929641566484641 with runtime 1.5249388217926025
# testing mccm limit for offertimes 60 instance 14
# the limit of offertimes 60 instance 14 is 6.377235759139844 with runtime 3.242033004760742
# testing mccm limit for offertimes 60 instance 15
# the limit of offertimes 60 instance 15 is 10.211776997798312 with runtime 5.138614177703857
# testing mccm limit for offertimes 60 instance 16
# the limit of offertimes 60 instance 16 is 10.32112087812465 with runtime 26.950042009353638
# testing mccm limit for offertimes 60 instance 17
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 17 is 14.941920953946209 with runtime 1.1875278949737549
# testing mccm limit for offertimes 60 instance 18
# the limit of offertimes 60 instance 18 is 5.381864984548176 with runtime 6.895841836929321
# testing mccm limit for offertimes 60 instance 19
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 19 is 2.524131032972397 with runtime 15.099762916564941
# testing mccm limit for offertimes 60 instance 20
# the limit of offertimes 60 instance 20 is 2.2693732841937213 with runtime 4.887104034423828
# testing mccm limit for offertimes 60 instance 21
# the limit of offertimes 60 instance 21 is 0.12337487868312451 with runtime 15.754224061965942
# testing mccm limit for offertimes 60 instance 22
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 22 is 3.3209552958215656 with runtime 0.98807692527771
# testing mccm limit for offertimes 60 instance 23
# the limit of offertimes 60 instance 23 is 0.7996598249031182 with runtime 4.464085817337036
# testing mccm limit for offertimes 60 instance 24
# the limit of offertimes 60 instance 24 is 10.51246626457058 with runtime 39.28190994262695
# testing mccm limit for offertimes 60 instance 25
# the limit of offertimes 60 instance 25 is 3.200775489381501 with runtime 4.1940271854400635
# testing mccm limit for offertimes 60 instance 26
# the limit of offertimes 60 instance 26 is 1.5668608163337208 with runtime 25.926097869873047
# testing mccm limit for offertimes 60 instance 27
# the limit of offertimes 60 instance 27 is 6.101955472644909 with runtime 3.7525830268859863
# testing mccm limit for offertimes 60 instance 28
# the limit of offertimes 60 instance 28 is 10.382183679422775 with runtime 5.894512176513672
# testing mccm limit for offertimes 60 instance 29
# the limit of offertimes 60 instance 29 is 14.412323509439197 with runtime 17.98068881034851
# testing mccm limit for offertimes 60 instance 30
# the limit of offertimes 60 instance 30 is 2.2161224738594973 with runtime 6.073601007461548
# testing mccm limit for offertimes 60 instance 31
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit;
#         message from solver=Ipopt 3.12.12\x3a Maximum Number of Iterations
#         Exceeded.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# cannot solve with initial solution and try directly solve the mccm limit
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# cannot directly solve the mccm limit and try adding lb to solve
# WARNING: Loading a SolverResults object with a warning status into
#     model=mccm_limit_lb;
#         message from solver=Ipopt 3.12.12\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# Error: Solver failed with status: warning
# MCCM limit: No solution found or an error occurred.
# cannot solve the mccm limit by adding lb and try with accept with higher tolerence
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# cannot solve with above 4 methods and accept MNL solution
# the limit of offertimes 60 instance 31 is 156.1965050801996 with runtime 0.22138333320617676
# testing mccm limit for offertimes 60 instance 32
# the limit of offertimes 60 instance 32 is 1.8816283689353632 with runtime 7.162069082260132
# testing mccm limit for offertimes 60 instance 33
# the limit of offertimes 60 instance 33 is 5.154437268829716 with runtime 6.663260221481323
# testing mccm limit for offertimes 60 instance 34
# the limit of offertimes 60 instance 34 is 0.1294566084858498 with runtime 7.4910829067230225
# testing mccm limit for offertimes 60 instance 35
# the limit of offertimes 60 instance 35 is 5.1971912993581775 with runtime 13.605395078659058
# testing mccm limit for offertimes 60 instance 36
# the limit of offertimes 60 instance 36 is 0.2149873500152757 with runtime 6.77262020111084
# testing mccm limit for offertimes 60 instance 37
# the limit of offertimes 60 instance 37 is 0.18049457447842696 with runtime 5.749786138534546
# testing mccm limit for offertimes 60 instance 38
# the limit of offertimes 60 instance 38 is 1.2302619665128265 with runtime 46.317281007766724
# testing mccm limit for offertimes 60 instance 39
# the limit of offertimes 60 instance 39 is 7.570384590337649 with runtime 8.552103996276855
# testing mccm limit for offertimes 60 instance 40
# the limit of offertimes 60 instance 40 is 8.478223124850839 with runtime 8.164682865142822
# testing mccm limit for offertimes 60 instance 41
# the limit of offertimes 60 instance 41 is 8.424725118647267 with runtime 5.395549058914185
# testing mccm limit for offertimes 60 instance 42
# the limit of offertimes 60 instance 42 is 10.048204671493934 with runtime 8.727169036865234
# testing mccm limit for offertimes 60 instance 43
# the limit of offertimes 60 instance 43 is 6.381106294276478 with runtime 5.8429601192474365
# testing mccm limit for offertimes 60 instance 44
# the limit of offertimes 60 instance 44 is 2.771569368792604 with runtime 5.659691095352173
# testing mccm limit for offertimes 60 instance 45
# the limit of offertimes 60 instance 45 is 14.864185554827436 with runtime 6.7471208572387695
# testing mccm limit for offertimes 60 instance 46
# the limit of offertimes 60 instance 46 is 2.815974048111613 with runtime 4.839806795120239
# testing mccm limit for offertimes 60 instance 47
# Error: Cannot load a SolverResults object with bad status: error
# MCCM limit: No solution found or an error occurred.
# the limit of offertimes 60 instance 47 is 20.63640492952444 with runtime 1.5731937885284424
# testing mccm limit for offertimes 60 instance 48
# the limit of offertimes 60 instance 48 is 0.07510751485397477 with runtime 14.552878141403198
# testing mccm limit for offertimes 60 instance 49
# the limit of offertimes 60 instance 49 is 851.2363451910454 with runtime 4.013870000839233

# %% [markdown]
# instance [3][14]

# %%
all_mccm_limit_loss[3][14], all_mccm_limit_prob[3][14] ,all_mccm_limit_runtime[3][14] = mccm_limit(all_full_instances[3][14],all_full_collections[3],all_full_offertimes[3])
# Out:
# 12.366170136904191 [[6.65570175e-01 7.94871795e-01 7.23577236e-01 7.66666667e-01
#   6.51817116e-01 6.80838672e-01 7.12454212e-01 6.22023701e-01
#   6.65570176e-01 6.20967741e-01 6.60156250e-01 6.80838665e-01
#   6.26865672e-01 6.33165829e-01 6.75521822e-01]
#  [3.34429825e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 5.67022176e-14 2.45614044e-01
#   1.96078437e-01 1.85483869e-01 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.05128205e-01 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 5.99220113e-13 0.00000000e+00
#   1.86651305e-13 0.00000000e+00 6.25000000e-02 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 2.76422764e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 2.95375406e-13 1.32362255e-01
#   1.93180365e-13 0.00000000e+00 0.00000000e+00 1.65990590e-08
#   0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 2.33333333e-01
#   0.00000000e+00 0.00000000e+00 1.04120247e-13 0.00000000e+00
#   1.38351386e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   3.48182884e-01 0.00000000e+00 3.99004881e-13 0.00000000e+00
#   2.07235562e-13 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.34328358e-01 2.21105528e-01 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 3.19161328e-01 0.00000000e+00 0.00000000e+00
#   1.96934777e-13 1.93548390e-01 2.77343750e-01 3.19161318e-01
#   2.38805970e-01 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 2.87545788e-01 0.00000000e+00
#   1.55526225e-13 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 6.80417718e-13 0.00000000e+00
#   2.03690875e-13 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 1.45728643e-01 3.24478178e-01]] 2.8907718658447266

# %% [markdown]
# instance [3][40]

# %%
all_mccm_limit_loss[3][40], all_mccm_limit_prob[3][40] ,all_mccm_limit_runtime[3][40]  = mccm_limit(all_full_instances[3][40],all_full_collections[3],all_full_offertimes[3])

# %%
def mccm_limit_w_intial2(data, collection,offertimes,x_intial, lam_intial, rho_initial):
    
    model = pyo.ConcreteModel(name="mccm_limit")
    
    n, m = data.shape
    
    # add Variables
    model.lam = pyo.Var(range(n), within=pyo.NonNegativeReals, name="lam")
    model.rho = pyo.Var(range(n), range(n), within=pyo.NonNegativeReals,  name="rho")
    
    # define nonnegative continuous variables for choice probability of each product in each assortment
    model.x = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="x")
    model.y = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="y")
    model.abs_var = pyo.Var(range(n), range(m), within=pyo.NonNegativeReals, name="abs_val")
    
    for i in range(n):
        model.lam[i] = lam_intial[i]
        for j in range(m):
            model.x[i,j] = x_intial[i,j]
    
    for i in range(n):
        for j in range(n):
            if i != j:
                model.rho[i,j] = rho_initial[i,j]
    
    model.obj = pyo.Objective(expr=sum( sum(offertimes[j]* data[i, j] * model.abs_var[i, j] for i in range(n) ) for j in range(m)), sense=pyo.minimize)
    #model.obj = Objective(expr=0,sense=minimize)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        # normalization constraint for each assortment.
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            model.norm_constraint.add(model.x[j,i] + model.y[j,i] == model.lam[j] + sum(model.y[k,i]*model.rho[k,j] for k in range(n)) )
            if j in collection[i]:
                # constraints for the absolute value
                model.norm_constraint.add(model.x[j, i] - data[j][i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(data[j][i] - model.x[j, i] - model.abs_var[j, i] <= 0)
                model.norm_constraint.add(model.y[j, i] == 0)
            else:
                model.norm_constraint.add(model.x[j, i] == 0)
                #model.norm_constraint.add(model.abs_var[j, i] == 0)
               
    # constraint of the arrival rate
    model.arrival_rate_constraint = pyo.Constraint(expr=sum(model.lam[i] for i in range(n)) == 1)
    
    ## constraints of the transition matrix
    model.transition_constraints = pyo.ConstraintList()
    model.transition_constraints.add(model.rho[0, 0] == 1)
    #model.transition_constraints.add(sum(model.rho[0, j] for j in range(n)) == 1)
    for j in range(1,n): 
        model.transition_constraints.add(model.rho[0, j] ==0 )
    for i in range(1, n):
        model.transition_constraints.add(model.rho[i, i] == 0)
        model.transition_constraints.add(sum(model.rho[i, j] for j in range(n)) == 1)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] =  10000
    solver.options['tol'] = 1e-6  # Tighten tolerance, might need further adjustments
    solver.options['dual_inf_tol'] = 1e-3  # Reduce tolerance for dual infeasibility
    solver.options['constr_viol_tol'] = 1e-8  # Tighten constraint violation tolerance
 
    
    try:
        # Your optimization solve code here
        #results = solver.solve(model)
        results = solver.solve(model,tee=True)
        status = str(results.solver.status)
        print("Pyomo optimization status:", status)
        #model.pprint()
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            #print('MLE: Optimal solution found!')
            #model.write('model.mps', io_options={'symbolic_solver_labels': True})
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            lam_values = [ model.lam[i].value for i in range(n)]
            lam_values = np.array(lam_values)
            
            rho_values = [[model.rho[i, j].value for j in range(n)] for i in range(n)]
            rho_values = np.array(rho_values)
            #model.pprint()
            #return [value(model.obj), x_values, results.solver.time]
            return [model.obj(), x_values, results.solver.time]
            
        
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")

    # Your further code to process results if needed

    except ValueError as e:
        print(f"Error: {e}")
        print('MCCM limit: No solution found or an error occurred.')
        #model.pprint()
        return [100000, np.zeros((n,m)), 0]

# %% [markdown]
# instance [4][13]

# %%
v_values, obj_value,runtime = mnl_mle_pyo(all_full_instances[4][31],all_full_collections[4],all_full_offertimes[4])
mnl_lam,mnl_rho,initial_probability = mccm_w_mnl(v_values,all_full_collections[4])
mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime =mccm_limit_w_intial2(all_full_instances[4][31],all_full_collections[4],all_full_offertimes[4],initial_probability,mnl_lam,mnl_rho)
all_mccm_limit_loss[4][31] = mccm_limit_loss
all_mccm_limit_prob[4][31] = mccm_limit_prob 
all_mccm_limit_runtime[4][31] = mccm_limit_runtime
# Out:
# Ipopt 3.12.12: max_iter=10000
# tol=1e-06
# dual_inf_tol=0.001
# constr_viol_tol=1e-08
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2586
# Number of nonzeros in inequality constraint Jacobian.:      124
# Number of nonzeros in Lagrangian Hessian.............:     1053
#
# Total number of variables............................:      355
#                      variables with only lower bounds:      355
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      273
# Total number of inequality constraints...............:       62
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       62
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.0819929e+01 9.90e-01 9.90e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.5362412e+01 9.74e-01 9.75e+01  -1.0 1.09e+00    -  1.10e-02 1.64e-02h  1
#    2  9.4046386e+01 9.59e-01 9.57e+02  -1.0 3.30e+01    -  8.88e-03 1.49e-02h  1
#    3  1.0209108e+02 9.56e-01 9.55e+02  -1.0 5.35e+01   0.0 7.02e-03 3.65e-03h  1
#    4  1.0511977e+02 9.55e-01 8.98e+02  -1.0 3.23e+02  -0.5 3.12e-04 1.23e-03h  1
#    5  1.1236442e+02 9.51e-01 8.72e+02  -1.0 3.36e+01    -  4.50e-03 3.26e-03h  1
#    6  1.1300545e+02 9.51e-01 8.72e+02  -1.0 1.88e+01   0.9 5.24e-03 2.69e-04h  1
#    7  1.1834622e+02 9.49e-01 9.23e+02  -1.0 3.39e+01   0.4 2.14e-03 2.16e-03h  1
#    8  1.1860503e+02 9.49e-01 9.24e+02  -1.0 4.19e+01    -  5.37e-03 1.11e-04h  1
#    9  1.2429359e+02 9.47e-01 1.24e+03  -1.0 6.23e+01    -  6.47e-03 2.33e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.2567805e+02 9.46e-01 1.36e+03  -1.0 2.97e+02    -  6.48e-04 5.40e-04h  1
#   11  1.2582435e+02 9.46e-01 1.36e+03  -1.0 5.98e+02    -  4.00e-04 4.36e-05h  1
#   12  1.2688435e+02 9.46e-01 1.95e+03  -1.0 8.65e+02    -  8.92e-06 3.49e-04h  1
#   13  1.2712031e+02 9.46e-01 1.98e+03  -1.0 6.74e+02    -  6.46e-05 7.88e-05h  1
#   14r 1.2712031e+02 9.46e-01 1.00e+03  -0.0 0.00e+00    -  0.00e+00 3.47e-07R  5
#   15r 2.2495024e+02 2.98e-01 1.00e+03  -0.0 3.24e+02    -  1.73e-04 2.89e-03f  1
#   16  2.7604435e+02 2.88e-01 3.55e+02  -1.0 5.75e+00    -  2.22e-02 3.44e-02f  1
#   17  2.8228404e+02 2.87e-01 3.61e+02  -1.0 1.24e+01    -  1.52e-02 3.85e-03h  1
#   18  2.9337620e+02 2.85e-01 4.18e+02  -1.0 2.23e+01  -0.1 1.38e-03 6.31e-03f  1
#   19  3.9792119e+02 2.66e-01 1.40e+03  -1.0 7.30e+00    -  1.29e-02 6.81e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  4.6513588e+02 2.54e-01 1.35e+03  -1.0 2.29e+00    -  8.22e-02 4.78e-02h  1
#   21  5.1907097e+02 2.44e-01 1.31e+03  -1.0 5.97e+00    -  5.67e-02 3.90e-02h  1
#   22  5.4402611e+02 2.39e-01 1.29e+03  -1.0 8.87e+00    -  6.39e-02 1.92e-02h  1
#   23  5.6057935e+02 2.36e-01 1.29e+03  -1.0 7.40e+00    -  1.47e-02 1.26e-02h  1
#   24  5.7539657e+02 2.33e-01 1.13e+03  -1.0 8.53e+00    -  1.14e-02 1.10e-02h  1
#   25  5.7725226e+02 2.33e-01 1.11e+03  -1.0 8.54e+01    -  2.38e-03 1.08e-03h  1
#   26  5.7873885e+02 2.33e-01 1.12e+03  -1.0 6.91e+01    -  4.96e-03 9.81e-04h  1
#   27  5.8567932e+02 2.32e-01 1.26e+03  -1.0 6.96e+01    -  2.72e-03 4.75e-03f  1
#   28  6.0019263e+02 2.29e-01 1.21e+03  -1.0 7.17e+00   0.3 4.57e-02 1.09e-02h  1
#   29  6.0785954e+02 2.28e-01 1.19e+03  -1.0 1.23e+01    -  1.21e-02 5.76e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  6.4451326e+02 2.21e-01 6.81e+02  -1.0 9.06e+00    -  1.75e-02 2.75e-02h  1
#   31  6.9101529e+02 2.13e-01 8.94e+02  -1.0 6.89e-01   1.7 1.74e-01 3.88e-02h  1
#   32  7.9214726e+02 1.95e-01 2.02e+03  -1.0 1.11e+00   1.2 2.90e-01 8.27e-02h  1
#   33  1.0710105e+03 1.47e-01 5.65e+03  -1.0 1.00e+00    -  2.49e-01 2.45e-01h  1
#   34  1.1563483e+03 1.32e-01 5.33e+03  -1.0 2.19e+00    -  2.10e-01 9.96e-02h  1
#   35  1.4165680e+03 8.69e-02 1.43e+04  -1.0 4.50e-01   0.7 1.00e+00 3.39e-01h  1
#   36  1.4884910e+03 7.45e-02 1.55e+04  -1.0 1.01e+00    -  3.82e-01 1.42e-01h  1
#   37  1.5127608e+03 7.04e-02 1.53e+04  -1.0 6.31e+00    -  9.77e-02 5.65e-02h  1
#   38  1.5142304e+03 6.94e-02 1.51e+04  -1.0 5.88e+01    -  2.02e-03 7.21e-03h  1
#   39  1.5719947e+03 5.94e-02 3.31e+04  -1.0 1.01e+00   1.1 5.92e-01 1.47e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.5903554e+03 5.60e-02 3.17e+04  -1.0 3.49e+00    -  1.09e-01 6.07e-02h  1
#   41  1.6066101e+03 5.30e-02 4.60e+04  -1.0 1.07e+00   1.6 9.84e-02 5.36e-02h  1
#   42  1.6201236e+03 5.09e-02 6.03e+04  -1.0 1.10e+00   2.0 6.51e-02 3.71e-02h  1
#   43  1.6378753e+03 4.80e-02 6.62e+04  -1.0 1.68e+00   1.5 5.65e-02 5.43e-02h  1
#   44  1.6494984e+03 4.63e-02 7.58e+04  -1.0 1.47e+00   1.9 1.57e-02 3.54e-02h  1
#   45  1.6644627e+03 4.40e-02 1.09e+05  -1.0 1.32e+00   2.4 1.17e-01 4.89e-02h  1
#   46  1.6673951e+03 4.36e-02 1.08e+05  -1.0 2.98e+00   1.9 2.85e-02 8.64e-03h  1
#   47  1.6708106e+03 4.30e-02 1.06e+05  -1.0 1.15e+00   2.3 2.16e-02 1.32e-02h  1
#   48  1.6720077e+03 4.28e-02 1.05e+05  -1.0 2.48e+00   2.7 5.47e-04 4.07e-03h  1
#   49  1.6744109e+03 4.23e-02 8.84e+04  -1.0 1.86e+00   3.2 1.75e-02 1.08e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.6768838e+03 4.19e-02 8.30e+04  -1.0 3.14e+00   2.7 3.15e-03 9.65e-03h  1
#   51  1.6786787e+03 4.16e-02 8.18e+04  -1.0 3.89e+00   2.2 4.27e-03 7.67e-03h  1
#   52  1.6891710e+03 3.96e-02 9.13e+04  -1.0 1.45e+00   2.6 6.96e-02 4.77e-02h  1
#   53  1.6917275e+03 3.91e-02 8.27e+04  -1.0 2.57e+00   2.1 4.77e-02 1.18e-02h  1
#   54  1.6973976e+03 3.80e-02 9.53e+04  -1.0 1.09e+00   2.6 3.89e-03 2.76e-02h  1
#   55  1.7005224e+03 3.74e-02 9.95e+04  -1.0 3.26e+00   2.1 7.08e-02 1.51e-02h  1
#   56  1.7061888e+03 3.64e-02 1.11e+05  -1.0 1.18e+00   2.5 4.36e-02 2.86e-02h  1
#   57  1.7063188e+03 3.63e-02 1.11e+05  -1.0 5.74e+00   2.0 9.87e-04 8.28e-04h  1
#   58  1.7067042e+03 3.63e-02 1.10e+05  -1.0 3.77e+00   2.5 7.92e-04 2.40e-03h  1
#   59  1.7067805e+03 3.62e-02 1.52e+05  -1.0 3.98e+00   2.9 5.45e-03 4.93e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  1.7075902e+03 3.61e-02 1.99e+05  -1.0 3.90e+00   2.4 7.29e-03 5.32e-03h  1
#   61  1.7088492e+03 3.59e-02 2.69e+05  -1.0 3.73e+00   2.8 7.31e-03 6.15e-03h  1
#   62  1.7095948e+03 3.58e-02 5.84e+05  -1.0 6.68e+00   2.4 8.05e-03 2.65e-03h  1
#   63  1.7099297e+03 3.57e-02 1.21e+06  -1.0 1.45e+01   2.8 3.84e-03 1.69e-03h  1
#   64  1.7101930e+03 3.57e-02 1.14e+06  -1.0 1.98e+01   2.3 6.69e-04 1.15e-03h  1
#   65  1.7102496e+03 3.57e-02 5.30e+06  -1.0 1.74e+01   2.7 1.34e-02 2.91e-04h  1
#   66  1.7110789e+03 3.56e-02 5.21e+06  -1.0 1.87e+01   2.3 2.75e-03 3.38e-03h  1
#   67  1.7110955e+03 3.56e-02 7.06e+06  -1.0 1.74e+01   2.7 5.26e-03 6.56e-05h  1
#   68  1.7116699e+03 3.55e-02 7.98e+06  -1.0 2.57e+01   2.2 9.39e-03 2.21e-03h  1
#   69  1.7119516e+03 3.55e-02 7.86e+06  -1.0 1.62e+01   2.6 6.61e-04 9.32e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.7123010e+03 3.54e-02 8.05e+06  -1.0 3.26e+01   2.2 1.22e-03 6.19e-04h  1
#   71  1.7121520e+03 3.54e-02 8.09e+06  -1.0 1.90e+02   1.7 1.87e-04 3.93e-04h  1
#   72  1.7140382e+03 3.53e-02 7.21e+06  -1.0 3.14e+01   2.1 6.04e-05 3.24e-03h  1
#   73  1.7144708e+03 3.52e-02 1.45e+07  -1.0 3.29e+01   2.5 1.02e-02 6.25e-04h  1
#   74  1.7192918e+03 3.50e-02 1.39e+07  -1.0 2.87e+01   2.1 2.26e-03 5.30e-03h  1
#   75  1.7196727e+03 3.50e-02 1.40e+07  -1.0 5.53e+01   1.6 1.08e-04 3.24e-04h  1
#   76  1.7228358e+03 3.49e-02 1.31e+07  -1.0 3.02e+01   2.0 1.31e-02 2.37e-03h  1
#   77  1.7247424e+03 3.49e-02 1.39e+07  -1.0 7.36e+01   1.5 5.78e-05 1.61e-03f  1
#   78  1.7263224e+03 3.48e-02 1.49e+07  -1.0 4.61e+01   2.0 1.46e-05 1.07e-03f  1
#   79  1.7268405e+03 3.48e-02 1.48e+07  -1.0 5.03e+01   1.5 4.22e-04 3.42e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  1.7270616e+03 3.48e-02 3.81e+07  -1.0 1.63e+01   2.8 6.27e-02 2.53e-04h  1
#   81  1.7422747e+03 3.48e-02 3.95e+07  -1.0 3.87e+01   2.3 8.91e-04 1.11e-02h  1
#   82  1.7426799e+03 3.48e-02 3.95e+07  -1.0 3.22e+01   1.9 1.47e-03 1.01e-03h  1
#   83  1.7426884e+03 3.48e-02 3.99e+07  -1.0 2.01e+01   4.1 1.30e-04 1.43e-05h  1
#   84r 1.7426884e+03 3.48e-02 1.00e+03  -1.0 0.00e+00   3.6 0.00e+00 3.29e-07R  5
#   85r 1.8043226e+03 1.74e-02 9.85e+02  -1.0 5.06e+01    -  3.27e-02 7.10e-03f  1
#   86  1.8043208e+03 1.74e-02 9.90e+01  -1.0 3.39e+01    -  5.19e-04 3.20e-05f  1
#   87  1.8043251e+03 1.74e-02 9.90e+01  -1.0 1.33e+01    -  2.16e-04 1.90e-05f  1
#   88  1.8055280e+03 1.73e-02 8.31e+02  -1.0 8.72e+00    -  1.21e-02 4.45e-03f  1
#   89  1.8069046e+03 1.72e-02 1.19e+03  -1.0 3.22e+00    -  2.83e-02 5.39e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  1.8107269e+03 1.69e-02 1.89e+03  -1.0 2.76e+00    -  3.05e-02 1.73e-02f  1
#   91  1.8129843e+03 1.67e-02 3.02e+03  -1.0 3.49e+00    -  5.11e-02 1.11e-02f  1
#   92  1.8184791e+03 1.63e-02 6.34e+03  -1.0 3.56e+00    -  5.91e-02 2.88e-02h  1
#   93  1.8210629e+03 1.60e-02 8.37e+03  -1.0 3.25e+00    -  1.84e-02 1.45e-02h  1
#   94  1.8224210e+03 1.61e-02 7.90e+03  -1.0 1.69e+01    -  1.62e-03 1.28e-02f  1
#   95  1.8238611e+03 1.58e-02 7.54e+03  -1.0 1.66e-01   3.1 8.11e-03 1.97e-02h  1
#   96  1.8267243e+03 1.53e-02 6.87e+03  -1.0 2.57e-01   2.7 1.34e-02 2.80e-02h  1
#   97  1.8293347e+03 1.50e-02 6.50e+03  -1.0 3.15e-01   2.2 7.02e-02 2.02e-02h  1
#   98  1.8297529e+03 1.49e-02 6.53e+03  -1.0 2.17e+01    -  8.32e-03 6.81e-03h  1
#   99  1.8324765e+03 1.46e-02 6.35e+03  -1.0 4.11e+00    -  8.21e-02 2.24e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  1.8360755e+03 1.41e-02 6.38e+03  -1.0 2.80e+00    -  1.84e-01 3.05e-02h  1
#  101  1.8370703e+03 1.39e-02 6.35e+03  -1.0 6.55e+00    -  1.24e-02 1.67e-02h  1
#  102  1.8434969e+03 1.31e-02 9.55e+03  -1.0 1.30e+00    -  6.93e-02 5.65e-02h  1
#  103  1.8405923e+03 1.38e-02 1.03e+04  -1.0 8.10e+01    -  1.95e-04 1.64e-03f  1
#  104  1.8451186e+03 1.49e-02 2.36e+04  -1.0 3.14e+00    -  3.65e-02 7.25e-02h  1
#  105  1.8482902e+03 1.45e-02 2.30e+04  -1.0 2.11e-01   1.7 9.50e-02 2.94e-02h  1
#  106  1.8521516e+03 1.41e-02 2.23e+04  -1.0 1.10e+00   1.2 2.95e-02 3.79e-02h  1
#  107  1.8516241e+03 1.48e-02 2.74e+04  -1.0 1.27e+01    -  1.63e-02 1.97e-02f  2
#  108  1.8638481e+03 1.40e-02 2.70e+04  -1.0 1.08e+00    -  2.07e-01 1.16e-01h  1
#  109  1.8797960e+03 1.17e-02 2.19e+04  -1.0 3.03e-01    -  2.44e-01 1.67e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.8969411e+03 9.23e-03 2.36e+04  -1.0 2.98e-01    -  8.47e-01 2.13e-01h  1
#  111  1.9063539e+03 8.02e-03 4.72e+04  -1.0 1.25e+00    -  7.61e-01 1.30e-01h  1
#  112  1.9185442e+03 6.72e-03 2.30e+05  -1.0 2.19e+00    -  1.18e-01 1.63e-01h  1
#  113  1.9247224e+03 6.06e-03 2.88e+05  -1.0 1.99e+00    -  3.43e-01 9.89e-02h  1
#  114  1.9311829e+03 5.29e-03 5.73e+05  -1.0 2.01e+00    -  2.00e-01 1.26e-01h  1
#  115  1.9324560e+03 5.14e-03 6.48e+05  -1.0 3.11e+00    -  7.28e-02 2.82e-02h  1
#  116  1.9336961e+03 5.01e-03 1.02e+06  -1.0 3.82e+00    -  8.38e-03 2.51e-02h  1
#  117  1.9386554e+03 4.54e-03 2.86e+06  -1.0 1.80e+00    -  1.97e-01 9.44e-02h  1
#  118  1.9393650e+03 4.32e-03 3.88e+06  -1.0 1.70e+00    -  1.38e-01 4.85e-02h  1
#  119  1.9393675e+03 4.30e-03 4.27e+06  -1.0 3.63e-05  11.1 5.37e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  1.9393739e+03 4.30e-03 4.27e+06  -1.0 1.24e+02    -  6.42e-04 1.32e-04h  1
#  121  1.9399977e+03 4.22e-03 4.19e+06  -1.0 1.36e+00    -  3.51e-03 1.88e-02h  1
#  122  1.9399983e+03 4.22e-03 4.19e+06  -1.0 4.53e-03  10.6 3.12e-03 1.04e-03h  1
#  123  1.9399983e+03 4.22e-03 4.19e+06  -1.0 4.52e-03  10.1 1.07e-03 4.41e-05h  1
#  124  1.9399994e+03 4.21e-03 4.18e+06  -1.0 4.52e-03   9.6 6.24e-04 2.15e-03h  1
#  125  1.9400017e+03 4.19e-03 4.16e+06  -1.0 4.51e-03   9.2 1.81e-03 4.33e-03f  1
#  126  1.9400018e+03 4.19e-03 4.16e+06  -1.0 4.50e-03   8.7 1.09e-02 1.01e-04h  1
#  127  1.9400135e+03 4.09e-03 4.10e+06  -1.0 4.50e-03   8.2 1.39e-03 2.23e-02f  1
#  128  1.9400174e+03 4.06e-03 4.07e+06  -1.0 4.40e-03   7.7 1.09e-01 7.53e-03h  1
#  129  1.9400305e+03 3.96e-03 3.97e+06  -1.0 4.36e-03   7.3 3.03e-02 2.45e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  1.9400702e+03 3.70e-03 3.72e+06  -1.0 5.00e-03   6.8 7.69e-02 6.72e-02h  1
#  131  1.9401388e+03 3.40e-03 3.42e+06  -1.7 7.78e-03   6.3 1.23e-01 8.13e-02h  1
#  132  1.9401757e+03 3.35e-03 3.37e+06  -1.7 7.35e-03   5.8 1.08e-01 1.51e-02h  1
#  133  1.9401916e+03 3.34e-03 3.36e+06  -1.7 4.97e-02   5.3 1.28e-03 3.31e-03h  1
#  134  1.9402054e+03 3.33e-03 3.35e+06  -1.7 1.92e-01   4.9 3.96e-03 2.33e-03h  1
#  135  1.9402007e+03 3.32e-03 3.35e+06  -1.7 1.23e+00   4.4 3.28e-03 8.23e-04h  1
#  136  1.9402258e+03 3.31e-03 3.33e+06  -1.7 2.90e-01   4.8 2.47e-03 4.05e-03h  1
#  137  1.9402288e+03 3.31e-03 3.33e+06  -1.7 2.89e-01   5.2 7.24e-03 5.99e-04h  1
#  138  1.9402392e+03 3.30e-03 3.33e+06  -1.7 3.96e-01   4.8 1.13e-02 1.52e-03h  1
#  139  1.9402789e+03 3.30e-03 3.32e+06  -1.7 4.79e+01    -  1.43e-04 6.41e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  1.9402840e+03 3.30e-03 3.32e+06  -1.7 3.27e+02    -  1.89e-04 1.80e-04h  1
#  141  1.9402878e+03 3.30e-03 3.32e+06  -1.7 7.86e-01   4.3 7.77e-03 4.20e-04h  1
#  142  1.9403640e+03 3.27e-03 3.29e+06  -1.7 5.04e-01   4.7 3.42e-04 1.03e-02h  1
#  143  1.9403823e+03 3.26e-03 3.27e+06  -1.7 5.63e-01   5.1 4.77e-03 3.24e-03h  1
#  144  1.9404976e+03 3.21e-03 3.23e+06  -1.7 5.75e-01   4.7 1.58e-04 1.50e-02f  1
#  145  1.9405040e+03 3.20e-03 3.23e+06  -1.7 1.25e-01   5.1 2.76e-04 1.09e-03h  1
#  146  1.9405121e+03 3.20e-03 3.22e+06  -1.7 5.05e-01   4.6 1.59e-02 1.04e-03h  1
#  147  1.9405337e+03 3.19e-03 3.21e+06  -1.7 6.46e-01   5.0 3.13e-03 3.58e-03h  1
#  148  1.9406569e+03 3.14e-03 3.13e+06  -1.7 6.16e-01   4.6 2.02e-04 1.55e-02f  1
#  149  1.9406668e+03 3.13e-03 3.12e+06  -1.7 6.30e-02   5.0 6.62e-03 1.64e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  1.9409055e+03 3.04e-03 3.04e+06  -1.7 1.84e-01   4.5 1.43e-03 3.12e-02f  1
#  151  1.9409668e+03 3.01e-03 3.04e+06  -1.7 6.28e-02   4.9 5.97e-02 9.92e-03h  1
#  152  1.9410973e+03 2.96e-03 2.96e+06  -1.7 2.85e-01   4.5 3.10e-03 1.63e-02h  1
#  153  1.9411191e+03 2.95e-03 5.39e+06  -1.7 6.95e-02   4.9 6.42e-02 3.38e-03h  1
#  154  1.9411523e+03 2.93e-03 5.44e+06  -1.7 6.71e-01   4.4 5.09e-04 3.96e-03h  1
#  155  1.9412422e+03 2.90e-03 5.33e+06  -1.7 1.42e-01   4.8 7.30e-04 1.34e-02f  1
#  156  1.9412436e+03 2.89e-03 5.18e+06  -1.7 1.17e-01   5.3 5.44e-03 2.98e-04h  1
#  157  1.9412534e+03 2.89e-03 5.17e+06  -1.7 7.06e-02   4.8 1.55e-03 1.43e-03h  1
#  158  1.9412689e+03 2.89e-03 6.54e+06  -1.7 9.28e-01   4.3 2.68e-02 1.79e-03h  1
#  159  1.9412717e+03 2.88e-03 7.90e+06  -1.7 2.33e-01   4.7 7.11e-02 3.96e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  1.9415275e+03 2.80e-03 3.30e+06  -1.7 6.95e-01   4.3 6.70e-04 2.89e-02h  1
#  161  1.9418259e+03 2.71e-03 3.49e+06  -1.7 6.11e-01   3.8 9.01e-02 3.17e-02h  1
#  162  1.9423650e+03 2.54e-03 3.49e+06  -1.7 1.29e+00   3.3 1.39e-02 6.39e-02h  1
#  163  1.9429885e+03 2.20e-03 4.50e+06  -1.7 1.21e+00   2.8 7.50e-03 1.34e-01h  1
#  164  1.9429909e+03 2.20e-03 4.89e+06  -1.7 6.22e-01   4.2 3.03e-02 3.45e-04h  1
#  165  1.9429942e+03 2.20e-03 4.86e+06  -1.7 1.02e+00   4.6 1.76e-04 5.53e-04h  1
#  166  1.9430007e+03 2.19e-03 1.12e+08  -1.7 9.56e-01   5.0 2.54e-01 1.40e-03h  1
#  167  1.9432368e+03 2.11e-03 1.06e+08  -1.7 9.76e-01   4.5 1.39e-03 3.75e-02h  1
#  168  1.9432378e+03 2.11e-03 1.53e+08  -1.7 8.24e-01   5.9 1.57e-02 4.61e-04h  1
#  169  1.9432381e+03 2.11e-03 2.61e+08  -1.7 9.20e-01   5.4 3.71e-02 8.91e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  1.9432965e+03 2.09e-03 2.80e+08  -1.7 9.90e-01   4.9 2.79e-04 8.86e-03f  1
#  171  1.9428824e+03 2.09e-03 2.80e+08  -1.7 1.04e+02    -  8.94e-04 2.02e-03h  1
#  172r 1.9428824e+03 2.09e-03 1.00e+03  -1.7 0.00e+00    -  0.00e+00 2.80e-07R  5
#  173r 1.9454538e+03 1.60e-03 1.12e+03  -1.7 2.85e-01    -  2.58e-01 2.00e-02f  1
#  174  1.9454403e+03 1.60e-03 7.03e+02  -1.7 2.69e+00    -  1.07e-02 6.18e-05f  1
#  175  1.9451392e+03 1.60e-03 1.26e+04  -1.7 8.41e-02    -  5.95e-02 2.26e-03f  1
#  176  1.9440783e+03 1.56e-03 5.02e+04  -1.7 8.84e-01    -  4.79e-04 2.62e-02h  1
#  177  1.9440795e+03 1.55e-03 1.86e+05  -1.7 2.24e-02   4.4 4.08e-02 2.67e-03h  1
#  178  1.9440982e+03 1.55e-03 7.72e+04  -1.7 4.98e-01   3.9 4.73e-05 1.72e-03h  1
#  179  1.9441098e+03 1.55e-03 1.80e+06  -1.7 7.56e-01   3.5 6.82e-02 3.61e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  1.9417305e+03 1.45e-03 5.19e+06  -1.7 2.83e+00    -  5.88e-03 6.38e-02f  1
#  181  1.9411012e+03 1.41e-03 5.19e+06  -1.7 3.89e+00    -  2.89e-02 2.86e-02h  1
#  182  1.9410912e+03 1.41e-03 5.18e+06  -1.7 3.04e+00    -  4.08e-04 2.78e-03h  1
#  183  1.9410917e+03 1.41e-03 5.18e+06  -1.7 2.16e-01   4.8 5.90e-04 3.12e-05h  1
#  184  1.9410874e+03 1.40e-03 5.16e+06  -1.7 3.13e+00    -  1.18e-04 2.89e-03f  1
#  185  1.9410872e+03 1.40e-03 5.16e+06  -1.7 2.85e-01   4.3 5.13e-04 3.40e-05h  1
#  186  1.9410856e+03 1.40e-03 5.16e+06  -1.7 1.30e+00    -  3.16e-05 1.36e-04h  1
#  187  1.9407893e+03 1.40e-03 5.12e+06  -1.7 6.85e+01    -  1.27e-03 3.99e-04f  1
#  188  1.9403737e+03 1.40e-03 5.06e+06  -1.7 7.17e+01    -  1.64e-03 2.97e-03h  1
#  189  1.9403753e+03 1.39e-03 5.05e+06  -1.7 2.24e+01    -  2.29e-02 1.91e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  1.9403457e+03 1.38e-03 5.00e+06  -1.7 3.34e+01    -  2.03e-02 8.47e-03h  1
#  191  1.9403449e+03 1.38e-03 5.00e+06  -1.7 1.22e+01    -  3.11e-02 2.31e-04h  1
#  192  1.9403456e+03 1.38e-03 4.99e+06  -1.7 3.35e-04  10.2 4.17e-01 7.39e-02h  1
#  193  1.9373199e+03 1.14e-03 4.14e+06  -1.7 3.51e-01    -  1.46e-01 1.70e-01h  1
#  194  1.9368311e+03 1.09e-03 3.96e+06  -1.7 1.15e-01    -  1.94e-01 4.44e-02h  1
#  195  1.9332766e+03 7.19e-04 2.57e+06  -1.7 1.24e-01    -  1.96e-03 3.42e-01h  1
#  196  1.9308030e+03 6.95e-04 2.49e+06  -1.7 3.30e-01    -  1.76e-02 3.29e-02f  1
#  197  1.9308036e+03 6.91e-04 2.48e+06  -1.7 8.02e-04   9.7 1.36e-02 6.35e-03h  1
#  198  1.9308048e+03 6.82e-04 2.47e+06  -1.7 7.97e-04   9.2 4.10e-02 1.32e-02h  1
#  199  1.9308083e+03 6.56e-04 2.45e+06  -1.7 7.87e-04   8.7 3.00e-02 3.75e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.9308133e+03 6.20e-04 4.59e+06  -1.7 7.57e-04   8.3 1.80e-01 5.57e-02h  1
#  201  1.9308173e+03 5.93e-04 4.38e+06  -1.7 7.15e-04   7.8 3.78e-02 4.30e-02h  1
#  202  1.9308174e+03 5.93e-04 4.35e+06  -1.7 1.01e-03   7.3 1.08e-02 5.09e-04h  1
#  203  1.9308193e+03 5.86e-04 4.29e+06  -1.7 5.36e-03   6.8 1.43e-03 1.11e-02f  1
#  204  1.9308314e+03 5.65e-04 4.13e+06  -1.7 6.33e-03   6.3 3.62e-02 3.56e-02h  1
#  205  1.9308330e+03 5.64e-04 3.40e+06  -1.7 1.40e-02   5.9 4.43e-01 2.20e-03h  1
#  206  1.9309059e+03 5.35e-04 2.06e+06  -1.7 2.08e-02   5.4 8.41e-01 5.11e-02h  1
#  207  1.9322144e+03 1.94e-04 8.21e+05  -1.7 2.05e-02   4.9 6.25e-01 6.37e-01h  1
#  208  1.9322946e+03 1.62e-04 6.79e+05  -2.5 8.25e-03   4.4 1.71e-01 1.66e-01h  1
#  209  1.9323067e+03 1.58e-04 6.62e+05  -2.5 7.34e-03   4.0 1.43e-01 2.47e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.9324539e+03 1.39e-04 5.83e+05  -2.5 1.16e-02   3.5 4.44e-01 1.20e-01h  1
#  211  1.9335189e+03 8.47e-05 3.53e+05  -2.5 1.86e-02   3.0 4.13e-03 3.90e-01h  1
#  212  1.9345525e+03 8.03e-05 4.10e+05  -2.5 9.60e-02   2.5 1.11e-02 5.17e-02h  1
#  213  1.9345544e+03 7.53e-05 8.85e+05  -2.5 4.11e-04   6.6 1.36e-01 6.18e-02h  1
#  214  1.9345551e+03 7.44e-05 1.32e+06  -2.5 1.89e-03   6.1 4.82e-02 1.31e-02h  1
#  215  1.9345578e+03 6.79e-05 9.98e+06  -2.5 7.29e-04   6.5 8.65e-01 8.71e-02h  1
#  216  1.9345916e+03 1.46e-05 7.85e+05  -2.5 1.60e-03   6.0 9.29e-01 7.85e-01h  1
#  217  1.9345922e+03 1.28e-05 1.71e+06  -2.5 3.15e-04   6.5 3.74e-01 1.19e-01h  1
#  218  1.9345922e+03 1.25e-05 1.68e+06  -2.5 7.67e-04   6.0 1.74e-02 2.87e-02f  2
#  219  1.9345922e+03 1.24e-05 2.03e+06  -2.5 5.35e-04   6.4 7.12e-02 5.07e-03f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  1.9345922e+03 1.20e-05 1.98e+06  -2.5 8.61e-04   5.9 3.70e-02 3.04e-02h  1
#  221  1.9345922e+03 1.20e-05 5.20e+04  -2.5 8.30e-07  10.9 1.00e+00 5.14e-02f  2
#  222  1.9345922e+03 1.19e-05 6.98e+04  -3.8 1.68e-05  10.4 4.41e-03 1.02e-02h  1
#  223  1.9345922e+03 1.19e-05 1.77e+06  -3.8 5.88e-05   9.9 8.71e-02 3.25e-03h  1
#  224  1.9345922e+03 1.17e-05 1.66e+06  -3.8 2.88e-07  11.3 5.97e-02 7.28e-01h  1
#  225  1.9345922e+03 1.16e-05 6.79e+06  -3.8 1.08e-04  10.8 3.53e-02 6.45e-03h  1
#  226  1.9345922e+03 1.15e-05 1.03e+07  -3.8 1.32e-04  10.3 5.69e-02 5.82e-03f  2
#  227  1.9345923e+03 1.12e-05 1.05e+07  -3.8 1.83e-04   9.8 4.63e-02 2.68e-02h  1
#  228  1.9345926e+03 8.90e-06 8.45e+06  -3.8 1.90e-04   9.3 3.18e-01 2.08e-01h  1
#  229  1.9345926e+03 8.66e-06 6.91e+06  -3.8 2.00e-04   8.9 1.81e-01 2.61e-02f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  1.9345926e+03 8.61e-06 6.87e+06  -3.8 1.67e-04   9.3 1.97e-03 6.48e-03h  1
#  231  1.9345926e+03 8.61e-06 4.63e+06  -3.8 3.52e-06  11.5 3.26e-01 1.41e-03f  2
#  232  1.9345926e+03 8.60e-06 1.37e+06  -3.8 6.32e-07  12.0 7.04e-01 1.07e-01h  1
#  233  1.9345926e+03 8.60e-06 1.17e+06  -3.8 2.81e-06  11.5 1.34e-01 1.98e-02f  2
#  234  1.9345926e+03 8.59e-06 1.77e+06  -3.8 3.58e-04  11.0 1.54e-03 5.16e-04h  1
#  235  1.9345926e+03 8.54e-06 1.27e+07  -3.8 1.56e-04  10.5 7.77e-02 6.17e-03f  2
#  236  1.9345927e+03 8.08e-06 1.94e+07  -3.8 1.58e-04  10.0 2.25e-01 5.36e-02h  1
#  237  1.9345927e+03 8.08e-06 1.94e+07  -3.8 1.09e-03   9.6 8.96e-05 1.01e-04h  1
#  238  1.9345927e+03 8.06e-06 1.93e+07  -3.8 1.88e-04   9.1 1.83e-03 3.35e-03f  1
#  239  1.9345927e+03 8.01e-06 2.80e+07  -3.8 1.04e-03   8.6 8.03e-02 5.97e-03f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  1.9345927e+03 8.00e-06 2.54e+07  -3.8 9.46e-07  11.8 9.03e-02 8.25e-02h  1
#  241  1.9345927e+03 8.00e-06 4.99e+05  -3.8 3.36e-07  12.2 1.00e+00 9.28e-02f  2
#  242  1.9345927e+03 7.97e-06 1.58e+07  -3.8 1.47e-04  11.7 1.04e-02 3.70e-03h  1
#  243  1.9345927e+03 7.91e-06 1.48e+07  -3.8 1.53e-04  11.2 6.40e-03 7.58e-03f  2
#  244  1.9345928e+03 7.43e-06 1.31e+07  -3.8 1.54e-04  10.7 5.64e-02 6.05e-02h  1
#  245  1.9345930e+03 5.94e-06 1.12e+07  -3.8 1.54e-04  10.3 2.08e-01 2.00e-01h  1
#  246  1.9345930e+03 5.75e-06 3.07e+07  -3.8 1.53e-04   9.8 1.37e-01 3.13e-02f  2
#  247  1.9345930e+03 5.75e-06 3.05e+07  -3.8 1.84e-02   9.3 2.67e-06 4.68e-05f  2
#  248  1.9345930e+03 5.69e-06 3.05e+07  -3.8 1.57e-04   9.7 3.69e-02 1.01e-02h  1
#  249  1.9345930e+03 5.64e-06 3.12e+07  -3.8 1.30e-04  10.2 3.74e-02 1.03e-02f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  1.9345930e+03 5.64e-06 3.03e+07  -3.8 1.36e-06  12.4 2.90e-02 1.42e-02f  1
#  251  1.9345930e+03 5.64e-06 2.82e+07  -3.8 4.32e-07  12.8 6.93e-02 1.48e-02f  2
#  252  1.9345930e+03 5.61e-06 4.47e+08  -3.8 1.18e-04  12.3 5.57e-02 4.86e-03h  1
#  253  1.9345930e+03 5.58e-06 7.10e+08  -3.8 1.18e-04  11.9 1.16e-01 5.03e-03f  2
#  254  1.9345931e+03 5.28e-06 6.66e+08  -3.8 1.19e-04  11.4 1.90e-02 5.40e-02h  1
#  255  1.9345931e+03 5.28e-06 6.06e+08  -3.8 1.60e-07  13.6 9.00e-02 1.69e-02f  2
#  256  1.9345931e+03 5.25e-06 7.31e+08  -3.8 1.13e-04  13.1 7.47e-03 5.02e-03h  1
#  257  1.9345931e+03 5.25e-06 7.52e+08  -3.8 1.04e-04  12.7 2.17e-03 7.06e-04f  2
#  258  1.9345931e+03 5.25e-06 6.74e+08  -3.8 1.55e-07  14.0 1.04e-01 1.33e-01h  1
#  259  1.9345931e+03 5.24e-06 6.32e+08  -3.8 5.23e-07  13.5 6.21e-02 4.44e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  1.9345931e+03 5.23e-06 4.18e+08  -3.8 1.90e-07  13.9 3.39e-01 5.32e-01f  1
#  261  1.9345931e+03 5.23e-06 8.17e+08  -3.8 1.12e-04  13.5 4.05e-03 4.10e-04f  3
#  262  1.9345931e+03 5.22e-06 9.99e+08  -3.8 1.12e-04  13.0 7.06e-03 1.92e-03h  2
#  263  1.9345931e+03 5.21e-06 9.80e+08  -3.8 1.12e-04  12.5 3.13e-05 1.70e-03f  2
#  264  1.9345931e+03 5.20e-06 1.05e+09  -3.8 1.13e-04  12.0 2.74e-02 1.67e-03h  1
#  265  1.9345931e+03 5.16e-06 1.04e+09  -3.8 1.13e-04  11.6 3.27e-03 9.21e-03f  2
#  266  1.9345931e+03 5.01e-06 8.07e+08  -3.8 1.24e-04  11.1 2.09e-01 2.81e-02h  1
#  267  1.9345931e+03 5.01e-06 7.83e+08  -3.8 2.04e-04  10.6 1.63e-02 1.17e-03f  2
#  268  1.9345931e+03 5.00e-06 7.82e+08  -3.8 6.61e+03  10.1 9.19e-05 3.53e-05H  1
#  269  1.9345931e+03 5.00e-06 7.75e+08  -3.8 2.92e-04  10.6 4.55e-03 3.98e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  1.9345931e+03 5.00e-06 7.60e+08  -3.8 1.40e-03  10.1 1.06e-02 6.03e-04f  1
#  271  1.9345931e+03 4.99e-06 7.19e+08  -3.8 4.89e-04  10.5 2.30e-02 2.01e-03h  1
#  272  1.9345931e+03 4.85e-06 6.77e+08  -3.8 1.28e-04  10.9 5.04e-02 2.88e-02f  1
#  273  1.9345931e+03 4.84e-06 6.79e+08  -3.8 7.34e-04  10.5 1.72e-04 1.42e-03f  2
#  274  1.9345931e+03 4.84e-06 6.34e+08  -3.8 3.33e-04  10.0 4.86e-02 5.46e-04h  1
#  275  1.9345931e+03 4.84e-06 6.29e+08  -3.8 2.56e-03  10.4 1.22e-03 2.24e-04f  2
#  276  1.9345931e+03 4.83e-06 6.25e+08  -3.8 3.17e-04   9.9 4.79e-03 5.18e-04f  1
#  277  1.9345931e+03 4.83e-06 5.70e+08  -3.8 2.34e-07  14.0 8.87e-02 5.64e-01f  1
#  278  1.9345931e+03 4.82e-06 5.74e+08  -3.8 1.05e-04  13.5 1.23e-03 1.19e-03f  2
#  279  1.9345931e+03 4.82e-06 5.86e+08  -3.8 1.05e-04  13.0 9.67e-04 6.06e-04f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  1.9345931e+03 4.82e-06 5.66e+08  -3.8 2.71e-06  13.4 3.37e-02 4.47e-04h  3
#  281  1.9345931e+03 4.81e-06 5.31e+08  -3.8 1.05e-04  13.0 6.02e-04 1.74e-03h  1
#  282  1.9345931e+03 4.76e-06 5.14e+08  -3.8 1.05e-04  12.5 8.22e-03 9.47e-03f  2
#  283  1.9345931e+03 4.76e-06 4.81e+08  -3.8 4.99e-07  13.8 6.47e-02 1.29e-01h  2
#  284  1.9345931e+03 4.76e-06 8.91e+08  -3.8 1.04e-04  13.3 6.70e-03 1.09e-03h  1
#  285  1.9345932e+03 4.71e-06 7.43e+08  -3.8 1.04e-04  12.9 3.15e-03 9.20e-03f  1
#  286  1.9345932e+03 4.66e-06 7.91e+08  -3.8 1.04e-04  12.4 1.95e-02 1.08e-02h  1
#  287  1.9345932e+03 4.52e-06 7.58e+08  -3.8 1.05e-04  11.9 1.93e-02 3.07e-02f  2
#  288  1.9345932e+03 4.47e-06 5.52e+08  -3.8 1.08e-04  11.4 1.89e-01 1.08e-02h  1
#  289  1.9345932e+03 4.47e-06 4.92e+08  -3.8 1.40e-04  10.9 3.37e-02 5.85e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  1.9345932e+03 4.34e-06 4.91e+08  -3.8 1.08e-04  11.4 1.48e-02 2.79e-02f  2
#  291  1.9345932e+03 4.34e-06 4.79e+08  -3.8 1.43e-04  10.9 6.51e-03 2.89e-04h  1
#  292  1.9345932e+03 4.29e-06 4.81e+08  -3.8 1.07e-04  11.3 4.50e-03 1.24e-02f  2
#  293  1.9345932e+03 4.29e-06 3.04e+08  -3.8 1.52e-04  10.8 8.94e-02 3.18e-04h  1
#  294  1.9345932e+03 4.17e-06 3.01e+08  -3.8 1.07e-04  11.3 2.14e-02 2.68e-02f  2
#  295  1.9345932e+03 4.16e-06 3.05e+08  -3.8 1.75e-04  10.8 1.04e-05 2.23e-03f  2
#  296  1.9345933e+03 3.87e-06 3.41e+08  -3.8 1.05e-04  11.2 1.76e-02 7.09e-02h  1
#  297  1.9345933e+03 3.86e-06 3.22e+08  -3.8 1.76e-04  10.7 1.06e-02 1.57e-03f  2
#  298  1.9345934e+03 3.01e-06 4.24e+08  -3.8 9.75e-05  11.2 7.39e-02 2.20e-01h  1
#  299  1.9345934e+03 3.01e-06 4.12e+08  -3.8 1.99e-07  14.3 2.86e-02 9.42e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  1.9345934e+03 3.01e-06 4.06e+08  -3.8 6.60e-05  13.8 1.19e-03 1.22e-03f  2
#  301  1.9345934e+03 3.01e-06 4.07e+08  -3.8 1.16e-04  13.4 2.23e-05 1.13e-05h  1
#  302  1.9345934e+03 3.00e-06 1.19e+09  -3.8 6.60e-05  12.9 5.59e-02 1.27e-03f  2
#  303  1.9345934e+03 2.98e-06 1.17e+09  -3.8 6.62e-05  12.4 3.35e-03 8.49e-03h  1
#  304  1.9345934e+03 2.94e-06 1.06e+09  -3.8 6.65e-05  11.9 1.68e-01 1.43e-02f  2
#  305  1.9345936e+03 1.70e-06 8.24e+08  -3.8 6.84e-05  11.4 3.00e-01 4.20e-01h  1
#  306  1.9345936e+03 1.69e-06 7.72e+08  -3.8 4.03e-05  11.0 3.47e-02 8.97e-03f  2
#  307  1.9345936e+03 1.68e-06 7.06e+08  -3.8 1.01e-04  10.5 3.64e-02 5.68e-03h  1
#  308  1.9345936e+03 1.68e-06 6.81e+08  -3.8 1.21e-07  14.5 3.64e-02 1.25e-02f  2
#  309  1.9345936e+03 1.68e-06 6.71e+08  -3.8 3.85e-07  14.0 1.49e-02 1.29e-02h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  1.9345936e+03 1.68e-06 6.34e+08  -3.8 1.37e-07  14.5 5.47e-02 4.99e-02h  1
#  311  1.9345936e+03 1.68e-06 6.12e+08  -3.8 4.44e-07  14.0 3.52e-02 3.15e-02f  1
#  312  1.9345936e+03 1.67e-06 4.10e+07  -3.8 1.55e-07  14.4 1.00e+00 7.37e-01f  1
#  313  1.9345936e+03 1.67e-06 4.10e+07  -3.8 5.22e-07  13.9 7.66e-02 2.51e-03f  2
#  314r 1.9345936e+03 1.67e-06 1.00e+03  -3.8 0.00e+00  14.4 0.00e+00 3.80e-07R 17
#  315r 1.9343721e+03 1.62e-06 1.39e+03  -3.8 9.32e-02    -  4.18e-02 2.10e-02f  1
#  316r 1.9300384e+03 5.06e-07 1.08e+03  -3.8 9.30e-02    -  2.37e-01 3.97e-01f  1
#  317  1.9297772e+03 5.12e-07 9.88e+01  -3.8 3.77e-01    -  9.68e-03 1.85e-03f  1
#  318  1.9282587e+03 5.51e-07 9.77e+01  -3.8 3.87e-01    -  2.97e-03 1.16e-02f  1
#  319  1.9266185e+03 5.91e-07 9.64e+01  -3.8 3.97e-01    -  1.70e-02 1.32e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  1.9234124e+03 6.61e-07 1.17e+02  -3.8 4.25e-01    -  6.88e-02 2.64e-02f  1
#  321  1.9106307e+03 1.03e-06 3.23e+02  -3.8 5.45e-01    -  1.86e-01 9.18e-02f  1
#  322  1.8368008e+03 3.73e-06 9.96e+01  -3.8 1.17e+00    -  1.67e-01 2.71e-01f  1
#  323  1.8351017e+03 3.01e-06 3.08e+02  -3.8 8.83e-02    -  5.18e-01 3.36e-01f  1
#  324  1.8351017e+03 3.01e-06 2.29e+05  -3.8 2.91e-09  13.9 1.00e+00 1.00e+00h  1
#  325  1.8302591e+03 3.01e-06 1.76e+05  -3.8 5.13e+02    -  2.31e-01 2.32e-03f  1
#  326  1.8302591e+03 3.01e-06 5.18e+04  -3.8 1.97e-09  13.4 1.00e+00 1.00e+00h  1
#  327  1.8302591e+03 3.00e-06 7.75e+04  -3.8 8.87e-09  12.9 1.00e+00 1.00e+00h  1
#  328  1.8302591e+03 2.96e-06 1.03e+05  -3.8 3.53e-08  12.5 1.00e+00 1.00e+00h  1
#  329  1.8292078e+03 2.95e-06 1.02e+05  -3.8 4.02e+01    -  1.27e-02 9.61e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  1.8292078e+03 2.83e-06 1.25e+05  -3.8 1.28e-07  12.0 1.00e+00 1.00e+00h  1
#  331  1.8292078e+03 2.42e-06 1.41e+05  -3.8 4.37e-07  11.5 1.00e+00 1.00e+00h  1
#  332  1.8291080e+03 2.40e-06 1.40e+05  -3.8 4.98e+00    -  8.03e-03 9.78e-03f  1
#  333  1.8291080e+03 2.05e-06 1.39e+05  -3.8 1.28e-06  11.0 1.00e+00 2.96e-01f  2
#  334  1.8291080e+03 2.40e-06 1.15e+05  -3.8 2.99e-06  10.6 5.29e-01 5.58e-01H  1
#  335  1.8291080e+03 2.39e-06 2.76e+05  -3.8 1.14e-04  10.1 3.08e-02 2.36e-03f  3
#  336  1.8291080e+03 2.38e-06 7.60e+05  -3.8 1.14e-04   9.6 3.00e-03 7.62e-03h  1
#  337  1.8291081e+03 2.34e-06 9.07e+05  -3.8 1.13e-04   9.1 1.26e-01 1.57e-02f  2
#  338  1.8291082e+03 2.30e-06 8.24e+05  -3.8 1.23e-04   8.6 2.84e-02 1.80e-02h  1
#  339  1.8291089e+03 2.27e-06 1.15e+06  -3.8 2.16e-04   8.2 1.00e+00 1.38e-02h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340  1.8291089e+03 3.15e-06 8.08e+05  -3.8 2.85e-06  10.4 2.99e-01 2.99e-01s 22
#  341r 1.8291089e+03 3.15e-06 1.00e+03  -3.8 0.00e+00   9.9 0.00e+00 0.00e+00R  1
#  342r 1.8291297e+03 1.55e-06 9.56e+02  -3.8 9.12e-02    -  9.47e-02 5.19e-02f  1
#  343  1.8291267e+03 1.54e-06 1.23e+03  -3.8 5.21e-03    -  1.89e-01 2.85e-03f  1
#  344  1.8290517e+03 1.42e-06 1.10e+03  -3.8 7.00e-03    -  2.40e-01 7.79e-02f  1
#  345  1.8286484e+03 3.79e-06 4.86e+02  -3.8 1.32e-02    -  4.98e-01 5.82e-01f  1
#  346  1.8286340e+03 3.74e-06 6.08e+02  -3.8 3.00e-01    -  1.03e-01 1.29e-02f  1
#  347  1.8286340e+03 2.11e-06 5.76e+03  -3.8 1.82e-06   9.4 2.48e-01 1.00e+00h  1
#  348  1.8286340e+03 9.78e-07 2.72e+03  -3.8 2.61e-06   9.0 1.00e+00 6.32e-01h  1
#  349  1.8286340e+03 9.74e-07 2.46e+03  -3.8 3.04e-06   8.5 1.00e+00 1.13e-01f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350  1.8285454e+03 9.31e-07 2.37e+03  -3.8 8.24e-01    -  3.20e-01 4.38e-02f  1
#  351  1.8285456e+03 9.27e-07 8.26e+02  -3.8 3.14e-06   8.0 1.00e+00 7.54e-01h  1
#  352  1.8285456e+03 9.27e-07 3.58e+03  -3.8 1.30e-02   7.5 1.60e-04 9.33e-05h  1
#  353  1.8285456e+03 9.16e-07 6.68e+03  -5.7 1.42e-07  10.7 7.65e-01 1.00e+00h  1
#  354  1.8285456e+03 9.12e-07 2.37e+04  -5.7 3.52e-04  10.2 1.96e-03 4.13e-03h  1
#  355  1.8285456e+03 9.12e-07 3.29e+04  -5.7 1.65e-08  12.4 9.40e-01 5.00e-01f  2
#  356  1.8285456e+03 9.11e-07 2.30e+05  -5.7 3.24e-04  12.0 4.24e-03 6.77e-04h  1
#  357  1.8285456e+03 8.99e-07 1.52e+07  -5.7 3.34e-04  11.5 2.03e-02 1.37e-02h  1
#  358r 1.8285456e+03 8.99e-07 1.00e+03  -5.7 0.00e+00  11.0 0.00e+00 2.47e-08R  2
#  359r 1.8285459e+03 8.92e-07 9.98e+02  -5.7 1.96e+00    -  2.14e-02 7.45e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360r 1.8285553e+03 5.55e-07 9.82e+02  -5.7 6.84e-01    -  7.26e-02 1.47e-02f  1
#  361  1.8285398e+03 5.51e-07 9.80e+01  -5.7 4.76e-03    -  4.67e-02 1.03e-02f  1
#  362  1.8285297e+03 5.48e-07 9.74e+01  -5.7 4.52e-03    -  2.99e-02 6.80e-03f  1
#  363  1.8285185e+03 5.43e-07 1.89e+02  -5.7 1.06e-02    -  7.02e-02 1.24e-02f  1
#  364  1.8284982e+03 5.48e-07 2.85e+02  -5.7 1.39e-02    -  7.46e-02 2.53e-02f  1
#  365  1.8284465e+03 5.66e-07 4.65e+02  -5.7 1.77e-02    -  1.42e-01 5.90e-02f  1
#  366  1.8283723e+03 6.15e-07 6.63e+02  -5.7 3.00e-02    -  1.38e-01 5.64e-02f  1
#  367  1.8283705e+03 6.16e-07 7.88e+02  -5.7 1.14e+00    -  2.93e-02 5.83e-04f  1
#  368  1.8280193e+03 4.10e-06 2.91e+02  -5.7 6.83e-02    -  1.21e-02 1.08e-01f  1
#  369  1.8279398e+03 4.07e-06 5.91e+02  -5.7 3.11e-01    -  3.14e-02 5.17e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370  1.8276078e+03 4.47e-06 5.35e+02  -5.7 2.26e+00    -  1.54e-03 2.12e-03f  1
#  371  1.8276078e+03 4.47e-06 5.10e+03  -5.7 2.29e-05  10.5 6.09e-03 1.29e-04f  2
#  372  1.8276078e+03 4.20e-06 4.97e+03  -5.7 2.47e-06  10.0 3.36e-02 9.88e-02h  1
#  373  1.8276083e+03 4.20e-06 4.97e+03  -5.7 1.26e+01    -  3.59e-07 9.96e-06h  5
#  374  1.8276083e+03 4.11e-06 4.54e+03  -5.7 2.59e-06   9.6 8.78e-02 2.81e-02f  2
#  375  1.8276083e+03 3.87e-06 4.19e+03  -5.7 2.74e-06   9.1 7.70e-02 7.04e-02h  1
#  376  1.8276083e+03 3.82e-06 3.80e+03  -5.7 3.03e-06   8.6 9.49e-02 1.64e-02f  2
#  377  1.8276084e+03 3.57e-06 3.35e+03  -5.7 3.68e-06   8.1 1.21e-01 6.84e-02h  1
#  378  1.8276085e+03 3.46e-06 3.02e+03  -5.7 5.79e-06   7.7 9.99e-02 3.31e-02f  2
#  379  1.8276090e+03 3.12e-06 2.74e+03  -5.7 9.32e-06   7.2 9.28e-02 1.03e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380  1.8276047e+03 3.03e-06 5.36e+05  -5.7 8.13e-02    -  1.28e-05 2.89e-02f  1
#  381  1.8276048e+03 3.04e-06 5.35e+05  -5.7 1.61e-04   6.7 4.80e-03 1.72e-03f  2
#  382  1.8276032e+03 3.02e-06 5.31e+05  -5.7 5.42e-02    -  1.10e-02 7.51e-03h  1
#  383  1.8276032e+03 3.02e-06 5.31e+05  -5.7 1.86e-04   6.2 1.80e-03 6.91e-04f  2
#  384  1.8276020e+03 3.01e-06 5.30e+05  -5.7 2.38e+00    -  4.02e-04 6.86e-04h  1
#  385  1.8276020e+03 3.02e-06 5.30e+05  -5.7 4.63e-04   5.8 8.46e-03 1.23e-03f  2
#  386  1.8276018e+03 3.03e-06 5.26e+05  -5.7 7.21e-04   5.3 5.31e-03 6.18e-03h  1
#  387  1.8275982e+03 3.01e-06 5.26e+05  -5.7 1.08e+00    -  3.01e-03 1.65e-03f  1
#  388  1.8275983e+03 3.01e-06 5.24e+05  -5.7 1.28e-01    -  7.37e-02 2.55e-03f  4
#  389r 1.8275983e+03 3.01e-06 1.00e+03  -5.5 0.00e+00   4.8 0.00e+00 3.85e-07R  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390r 1.8276536e+03 1.45e-06 1.00e+03  -5.5 2.21e-01    -  4.42e-04 1.02e-03f  1
#  391  1.8276422e+03 1.45e-06 1.64e+02  -5.7 1.58e-02    -  6.41e-02 3.34e-03f  1
#  392  1.8275028e+03 1.39e-06 5.83e+02  -5.7 2.06e-02    -  1.45e-01 3.34e-02f  1
#  393  1.8264844e+03 1.92e-05 1.27e+02  -5.7 5.40e-02    -  1.34e-02 7.85e-02f  1
#  394  1.8257100e+03 1.73e-05 1.44e+02  -5.7 1.39e-01    -  2.23e-02 1.98e-02f  1
#  395  1.8250520e+03 1.71e-05 2.11e+02  -5.7 6.43e-01    -  5.91e-03 2.86e-03f  1
#  396  1.8250509e+03 1.69e-05 5.86e+02  -5.7 7.34e-04   4.3 2.06e-01 1.04e-02f  1
#  397  1.8250241e+03 1.56e-05 5.43e+02  -5.7 8.29e-04   3.8 8.13e-02 7.84e-02f  1
#  398  1.8247666e+03 1.17e-05 2.61e+02  -5.7 1.83e-03   3.4 9.77e-02 2.47e-01f  1
#  399  1.8239795e+03 8.48e-06 2.29e+02  -5.7 6.32e-03   2.9 1.43e-01 2.59e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400  1.8225503e+03 7.76e-06 2.63e+02  -5.7 2.59e-02   2.4 2.95e-02 1.18e-01f  1
#  401  1.8222966e+03 7.27e-06 1.33e+02  -5.7 8.32e-03   2.8 3.35e-01 6.39e-02f  1
#  402  1.8205234e+03 7.32e-06 1.14e+02  -5.7 3.25e-02   2.4 1.08e-01 1.11e-01f  1
#  403  1.8171646e+03 2.23e-05 9.07e+02  -5.7 1.89e-01   1.9 1.82e-03 3.78e-02f  1
#  404  1.8171511e+03 2.23e-05 4.98e+02  -5.7 3.00e-02   2.3 1.88e-01 8.28e-04f  1
#  405  1.8167339e+03 2.23e-05 4.17e+02  -5.7 2.70e-01   1.8 7.43e-03 3.79e-03f  1
#  406  1.8165442e+03 2.21e-05 3.81e+02  -5.7 3.65e-02   2.3 1.72e-02 7.84e-03f  1
#  407  1.8164628e+03 2.21e-05 6.94e+02  -5.7 2.68e-01   1.8 2.39e-02 6.85e-04f  1
#  408  1.8116588e+03 3.45e-05 3.56e+02  -5.7 3.76e-02   2.2 1.54e-01 2.11e-01f  1
#  409  1.8080220e+03 2.83e-05 2.05e+02  -5.7 1.31e-02   2.6 4.41e-01 3.78e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410  1.8054865e+03 1.36e-05 2.07e+02  -5.7 4.73e-03   3.1 8.26e-02 6.12e-01f  1
#  411  1.8054912e+03 1.36e-05 1.94e+02  -5.7 5.49e+00    -  1.86e-03 5.40e-05h  6
#  412  1.8003179e+03 3.10e-05 1.62e+02  -5.7 2.75e-02   2.6 2.02e-01 3.02e-01f  1
#  413  1.7992038e+03 2.79e-05 1.33e+02  -5.7 6.77e-03   3.0 1.90e-01 1.41e-01f  1
#  414  1.7971339e+03 3.34e-05 1.26e+02  -5.7 4.83e-02   2.5 4.53e-02 6.02e-02f  1
#  415  1.7960654e+03 3.00e-05 1.03e+02  -5.7 7.77e-03   3.0 2.19e-01 1.22e-01f  1
#  416  1.7887003e+03 1.02e-04 8.88e+01  -5.7 4.55e-02   2.5 4.24e-02 1.79e-01f  1
#  417  1.7867106e+03 8.56e-05 1.16e+02  -5.7 9.20e-03   2.9 5.37e-02 1.67e-01f  1
#  418  1.7867445e+03 8.56e-05 1.15e+02  -5.7 4.72e+00    -  3.10e-03 5.02e-04h  1
#  419  1.7805709e+03 9.80e-05 1.84e+02  -5.7 3.69e-02   2.4 7.03e-04 1.19e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420  1.7801586e+03 9.54e-05 1.69e+02  -5.7 1.02e-02   2.9 5.89e-02 2.71e-02f  1
#  421  1.7767235e+03 9.47e-05 1.72e+02  -5.7 3.97e-02   2.4 3.04e-02 5.86e-02f  1
#  422  1.7660796e+03 6.10e-05 2.31e+02  -5.7 1.15e-02   2.8 5.72e-02 5.95e-01f  1
#  423  1.7608000e+03 6.49e-05 2.23e+02  -5.7 4.00e-02   2.3 4.18e-02 8.19e-02f  1
#  424  1.7551416e+03 8.29e-05 2.26e+02  -5.7 3.02e-01   1.8 3.47e-03 1.21e-02f  1
#  425  1.7171458e+03 4.43e-04 2.13e+02  -5.7 4.45e-02   2.3 1.18e-01 4.90e-01f  1
#  426  1.6691585e+03 9.14e-04 2.14e+02  -5.7 1.71e-01   1.8 1.71e-02 1.47e-01f  1
#  427  1.6587396e+03 8.24e-04 1.34e+02  -5.7 8.41e-02   2.2 3.45e-01 1.04e-01f  1
#  428  1.6497278e+03 8.16e-04 1.33e+02  -5.7 1.68e-01   1.7 9.97e-03 2.44e-02f  1
#  429  1.6444966e+03 7.82e-04 1.34e+02  -5.7 4.83e-02   2.2 2.45e-03 4.49e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430  1.6402093e+03 7.77e-04 1.29e+02  -5.7 2.00e-01   1.7 2.89e-02 9.81e-03f  1
#  431  1.5621816e+03 1.04e-03 1.04e+02  -5.7 5.52e-02   2.1 2.33e-01 5.84e-01f  1
#  432  1.5569010e+03 1.03e-03 8.77e+01  -5.7 1.95e-01   1.6 1.23e-01 1.07e-02f  1
#  433  1.5497102e+03 9.93e-04 2.49e+01  -5.7 6.43e-02   2.1 6.66e-01 4.50e-02f  1
#  434  1.5005748e+03 1.20e-03 1.97e+01  -5.7 2.29e-01   1.6 1.34e-01 8.60e-02f  1
#  435  1.4894806e+03 1.23e-03 2.62e+01  -5.7 3.71e+00   1.1 1.81e-02 2.16e-03f  1
#  436  1.4915826e+03 1.23e-03 2.07e+03  -5.7 2.92e+00   0.6 2.27e-02 2.43e-03h  1
#  437  1.4892233e+03 1.13e-03 1.90e+03  -5.7 1.12e-02   2.9 6.50e-01 8.28e-02f  1
#  438  1.4816859e+03 3.83e-04 6.46e+02  -5.7 4.53e-03   3.3 4.62e-01 6.60e-01f  1
#  439  1.4803771e+03 3.67e-04 6.19e+02  -5.7 1.25e-02   2.8 4.24e-01 4.22e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440  1.4790602e+03 3.44e-04 2.32e+03  -5.7 2.87e-02   2.3 6.00e-02 6.09e-02f  1
#  441  1.4789774e+03 3.39e-04 2.28e+03  -5.7 1.92e-03   3.7 2.21e-01 1.70e-02f  1
#  442  1.4781046e+03 3.20e-04 2.15e+03  -5.7 7.15e-03   3.2 1.43e-01 5.46e-02f  1
#  443  1.4752878e+03 1.53e-04 1.03e+03  -5.7 2.15e-03   3.6 1.00e+00 5.23e-01f  1
#  444  1.4738270e+03 1.41e-04 9.45e+02  -5.7 8.44e-03   3.1 5.60e-02 7.96e-02f  1
#  445  1.4732686e+03 1.27e-04 8.53e+02  -5.7 2.31e-03   3.6 6.80e-01 9.82e-02f  1
#  446  1.4700110e+03 1.09e-04 7.29e+02  -5.7 1.09e-02   3.1 2.80e-02 1.46e-01f  1
#  447  1.4700083e+03 1.09e-04 7.28e+02  -5.7 1.92e-02   2.6 7.89e-02 2.41e-04f  1
#  448  1.4690976e+03 1.04e-04 1.59e+03  -5.7 7.90e-02   2.1 6.81e-03 3.01e-02f  1
#  449  1.4686595e+03 1.03e-04 1.61e+03  -5.7 8.75e-02   1.7 3.19e-02 8.13e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450  1.4673207e+03 5.03e-05 7.84e+02  -5.7 1.04e-03   3.9 8.09e-01 5.13e-01f  1
#  451  1.4671998e+03 4.62e-05 8.59e+04  -5.7 1.87e-03   3.4 3.40e-02 8.12e-02f  1
#  452  1.4666791e+03 3.76e-05 5.86e+04  -5.7 1.07e-03   3.8 3.18e-01 1.86e-01f  1
#  453  1.4666661e+03 3.74e-05 5.04e+04  -5.7 3.32e-03   3.4 2.54e-03 6.54e-03f  1
#  454  1.4660253e+03 2.98e-05 2.30e+04  -5.7 1.23e-03   3.8 5.42e-01 2.04e-01f  1
#  455  1.4658965e+03 2.79e-05 6.47e+04  -5.7 2.86e-03   3.3 3.55e-02 6.29e-02f  1
#  456  1.4654429e+03 2.14e-05 6.69e+03  -5.7 1.88e-04   4.6 6.96e-05 9.40e-01f  1
#  457  1.4653520e+03 2.02e-05 6.27e+03  -5.7 6.11e-04   4.2 3.47e-01 6.25e-02f  1
#  458  1.4648564e+03 2.31e-06 8.00e+00  -5.7 2.05e-04   4.6 8.10e-01 1.00e+00f  1
#  459  1.4642455e+03 1.45e-06 4.46e+01  -5.7 7.55e-04   4.1 1.55e-01 3.68e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460  1.4642030e+03 1.41e-06 4.17e+01  -5.7 1.30e-03   3.6 4.74e-02 3.09e-02f  1
#  461  1.4624219e+03 2.62e-06 2.15e+02  -5.7 8.61e-04   4.1 1.09e-02 9.94e-01f  1
#  462  1.4622836e+03 2.45e-06 2.98e+04  -5.7 1.79e-03   3.6 2.09e-02 6.32e-02f  1
#  463  1.4620899e+03 2.39e-06 2.56e+04  -5.7 5.95e-03   3.1 1.30e-02 2.75e-02f  1
#  464  1.4620198e+03 2.38e-06 2.75e+04  -5.7 1.87e-02   2.6 1.86e-02 3.24e-03f  1
#  465  1.4596835e+03 2.27e-06 2.23e+04  -5.7 3.86e-02   2.2 4.02e-03 4.43e-02f  1
#  466  1.4584137e+03 2.26e-06 2.21e+04  -5.7 1.50e-01   1.7 5.84e-03 6.83e-03f  1
#  467  1.4529394e+03 1.97e-05 2.16e+04  -5.7 4.57e-01   1.2 6.26e-03 1.09e-02f  1
#  468  1.4529118e+03 1.91e-05 1.41e+04  -5.7 3.43e-04   4.3 3.51e-01 3.09e-02f  1
#  469  1.4528854e+03 1.87e-05 1.31e+04  -5.7 1.04e-03   3.9 1.50e-02 2.09e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470  1.4528826e+03 1.87e-05 1.41e+04  -5.7 2.64e-03   3.4 1.15e-02 7.99e-04f  1
#  471  1.4527265e+03 1.86e-05 1.37e+04  -5.7 1.07e-01   2.9 6.16e-05 4.05e-03f  1
#  472  1.4527255e+03 1.86e-05 1.48e+04  -5.7 2.50e-02   2.4 1.31e-02 3.03e-05f  1
#  473  1.4522259e+03 1.86e-05 1.55e+04  -5.7 7.10e-02   1.9 1.62e-02 5.60e-03f  1
#  474  1.4509003e+03 1.90e-05 1.54e+04  -5.7 2.30e-01   1.5 4.35e-03 4.69e-03f  1
#  475  1.4507944e+03 1.48e-05 1.36e+03  -5.7 4.24e-04   4.6 9.21e-01 2.19e-01f  1
#  476  1.4507738e+03 1.44e-05 7.69e+03  -5.7 5.40e-04   4.1 4.95e-02 2.86e-02f  1
#  477  1.4507688e+03 1.44e-05 1.45e+04  -5.7 1.37e-03   3.7 8.30e-02 2.45e-03f  1
#  478  1.4506190e+03 1.40e-05 1.45e+04  -5.7 4.58e-03   3.2 4.44e-02 2.33e-02f  1
#  479  1.4505678e+03 1.29e-05 1.23e+03  -5.7 2.49e-04   4.5 1.00e+00 8.36e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480  1.4505051e+03 9.34e-06 8.90e+02  -5.7 8.93e-05   4.9 5.88e-01 2.74e-01f  1
#  481  1.4502796e+03 6.24e-06 5.95e+02  -5.7 2.77e-04   4.5 1.00e+00 3.32e-01f  1
#  482  1.4502130e+03 6.10e-06 5.82e+02  -5.7 3.08e-03   4.0 6.91e-02 2.26e-02f  1
#  483  1.4494505e+03 7.05e-07 7.77e+00  -5.7 3.07e-04   4.4 1.00e+00 1.00e+00f  1
#  484  1.4491728e+03 1.68e-07 7.44e+00  -5.7 1.10e-04   4.8 9.42e-01 1.00e+00f  1
#  485  1.4491680e+03 1.74e-07 8.48e+01  -5.7 3.60e-04   4.4 1.00e+00 5.55e-03f  1
#  486  1.4488553e+03 2.04e-07 7.44e+00  -5.7 1.24e-04   4.8 1.00e+00 1.00e+00f  1
#  487  1.4488216e+03 2.31e-07 6.50e+01  -5.7 3.97e-04   4.3 1.00e+00 3.48e-02f  1
#  488  1.4484693e+03 2.28e-07 7.45e+00  -5.7 1.40e-04   4.7 1.00e+00 1.00e+00f  1
#  489  1.4483328e+03 3.40e-07 8.66e+01  -5.7 4.51e-04   4.2 1.00e+00 1.24e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490  1.4479357e+03 2.63e-07 7.47e+00  -5.7 1.58e-04   4.7 1.00e+00 1.00e+00f  1
#  491  1.4476834e+03 4.97e-07 9.10e+01  -5.7 5.18e-04   4.2 1.00e+00 2.02e-01f  1
#  492  1.4472440e+03 3.03e-07 7.49e+00  -5.7 1.78e-04   4.6 1.00e+00 9.82e-01f  1
#  493  1.4469273e+03 6.48e-07 8.10e+01  -5.7 6.00e-04   4.1 6.03e-01 2.22e-01f  1
#  494  1.4464224e+03 3.55e-07 7.52e+00  -5.7 2.01e-04   4.6 1.00e+00 1.00e+00f  1
#  495  1.4462452e+03 5.95e-07 1.48e+02  -5.7 7.07e-04   4.1 8.08e-01 1.08e-01f  1
#  496  1.4458398e+03 4.57e-07 2.06e+01  -5.7 2.27e-04   4.5 1.00e+00 7.12e-01f  1
#  497  1.4455884e+03 9.18e-07 1.19e+02  -5.7 9.33e-04   4.0 3.36e-01 1.30e-01f  1
#  498  1.4451234e+03 6.05e-07 3.18e+02  -5.7 2.57e-04   4.5 1.00e+00 7.23e-01f  1
#  499  1.4450195e+03 9.21e-07 1.87e+02  -5.7 1.81e-03   4.0 2.30e-01 4.25e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500  1.4442931e+03 5.55e-07 7.66e+00  -5.7 2.92e-04   4.4 1.00e+00 1.00e+00f  1
#  501  1.4442619e+03 8.84e-07 1.08e+02  -5.7 2.42e-02   3.9 1.09e-02 3.33e-03f  1
#  502  1.4434400e+03 6.86e-07 7.74e+00  -5.7 3.31e-04   4.4 1.00e+00 1.00e+00f  1
#  503  1.4431397e+03 1.82e-07 7.44e+00  -5.7 1.19e-04   4.8 9.86e-01 9.96e-01f  1
#  504  1.4431370e+03 1.85e-07 1.92e+02  -5.7 4.00e-04   4.3 1.00e+00 2.90e-03f  1
#  505  1.4427971e+03 2.22e-07 7.45e+00  -5.7 1.34e-04   4.7 1.00e+00 1.00e+00f  1
#  506  1.4427315e+03 2.75e-07 1.33e+02  -5.7 4.32e-04   4.3 1.00e+00 6.21e-02f  1
#  507  1.4423486e+03 2.51e-07 7.46e+00  -5.7 1.52e-04   4.7 1.00e+00 1.00e+00f  1
#  508  1.4421391e+03 4.35e-07 1.42e+02  -5.7 4.95e-04   4.2 1.00e+00 1.75e-01f  1
#  509  1.4417073e+03 2.87e-07 7.48e+00  -5.7 1.71e-04   4.6 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510  1.4414228e+03 5.78e-07 1.75e+02  -5.7 5.71e-04   4.2 1.00e+00 2.08e-01f  1
#  511  1.4409360e+03 3.32e-07 7.52e+00  -5.7 1.93e-04   4.6 1.00e+00 1.00e+00f  1
#  512  1.4406296e+03 7.15e-07 2.43e+02  -5.7 6.69e-04   4.1 1.00e+00 1.95e-01f  1
#  513  1.4400802e+03 3.86e-07 7.55e+00  -5.7 2.19e-04   4.5 1.00e+00 1.00e+00f  1
#  514  1.4398079e+03 8.37e-07 2.51e+02  -5.7 8.06e-04   4.1 6.96e-01 1.48e-01f  1
#  515  1.4392495e+03 4.89e-07 7.62e+00  -5.7 2.47e-04   4.5 1.00e+00 9.00e-01f  1
#  516  1.4391004e+03 8.67e-07 1.58e+02  -5.7 1.40e-03   4.0 2.57e-01 6.65e-02f  1
#  517  1.4390582e+03 8.37e-07 2.86e+04  -5.7 1.54e-03   3.5 1.22e-02 3.49e-02f  1
#  518  1.4388568e+03 9.06e-06 7.14e+03  -5.7 1.02e-04   4.9 9.27e-01 7.69e-01f  1
#  519  1.4380799e+03 2.46e-06 7.47e+02  -5.7 3.91e-04   4.4 1.40e-01 9.90e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520  1.4378727e+03 8.25e-07 1.62e+02  -5.7 1.17e-04   4.8 1.00e+00 7.08e-01f  1
#  521  1.4378157e+03 7.76e-07 1.41e+02  -5.7 3.87e-04   4.3 3.04e-01 6.04e-02f  1
# ...
# 1652r 1.0859888e+03 2.15e-04 3.85e-01  -4.5 7.22e-02    -  1.00e+00 1.00e+00h  1
# 1653r 9.3854759e+02 3.98e-04 7.07e-02  -4.5 1.48e-01    -  1.00e+00 1.00e+00h  1
# 1654r 9.2680897e+02 9.90e-07 6.91e-04  -4.5 1.60e-02    -  1.00e+00 1.00e+00h  1
# 1655r 5.3408517e+02 1.95e-03 2.27e+00  -6.8 3.34e-01    -  8.27e-01 8.46e-01f  1
# 1656r 5.1589341e+02 7.18e-04 3.48e+02  -6.8 2.68e-02    -  1.00e+00 6.39e-01h  1
# 1657r 5.1543387e+02 7.56e-08 1.71e+01  -6.8 2.94e-04  -1.0 9.39e-01 1.00e+00h  1
# 1658r 2.1527637e+02 6.58e-04 3.26e-01  -6.8 2.71e-01    -  1.00e+00 1.00e+00h  1
# 1659r 2.5897154e+02 4.21e-06 1.20e-02  -6.8 3.85e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1660r 2.5510343e+02 3.55e-08 4.05e-04  -6.8 2.53e-03    -  1.00e+00 1.00e+00h  1
# 1661r 2.5507193e+02 4.18e-10 5.19e-03  -6.8 1.94e-05    -  1.00e+00 1.00e+00h  1
# 1662  2.5507083e+02 6.48e-09 1.83e+02  -5.7 6.56e+03    -  1.59e-02 1.50e-06f 12
# 1663  2.5507018e+02 9.45e-09 1.80e+02  -5.7 6.67e+03    -  2.10e-02 9.37e-07f 14
# 1664  2.5506850e+02 1.28e-08 1.72e+02  -5.7 2.75e+03    -  5.35e-02 2.60e-06f 14
# 1665  2.5506738e+02 1.31e-08 1.36e+02  -5.7 1.14e+03    -  2.75e-01 1.97e-06f 16
# 1666  2.5506689e+02 1.31e-08 1.08e+02  -5.7 3.47e+02    -  3.22e-01 1.25e-06f 17
# 1667  1.9520789e+02 7.06e-02 5.94e+01  -5.7 2.28e+02    -  7.11e-01 1.89e-01f  1
# 1668  8.6807745e+01 4.21e-02 2.60e+01  -5.7 1.01e+00  -4.9 5.39e-01 5.60e-01f  1
# 1669  7.6899485e+01 4.95e-02 2.54e+01  -5.7 5.56e+00  -5.4 2.89e-01 1.30e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1670  5.2140030e+01 5.51e-02 1.71e+01  -5.7 8.51e+01    -  4.64e-01 3.77e-01f  1
# 1671  4.8126658e+01 1.67e-01 1.51e+01  -5.7 7.19e+00  -5.9 8.44e-02 9.98e-02f  1
# 1672  2.7781038e+01 6.79e-01 6.84e+00  -5.7 1.03e+02    -  4.29e-01 5.63e-01f  1
# 1673  2.7246983e+01 6.58e-01 6.58e+00  -5.7 3.86e+00  -5.4 6.14e-02 3.43e-02h  1
# 1674  2.3669262e+01 5.06e-01 5.43e+00  -5.7 1.41e+00  -4.1 3.32e-01 2.38e-01f  1
# 1675  1.6331618e+01 2.76e-01 1.01e+01  -5.7 1.09e+02    -  9.43e-01 6.42e-01f  1
# 1676  1.2372649e+01 4.24e-01 1.92e+01  -5.7 1.92e+02    -  1.00e+00 9.74e-01h  1
# 1677  1.2280832e+01 7.75e-01 2.66e+01  -5.7 4.26e+02    -  1.00e+00 8.72e-01h  1
# 1678  1.2268510e+01 5.04e-04 8.55e-01  -5.7 2.75e-01  -4.6 1.00e+00 1.00e+00h  1
# 1679  1.2268518e+01 3.84e-04 1.53e+01  -5.7 7.68e-02  -5.1 1.00e+00 4.77e-01H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1680  1.2268523e+01 1.14e-05 1.16e-01  -5.7 3.50e-02  -4.6 1.00e+00 1.00e+00F  1
# 1681  1.2268521e+01 1.12e-05 4.69e-01  -5.7 1.09e-01  -5.1 1.00e+00 1.00e+00H  1
# 1682  1.2268521e+01 4.21e-06 8.76e-01  -5.7 2.65e+01  -5.6 1.77e-02 1.43e-04h  8
# 1683  1.2268521e+01 7.40e-06 2.64e+00  -5.7 3.01e-01  -5.2 1.00e+00 7.81e-03h  8
# 1684  1.2266743e+01 3.20e-01 3.58e+01  -5.7 4.29e+02    -  1.00e+00 1.00e+00h  1
# 1685  1.2267349e+01 1.08e-01 3.02e+00  -5.7 7.28e-01  -5.7 1.00e+00 1.00e+00h  1
# 1686  1.2267323e+01 5.34e-03 1.35e+00  -5.7 1.37e-01  -5.2 1.00e+00 1.00e+00h  1
# 1687  1.2267322e+01 7.22e-03 7.24e-02  -5.7 3.90e-01  -5.7 1.00e+00 1.00e+00H  1
# 1688  1.2267322e+01 4.38e-03 7.86e+00  -5.7 1.69e+00  -6.2 5.24e-01 7.76e-02h  4
# 1689  1.2267327e+01 1.57e-04 6.88e-03  -5.7 5.30e-02  -4.8 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1690  1.2267327e+01 7.65e-05 4.20e-02  -5.7 1.44e-01  -5.3 1.00e+00 1.00e+00H  1
# 1691  1.2267327e+01 8.35e-05 2.47e+00  -5.7 3.77e-01  -5.8 1.00e+00 3.12e-02h  6
# 1692  1.2267327e+01 8.86e-05 5.70e-01  -5.7 1.48e-01  -5.4 1.00e+00 1.25e-01h  4
# 1693  1.2267327e+01 8.87e-05 3.12e+00  -5.7 4.21e-01  -5.9 1.00e+00 7.81e-03h  8
# 1694  1.2267327e+01 8.81e-05 6.03e-01  -5.7 1.64e-01  -5.4 1.00e+00 6.25e-02h  5
# 1695  1.2267327e+01 8.84e-05 3.93e+00  -5.7 4.77e-01  -5.9 1.00e+00 7.81e-03h  8
# 1696  1.2267327e+01 1.67e-03 2.22e-01  -5.7 1.83e-01  -5.5 1.00e+00 1.00e+00h  1
# 1697  1.2267326e+01 1.58e-02 6.08e+00  -5.7 5.04e-01  -6.0 1.00e+00 1.00e+00h  1
# 1698  1.2267326e+01 1.94e-02 1.63e+01  -5.7 2.58e+00  -6.4 4.13e-01 1.25e-01h  3
# 1699  1.2267327e+01 7.54e-03 3.71e+00  -5.7 5.64e-01  -6.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1700  1.2267327e+01 4.17e-04 1.31e-01  -5.7 1.92e-01  -5.6 1.00e+00 1.00e+00h  1
# 1701  1.2267327e+01 4.88e-03 3.29e+00  -5.7 4.18e-01  -6.1 1.00e+00 1.00e+00h  1
# 1702  1.2267326e+01 1.10e-02 1.30e+01  -5.7 1.11e+00  -6.5 1.00e+00 5.00e-01h  2
# 1703  1.2267327e+01 2.60e-03 1.37e+00  -5.7 4.93e-01  -6.1 1.00e+00 1.00e+00h  1
# 1704  1.2267327e+01 1.44e-04 7.25e-02  -5.7 1.55e-01  -5.7 1.00e+00 1.00e+00h  1
# 1705  1.2267327e+01 1.19e-03 3.91e-01  -5.7 3.75e-01  -6.2 1.00e+00 1.00e+00h  1
# 1706  1.2267326e+01 8.71e-03 2.14e+01  -5.7 1.12e+00  -6.6 1.00e+00 5.00e-01h  2
# 1707  1.2267327e+01 1.29e-02 7.63e-01  -5.7 1.85e+00  -7.1 1.00e+00 1.00e+00h  1
# 1708  1.2267327e+01 5.29e-04 8.40e-01  -5.7 5.73e-01  -6.7 1.00e+00 1.00e+00h  1
# 1709  1.2267327e+01 2.05e-03 7.81e+00  -5.7 1.59e+00  -7.2 1.00e+00 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1710  1.2267328e+01 3.59e-04 1.34e+00  -5.7 4.91e-01  -6.7 1.00e+00 1.00e+00h  1
# 1711  1.2267326e+01 5.50e-03 1.68e+01  -5.7 1.35e+00  -7.2 1.00e+00 1.00e+00h  1
# 1712  1.2266120e+01 2.39e-01 3.89e+02  -5.7 6.49e+02    -  1.00e+00 1.00e+00h  1
# 1713  1.2266522e+01 3.38e-04 1.32e+00  -5.7 2.23e-01  -6.8 1.00e+00 1.00e+00h  1
# 1714  1.2266522e+01 6.16e-04 2.30e+00  -5.7 7.32e-01  -7.3 1.00e+00 1.00e+00h  1
# 1715  1.2266522e+01 2.66e-05 2.33e+00  -5.7 1.98e+00  -7.7 1.00e+00 1.00e+00h  1
# 1716  1.2266522e+01 8.36e-05 5.20e-01  -5.7 7.26e-01  -7.3 1.00e+00 1.00e+00h  1
# 1717  1.2266521e+01 2.87e-06 1.39e+00  -5.7 2.00e+00  -7.8 1.00e+00 1.00e+00h  1
# 1718  1.2266521e+01 1.93e-05 1.61e-01  -5.7 7.34e-01  -7.4 1.00e+00 1.00e+00h  1
# 1719  1.2266521e+01 1.29e-05 3.00e-02  -5.7 2.04e+00  -7.8 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1720  1.2266520e+01 5.17e-03 2.23e+01  -5.7 5.93e+00  -8.3 1.00e+00 5.00e-01h  2
# 1721  1.2266278e+01 3.30e-02 1.22e+02  -5.7 1.00e+03    -  5.39e-01 2.92e-01h  2
# 1722  1.2266311e+01 1.22e-03 5.22e+00  -5.7 1.77e-01  -6.1 1.00e+00 1.00e+00h  1
# 1723  1.2266309e+01 1.32e-02 5.80e+01  -5.7 2.49e+00  -6.6 8.93e-01 4.20e-01h  2
# 1724  1.2266310e+01 4.46e-04 1.76e+00  -5.7 3.70e-01  -7.0 1.00e+00 1.00e+00h  1
# 1725  1.2266309e+01 2.12e-03 8.08e+00  -5.7 1.05e+00  -7.5 1.00e+00 5.00e-01h  2
# 1726  1.2266309e+01 2.10e-03 1.10e+01  -5.7 2.50e+00  -8.0 1.00e+00 3.12e-02h  6
# 1727  1.2266308e+01 4.53e-02 4.57e+00  -5.7 2.72e+00  -7.6 1.00e+00 1.00e+00H  1
# 1728  1.2266120e+01 2.93e-02 9.81e+01  -5.7 1.12e+03    -  9.29e-01 2.76e-01h  2
# 1729  1.2266138e+01 1.74e-03 1.81e+01  -5.7 8.18e-01  -7.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1730  1.2266138e+01 1.71e-03 1.76e+01  -5.7 1.80e+00  -7.6 1.00e+00 3.12e-02h  6
# 1731  1.2266138e+01 1.06e-01 3.58e+01  -5.7 4.68e+00  -8.1 1.00e+00 1.00e+00H  1
# 1732  1.2265895e+01 7.67e-02 1.19e+03  -5.7 1.31e+03    -  1.00e+00 4.24e-01h  2
# 1733  1.2265917e+01 3.19e-03 1.34e+01  -5.7 2.28e+00  -8.6 1.00e+00 1.00e+00h  1
# 1734  1.2265913e+01 2.36e-03 1.03e+02  -5.7 1.70e+03    -  5.66e-02 1.20e-02h  3
# 1735  1.2265914e+01 1.11e-03 5.71e+00  -5.7 4.64e-01  -7.3 1.00e+00 1.00e+00h  1
# 1736  1.2265917e+01 2.79e-04 1.03e+00  -5.7 4.07e-01  -7.7 1.00e+00 1.00e+00h  1
# 1737  1.2265862e+01 1.55e-02 1.63e+02  -5.7 1.40e+03    -  3.21e-01 1.18e-01h  2
# 1738  1.2265860e+01 9.69e-02 3.32e+01  -5.7 4.98e+00  -8.2 1.00e+00 1.00e+00H  1
# 1739  1.2265433e+01 2.47e-01 1.55e+04  -5.7 1.60e+03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1740  1.2265424e+01 2.33e-01 1.54e+04  -5.7 4.87e+03    -  2.01e-01 6.08e-02h  2
# 1741  1.2265511e+01 3.79e-03 1.39e+01  -5.7 1.25e+00  -8.7 1.00e+00 1.00e+00h  1
# 1742  1.2265229e+01 1.95e-01 2.32e+04  -5.7 2.37e+03    -  1.00e+00 1.00e+00h  1
# 1743  1.2265193e+01 1.50e-01 4.42e+04  -5.7 5.09e+03    -  6.36e-01 2.90e-01h  2
# 1744  1.2265255e+01 1.32e-02 3.80e+03  -5.7 2.77e+00  -9.2 1.00e+00 9.14e-01h  1
# 1745  1.2265094e+01 1.63e-01 5.30e+04  -5.7 3.95e+03    -  1.00e+00 1.00e+00f  1
# 1746  1.2264983e+01 2.45e-01 2.02e+04  -5.7 9.84e+03    -  1.00e+00 1.00e+00h  1
# 1747  1.2264979e+01 1.91e-01 9.77e+04  -5.7 2.93e+04    -  3.79e-01 2.24e-01h  2
# 1748  1.2264979e+01 1.91e-01 1.04e+05  -5.7 2.05e+06    -  9.78e-03 7.63e-04h  4
# 1749  1.2265000e+01 7.62e-02 1.35e+06  -5.7 2.30e+04    -  6.68e-01 4.68e-01H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1750  1.2264974e+01 1.65e-03 7.73e+00  -5.7 9.22e-02  -3.3 6.56e-01 1.00e+00h  1
# 1751  1.2264974e+01 1.53e-03 3.28e+00  -5.7 8.68e-02  -3.8 1.00e+00 7.09e-02h  1
# 1752  1.2264968e+01 3.19e-05 1.06e-02  -5.7 1.81e-02  -3.4 1.00e+00 1.00e+00f  1
# 1753  1.2264965e+01 2.18e-05 3.59e-03  -5.7 1.59e-02  -3.8 1.00e+00 1.00e+00h  1
# 1754  1.2264964e+01 1.55e-06 4.67e-04  -5.7 4.62e-03  -3.4 1.00e+00 1.00e+00h  1
# 1755  1.2264963e+01 1.80e-08 1.03e-03  -5.7 5.29e-03  -3.9 1.00e+00 1.00e+00H  1
# 1756  1.2264963e+01 3.13e-10 1.55e-04  -5.7 1.57e-03  -3.5 1.00e+00 1.00e+00H  1
# 1757  1.2264961e+01 1.90e-10 3.44e-04  -5.7 4.39e-03  -3.9 1.00e+00 1.00e+00H  1
# 1758  1.2264961e+01 1.44e-10 4.96e-05  -5.7 1.60e-03  -3.5 1.00e+00 1.00e+00H  1
# 1759  1.2264960e+01 1.09e-10 1.55e-04  -5.7 4.32e-03  -4.0 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1760  1.2264958e+01 7.19e-11 5.18e-04  -5.7 9.68e-03  -4.5 1.00e+00 1.00e+00H  1
# 1761  1.2264958e+01 5.46e-11 6.05e-05  -5.7 3.21e-03  -4.0 1.00e+00 1.00e+00H  1
# 1762  1.2264957e+01 4.13e-11 6.78e-06  -5.7 1.15e-03  -3.6 1.00e+00 1.00e+00H  1
# 1763  1.2263469e+01 5.87e-08 3.65e+00  -7.0 6.21e-02  -4.1 1.00e+00 9.25e-01f  1
# 1764  1.2263274e+01 6.93e-03 5.37e+03  -7.0 3.98e+04    -  2.67e-02 2.68e-02f  1
# 1765  1.2263192e+01 2.62e-03 2.03e+03  -7.0 3.44e-02  -3.7 1.00e+00 6.21e-01h  1
# 1766  1.2263123e+01 1.37e-05 2.18e-01  -7.0 8.21e-02  -4.2 1.00e+00 1.00e+00f  1
# 1767  1.2263100e+01 1.15e-05 8.99e+00  -7.0 1.40e-01  -4.6 6.32e-01 5.52e-01h  1
# 1768  1.2263088e+01 2.42e-04 6.26e+00  -7.0 1.80e-01  -5.1 8.98e-01 1.00e+00f  1
# 1769  1.2263070e+01 7.07e-02 1.41e+05  -7.0 1.81e+05    -  2.43e-01 4.74e-01H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1770  1.2263069e+01 6.38e-02 1.21e+05  -7.0 5.98e+00  -5.6 1.23e-01 1.40e-01h  1
# 1771  1.2263067e+01 4.71e-02 8.95e+04  -7.0 1.21e-01  -2.4 4.13e-01 2.61e-01h  1
# 1772  1.2263065e+01 2.22e-02 4.23e+04  -7.0 3.41e-02  -2.0 1.00e+00 5.28e-01h  1
# 1773  1.2263065e+01 2.20e-02 3.87e+04  -7.0 4.60e+03    -  4.62e-02 8.43e-02h  1
# 1774  1.2263066e+01 4.24e-05 8.94e-02  -7.0 1.85e-02  -2.5 1.00e+00 1.00e+00f  1
# 1775  1.2263063e+01 3.16e-02 1.07e+02  -7.0 3.82e+02    -  9.66e-01 1.00e+00h  1
# 1776  1.2263063e+01 3.07e-02 1.03e+02  -7.0 5.06e+03    -  7.76e-02 1.91e-02h  2
# 1777  1.2263063e+01 1.90e-02 1.13e+02  -7.0 3.10e+02    -  1.00e+00 4.11e-01h  2
# 1778  1.2263063e+01 1.37e-02 1.36e+02  -7.0 1.55e+03    -  1.00e+00 2.77e-01h  2
# 1779  1.2263064e+01 7.61e-07 2.89e-04  -7.0 2.83e-03  -2.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1780r 1.2263064e+01 7.61e-07 9.99e+02  -6.1 0.00e+00    -  0.00e+00 3.79e-07R 20
# 1781r 1.2263065e+01 3.29e-07 9.80e+02  -6.1 1.47e+00    -  1.10e-01 1.46e-03f  1
# 1782  1.2263014e+01 5.14e-01 7.45e+02  -7.0 1.27e+05    -  4.41e-01 3.46e-01h  1
# 1783  1.2263010e+01 1.91e-01 1.36e+05  -7.0 1.64e+05    -  5.77e-01 5.96e-01h  1
# 1784  1.2263015e+01 1.58e-02 1.12e+04  -7.0 2.81e-02  -1.6 7.90e-01 9.17e-01h  1
# 1785  1.2263019e+01 3.52e-06 4.43e-03  -7.0 1.65e-02  -2.1 1.00e+00 1.00e+00f  1
# 1786  1.2263019e+01 3.52e-06 4.06e+00  -7.0 8.15e+03    -  5.40e-01 5.91e-04h 11
# 1787  1.2263020e+01 7.33e-08 1.32e-05  -7.0 6.60e-04  -1.7 1.00e+00 1.00e+00h  1
# 1788  1.2263020e+01 1.34e-07 1.61e-05  -7.0 1.19e-03  -2.2 1.00e+00 1.00e+00h  1
# 1789  1.2263020e+01 1.69e-08 8.10e-06  -7.0 4.56e-04  -1.7 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1790  1.2263020e+01 6.92e-08 6.29e-06  -7.0 1.06e-03  -2.2 1.00e+00 1.00e+00h  1
# 1791  1.2263020e+01 7.43e-09 6.05e-06  -7.0 3.83e-04  -1.8 1.00e+00 1.00e+00h  1
# 1792  1.2263020e+01 3.96e-08 7.31e-06  -7.0 9.46e-04  -2.3 1.00e+00 1.00e+00h  1
# 1793  1.2263022e+01 1.05e-02 3.92e+03  -7.0 1.85e+04    -  1.00e+00 2.99e-01h  2
# 1794  1.2263022e+01 1.16e-06 2.44e-04  -7.0 1.79e-03  -1.9 1.00e+00 1.00e+00h  1
# 1795  1.2263022e+01 3.17e-08 2.05e-05  -7.0 6.60e-04  -2.3 1.00e+00 1.00e+00h  1
# 1796  1.2263022e+01 3.57e-09 2.97e-06  -7.0 2.38e-04  -1.9 1.00e+00 1.00e+00h  1
# 1797  1.2263022e+01 2.13e-08 1.44e-05  -7.0 6.29e-04  -2.4 1.00e+00 1.00e+00h  1
# 1798  1.2263022e+01 2.56e-09 2.69e-06  -7.0 2.26e-04  -2.0 1.00e+00 1.00e+00h  1
# 1799  1.2263022e+01 3.59e-03 4.20e+03  -7.0 8.55e+08    -  6.88e-05 1.31e-05h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1800  1.2263022e+01 4.39e-07 1.74e-04  -7.0 9.03e-04  -1.5 1.00e+00 1.00e+00h  1
# 1801  1.2263022e+01 1.77e-08 1.34e-05  -7.0 2.36e-04  -2.0 1.00e+00 1.00e+00h  1
# 1802  1.2263022e+01 3.03e-08 4.51e-05  -7.0 6.16e-04  -2.5 1.00e+00 1.00e+00h  1
# 1803  1.2263022e+01 3.17e-09 7.70e-06  -7.0 2.21e-04  -2.1 1.00e+00 1.00e+00h  1
# 1804  1.2263025e+01 1.34e-02 6.17e+03  -7.0 2.14e+04    -  1.00e+00 1.00e+00H  1
# 1805  1.2263025e+01 1.65e-02 5.54e+03  -7.0 1.32e+04    -  3.00e-01 1.01e-01h  2
# 1806  1.2263025e+01 2.27e-06 1.08e-03  -7.0 4.77e-03  -2.5 1.00e+00 1.00e+00h  1
# 1807  1.2263025e+01 1.12e-09 2.26e-06  -7.0 2.87e-05  -1.2 1.00e+00 1.00e+00h  1
# 1808  1.2263023e+01 8.68e-03 5.75e+03  -7.0 3.39e+04    -  1.00e+00 1.00e+00H  1
# 1809  1.2263023e+01 5.54e-03 3.67e+03  -7.0 3.09e-03  -1.7 1.00e+00 3.62e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 1810  1.2263023e+01 3.56e-03 2.36e+03  -7.0 1.90e-03  -1.3 1.00e+00 3.57e-01h  2
# 1811  1.2263023e+01 3.96e-07 4.37e-04  -7.0 1.67e-03  -1.7 1.00e+00 1.00e+00h  1
# 1812  1.2263024e+01 7.10e-04 3.17e+01  -7.0 2.94e+03    -  1.00e+00 1.00e+00h  1
# 1813  1.2263024e+01 1.24e-08 1.10e-05  -7.0 2.23e-04  -1.3 1.00e+00 1.00e+00h  1
# 1814  1.2263024e+01 7.72e-04 6.73e+02  -7.0 2.17e+03    -  1.00e+00 1.00e+00h  1
# 1815  1.2263024e+01 5.79e-04 5.05e+02  -7.0 4.03e-04  -1.8 1.00e+00 2.50e-01h  3
# 1816  1.2263024e+01 6.31e-09 2.87e-05  -7.0 2.12e-04  -1.4 1.00e+00 1.00e+00h  1
# 1817  1.2263024e+01 5.68e-09 6.54e-06  -7.0 7.07e-05  -1.8 1.00e+00 1.00e+00h  1
# 1818  1.2263024e+01 4.75e-10 7.74e-07  -7.0 1.99e-05  -1.4 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1818
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0383593597625242e+00    1.2263024038795411e+01
# Dual infeasibility......:   7.7418960716699565e-07    9.1431792606422192e-06
# Constraint violation....:   4.7453524443241690e-10    4.7453524443241690e-10
# Complementarity.........:   9.0909435573249214e-08    1.0736404341200732e-06
# Overall NLP error.......:   7.7418960716699565e-07    9.1431792606422192e-06
#
#
# Number of objective function evaluations             = 2580
# Number of objective gradient evaluations             = 1733
# Number of equality constraint evaluations            = 2580
# Number of inequality constraint evaluations          = 2580
# Number of equality constraint Jacobian evaluations   = 1835
# Number of inequality constraint Jacobian evaluations = 1835
# Number of Lagrangian Hessian evaluations             = 1818
# Total CPU secs in IPOPT (w/o function evaluations)   =     67.604
# Total CPU secs in NLP function evaluations           =      1.973
#
# EXIT: Optimal Solution Found.
# Pyomo optimization status: ok

# %% [markdown]
# instance [4][49]

# %%
all_mccm_limit_loss[4][49]
# Out:
# 851.2363451910454

# %%
mccm_limit_loss, mccm_limit_prob,mccm_limit_runtime = mccm_limit(all_full_instances[4][49],all_full_collections[4],all_full_offertimes[4])
all_mccm_limit_loss[4][49] = mccm_limit_loss
all_mccm_limit_prob[4][49] = mccm_limit_prob
all_mccm_limit_runtime[4][49] = mccm_limit_runtime
# Out:
# 1.9577933958664695

# %%
## adding limit results
ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    df_mccm_loss = pd.DataFrame({'ins_idx':ins_idx,'mccm_loss':all_mccm_limit_loss[i],'avg_loss':all_mccm_limit_loss[i]/sum(all_full_offertimes[i]),  'mccm_limit_time':all_mccm_limit_runtime[i]})
    df_mccm_loss.to_csv('limit/mccm/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_mccm_limit_prob[i][j])
        df_limit_prob.to_csv('limit/mccm/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
for i in range(len(pred_offer_times_list)):
    all_avg_loss.append(all_mccm_limit_loss[i]/sum(all_full_offertimes[i]))

# %%
avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_mccm_limit_runtime = []

#avg_loss = []
avg_loss_se = []

for i in range(len(pred_offer_times_list)):

    
    avg_total_limit_loss.append(np.mean(all_mccm_limit_loss[i]))
    avg_mccm_limit_runtime.append(np.sum(all_mccm_limit_runtime[i]))
    avg_toal_limit_loss_se.append(np.std(all_mccm_limit_loss[i])/np.sqrt(len(all_mccm_limit_loss[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))

# %%
avg_loss = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))

# %%
df_mccm_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'total_mccm_loss':avg_total_limit_loss,'total_mccm_loss_se':avg_toal_limit_loss_se,
                                   'avg_mccm_loss':avg_loss,'avg_mccm_loss_se':avg_loss_se,
                                   'avg_mccm_limit_runtime':avg_mccm_limit_runtime
                                   })
df_mccm_limit.to_csv('limit/mccm/mccm_limit_summary.csv')
df_mccm_limit
# Out:
#    offertimes  total_mccm_loss  total_mccm_loss_se  avg_mccm_loss  \
# 0          20        36.715851            1.029740       0.004796
# 1          30        27.671420            0.919718       0.003675
# 2          40        17.989138            0.985292       0.002444
# 3          50         9.646535            0.834958       0.001342
# 4          60         6.467233            0.833142       0.000913
#
#    avg_mccm_loss_se  avg_mccm_limit_runtime
# 0          0.000135              599.083187
# 1          0.000122              761.105921
# 2          0.000134              514.440836
# 3          0.000116              339.754596
# 4          0.000118              466.141473

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.0047963228328896145
# 0.00367531141991045
# 0.002443844315344835
# 0.0013416599706696077
# 0.0009131930847690751
