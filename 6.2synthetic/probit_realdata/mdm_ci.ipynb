# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def generate_negatively_correlated_covariance_matrix(n):
    # Generate a random correlation matrix with negative correlations
    correlation_matrix = np.random.uniform(low=-0.9, high=-0.1, size=(n, n))
    np.fill_diagonal(correlation_matrix, 1)  # Set diagonal elements to 1
    correlation_matrix = (correlation_matrix + correlation_matrix.T) / 2  # Ensure symmetry

    # Ensure the correlation matrix is valid for Cholesky decomposition
    cholesky_success = False
    while not cholesky_success:
        try:
            # Perform Cholesky decomposition
            cholesky_matrix = np.linalg.cholesky(correlation_matrix)
            cholesky_success = True
        except np.linalg.LinAlgError:
            # If Cholesky decomposition fails, adjust the correlation matrix slightly
            correlation_matrix += np.eye(n) * 0.01  # Adjust diagonal elements slightly

    # Generate random standard deviations
    #standard_deviations = np.random.uniform(0.5, 2, size=n)
    
    variance_outsideopt = np.random.uniform(30,40)
    variance_products = np.random.uniform(0.5,2,size=n-1)
    standard_deviations = np.hstack((variance_outsideopt,variance_products))
    # Construct diagonal matrix from standard deviations
    diagonal_matrix = np.diag(standard_deviations)
    #diagonal_matrix = np.eye(n)

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix

# %%
def is_positive_semidefinite(matrix):
    """
    Check if a matrix is positive semidefinite.
    
    Args:
        matrix (numpy.ndarray): The matrix to check.
        
    Returns:
        bool: True if the matrix is positive semidefinite, False otherwise.
    """
    # Check if the matrix is symmetric
    if not np.allclose(matrix, matrix.T):
        return False
    
    # Check if all eigenvalues are non-negative
    eigvals, _ = np.linalg.eig(matrix)
    return np.all(eigvals >= 0)

# %%
def collection_distribution_prob_neg(n,collection):
    # generate mean 
    #mu = np.random.uniform(-2,2,n)
    mu_0 = np.random.uniform(6,10)
    mu_1n = np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    # generate covariance matrix with positive correlation
    neg_cov = generate_negatively_correlated_covariance_matrix(n)
    if is_positive_semidefinite(neg_cov): 
        sample_size = 10000
        utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    else:
        print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 
        
        
        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_instance = collection_distribution_prob_neg(n,whole_collection)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-11:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(jd_collection,jd_offertimes)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-11:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:

            
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples) '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-3:
                    condition = True
        if condition == True:
            print('instance_generation error')
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 30
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 40
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 50
# instance_generation error
# instance_generation error
# instance_generation error
# check assortment index for offertimes 60
# instance_generation error
# instance_generation error

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        ''' df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''
        
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
pd.DataFrame(all_train_instances[0][0])
# Out:
#          0        1        2         3         4         5         6   \
# 0  0.713816  0.75641  0.75122  0.764444  0.758882  0.769231  0.684211
# 1  0.286184  0.00000  0.00000  0.000000  0.000000  0.000000  0.210526
# 2  0.000000  0.24359  0.00000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.00000  0.24878  0.000000  0.000000  0.000000  0.105263
# 4  0.000000  0.00000  0.00000  0.235556  0.000000  0.000000  0.000000
# 5  0.000000  0.00000  0.00000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.00000  0.00000  0.000000  0.241118  0.000000  0.000000
# 7  0.000000  0.00000  0.00000  0.000000  0.000000  0.230769  0.000000
# 8  0.000000  0.00000  0.00000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...    14        15        16        17  \
# 0  0.784314  0.695652  0.733871  ...  0.60  0.769231  0.707317  0.708333
# 1  0.196078  0.282609  0.177419  ...  0.00  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.25  0.038462  0.146341  0.250000
# 4  0.019608  0.000000  0.000000  ...  0.15  0.000000  0.000000  0.000000
# 5  0.000000  0.021739  0.000000  ...  0.00  0.192308  0.000000  0.000000
# 6  0.000000  0.000000  0.088710  ...  0.00  0.000000  0.146341  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.041667
#
#         18        19        20        21        22        23
# 0  0.62500  0.844444  0.869565  0.857143  0.800000  0.764706
# 1  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.03125  0.044444  0.043478  0.000000  0.000000  0.000000
# 5  0.34375  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.00000  0.111111  0.000000  0.000000  0.114286  0.000000
# 7  0.00000  0.000000  0.086957  0.000000  0.085714  0.000000
# 8  0.00000  0.000000  0.000000  0.142857  0.000000  0.235294
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_test_instance[0][0])
# Out:
#           0      1         2         3         4
# 0  0.772567  0.750  0.746269  0.718593  0.787879
# 1  0.000000  0.000  0.000000  0.000000  0.000000
# 2  0.000000  0.000  0.000000  0.000000  0.000000
# 3  0.000000  0.125  0.000000  0.000000  0.000000
# 4  0.000000  0.000  0.000000  0.000000  0.000000
# 5  0.227433  0.000  0.119403  0.135678  0.000000
# 6  0.000000  0.000  0.134328  0.000000  0.030303
# 7  0.000000  0.125  0.000000  0.000000  0.000000
# 8  0.000000  0.000  0.000000  0.145729  0.181818

# %%
pd.DataFrame(all_train_lb[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.671804  0.619981  0.716619  0.708293  0.729904  0.718617  0.511387
# 1  0.244173  0.000000  0.000000  0.000000  0.000000  0.000000  0.058950
# 2  0.000000  0.107160  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.214180  0.000000  0.000000  0.000000 -0.008840
# 4  0.000000  0.000000  0.000000  0.179404  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.212140  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.180155  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.622648  0.505216  0.622469  ...  0.382568  0.537289  0.592157  0.447895
# 1  0.040021  0.096254  0.081119  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.057816 -0.067405  0.056883  0.001891
# 4 -0.034890  0.000000  0.000000  ... -0.008479  0.000000  0.000000  0.000000
# 5  0.000000 -0.038616  0.000000  ...  0.000000 -0.024654  0.000000  0.000000
# 6  0.000000  0.000000  0.017037  ...  0.000000  0.000000  0.056883  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000 -0.072830
#
#          18        19        20        21        22        23
# 0  0.384769  0.692785  0.672445  0.671514  0.610210  0.712838
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4 -0.055088 -0.041789 -0.075884  0.000000  0.000000  0.000000
# 5  0.108067  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000 -0.020394  0.000000  0.000000 -0.036672  0.000000
# 7  0.000000  0.000000 -0.077966  0.000000 -0.047111  0.000000
# 8  0.000000  0.000000  0.000000 -0.042772  0.000000  0.183427
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_train_ub[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.755827  0.892840  0.785820  0.820596  0.787860  0.819845  0.857034
# 1  0.328196  0.000000  0.000000  0.000000  0.000000  0.000000  0.362103
# 2  0.000000  0.380019  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.283381  0.000000  0.000000  0.000000  0.219366
# 4  0.000000  0.000000  0.000000  0.291707  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.270096  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.281383  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.945980  0.886089  0.845273  ...  0.817432  1.001172  0.822477  0.968771
# 1  0.352136  0.468963  0.273719  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.442184  0.144328  0.235800  0.498109
# 4  0.074105  0.000000  0.000000  ...  0.308479  0.000000  0.000000  0.000000
# 5  0.000000  0.082095  0.000000  ...  0.000000  0.409269  0.000000  0.000000
# 6  0.000000  0.000000  0.160382  ...  0.000000  0.000000  0.235800  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.156164
#
#          18        19        20        21        22        23
# 0  0.865231  0.996104  1.066686  1.042772  0.989790  0.816573
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.117588  0.130678  0.162841  0.000000  0.000000  0.000000
# 5  0.579433  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.242617  0.000000  0.000000  0.265244  0.000000
# 7  0.000000  0.000000  0.251879  0.000000  0.218540  0.000000
# 8  0.000000  0.000000  0.000000  0.328486  0.000000  0.287162
#
# [9 rows x 24 columns]

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
def find_product_notin_assortment(collection,n):
    notin_collection = []
    for i in range(len(collection)):
        notin_assortment = []
        for j in range(n):
            if j not in collection[i]:
                notin_assortment.append(j)
        notin_collection.append(notin_assortment)
    return notin_collection

# %%
def robust_mdm_prediction_w_ci(lb,ub,data, collection, unseen_assortment, price,produts_notin_collection):
    
    eps = 0.01
    l = len(unseen_assortment)
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    # Create a Gurobi model
    model = gp.Model('robust_mdm_ci')
    model.setParam('OutputFlag', 0)

    # Define variables
    x = model.addVars(l, vtype=GRB.CONTINUOUS, name="x", lb=0) # choice probabilities of unseen assortment
    y = model.addVars(n, m, vtype=gp.GRB.CONTINUOUS, lb=0, name="y") # define for the in sample choice probability
    delta_plus = model.addVars(m, vtype=GRB.BINARY, name="delta_plus") # delta_{A,S}
    delta_minu = model.addVars(m, vtype=GRB.BINARY, name="delta_minu") # delta_{S,A}
    eta = model.addVar(lb=0, name="eta") # lambda_A 
    lam = model.addVars(m, lb=0, vtype=GRB.CONTINUOUS, name="lam") # lambda_S for all S in the collection
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta") # delta_{S,T}

    # Normalization constraints of unseen assortment and bound on the lambda(A)
    model.addConstr(gp.quicksum(x[i] for i in range(l)) == 1, name="Normalization")
    model.addConstr(eta <= 1, name="Eta_Bound")
    
    # Add normalization constraints
    # Bounds for lambda
    for j in range(m):
        model.addConstr(sum(y[i, j] for i in range(n)) == 1, name=f"normalization_{j}")
        model.addConstr(lam[j] <= 1, name=f"Lambda_Bound_{j}")
    
    # in-sample MDM consistency
    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"Contr1_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"Contr2_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"Contr3_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"Contr4_pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"Contr5_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"Contr6_pro_{i}_aspair_{j}_{k}")
    
    
    # Out-of-sample MDM consistency
    for k in range(len(unseen_assortment)):
        for i in prod_in_ass[unseen_assortment[k]]:
            model.addConstr(eta - lam[i] + delta_plus[i] >= 0, name=f"Cons1_{k}_{i}")
            model.addConstr(eta - lam[i] - 1 + delta_plus[i] + eps * delta_plus[i] <= 0, name=f"Cons2_{k}_{i}")
            
            model.addConstr(lam[i] - eta + delta_minu[i] >= 0, name=f"Cons3_{k}_{i}")
            model.addConstr(lam[i] - eta - 1 + delta_minu[i] + eps * delta_minu[i] <= 0, name=f"Cons4_{k}_{i}")
            
            model.addConstr(x[k] - y[unseen_assortment[k],i] - delta_plus[i] + 1 >= 0, name=f"Cons5_{k}_{i}")
            model.addConstr(x[k] - y[unseen_assortment[k],i]  + delta_minu[i] - 1 <= 0, name=f"Cons6_{k}_{i}")
            
            model.addConstr(x[k] - y[unseen_assortment[k],i]  + delta_plus[i] + delta_minu[i] >= 0,
                            name=f"Cons7_{k}_{i}")
            model.addConstr(x[k] - y[unseen_assortment[k],i]  - delta_plus[i] - delta_minu[i] <= 0,
                            name=f"Cons8_{k}_{i}")

    # In-sample MDM choice probability lies in the confidence interval
    for i in range(len(collection)):
        # normalization constraint for each assortment. 
        #model.addConstr(gp.quicksum(x[k, i] for k in collection[i]) == 1)
        for j in collection[i]:
            # constraints for the lower bound and upper bound values
            model.addConstr(y[j,i]>= lb[j,i],name=f"lb_product{j}_assortment_{i}")
            model.addConstr(y[j,i]<= ub[j,i],name=f"ub_product{j}_assortment_{i}")

        for k in produts_notin_collection[i]:
            # constraints for products that are not in the assortments
            model.addConstr(y[k,i] == 0,name=f"prob_product{k}_assortment_{i}")

    # Objective
    obj = gp.quicksum(price[unseen_assortment[i]] * x[i] for i in range(l))
    model.setObjective(obj, GRB.MINIMIZE)

    # Optimize the model
    model.optimize()

    # Access the optimal solution
    if model.status == gp.GRB.OPTIMAL:
        #model.write("robust_mdm_ci.sol")
        #model.write("robust_mdm_ci.lp")
        print(f"MDM robust prediction revenue of assortment {unseen_assortment} is : {model.objVal}") 
        y_values = [[y[i, j].X for j in range(m)] for i in range(n)]
        y_values = np.array(y_values) 
        return [model.objVal, [x[i].x for i in range(l)], [lam[i].x for i in range(m)], eta.x,y_values, model.Runtime]
    else:
        print(f'error occurred for MDM robust prediction revenue of assortment {unseen_assortment} .')
        print("Gurobi optimization status:",model.status)
        return [-1000]

# %%
def best_case_mdm_prediction_w_ci(lb,ub,data, collection, unseen_assortment, price,produts_notin_collection):
    
    eps = 0.01
    l = len(unseen_assortment)
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    # Create a Gurobi model
    model = gp.Model('best_case_mdm_ci')
    model.setParam('OutputFlag', 0)

    # Define variables
    x = model.addVars(l, vtype=GRB.CONTINUOUS, name="x", lb=0) # choice probabilities of unseen assortment
    y = model.addVars(n, m, vtype=gp.GRB.CONTINUOUS, lb=0, name="y") # define for the in sample choice probability
    delta_plus = model.addVars(m, vtype=GRB.BINARY, name="delta_plus") # delta_{A,S}
    delta_minu = model.addVars(m, vtype=GRB.BINARY, name="delta_minu") # delta_{S,A}
    eta = model.addVar(lb=0, name="eta") # lambda_A 
    lam = model.addVars(m, lb=0, vtype=GRB.CONTINUOUS, name="lam") # lambda_S for all S in the collection
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta") # delta_{S,T}

    # Normalization constraints of unseen assortment and bound on the lambda(A)
    model.addConstr(gp.quicksum(x[i] for i in range(l)) == 1, name="Normalization")
    model.addConstr(eta <= 1, name="Eta_Bound")
    
    # Add normalization constraints
    # Bounds for lambda
    for j in range(m):
        model.addConstr(sum(y[i, j] for i in range(n)) == 1, name=f"normalization_{j}")
        model.addConstr(lam[j] <= 1, name=f"Lambda_Bound_{j}")
    
    # in-sample MDM consistency
    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"Contr1_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"Contr2_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"Contr3_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"Contr4_pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"Contr5_pro_{i}_aspair_{j}_{k}")
                        model.addConstr(y[i, j] - y[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"Contr6_pro_{i}_aspair_{j}_{k}")
    
    
    # Out-of-sample MDM consistency
    for k in range(len(unseen_assortment)):
        for i in prod_in_ass[unseen_assortment[k]]:
            model.addConstr(eta - lam[i] + delta_plus[i] >= 0, name=f"Cons1_{k}_{i}")
            model.addConstr(eta - lam[i] - 1 + delta_plus[i] + eps * delta_plus[i] <= 0, name=f"Cons2_{k}_{i}")
            
            model.addConstr(lam[i] - eta + delta_minu[i] >= 0, name=f"Cons3_{k}_{i}")
            model.addConstr(lam[i] - eta - 1 + delta_minu[i] + eps * delta_minu[i] <= 0, name=f"Cons4_{k}_{i}")
            
            model.addConstr(x[k] - y[unseen_assortment[k],i] - delta_plus[i] + 1 >= 0, name=f"Cons5_{k}_{i}")
            model.addConstr(x[k] - y[unseen_assortment[k],i]  + delta_minu[i] - 1 <= 0, name=f"Cons6_{k}_{i}")
            
            model.addConstr(x[k] - y[unseen_assortment[k],i]  + delta_plus[i] + delta_minu[i] >= 0,
                            name=f"Cons7_{k}_{i}")
            model.addConstr(x[k] - y[unseen_assortment[k],i]  - delta_plus[i] - delta_minu[i] <= 0,
                            name=f"Cons8_{k}_{i}")

    # In-sample MDM choice probability lies in the confidence interval
    for i in range(len(collection)):
        # normalization constraint for each assortment. 
        #model.addConstr(gp.quicksum(x[k, i] for k in collection[i]) == 1)
        for j in collection[i]:
            # constraints for the lower bound and upper bound values
            model.addConstr(y[j,i]>= lb[j,i],name=f"lb_product{j}_assortment_{i}")
            model.addConstr(y[j,i]<= ub[j,i],name=f"ub_product{j}_assortment_{i}")

        for k in produts_notin_collection[i]:
            # constraints for products that are not in the assortments
            model.addConstr(y[k,i] == 0,name=f"prob_product{k}_assortment_{i}")


    # Objective
    obj = gp.quicksum(price[unseen_assortment[i]] * x[i] for i in range(l))
    model.setObjective(obj, GRB.MAXIMIZE)

    # Optimize the model
    model.optimize()

    # Access the optimal solution
    if model.status == gp.GRB.OPTIMAL:
        #model.write("robust_mdm_ci.sol")
        #model.write("robust_mdm_ci.lp")
        print(f"MDM best_case prediction revenue of assortment {unseen_assortment} is : {model.objVal}") 
        y_values = [[y[i, j].X for j in range(m)] for i in range(n)]
        y_values = np.array(y_values) 
        return [model.objVal, [x[i].x for i in range(l)], [lam[i].x for i in range(m)], eta.x,y_values, model.Runtime]
    else:
        print(f'error occurred for MDM best_case prediction revenue of assortment {unseen_assortment} .')
        print("Gurobi optimization status:",model.status)
        return [-1000]

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm_feasibility')
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    lam_values = [lam[i].x for i in range(data.shape[1])]
    lam_values = np.array(lam_values)

    if (model.objVal> 0):
        #model.write("mdmfeas_out.sol")
        #model.write("mdmfeas_model.lp") 
        return [1,model.Runtime,lam_values]
    else:
        #model.write("mdminfeas_model.lp")
        #return [0, used_time]
        return [0,model.Runtime,lam_values]

# %%
def robust_prediction_lp(lambda_S_lst,lambda_A,prod_in_ass,assortment_A,limit_prob,price):
    # robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
    
    model = gp.Model('robust_rev_lp')
    model.setParam('OutputFlag', 0)
    x = model.addVars(len(assortment_A),vtype=GRB.CONTINUOUS, lb=0, name='x')
    
    model.addConstr(gp.quicksum(x[i] for i in range(len(assortment_A))) == 1, name="Normalization")
    
    ## MDM consistency
    for i in range(len(assortment_A)):
        for j in range(len(prod_in_ass[assortment_A[i]])):
            if lambda_A >= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]<= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
            if lambda_A <= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]>= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
    
    # Objective
    obj = gp.quicksum(price[assortment_A[i]] * x[i] for i in range(len(assortment_A)))
    model.setObjective(obj, GRB.MINIMIZE)

    # Optimize the model
    model.optimize()
    
    if model.Status == GRB.OPTIMAL :
        return [model.objVal, [x[i].x for i in range(len(assortment_A))], model.Runtime]
    else:
        return [100000,[-1 for i in range(len(assortment_A))], model.Runtime]

# %%
def best_case_prediction_lp(lambda_S_lst,lambda_A,prod_in_ass,assortment_A,limit_prob,price):
    
    model = gp.Model('best_case_rev_lp')
    model.setParam('OutputFlag', 0)
    x = model.addVars(len(assortment_A),vtype=GRB.CONTINUOUS, lb=0, name='x')
    
    model.addConstr(gp.quicksum(x[i] for i in range(len(assortment_A))) == 1, name="Normalization")
    
    ## MDM consistency
    for i in range(len(assortment_A)):
        for j in range(len(prod_in_ass[assortment_A[i]])):
            if lambda_A >= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]<= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
            if lambda_A <= lambda_S_lst[prod_in_ass[assortment_A[i]][j]]:
                model.addConstr(x[i]>= limit_prob[ assortment_A[i]][prod_in_ass[assortment_A[i]][j]])
    
    # Objective
    obj = gp.quicksum(price[assortment_A[i]] * x[i] for i in range(len(assortment_A)))
    model.setObjective(obj, GRB.MAXIMIZE)

    # Optimize the model
    model.optimize()
    
    if model.Status == GRB.OPTIMAL :
        return [model.objVal, [x[i].x for i in range(len(assortment_A))], model.Runtime]
    else:
        return [-100000,[-1 for i in range(len(assortment_A))], model.Runtime]

# %%
## mdm milp for the worst case revenue
def mdm_revenue(curr_limit_prob, curr_lam, prod_in_ass,lambda_A_lst, assortment_A, price):
    
    robust_revenue_lst = []
    best_case_revenue_lst = []
    robust_pred_runtime = 0
    best_case_pred_runtime = 0
    #robust_prob_lst = []
    #best_case_prob_lst = []

    for j in range(len(lambda_A_lst)):
        lambda_A = lambda_A_lst[j]
        curr_robust_revenue,curr_robust_prob,curr_robust_runtime = robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
        
        robust_revenue_lst.append(curr_robust_revenue)
        robust_pred_runtime = robust_pred_runtime + curr_robust_runtime
        #robust_prob_lst.append(curr_robust_prob)
        
        curr_best_case_revenue,curr_bestcase_prob,curr_best_case_runtime = best_case_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,price)
        best_case_revenue_lst.append(curr_best_case_revenue)
        best_case_pred_runtime = best_case_pred_runtime + curr_best_case_runtime
        #best_case_prob_lst.append(curr_bestcase_prob)
    
    robust_revenue_A = np.min(robust_revenue_lst)
    best_case_revenue_A = np.max(best_case_revenue_lst)
    
    ''' robust_prob_A = robust_prob_lst[np.argmin(robust_revenue_lst)]
    bestcase_prob_A = best_case_prob_lst[np.argmax(best_case_revenue_lst)] '''
    
    print(f'the robust revenue for assortment {assortment_A} is {robust_revenue_A} with runtime {robust_pred_runtime}')
    if robust_revenue_A>100:
        print('robust MDM prediction error ')
    print(f'the best-case revenue for assortment {assortment_A} is {best_case_revenue_A} with runtime {best_case_pred_runtime}\n')
    if best_case_revenue_A<0:
        print('best-case MDM prediction error ')
    
    ''' lb_sales_A = np.zeros(len(price))
    ub_sales_A = np.zeros(len(price))
    
    for k in range(len(assortment_A)):
        unit_price = np.zeros(n)
        unit_price[assortment_A[k]] = 1
        
        robust_product_prob_lst = []
        bestcase_product_prob_lst = []
        
        for j in range(len(lambda_A_lst)):
            if best_case_revenue_lst[j]>0:
                lambda_A = lambda_A_lst[j]
                curr_robust_prob = robust_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,unit_price)[0]
                
                robust_product_prob_lst.append(curr_robust_prob)
                
                curr_bestcase_prob = best_case_prediction_lp(curr_lam,lambda_A,prod_in_ass,assortment_A,curr_limit_prob,unit_price)[0]
                bestcase_product_prob_lst.append(curr_bestcase_prob)
        
        lb_sales_A[assortment_A[k]] = np.min(robust_product_prob_lst)
        ub_sales_A[assortment_A[k]] = np.max(bestcase_product_prob_lst)
        print(f'the sales lb for product {assortment_A[k]} in assortment {assortment_A} is {lb_sales_A[assortment_A[k]]}')
        print(f'the sales ub for product {assortment_A[k]} in assortment {assortment_A} is {ub_sales_A[assortment_A[k]]}\n')
     '''
    #return [robust_revenue_A,robust_pred_runtime,robust_prob_A,lb_sales_A, best_case_revenue_A,best_case_pred_runtime, bestcase_prob_A,ub_sales_A]
    return [robust_revenue_A,robust_pred_runtime, best_case_revenue_A,best_case_pred_runtime]

# %%
def mdm_prediction(curr_test_collection,curr_test_instance,price,curr_limit_prob, curr_lam, curr_train_collection):
    ''' true assortment ranking '''
    #true_choice_prob = [] 
    true_revenue = []
    
    ''' lb_mdm_rev_prob = []
    ub_mdm_rev_prob = []
    
    lb_mdm_sales = []
    ub_mdm_sales = [] '''
    
    lb_mdm_revenue = [] 
    ub_mdm_revenue = []
    
    lb_mdm_runtime = []
    ub_mdm_runtime = []
    
    prod_in_ass = [[] for _ in range(len(price))]
    for i, assort in enumerate(curr_train_collection):
        for j in assort:
            prod_in_ass[j].append(i)
    
    dec_lam = np.abs(np.sort(-curr_lam))
    lambda_A_lst = [np.max(curr_lam)+1]
    for i in range(len(dec_lam)-1):
        lambda_A_lst.append((dec_lam[i] + dec_lam[i+1])/2)
    lambda_A_lst.append(np.min(curr_lam)-1)
    
    for k in range(len(curr_test_collection)):
            
            assortment_A = curr_test_collection[k]
            
            # true revenue and true choice probabilities for current testing assortment
            curr_revenue = np.dot(curr_test_instance[:,k],price)
            true_revenue.append(curr_revenue)
            #true_choice_prob.append(curr_test_instance[:,k])
            
            # MDM revenue prediction
            print(f'revenue prediction for unseen assortment {assortment_A}')
            mdm_prediction_result = mdm_revenue(curr_limit_prob, curr_lam, prod_in_ass,lambda_A_lst, assortment_A, price)
            
            # return [robust_revenue_A,robust_pred_runtime, best_case_revenue_A,best_case_pred_runtime]
            
            ## record the revenue result
            lb_mdm_revenue.append(mdm_prediction_result[0])
            ub_mdm_revenue.append(mdm_prediction_result[2])
            
            ## record the choice probability result
            ''' lb_prob = np.zeros(n)
            lb_prob_result = mdm_prediction_result[2]
            
            ub_prob = np.zeros(n)
            ub_prob_result = mdm_prediction_result[6]
            
            for l in range(len(assortment_A)):
                lb_prob[assortment_A[l]] = lb_prob_result[l]
                ub_prob[assortment_A[l]] = ub_prob_result[l]
            
            lb_mdm_rev_prob.append(lb_prob)
            ub_mdm_rev_prob.append(ub_prob) '''
            
            ## record the runtime result
            lb_mdm_runtime.append(mdm_prediction_result[1])
            ub_mdm_runtime.append(mdm_prediction_result[3])
            
            
            ## MDM choice probability interval prediction
            ''' lb_sales_frac = mdm_prediction_result[3]
            ub_sales_frac = mdm_prediction_result[-1] '''
            
            ''' lb_mdm_sales.append(lb_sales_frac)
            ub_mdm_sales.append(ub_sales_frac) '''
    return true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime       
    #return true_choice_prob,true_revenue,lb_mdm_rev_prob,ub_mdm_rev_prob,lb_mdm_sales,ub_mdm_sales,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
# since the underlying choice probabilities are from MEM, 
# we don't need to do representability check and limit computation

## record the kendall tau distance between the predicted ranking of MDM and the truth
all_mdm_lb_distance_list = []  
all_mdm_ub_distance_list = []

## record the true revenue of the predicted best assortment
all_best_true_revenue_list = []
all_best_revenue_mdm_lb = []  
all_best_revenue_mdm_ub =[]

## record the difference in best assortment
all_mdm_lb_best_rev_diff = []
all_mdm_ub_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mdm_lb_revenue_list = []
all_mdm_ub_revenue_list = []

## choice probability under the revenue prediction 
''' all_true_choice_prob_list = [] 
all_mdm_lb_rev_prob_list = []
all_mdm_ub_rev_prob_list = []

all_mdm_lb_sales_list = []
all_mdm_ub_sales_list = [] '''

all_true_ranking = []
all_mdm_lb_ranking = []
all_mdm_ub_ranking = []

## record the runtime of MDM prediction
all_mdm_rev_lb_runtime = []
all_mdm_rev_ub_runtime = []

all_infeasible_collection = []

for i in range(len(all_full_collections)):
    
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mdm_lb_best_rev_collection = [] # a container for the best revenue predicted by robust MDM
    mdm_ub_best_rev_collection = [] # a container for the best revenue predicted by best-case MDM
    
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mdm_lb_ranking_collection = [] # a container for ranking by robust mdm
    mdm_ub_ranking_collection = [] # a container for ranking by best-case mdm
    
    mdm_lb_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mdm
    mdm_ub_distance_collection = [] # kendall tau distance between true ranking and the ranking by best-case mdm
    
    ''' true_choice_prob_collection = []
    mdm_lb_rev_prob_collection = []
    mdm_ub_rev_prob_collection = []
    mdm_lb_sales_frac_collection = []
    mdm_ub_sales_frac_collection = [] '''
    
    true_revenue_collection = []
    mdm_lb_revenue_collection = []
    mdm_ub_revenue_collection = []
    
    mdm_lb_runtime_collection = []
    mdm_ub_runtime_collection = []
    
    infeasible_collection = []
    
    for j in range(pred_instance_size[i]):

        # the following lists are of the same size as number of testing assortments
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        ''' true assortment ranking '''
        true_choice_prob = [] 
        true_revenue = []
        
        ''' lb_mdm_rev_prob = []
        ub_mdm_rev_prob = []
        
        lb_mdm_sales = []
        ub_mdm_sales = [] '''
        
        lb_mdm_revenue = [] 
        ub_mdm_revenue = []
        
        lb_mdm_runtime = []
        ub_mdm_runtime = []
        flag=0
        
        row_data = row_assortment_data(all_train_instances[i][j],all_train_collection[i][j])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_train_instances[i][j],rank,equal)
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        ''' mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_runtime_collection.append(curr_rep_result[1]) '''
        
                # check if representable
        if curr_rep_result[0] > 0:
            # representable and then do prediction 
            # mdm_prediction(curr_test_instance,curr_test_collection,price,curr_train_instance,curr_train_collection,curr_train_perm_collection,unseen_assortment_perm_collection) mdm_prediction(curr_test_collection,curr_test_instance,price,curr_limit_prob, curr_lam, curr_train_collection)
            true_revenue,lb_mdm_revenue,ub_mdm_revenue,lb_mdm_runtime,ub_mdm_runtime = mdm_prediction(all_test_collection[i][j],all_test_instance[i][j],price,all_train_instances[i][j],curr_rep_result[-1], all_train_collection[i][j])
        else:
            
            produts_notin_collection = find_product_notin_assortment(all_train_collection[i][j],n)
            for k in range(len(all_test_collection[i][j])):
                
                unseen_assortment = all_test_collection[i][j][k]
                
                
                
                # MDM revenue prediction
                # robust_mdm_prediction_w_ci(lb,ub,data, collection, unseen_assortment, price,produts_notin_collection)
                curr_mdm_lb_result = robust_mdm_prediction_w_ci(all_train_lb[i][j],all_train_ub[i][j],all_train_instances[i][j],all_train_collection[i][j],unseen_assortment,price,produts_notin_collection)
                curr_mdm_ub_result = best_case_mdm_prediction_w_ci(all_train_lb[i][j],all_train_ub[i][j],all_train_instances[i][j],all_train_collection[i][j],unseen_assortment,price,produts_notin_collection)
                
                if curr_mdm_lb_result[0]<0:
                    flag=1
                    break
                else:
                    ## record the revenue result
                    lb_mdm_revenue.append(curr_mdm_lb_result[0])
                    ub_mdm_revenue.append(curr_mdm_ub_result[0])
                    
                    ## record the choice probability result
                    ''' lb_prob = np.zeros(n)
                    lb_prob_result = curr_mdm_lb_result[1]
                    
                    ub_prob = np.zeros(n)
                    ub_prob_result = curr_mdm_ub_result[1]
                    
                    for l in range(len(unseen_assortment)):
                        lb_prob[unseen_assortment[l]] = lb_prob_result[l]
                        ub_prob[unseen_assortment[l]] = ub_prob_result[l]
                    
                    lb_mdm_rev_prob.append(lb_prob)
                    ub_mdm_rev_prob.append(ub_prob) '''
                    
                    ## record the runtime result
                    lb_mdm_runtime.append(curr_mdm_lb_result[-1])
                    ub_mdm_runtime.append(curr_mdm_ub_result[-1])
                    
                    
                    # true revenue and true choice probabilities for current testing assortment
                    curr_revenue = np.dot(all_test_instance[i][j][:,k],price)
                    true_revenue.append(curr_revenue)
                    true_choice_prob.append(all_test_instance[i][j][:,k])
                    
                    ## MDM choice probability interval prediction
                    ''' lb_sales_frac = np.zeros(n)
                    ub_sales_frac = np.zeros(n)

                    for l in range(len(unseen_assortment)):
                        unit_price = np.zeros(n)
                        unit_price[unseen_assortment[l]] = 1
                        ## unit price is a vector that takes value 1 only at unseen_assortment[l] and all zeros for other n-1 elements
                        lb_sales_frac[unseen_assortment[l]] = robust_mdm_prediction_w_ci(all_train_lb[i][j],all_train_ub[i][j],all_train_instances[i][j],all_train_collection[i][j],unseen_assortment,unit_price,produts_notin_collection)[0]
                        ub_sales_frac[unseen_assortment[l]] = best_case_mdm_prediction_w_ci(all_train_lb[i][j],all_train_ub[i][j],all_train_instances[i][j],all_train_collection[i][j],unseen_assortment,unit_price,produts_notin_collection)[0]
                    
                    lb_mdm_sales.append(lb_sales_frac)
                    ub_mdm_sales.append(ub_sales_frac) '''
        if flag==0:        
            true_revenue_collection.append(true_revenue)
            #true_choice_prob_collection.append(true_choice_prob)
            
            mdm_lb_revenue_collection.append(lb_mdm_revenue)   
            mdm_ub_revenue_collection.append(ub_mdm_revenue)
            #mdm_lb_rev_prob_collection.append(lb_mdm_rev_prob)
            #mdm_ub_rev_prob_collection.append(ub_mdm_rev_prob)
            
            mdm_lb_runtime_collection.append(lb_mdm_runtime)
            mdm_ub_runtime_collection.append(ub_mdm_runtime)
            
            ## sales fraction record
            #mdm_lb_sales_frac_collection.append(lb_mdm_sales)
            #mdm_ub_sales_frac_collection.append(ub_mdm_sales)
            
            # true assortment ranking for test instance [i][j]
            curr_true_rank = np.argsort(-np.array(true_revenue))  
            true_ranking_collection.append(curr_true_rank)
            # true best assortment revenue for test instance [i][j]
            true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
            
            # lb mdm assortment ranking for test instance [i][j] 
            curr_mdm_lb_rank  = np.argsort(-np.array(lb_mdm_revenue)) 
            mdm_lb_ranking_collection.append(curr_mdm_lb_rank)
            mdm_lb_best_rev_collection.append(true_revenue[curr_mdm_lb_rank[0]])
            
            # ub mdm assortment ranking for test instance [i][j]
            curr_mdm_ub_rank = np.argsort(-np.array(ub_mdm_revenue)) 
            mdm_ub_ranking_collection.append(curr_mdm_ub_rank)
            mdm_ub_best_rev_collection.append(true_revenue[curr_mdm_ub_rank[0]])
            
            #  MDM kendallTau Distance for current instance [i][j]
            curr_mdm_lb_dist = kendall_tau_distance(curr_true_rank, curr_mdm_lb_rank)
            mdm_lb_distance_collection.append(curr_mdm_lb_dist)
            
            curr_mdm_ub_dist = kendall_tau_distance(curr_true_rank, curr_mdm_ub_rank)
            mdm_ub_distance_collection.append(curr_mdm_ub_dist)
        else:
            infeasible_collection.append(flag)
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mdm_lb_distance_list.append(mdm_lb_distance_collection)
    all_mdm_ub_distance_list.append(mdm_ub_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_revenue_list.append(true_best_rev_collection) 
    all_best_revenue_mdm_lb.append(mdm_lb_best_rev_collection)
    all_best_revenue_mdm_ub.append(mdm_ub_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_mdm_lb_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(mdm_lb_best_rev_collection))/ np.array(true_best_rev_collection))
    all_mdm_ub_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(mdm_ub_best_rev_collection))/np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    #all_true_choice_prob_list.append(true_choice_prob_collection)
    all_mdm_lb_revenue_list.append(mdm_lb_revenue_collection)
    all_mdm_ub_revenue_list.append(mdm_ub_revenue_collection)
    #all_mdm_lb_rev_prob_list.append(mdm_lb_rev_prob_collection)
    #all_mdm_ub_rev_prob_list.append(mdm_ub_rev_prob_collection)
    
    #all_mdm_lb_sales_list.append(mdm_lb_sales_frac_collection)
    #all_mdm_ub_sales_list.append(mdm_ub_sales_frac_collection)
    
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mdm_lb_ranking.append(mdm_lb_ranking_collection)
    all_mdm_ub_ranking.append(mdm_ub_ranking_collection)
    
    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mdm_rev_lb_runtime.append(mdm_lb_runtime_collection)
    all_mdm_rev_ub_runtime.append(mdm_ub_runtime_collection)
    
    all_infeasible_collection.append(infeasible_collection)
# Out:
# testing for offertimes 20, 0th instance
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# MDM robust prediction revenue of assortment [0, 5] is : 0.1268704018825796
# MDM best_case prediction revenue of assortment [0, 5] is : 0.30305484794152904
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.09547160774843749
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.17120654904399127
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.10152115205317716
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.30305484794152904
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.21534288215082387
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.45270940823718153
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.10055459006615582
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.44337837901885485
# testing for offertimes 20, 1th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.1259061938349947
# MDM best_case prediction revenue of assortment [0, 3] is : 0.16643303387267672
# MDM robust prediction revenue of assortment [0, 4] is : 0.03232041002868299
# MDM best_case prediction revenue of assortment [0, 4] is : 0.4566331819816683
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.2672907247133824
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.4818715420428463
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.12590619383499474
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.16643303387267652
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.1430048942072042
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.4512409297587503
# testing for offertimes 20, 2th instance
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.3046815255399226
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.8014402239722123
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.12313384793586318
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.17099319770761984
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.10594332881283487
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.6768903186835648
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.3181009412436525
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.7800245778159094
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.3436081757770116
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.8196510283734814
# testing for offertimes 20, 3th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.08583885315385163
# MDM best_case prediction revenue of assortment [0, 1] is : 0.31300984914810315
# MDM robust prediction revenue of assortment [0, 4] is : 0.22547645259461266
# MDM best_case prediction revenue of assortment [0, 4] is : 0.5427588898917968
# MDM robust prediction revenue of assortment [0, 7] is : 0.07035180177889945
# MDM best_case prediction revenue of assortment [0, 7] is : 0.20145686736717475
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.08744538186594732
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.5427588898917947
# MDM robust prediction revenue of assortment [0, 8] is : 0.13975168820203152
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5812258091041785
# testing for offertimes 20, 4th instance
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.2563671394813487
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.7943168089267884
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.1071477176792339
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.3130311463776826
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.10602941857887076
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.6486996610377976
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.10877799068689677
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.35873935474406526
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.10877799068689736
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.26602180965317895
# testing for offertimes 20, 5th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.15706655625597846
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3998203319312952
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.24130796779354513
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.649884998169388
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.1215742728331308
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.3002291219999139
# MDM robust prediction revenue of assortment [0, 4, 7] is : 0.18063422292620354
# MDM best_case prediction revenue of assortment [0, 4, 7] is : 0.5899940221796275
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.12670854710305526
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.4252553139330746
# testing for offertimes 20, 6th instance
# MDM robust prediction revenue of assortment [0, 4] is : 0.42085820208083186
# MDM best_case prediction revenue of assortment [0, 4] is : 0.8359625434170517
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.10480058701942738
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.343151826220818
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.10480058701942738
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.2811511738111604
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.4118841634985029
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 1.0021923518613436
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.3158552991616563
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.7998829196558876
# testing for offertimes 20, 7th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.1491794149329157
# MDM best_case prediction revenue of assortment [0, 1] is : 0.22135531628576974
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.10214368255606
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.3234495294677182
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.08425776345869088
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.2105660328695632
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.2430167455626617
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.561047613609738
# MDM robust prediction revenue of assortment [0, 8] is : 0.07329257253119631
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5392310298777809
# testing for offertimes 20, 8th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.0713746272492218
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3837063672600068
# MDM robust prediction revenue of assortment [0, 7] is : 0.045714908041306
# MDM best_case prediction revenue of assortment [0, 7] is : 0.24695798853429834
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.22359613939398904
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.5063849098877458
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.13443332657473583
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.34574322624919973
# MDM robust prediction revenue of assortment [0, 8] is : 0.23083404064182705
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5274556236207474
# testing for offertimes 20, 9th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.11584827174473511
# MDM best_case prediction revenue of assortment [0, 1] is : 0.4025003444403407
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.09486264318455849
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.4025003444403407
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.12306790383922281
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.2211201384913562
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.09486264318455849
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.4128945665106426
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.36067271685328683
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.6484553022116158
# testing for offertimes 20, 10th instance
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.09653949009931546
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.3504475167547093
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.1127720322313017
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.3072027899821978
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.08648373301508755
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.5697415886777322
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.0973869099236324
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.21963772401223006
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.11703252763957935
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.41422958682433114
# testing for offertimes 20, 11th instance
# error occurred for MDM robust prediction revenue of assortment [0, 1, 3] .
# Gurobi optimization status: 3
# error occurred for MDM best_case prediction revenue of assortment [0, 1, 3] .
# Gurobi optimization status: 4
# testing for offertimes 20, 12th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.05351457817523659
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3930097479026522
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.27901668638215343
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.48759265596400114
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.13544745637038325
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.33582744079285237
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.13544745637038325
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.22197869757460229
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.1261272132704743
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.32639334500143846
# testing for offertimes 20, 13th instance
# MDM robust prediction revenue of assortment [0, 4] is : 0.12729590612418717
# MDM best_case prediction revenue of assortment [0, 4] is : 0.6564828958038753
# MDM robust prediction revenue of assortment [0, 6] is : 0.027339405984219394
# MDM best_case prediction revenue of assortment [0, 6] is : 0.15370639014373358
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.3098648643061604
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.7990899252465692
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.3628494343975531
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.9152837870194821
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.23561070647589488
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.5455745564166435
# testing for offertimes 20, 14th instance
# MDM robust prediction revenue of assortment [0, 4] is : 0.010536559725486205
# MDM best_case prediction revenue of assortment [0, 4] is : 0.41736392844017456
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.3177630112365277
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.6014782969437188
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.1377333987632584
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.45916939119593286
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.4422578753537538
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.7042801033713687
# MDM robust prediction revenue of assortment [0, 8] is : 0.442257875353754
# MDM best_case prediction revenue of assortment [0, 8] is : 0.7042801033713687
# testing for offertimes 20, 15th instance
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.1184024063812611
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.1807581729717932
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.07769531668763259
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.33008548656285197
# MDM robust prediction revenue of assortment [0, 4, 7] is : 0.19007374166963684
# MDM best_case prediction revenue of assortment [0, 4, 7] is : 0.7213699199684672
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.4317794549569954
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.9635920476422598
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.12809710780074635
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.303803104437139
# testing for offertimes 20, 16th instance
# MDM robust prediction revenue of assortment [0, 7] is : 0.006840617858943804
# MDM best_case prediction revenue of assortment [0, 7] is : 0.3491115304378255
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.2771056858173099
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.5264655486727732
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.09711205447696691
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.34911153043782617
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.11596574778835084
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.5583355753897361
# MDM robust prediction revenue of assortment [0, 8] is : 0.12726619074871076
# MDM best_case prediction revenue of assortment [0, 8] is : 0.6451543562758735
# testing for offertimes 20, 17th instance
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.20459279322980933
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.4416256524118852
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.10020008622237957
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.5427588898917947
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.10020008622237957
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.32609025050825646
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.10020008622237957
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.28045900183442285
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.09864219960295414
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.4204405279231027
# testing for offertimes 20, 18th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.051223166534759695
# MDM best_case prediction revenue of assortment [0, 2] is : 0.1755715251509939
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.11503984909597188
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.3749741769036885
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.10328016691661067
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.5380982513955754
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.3233747658907421
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.6729493259395714
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.11410006341426533
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.509632591224003
# testing for offertimes 20, 19th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.07003935738912656
# MDM best_case prediction revenue of assortment [0, 6] is : 0.19654559574572358
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.23025464467699788
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.4770202189863928
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.10454188303125428
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.2816816610671081
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.07472287746303105
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.33319667736404524
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.24799131108805508
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.5556454291268387
# testing for offertimes 20, 20th instance
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.15275532441394093
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.345104435390304
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.11622663439880782
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.21655157756383198
# MDM robust prediction revenue of assortment [0, 4, 7] is : 0.19154087024059135
# MDM best_case prediction revenue of assortment [0, 4, 7] is : 0.7018580264687219
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.13550801864781964
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.2590521461708708
# MDM robust prediction revenue of assortment [0, 8] is : 0.14605089603417462
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5443751953036896
# testing for offertimes 20, 21th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.039647096277719424
# MDM best_case prediction revenue of assortment [0, 3] is : 0.15483204146442553
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.14728282598516937
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.30383123032603143
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.11147389378918234
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.24655809393736555
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.11410006341426533
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.4765852159761835
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.316730051863923
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.6353327610252639
# testing for offertimes 20, 22th instance
# MDM robust prediction revenue of assortment [0, 4] is : 0.023060271794443248
# MDM best_case prediction revenue of assortment [0, 4] is : 0.5530659268375969
# MDM robust prediction revenue of assortment [0, 6] is : 0.06605791115241487
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1582095650700185
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.21179135219988843
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.42551615558208905
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.08911818294685739
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.5447167598049172
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.19958573180328176
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.45532719944950856
# testing for offertimes 20, 23th instance
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.17708941725751595
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.5770050335240059
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.27387662958822573
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.843612155188103
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.10286816730931439
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.6185370248643376
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.10038513606425974
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.4101780436858428
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.12204162562660771
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.3065125469019279
# testing for offertimes 20, 24th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.20556632033282687
# MDM best_case prediction revenue of assortment [0, 1] is : 0.45730092246561455
# MDM robust prediction revenue of assortment [0, 2] is : 0.09065353435209608
# MDM best_case prediction revenue of assortment [0, 2] is : 0.18529054296928565
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.2771056858173099
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.6256300931948584
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.11218604352264915
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.6505136858483804
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.38337798544989404
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.7747233371496902
# testing for offertimes 20, 25th instance
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.2903526009040692
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.6251194617843956
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.12549015051734297
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.32847416866702717
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.12549015051734294
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.336461214798499
# MDM robust prediction revenue of assortment [0, 4, 7] is : 0.23327550742052267
# MDM best_case prediction revenue of assortment [0, 4, 7] is : 0.7840540938758019
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.13473589283360857
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.579617918562841
# testing for offertimes 20, 26th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.0
# MDM best_case prediction revenue of assortment [0, 1] is : 0.33276792687430157
# MDM robust prediction revenue of assortment [0, 6] is : 0.08249136718862746
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1569906077234625
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.09347517143964203
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.2820911819566066
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.09347517143964203
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.31423695881937713
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.24867821821552671
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.6091057266493086
# testing for offertimes 20, 27th instance
# MDM robust prediction revenue of assortment [0, 7] is : 0.021801361957594943
# MDM best_case prediction revenue of assortment [0, 7] is : 0.2012450301753788
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.0898187933961344
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.24880132933667906
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.12520763333395168
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.16813586507021722
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.13765869629596683
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.4221994264539344
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.1376586962959668
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.5354673942911091
# testing for offertimes 20, 28th instance
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.12283548062637364
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.2902481335840369
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.1821835940855527
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.4034521644129842
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.09682581658625079
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.35317824423372857
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.08071646821564649
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.17231114419892712
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.11279977474251143
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.29624304894805115
# testing for offertimes 20, 29th instance
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.2085807389432224
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.440450147543839
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.15195525828751857
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.3105929627440113
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.09353487687932004
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.24655809393736555
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.08441989337070664
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.17862120609032894
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.09605902615862837
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.3950088542503393
# testing for offertimes 20, 30th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.1488271172985231
# MDM best_case prediction revenue of assortment [0, 1] is : 0.5086465669120029
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.2838467174331118
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.8687315855386764
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.10661293613481913
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.6022105697842592
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.4149997155938484
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.934650017501675
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.3201114757603009
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.8101337509234083
# testing for offertimes 20, 31th instance
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.19378672873914712
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.4283716138356466
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.32941199752277617
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.6883201358314694
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.13309057291780196
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.34181331402033194
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.13309057291780194
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.43343934939386064
# MDM robust prediction revenue of assortment [0, 8] is : 0.014922391408645168
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5553505930646121
# testing for offertimes 20, 32th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.0
# MDM best_case prediction revenue of assortment [0, 5] is : 0.5909785913541511
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.10326574112365315
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.5765451301428614
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.1323544338166049
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.2564034447125022
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.14627830255716498
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.5017367802049519
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.24496993757727684
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.6388761636197865
# testing for offertimes 20, 33th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.019431417587292225
# MDM best_case prediction revenue of assortment [0, 2] is : 0.17122373569748764
# MDM robust prediction revenue of assortment [0, 7] is : 0.0
# MDM best_case prediction revenue of assortment [0, 7] is : 0.21946195306427424
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.10855260608120819
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.2042084895868833
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.10142569671006087
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.4973751415299713
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.11688114524998865
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.5423151483096499
# testing for offertimes 20, 34th instance
# MDM robust prediction revenue of assortment [0, 7] is : 0.023470185474822148
# MDM best_case prediction revenue of assortment [0, 7] is : 0.3112260366157817
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.15451553992171674
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.4074699292546194
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.12797506597771566
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.4540492337893091
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.12797505762883538
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.22223657425087556
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.12797506597771566
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.2708107916479041
# testing for offertimes 20, 35th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.0026793143917912886
# MDM best_case prediction revenue of assortment [0, 1] is : 0.2950864249706744
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.13875026869841273
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.27504490565605305
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.09039199156979313
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.24272110784302106
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.08677841692087604
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.3072912304246173
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.09748509890300444
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.20999178646714914
# testing for offertimes 20, 36th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.13550801864782153
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.3675140587263391
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.1303621445219549
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.22293882071669374
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.1117798212896587
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.20679388638315283
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.11177982128965874
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.5564612552267885
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.29985671764096383
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.7025483007439822
# testing for offertimes 20, 37th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.058673948886344224
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3820274417626112
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.08885360511478964
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.3820274417626112
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.09742934951787235
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.5527146004207805
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.2866548115328162
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.720135642699377
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.2925372284756576
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.5873773580635517
# testing for offertimes 20, 38th instance
# error occurred for MDM robust prediction revenue of assortment [0, 3] .
# Gurobi optimization status: 3
# error occurred for MDM best_case prediction revenue of assortment [0, 3] .
# Gurobi optimization status: 4
# testing for offertimes 20, 39th instance
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.2694919733822735
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.6597707508852302
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.09339397685436751
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.15822818031183872
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.265173312784766
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.5524006926310109
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.09500275545128153
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.24813900497057872
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.09500275545128153
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.496570869075714
# testing for offertimes 20, 40th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.00913497134027699
# MDM best_case prediction revenue of assortment [0, 2] is : 0.17575970863426107
# MDM robust prediction revenue of assortment [0, 3] is : 0.03887964309954332
# MDM best_case prediction revenue of assortment [0, 3] is : 0.1600241741057951
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.1446600985509349
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.5345966999571992
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.1446600985509349
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.37343564439883337
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.1446600985509349
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.6130370533076273
# testing for offertimes 20, 41th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.03448482765762143
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3601080922878304
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.10633675810158633
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.3244662196647726
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.2038096770898318
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.6840817251086303
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.08455108506952397
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.25048458172022015
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.0878886279012157
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.3268287270578177
# testing for offertimes 20, 42th instance
# MDM robust prediction revenue of assortment [0, 4] is : 0.0
# MDM best_case prediction revenue of assortment [0, 4] is : 0.5090553846634319
# MDM robust prediction revenue of assortment [0, 6] is : 0.03926703269741104
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1456199470914102
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.22700392628474178
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.42028574887482517
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.09602297649154662
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.5875681651119241
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.28831451253472035
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.8609996181584432
# testing for offertimes 20, 43th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.05010715617066908
# MDM best_case prediction revenue of assortment [0, 3] is : 0.1387214677799307
# MDM robust prediction revenue of assortment [0, 6] is : 0.08082931352661832
# MDM best_case prediction revenue of assortment [0, 6] is : 0.16816873587643716
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.26228477672487294
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.573333593998726
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.22880843426896133
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.3924131333421441
# MDM robust prediction revenue of assortment [0, 1, 7] is : 0.14610252127755277
# MDM best_case prediction revenue of assortment [0, 1, 7] is : 0.3488140895133942
# testing for offertimes 20, 44th instance
# error occurred for MDM robust prediction revenue of assortment [0, 6] .
# Gurobi optimization status: 3
# error occurred for MDM best_case prediction revenue of assortment [0, 6] .
# Gurobi optimization status: 4
# testing for offertimes 20, 45th instance
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.30298021848745105
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.7425991813985362
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.11208335672275041
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.3482530694847313
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.07697942389159866
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.1488913511049729
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.07167386162832548
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.48244632595239134
# MDM robust prediction revenue of assortment [0, 4, 7] is : 0.13894147345599378
# MDM best_case prediction revenue of assortment [0, 4, 7] is : 0.5364855568100486
# testing for offertimes 20, 46th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.011665073428433294
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3349706344984257
# MDM robust prediction revenue of assortment [0, 4] is : 0.13524773374194204
# MDM best_case prediction revenue of assortment [0, 4] is : 0.6661549485797966
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.27007687023491794
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.4083508084768433
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.3486621463446272
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.5840057534923844
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.08556399173535091
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.6661549485797966
# testing for offertimes 20, 47th instance
# MDM robust prediction revenue of assortment [0, 7] is : 0.09181352627782813
# MDM best_case prediction revenue of assortment [0, 7] is : 0.23466767510962583
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.2738766295882258
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.6048916233173867
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.12470463249262152
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.40705099858480726
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.12797506597771563
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.3402840103524911
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.39654062798550355
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 1.0740178158121059
# testing for offertimes 20, 48th instance
# MDM robust prediction revenue of assortment [0, 4] is : 0.19790662098482437
# MDM best_case prediction revenue of assortment [0, 4] is : 0.41736392844017495
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.24674303556504093
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.4817478906018794
# MDM robust prediction revenue of assortment [0, 3, 5] is : 0.1067401411842132
# MDM best_case prediction revenue of assortment [0, 3, 5] is : 0.3292235026308295
# MDM robust prediction revenue of assortment [0, 4, 8] is : 0.2598121700784985
# MDM best_case prediction revenue of assortment [0, 4, 8] is : 0.49241145571095035
# MDM robust prediction revenue of assortment [0, 8] is : 0.061905549093665316
# MDM best_case prediction revenue of assortment [0, 8] is : 0.4268127521329834
# testing for offertimes 20, 49th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.05911669381437945
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3545373165409464
# MDM robust prediction revenue of assortment [0, 7] is : 0.05147148889753352
# MDM best_case prediction revenue of assortment [0, 7] is : 0.3032287425238797
# MDM robust prediction revenue of assortment [0, 2, 3, 6] is : 0.0901337581813762
# MDM best_case prediction revenue of assortment [0, 2, 3, 6] is : 0.20580506468472487
# MDM robust prediction revenue of assortment [0, 3, 8] is : 0.06694229816512597
# MDM best_case prediction revenue of assortment [0, 3, 8] is : 0.41993216557113544
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.10293869274279348
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.30322874252387993
# testing for offertimes 30, 0th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.10961590176264481
# MDM best_case prediction revenue of assortment [0, 1] is : 0.2687223992394659
# MDM robust prediction revenue of assortment [0, 5] is : 0.1268704018825796
# MDM best_case prediction revenue of assortment [0, 5] is : 0.3030548479415294
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.08374424146158707
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.26872239923946484
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.22083824527187398
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.49804768191434456
# testing for offertimes 30, 1th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.09065353435209608
# MDM best_case prediction revenue of assortment [0, 2] is : 0.2060007800206653
# MDM robust prediction revenue of assortment [0, 6] is : 0.04140948425645217
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1306240967165424
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.12704287378140505
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.27521843316975414
# MDM robust prediction revenue of assortment [0, 8] is : 0.36219674505928745
# MDM best_case prediction revenue of assortment [0, 8] is : 0.7603506442839526
# testing for offertimes 30, 2th instance
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.12313384793586318
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.3361026884649144
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.10408369326953214
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.3728842534050868
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.1279943945649104
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.3628942748505661
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.2357704338970304
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.732421498822481
# testing for offertimes 30, 3th instance
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.08282450389655148
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.3077297026043382
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.27609753701638756
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.945778011462903
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.26255979107576
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.8518886703875417
# MDM robust prediction revenue of assortment [0, 6, 8] is : 0.10116229772899978
# MDM best_case prediction revenue of assortment [0, 6, 8] is : 0.5417819322534096
# testing for offertimes 30, 4th instance
# MDM robust prediction revenue of assortment [0, 1, 3] is : 0.10602941857887076
# MDM best_case prediction revenue of assortment [0, 1, 3] is : 0.4426918661227769
# MDM robust prediction revenue of assortment [0, 3, 4] is : 0.10602941857887076
# MDM best_case prediction revenue of assortment [0, 3, 4] is : 0.6855603667467816
# MDM robust prediction revenue of assortment [0, 3, 7] is : 0.10602941857887076
# MDM best_case prediction revenue of assortment [0, 3, 7] is : 0.26708005503378807
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.2891210583584086
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.6673155884655702
# testing for offertimes 30, 5th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.15706655625597846
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3998203319312952
# MDM robust prediction revenue of assortment [0, 1, 8] is : 0.2545945073328544
# MDM best_case prediction revenue of assortment [0, 1, 8] is : 0.5456722529296205
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.127791972637344
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.6128203749055606
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.12779197263734404
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.2653000606375361
# testing for offertimes 30, 6th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.152760182941752
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.36644286375570523
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.14695923775554656
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.36754562905056715
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.3158552991616563
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.8009013277678174
# MDM robust prediction revenue of assortment [0, 6, 7] is : 0.15276026029852866
# MDM best_case prediction revenue of assortment [0, 6, 7] is : 0.32931870569156985
# testing for offertimes 30, 7th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.02352109093012543
# MDM best_case prediction revenue of assortment [0, 2] is : 0.15255712146470357
# MDM robust prediction revenue of assortment [0, 5] is : 0.09816721940800686
# MDM best_case prediction revenue of assortment [0, 5] is : 0.4159377326389716
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.20283418871036854
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.47909967180892
# MDM robust prediction revenue of assortment [0, 8] is : 0.07329257253119631
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5392310298777809
# testing for offertimes 30, 8th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.020783168747583028
# MDM best_case prediction revenue of assortment [0, 2] is : 0.168078869808418
# MDM robust prediction revenue of assortment [0, 3] is : 0.018085807511055433
# MDM best_case prediction revenue of assortment [0, 3] is : 0.16933699842449668
# MDM robust prediction revenue of assortment [0, 7] is : 0.045714908041306
# MDM best_case prediction revenue of assortment [0, 7] is : 0.28655999194346704
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.25745917945780855
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.3945437570663764
# testing for offertimes 30, 9th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.009401465334694444
# MDM best_case prediction revenue of assortment [0, 3] is : 0.13436370256326788
# MDM robust prediction revenue of assortment [0, 6] is : 0.0910058725138006
# MDM best_case prediction revenue of assortment [0, 6] is : 0.17671457877291635
# MDM robust prediction revenue of assortment [0, 1, 5] is : 0.2525626893992976
# MDM best_case prediction revenue of assortment [0, 1, 5] is : 0.4562525600591611
# MDM robust prediction revenue of assortment [0, 8] is : 0.13975168820203152
# MDM best_case prediction revenue of assortment [0, 8] is : 0.6029975663328273
# testing for offertimes 30, 10th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.19888566971069313
# MDM best_case prediction revenue of assortment [0, 5] is : 0.4028630740078998
# MDM robust prediction revenue of assortment [0, 1, 4] is : 0.2302545964453136
# MDM best_case prediction revenue of assortment [0, 1, 4] is : 0.6279838651782108
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.11277203223130165
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.3349106267424802
# MDM robust prediction revenue of assortment [0, 4, 6] is : 0.11703252763957935
# MDM best_case prediction revenue of assortment [0, 4, 6] is : 0.5737980867215512
# testing for offertimes 30, 11th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.025308036078032586
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3031290696430897
# MDM robust prediction revenue of assortment [0, 2] is : 0.040720282255340516
# MDM best_case prediction revenue of assortment [0, 2] is : 0.14471027277167653
# MDM robust prediction revenue of assortment [0, 4, 5] is : 0.30326273826465205
# MDM best_case prediction revenue of assortment [0, 4, 5] is : 0.7423620591897708
# ...
# MDM best_case prediction revenue of assortment [0, 3] is : 0.1700265682538561
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.1397455366132073
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.47659450446383134
# testing for offertimes 60, 6th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.13236015029252443
# MDM best_case prediction revenue of assortment [0, 5] is : 0.5494662050449994
# MDM robust prediction revenue of assortment [0, 8] is : 0.1587556964811374
# MDM best_case prediction revenue of assortment [0, 8] is : 0.7123403441895141
# testing for offertimes 60, 7th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.042327661818051324
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1585791131014682
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.08162411527173488
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.20968890173143084
# testing for offertimes 60, 8th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.022850105885158036
# MDM best_case prediction revenue of assortment [0, 5] is : 0.4327293709541287
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.11089331369350577
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.24187875536444373
# testing for offertimes 60, 9th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.0
# MDM best_case prediction revenue of assortment [0, 1] is : 0.4025003444403407
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.1328221041216984
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.4271361397961904
# testing for offertimes 60, 10th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.11703252763957935
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.45549258721371755
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.09653949009931546
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.24092753367211125
# testing for offertimes 60, 11th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.0047424369455665106
# MDM best_case prediction revenue of assortment [0, 3] is : 0.12325042549684319
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.30326273826465205
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.7219718994867698
# testing for offertimes 60, 12th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.12558395049248428
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.4263575094647919
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.12086221459174595
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.2872103053452531
# testing for offertimes 60, 13th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.03381501739352575
# MDM best_case prediction revenue of assortment [0, 3] is : 0.12679155811434564
# MDM robust prediction revenue of assortment [0, 8] is : 0.17806189251132803
# MDM best_case prediction revenue of assortment [0, 8] is : 0.7203836481786975
# testing for offertimes 60, 14th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.1377333987632584
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.5519996603415755
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.35501307448546177
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.8759775834367876
# testing for offertimes 60, 15th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.054274829528425016
# MDM best_case prediction revenue of assortment [0, 2] is : 0.17631139007184957
# MDM robust prediction revenue of assortment [0, 5] is : 0.0
# MDM best_case prediction revenue of assortment [0, 5] is : 0.3646431331984346
# testing for offertimes 60, 16th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.05274636822243319
# MDM best_case prediction revenue of assortment [0, 2] is : 0.1814873428607958
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.11772663381606731
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.4375903214246567
# testing for offertimes 60, 17th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.08846773631820637
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3151608659870503
# MDM robust prediction revenue of assortment [0, 3] is : 0.03811420976814821
# MDM best_case prediction revenue of assortment [0, 3] is : 0.12679155811434564
# testing for offertimes 60, 18th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.12534586213121945
# MDM best_case prediction revenue of assortment [0, 1] is : 0.4306887053045623
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.1005064068244804
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.19441077803971146
# testing for offertimes 60, 19th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.07003935738912656
# MDM best_case prediction revenue of assortment [0, 6] is : 0.19654559574572317
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.09948014210406808
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.3745137762207693
# testing for offertimes 60, 20th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.014155420860493312
# MDM best_case prediction revenue of assortment [0, 2] is : 0.19850937475210287
# MDM robust prediction revenue of assortment [0, 3] is : 0.027059794659306746
# MDM best_case prediction revenue of assortment [0, 3] is : 0.17698483007467145
# testing for offertimes 60, 21th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.07928786195671747
# MDM best_case prediction revenue of assortment [0, 5] is : 0.4224492907401148
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.11410006341426533
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.40173909234528776
# testing for offertimes 60, 22th instance
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.11079259216890124
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.26064675528437536
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.09591742522708775
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.19104048603421198
# testing for offertimes 60, 23th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.21313726724345894
# MDM best_case prediction revenue of assortment [0, 1] is : 0.5307861057141406
# MDM robust prediction revenue of assortment [0, 2] is : 0.08096148034115719
# MDM best_case prediction revenue of assortment [0, 2] is : 0.18908183894525268
# testing for offertimes 60, 24th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.20556632033282687
# MDM best_case prediction revenue of assortment [0, 1] is : 0.5307861057141406
# MDM robust prediction revenue of assortment [0, 8] is : 0.11494121810152362
# MDM best_case prediction revenue of assortment [0, 8] is : 0.6962027818778086
# testing for offertimes 60, 25th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.027339405984219394
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1606086392569342
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.12720326456577521
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.4195726758811609
# testing for offertimes 60, 26th instance
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.1095754897293574
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.34044850358996054
# MDM robust prediction revenue of assortment [0, 8] is : 0.16515894904946674
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5222807484156932
# testing for offertimes 60, 27th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.017571419727830752
# MDM best_case prediction revenue of assortment [0, 3] is : 0.16652325088665546
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.1376586962959668
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.43992434057853813
# testing for offertimes 60, 28th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.03448482765762155
# MDM best_case prediction revenue of assortment [0, 1] is : 0.35453731654094695
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.1066937034185765
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.24808258694706692
# testing for offertimes 60, 29th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.0
# MDM best_case prediction revenue of assortment [0, 5] is : 0.36985976674944676
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.09605902615862837
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.36985976674944676
# testing for offertimes 60, 30th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.008782096402680207
# MDM best_case prediction revenue of assortment [0, 3] is : 0.19411170663562954
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.1310524936800573
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.3237105421687434
# testing for offertimes 60, 31th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.0
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3837063672600068
# MDM robust prediction revenue of assortment [0, 5] is : 0.18323452933821158
# MDM best_case prediction revenue of assortment [0, 5] is : 0.4547609482333646
# testing for offertimes 60, 32th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.014155420860493312
# MDM best_case prediction revenue of assortment [0, 2] is : 0.19850937475210273
# MDM robust prediction revenue of assortment [0, 8] is : 0.1587556964811374
# MDM best_case prediction revenue of assortment [0, 8] is : 0.6391694934712859
# testing for offertimes 60, 33th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.13421702482503853
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.5235999213536751
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.11489945750262398
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.3996260137758966
# testing for offertimes 60, 34th instance
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.12797506597771566
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.2982578847833466
# MDM robust prediction revenue of assortment [0, 8] is : 0.029623391104949177
# MDM best_case prediction revenue of assortment [0, 8] is : 0.7157797996049838
# testing for offertimes 60, 35th instance
# MDM robust prediction revenue of assortment [0, 3] is : 0.0345277424666933
# MDM best_case prediction revenue of assortment [0, 3] is : 0.13786388662382132
# MDM robust prediction revenue of assortment [0, 6] is : 0.03665539740527127
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1343621185745434
# testing for offertimes 60, 36th instance
# revenue prediction for unseen assortment [0, 2, 6]
# the robust revenue for assortment [0, 2, 6] is 0.1483993636092447 with runtime 0.0006678104400634766
# the best-case revenue for assortment [0, 2, 6] is 0.20664143920595532 with runtime 0.0005397796630859375
#
# revenue prediction for unseen assortment [0, 5, 6]
# the robust revenue for assortment [0, 5, 6] is 0.2529899088940638 with runtime 0.0007421970367431641
# the best-case revenue for assortment [0, 5, 6] is 0.34334341060139406 with runtime 0.0005586147308349609
#
# testing for offertimes 60, 37th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.05867394888634434
# MDM best_case prediction revenue of assortment [0, 1] is : 0.4306887053045622
# MDM robust prediction revenue of assortment [0, 6] is : 0.05801138781134343
# MDM best_case prediction revenue of assortment [0, 6] is : 0.17871223045065562
# testing for offertimes 60, 38th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.030542333965656226
# MDM best_case prediction revenue of assortment [0, 2] is : 0.16377396903756916
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.24015356924533346
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.69430151786013
# testing for offertimes 60, 39th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.0
# MDM best_case prediction revenue of assortment [0, 5] is : 0.43246247632912244
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.22978761305443474
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.6521777286981159
# testing for offertimes 60, 40th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.00913497134027699
# MDM best_case prediction revenue of assortment [0, 2] is : 0.17575970863426107
# MDM robust prediction revenue of assortment [0, 6] is : 0.0791712296189151
# MDM best_case prediction revenue of assortment [0, 6] is : 0.18269759186982426
# testing for offertimes 60, 41th instance
# MDM robust prediction revenue of assortment [0, 1] is : 0.03448482765762155
# MDM best_case prediction revenue of assortment [0, 1] is : 0.3032188333039837
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.18379804372454425
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.49760780022539747
# testing for offertimes 60, 42th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.03926703269741104
# MDM best_case prediction revenue of assortment [0, 6] is : 0.15246756147338156
# MDM robust prediction revenue of assortment [0, 8] is : 0.07329257253119648
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5978787583598686
# testing for offertimes 60, 43th instance
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.12519694599015882
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.2780634865598056
# MDM robust prediction revenue of assortment [0, 8] is : 0.23754936426981094
# MDM best_case prediction revenue of assortment [0, 8] is : 0.5895623196006661
# testing for offertimes 60, 44th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.038803518625831014
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1651317289162303
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.05511180516735494
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.2911047112447044
# testing for offertimes 60, 45th instance
# MDM robust prediction revenue of assortment [0, 2] is : 0.02770586520991994
# MDM best_case prediction revenue of assortment [0, 2] is : 0.13282208254292954
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.07167386162832547
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.15325730216189182
# testing for offertimes 60, 46th instance
# MDM robust prediction revenue of assortment [0, 6] is : 0.031639371066410744
# MDM best_case prediction revenue of assortment [0, 6] is : 0.1525226520194564
# MDM robust prediction revenue of assortment [0, 5, 8] is : 0.3158552991616563
# MDM best_case prediction revenue of assortment [0, 5, 8] is : 0.9923565619692263
# testing for offertimes 60, 47th instance
# MDM robust prediction revenue of assortment [0, 1, 6] is : 0.12470463249262152
# MDM best_case prediction revenue of assortment [0, 1, 6] is : 0.4120155926191105
# MDM robust prediction revenue of assortment [0, 8] is : 0.12108283019912391
# MDM best_case prediction revenue of assortment [0, 8] is : 0.6799962826810418
# testing for offertimes 60, 48th instance
# MDM robust prediction revenue of assortment [0, 3, 6] is : 0.08376411771146251
# MDM best_case prediction revenue of assortment [0, 3, 6] is : 0.18195578269167767
# MDM robust prediction revenue of assortment [0, 5, 6] is : 0.112349854810595
# MDM best_case prediction revenue of assortment [0, 5, 6] is : 0.4461264119671373
# testing for offertimes 60, 49th instance
# MDM robust prediction revenue of assortment [0, 5] is : 0.2041386396321761
# MDM best_case prediction revenue of assortment [0, 5] is : 0.46117586223027973
# MDM robust prediction revenue of assortment [0, 2, 6] is : 0.09902962846142159
# MDM best_case prediction revenue of assortment [0, 2, 6] is : 0.2423153811956942

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mdm_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i]-len(all_infeasible_collection[i]))),'mdm_lb_dist':all_mdm_lb_distance_list[i],'mdm_ub_dist':all_mdm_ub_distance_list[i],
                                    'true_best_rev':all_best_true_revenue_list[i],'mdm_lb_best_rev':all_best_revenue_mdm_lb[i],'mdm_ub_best_rev':all_best_revenue_mdm_ub[i],
                                    'mdm_lb_best_rev_diff':all_mdm_lb_best_rev_diff[i],'mdm_ub_best_rev_diff':all_mdm_ub_best_rev_diff[i]})
    df_mdm_details1.to_csv('prediction/mdm/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]-sum(all_infeasible_collection[i])):
        
        true_rank = all_true_ranking[i][j]
        lb_rank = all_mdm_lb_ranking[i][j]
        ub_rank = all_mdm_ub_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'lb_rank':lb_rank,'ub_rank':ub_rank})
        df_rank.to_csv('prediction/mdm/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        lb_rev = all_mdm_lb_revenue_list[i][j]
        ub_rev = all_mdm_ub_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'lb_rev':lb_rev,'ub_rev':ub_rev})
        df_rev.to_csv('prediction/mdm/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ''' true_prob = all_true_choice_prob_list[i][j]
        lb_prob = all_mdm_lb_rev_prob_list[i][j]
        ub_prob = all_mdm_ub_rev_prob_list[i][j]
        
        df_true_prob = pd.DataFrame(true_prob).T
        df_lb_prob = pd.DataFrame(lb_prob).T
        df_ub_prob = pd.DataFrame(ub_prob).T
        
        df_true_prob.to_csv('prediction/mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_prob.to_csv('prediction/mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/mdm_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_ub_prob.to_csv('prediction/mdm/revenue_prediction/details2/probabilities/offertimes'+str(pred_offer_times_list[i])+'/mdm_ub/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''
        lb_runtime = all_mdm_rev_lb_runtime[i][j]
        ub_runtime = all_mdm_rev_ub_runtime[i][j]
        df_runtime = pd.DataFrame({'lb_runtime':lb_runtime,'ub_runtime':ub_runtime})
        df_runtime.to_csv('prediction/mdm/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        
        ## using sales fraction prediction
        ## record the choice probability prediction interval
        ''' lb_sales = all_mdm_lb_sales_list[i][j]
        ub_sales = all_mdm_ub_sales_list[i][j]
        df_lb_sales = pd.DataFrame(lb_sales).T
        df_ub_sales = pd.DataFrame(ub_sales).T
        
        df_true_prob.to_csv('prediction/mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lb_sales.to_csv('prediction/mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mdm_lb/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_ub_sales.to_csv('prediction/mdm/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mdm_ub/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## adding details 2 about runtime 
all_lb_avg_runtime = []
all_ub_avg_runtime =[]

for i in range(len(pred_offer_times_list)):
    
    avg_lb_runtime_collection = []
    avg_ub_runtime_collection = []
    
    for j in range(pred_instance_size[i]-len(all_infeasible_collection[i])):
        avg_lb_runtime_collection.append(np.mean(np.array(all_mdm_rev_lb_runtime[i][j])))
        avg_ub_runtime_collection.append(np.mean(np.array(all_mdm_rev_ub_runtime[i][j])))
    
    all_lb_avg_runtime.append(np.mean(np.array(avg_lb_runtime_collection)))
    all_ub_avg_runtime.append(np.mean(np.array(avg_ub_runtime_collection)))

avg_mdm_lb_dist = []
avg_mdm_ub_dist = []

avg_mdm_lb_best_rev_diff = []
avg_mdm_ub_best_rev_diff = []

avg_infeasible_prop = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_lb_dist.append(np.mean(all_mdm_lb_distance_list[i]))
    avg_mdm_ub_dist.append(np.mean(all_mdm_ub_distance_list[i]))
    
    avg_mdm_lb_best_rev_diff.append(np.mean(all_mdm_lb_best_rev_diff[i]))
    avg_mdm_ub_best_rev_diff.append(np.mean(all_mdm_ub_best_rev_diff[i]))
    
    avg_infeasible_prop.append(sum(all_infeasible_collection[i])/pred_instance_size[i])

df_mdm_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'train_size':pred_train_collection_size,'test_size':pred_test_collection_size,
                                  'infeas_prop':avg_infeasible_prop,
                                   'avg_lb_dist':avg_mdm_lb_dist,'avg_ub_dist':avg_mdm_ub_dist,
                                   'avg_lb_best_rev_diff':avg_mdm_lb_best_rev_diff,'avg_ub_best_rev_diff':avg_mdm_ub_best_rev_diff,
                                   'avg_lb_runtime':all_lb_avg_runtime,'avg_ub_runtime':all_ub_avg_runtime})
df_mdm_jd_summary.to_csv('prediction/mdm/jd_mdm_summary.csv')

# %%
df_mdm_jd_summary
# Out:
#    offertimes  train_size  test_size  infeas_prop  avg_lb_dist  avg_ub_dist  \
# 0          20          24          5         0.06      2.93617     1.914894
# 1          30          20          4         0.00      1.42000     0.920000
# 2          40          16          3         0.00      0.78000     0.460000
# 3          50          12          3         0.00      0.84000     0.220000
# 4          60          11          2         0.00      0.18000     0.060000
#
#    avg_lb_best_rev_diff  avg_ub_best_rev_diff  avg_lb_runtime  avg_ub_runtime
# 0              0.093054              0.070904        0.259867        0.311523
# 1              0.105559              0.058304        0.140805        0.161980
# 2              0.095387              0.070954        0.066352        0.069073
# 3              0.089414              0.023435        0.030245        0.029565
# 4              0.070209              0.011262        0.020935        0.022002
