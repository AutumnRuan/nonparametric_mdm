# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def generate_negatively_correlated_covariance_matrix(n):
    # Generate a random correlation matrix with negative correlations
    correlation_matrix = np.random.uniform(low=-0.9, high=-0.1, size=(n, n))
    np.fill_diagonal(correlation_matrix, 1)  # Set diagonal elements to 1
    correlation_matrix = (correlation_matrix + correlation_matrix.T) / 2  # Ensure symmetry

    # Ensure the correlation matrix is valid for Cholesky decomposition
    cholesky_success = False
    while not cholesky_success:
        try:
            # Perform Cholesky decomposition
            cholesky_matrix = np.linalg.cholesky(correlation_matrix)
            cholesky_success = True
        except np.linalg.LinAlgError:
            # If Cholesky decomposition fails, adjust the correlation matrix slightly
            correlation_matrix += np.eye(n) * 0.01  # Adjust diagonal elements slightly

    # Generate random standard deviations
    #standard_deviations = np.random.uniform(0.5, 2, size=n)
    
    variance_outsideopt = np.random.uniform(30,40)
    variance_products = np.random.uniform(0.5,2,size=n-1)
    
    ''' variance_outsideopt = np.random.uniform(0.5,2)
    variance_products = np.random.uniform(30,40,size=n-1) '''
    
    standard_deviations = np.hstack((variance_outsideopt,variance_products))
    # Construct diagonal matrix from standard deviations
    diagonal_matrix = np.diag(standard_deviations)
    #diagonal_matrix = np.eye(n)

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix

# %%
''' def generate_negatively_correlated_covariance_matrix(n):

    # Define a diagonal matrix D with non-negative entries (eigenvalues)
    #variance_outsideopt = [np.random.uniform(30,40)]
    variance_products = np.random.uniform(0.5,40,size=n).tolist()
    
    diagonal_matrix = np.diag(variance_products)

    # Generate a random orthogonal matrix Q using QR decomposition
    cholesky_matrix, _ = np.linalg.qr(np.random.randn(n, n))

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix
 '''
# Out:
# ' def generate_negatively_correlated_covariance_matrix(n):\n\n    # Define a diagonal matrix D with non-negative entries (eigenvalues)\n    #variance_outsideopt = [np.random.uniform(30,40)]\n    variance_products = np.random.uniform(0.5,40,size=n).tolist()\n    \n    diagonal_matrix = np.diag(variance_products)\n\n    # Generate a random orthogonal matrix Q using QR decomposition\n    cholesky_matrix, _ = np.linalg.qr(np.random.randn(n, n))\n\n    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix\n    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T\n\n    return covariance_matrix\n '

# %%
def is_positive_semidefinite(matrix):
    """
    Check if a matrix is positive semidefinite.
    
    Args:
        matrix (numpy.ndarray): The matrix to check.
        
    Returns:
        bool: True if the matrix is positive semidefinite, False otherwise.
    """
    # Check if the matrix is symmetric
    if not np.allclose(matrix, matrix.T):
        return False
    
    # Check if all eigenvalues are non-negative
    eigvals, _ = np.linalg.eig(matrix)
    return np.all(eigvals >= 0)

# %%
def collection_distribution_prob_neg(n,collection):
    # generate mean 
    mu_0 = np.random.uniform(6,10)
    mu_1n = np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    # generate covariance matrix with positive correlation
    neg_cov = generate_negatively_correlated_covariance_matrix(n)
    if is_positive_semidefinite(neg_cov): 
        sample_size = 10000
        utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    else:
        print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 
        
        
        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
def whole_instance_generation(n,whole_collection,whole_offertimes):
    ## generate LCMNL instances based on the assortment collection infomation
    # step 1: randomly generate LCMNL parameters
    # 1.1 the number of classes in LCMNL, the number of classes is between 10 and 15, both endpoints are included
    ''' num_classes = 20
    # 1.2 randomly generate weights of all classes 
    #weight_pre = np.random.exponential(1, num_classes)
    weights = np.array([1/ num_classes for _ in range(num_classes)])
    # 1.3 randomly generate parameters of each mnl
    parameters_v = np.random.uniform(-30, 30, size=(num_classes,n)) '''
    ''' parameters_v = np.zeros((num_classes,n))
    for i in range(num_classes):
        parameters_v[i] = np.random.exponential(1, n) '''
    #np.random.uniform(-30, 30, size=(num_classes,n))
    # step 2: generate LCMNL instance with the above parameters of LCMNL
    true_lcmnl_instance = collection_distribution_prob_neg(n,whole_collection)
    # step 3: generate multinomial samples based on lcmnl instance and the emprical assortment offertimes
    purchased_samples = []
    for i in range(len(whole_collection)):
        sample_i = np.random.multinomial(whole_offertimes[i], true_lcmnl_instance[:,i])
        purchased_samples.append(sample_i)
    # step 4: compute the simulated collection probabilities
    whole_choice_collection = np.zeros((n,len(whole_collection)))
    for i in range(len(whole_collection)):
        whole_choice_collection[:,i] = np.array([k/np.sum(purchased_samples[i]) for k in purchased_samples[i]])
        
    return whole_choice_collection,purchased_samples

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [50,50,50,50,50]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
# check if the collection are nested
def check_subsets(lists):
    # Convert all lists to sets
    sets = [set(lst) for lst in lists]
    
    # Check subsets
    for i in range(len(sets) - 1):
        if not sets[i + 1].issubset(sets[i]):
            return False
    return True

# Check and print the result
result = check_subsets(all_full_assortment_index)
print("All subsequent lists are subsets of the previous one:", result)
# Out:
# All subsequent lists are subsets of the previous one: True

# %%
def filter_probability_frequency2(whole_choice_collection,purchase_samples,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    frequency_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
        frequency_collection[:,i] = purchase_samples[assortment_index[i]]
        
    return choice_collection,frequency_collection

# %%
# generate instances that satisfy for assortment offertimes is >=20
## generate 50 random full instances 
# the observations with at least 20 times are >= 1e-3
pred_full_instance = []
pred_full_samples = []
#collection_20,offertimes_20,assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[0])

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    curr_whole_instance,curr_purchase_samples = whole_instance_generation(n,jd_collection,jd_offertimes)
    # filter choice probability and purchase frequency of each produt in each assortment
    curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

    pred_full_instance.append(curr_whole_instance)
    pred_full_samples.append(curr_purchase_samples)
    
    ''' condition = False
    for x in range(len(all_full_collections[0])):
        for y in all_full_collections[0][x]:
            if curr_choice_collection[y][x]<1e-11:
                condition = True
    while condition:
        curr_whole_instance,curr_purchase_samples = whole_instance_generation(jd_collection,jd_offertimes)
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(curr_whole_instance,curr_purchase_samples,all_full_assortment_index[0])

        condition = False
        for x in range(len(all_full_collections[0])):
            for y in all_full_collections[0][x]:
                if curr_choice_collection[y][x] < 1e-11:
                    condition = True
    if condition == True:
        print('instance_generation error')
    else:

            
        pred_full_instance.append(curr_whole_instance)
        pred_full_samples.append(curr_purchase_samples) '''
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance

# %%
def compute_lb_ub_w_ci(frequency_collection,choice_collection,target_z_score):
    
    stardard_error = np.zeros(frequency_collection.shape)
    for i in range(stardard_error.shape[0]):
        for j in range(stardard_error.shape[1]):
            if frequency_collection[i][j]!=0:
                stardard_error[i][j] = np.sqrt((1-choice_collection[i][j])/frequency_collection[i][j])
                
    lb = np.zeros(frequency_collection.shape)
    ub = np.zeros(frequency_collection.shape)
    for i in range(lb.shape[0]):
        for j in range(lb.shape[1]):
            if frequency_collection[i][j]!=0:
                lb[i][j] = choice_collection[i][j] * (1-target_z_score*stardard_error[i][j]) 
                ub[i][j] = choice_collection[i][j] * (1+target_z_score*stardard_error[i][j])
    
    return lb,ub

# %%
# full instance generation 
all_full_instances = []
all_full_lb = []
all_full_ub = []

# pre-determined confidence interval 
confidence_level = 0.995
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)  

for i in range(len(pred_offer_times_list)):
    
    full_instances = []
    full_lbs = []
    full_ubs = []
    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection,curr_frequency = filter_probability_frequency2(pred_full_instance[j],pred_full_samples[j],all_full_assortment_index[i])
        # re-check if all choice probability are >= 1e-3
        ''' condition = False
        for x in range(len(all_full_collections[i])):
            for y in all_full_collections[i][x]:
                if curr_choice_collection[y][x] < 1e-11:
                    condition = True
        if condition == True:
            print('instance_generation error') '''
        
        # compute the collection of lower bound and upper bound l_ij and u_ij
        curr_lb,curr_ub = compute_lb_ub_w_ci(curr_frequency,curr_choice_collection,target_z_score)
        
        full_instances.append(curr_choice_collection)
        full_lbs.append(curr_lb)
        full_ubs.append(curr_ub)
    
    all_full_instances.append(full_instances)
    all_full_lb.append(full_lbs)
    all_full_ub.append(full_ubs)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
# train-test split
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(all_full_collections[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(all_full_collections[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(all_full_collections[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = all_full_instances[i][j][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = all_full_lb[i][j][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = all_full_ub[i][j][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(all_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(all_full_collections[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = all_full_instances[i][j][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ''' ## output the training and testing instance
        df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
def mnl_feasibility(data,collection,n):
    
    # MNL cannot reproduce zero probability 
    start_time = time.time()
    for i in range(len(collection)):
        for j in collection[i]:
            if data[j][i] == 0:
                return [0,time.time()-start_time]
    
           
    actual_prod = np.unique(np.nonzero(data)[0]).tolist()
    model = gp.Model('mnl')
    model.setParam('OutputFlag', 0)
    v = model.addVars(n,name = 'v') # positive 
  
    for ass_idx in range(len(collection)):
        for i in collection[ass_idx]:
            model.addConstr(data[i][ass_idx]*sum(v[j] for j in collection[ass_idx])-v[i]==0)
    
    model.addConstrs(v[i]>=0 for i in range(n))
    model.addConstrs(v[i]<=100 for i in range(n))
    #model.setObjective(0,GRB.MAXIMIZE)
    model.setObjective(sum(v[i] for i in actual_prod),GRB.MAXIMIZE)
    model.optimize()
        
    if model.Status == 2: #optimal
        soln = []
        for v in model.getVars():
            soln.append(v.x)
        
        for i in actual_prod:
            if soln[i] == 0:
                return [0,model.Runtime]
        if sum(soln) >0:
            return [1,model.Runtime]

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.opt import SolverFactory

def mnl_mle_pyo(data, collection,offertimes):
    n = data.shape[0]
    model = pyo.ConcreteModel()
    model.v = pyo.Var(range(n), bounds=(-100, 100))
    
    def obj_rule(model):
        obj = 0
        for i in range(len(collection)):
            for j in collection[i]:
                obj += offertimes[i]*data[j][i] * model.v[j]
            obj -= offertimes[i]*pyo.log(sum([pyo.exp(model.v[k]) for k in collection[i]]))
        return obj
    
    model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)
    
    # scale the preference of the outside option to be 1
    model.outsideopt_constraint = pyo.Constraint(expr=model.v[0] == 0)
    
    opt = pyo.SolverFactory('ipopt')  # use iterior point method to solve convex optimizatio problem 
    results = opt.solve(model)
    
    if (results.solver.status == pyo.SolverStatus.ok) and (results.solver.termination_condition == pyo.TerminationCondition.optimal):
        v_values = [model.v[i].value for i in range(n)]
        obj_value = model.obj()
        #model.pprint()
        return v_values, obj_value,results.solver.time
    else:
        raise ValueError("Solver failed to find an optimal solution.")

# %%
def mnl_distribution(v, collection):
    collection_distribution = np.zeros((len(v), len(collection)))
    for i, curr_collection in enumerate(collection):
        curr_total_v = np.sum([np.exp(v[j]) for j in curr_collection])
        for k, idx in enumerate(curr_collection):
            collection_distribution[idx][i] = np.exp(v[idx]) / curr_total_v
    
    return collection_distribution

# %%
## prediction for the current testing collection of assortments 
def mnl_prediction(curr_test_instance,curr_test_collection,price,v_values):
    ''' true assortment ranking '''
    true_choice_prob = [] 
    true_revenue = []
    
    mnl_revenue = []
    mnl_sales = []
    
    mnl_runtime = []
    
    
    # mle estimate
    start_time = time.time()
    estimated_oos_prob = mnl_distribution(v_values,curr_test_collection)
    used_t_1 = time.time() - start_time
    
    for k in range(len(curr_test_collection)):

        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        true_choice_prob.append(curr_test_instance[:,k])
        
        st_time_2 = time.time()
        curr_mnl_rev = np.dot(estimated_oos_prob[:,k],price)
        used_t_2 = time.time() - st_time_2
        
        mnl_sales.append(estimated_oos_prob[:,k])
        mnl_revenue.append(curr_mnl_rev)
        print(f'revenue of assortment {curr_test_collection[k]} is {curr_mnl_rev}')
        
        ## record the runtime result
        mnl_runtime.append(used_t_1+used_t_2)
        
    return true_revenue,true_choice_prob,mnl_revenue,mnl_sales,mnl_runtime

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record representability of all instances

## record the kendall tau distance between the predicted ranking of mnl and the truth
all_mnl_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_rev_list = []
all_best_rev_mnl_list = []  

## record the difference in best assortment
all_mnl_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mnl_revenue_list = []

all_true_prob_list = [] 
all_mnl_sales_list = []

all_true_ranking = []
all_mnl_ranking = []

## record the runtime of mnl prediction
all_mnl_pred_runtime = []

for i in range(len(all_full_collections)):
       
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mnl_best_rev_collection = [] # a container for the best revenue predicted by robust mnl
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mnl_ranking_collection = [] # a container for ranking by robust mnl
    
    mnl_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mnl
   
    
    true_choice_prob_collection = []
    mnl_sales_frac_collection = []

    true_revenue_collection = []
    mnl_revenue_collection = []
    
    mnl_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        ## mle 
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        
        v_values,ll_value,ll_time = mnl_mle_pyo(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
        ########### mnl prediction#################
        # mnl_prediction(curr_test_instance,curr_test_collection,price,v_values)
        true_revenue,true_choice_prob,mnl_revenue,mnl_sales,mnl_runtime = mnl_prediction(all_test_instance[i][j],all_test_collection[i][j],price,v_values)
        # the following lists are of the same size as number of testing assortments
        
        for x in range(len(mnl_runtime)):
            mnl_runtime[x] = mnl_runtime[x] + ll_time
        
        true_revenue_collection.append(true_revenue)
        true_choice_prob_collection.append(true_choice_prob)
        
        mnl_revenue_collection.append(mnl_revenue)   
        mnl_sales_frac_collection.append(mnl_sales)
        mnl_runtime_collection.append(mnl_runtime)
         
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_mnl_rank  = np.argsort(-np.array(mnl_revenue)) 
        mnl_ranking_collection.append(curr_mnl_rank)
        mnl_best_rev_collection.append(true_revenue[curr_mnl_rank[0]])
        if true_revenue[curr_mnl_rank[0]]==0 or np.isnan(true_revenue[curr_mnl_rank[0]]):
            print('error in instance {i} {j}')
        
        #  mnl kendallTau Distance for current instance [i][j]
        curr_mnl_dist = kendall_tau_distance(curr_true_rank, curr_mnl_rank)
        mnl_distance_collection.append(curr_mnl_dist)
    
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mnl_distance_list.append(mnl_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_rev_list.append(true_best_rev_collection) 
    all_best_rev_mnl_list.append(mnl_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    with np.errstate(divide='ignore', invalid='ignore'):
        result = (np.array(true_best_rev_collection) - np.array(mnl_best_rev_collection))/ np.array(true_best_rev_collection)
        # Replace NaN values (0/0) with 0 values with a large number or zero
        result = np.where(np.isnan(result), 0.0, result)
        

    all_mnl_best_rev_diff.append(result)
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    
    all_mnl_revenue_list.append(mnl_revenue_collection)
    
    all_true_prob_list.append(true_choice_prob_collection)
    all_mnl_sales_list.append(mnl_sales_frac_collection)
 
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mnl_ranking.append(mnl_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mnl_pred_runtime.append(mnl_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# revenue of assortment [0, 5] is 0.2400570114887312
# revenue of assortment [0, 3, 7] is 0.192504635492129
# revenue of assortment [0, 5, 6] is 0.28352811181390547
# revenue of assortment [0, 5, 8] is 0.4790457761337872
# revenue of assortment [0, 6, 8] is 0.36470725004946186
# testing for offertimes 20, 1th instance
# revenue of assortment [0, 3] is 0.11419706775560658
# revenue of assortment [0, 4] is 0.10901142982763345
# revenue of assortment [0, 1, 4] is 0.34867620499108853
# revenue of assortment [0, 3, 4] is 0.18745924968706296
# revenue of assortment [0, 5, 6] is 0.35573923563633914
# testing for offertimes 20, 2th instance
# revenue of assortment [0, 1, 8] is 0.6145951785850067
# revenue of assortment [0, 2, 6] is 0.21064777267552084
# revenue of assortment [0, 3, 4] is 0.4983024110919462
# revenue of assortment [0, 4, 5] is 0.6559020904922872
# revenue of assortment [0, 5, 8] is 0.6502905015873532
# testing for offertimes 20, 3th instance
# revenue of assortment [0, 1] is 0.1595822948310781
# revenue of assortment [0, 4] is 0.42679248698597555
# revenue of assortment [0, 7] is 0.12626211838498777
# revenue of assortment [0, 3, 4] is 0.4207085472209848
# revenue of assortment [0, 8] is 0.3458293319367949
# testing for offertimes 20, 4th instance
# revenue of assortment [0, 1, 8] is 0.5710645899916937
# revenue of assortment [0, 2, 3, 6] is 0.2326662903610901
# revenue of assortment [0, 3, 8] is 0.4276177774841541
# revenue of assortment [0, 5, 6] is 0.26630202894782884
# revenue of assortment [0, 6, 7] is 0.21840770737267046
# testing for offertimes 20, 5th instance
# revenue of assortment [0, 1] is 0.26300500739984545
# revenue of assortment [0, 1, 4] is 0.5500022152587831
# revenue of assortment [0, 2, 6] is 0.22677141572962486
# revenue of assortment [0, 4, 7] is 0.4801770119815968
# revenue of assortment [0, 5, 6] is 0.36651686148308293
# testing for offertimes 20, 6th instance
# revenue of assortment [0, 4] is 0.4579937467395208
# revenue of assortment [0, 1, 3] is 0.2655866105057636
# revenue of assortment [0, 3, 7] is 0.23840683678592864
# revenue of assortment [0, 4, 8] is 0.7250568163750999
# revenue of assortment [0, 5, 8] is 0.6392321849174996
# testing for offertimes 20, 7th instance
# revenue of assortment [0, 1] is 0.13302733629973276
# revenue of assortment [0, 1, 6] is 0.20405060556487203
# revenue of assortment [0, 3, 6] is 0.16554797352410433
# revenue of assortment [0, 4, 5] is 0.5252463559330377
# revenue of assortment [0, 8] is 0.23904904424497467
# testing for offertimes 20, 8th instance
# revenue of assortment [0, 1] is 0.20320533189612694
# revenue of assortment [0, 7] is 0.13876973478323004
# revenue of assortment [0, 1, 8] is 0.4713762045393057
# revenue of assortment [0, 4, 6] is 0.40579378422996687
# revenue of assortment [0, 8] is 0.366483009675
# testing for offertimes 20, 9th instance
# revenue of assortment [0, 1] is 0.18439315349439775
# revenue of assortment [0, 1, 3] is 0.22318835336752355
# revenue of assortment [0, 2, 3, 6] is 0.2132595607446023
# revenue of assortment [0, 3, 5] is 0.3174714387807222
# revenue of assortment [0, 4, 8] is 0.6598445109118667
# testing for offertimes 20, 10th instance
# revenue of assortment [0, 1, 3] is 0.2796008695872706
# revenue of assortment [0, 2, 6] is 0.1969871804173379
# revenue of assortment [0, 3, 4] is 0.4093814952793544
# revenue of assortment [0, 3, 6] is 0.17348386814524014
# revenue of assortment [0, 5, 6] is 0.3395299117382977
# testing for offertimes 20, 11th instance
# revenue of assortment [0, 1, 3] is 0.22677969322614522
# revenue of assortment [0, 1, 7] is 0.29391570819835067
# revenue of assortment [0, 2, 6] is 0.1549760748827181
# revenue of assortment [0, 4, 6] is 0.46958430332138984
# revenue of assortment [0, 5, 6] is 0.34829468369971217
# testing for offertimes 20, 12th instance
# revenue of assortment [0, 1] is 0.17381818174930164
# revenue of assortment [0, 1, 5] is 0.41745022992999836
# revenue of assortment [0, 2, 3, 6] is 0.25578524020636095
# revenue of assortment [0, 3, 6] is 0.20941574291554793
# revenue of assortment [0, 6, 7] is 0.2663234726922399
# testing for offertimes 20, 13th instance
# revenue of assortment [0, 4] is 0.3913856706365087
# revenue of assortment [0, 6] is 0.05306825396788138
# revenue of assortment [0, 4, 5] is 0.5827921658531197
# revenue of assortment [0, 4, 8] is 0.6569335485557464
# revenue of assortment [0, 6, 8] is 0.4394363580586991
# testing for offertimes 20, 14th instance
# revenue of assortment [0, 4] is 0.17996079842546134
# revenue of assortment [0, 1, 5] is 0.5429543752618534
# revenue of assortment [0, 1, 6] is 0.37206992283657686
# revenue of assortment [0, 4, 8] is 0.4576602766669331
# revenue of assortment [0, 8] is 0.34462089326614787
# testing for offertimes 20, 15th instance
# revenue of assortment [0, 2, 3, 6] is 0.2096139128812678
# revenue of assortment [0, 3, 5] is 0.24514243898830784
# revenue of assortment [0, 4, 7] is 0.5811227673657351
# revenue of assortment [0, 4, 8] is 0.7772205095852193
# revenue of assortment [0, 6, 7] is 0.255934796567428
# testing for offertimes 20, 16th instance
# revenue of assortment [0, 7] is 0.16174729085210354
# revenue of assortment [0, 1, 5] is 0.4885315058868416
# revenue of assortment [0, 3, 7] is 0.21010094047109923
# revenue of assortment [0, 4, 6] is 0.4173425947343715
# revenue of assortment [0, 8] is 0.3146906949708784
# testing for offertimes 20, 17th instance
# revenue of assortment [0, 1, 8] is 0.40190749081209987
# revenue of assortment [0, 3, 4] is 0.4531774759904822
# revenue of assortment [0, 3, 5] is 0.2986236870738227
# revenue of assortment [0, 3, 7] is 0.22410191548993932
# revenue of assortment [0, 6, 8] is 0.2950427533251542
# testing for offertimes 20, 18th instance
# revenue of assortment [0, 2] is 0.10103030005445178
# revenue of assortment [0, 1, 3] is 0.33208341121883767
# revenue of assortment [0, 3, 4] is 0.3851233923442632
# revenue of assortment [0, 4, 8] is 0.5989455303679772
# revenue of assortment [0, 6, 8] is 0.37815793404145126
# testing for offertimes 20, 19th instance
# revenue of assortment [0, 6] is 0.12291349066101463
# revenue of assortment [0, 1, 8] is 0.5117208051490241
# revenue of assortment [0, 2, 3, 6] is 0.2097278167434787
# revenue of assortment [0, 4, 6] is 0.3306834362303069
# revenue of assortment [0, 5, 8] is 0.5280561310586035
# testing for offertimes 20, 20th instance
# revenue of assortment [0, 1, 7] is 0.31103468896028863
# revenue of assortment [0, 3, 6] is 0.20655388009301223
# revenue of assortment [0, 4, 7] is 0.539002416269652
# revenue of assortment [0, 5, 6] is 0.31915424511182516
# revenue of assortment [0, 8] is 0.26884080279157735
# testing for offertimes 20, 21th instance
# revenue of assortment [0, 3] is 0.09598258575893968
# revenue of assortment [0, 1, 7] is 0.3077170747980088
# revenue of assortment [0, 2, 6] is 0.17556298563467812
# revenue of assortment [0, 4, 6] is 0.3634339151989776
# revenue of assortment [0, 4, 8] is 0.5654715073575532
# testing for offertimes 20, 22th instance
# revenue of assortment [0, 4] is 0.2594523733961074
# revenue of assortment [0, 6] is 0.09089769098616318
# revenue of assortment [0, 3, 5] is 0.3701135829640278
# revenue of assortment [0, 4, 6] is 0.29522761836354083
# revenue of assortment [0, 5, 6] is 0.38010263426701196
# testing for offertimes 20, 23th instance
# revenue of assortment [0, 1, 7] is 0.40603567107932365
# revenue of assortment [0, 1, 8] is 0.593936386483458
# revenue of assortment [0, 3, 4] is 0.4579361966872613
# revenue of assortment [0, 3, 5] is 0.3245493847963714
# revenue of assortment [0, 6, 7] is 0.26300848789713616
# testing for offertimes 20, 24th instance
# revenue of assortment [0, 1] is 0.31989384706785895
# revenue of assortment [0, 2] is 0.14632342079928948
# revenue of assortment [0, 1, 5] is 0.49372626624314814
# revenue of assortment [0, 3, 4] is 0.4713309318195031
# revenue of assortment [0, 4, 8] is 0.6859853235717502
# testing for offertimes 20, 25th instance
# revenue of assortment [0, 1, 8] is 0.5379297069166761
# revenue of assortment [0, 3, 7] is 0.26418914119937376
# revenue of assortment [0, 3, 8] is 0.3838618562774756
# revenue of assortment [0, 4, 7] is 0.6261641884645999
# revenue of assortment [0, 6, 8] is 0.39734841450936526
# testing for offertimes 20, 26th instance
# revenue of assortment [0, 1] is 0.08388435598609023
# revenue of assortment [0, 6] is 0.12539221653377775
# revenue of assortment [0, 1, 3] is 0.1603293147103102
# revenue of assortment [0, 3, 5] is 0.2549803063859411
# revenue of assortment [0, 4, 5] is 0.522476011795179
# testing for offertimes 20, 27th instance
# revenue of assortment [0, 7] is 0.052453551207943164
# revenue of assortment [0, 1, 3] is 0.25364522096613806
# revenue of assortment [0, 3, 6] is 0.19506118620931956
# revenue of assortment [0, 5, 6] is 0.33804038945583664
# revenue of assortment [0, 6, 8] is 0.39867531293052916
# testing for offertimes 20, 28th instance
# revenue of assortment [0, 1, 7] is 0.2804027447657239
# revenue of assortment [0, 1, 8] is 0.3893590745532692
# revenue of assortment [0, 3, 5] is 0.32674876481943976
# revenue of assortment [0, 3, 7] is 0.18390723166437825
# revenue of assortment [0, 6, 8] is 0.3041228387492132
# testing for offertimes 20, 29th instance
# revenue of assortment [0, 1, 4] is 0.45622669860335774
# revenue of assortment [0, 1, 7] is 0.31255271082571046
# revenue of assortment [0, 2, 6] is 0.19420621559484835
# revenue of assortment [0, 3, 6] is 0.15810648583275544
# revenue of assortment [0, 4, 6] is 0.3488440882598517
# testing for offertimes 20, 30th instance
# revenue of assortment [0, 1] is 0.29891569984577476
# revenue of assortment [0, 1, 8] is 0.61236909725015
# revenue of assortment [0, 3, 8] is 0.47716496770959516
# revenue of assortment [0, 4, 8] is 0.7515838448043947
# revenue of assortment [0, 5, 8] is 0.6324834797348233
# testing for offertimes 20, 31th instance
# revenue of assortment [0, 3, 5] is 0.36802099629822144
# revenue of assortment [0, 4, 8] is 0.5137326174710725
# revenue of assortment [0, 6, 7] is 0.25395495405875174
# revenue of assortment [0, 6, 8] is 0.23906050374698207
# revenue of assortment [0, 8] is 0.14652268629006007
# testing for offertimes 20, 32th instance
# revenue of assortment [0, 5] is 0.12484567751961538
# revenue of assortment [0, 3, 5] is 0.19681414530144914
# revenue of assortment [0, 3, 6] is 0.20761250296931236
# revenue of assortment [0, 5, 6] is 0.23175756189821278
# revenue of assortment [0, 5, 8] is 0.4250214623770101
# testing for offertimes 20, 33th instance
# revenue of assortment [0, 2] is 0.055891765284533934
# revenue of assortment [0, 7] is 0.0404949866631512
# revenue of assortment [0, 2, 3, 6] is 0.20231306295880921
# revenue of assortment [0, 3, 4] is 0.3488249820727898
# revenue of assortment [0, 6, 8] is 0.40532175488249766
# testing for offertimes 20, 34th instance
# revenue of assortment [0, 7] is 0.1395496172718595
# revenue of assortment [0, 1, 7] is 0.31327418790236466
# revenue of assortment [0, 3, 5] is 0.37004756272480377
# revenue of assortment [0, 3, 6] is 0.2140134674714041
# revenue of assortment [0, 3, 7] is 0.21725859704642764
# testing for offertimes 20, 35th instance
# revenue of assortment [0, 1] is 0.08020392811942029
# revenue of assortment [0, 1, 7] is 0.21845027273642006
# revenue of assortment [0, 2, 3, 6] is 0.2165389631527805
# revenue of assortment [0, 3, 4] is 0.2968403277559628
# revenue of assortment [0, 6, 7] is 0.21461528317097744
# testing for offertimes 20, 36th instance
# revenue of assortment [0, 1, 6] is 0.3352327455201045
# revenue of assortment [0, 2, 6] is 0.1977016201787039
# revenue of assortment [0, 3, 6] is 0.20148891154018883
# revenue of assortment [0, 3, 8] is 0.3927889082589415
# revenue of assortment [0, 5, 8] is 0.5605677198825374
# testing for offertimes 20, 37th instance
# revenue of assortment [0, 1] is 0.14054598660368695
# revenue of assortment [0, 1, 3] is 0.18723898324970087
# revenue of assortment [0, 3, 8] is 0.4325585759076657
# revenue of assortment [0, 4, 5] is 0.5722136492553629
# revenue of assortment [0, 5, 8] is 0.5621397595199855
# testing for offertimes 20, 38th instance
# revenue of assortment [0, 3] is 0.048615588499046
# revenue of assortment [0, 6] is 0.07596790320510424
# revenue of assortment [0, 3, 6] is 0.10952891903920733
# revenue of assortment [0, 3, 7] is 0.17133484801072107
# revenue of assortment [0, 6, 8] is 0.40748662246224243
# testing for offertimes 20, 39th instance
# revenue of assortment [0, 1, 4] is 0.5256112380835818
# revenue of assortment [0, 3, 6] is 0.16244536015944527
# revenue of assortment [0, 5, 8] is 0.5246776649193615
# revenue of assortment [0, 6, 7] is 0.20293977093674082
# revenue of assortment [0, 6, 8] is 0.3781103123533984
# testing for offertimes 20, 40th instance
# revenue of assortment [0, 2] is 0.03989636730866015
# revenue of assortment [0, 3] is 0.0815753648277736
# revenue of assortment [0, 4, 6] is 0.39091417769041426
# revenue of assortment [0, 6, 7] is 0.28836458274470683
# revenue of assortment [0, 6, 8] is 0.4380946055431096
# testing for offertimes 20, 41th instance
# revenue of assortment [0, 1] is 0.14759344369710004
# revenue of assortment [0, 1, 3] is 0.21527577824267102
# revenue of assortment [0, 1, 4] is 0.48527601309957175
# revenue of assortment [0, 2, 6] is 0.17842931545006283
# revenue of assortment [0, 5, 6] is 0.24750527730633753
# testing for offertimes 20, 42th instance
# revenue of assortment [0, 4] is 0.06340165586343564
# revenue of assortment [0, 6] is 0.0760332623779426
# revenue of assortment [0, 1, 4] is 0.2956385245168009
# revenue of assortment [0, 3, 8] is 0.4320997298610624
# revenue of assortment [0, 5, 8] is 0.5940779096339399
# testing for offertimes 20, 43th instance
# revenue of assortment [0, 3] is 0.08305611529439796
# revenue of assortment [0, 6] is 0.11970882811364823
# revenue of assortment [0, 1, 4] is 0.5803492760657405
# revenue of assortment [0, 1, 5] is 0.40224178789302845
# revenue of assortment [0, 1, 7] is 0.32730629738612227
# testing for offertimes 20, 44th instance
# revenue of assortment [0, 6] is 0.08202531587693104
# revenue of assortment [0, 1, 4] is 0.49001994999883713
# revenue of assortment [0, 3, 5] is 0.2802091630949485
# revenue of assortment [0, 4, 5] is 0.5032113008937664
# revenue of assortment [0, 4, 6] is 0.3723235778000048
# testing for offertimes 20, 45th instance
# revenue of assortment [0, 1, 5] is 0.5136589936844943
# revenue of assortment [0, 1, 6] is 0.30429227832715605
# revenue of assortment [0, 2, 6] is 0.14706304844480497
# revenue of assortment [0, 3, 4] is 0.35553092894783017
# revenue of assortment [0, 4, 7] is 0.4206834475990683
# testing for offertimes 20, 46th instance
# revenue of assortment [0, 1] is 0.08892263235843505
# revenue of assortment [0, 4] is 0.3815424659810034
# revenue of assortment [0, 1, 5] is 0.36042812276188796
# revenue of assortment [0, 1, 8] is 0.558644963763586
# revenue of assortment [0, 3, 4] is 0.38347474911140134
# testing for offertimes 20, 47th instance
# revenue of assortment [0, 7] is 0.16278055692469948
# revenue of assortment [0, 1, 4] is 0.5199092112573211
# revenue of assortment [0, 1, 6] is 0.33179898886983905
# revenue of assortment [0, 2, 3, 6] is 0.2671695310833176
# revenue of assortment [0, 5, 8] is 0.6921888249237224
# testing for offertimes 20, 48th instance
# revenue of assortment [0, 4] is 0.4153157117700622
# revenue of assortment [0, 1, 4] is 0.5397299609734787
# revenue of assortment [0, 3, 5] is 0.32337137164542995
# revenue of assortment [0, 4, 8] is 0.5384636476040168
# revenue of assortment [0, 8] is 0.21790073409112037
# testing for offertimes 20, 49th instance
# revenue of assortment [0, 1] is 0.1781632609417087
# revenue of assortment [0, 7] is 0.15907926213381218
# revenue of assortment [0, 2, 3, 6] is 0.1915439741513923
# revenue of assortment [0, 3, 8] is 0.27384667245785244
# revenue of assortment [0, 6, 7] is 0.2152750787825849
# testing for offertimes 30, 0th instance
# revenue of assortment [0, 1] is 0.22871007055858375
# revenue of assortment [0, 5] is 0.1974159496221543
# revenue of assortment [0, 1, 3] is 0.26113817703229814
# revenue of assortment [0, 1, 8] is 0.46091807964262416
# testing for offertimes 30, 1th instance
# revenue of assortment [0, 2] is 0.14303513959743813
# revenue of assortment [0, 6] is 0.07596817703444361
# revenue of assortment [0, 3, 4] is 0.348159530119132
# revenue of assortment [0, 8] is 0.5714539218417417
# testing for offertimes 30, 2th instance
# revenue of assortment [0, 2, 6] is 0.2231540599636834
# revenue of assortment [0, 3, 7] is 0.2525450979209452
# revenue of assortment [0, 6, 7] is 0.2695401302573551
# revenue of assortment [0, 6, 8] is 0.5412797243629801
# testing for offertimes 30, 3th instance
# revenue of assortment [0, 1, 3] is 0.266225109136458
# revenue of assortment [0, 4, 5] is 0.6424800187882903
# revenue of assortment [0, 5, 8] is 0.5713472296104474
# revenue of assortment [0, 6, 8] is 0.4170387346068891
# testing for offertimes 30, 4th instance
# revenue of assortment [0, 1, 3] is 0.31905873522778483
# revenue of assortment [0, 3, 4] is 0.4278207159287309
# revenue of assortment [0, 3, 7] is 0.2202061005551304
# revenue of assortment [0, 5, 8] is 0.5536462218112193
# testing for offertimes 30, 5th instance
# revenue of assortment [0, 1] is 0.25943908040271363
# revenue of assortment [0, 1, 8] is 0.5101317025170965
# revenue of assortment [0, 4, 6] is 0.4375145958567589
# revenue of assortment [0, 6, 7] is 0.24590418227179536
# testing for offertimes 30, 6th instance
# revenue of assortment [0, 1, 6] is 0.3080766885846975
# revenue of assortment [0, 2, 6] is 0.23688584885551595
# revenue of assortment [0, 5, 8] is 0.6405237295261702
# revenue of assortment [0, 6, 7] is 0.27352929600197795
# testing for offertimes 30, 7th instance
# revenue of assortment [0, 2] is 0.06039921466394511
# revenue of assortment [0, 5] is 0.21226467632426843
# revenue of assortment [0, 1, 5] is 0.3596351866581019
# revenue of assortment [0, 8] is 0.2214901688077531
# testing for offertimes 30, 8th instance
# revenue of assortment [0, 2] is 0.06157025334234704
# revenue of assortment [0, 3] is 0.07069624989128472
# revenue of assortment [0, 7] is 0.14436922405262156
# revenue of assortment [0, 1, 5] is 0.4050258351253587
# testing for offertimes 30, 9th instance
# revenue of assortment [0, 3] is 0.04310854157792909
# revenue of assortment [0, 6] is 0.12830775374218584
# revenue of assortment [0, 1, 5] is 0.4345542809039748
# revenue of assortment [0, 8] is 0.31540781126424744
# testing for offertimes 30, 10th instance
# revenue of assortment [0, 5] is 0.2769384362490324
# revenue of assortment [0, 1, 4] is 0.5498985651838281
# revenue of assortment [0, 2, 6] is 0.20532293701749185
# revenue of assortment [0, 4, 6] is 0.44141366619777783
# testing for offertimes 30, 11th instance
# revenue of assortment [0, 1] is 0.08876664165158002
# revenue of assortment [0, 2] is 0.08485485532657958
# revenue of assortment [0, 4, 5] is 0.6098000692677894
# revenue of assortment [0, 4, 6] is 0.46604191347314555
# testing for offertimes 30, 12th instance
# revenue of assortment [0, 6] is 0.06921781382385647
# revenue of assortment [0, 7] is 0.1839036494916274
# revenue of assortment [0, 3, 4] is 0.40982991322719114
# revenue of assortment [0, 4, 6] is 0.42464768042976675
# testing for offertimes 30, 13th instance
# revenue of assortment [0, 2] is 0.11707593087061856
# revenue of assortment [0, 3, 7] is 0.25265675058548154
# revenue of assortment [0, 5, 6] is 0.3647608989840736
# revenue of assortment [0, 6, 8] is 0.44000792253854126
# testing for offertimes 30, 14th instance
# revenue of assortment [0, 4] is 0.20447804935284586
# revenue of assortment [0, 7] is 0.1516377720218442
# revenue of assortment [0, 1, 7] is 0.38770592165056117
# revenue of assortment [0, 1, 8] is 0.5919598490106825
# testing for offertimes 30, 15th instance
# revenue of assortment [0, 7] is 0.2159249318999315
# revenue of assortment [0, 2, 6] is 0.20486631803994404
# revenue of assortment [0, 4, 6] is 0.5395710149487184
# revenue of assortment [0, 6, 7] is 0.2588817727487172
# testing for offertimes 30, 16th instance
# revenue of assortment [0, 4] is 0.3166709800891248
# revenue of assortment [0, 7] is 0.1466998816263007
# revenue of assortment [0, 3, 6] is 0.17818619551673215
# revenue of assortment [0, 4, 6] is 0.3505818863617911
# testing for offertimes 30, 17th instance
# revenue of assortment [0, 1, 5] is 0.40243956923199325
# revenue of assortment [0, 1, 8] is 0.40966773265556433
# revenue of assortment [0, 3, 7] is 0.22554807078856343
# revenue of assortment [0, 6, 7] is 0.2167824747362125
# testing for offertimes 30, 18th instance
# revenue of assortment [0, 1] is 0.2971899330763726
# revenue of assortment [0, 1, 6] is 0.33213463645462543
# revenue of assortment [0, 3, 6] is 0.18413031067999736
# revenue of assortment [0, 5, 6] is 0.27966850763200335
# testing for offertimes 30, 19th instance
# revenue of assortment [0, 1] is 0.17363267495862472
# revenue of assortment [0, 6] is 0.12357490950489802
# revenue of assortment [0, 1, 5] is 0.35699534250713166
# revenue of assortment [0, 1, 8] is 0.480714699592381
# testing for offertimes 30, 20th instance
# revenue of assortment [0, 5] is 0.13950396643197416
# revenue of assortment [0, 7] is 0.08090690939988811
# revenue of assortment [0, 1, 6] is 0.2886111348745233
# revenue of assortment [0, 4, 6] is 0.4942704102782173
# testing for offertimes 30, 21th instance
# revenue of assortment [0, 7] is 0.15193333587961982
# revenue of assortment [0, 1, 4] is 0.4663191619452497
# revenue of assortment [0, 1, 6] is 0.282802045242188
# revenue of assortment [0, 2, 6] is 0.18397936308098103
# testing for offertimes 30, 22th instance
# revenue of assortment [0, 4] is 0.2957048620237302
# revenue of assortment [0, 1, 8] is 0.5019679505584607
# revenue of assortment [0, 4, 5] is 0.5373216460720126
# revenue of assortment [0, 6, 7] is 0.23583537349589545
# testing for offertimes 30, 23th instance
# revenue of assortment [0, 1, 7] is 0.4040607197713443
# revenue of assortment [0, 3, 6] is 0.16852389096717604
# revenue of assortment [0, 4, 5] is 0.6271112428228616
# revenue of assortment [0, 6, 7] is 0.26223009787602175
# testing for offertimes 30, 24th instance
# revenue of assortment [0, 3] is 0.08457251144994711
# revenue of assortment [0, 1, 3] is 0.3470976343148378
# revenue of assortment [0, 4, 5] is 0.637911732367843
# revenue of assortment [0, 8] is 0.26341956702386443
# testing for offertimes 30, 25th instance
# revenue of assortment [0, 2] is 0.07468751420253499
# revenue of assortment [0, 3] is 0.13920301330704718
# revenue of assortment [0, 5] is 0.3884625802568564
# revenue of assortment [0, 6] is 0.05216902610219727
# testing for offertimes 30, 26th instance
# revenue of assortment [0, 6] is 0.1289439128672447
# revenue of assortment [0, 7] is 0.12155742537307712
# revenue of assortment [0, 1, 4] is 0.5117238705425031
# revenue of assortment [0, 4, 5] is 0.5336425178989237
# testing for offertimes 30, 27th instance
# revenue of assortment [0, 1, 4] is 0.49640927140136343
# revenue of assortment [0, 1, 6] is 0.29295870054823603
# revenue of assortment [0, 3, 7] is 0.18618716592478238
# revenue of assortment [0, 5, 6] is 0.3369254538580988
# testing for offertimes 30, 28th instance
# revenue of assortment [0, 4] is 0.18737402098824574
# revenue of assortment [0, 1, 5] is 0.43145527062185973
# revenue of assortment [0, 1, 6] is 0.26274988612404165
# revenue of assortment [0, 1, 7] is 0.28752487108066305
# testing for offertimes 30, 29th instance
# revenue of assortment [0, 1, 3] is 0.2630371509148036
# revenue of assortment [0, 3, 6] is 0.15624202265136222
# revenue of assortment [0, 5, 6] is 0.27713976441799354
# revenue of assortment [0, 6, 8] is 0.4370807326756162
# testing for offertimes 30, 30th instance
# revenue of assortment [0, 4] is 0.33662538236007644
# revenue of assortment [0, 5] is 0.24216168942000402
# revenue of assortment [0, 4, 5] is 0.4802811398887533
# revenue of assortment [0, 4, 6] is 0.3724879540559912
# testing for offertimes 30, 31th instance
# revenue of assortment [0, 4] is 0.4094119047231286
# revenue of assortment [0, 5] is 0.34923159140307986
# revenue of assortment [0, 1, 6] is 0.2933570604302183
# revenue of assortment [0, 1, 8] is 0.4357608568404603
# testing for offertimes 30, 32th instance
# revenue of assortment [0, 3] is 0.07123310372101872
# revenue of assortment [0, 1, 8] is 0.5249325463120984
# revenue of assortment [0, 4, 6] is 0.5064403467948544
# revenue of assortment [0, 5, 6] is 0.3468253245686226
# testing for offertimes 30, 33th instance
# revenue of assortment [0, 3] is 0.06505901368319694
# revenue of assortment [0, 1, 3] is 0.34212359145678634
# revenue of assortment [0, 4, 5] is 0.5195244168284653
# revenue of assortment [0, 4, 6] is 0.3833921749134066
# testing for offertimes 30, 34th instance
# revenue of assortment [0, 1, 4] is 0.603228005042937
# revenue of assortment [0, 1, 5] is 0.48429172363603445
# revenue of assortment [0, 1, 7] is 0.35155580700393047
# revenue of assortment [0, 4, 6] is 0.4996054668820784
# testing for offertimes 30, 35th instance
# revenue of assortment [0, 4] is 0.13527354181748072
# revenue of assortment [0, 1, 4] is 0.29187384950532225
# revenue of assortment [0, 3, 4] is 0.1947559929105429
# revenue of assortment [0, 4, 5] is 0.37341805017399354
# testing for offertimes 30, 36th instance
# revenue of assortment [0, 1] is 0.24451001708205122
# revenue of assortment [0, 2] is 0.044852981285565065
# revenue of assortment [0, 4] is 0.18402738200325075
# revenue of assortment [0, 1, 5] is 0.4512681647473762
# testing for offertimes 30, 37th instance
# revenue of assortment [0, 1] is 0.14046903998687263
# revenue of assortment [0, 3] is 0.03659162335529149
# revenue of assortment [0, 5, 6] is 0.28906539525334324
# revenue of assortment [0, 6, 7] is 0.2567540736121944
# testing for offertimes 30, 38th instance
# revenue of assortment [0, 6] is 0.07051327570346963
# revenue of assortment [0, 1, 3] is 0.2862844510243532
# revenue of assortment [0, 2, 6] is 0.12659386707021505
# revenue of assortment [0, 4, 6] is 0.3276396200319793
# testing for offertimes 30, 39th instance
# revenue of assortment [0, 4] is 0.2401439188996981
# revenue of assortment [0, 6] is 0.05191330870122188
# revenue of assortment [0, 3, 4] is 0.27498650057631074
# revenue of assortment [0, 6, 7] is 0.17784558015152785
# testing for offertimes 30, 40th instance
# revenue of assortment [0, 4] is 0.27449714885941584
# revenue of assortment [0, 6] is 0.12696483142339177
# revenue of assortment [0, 1, 3] is 0.3153140551278855
# revenue of assortment [0, 8] is 0.2788566397818426
# testing for offertimes 30, 41th instance
# revenue of assortment [0, 1, 5] is 0.3443806053432415
# revenue of assortment [0, 1, 8] is 0.41797508868930494
# revenue of assortment [0, 2, 6] is 0.19422437735221412
# revenue of assortment [0, 4, 5] is 0.520862623753594
# testing for offertimes 30, 42th instance
# revenue of assortment [0, 1, 4] is 0.44823297355275593
# revenue of assortment [0, 3, 6] is 0.16483980096229067
# revenue of assortment [0, 4, 5] is 0.49281364671756145
# revenue of assortment [0, 6, 8] is 0.4152760527557656
# testing for offertimes 30, 43th instance
# revenue of assortment [0, 4] is 0.29165526817222764
# revenue of assortment [0, 7] is 0.08709580680873157
# revenue of assortment [0, 1, 6] is 0.3054350215790691
# revenue of assortment [0, 5, 8] is 0.5626389453900904
# testing for offertimes 30, 44th instance
# revenue of assortment [0, 1] is 0.2139829443351063
# revenue of assortment [0, 2] is 0.07922092506754602
# revenue of assortment [0, 1, 5] is 0.3901411453294016
# revenue of assortment [0, 1, 6] is 0.2619742679849179
# testing for offertimes 30, 45th instance
# revenue of assortment [0, 1, 6] is 0.3027231021331619
# revenue of assortment [0, 3, 4] is 0.3482394024886753
# revenue of assortment [0, 5, 6] is 0.395208055175966
# revenue of assortment [0, 8] is 0.1674441305386193
# testing for offertimes 30, 46th instance
# revenue of assortment [0, 3] is 0.08752009142691464
# revenue of assortment [0, 1, 6] is 0.26286418839305753
# revenue of assortment [0, 1, 8] is 0.6085623315395194
# revenue of assortment [0, 5, 6] is 0.34148709847972614
# testing for offertimes 30, 47th instance
# revenue of assortment [0, 4] is 0.20511178655359202
# revenue of assortment [0, 7] is 0.15923859726381964
# revenue of assortment [0, 1, 4] is 0.41270232317796013
# revenue of assortment [0, 3, 4] is 0.2661002685661667
# testing for offertimes 30, 48th instance
# revenue of assortment [0, 3, 6] is 0.14828214844096393
# revenue of assortment [0, 4, 5] is 0.6289223688595325
# revenue of assortment [0, 5, 6] is 0.3487482601060021
# revenue of assortment [0, 6, 8] is 0.33439867515201427
# testing for offertimes 30, 49th instance
# revenue of assortment [0, 6] is 0.06977193304309957
# revenue of assortment [0, 1, 4] is 0.4920321544053052
# revenue of assortment [0, 1, 7] is 0.3194546127096602
# revenue of assortment [0, 6, 7] is 0.18940110876974225
# testing for offertimes 40, 0th instance
# revenue of assortment [0, 7] is 0.10589618095489543
# revenue of assortment [0, 1, 5] is 0.4397019903867885
# revenue of assortment [0, 5, 8] is 0.504626152333061
# testing for offertimes 40, 1th instance
# revenue of assortment [0, 7] is 0.2699865066128476
# revenue of assortment [0, 1, 3] is 0.32394761251202187
# revenue of assortment [0, 2, 6] is 0.22831516817730235
# testing for offertimes 40, 2th instance
# revenue of assortment [0, 3] is 0.09606922648597337
# revenue of assortment [0, 1, 4] is 0.6455630785340418
# revenue of assortment [0, 8] is 0.610941278811763
# testing for offertimes 40, 3th instance
# revenue of assortment [0, 3] is 0.07490293981640557
# revenue of assortment [0, 1, 6] is 0.28423593173296197
# revenue of assortment [0, 3, 7] is 0.20268556797034398
# testing for offertimes 40, 4th instance
# revenue of assortment [0, 1, 3] is 0.319436870144745
# revenue of assortment [0, 1, 5] is 0.4204844481278615
# revenue of assortment [0, 3, 4] is 0.4330412523786443
# testing for offertimes 40, 5th instance
# revenue of assortment [0, 2] is 0.1012451059065366
# revenue of assortment [0, 6] is 0.070878944748235
# revenue of assortment [0, 1, 6] is 0.3535838434044829
# testing for offertimes 40, 6th instance
# revenue of assortment [0, 1, 3] is 0.2809749592367839
# revenue of assortment [0, 1, 5] is 0.4719096909956601
# revenue of assortment [0, 1, 6] is 0.3104635041884489
# testing for offertimes 40, 7th instance
# revenue of assortment [0, 3] is 0.10166371980984458
# revenue of assortment [0, 4] is 0.1557789426997978
# revenue of assortment [0, 1, 6] is 0.2737653173390295
# testing for offertimes 40, 8th instance
# revenue of assortment [0, 1] is 0.18910076527627734
# revenue of assortment [0, 1, 3] is 0.23338382734817115
# revenue of assortment [0, 8] is 0.41854100046073967
# testing for offertimes 40, 9th instance
# revenue of assortment [0, 3] is 0.039400656513907
# revenue of assortment [0, 1, 3] is 0.24908284945018322
# revenue of assortment [0, 3, 4] is 0.4169431829109224
# testing for offertimes 40, 10th instance
# revenue of assortment [0, 3] is 0.034091201116122995
# revenue of assortment [0, 1, 4] is 0.5431457844849277
# revenue of assortment [0, 5, 8] is 0.4939763634067181
# testing for offertimes 40, 11th instance
# revenue of assortment [0, 1] is 0.08442511272403135
# revenue of assortment [0, 3] is 0.04054878748647209
# revenue of assortment [0, 5, 8] is 0.5884295881397037
# testing for offertimes 40, 12th instance
# revenue of assortment [0, 1, 5] is 0.4862631793734717
# revenue of assortment [0, 2, 6] is 0.2212593676810674
# revenue of assortment [0, 4, 6] is 0.42957301933277486
# testing for offertimes 40, 13th instance
# revenue of assortment [0, 4] is 0.4300351955750828
# revenue of assortment [0, 5] is 0.3055574819595675
# revenue of assortment [0, 4, 6] is 0.437890578881165
# testing for offertimes 40, 14th instance
# revenue of assortment [0, 3] is 0.0572870680036569
# revenue of assortment [0, 1, 6] is 0.37015440212652645
# revenue of assortment [0, 5, 6] is 0.4124896580790367
# testing for offertimes 40, 15th instance
# revenue of assortment [0, 6] is 0.09302914322847153
# revenue of assortment [0, 5, 6] is 0.291403965413451
# revenue of assortment [0, 5, 8] is 0.5954125625221685
# testing for offertimes 40, 16th instance
# revenue of assortment [0, 5] is 0.29233648361383197
# revenue of assortment [0, 1, 6] is 0.32717199211760095
# revenue of assortment [0, 8] is 0.30020392426634457
# testing for offertimes 40, 17th instance
# revenue of assortment [0, 4] is 0.35797710720171066
# revenue of assortment [0, 1, 5] is 0.414104583532142
# revenue of assortment [0, 5, 6] is 0.31198064901783906
# testing for offertimes 40, 18th instance
# revenue of assortment [0, 5] is 0.20086593144608317
# revenue of assortment [0, 7] is 0.04586255511817998
# revenue of assortment [0, 1, 5] is 0.416889611653133
# testing for offertimes 40, 19th instance
# revenue of assortment [0, 2] is 0.08501170100857107
# revenue of assortment [0, 5] is 0.1218457188997738
# revenue of assortment [0, 5, 8] is 0.4621330342537722
# testing for offertimes 40, 20th instance
# revenue of assortment [0, 7] is 0.09269998591536742
# revenue of assortment [0, 1, 6] is 0.2926198483897746
# revenue of assortment [0, 5, 8] is 0.5722510190743264
# testing for offertimes 40, 21th instance
# revenue of assortment [0, 6] is 0.09126946878980963
# revenue of assortment [0, 1, 5] is 0.4031738572138659
# revenue of assortment [0, 3, 6] is 0.1598283380518499
# testing for offertimes 40, 22th instance
# revenue of assortment [0, 2] is 0.04730952506406381
# revenue of assortment [0, 6] is 0.08902627182651551
# revenue of assortment [0, 5, 8] is 0.6166773449869072
# testing for offertimes 40, 23th instance
# revenue of assortment [0, 3] is 0.06565645443769856
# revenue of assortment [0, 1, 3] is 0.3323795044701049
# revenue of assortment [0, 1, 4] is 0.6268704130737943
# testing for offertimes 40, 24th instance
# revenue of assortment [0, 1, 4] is 0.6482318531648089
# revenue of assortment [0, 3, 6] is 0.18248423558277777
# revenue of assortment [0, 3, 7] is 0.28552801776305936
# testing for offertimes 40, 25th instance
# revenue of assortment [0, 1] is 0.18846952027427497
# revenue of assortment [0, 1, 6] is 0.245047093415947
# revenue of assortment [0, 3, 4] is 0.5859553175122709
# testing for offertimes 40, 26th instance
# revenue of assortment [0, 6] is 0.12369524517189477
# revenue of assortment [0, 1, 4] is 0.5199423241623534
# revenue of assortment [0, 4, 6] is 0.44194678321442693
# testing for offertimes 40, 27th instance
# revenue of assortment [0, 1] is 0.1052857061847875
# revenue of assortment [0, 3, 6] is 0.19486890576398735
# revenue of assortment [0, 8] is 0.25217261243249217
# testing for offertimes 40, 28th instance
# revenue of assortment [0, 1, 4] is 0.4514941438843044
# revenue of assortment [0, 3, 4] is 0.3504005642154201
# revenue of assortment [0, 8] is 0.15184327255391858
# testing for offertimes 40, 29th instance
# revenue of assortment [0, 6] is 0.07130847949474664
# revenue of assortment [0, 3, 4] is 0.36978524806540136
# revenue of assortment [0, 8] is 0.3887224591995734
# testing for offertimes 40, 30th instance
# revenue of assortment [0, 3] is 0.04805688534763968
# revenue of assortment [0, 1, 3] is 0.3384243753272103
# revenue of assortment [0, 4, 6] is 0.5001971154770078
# testing for offertimes 40, 31th instance
# revenue of assortment [0, 1] is 0.07456013098910956
# revenue of assortment [0, 6] is 0.12494608518102923
# revenue of assortment [0, 5, 6] is 0.3902545081627264
# testing for offertimes 40, 32th instance
# revenue of assortment [0, 1, 6] is 0.3495671393414612
# revenue of assortment [0, 3, 7] is 0.2217168423114043
# revenue of assortment [0, 5, 6] is 0.350452193850613
# testing for offertimes 40, 33th instance
# revenue of assortment [0, 1, 3] is 0.34701907819044914
# revenue of assortment [0, 1, 6] is 0.3629312420176799
# revenue of assortment [0, 8] is 0.29628862404283934
# testing for offertimes 40, 34th instance
# revenue of assortment [0, 1, 3] is 0.292765915091726
# revenue of assortment [0, 4, 6] is 0.50361933709828
# revenue of assortment [0, 8] is 0.1493229675025699
# testing for offertimes 40, 35th instance
# revenue of assortment [0, 1, 4] is 0.42090135149467856
# revenue of assortment [0, 1, 6] is 0.2589918143043639
# revenue of assortment [0, 3, 6] is 0.15932781339275884
# testing for offertimes 40, 36th instance
# revenue of assortment [0, 2] is 0.04493688530808747
# revenue of assortment [0, 3] is 0.08974795170296525
# revenue of assortment [0, 1, 3] is 0.31005981761477597
# testing for offertimes 40, 37th instance
# revenue of assortment [0, 6] is 0.10116785615368841
# revenue of assortment [0, 2, 6] is 0.16891194225588854
# revenue of assortment [0, 5, 6] is 0.2849476222000269
# testing for offertimes 40, 38th instance
# revenue of assortment [0, 7] is 0.11959355458682402
# revenue of assortment [0, 1, 5] is 0.3910490475955434
# revenue of assortment [0, 5, 6] is 0.25506763959090806
# testing for offertimes 40, 39th instance
# revenue of assortment [0, 1, 5] is 0.4774238976555203
# revenue of assortment [0, 2, 6] is 0.1887196689505024
# revenue of assortment [0, 8] is 0.3400446561831182
# testing for offertimes 40, 40th instance
# revenue of assortment [0, 3] is 0.08395801942977527
# revenue of assortment [0, 6] is 0.1246855001195108
# revenue of assortment [0, 3, 7] is 0.261967534141537
# testing for offertimes 40, 41th instance
# revenue of assortment [0, 4] is 0.48448004090810226
# revenue of assortment [0, 3, 4] is 0.46214194819388377
# revenue of assortment [0, 5, 6] is 0.25031698869450986
# testing for offertimes 40, 42th instance
# revenue of assortment [0, 5] is 0.3064639997305123
# revenue of assortment [0, 6] is 0.07618480654899537
# revenue of assortment [0, 1, 4] is 0.44969037138322854
# testing for offertimes 40, 43th instance
# revenue of assortment [0, 2] is 0.03237772159581178
# revenue of assortment [0, 7] is 0.08775950040183012
# revenue of assortment [0, 3, 6] is 0.19190814262258754
# testing for offertimes 40, 44th instance
# revenue of assortment [0, 2, 6] is 0.18155380265097432
# revenue of assortment [0, 3, 4] is 0.36655777364184394
# revenue of assortment [0, 4, 6] is 0.3824141544619858
# testing for offertimes 40, 45th instance
# revenue of assortment [0, 6] is 0.03997165281735176
# revenue of assortment [0, 3, 4] is 0.3533068420050787
# revenue of assortment [0, 5, 6] is 0.3936675425279854
# testing for offertimes 40, 46th instance
# revenue of assortment [0, 2] is 0.1452358764795331
# revenue of assortment [0, 5, 6] is 0.3750318283378658
# revenue of assortment [0, 5, 8] is 0.6505984416449533
# testing for offertimes 40, 47th instance
# revenue of assortment [0, 3] is 0.1261477577256239
# revenue of assortment [0, 4] is 0.15862243251099664
# revenue of assortment [0, 1, 4] is 0.38399782416499895
# testing for offertimes 40, 48th instance
# revenue of assortment [0, 3] is 0.04806725040798813
# revenue of assortment [0, 5] is 0.29760204406118784
# revenue of assortment [0, 1, 4] is 0.5974516822582723
# testing for offertimes 40, 49th instance
# revenue of assortment [0, 3] is 0.06538024186038668
# revenue of assortment [0, 1, 3] is 0.26631412545950134
# revenue of assortment [0, 3, 7] is 0.18026593583773862
# testing for offertimes 50, 0th instance
# revenue of assortment [0, 3] is 0.0665813827218473
# revenue of assortment [0, 6] is 0.07807355852263333
# revenue of assortment [0, 1, 3] is 0.30042604063703576
# testing for offertimes 50, 1th instance
# revenue of assortment [0, 3] is 0.12696137363762874
# revenue of assortment [0, 1, 3] is 0.32312505465044983
# revenue of assortment [0, 1, 6] is 0.3359882346372551
# testing for offertimes 50, 2th instance
# revenue of assortment [0, 4] is 0.40545170097129063
# revenue of assortment [0, 5] is 0.14829116013822538
# revenue of assortment [0, 8] is 0.5592926870622974
# testing for offertimes 50, 3th instance
# revenue of assortment [0, 1] is 0.11110855793025161
# revenue of assortment [0, 1, 3] is 0.16955261901287447
# revenue of assortment [0, 1, 6] is 0.1779201575070883
# testing for offertimes 50, 4th instance
# revenue of assortment [0, 1] is 0.25307194314673365
# revenue of assortment [0, 1, 6] is 0.2975329903793292
# revenue of assortment [0, 2, 6] is 0.2066288763527521
# testing for offertimes 50, 5th instance
# revenue of assortment [0, 4] is 0.2289758328927648
# revenue of assortment [0, 5] is 0.33022423119192623
# revenue of assortment [0, 5, 8] is 0.5875777002292057
# testing for offertimes 50, 6th instance
# revenue of assortment [0, 3] is 0.07892725900023408
# revenue of assortment [0, 4] is 0.46945462007031963
# revenue of assortment [0, 5] is 0.2787529113653142
# testing for offertimes 50, 7th instance
# revenue of assortment [0, 5] is 0.21383074541566105
# revenue of assortment [0, 1, 6] is 0.27735802503831875
# revenue of assortment [0, 8] is 0.20078979466979616
# testing for offertimes 50, 8th instance
# revenue of assortment [0, 5] is 0.10833779555271116
# revenue of assortment [0, 2, 6] is 0.2370969366146364
# revenue of assortment [0, 5, 6] is 0.2150432093641933
# testing for offertimes 50, 9th instance
# revenue of assortment [0, 1, 3] is 0.263170578156682
# revenue of assortment [0, 5, 6] is 0.36870464102152806
# revenue of assortment [0, 5, 8] is 0.594427754892756
# testing for offertimes 50, 10th instance
# revenue of assortment [0, 3] is 0.0345599654119189
# revenue of assortment [0, 1, 4] is 0.5677821518678975
# revenue of assortment [0, 5, 8] is 0.4966509841669625
# testing for offertimes 50, 11th instance
# revenue of assortment [0, 2] is 0.08534943790666928
# revenue of assortment [0, 5, 6] is 0.3745918547022451
# revenue of assortment [0, 5, 8] is 0.5993756542374915
# testing for offertimes 50, 12th instance
# revenue of assortment [0, 4] is 0.216929155337971
# revenue of assortment [0, 5] is 0.19854403099693113
# revenue of assortment [0, 5, 6] is 0.2627872305785853
# testing for offertimes 50, 13th instance
# revenue of assortment [0, 1] is 0.1983602700199896
# revenue of assortment [0, 2] is 0.11756189540208312
# revenue of assortment [0, 5, 6] is 0.3700157746104292
# testing for offertimes 50, 14th instance
# revenue of assortment [0, 2] is 0.04051766908797231
# revenue of assortment [0, 1, 6] is 0.37360230632102764
# revenue of assortment [0, 3, 6] is 0.19946870580256815
# testing for offertimes 50, 15th instance
# revenue of assortment [0, 1] is 0.29216115922837455
# revenue of assortment [0, 5] is 0.03689924490307016
# revenue of assortment [0, 1, 4] is 0.6691986371910972
# testing for offertimes 50, 16th instance
# revenue of assortment [0, 2, 6] is 0.24193688365527707
# revenue of assortment [0, 3, 6] is 0.18395614830547022
# revenue of assortment [0, 5, 6] is 0.37510121441316596
# testing for offertimes 50, 17th instance
# revenue of assortment [0, 6] is 0.0471137154297186
# revenue of assortment [0, 1, 4] is 0.5866872789297796
# revenue of assortment [0, 1, 6] is 0.24824006140845334
# testing for offertimes 50, 18th instance
# revenue of assortment [0, 6] is 0.05605579752857819
# revenue of assortment [0, 1, 4] is 0.5669017740894131
# revenue of assortment [0, 2, 6] is 0.1349480508981833
# testing for offertimes 50, 19th instance
# revenue of assortment [0, 6] is 0.12081814774828112
# revenue of assortment [0, 1, 4] is 0.482595740844729
# revenue of assortment [0, 5, 6] is 0.3028855675281743
# testing for offertimes 50, 20th instance
# revenue of assortment [0, 1] is 0.017094228354865893
# revenue of assortment [0, 2] is 0.050033685653799696
# revenue of assortment [0, 1, 3] is 0.1327073312366324
# testing for offertimes 50, 21th instance
# revenue of assortment [0, 6] is 0.09538346401502422
# revenue of assortment [0, 1, 3] is 0.2666518589027116
# revenue of assortment [0, 3, 6] is 0.16363913103616323
# testing for offertimes 50, 22th instance
# revenue of assortment [0, 6] is 0.10537411561185164
# revenue of assortment [0, 3, 6] is 0.17260060958209844
# revenue of assortment [0, 5, 6] is 0.3815960042092223
# testing for offertimes 50, 23th instance
# revenue of assortment [0, 1, 3] is 0.3307566416349313
# revenue of assortment [0, 1, 6] is 0.34970773357414775
# revenue of assortment [0, 2, 6] is 0.20941964597477455
# testing for offertimes 50, 24th instance
# revenue of assortment [0, 1] is 0.3224975881277721
# revenue of assortment [0, 5] is 0.3030396396333516
# revenue of assortment [0, 2, 6] is 0.16813240515982555
# testing for offertimes 50, 25th instance
# revenue of assortment [0, 1, 6] is 0.342337678294715
# revenue of assortment [0, 3, 6] is 0.19732115291434682
# revenue of assortment [0, 5, 8] is 0.6385103257478975
# testing for offertimes 50, 26th instance
# revenue of assortment [0, 1, 4] is 0.5300526864187813
# revenue of assortment [0, 3, 6] is 0.1827507890569146
# revenue of assortment [0, 5, 8] is 0.525779265663895
# testing for offertimes 50, 27th instance
# revenue of assortment [0, 4] is 0.28313359207485095
# revenue of assortment [0, 1, 3] is 0.2699730257994168
# revenue of assortment [0, 1, 6] is 0.2979801216562424
# testing for offertimes 50, 28th instance
# revenue of assortment [0, 3] is 0.05792512978374473
# revenue of assortment [0, 5] is 0.34608082679678404
# revenue of assortment [0, 3, 6] is 0.14585540190707416
# testing for offertimes 50, 29th instance
# revenue of assortment [0, 1] is 0.22579716896078691
# revenue of assortment [0, 1, 4] is 0.49022045766790934
# revenue of assortment [0, 2, 6] is 0.19582434189738132
# testing for offertimes 50, 30th instance
# revenue of assortment [0, 2] is 0.0778901374353865
# revenue of assortment [0, 3, 6] is 0.19425468304855753
# revenue of assortment [0, 8] is 0.3045116745385143
# testing for offertimes 50, 31th instance
# revenue of assortment [0, 4] is 0.4676827495236729
# revenue of assortment [0, 1, 3] is 0.2581051646412675
# revenue of assortment [0, 3, 6] is 0.18701595230453788
# testing for offertimes 50, 32th instance
# revenue of assortment [0, 5] is 0.17367370984891353
# revenue of assortment [0, 2, 6] is 0.19279844831095233
# revenue of assortment [0, 8] is 0.3132996778019664
# testing for offertimes 50, 33th instance
# revenue of assortment [0, 3] is 0.04871203245673618
# revenue of assortment [0, 2, 6] is 0.19084436638977417
# revenue of assortment [0, 3, 6] is 0.14869333194843024
# testing for offertimes 50, 34th instance
# revenue of assortment [0, 3] is 0.15392601767694936
# revenue of assortment [0, 5] is 0.42502217779723733
# revenue of assortment [0, 5, 6] is 0.4358221304229639
# testing for offertimes 50, 35th instance
# revenue of assortment [0, 2] is 0.12825904234239943
# revenue of assortment [0, 5, 6] is 0.3180584495804045
# revenue of assortment [0, 8] is 0.4425437208759097
# testing for offertimes 50, 36th instance
# revenue of assortment [0, 1] is 0.26792544134287094
# revenue of assortment [0, 6] is 0.13275275812524173
# revenue of assortment [0, 1, 6] is 0.31411573963658646
# testing for offertimes 50, 37th instance
# revenue of assortment [0, 5] is 0.12144827586220801
# revenue of assortment [0, 5, 6] is 0.20249949869568293
# revenue of assortment [0, 8] is 0.4466739130435738
# testing for offertimes 50, 38th instance
# revenue of assortment [0, 3] is 0.05978324363597396
# revenue of assortment [0, 5] is 0.11423763762564404
# revenue of assortment [0, 1, 4] is 0.4720258639342155
# testing for offertimes 50, 39th instance
# revenue of assortment [0, 5] is 0.10783795639196597
# revenue of assortment [0, 1, 3] is 0.32382024960712014
# revenue of assortment [0, 5, 8] is 0.4345357599154284
# testing for offertimes 50, 40th instance
# revenue of assortment [0, 3] is 0.053721968282654575
# revenue of assortment [0, 1, 3] is 0.31916458908592577
# revenue of assortment [0, 8] is 0.2708108983743163
# testing for offertimes 50, 41th instance
# revenue of assortment [0, 2] is 0.09166279972198536
# revenue of assortment [0, 1, 4] is 0.5196527350002549
# revenue of assortment [0, 3, 6] is 0.1715349803164407
# testing for offertimes 50, 42th instance
# revenue of assortment [0, 1] is 0.3492991054162605
# revenue of assortment [0, 3] is 0.04520459102013083
# revenue of assortment [0, 1, 3] is 0.3526318482861321
# testing for offertimes 50, 43th instance
# revenue of assortment [0, 3] is 0.14046589380899627
# revenue of assortment [0, 1, 4] is 0.6130066150439525
# revenue of assortment [0, 3, 6] is 0.2123764478807278
# testing for offertimes 50, 44th instance
# revenue of assortment [0, 5] is 0.08779754712390246
# revenue of assortment [0, 2, 6] is 0.18145402867491237
# revenue of assortment [0, 3, 6] is 0.16183633013805823
# testing for offertimes 50, 45th instance
# revenue of assortment [0, 4] is 0.043800851235830454
# revenue of assortment [0, 5] is 0.3515789771107065
# revenue of assortment [0, 1, 6] is 0.30129887606772937
# testing for offertimes 50, 46th instance
# revenue of assortment [0, 5] is 0.15077929506619955
# revenue of assortment [0, 6] is 0.050791384970139374
# revenue of assortment [0, 8] is 0.5441990590372986
# testing for offertimes 50, 47th instance
# revenue of assortment [0, 1, 4] is 0.5552977792925975
# revenue of assortment [0, 2, 6] is 0.2440000022788144
# revenue of assortment [0, 5, 8] is 0.7002038401900057
# testing for offertimes 50, 48th instance
# revenue of assortment [0, 6] is 0.0916488215712212
# revenue of assortment [0, 1, 3] is 0.28456130279315217
# revenue of assortment [0, 1, 4] is 0.6029320511277217
# testing for offertimes 50, 49th instance
# revenue of assortment [0, 1] is 0.18333976089411058
# revenue of assortment [0, 1, 4] is 0.49347664569951133
# revenue of assortment [0, 3, 6] is 0.1515581034207544
# testing for offertimes 60, 0th instance
# revenue of assortment [0, 3] is 0.070750951959881
# revenue of assortment [0, 5] is 0.19095688985118153
# testing for offertimes 60, 1th instance
# revenue of assortment [0, 5, 6] is 0.39319570625392786
# revenue of assortment [0, 5, 8] is 0.7132202905887803
# testing for offertimes 60, 2th instance
# revenue of assortment [0, 2, 6] is 0.2237501257389828
# revenue of assortment [0, 5, 8] is 0.6618636596910032
# testing for offertimes 60, 3th instance
# revenue of assortment [0, 5] is 0.23030177916847663
# revenue of assortment [0, 6] is 0.04065337824993432
# testing for offertimes 60, 4th instance
# revenue of assortment [0, 3, 6] is 0.18339300568580152
# revenue of assortment [0, 5, 8] is 0.5499812729964243
# testing for offertimes 60, 5th instance
# revenue of assortment [0, 3] is 0.10510314234387963
# revenue of assortment [0, 1, 6] is 0.37662681418572497
# testing for offertimes 60, 6th instance
# revenue of assortment [0, 5] is 0.2616980684800371
# revenue of assortment [0, 8] is 0.3368386263443726
# testing for offertimes 60, 7th instance
# revenue of assortment [0, 6] is 0.08176841305545599
# revenue of assortment [0, 3, 6] is 0.14669447000063124
# testing for offertimes 60, 8th instance
# revenue of assortment [0, 5] is 0.09439636279153801
# revenue of assortment [0, 3, 6] is 0.1949973620714445
# testing for offertimes 60, 9th instance
# revenue of assortment [0, 1] is 0.08222450813931691
# revenue of assortment [0, 5, 6] is 0.35651592057853576
# testing for offertimes 60, 10th instance
# revenue of assortment [0, 1, 6] is 0.3163242713764861
# revenue of assortment [0, 3, 6] is 0.17459155309172408
# testing for offertimes 60, 11th instance
# revenue of assortment [0, 3] is 0.03965108146573964
# revenue of assortment [0, 5, 8] is 0.5915556498806405
# testing for offertimes 60, 12th instance
# revenue of assortment [0, 1, 6] is 0.34851585910668365
# revenue of assortment [0, 2, 6] is 0.2227354701918566
# testing for offertimes 60, 13th instance
# revenue of assortment [0, 3] is 0.07095346175831373
# revenue of assortment [0, 8] is 0.39287546457927314
# testing for offertimes 60, 14th instance
# revenue of assortment [0, 1, 6] is 0.3777190038732767
# revenue of assortment [0, 5, 8] is 0.6684969699252215
# testing for offertimes 60, 15th instance
# revenue of assortment [0, 2] is 0.10497665499877049
# revenue of assortment [0, 5] is 0.03689352772449071
# testing for offertimes 60, 16th instance
# revenue of assortment [0, 2] is 0.105796796439404
# revenue of assortment [0, 1, 6] is 0.33608161554198196
# testing for offertimes 60, 17th instance
# revenue of assortment [0, 1] is 0.19713838464581307
# revenue of assortment [0, 3] is 0.08538872262492903
# testing for offertimes 60, 18th instance
# revenue of assortment [0, 1] is 0.29067461518092663
# revenue of assortment [0, 3, 6] is 0.182380587167214
# testing for offertimes 60, 19th instance
# revenue of assortment [0, 6] is 0.12109620646902128
# revenue of assortment [0, 5, 6] is 0.3029970112830946
# testing for offertimes 60, 20th instance
# revenue of assortment [0, 2] is 0.05011430902918809
# revenue of assortment [0, 3] is 0.08622173789020601
# testing for offertimes 60, 21th instance
# revenue of assortment [0, 5] is 0.19552060183576048
# revenue of assortment [0, 1, 6] is 0.2953384302225741
# testing for offertimes 60, 22th instance
# revenue of assortment [0, 2, 6] is 0.19903755826110708
# revenue of assortment [0, 3, 6] is 0.18427044515234708
# testing for offertimes 60, 23th instance
# revenue of assortment [0, 1] is 0.4049217301717294
# revenue of assortment [0, 2] is 0.1425862967927345
# testing for offertimes 60, 24th instance
# revenue of assortment [0, 1] is 0.38873745900904066
# revenue of assortment [0, 8] is 0.2885738502975577
# testing for offertimes 60, 25th instance
# revenue of assortment [0, 6] is 0.04842579997285523
# revenue of assortment [0, 1, 6] is 0.3350578544866064
# testing for offertimes 60, 26th instance
# revenue of assortment [0, 5, 6] is 0.2821921755811857
# revenue of assortment [0, 8] is 0.3360873399933977
# testing for offertimes 60, 27th instance
# revenue of assortment [0, 3] is 0.06967551497697284
# revenue of assortment [0, 5, 6] is 0.3415365032992669
# testing for offertimes 60, 28th instance
# revenue of assortment [0, 1] is 0.1504306382525096
# revenue of assortment [0, 2, 6] is 0.1757107472268912
# testing for offertimes 60, 29th instance
# revenue of assortment [0, 5] is 0.02423555948975924
# revenue of assortment [0, 5, 6] is 0.11972153818472245
# testing for offertimes 60, 30th instance
# revenue of assortment [0, 3] is 0.053225106265913195
# revenue of assortment [0, 2, 6] is 0.20757400485364141
# testing for offertimes 60, 31th instance
# revenue of assortment [0, 1] is 0.03572684462459912
# revenue of assortment [0, 5] is 0.3201338319123525
# testing for offertimes 60, 32th instance
# revenue of assortment [0, 2] is 0.05163775229056232
# revenue of assortment [0, 8] is 0.3475306748280216
# testing for offertimes 60, 33th instance
# revenue of assortment [0, 1, 6] is 0.3667812548784378
# revenue of assortment [0, 5, 6] is 0.33307344810263306
# testing for offertimes 60, 34th instance
# revenue of assortment [0, 3, 6] is 0.2170325871058274
# revenue of assortment [0, 8] is 0.14942927469599687
# testing for offertimes 60, 35th instance
# revenue of assortment [0, 3] is 0.07997504148105372
# revenue of assortment [0, 6] is 0.05001846338794901
# testing for offertimes 60, 36th instance
# revenue of assortment [0, 2, 6] is 0.20358292632912417
# revenue of assortment [0, 5, 6] is 0.363527158069388
# testing for offertimes 60, 37th instance
# revenue of assortment [0, 1] is 0.18496423678197904
# revenue of assortment [0, 6] is 0.10148040200213752
# testing for offertimes 60, 38th instance
# revenue of assortment [0, 2] is 0.07031754726992123
# revenue of assortment [0, 5, 8] is 0.5054343533009391
# testing for offertimes 60, 39th instance
# revenue of assortment [0, 5] is 0.10783853881028628
# revenue of assortment [0, 5, 8] is 0.4345360705464676
# testing for offertimes 60, 40th instance
# revenue of assortment [0, 2] is 0.038065940060369556
# revenue of assortment [0, 6] is 0.12705687254381184
# testing for offertimes 60, 41th instance
# revenue of assortment [0, 1] is 0.14155689903954619
# revenue of assortment [0, 5, 8] is 0.4269983132694608
# testing for offertimes 60, 42th instance
# revenue of assortment [0, 6] is 0.07754100626505858
# revenue of assortment [0, 8] is 0.21794975932419408
# testing for offertimes 60, 43th instance
# revenue of assortment [0, 2, 6] is 0.19602306195900215
# revenue of assortment [0, 8] is 0.4395628126445625
# testing for offertimes 60, 44th instance
# revenue of assortment [0, 6] is 0.09192426169512831
# revenue of assortment [0, 2, 6] is 0.17111047886575287
# testing for offertimes 60, 45th instance
# revenue of assortment [0, 2] is 0.06319885316933863
# revenue of assortment [0, 3, 6] is 0.1400584174697178
# testing for offertimes 60, 46th instance
# revenue of assortment [0, 6] is 0.05212185540814824
# revenue of assortment [0, 5, 8] is 0.650055551813321
# testing for offertimes 60, 47th instance
# revenue of assortment [0, 1, 6] is 0.34745739512736873
# revenue of assortment [0, 8] is 0.3298034124546514
# testing for offertimes 60, 48th instance
# revenue of assortment [0, 3, 6] is 0.14958964494224558
# revenue of assortment [0, 5, 6] is 0.3499254116873598
# testing for offertimes 60, 49th instance
# revenue of assortment [0, 5] is 0.3376082694773107
# revenue of assortment [0, 2, 6] is 0.17583444603401502

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mnl_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mnl_dist':all_mnl_distance_list[i],
                                    'true_best_rev':all_best_true_rev_list[i],'mnl_best_rev':all_best_rev_mnl_list[i],
                                    'mnl_best_rev_diff':all_mnl_best_rev_diff[i]})
    df_mnl_details1.to_csv('prediction/mnl/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        mnl_rank = all_mnl_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'mnl_rank':mnl_rank})
        df_rank.to_csv('prediction/mnl/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        mnl_rev = all_mnl_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'mnl_rev':mnl_rev})
        df_rev.to_csv('prediction/mnl/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
    
        mnl_runtime = all_mnl_pred_runtime[i][j]
        df_runtime = pd.DataFrame({'mnl_runtime':mnl_runtime})
        df_runtime.to_csv('prediction/mnl/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ## using sales fraction prediction
        ## record the choice probability prediction interval
        ''' true_prob = all_true_prob_list[i][j]
        df_true_prob = pd.DataFrame(true_prob)
        
        mnl_sales = all_mnl_sales_list[i][j]
        df_mnl_sales = pd.DataFrame(mnl_sales).T
 
        df_true_prob.to_csv('prediction/mnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_mnl_sales.to_csv('prediction/mnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mnl/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## avg prediction mnl runtime 
all_mnl_pred_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    avg_mnl_pred_runtime_collection = []
    
    for j in range(pred_instance_size[i]): 
        avg_mnl_pred_runtime_collection.append(np.mean(np.array(all_mnl_pred_runtime[i][j]))) 
        
    all_mnl_pred_avg_runtime.append(np.mean(np.array(avg_mnl_pred_runtime_collection)))

avg_mnl_dist = []
avg_mnl_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    
    avg_mnl_dist.append(np.mean(all_mnl_distance_list[i]))
    avg_mnl_best_rev_diff.append(np.mean(all_mnl_best_rev_diff[i]))
    

df_mnl_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'avg_mnl_dist':avg_mnl_dist,'avg_mnl_best_rev_diff':avg_mnl_best_rev_diff,
                                   'avg_mnl_pred_runtime':all_mnl_pred_avg_runtime})
df_mnl_jd_summary.to_csv('prediction/mnl/jd_mnl_summary.csv')

# %%
df_mnl_jd_summary
# Out:
#    offertimes  avg_mnl_dist  avg_mnl_best_rev_diff  avg_mnl_pred_runtime
# 0          20          2.56               0.079700              0.252538
# 1          30          1.22               0.081838              0.248655
# 2          40          0.64               0.094136              0.251810
# 3          50          0.68               0.094529              0.244268
# 4          60          0.20               0.071108              0.233608

# %%
## record representability of all instances
all_mnl_rep = []
all_mnl_rep_time = []

## record the limit loss of all instances
all_mnl_limit_loss = []
all_mnl_limit_prob = []
all_mnl_limit_runtime = []

for i in range(len(pred_offer_times_list)):
    
    ## define container for mnl representability check
    mnl_rep_collection =[]
    mnl_rep_runtime_collection =[]
    
    ## define container for mnl limit 
    mnl_limit_loss_collection =[]
    mnl_limit_runtime_collection =[]
    mnl_limit_probability_collection =[]
    
    for j in range(pred_instance_size[i]):
        
        ####### mnl representability check ##########
        
        # mnl_feasibility(data,collection,n)
        curr_rep_result = mnl_feasibility(all_full_instances[i][j],all_full_collections[i],n)
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mnl_rep_collection.append(curr_rep_result[0])
        mnl_rep_runtime_collection.append(curr_rep_result[1])
        
        if curr_rep_result[0] > 0:
           
            # representable - no loss
            mnl_limit_probability_collection.append(all_full_instances[i][j])
            mnl_limit_loss_collection.append(0)
            mnl_limit_runtime_collection.append(0)
            
        else:
            # not representable # limit 
            start_time = time.time()
            v_values1,ll_value1,ll_time1 = mnl_mle_pyo(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            # return v_values, obj_value,results.solver.time
            
            curr_limit_prob = mnl_distribution(v_values1, all_full_collections[i])
            curr_loss = 0
            for x in range(len(all_full_collections[i])):
                for y in all_full_collections[i][x]:
                    curr_loss = curr_loss + all_full_offertimes[i][x]*all_full_instances[i][j][y][x]*np.abs(all_full_instances[i][j][y][x] -curr_limit_prob[y][x])
            #curr_loss = np.sum(all_full_instances[i][j] * np.abs(all_full_instances[i][j] - curr_limit_prob))
            used_time = time.time() - start_time  
            
            mnl_limit_probability_collection.append(curr_limit_prob)
            mnl_limit_loss_collection.append(curr_loss)
            mnl_limit_runtime_collection.append(used_time)
    ## for each train instance [i][j] representability result is a number
    all_mnl_rep.append(mnl_rep_collection)
    all_mnl_rep_time.append(mnl_rep_runtime_collection)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mnl_limit_loss.append(mnl_limit_loss_collection)
    all_mnl_limit_runtime.append(mnl_limit_runtime_collection)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mnl_limit_prob.append(mnl_limit_probability_collection)

# %%
## adding rep results
ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    df_mnl_rep = pd.DataFrame({'ins_idx':ins_idx,'mnl_rep':all_mnl_rep[i], 'mnl_rep_time':all_mnl_rep_time[i]})
    df_mnl_rep.to_csv('limit/mnl/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding limit results
ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    df_mnl_loss = pd.DataFrame({'ins_idx':ins_idx,'mnl_loss':all_mnl_limit_loss[i],'avg_loss':all_mnl_limit_loss[i]/sum(all_full_offertimes[i]),  'mnl_limit_time':all_mnl_limit_runtime[i]})
    df_mnl_loss.to_csv('limit/mnl/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_mnl_limit_prob[i][j])
        df_limit_prob.to_csv('limit/mnl/limit/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss = []
for k in range(len(pred_offer_times_list)):
    all_avg_loss.append(all_mnl_limit_loss[k]/sum(all_full_offertimes[k]))

# %%
avg_mnl_rep = []
avg_mnl_rep_runtime = []

avg_total_limit_loss = []
avg_toal_limit_loss_se = []
avg_mnl_limit_runtime = []

#avg_loss = []
avg_loss_se = []

for i in range(len(pred_offer_times_list)):
    avg_mnl_rep.append(np.mean(all_mnl_rep[i]))
    avg_mnl_rep_runtime.append(np.mean(all_mnl_rep_time[i]))
    
    avg_total_limit_loss.append(np.mean(all_mnl_limit_loss[i]))
    avg_mnl_limit_runtime.append(np.sum(all_mnl_limit_runtime[i])/(pred_instance_size[i] - np.sum(all_mnl_rep[i])))
    avg_toal_limit_loss_se.append(np.std(all_mnl_limit_loss[i])/np.sqrt(len(all_mnl_limit_loss[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se.append(np.std(all_avg_loss[i])/np.sqrt(len(all_avg_loss[i])))

# %%
avg_loss = []
for i in range(len(avg_total_limit_loss)):
    avg_loss.append(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))

# %%
df_mnl_limit = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'mnl_rep':avg_mnl_rep,'mnl_rep_runtime':avg_mnl_rep_runtime,
                                   'total_mnl_loss':avg_total_limit_loss,'total_mnl_loss_se':avg_toal_limit_loss_se,
                                   'avg_mnl_loss':avg_loss,'avg_mnl_loss_se':avg_loss_se,
                                   'avg_mnl_limit_runtime':avg_mnl_limit_runtime
                                   })
df_mnl_limit.to_csv('limit/mnl/mnl_limit_summary.csv')
df_mnl_limit
# Out:
#    offertimes  mnl_rep  mnl_rep_runtime  total_mnl_loss  total_mnl_loss_se  \
# 0          20      0.0         0.000144      236.182925           3.800958
# 1          30      0.0         0.000225      214.136409           3.832030
# 2          40      0.0         0.000270      185.772978           3.634913
# 3          50      0.0         0.000327      155.570696           3.466264
# 4          60      0.0         0.000320      135.515760           3.115895
#
#    avg_mnl_loss  avg_mnl_loss_se  avg_mnl_limit_runtime
# 0      0.030853         0.000497               0.258483
# 1      0.028442         0.000509               0.246722
# 2      0.025237         0.000494               0.237927
# 3      0.021637         0.000482               0.235323
# 4      0.019135         0.000440               0.237786

# %%
for i in range(len(avg_total_limit_loss)):
    print(avg_total_limit_loss[i]/sum(all_full_offertimes[i]))
# Out:
# 0.030853419328112877
# 0.0284415472018809
# 0.025237464689342404
# 0.02163709262169603
# 0.01913523859281192
