# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
#offertimes.to_csv('offertimes.csv')
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
#inc_prod_num.to_csv('inc_prod_num.csv')
choice_prob = raw_jd_choice['clicknum'] / raw_jd_choice.groupby('clickset')['clicknum'].transform('sum')
raw_jd_choice['choice prob'] = choice_prob

assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

# all purchase options in each assortment
purchaseset = raw_jd_choice['purchaseset']
purchaseset_list = []
for pset in purchaseset:
    num_lst = json.loads(pset)
    purchaseset_list.append(num_lst)
raw_jd_choice['purchaseset'] = purchaseset_list

purchasenum_list = raw_jd_choice['clicknum'].tolist()
jd_choice=pd.DataFrame({'clickset':clickset_list,'purchaseset':purchaseset_list,'purchasenum':purchasenum_list,'choice prob':choice_prob})

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
collection = []
for cset in clickset_list:
    if cset not in collection:
        collection.append(cset)
print('there are {} different assortments'.format(len(collection)))

assortment_info_df['assortments'] = collection
choice_collection = np.zeros((n,len(collection)))
global_num = 0
for i in range(len(collection)):
    local_num =0
    while(local_num < inc_prod_num[i]):
        if purchaseset_list[global_num][0] in collection[i]:
            choice_collection[purchaseset_list[global_num][0]][i] = choice_prob[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print('error!')
full_choice_collection = pd.DataFrame(choice_collection)
#full_choice_collection.to_csv('instances/full_instances/full_choice.csv')
# Out:
# there are 9 different products
# there are 134 different assortments

# %%
assortment_info_df_20 = assortment_info_df[(assortment_info_df['offer_times']>=20)]
assortments_20 = []
for i in range(len(assortment_info_df_20['assortments'])):
    assortments_20.append(assortment_info_df_20['assortments'][i])


jd_choice_20 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_20:
        jd_choice_20.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_20 = assortment_info_df_20['assortments']
choice_collection_20 = np.zeros((n,len(collection_20)))

frequency_collection_20 = np.zeros((n,len(collection_20)))

purchaseset_list_20 = jd_choice_20['purchaseset'].tolist()

inc_prod_num_20 = assortment_info_df_20['includ_prod_num']
choice_prob_20 = jd_choice_20['choice prob']
frequency_20 = jd_choice_20['purchasenum']

global_num = 0
for i in range(len(collection_20)):
    local_num =0
    while(local_num < inc_prod_num_20[i]):
        if purchaseset_list_20[global_num][0] in assortments_20[i]:
            choice_collection_20[purchaseset_list_20[global_num][0]][i] = choice_prob_20[global_num]
            frequency_collection_20[purchaseset_list_20[global_num][0]][i] = frequency_20[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_20[global_num])
            print(assortments_20[i])
            print('error!')
            break
#print(global_num)  

choice_check_20 = pd.DataFrame(choice_collection_20)
#choice_check_20.to_csv('instances/full_instances/full_20.csv')
frequency_collection_20 = frequency_collection_20.astype(int)
frequency_check_20 = pd.DataFrame(frequency_collection_20)
#frequency_check_20.to_csv('instances/full_instances/frequency_20.csv')

offer_times_20 = assortment_info_df_20['offer_times'].tolist()
print('the number of assortments with at least 20 purchases is',len(assortments_20))
# Out:
# the number of assortments with at least 20 purchases is 29

# %%
assortment_info_df_30 = assortment_info_df[(assortment_info_df['offer_times']>=30)]
assortments_30 = []
for i in range(len(assortment_info_df_30['assortments'])):
    assortments_30.append(assortment_info_df_30['assortments'][i])


jd_choice_30 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_30:
        jd_choice_30.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_30 = assortment_info_df_30['assortments']
choice_collection_30 = np.zeros((n,len(collection_30)))

frequency_collection_30 = np.zeros((n,len(collection_30)))

purchaseset_list_30 = jd_choice_30['purchaseset'].tolist()

inc_prod_num_30 = assortment_info_df_30['includ_prod_num']
choice_prob_30 = jd_choice_30['choice prob']
frequency_30 = jd_choice_30['purchasenum']

global_num = 0
for i in range(len(collection_30)):
    local_num =0
    while(local_num < inc_prod_num_30[i]):
        if purchaseset_list_30[global_num][0] in assortments_30[i]:
            choice_collection_30[purchaseset_list_30[global_num][0]][i] = choice_prob_30[global_num]
            frequency_collection_30[purchaseset_list_30[global_num][0]][i] = frequency_30[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_30[global_num])
            print(assortments_30[i])
            print('error!')
            break
#print(global_num)  

choice_check_30 = pd.DataFrame(choice_collection_30)
#choice_check_30.to_csv('instances/full_instances/full_30.csv')
frequency_collection_30 = frequency_collection_30.astype(int)
frequency_check_30 = pd.DataFrame(frequency_collection_30)
#frequency_check_30.to_csv('instances/full_instances/frequency_30.csv')

offer_times_30 = assortment_info_df_30['offer_times'].tolist()
print('the number of assortments with at least 30 purchases is',len(assortments_30))
# Out:
# the number of assortments with at least 30 purchases is 24

# %%
assortment_info_df_40 = assortment_info_df[(assortment_info_df['offer_times']>=40)]
assortments_40 = []
for i in range(len(assortment_info_df_40['assortments'])):
    assortments_40.append(assortment_info_df_40['assortments'][i])


jd_choice_40 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_40:
        jd_choice_40.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_40 = assortment_info_df_40['assortments']
choice_collection_40 = np.zeros((n,len(collection_40)))

frequency_collection_40 = np.zeros((n,len(collection_40)))

purchaseset_list_40 = jd_choice_40['purchaseset'].tolist()

inc_prod_num_40 = assortment_info_df_40['includ_prod_num']
choice_prob_40 = jd_choice_40['choice prob']
frequency_40 = jd_choice_40['purchasenum']

global_num = 0
for i in range(len(collection_40)):
    local_num =0
    while(local_num < inc_prod_num_40[i]):
        if purchaseset_list_40[global_num][0] in assortments_40[i]:
            choice_collection_40[purchaseset_list_40[global_num][0]][i] = choice_prob_40[global_num]
            frequency_collection_40[purchaseset_list_40[global_num][0]][i] = frequency_40[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_40[global_num])
            print(assortments_40[i])
            print('error!')
            break
#print(global_num)  

choice_check_40 = pd.DataFrame(choice_collection_40)
#choice_check_40.to_csv('instances/full_instances/full_40.csv')
frequency_collection_40 = frequency_collection_40.astype(int)
frequency_check_40 = pd.DataFrame(frequency_collection_40)
#frequency_check_40.to_csv('instances/full_instances/frequency_40.csv')

offer_times_40 = assortment_info_df_40['offer_times'].tolist()
print('the number of assortments with at least 40 purchases is',len(assortments_40))
# Out:
# the number of assortments with at least 40 purchases is 19

# %%
assortment_info_df_50 = assortment_info_df[(assortment_info_df['offer_times']>=50)]
assortments_50 = []
for i in range(len(assortment_info_df_50['assortments'])):
    assortments_50.append(assortment_info_df_50['assortments'][i])


jd_choice_50 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_50:
        jd_choice_50.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_50 = assortment_info_df_50['assortments']
choice_collection_50 = np.zeros((n,len(collection_50)))

frequency_collection_50 = np.zeros((n,len(collection_50)))

purchaseset_list_50 = jd_choice_50['purchaseset'].tolist()

inc_prod_num_50 = assortment_info_df_50['includ_prod_num']
choice_prob_50 = jd_choice_50['choice prob']
frequency_50 = jd_choice_50['purchasenum']

global_num = 0
for i in range(len(collection_50)):
    local_num =0
    while(local_num < inc_prod_num_50[i]):
        if purchaseset_list_50[global_num][0] in assortments_50[i]:
            choice_collection_50[purchaseset_list_50[global_num][0]][i] = choice_prob_50[global_num]
            frequency_collection_50[purchaseset_list_50[global_num][0]][i] = frequency_50[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_50[global_num])
            print(assortments_50[i])
            print('error!')
            break
#print(global_num)  

choice_check_50 = pd.DataFrame(choice_collection_50)
#choice_check_50.to_csv('instances/full_instances/full_50.csv')
frequency_collection_50 = frequency_collection_50.astype(int)
frequency_check_50 = pd.DataFrame(frequency_collection_50)
#frequency_check_50.to_csv('instances/full_instances/frequency_50.csv')

offer_times_50 = assortment_info_df_50['offer_times'].tolist()
print('the number of assortments with at least 50 purchases is',len(assortments_50))
# Out:
# the number of assortments with at least 50 purchases is 15

# %%
assortment_info_df_60 = assortment_info_df[(assortment_info_df['offer_times']>=60)]
assortments_60 = []
for i in range(len(assortment_info_df_60['assortments'])):
    assortments_60.append(assortment_info_df_60['assortments'][i])


jd_choice_60 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_60:
        jd_choice_60.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_60 = assortment_info_df_60['assortments']
choice_collection_60 = np.zeros((n,len(collection_60)))

frequency_collection_60 = np.zeros((n,len(collection_60)))

purchaseset_list_60 = jd_choice_60['purchaseset'].tolist()

inc_prod_num_60 = assortment_info_df_60['includ_prod_num']
choice_prob_60 = jd_choice_60['choice prob']
frequency_60 = jd_choice_60['purchasenum']

global_num = 0
for i in range(len(collection_60)):
    local_num =0
    while(local_num < inc_prod_num_60[i]):
        if purchaseset_list_60[global_num][0] in assortments_60[i]:
            choice_collection_60[purchaseset_list_60[global_num][0]][i] = choice_prob_60[global_num]
            frequency_collection_60[purchaseset_list_60[global_num][0]][i] = frequency_60[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_60[global_num])
            print(assortments_60[i])
            print('error!')
            break
#print(global_num)  

choice_check_60 = pd.DataFrame(choice_collection_60)
#choice_check_60.to_csv('instances/full_instances/full_60.csv')
frequency_collection_60 = frequency_collection_60.astype(int)
frequency_check_60 = pd.DataFrame(frequency_collection_60)
#frequency_check_60.to_csv('instances/full_instances/frequency_60.csv')

offer_times_60 = assortment_info_df_60['offer_times'].tolist()
print('the number of assortments with at least 60 purchases is',len(assortments_60))
# Out:
# the number of assortments with at least 60 purchases is 13

# %%
assortment_info_df_75 = assortment_info_df[(assortment_info_df['offer_times']>=75)]
assortments_75 = []
for i in range(len(assortment_info_df_75['assortments'])):
    assortments_75.append(assortment_info_df_75['assortments'][i])


jd_choice_75 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_75:
        jd_choice_75.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_75 = assortment_info_df_75['assortments']
choice_collection_75 = np.zeros((n,len(collection_75)))

frequency_collection_75 = np.zeros((n,len(collection_75)))

purchaseset_list_75 = jd_choice_75['purchaseset'].tolist()

inc_prod_num_75 = assortment_info_df_75['includ_prod_num']
choice_prob_75 = jd_choice_75['choice prob']
frequency_75 = jd_choice_75['purchasenum']

global_num = 0
for i in range(len(collection_75)):
    local_num =0
    while(local_num < inc_prod_num_75[i]):
        if purchaseset_list_75[global_num][0] in assortments_75[i]:
            choice_collection_75[purchaseset_list_75[global_num][0]][i] = choice_prob_75[global_num]
            frequency_collection_75[purchaseset_list_75[global_num][0]][i] = frequency_75[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_75[global_num])
            print(assortments_75[i])
            print('error!')
            break
#print(global_num)  

choice_check_75 = pd.DataFrame(choice_collection_75)
#choice_check_75.to_csv('instances/full_instances/full_75.csv')
frequency_collection_75 = frequency_collection_75.astype(int)
frequency_check_75 = pd.DataFrame(frequency_collection_75)
#frequency_check_75.to_csv('instances/full_instances/frequency_75.csv')

offer_times_75 = assortment_info_df_75['offer_times'].tolist()
print('the number of assortments with at least 75 purchases is',len(assortments_75))
# Out:
# the number of assortments with at least 75 purchases is 12

# %%
assortment_info_df_100 = assortment_info_df[(assortment_info_df['offer_times']>=100)]
assortments_100 = []
for i in range(len(assortment_info_df_100['assortments'])):
    assortments_100.append(assortment_info_df_100['assortments'][i])

jd_choice_100 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_100:
        jd_choice_100.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_100 = assortment_info_df_100['assortments']
choice_collection_100 = np.zeros((n,len(collection_100)))

frequency_collection_100 = np.zeros((n,len(collection_100)))

purchaseset_list_100 = jd_choice_100['purchaseset'].tolist()

inc_prod_num_100 = assortment_info_df_100['includ_prod_num']
choice_prob_100 = jd_choice_100['choice prob']
frequency_100 = jd_choice_100['purchasenum']

global_num=0
for i in range(len(collection_100)):
    local_num =0
    while(local_num < inc_prod_num_100[i]):
        if purchaseset_list_100[global_num][0] in assortments_100[i]:
            choice_collection_100[purchaseset_list_100[global_num][0]][i] = choice_prob_100[global_num]
            frequency_collection_100[purchaseset_list_100[global_num][0]][i] = frequency_100[global_num]
            global_num = global_num +1
            local_num = local_num +1

choice_check_100 = pd.DataFrame(choice_collection_100)
#choice_check_100.to_csv('instances/full_instances/full_100.csv')
frequency_collection_100 = frequency_collection_100.astype(int)
frequency_check_100 = pd.DataFrame(frequency_collection_100)
#frequency_check_100.to_csv('instances/full_instances/frequency_100.csv')

offer_times_100 = assortment_info_df_100['offer_times'].tolist()
print('the number of assortments with at least 100 purchases is',len(assortments_100))
# Out:
# the number of assortments with at least 100 purchases is 11

# %%
assortment_info_df_15 = assortment_info_df[(assortment_info_df['offer_times']>=15)]
assortments_15 = []
for i in range(len(assortment_info_df_15['assortments'])):
    assortments_15.append(assortment_info_df_15['assortments'][i])


jd_choice_15 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_15:
        jd_choice_15.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_15 = assortment_info_df_15['assortments']
choice_collection_15 = np.zeros((n,len(collection_15)))

frequency_collection_15 = np.zeros((n,len(collection_15)))

purchaseset_list_15 = jd_choice_15['purchaseset'].tolist()

inc_prod_num_15 = assortment_info_df_15['includ_prod_num']
choice_prob_15 = jd_choice_15['choice prob']
frequency_15 = jd_choice_15['purchasenum']

global_num = 0
for i in range(len(collection_15)):
    local_num =0
    while(local_num < inc_prod_num_15[i]):
        if purchaseset_list_15[global_num][0] in assortments_15[i]:
            choice_collection_15[purchaseset_list_15[global_num][0]][i] = choice_prob_15[global_num]
            frequency_collection_15[purchaseset_list_15[global_num][0]][i] = frequency_15[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_15[global_num])
            print(assortments_15[i])
            print('error!')
            break
#print(global_num)  

choice_check_15 = pd.DataFrame(choice_collection_15)
#choice_check_15.to_csv('instances/full_instances/full_15.csv')
frequency_collection_15 = frequency_collection_15.astype(int)
frequency_check_15 = pd.DataFrame(frequency_collection_15)
#frequency_check_15.to_csv('instances/full_instances/frequency_15.csv')

offer_times_15 = assortment_info_df_15['offer_times'].tolist()
print('the number of assortments with at least 15 purchases is',len(assortments_15))
# Out:
# the number of assortments with at least 15 purchases is 38

# %% [markdown]
# both MDM and RUM represent the data with approximately 99.8% confidence interval,  we set both z = 3.090232306167813 for both RUM and MDM, which corresponding to  99.8% confidence interval

# %%
confidence_level = 0.998
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)

stardard_error_20 = np.zeros(frequency_collection_20.shape)
for i in range(stardard_error_20.shape[0]):
    for j in range(stardard_error_20.shape[1]):
        if frequency_collection_20[i][j]!=0:
            stardard_error_20[i][j] = np.sqrt((1-choice_collection_20[i][j])/frequency_collection_20[i][j])
            
lb_20 = np.zeros(frequency_collection_20.shape)
ub_20 = np.zeros(frequency_collection_20.shape)
for i in range(lb_20.shape[0]):
    for j in range(lb_20.shape[1]):
        if frequency_collection_20[i][j]!=0:
            lb_20[i][j] = choice_collection_20[i][j] * (1-target_z_score*stardard_error_20[i][j]) 
            ub_20[i][j] = choice_collection_20[i][j] * (1+target_z_score*stardard_error_20[i][j])

stardard_error_30 = np.zeros(frequency_collection_30.shape)
for i in range(stardard_error_30.shape[0]):
    for j in range(stardard_error_30.shape[1]):
        if frequency_collection_30[i][j]!=0:
            stardard_error_30[i][j] = np.sqrt((1-choice_collection_30[i][j])/frequency_collection_30[i][j])
            
lb_30 = np.zeros(frequency_collection_30.shape)
ub_30 = np.zeros(frequency_collection_30.shape)
for i in range(lb_30.shape[0]):
    for j in range(lb_30.shape[1]):
        if frequency_collection_30[i][j]!=0:
            lb_30[i][j] = choice_collection_30[i][j] * (1-target_z_score*stardard_error_30[i][j]) 
            ub_30[i][j] = choice_collection_30[i][j] * (1+target_z_score*stardard_error_30[i][j])
            
stardard_error_40 = np.zeros(frequency_collection_40.shape)
for i in range(stardard_error_40.shape[0]):
    for j in range(stardard_error_40.shape[1]):
        if frequency_collection_40[i][j]!=0:
            stardard_error_40[i][j] = np.sqrt((1-choice_collection_40[i][j])/frequency_collection_40[i][j])
            
lb_40 = np.zeros(frequency_collection_40.shape)
ub_40 = np.zeros(frequency_collection_40.shape)
for i in range(lb_40.shape[0]):
    for j in range(lb_40.shape[1]):
        if frequency_collection_40[i][j]!=0:
            lb_40[i][j] = choice_collection_40[i][j] * (1-target_z_score*stardard_error_40[i][j]) 
            ub_40[i][j] = choice_collection_40[i][j] * (1+target_z_score*stardard_error_40[i][j])

stardard_error_50 = np.zeros(frequency_collection_50.shape)
for i in range(stardard_error_50.shape[0]):
    for j in range(stardard_error_50.shape[1]):
        if frequency_collection_50[i][j]!=0:
            stardard_error_50[i][j] = np.sqrt((1-choice_collection_50[i][j])/frequency_collection_50[i][j])
            
lb_50 = np.zeros(frequency_collection_50.shape)
ub_50 = np.zeros(frequency_collection_50.shape)
for i in range(lb_50.shape[0]):
    for j in range(lb_50.shape[1]):
        if frequency_collection_50[i][j]!=0:
            lb_50[i][j] = choice_collection_50[i][j] * (1-target_z_score*stardard_error_50[i][j]) 
            ub_50[i][j] = choice_collection_50[i][j] * (1+target_z_score*stardard_error_50[i][j])
            
stardard_error_60 = np.zeros(frequency_collection_60.shape)
for i in range(stardard_error_60.shape[0]):
    for j in range(stardard_error_60.shape[1]):
        if frequency_collection_60[i][j]!=0:
            stardard_error_60[i][j] = np.sqrt((1-choice_collection_60[i][j])/frequency_collection_60[i][j])
            
lb_60 = np.zeros(frequency_collection_60.shape)
ub_60 = np.zeros(frequency_collection_60.shape)
for i in range(lb_60.shape[0]):
    for j in range(lb_60.shape[1]):
        if frequency_collection_60[i][j]!=0:
            lb_60[i][j] = choice_collection_60[i][j] * (1-target_z_score*stardard_error_60[i][j]) 
            ub_60[i][j] = choice_collection_60[i][j] * (1+target_z_score*stardard_error_60[i][j])

# %% [markdown]
# ### full data with different offertimes

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_full_instance  = [choice_collection_20,choice_collection_30,choice_collection_40,choice_collection_50,choice_collection_60]
pred_full_lb = [lb_20,lb_30,lb_40,lb_50,lb_60]
pred_full_ub = [ub_20,ub_30,ub_40,ub_50,ub_60]

pred_full_collection = [collection_20,collection_30,collection_40,collection_50,collection_60]
pred_full_collection_size = [len(offer_times_20),len(offer_times_30),len(offer_times_40),len(offer_times_50),len(offer_times_60)]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
#pred_instance_size = [100,100,100,50,50]
pred_instance_size = [50,50,50,50,50]

price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

pred_full_offertimes = [offer_times_20,offer_times_30,offer_times_40,offer_times_50,offer_times_60]

# %% [markdown]
# train-test split

# %%
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(pred_full_collection[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(pred_full_collection[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(pred_full_collection[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = pred_full_instance[i][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = pred_full_lb[i][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = pred_full_ub[i][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(pred_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(pred_full_collection[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = pred_full_instance[i][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        ''' df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
pd.DataFrame(all_train_instances[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.735746  0.705128  0.647154  0.773333  0.738497  0.741758  0.736842
# 1  0.264254  0.000000  0.000000  0.000000  0.000000  0.000000  0.070175
# 2  0.000000  0.294872  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.352846  0.000000  0.000000  0.000000  0.192982
# 4  0.000000  0.000000  0.000000  0.226667  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.261503  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.258242  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...    14        15        16        17  \
# 0  0.745098  0.847826  0.846774  ...  0.75  0.692308  0.715447  0.791667
# 1  0.176471  0.130435  0.048387  ...  0.00  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.25  0.269231  0.211382  0.166667
# 4  0.078431  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 5  0.000000  0.021739  0.000000  ...  0.00  0.038462  0.000000  0.000000
# 6  0.000000  0.000000  0.104839  ...  0.00  0.000000  0.073171  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.041667
#
#         18        19        20        21        22        23
# 0  0.78125  0.822222  0.739130  0.642857  0.714286  0.688805
# 1  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.18750  0.022222  0.043478  0.035714  0.000000  0.000000
# 5  0.03125  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.00000  0.155556  0.000000  0.000000  0.142857  0.000000
# 7  0.00000  0.000000  0.217391  0.000000  0.142857  0.000000
# 8  0.00000  0.000000  0.000000  0.285714  0.000000  0.311195
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_test_instance[0][0])
# Out:
#          0      1         2         3         4
# 0  0.91442  0.625  0.686567  0.748744  0.757576
# 1  0.00000  0.000  0.000000  0.000000  0.000000
# 2  0.00000  0.000  0.000000  0.000000  0.000000
# 3  0.00000  0.275  0.000000  0.000000  0.000000
# 4  0.00000  0.000  0.000000  0.000000  0.000000
# 5  0.08558  0.000  0.044776  0.060302  0.000000
# 6  0.00000  0.000  0.268657  0.000000  0.121212
# 7  0.00000  0.100  0.000000  0.000000  0.000000
# 8  0.00000  0.000  0.000000  0.190955  0.121212

# %%
pd.DataFrame(all_train_lb[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.690626  0.545579  0.605049  0.712343  0.705724  0.683877  0.556603
# 1  0.219134  0.000000  0.000000  0.000000  0.000000  0.000000 -0.034380
# 2  0.000000  0.135323  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.310740  0.000000  0.000000  0.000000  0.031452
# 4  0.000000  0.000000  0.000000  0.165676  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.228729  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.200360  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.556516  0.684169  0.746813  ...  0.538426  0.412595  0.589726  0.535492
# 1  0.011509 -0.023013 -0.011162  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.038426  0.000414  0.097618 -0.068415
# 4 -0.037905  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5  0.000000 -0.044706  0.000000  ...  0.000000 -0.078085  0.000000  0.000000
# 6  0.000000  0.000000  0.019824  ...  0.000000  0.000000  0.000609  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000 -0.084382
#
#          18        19        20        21        22        23
# 0  0.555418  0.646098  0.456187  0.363030  0.478314  0.626481
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4 -0.025720 -0.045682 -0.087926 -0.072662  0.000000  0.000000
# 5 -0.063799  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000 -0.011405  0.000000  0.000000 -0.039925  0.000000
# 7  0.000000  0.000000 -0.048388  0.000000 -0.039925  0.000000
# 8  0.000000  0.000000  0.000000  0.021890  0.000000  0.248872
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_train_ub[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.780866  0.864677  0.689260  0.834324  0.771271  0.799640  0.917081
# 1  0.309374  0.000000  0.000000  0.000000  0.000000  0.000000  0.174731
# 2  0.000000  0.454421  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.394951  0.000000  0.000000  0.000000  0.354513
# 4  0.000000  0.000000  0.000000  0.287657  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.294276  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.316123  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.933680  1.011484  0.946735  ...  0.961574  0.972020  0.841168  1.047841
# 1  0.341432  0.283882  0.107936  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.461574  0.538048  0.325146  0.401749
# 4  0.194768  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5  0.000000  0.088184  0.000000  ...  0.000000  0.155009  0.000000  0.000000
# 6  0.000000  0.000000  0.189853  ...  0.000000  0.000000  0.145732  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.167715
#
#          18        19        20        21        22        23
# 0  1.007082  0.998346  1.022074  0.922685  0.950257  0.751128
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.400720  0.090127  0.174883  0.144091  0.000000  0.000000
# 5  0.126299  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.322516  0.000000  0.000000  0.325640  0.000000
# 7  0.000000  0.000000  0.483170  0.000000  0.325640  0.000000
# 8  0.000000  0.000000  0.000000  0.549538  0.000000  0.373519
#
# [9 rows x 24 columns]

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.opt import SolverFactory

def mnl_mle_pyo(data, collection,offertimes):
    n = data.shape[0]
    model = pyo.ConcreteModel()
    model.v = pyo.Var(range(n), bounds=(-100, 100))
    
    def obj_rule(model):
        obj = 0
        for i in range(len(collection)):
            for j in collection[i]:
                obj += offertimes[i]*data[j][i] * model.v[j]
            obj -= offertimes[i]*pyo.log(sum([pyo.exp(model.v[k]) for k in collection[i]]))
        return obj
    
    model.obj = pyo.Objective(rule=obj_rule, sense=pyo.maximize)
    
    # scale the preference of the outside option to be 1
    model.outsideopt_constraint = pyo.Constraint(expr=model.v[0] == 0)
    
    opt = pyo.SolverFactory('ipopt')  # use iterior point method to solve convex optimizatio problem 
    results = opt.solve(model)
    
    if (results.solver.status == pyo.SolverStatus.ok) and (results.solver.termination_condition == pyo.TerminationCondition.optimal):
        v_values = [model.v[i].value for i in range(n)]
        obj_value = model.obj()
        #model.pprint()
        return v_values, obj_value,results.solver.time
    else:
        raise ValueError("Solver failed to find an optimal solution.")

# %%
def mnl_distribution(v, collection):
    collection_distribution = np.zeros((len(v), len(collection)))
    for i, curr_collection in enumerate(collection):
        curr_total_v = np.sum([np.exp(v[j]) for j in curr_collection])
        for k, idx in enumerate(curr_collection):
            collection_distribution[idx][i] = np.exp(v[idx]) / curr_total_v
    
    return collection_distribution

# %%
## prediction for the current testing collection of assortments 
def mnl_prediction(curr_test_instance,curr_test_collection,price,v_values):
    ''' true assortment ranking '''
    true_choice_prob = [] 
    true_revenue = []
    
    mnl_revenue = []
    mnl_sales = []
    
    mnl_runtime = []
    
    
    # mle estimate
    start_time = time.time()
    estimated_oos_prob = mnl_distribution(v_values,curr_test_collection)
    used_t_1 = time.time() - start_time
    
    for k in range(len(curr_test_collection)):

        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        true_choice_prob.append(curr_test_instance[:,k])
        
        st_time_2 = time.time()
        curr_mnl_rev = np.dot(estimated_oos_prob[:,k],price)
        used_t_2 = time.time() - st_time_2
        
        mnl_sales.append(estimated_oos_prob[:,k])
        mnl_revenue.append(curr_mnl_rev)
        print(f'revenue of assortment {curr_test_collection[k]} is {curr_mnl_rev}')
        
        ## record the runtime result
        mnl_runtime.append(used_t_1+used_t_2)
        
    return true_revenue,true_choice_prob,mnl_revenue,mnl_sales,mnl_runtime

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record representability of all instances

## record the kendall tau distance between the predicted ranking of mnl and the truth
all_mnl_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_rev_list = []
all_best_rev_mnl_list = []  

## record the difference in best assortment
all_mnl_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_mnl_revenue_list = []

all_true_prob_list = [] 
all_mnl_sales_list = []

all_true_ranking = []
all_mnl_ranking = []

## record the runtime of mnl prediction
all_mnl_pred_runtime = []

for i in range(len(pred_full_collection)):
       
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    mnl_best_rev_collection = [] # a container for the best revenue predicted by robust mnl
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    mnl_ranking_collection = [] # a container for ranking by robust mnl
    
    mnl_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust mnl
   
    
    true_choice_prob_collection = []
    mnl_sales_frac_collection = []

    true_revenue_collection = []
    mnl_revenue_collection = []
    
    mnl_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        ## mle 
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        
        v_values,ll_value,ll_time = mnl_mle_pyo(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j])
        ########### mnl prediction#################
        # mnl_prediction(curr_test_instance,curr_test_collection,price,v_values)
        true_revenue,true_choice_prob,mnl_revenue,mnl_sales,mnl_runtime = mnl_prediction(all_test_instance[i][j],all_test_collection[i][j],price,v_values)
        # the following lists are of the same size as number of testing assortments
        
        for x in range(len(mnl_runtime)):
            mnl_runtime[x] = mnl_runtime[x] + ll_time
        
        true_revenue_collection.append(true_revenue)
        true_choice_prob_collection.append(true_choice_prob)
        
        mnl_revenue_collection.append(mnl_revenue)   
        mnl_sales_frac_collection.append(mnl_sales)
        mnl_runtime_collection.append(mnl_runtime)
         
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_mnl_rank  = np.argsort(-np.array(mnl_revenue)) 
        mnl_ranking_collection.append(curr_mnl_rank)
        mnl_best_rev_collection.append(true_revenue[curr_mnl_rank[0]])
        
        
        #  mnl kendallTau Distance for current instance [i][j]
        curr_mnl_dist = kendall_tau_distance(curr_true_rank, curr_mnl_rank)
        mnl_distance_collection.append(curr_mnl_dist)
    
    
    # for each test instance [i][j] kendall tau distance is a number
    all_mnl_distance_list.append(mnl_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_rev_list.append(true_best_rev_collection) 
    all_best_rev_mnl_list.append(mnl_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_mnl_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(mnl_best_rev_collection))/ np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    
    all_mnl_revenue_list.append(mnl_revenue_collection)
    
    all_true_prob_list.append(true_choice_prob_collection)
    all_mnl_sales_list.append(mnl_sales_frac_collection)
 
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_mnl_ranking.append(mnl_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_mnl_pred_runtime.append(mnl_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# revenue of assortment [0, 5] is 0.04433014971095317
# revenue of assortment [0, 3, 7] is 0.22899011370526687
# revenue of assortment [0, 5, 6] is 0.145450409661607
# revenue of assortment [0, 5, 8] is 0.4864458490082007
# revenue of assortment [0, 6, 8] is 0.4688893658997096
# testing for offertimes 20, 1th instance
# revenue of assortment [0, 3] is 0.10902744444016627
# revenue of assortment [0, 4] is 0.14466513839648812
# revenue of assortment [0, 1, 4] is 0.33665480427732564
# revenue of assortment [0, 3, 4] is 0.20892117008120653
# revenue of assortment [0, 5, 6] is 0.18047301777168287
# testing for offertimes 20, 2th instance
# revenue of assortment [0, 1, 8] is 0.5559583752083967
# revenue of assortment [0, 2, 6] is 0.18627608107412308
# revenue of assortment [0, 3, 4] is 0.3403337460764078
# revenue of assortment [0, 4, 5] is 0.37630494725892927
# revenue of assortment [0, 5, 8] is 0.4946948840022516
# testing for offertimes 20, 3th instance
# revenue of assortment [0, 1] is 0.12159670406842962
# revenue of assortment [0, 4] is 0.1417410648598968
# revenue of assortment [0, 7] is 0.11017263033850502
# revenue of assortment [0, 3, 4] is 0.22107449170492993
# revenue of assortment [0, 8] is 0.3257026977976328
# testing for offertimes 20, 4th instance
# revenue of assortment [0, 1, 8] is 0.5362113193181454
# revenue of assortment [0, 2, 3, 6] is 0.2292382668483604
# revenue of assortment [0, 3, 8] is 0.4164097997357916
# revenue of assortment [0, 5, 6] is 0.18189618669574287
# revenue of assortment [0, 6, 7] is 0.22553844270300494
# testing for offertimes 20, 5th instance
# revenue of assortment [0, 1] is 0.1085885681065095
# revenue of assortment [0, 1, 4] is 0.3839780185187601
# revenue of assortment [0, 2, 6] is 0.18531744889015947
# revenue of assortment [0, 4, 7] is 0.3934869611338999
# revenue of assortment [0, 5, 6] is 0.18084354994722818
# testing for offertimes 20, 6th instance
# revenue of assortment [0, 4] is 0.1334860987246157
# revenue of assortment [0, 1, 3] is 0.28532811011558873
# revenue of assortment [0, 3, 7] is 0.22929235087736202
# revenue of assortment [0, 4, 8] is 0.5251239476538877
# revenue of assortment [0, 5, 8] is 0.496876563222009
# testing for offertimes 20, 7th instance
# revenue of assortment [0, 1] is 0.15670978250012624
# revenue of assortment [0, 1, 6] is 0.22782126006269166
# revenue of assortment [0, 3, 6] is 0.19632265026500473
# revenue of assortment [0, 4, 5] is 0.3598295179128237
# revenue of assortment [0, 8] is 0.3300709272308238
# testing for offertimes 20, 8th instance
# revenue of assortment [0, 1] is 0.1280917622460667
# revenue of assortment [0, 7] is 0.11246992955547389
# revenue of assortment [0, 1, 8] is 0.38060334079841623
# revenue of assortment [0, 4, 6] is 0.3487128278853828
# revenue of assortment [0, 8] is 0.30660867338155817
# testing for offertimes 20, 9th instance
# revenue of assortment [0, 1] is 0.12895814409908316
# revenue of assortment [0, 1, 3] is 0.21092273531588152
# revenue of assortment [0, 2, 3, 6] is 0.22953211846114824
# revenue of assortment [0, 3, 5] is 0.19028838381494723
# revenue of assortment [0, 4, 8] is 0.5967887761316247
# testing for offertimes 20, 10th instance
# revenue of assortment [0, 1, 3] is 0.2871519485110651
# revenue of assortment [0, 2, 6] is 0.18799984094476643
# revenue of assortment [0, 3, 4] is 0.3414059899734696
# revenue of assortment [0, 3, 6] is 0.19682879834401815
# revenue of assortment [0, 5, 6] is 0.18415720405475994
# testing for offertimes 20, 11th instance
# revenue of assortment [0, 1, 3] is 0.2865012318827922
# revenue of assortment [0, 1, 7] is 0.3308787820907028
# revenue of assortment [0, 2, 6] is 0.186255239901985
# revenue of assortment [0, 4, 6] is 0.3526352707172481
# revenue of assortment [0, 5, 6] is 0.1822378675057888
# testing for offertimes 20, 12th instance
# revenue of assortment [0, 1] is 0.12248315508374083
# revenue of assortment [0, 1, 5] is 0.1994368263077545
# revenue of assortment [0, 2, 3, 6] is 0.23107247221309923
# revenue of assortment [0, 3, 6] is 0.19468259421299589
# revenue of assortment [0, 6, 7] is 0.22642370791284966
# testing for offertimes 20, 13th instance
# revenue of assortment [0, 4] is 0.08189552110693424
# revenue of assortment [0, 6] is 0.08857651249679736
# revenue of assortment [0, 4, 5] is 0.16650775311194088
# revenue of assortment [0, 4, 8] is 0.47193121832065377
# revenue of assortment [0, 6, 8] is 0.4342032570723447
# testing for offertimes 20, 14th instance
# revenue of assortment [0, 4] is 0.13409192514930318
# revenue of assortment [0, 1, 5] is 0.3149905272130869
# revenue of assortment [0, 1, 6] is 0.300853133745601
# revenue of assortment [0, 4, 8] is 0.4040932018768176
# revenue of assortment [0, 8] is 0.3167324173362756
# testing for offertimes 20, 15th instance
# revenue of assortment [0, 2, 3, 6] is 0.22938547540931992
# revenue of assortment [0, 3, 5] is 0.18956179372386192
# revenue of assortment [0, 4, 7] is 0.3931786143716473
# revenue of assortment [0, 4, 8] is 0.6033938694298346
# revenue of assortment [0, 6, 7] is 0.22571225072594994
# testing for offertimes 20, 16th instance
# revenue of assortment [0, 7] is 0.12366513785636654
# revenue of assortment [0, 1, 5] is 0.3013429639579225
# revenue of assortment [0, 3, 7] is 0.2024281975017104
# revenue of assortment [0, 4, 6] is 0.3512464686698964
# revenue of assortment [0, 8] is 0.33263296991356917
# testing for offertimes 20, 17th instance
# revenue of assortment [0, 1, 8] is 0.5357254782633645
# revenue of assortment [0, 3, 4] is 0.34071755102474166
# revenue of assortment [0, 3, 5] is 0.19036049524413362
# revenue of assortment [0, 3, 7] is 0.22950432098342016
# revenue of assortment [0, 6, 8] is 0.43428989809535745
# testing for offertimes 20, 18th instance
# revenue of assortment [0, 2] is 0.08978048142409345
# revenue of assortment [0, 1, 3] is 0.2861743166089981
# revenue of assortment [0, 3, 4] is 0.3470235584072802
# revenue of assortment [0, 4, 8] is 0.6133449375644694
# revenue of assortment [0, 6, 8] is 0.436430022462551
# testing for offertimes 20, 19th instance
# revenue of assortment [0, 6] is 0.09014964083902749
# revenue of assortment [0, 1, 8] is 0.5545695741950722
# revenue of assortment [0, 2, 3, 6] is 0.2166702684186286
# revenue of assortment [0, 4, 6] is 0.345356109634009
# revenue of assortment [0, 5, 8] is 0.4929159654846914
# testing for offertimes 20, 20th instance
# revenue of assortment [0, 1, 7] is 0.32707667664430384
# revenue of assortment [0, 3, 6] is 0.19472645895017457
# revenue of assortment [0, 4, 7] is 0.38716365605063946
# revenue of assortment [0, 5, 6] is 0.18254325742208222
# revenue of assortment [0, 8] is 0.3325629785069859
# testing for offertimes 20, 21th instance
# revenue of assortment [0, 3] is 0.11017413330901918
# revenue of assortment [0, 1, 7] is 0.32663587012749296
# revenue of assortment [0, 2, 6] is 0.18560444814650764
# revenue of assortment [0, 4, 6] is 0.35860556340964816
# revenue of assortment [0, 4, 8] is 0.6081175935075722
# testing for offertimes 20, 22th instance
# revenue of assortment [0, 4] is 0.14654381610384434
# revenue of assortment [0, 6] is 0.08272174214585494
# revenue of assortment [0, 3, 5] is 0.18984922317503955
# revenue of assortment [0, 4, 6] is 0.19945353308330183
# revenue of assortment [0, 5, 6] is 0.1573170462342731
# testing for offertimes 20, 23th instance
# revenue of assortment [0, 1, 7] is 0.33093784763974976
# revenue of assortment [0, 1, 8] is 0.5310958174239083
# revenue of assortment [0, 3, 4] is 0.3407017326923765
# revenue of assortment [0, 3, 5] is 0.19028010047041738
# revenue of assortment [0, 6, 7] is 0.22822741314546818
# testing for offertimes 20, 24th instance
# revenue of assortment [0, 1] is 0.12215699769370002
# revenue of assortment [0, 2] is 0.0895371784309146
# revenue of assortment [0, 1, 5] is 0.1991227040180442
# revenue of assortment [0, 3, 4] is 0.3446974060581461
# revenue of assortment [0, 4, 8] is 0.6057132426560954
# testing for offertimes 20, 25th instance
# revenue of assortment [0, 1, 8] is 0.541500348666298
# revenue of assortment [0, 3, 7] is 0.22930455534401273
# revenue of assortment [0, 3, 8] is 0.4216076420728144
# revenue of assortment [0, 4, 7] is 0.3876338674150741
# revenue of assortment [0, 6, 8] is 0.44061692621217124
# testing for offertimes 20, 26th instance
# revenue of assortment [0, 1] is 0.12530999344531554
# revenue of assortment [0, 6] is 0.08714266664804964
# revenue of assortment [0, 1, 3] is 0.2085740325968742
# revenue of assortment [0, 3, 5] is 0.1907532037177117
# revenue of assortment [0, 4, 5] is 0.3592068509314984
# testing for offertimes 20, 27th instance
# revenue of assortment [0, 7] is 0.11664139918913062
# revenue of assortment [0, 1, 3] is 0.28649076231270193
# revenue of assortment [0, 3, 6] is 0.1959121669069455
# revenue of assortment [0, 5, 6] is 0.18369452507729994
# revenue of assortment [0, 6, 8] is 0.4386217083469562
# testing for offertimes 20, 28th instance
# revenue of assortment [0, 1, 7] is 0.3315702055202322
# revenue of assortment [0, 1, 8] is 0.5358937540546955
# revenue of assortment [0, 3, 5] is 0.18998119104527894
# revenue of assortment [0, 3, 7] is 0.23155891994424438
# revenue of assortment [0, 6, 8] is 0.43418890782075126
# testing for offertimes 20, 29th instance
# revenue of assortment [0, 1, 4] is 0.47021944354897455
# revenue of assortment [0, 1, 7] is 0.3281735361537183
# revenue of assortment [0, 2, 6] is 0.18868958656201656
# revenue of assortment [0, 3, 6] is 0.1961462520334934
# revenue of assortment [0, 4, 6] is 0.3627513886067077
# testing for offertimes 20, 30th instance
# revenue of assortment [0, 1] is 0.12931356168122543
# revenue of assortment [0, 1, 8] is 0.5136552073333036
# revenue of assortment [0, 3, 8] is 0.4429457808846825
# revenue of assortment [0, 4, 8] is 0.6271765487068977
# revenue of assortment [0, 5, 8] is 0.5021526055417653
# testing for offertimes 20, 31th instance
# revenue of assortment [0, 3, 5] is 0.18922365407431663
# revenue of assortment [0, 4, 8] is 0.5315428162222912
# revenue of assortment [0, 6, 7] is 0.22584871998598108
# revenue of assortment [0, 6, 8] is 0.3554047009817044
# revenue of assortment [0, 8] is 0.3252447490211787
# testing for offertimes 20, 32th instance
# revenue of assortment [0, 5] is 0.03789518207456366
# revenue of assortment [0, 3, 5] is 0.15740523672758727
# revenue of assortment [0, 3, 6] is 0.19512573270877742
# revenue of assortment [0, 5, 6] is 0.14305638683831
# revenue of assortment [0, 5, 8] is 0.473896878261584
# testing for offertimes 20, 33th instance
# revenue of assortment [0, 2] is 0.09395939870653898
# revenue of assortment [0, 7] is 0.11611993680202697
# revenue of assortment [0, 2, 3, 6] is 0.22502235712408641
# revenue of assortment [0, 3, 4] is 0.33993280809178383
# revenue of assortment [0, 6, 8] is 0.43833287203267024
# testing for offertimes 20, 34th instance
# revenue of assortment [0, 7] is 0.14165929351969206
# revenue of assortment [0, 1, 7] is 0.31351521197882737
# revenue of assortment [0, 3, 5] is 0.19176686717735802
# revenue of assortment [0, 3, 6] is 0.1954279435618631
# revenue of assortment [0, 3, 7] is 0.2150723564477772
# testing for offertimes 20, 35th instance
# revenue of assortment [0, 1] is 0.11501844786055522
# revenue of assortment [0, 1, 7] is 0.24314566469048687
# revenue of assortment [0, 2, 3, 6] is 0.22892123834535555
# revenue of assortment [0, 3, 4] is 0.33849026489969586
# revenue of assortment [0, 6, 7] is 0.22808718523344662
# testing for offertimes 20, 36th instance
# revenue of assortment [0, 1, 6] is 0.30067728330818505
# revenue of assortment [0, 2, 6] is 0.1903588969589192
# revenue of assortment [0, 3, 6] is 0.19800363830457762
# revenue of assortment [0, 3, 8] is 0.4478441647127238
# revenue of assortment [0, 5, 8] is 0.5089474135823756
# testing for offertimes 20, 37th instance
# revenue of assortment [0, 1] is 0.12928061823214163
# revenue of assortment [0, 1, 3] is 0.2116310610254993
# revenue of assortment [0, 3, 8] is 0.4460437771386101
# revenue of assortment [0, 4, 5] is 0.36055518582808277
# revenue of assortment [0, 5, 8] is 0.506853388987847
# testing for offertimes 20, 38th instance
# revenue of assortment [0, 3] is 0.10959852341178813
# revenue of assortment [0, 6] is 0.09676366405471765
# revenue of assortment [0, 3, 6] is 0.16638621279894564
# revenue of assortment [0, 3, 7] is 0.21719273845136647
# revenue of assortment [0, 6, 8] is 0.4362372928747118
# testing for offertimes 20, 39th instance
# revenue of assortment [0, 1, 4] is 0.45777674337901897
# revenue of assortment [0, 3, 6] is 0.19571787324518947
# revenue of assortment [0, 5, 8] is 0.5082354942308878
# revenue of assortment [0, 6, 7] is 0.22745372771582845
# revenue of assortment [0, 6, 8] is 0.4691220798495797
# testing for offertimes 20, 40th instance
# revenue of assortment [0, 2] is 0.08946921607987599
# revenue of assortment [0, 3] is 0.10978463871541243
# revenue of assortment [0, 4, 6] is 0.3515725876140993
# revenue of assortment [0, 6, 7] is 0.22537419259929664
# revenue of assortment [0, 6, 8] is 0.4378182697465864
# testing for offertimes 20, 41th instance
# revenue of assortment [0, 1] is 0.10903627169034891
# revenue of assortment [0, 1, 3] is 0.1986664768723577
# revenue of assortment [0, 1, 4] is 0.37806229825429005
# revenue of assortment [0, 2, 6] is 0.185394756370186
# revenue of assortment [0, 5, 6] is 0.18086462701503697
# testing for offertimes 20, 42th instance
# revenue of assortment [0, 4] is 0.11351129599897215
# revenue of assortment [0, 6] is 0.08830207601407243
# revenue of assortment [0, 1, 4] is 0.31503983807632907
# revenue of assortment [0, 3, 8] is 0.44571419348537356
# revenue of assortment [0, 5, 8] is 0.5053067416943934
# testing for offertimes 20, 43th instance
# revenue of assortment [0, 3] is 0.10735932094817952
# revenue of assortment [0, 6] is 0.08770150267023825
# revenue of assortment [0, 1, 4] is 0.4566966387490644
# revenue of assortment [0, 1, 5] is 0.3019435904965553
# revenue of assortment [0, 1, 7] is 0.32850749276330016
# testing for offertimes 20, 44th instance
# revenue of assortment [0, 6] is 0.08898194626902753
# revenue of assortment [0, 1, 4] is 0.4688223101119634
# revenue of assortment [0, 3, 5] is 0.19009946981065767
# revenue of assortment [0, 4, 5] is 0.3883626726708346
# revenue of assortment [0, 4, 6] is 0.3546570036441268
# testing for offertimes 20, 45th instance
# revenue of assortment [0, 1, 5] is 0.3173467318844577
# revenue of assortment [0, 1, 6] is 0.3026534442733992
# revenue of assortment [0, 2, 6] is 0.1880898828139403
# revenue of assortment [0, 3, 4] is 0.3460185555023021
# revenue of assortment [0, 4, 7] is 0.3978241578306052
# testing for offertimes 20, 46th instance
# revenue of assortment [0, 1] is 0.12319092845664216
# revenue of assortment [0, 4] is 0.1450029020382285
# revenue of assortment [0, 1, 5] is 0.19975161172604086
# revenue of assortment [0, 1, 8] is 0.47255939407287006
# revenue of assortment [0, 3, 4] is 0.22338049313929706
# testing for offertimes 20, 47th instance
# revenue of assortment [0, 7] is 0.11678826083055767
# revenue of assortment [0, 1, 4] is 0.4668577534295024
# revenue of assortment [0, 1, 6] is 0.29984823859041687
# revenue of assortment [0, 2, 3, 6] is 0.23021212468922203
# revenue of assortment [0, 5, 8] is 0.49907700818787426
# testing for offertimes 20, 48th instance
# revenue of assortment [0, 4] is 0.12138318332779569
# revenue of assortment [0, 1, 4] is 0.32095643576105554
# revenue of assortment [0, 3, 5] is 0.1887289687736195
# revenue of assortment [0, 4, 8] is 0.39477432938655677
# revenue of assortment [0, 8] is 0.31569652582468494
# testing for offertimes 20, 49th instance
# revenue of assortment [0, 1] is 0.12452183887113182
# revenue of assortment [0, 7] is 0.10921690042831798
# revenue of assortment [0, 2, 3, 6] is 0.22892736769804395
# revenue of assortment [0, 3, 8] is 0.41894497554162835
# revenue of assortment [0, 6, 7] is 0.18651371554593082
# testing for offertimes 30, 0th instance
# revenue of assortment [0, 1] is 0.13335750550901107
# revenue of assortment [0, 5] is 0.07541170928215635
# revenue of assortment [0, 1, 3] is 0.21413042461987997
# revenue of assortment [0, 1, 8] is 0.4812146929615423
# testing for offertimes 30, 1th instance
# revenue of assortment [0, 2] is 0.08870029875558463
# revenue of assortment [0, 6] is 0.08877953493302873
# revenue of assortment [0, 3, 4] is 0.3512035664301838
# revenue of assortment [0, 8] is 0.32938758019449205
# testing for offertimes 30, 2th instance
# revenue of assortment [0, 2, 6] is 0.1982544737185803
# revenue of assortment [0, 3, 7] is 0.2306978685095991
# revenue of assortment [0, 6, 7] is 0.22896734125961676
# revenue of assortment [0, 6, 8] is 0.4429461609014861
# testing for offertimes 30, 3th instance
# revenue of assortment [0, 1, 3] is 0.2863457142406747
# revenue of assortment [0, 4, 5] is 0.3770084441307816
# revenue of assortment [0, 5, 8] is 0.5185818562459803
# revenue of assortment [0, 6, 8] is 0.47769313459495966
# testing for offertimes 30, 4th instance
# revenue of assortment [0, 1, 3] is 0.2865982102164827
# revenue of assortment [0, 3, 4] is 0.35253223156543373
# revenue of assortment [0, 3, 7] is 0.23028620266826597
# revenue of assortment [0, 5, 8] is 0.5073826153696414
# testing for offertimes 30, 5th instance
# revenue of assortment [0, 1] is 0.12987055645155113
# revenue of assortment [0, 1, 8] is 0.48080912353353444
# revenue of assortment [0, 4, 6] is 0.36344743568240356
# revenue of assortment [0, 6, 7] is 0.22508570784519843
# testing for offertimes 30, 6th instance
# revenue of assortment [0, 1, 6] is 0.29976589706587364
# revenue of assortment [0, 2, 6] is 0.19967415421519022
# revenue of assortment [0, 5, 8] is 0.5077716077027035
# revenue of assortment [0, 6, 7] is 0.22785966982825487
# testing for offertimes 30, 7th instance
# revenue of assortment [0, 2] is 0.09386633625319186
# revenue of assortment [0, 5] is 0.07958169331220175
# revenue of assortment [0, 1, 5] is 0.2916608427676003
# revenue of assortment [0, 8] is 0.32909432297829566
# testing for offertimes 30, 8th instance
# revenue of assortment [0, 2] is 0.093783449990092
# revenue of assortment [0, 3] is 0.10503938462241731
# revenue of assortment [0, 7] is 0.1005084579474154
# revenue of assortment [0, 1, 5] is 0.3017730060954595
# testing for offertimes 30, 9th instance
# revenue of assortment [0, 3] is 0.1038119632573326
# revenue of assortment [0, 6] is 0.0883724777100359
# revenue of assortment [0, 1, 5] is 0.2999801012639655
# revenue of assortment [0, 8] is 0.32981193079014437
# testing for offertimes 30, 10th instance
# revenue of assortment [0, 5] is 0.0771554695458355
# revenue of assortment [0, 1, 4] is 0.48341234781068293
# revenue of assortment [0, 2, 6] is 0.19797858899822407
# revenue of assortment [0, 4, 6] is 0.3767482357856853
# testing for offertimes 30, 11th instance
# revenue of assortment [0, 1] is 0.1261403168292173
# revenue of assortment [0, 2] is 0.09386846120275125
# revenue of assortment [0, 4, 5] is 0.39045026082712453
# revenue of assortment [0, 4, 6] is 0.3633102028912348
# testing for offertimes 30, 12th instance
# revenue of assortment [0, 6] is 0.08959037156134204
# revenue of assortment [0, 7] is 0.10146000102809004
# revenue of assortment [0, 3, 4] is 0.3660540555858817
# revenue of assortment [0, 4, 6] is 0.37424407223357625
# testing for offertimes 30, 13th instance
# revenue of assortment [0, 2] is 0.09386696554644626
# revenue of assortment [0, 3, 7] is 0.22920488434207406
# revenue of assortment [0, 5, 6] is 0.18219646855212268
# revenue of assortment [0, 6, 8] is 0.4428887327348311
# testing for offertimes 30, 14th instance
# revenue of assortment [0, 4] is 0.13858201682024776
# revenue of assortment [0, 7] is 0.10851960435367597
# revenue of assortment [0, 1, 7] is 0.2974713931361352
# revenue of assortment [0, 1, 8] is 0.5341210726946963
# testing for offertimes 30, 15th instance
# revenue of assortment [0, 7] is 0.09499198340216473
# revenue of assortment [0, 2, 6] is 0.19826634365311213
# revenue of assortment [0, 4, 6] is 0.3659552432681249
# revenue of assortment [0, 6, 7] is 0.17827892185778207
# testing for offertimes 30, 16th instance
# revenue of assortment [0, 4] is 0.17063780074928064
# revenue of assortment [0, 7] is 0.10397706431659597
# revenue of assortment [0, 3, 6] is 0.1957154928684771
# revenue of assortment [0, 4, 6] is 0.24051421786440458
# testing for offertimes 30, 17th instance
# revenue of assortment [0, 1, 5] is 0.3059748876495166
# revenue of assortment [0, 1, 8] is 0.5362832347266693
# revenue of assortment [0, 3, 7] is 0.23073715107594794
# revenue of assortment [0, 6, 7] is 0.22835047519230484
# testing for offertimes 30, 18th instance
# revenue of assortment [0, 1] is 0.1588478473095422
# revenue of assortment [0, 1, 6] is 0.2294758215772103
# revenue of assortment [0, 3, 6] is 0.19691310056038935
# revenue of assortment [0, 5, 6] is 0.18602605453820556
# testing for offertimes 30, 19th instance
# revenue of assortment [0, 1] is 0.12226960393331895
# revenue of assortment [0, 6] is 0.08801700576460193
# revenue of assortment [0, 1, 5] is 0.19937512320418768
# revenue of assortment [0, 1, 8] is 0.4766784442884229
# testing for offertimes 30, 20th instance
# revenue of assortment [0, 5] is 0.07734118268832098
# revenue of assortment [0, 7] is 0.10434059162025255
# revenue of assortment [0, 1, 6] is 0.2986829643550381
# revenue of assortment [0, 4, 6] is 0.366408407257208
# testing for offertimes 30, 21th instance
# revenue of assortment [0, 7] is 0.10443759911612155
# revenue of assortment [0, 1, 4] is 0.478870783868276
# revenue of assortment [0, 1, 6] is 0.3000438052958265
# revenue of assortment [0, 2, 6] is 0.1992664924693879
# testing for offertimes 30, 22th instance
# revenue of assortment [0, 4] is 0.0820657736950445
# revenue of assortment [0, 1, 8] is 0.5337915163427673
# revenue of assortment [0, 4, 5] is 0.16733172087915912
# revenue of assortment [0, 6, 7] is 0.22559260266566472
# testing for offertimes 30, 23th instance
# revenue of assortment [0, 1, 7] is 0.32873006153583967
# revenue of assortment [0, 3, 6] is 0.19609340205052334
# revenue of assortment [0, 4, 5] is 0.3771011091372566
# revenue of assortment [0, 6, 7] is 0.22996613873212363
# testing for offertimes 30, 24th instance
# revenue of assortment [0, 3] is 0.110263964979586
# revenue of assortment [0, 1, 3] is 0.27780816643570877
# revenue of assortment [0, 4, 5] is 0.37517494532543366
# revenue of assortment [0, 8] is 0.33200032841644983
# testing for offertimes 30, 25th instance
# revenue of assortment [0, 2] is 0.08847517002854223
# revenue of assortment [0, 3] is 0.10366589155862592
# revenue of assortment [0, 5] is 0.07575908511436882
# revenue of assortment [0, 6] is 0.08756261185134452
# testing for offertimes 30, 26th instance
# revenue of assortment [0, 6] is 0.08952488940493458
# revenue of assortment [0, 7] is 0.10142630989725371
# revenue of assortment [0, 1, 4] is 0.46701572931246516
# revenue of assortment [0, 4, 5] is 0.38655886770502035
# testing for offertimes 30, 27th instance
# revenue of assortment [0, 1, 4] is 0.4792654719498925
# revenue of assortment [0, 1, 6] is 0.3000485712510515
# revenue of assortment [0, 3, 7] is 0.22938944744190146
# revenue of assortment [0, 5, 6] is 0.1840217025960807
# testing for offertimes 30, 28th instance
# revenue of assortment [0, 4] is 0.1397848591285278
# revenue of assortment [0, 1, 5] is 0.31756022962572333
# revenue of assortment [0, 1, 6] is 0.30242934378279884
# revenue of assortment [0, 1, 7] is 0.34150039787085484
# testing for offertimes 30, 29th instance
# revenue of assortment [0, 1, 3] is 0.28721611966964117
# revenue of assortment [0, 3, 6] is 0.19688382956714817
# revenue of assortment [0, 5, 6] is 0.1845789935635837
# revenue of assortment [0, 6, 8] is 0.4431552487425733
# testing for offertimes 30, 30th instance
# revenue of assortment [0, 4] is 0.09913788311303881
# revenue of assortment [0, 5] is 0.08046466696231243
# revenue of assortment [0, 4, 5] is 0.16868529026833887
# revenue of assortment [0, 4, 6] is 0.18659435234040533
# testing for offertimes 30, 31th instance
# revenue of assortment [0, 4] is 0.13913667335855132
# revenue of assortment [0, 5] is 0.07609069711825539
# revenue of assortment [0, 1, 6] is 0.30095664379388354
# revenue of assortment [0, 1, 8] is 0.5409579596782826
# testing for offertimes 30, 32th instance
# revenue of assortment [0, 3] is 0.10663858756033132
# revenue of assortment [0, 1, 8] is 0.5340587821366336
# revenue of assortment [0, 4, 6] is 0.364346958235592
# revenue of assortment [0, 5, 6] is 0.1820429870502511
# testing for offertimes 30, 33th instance
# revenue of assortment [0, 3] is 0.11056423663973838
# revenue of assortment [0, 1, 3] is 0.2782771137492303
# revenue of assortment [0, 4, 5] is 0.392386452674014
# revenue of assortment [0, 4, 6] is 0.36490163856122576
# testing for offertimes 30, 34th instance
# revenue of assortment [0, 1, 4] is 0.48622367284204365
# revenue of assortment [0, 1, 5] is 0.30451924853788476
# revenue of assortment [0, 1, 7] is 0.3305692084076798
# revenue of assortment [0, 4, 6] is 0.37684217393123853
# testing for offertimes 30, 35th instance
# revenue of assortment [0, 4] is 0.048298187864108534
# revenue of assortment [0, 1, 4] is 0.27214350169697704
# revenue of assortment [0, 3, 4] is 0.1630036472327691
# revenue of assortment [0, 4, 5] is 0.13798123260224376
# testing for offertimes 30, 36th instance
# revenue of assortment [0, 1] is 0.1195045649414662
# revenue of assortment [0, 2] is 0.09372278817008847
# revenue of assortment [0, 4] is 0.13289870397200507
# revenue of assortment [0, 1, 5] is 0.1970853430039748
# testing for offertimes 30, 37th instance
# revenue of assortment [0, 1] is 0.12409038396999085
# revenue of assortment [0, 3] is 0.10401486146063975
# revenue of assortment [0, 5, 6] is 0.1811789367483786
# revenue of assortment [0, 6, 7] is 0.2237254223915886
# testing for offertimes 30, 38th instance
# revenue of assortment [0, 6] is 0.07754502284280733
# revenue of assortment [0, 1, 3] is 0.2848312144172991
# revenue of assortment [0, 2, 6] is 0.17561489647823503
# revenue of assortment [0, 4, 6] is 0.3562108473930189
# testing for offertimes 30, 39th instance
# revenue of assortment [0, 4] is 0.17003000109502392
# revenue of assortment [0, 6] is 0.08959055918859239
# revenue of assortment [0, 3, 4] is 0.23991064753006092
# revenue of assortment [0, 6, 7] is 0.21133336934940838
# testing for offertimes 30, 40th instance
# revenue of assortment [0, 4] is 0.13623835512481114
# revenue of assortment [0, 6] is 0.08905382888177611
# revenue of assortment [0, 1, 3] is 0.2841741675961882
# revenue of assortment [0, 8] is 0.329490305892893
# testing for offertimes 30, 41th instance
# revenue of assortment [0, 1, 5] is 0.30674919025254
# revenue of assortment [0, 1, 8] is 0.5363352907807032
# revenue of assortment [0, 2, 6] is 0.19770917323417148
# revenue of assortment [0, 4, 5] is 0.37827688312092944
# testing for offertimes 30, 42th instance
# revenue of assortment [0, 1, 4] is 0.4694974346346683
# revenue of assortment [0, 3, 6] is 0.19614135345506944
# revenue of assortment [0, 4, 5] is 0.38837841640448917
# revenue of assortment [0, 6, 8] is 0.4431381657253747
# testing for offertimes 30, 43th instance
# revenue of assortment [0, 4] is 0.13938442803310086
# revenue of assortment [0, 7] is 0.10421470543047687
# revenue of assortment [0, 1, 6] is 0.297760450101188
# revenue of assortment [0, 5, 8] is 0.5075109596426279
# testing for offertimes 30, 44th instance
# revenue of assortment [0, 1] is 0.16238398017837238
# revenue of assortment [0, 2] is 0.09441300104895814
# revenue of assortment [0, 1, 5] is 0.23385041319109473
# revenue of assortment [0, 1, 6] is 0.2303338502227357
# testing for offertimes 30, 45th instance
# revenue of assortment [0, 1, 6] is 0.29857271555028775
# revenue of assortment [0, 3, 4] is 0.3525960697911368
# revenue of assortment [0, 5, 6] is 0.1831901668718941
# revenue of assortment [0, 8] is 0.33262697624112314
# testing for offertimes 30, 46th instance
# revenue of assortment [0, 3] is 0.10704823003137878
# revenue of assortment [0, 1, 6] is 0.30101634750587963
# revenue of assortment [0, 1, 8] is 0.5421947013445341
# revenue of assortment [0, 5, 6] is 0.18363808407899
# testing for offertimes 30, 47th instance
# revenue of assortment [0, 4] is 0.17937520598840984
# revenue of assortment [0, 7] is 0.10356144071416853
# revenue of assortment [0, 1, 4] is 0.3607268849796169
# revenue of assortment [0, 3, 4] is 0.2461283089600729
# testing for offertimes 30, 48th instance
# revenue of assortment [0, 3, 6] is 0.19582713793481138
# revenue of assortment [0, 4, 5] is 0.3779407644726374
# revenue of assortment [0, 5, 6] is 0.18546039830321165
# revenue of assortment [0, 6, 8] is 0.44317351855740056
# testing for offertimes 30, 49th instance
# revenue of assortment [0, 6] is 0.09023547729319863
# revenue of assortment [0, 1, 4] is 0.46783438163167446
# revenue of assortment [0, 1, 7] is 0.32827903968697747
# revenue of assortment [0, 6, 7] is 0.2145940070280675
# testing for offertimes 40, 0th instance
# revenue of assortment [0, 7] is 0.09648277341556016
# revenue of assortment [0, 1, 5] is 0.30768011670050766
# revenue of assortment [0, 5, 8] is 0.5152566727882288
# testing for offertimes 40, 1th instance
# revenue of assortment [0, 7] is 0.09693693422893783
# revenue of assortment [0, 1, 3] is 0.2890669647232225
# revenue of assortment [0, 2, 6] is 0.1982975167043472
# testing for offertimes 40, 2th instance
# revenue of assortment [0, 3] is 0.10685216552222154
# revenue of assortment [0, 1, 4] is 0.47002401034124275
# revenue of assortment [0, 8] is 0.31095976861699
# testing for offertimes 40, 3th instance
# revenue of assortment [0, 3] is 0.10290628937440294
# revenue of assortment [0, 1, 6] is 0.3023730213732757
# revenue of assortment [0, 3, 7] is 0.21867909534161806
# testing for offertimes 40, 4th instance
# revenue of assortment [0, 1, 3] is 0.2922298794483731
# revenue of assortment [0, 1, 5] is 0.31242061880913014
# revenue of assortment [0, 3, 4] is 0.35286787516835505
# testing for offertimes 40, 5th instance
# revenue of assortment [0, 2] is 0.09020627631751865
# revenue of assortment [0, 6] is 0.09676380768123079
# revenue of assortment [0, 1, 6] is 0.2948318101057424
# testing for offertimes 40, 6th instance
# revenue of assortment [0, 1, 3] is 0.30551858653027886
# revenue of assortment [0, 1, 5] is 0.32943534773718447
# revenue of assortment [0, 1, 6] is 0.3124089820603278
# testing for offertimes 40, 7th instance
# revenue of assortment [0, 3] is 0.10519893041623284
# revenue of assortment [0, 4] is 0.08071747685840944
# revenue of assortment [0, 1, 6] is 0.30124206915592977
# testing for offertimes 40, 8th instance
# revenue of assortment [0, 1] is 0.12055610778370458
# revenue of assortment [0, 1, 3] is 0.20618883614738254
# revenue of assortment [0, 8] is 0.3108583105634852
# testing for offertimes 40, 9th instance
# revenue of assortment [0, 3] is 0.10964154303849644
# revenue of assortment [0, 1, 3] is 0.28115572630476604
# revenue of assortment [0, 3, 4] is 0.34957318021668715
# testing for offertimes 40, 10th instance
# revenue of assortment [0, 3] is 0.10685265779585172
# revenue of assortment [0, 1, 4] is 0.4700294157757161
# revenue of assortment [0, 5, 8] is 0.5141647606166796
# testing for offertimes 40, 11th instance
# revenue of assortment [0, 1] is 0.11597298660499215
# revenue of assortment [0, 3] is 0.10405266217069241
# revenue of assortment [0, 5, 8] is 0.5139269416042289
# testing for offertimes 40, 12th instance
# revenue of assortment [0, 1, 5] is 0.3076570213738199
# revenue of assortment [0, 2, 6] is 0.19862677139720725
# revenue of assortment [0, 4, 6] is 0.36654068504921045
# testing for offertimes 40, 13th instance
# revenue of assortment [0, 4] is 0.09941315132488121
# revenue of assortment [0, 5] is 0.08064674182076262
# revenue of assortment [0, 4, 6] is 0.18748942868435375
# testing for offertimes 40, 14th instance
# revenue of assortment [0, 3] is 0.1073004876183385
# revenue of assortment [0, 1, 6] is 0.3023082796289299
# revenue of assortment [0, 5, 6] is 0.18536643058650057
# testing for offertimes 40, 15th instance
# revenue of assortment [0, 6] is 0.08456233598498811
# revenue of assortment [0, 5, 6] is 0.1601904514544848
# revenue of assortment [0, 5, 8] is 0.5148624461838455
# testing for offertimes 40, 16th instance
# revenue of assortment [0, 5] is 0.07602146100981308
# revenue of assortment [0, 1, 6] is 0.30315088380079436
# revenue of assortment [0, 8] is 0.30670095180483026
# testing for offertimes 40, 17th instance
# revenue of assortment [0, 4] is 0.08222952021356891
# revenue of assortment [0, 1, 5] is 0.3072864511087584
# revenue of assortment [0, 5, 6] is 0.1850596586727727
# testing for offertimes 40, 18th instance
# revenue of assortment [0, 5] is 0.08920108632157685
# revenue of assortment [0, 7] is 0.09648264140651722
# revenue of assortment [0, 1, 5] is 0.30177843875280835
# testing for offertimes 40, 19th instance
# revenue of assortment [0, 2] is 0.094051325872324
# revenue of assortment [0, 5] is 0.054083653512147556
# revenue of assortment [0, 5, 8] is 0.49618636405863664
# testing for offertimes 40, 20th instance
# revenue of assortment [0, 7] is 0.09651495243248562
# revenue of assortment [0, 1, 6] is 0.30327673450475096
# revenue of assortment [0, 5, 8] is 0.5142139969816275
# testing for offertimes 40, 21th instance
# revenue of assortment [0, 6] is 0.09979689866811546
# revenue of assortment [0, 1, 5] is 0.3067104216132157
# revenue of assortment [0, 3, 6] is 0.18573001687628096
# testing for offertimes 40, 22th instance
# revenue of assortment [0, 2] is 0.08891527295207574
# revenue of assortment [0, 6] is 0.08993581645952144
# revenue of assortment [0, 5, 8] is 0.5140078785623641
# testing for offertimes 40, 23th instance
# revenue of assortment [0, 3] is 0.11072131216570064
# revenue of assortment [0, 1, 3] is 0.2823664804961077
# revenue of assortment [0, 1, 4] is 0.4739464230828351
# testing for offertimes 40, 24th instance
# revenue of assortment [0, 1, 4] is 0.47197165189667234
# revenue of assortment [0, 3, 6] is 0.19650348650897895
# revenue of assortment [0, 3, 7] is 0.2346183850996115
# testing for offertimes 40, 25th instance
# revenue of assortment [0, 1] is 0.1589753831296348
# revenue of assortment [0, 1, 6] is 0.22864887228996375
# revenue of assortment [0, 3, 4] is 0.35098167798481905
# testing for offertimes 40, 26th instance
# revenue of assortment [0, 6] is 0.09122651493360927
# revenue of assortment [0, 1, 4] is 0.48618183913689805
# revenue of assortment [0, 4, 6] is 0.37229507514001825
# testing for offertimes 40, 27th instance
# revenue of assortment [0, 1] is 0.11859720954860917
# revenue of assortment [0, 3, 6] is 0.1957060355054662
# revenue of assortment [0, 8] is 0.3108639904051547
# testing for offertimes 40, 28th instance
# revenue of assortment [0, 1, 4] is 0.48551927694955177
# revenue of assortment [0, 3, 4] is 0.3628233711415262
# revenue of assortment [0, 8] is 0.3109615208189339
# testing for offertimes 40, 29th instance
# revenue of assortment [0, 6] is 0.091044880360857
# revenue of assortment [0, 3, 4] is 0.35148297657663524
# revenue of assortment [0, 8] is 0.3108926653477564
# testing for offertimes 40, 30th instance
# revenue of assortment [0, 3] is 0.11086278671005788
# revenue of assortment [0, 1, 3] is 0.28156481758339086
# revenue of assortment [0, 4, 6] is 0.3652399105227962
# testing for offertimes 40, 31th instance
# revenue of assortment [0, 1] is 0.11389573177544268
# revenue of assortment [0, 6] is 0.08205127046709193
# revenue of assortment [0, 5, 6] is 0.157767374686622
# testing for offertimes 40, 32th instance
# revenue of assortment [0, 1, 6] is 0.30309729276884567
# revenue of assortment [0, 3, 7] is 0.233408195279933
# revenue of assortment [0, 5, 6] is 0.1856811876834188
# testing for offertimes 40, 33th instance
# revenue of assortment [0, 1, 3] is 0.30172359171455776
# revenue of assortment [0, 1, 6] is 0.30822294814087065
# revenue of assortment [0, 8] is 0.3109873096329589
# testing for offertimes 40, 34th instance
# revenue of assortment [0, 1, 3] is 0.28923573028313004
# revenue of assortment [0, 4, 6] is 0.3664278656564671
# revenue of assortment [0, 8] is 0.3109664842793676
# testing for offertimes 40, 35th instance
# revenue of assortment [0, 1, 4] is 0.48282575576102765
# revenue of assortment [0, 1, 6] is 0.3059603176078734
# revenue of assortment [0, 3, 6] is 0.19810100260186758
# testing for offertimes 40, 36th instance
# revenue of assortment [0, 2] is 0.09400972561375721
# revenue of assortment [0, 3] is 0.11053571054974382
# revenue of assortment [0, 1, 3] is 0.2813526291770877
# testing for offertimes 40, 37th instance
# revenue of assortment [0, 6] is 0.06223476299676806
# revenue of assortment [0, 2, 6] is 0.16716245650366066
# revenue of assortment [0, 5, 6] is 0.14335527455934322
# testing for offertimes 40, 38th instance
# revenue of assortment [0, 7] is 0.09647934832646617
# revenue of assortment [0, 1, 5] is 0.3084321106559258
# revenue of assortment [0, 5, 6] is 0.1852734327950073
# testing for offertimes 40, 39th instance
# revenue of assortment [0, 1, 5] is 0.30667523139739156
# revenue of assortment [0, 2, 6] is 0.19828322480741248
# revenue of assortment [0, 8] is 0.31144377300966064
# testing for offertimes 40, 40th instance
# revenue of assortment [0, 3] is 0.09912958871500549
# revenue of assortment [0, 6] is 0.08925623161697457
# revenue of assortment [0, 3, 7] is 0.2168860691496736
# testing for offertimes 40, 41th instance
# revenue of assortment [0, 4] is 0.11142303496467731
# revenue of assortment [0, 3, 4] is 0.20255272618144216
# revenue of assortment [0, 5, 6] is 0.18342158959106197
# testing for offertimes 40, 42th instance
# revenue of assortment [0, 5] is 0.07947630640331972
# revenue of assortment [0, 6] is 0.09088873526485329
# revenue of assortment [0, 1, 4] is 0.4698047169931108
# testing for offertimes 40, 43th instance
# revenue of assortment [0, 2] is 0.09466120878477895
# revenue of assortment [0, 7] is 0.09725720040106062
# revenue of assortment [0, 3, 6] is 0.19605103201658772
# testing for offertimes 40, 44th instance
# revenue of assortment [0, 2, 6] is 0.19861461347944592
# revenue of assortment [0, 3, 4] is 0.367269799436418
# revenue of assortment [0, 4, 6] is 0.381564647256975
# testing for offertimes 40, 45th instance
# revenue of assortment [0, 6] is 0.08466773411216644
# revenue of assortment [0, 3, 4] is 0.3512328251269294
# revenue of assortment [0, 5, 6] is 0.16012459688011002
# testing for offertimes 40, 46th instance
# revenue of assortment [0, 2] is 0.09395251879226764
# revenue of assortment [0, 5, 6] is 0.18353433994866883
# revenue of assortment [0, 5, 8] is 0.5148653886749693
# testing for offertimes 40, 47th instance
# revenue of assortment [0, 3] is 0.10418157646572417
# revenue of assortment [0, 4] is 0.026044970615656252
# revenue of assortment [0, 1, 4] is 0.26050643505528914
# testing for offertimes 40, 48th instance
# revenue of assortment [0, 3] is 0.1068466094118871
# revenue of assortment [0, 5] is 0.08062692600481364
# revenue of assortment [0, 1, 4] is 0.4699629966443435
# testing for offertimes 40, 49th instance
# revenue of assortment [0, 3] is 0.10540084387392762
# revenue of assortment [0, 1, 3] is 0.27972524574886215
# revenue of assortment [0, 3, 7] is 0.21986868228926174
# testing for offertimes 50, 0th instance
# revenue of assortment [0, 3] is 0.09710801716618438
# revenue of assortment [0, 6] is 0.08948560066583269
# revenue of assortment [0, 1, 3] is 0.2794605609829034
# testing for offertimes 50, 1th instance
# revenue of assortment [0, 3] is 0.10307161252329132
# revenue of assortment [0, 1, 3] is 0.29741852783226896
# revenue of assortment [0, 1, 6] is 0.31264993789198686
# testing for offertimes 50, 2th instance
# revenue of assortment [0, 4] is 0.1661934854891964
# revenue of assortment [0, 5] is 0.08291845043779003
# revenue of assortment [0, 8] is 0.3082470359382717
# testing for offertimes 50, 3th instance
# revenue of assortment [0, 1] is 0.22333081395373564
# revenue of assortment [0, 1, 3] is 0.27250115549591486
# revenue of assortment [0, 1, 6] is 0.2758488427525754
# testing for offertimes 50, 4th instance
# revenue of assortment [0, 1] is 0.16662667834892766
# revenue of assortment [0, 1, 6] is 0.23519275823171684
# revenue of assortment [0, 2, 6] is 0.2004074668209441
# testing for offertimes 50, 5th instance
# revenue of assortment [0, 4] is 0.16619316688629573
# revenue of assortment [0, 5] is 0.06875299265393928
# revenue of assortment [0, 5, 8] is 0.5024153751967078
# testing for offertimes 50, 6th instance
# revenue of assortment [0, 3] is 0.09953837759515242
# revenue of assortment [0, 4] is 0.16600638970222803
# revenue of assortment [0, 5] is 0.08920188121375407
# testing for offertimes 50, 7th instance
# revenue of assortment [0, 5] is 0.08306018124974854
# revenue of assortment [0, 1, 6] is 0.3074627465156947
# revenue of assortment [0, 8] is 0.30827897091580825
# testing for offertimes 50, 8th instance
# revenue of assortment [0, 5] is 0.09643024771851956
# revenue of assortment [0, 2, 6] is 0.19827970884382104
# revenue of assortment [0, 5, 6] is 0.1838496647185669
# testing for offertimes 50, 9th instance
# revenue of assortment [0, 1, 3] is 0.292343823389973
# revenue of assortment [0, 5, 6] is 0.18613773765346542
# revenue of assortment [0, 5, 8] is 0.5160539858625084
# testing for offertimes 50, 10th instance
# revenue of assortment [0, 3] is 0.09960350819006566
# revenue of assortment [0, 1, 4] is 0.5047907092370867
# revenue of assortment [0, 5, 8] is 0.5152568338279336
# testing for offertimes 50, 11th instance
# revenue of assortment [0, 2] is 0.09406484894948774
# revenue of assortment [0, 5, 6] is 0.18588916101362762
# revenue of assortment [0, 5, 8] is 0.5160539858625085
# testing for offertimes 50, 12th instance
# revenue of assortment [0, 4] is 0.16618845377036262
# revenue of assortment [0, 5] is 0.09643024771851547
# revenue of assortment [0, 5, 6] is 0.18322855750931802
# testing for offertimes 50, 13th instance
# revenue of assortment [0, 1] is 0.11209575245879455
# revenue of assortment [0, 2] is 0.09391362673850824
# revenue of assortment [0, 5, 6] is 0.18491635239577203
# testing for offertimes 50, 14th instance
# revenue of assortment [0, 2] is 0.09541552231131502
# revenue of assortment [0, 1, 6] is 0.30862006857554214
# revenue of assortment [0, 3, 6] is 0.1987430599096236
# testing for offertimes 50, 15th instance
# revenue of assortment [0, 1] is 0.07768674802071811
# revenue of assortment [0, 5] is 0.08917946620254777
# revenue of assortment [0, 1, 4] is 0.41464948521646094
# testing for offertimes 50, 16th instance
# revenue of assortment [0, 2, 6] is 0.2002484218268182
# revenue of assortment [0, 3, 6] is 0.19759779618412265
# revenue of assortment [0, 5, 6] is 0.1888015963514164
# testing for offertimes 50, 17th instance
# revenue of assortment [0, 6] is 0.09923466391162486
# revenue of assortment [0, 1, 4] is 0.5160372185795885
# revenue of assortment [0, 1, 6] is 0.30150950710859475
# testing for offertimes 50, 18th instance
# revenue of assortment [0, 6] is 0.07687081549293416
# revenue of assortment [0, 1, 4] is 0.5042247354343191
# revenue of assortment [0, 2, 6] is 0.17523912300440866
# testing for offertimes 50, 19th instance
# revenue of assortment [0, 6] is 0.08437219819200972
# revenue of assortment [0, 1, 4] is 0.504434163050836
# revenue of assortment [0, 5, 6] is 0.16173795084801207
# testing for offertimes 50, 20th instance
# revenue of assortment [0, 1] is 0.1137232577978506
# revenue of assortment [0, 2] is 0.09404467274662105
# revenue of assortment [0, 1, 3] is 0.20239825891355612
# testing for offertimes 50, 21th instance
# revenue of assortment [0, 6] is 0.10117267792095555
# revenue of assortment [0, 1, 3] is 0.29272167963570117
# revenue of assortment [0, 3, 6] is 0.1881605175758269
# testing for offertimes 50, 22th instance
# revenue of assortment [0, 6] is 0.09398537356786994
# revenue of assortment [0, 3, 6] is 0.1830918953051143
# revenue of assortment [0, 5, 6] is 0.16890783900399386
# testing for offertimes 50, 23th instance
# revenue of assortment [0, 1, 3] is 0.3058878779821757
# revenue of assortment [0, 1, 6] is 0.31326155717596804
# revenue of assortment [0, 2, 6] is 0.20042703521545302
# testing for offertimes 50, 24th instance
# revenue of assortment [0, 1] is 0.11234237683091901
# revenue of assortment [0, 5] is 0.08923582032099273
# revenue of assortment [0, 2, 6] is 0.19815470205174104
# testing for offertimes 50, 25th instance
# revenue of assortment [0, 1, 6] is 0.308733096434943
# revenue of assortment [0, 3, 6] is 0.1989119798270198
# revenue of assortment [0, 5, 8] is 0.5152973045162689
# testing for offertimes 50, 26th instance
# revenue of assortment [0, 1, 4] is 0.5054971848745584
# revenue of assortment [0, 3, 6] is 0.19721578046252924
# revenue of assortment [0, 5, 8] is 0.5152784858404583
# testing for offertimes 50, 27th instance
# revenue of assortment [0, 4] is 0.17105551817939008
# revenue of assortment [0, 1, 3] is 0.30497465350546216
# revenue of assortment [0, 1, 6] is 0.311831955756732
# testing for offertimes 50, 28th instance
# revenue of assortment [0, 3] is 0.09326788519253565
# revenue of assortment [0, 5] is 0.08940694145203072
# revenue of assortment [0, 3, 6] is 0.17121309800040807
# testing for offertimes 50, 29th instance
# revenue of assortment [0, 1] is 0.07779750976423687
# revenue of assortment [0, 1, 4] is 0.41470613864616346
# revenue of assortment [0, 2, 6] is 0.1980558341793526
# testing for offertimes 50, 30th instance
# revenue of assortment [0, 2] is 0.09478929192084572
# revenue of assortment [0, 3, 6] is 0.19704918915879255
# revenue of assortment [0, 8] is 0.31145043153998575
# testing for offertimes 50, 31th instance
# revenue of assortment [0, 4] is 0.1672710260946565
# revenue of assortment [0, 1, 3] is 0.2926171705118583
# revenue of assortment [0, 3, 6] is 0.19831463172805883
# testing for offertimes 50, 32th instance
# revenue of assortment [0, 5] is 0.08296321071548896
# revenue of assortment [0, 2, 6] is 0.1986082424689481
# revenue of assortment [0, 8] is 0.3082571206695219
# testing for offertimes 50, 33th instance
# revenue of assortment [0, 3] is 0.09327343290631414
# revenue of assortment [0, 2, 6] is 0.2005487842763926
# revenue of assortment [0, 3, 6] is 0.17207136836381515
# testing for offertimes 50, 34th instance
# revenue of assortment [0, 3] is 0.09949150340791914
# revenue of assortment [0, 5] is 0.09643024771850989
# revenue of assortment [0, 5, 6] is 0.18283898317199754
# testing for offertimes 50, 35th instance
# revenue of assortment [0, 2] is 0.09406484894948748
# revenue of assortment [0, 5, 6] is 0.18442798061525145
# revenue of assortment [0, 8] is 0.31177773642893425
# testing for offertimes 50, 36th instance
# revenue of assortment [0, 1] is 0.16651500062010752
# revenue of assortment [0, 6] is 0.09920329123467188
# revenue of assortment [0, 1, 6] is 0.2224471163008171
# testing for offertimes 50, 37th instance
# revenue of assortment [0, 5] is 0.08750310559019579
# revenue of assortment [0, 5, 6] is 0.17692417521390782
# revenue of assortment [0, 8] is 0.3092834224599999
# testing for offertimes 50, 38th instance
# revenue of assortment [0, 3] is 0.09960030570629717
# revenue of assortment [0, 5] is 0.08920258819036414
# revenue of assortment [0, 1, 4] is 0.5047900131112069
# testing for offertimes 50, 39th instance
# revenue of assortment [0, 5] is 0.06876364160408235
# revenue of assortment [0, 1, 3] is 0.29236491623721506
# revenue of assortment [0, 5, 8] is 0.5024199149607451
# testing for offertimes 50, 40th instance
# revenue of assortment [0, 3] is 0.1025147727770755
# revenue of assortment [0, 1, 3] is 0.28219300640271794
# revenue of assortment [0, 8] is 0.3114418525937892
# testing for offertimes 50, 41th instance
# revenue of assortment [0, 2] is 0.09479124802628508
# revenue of assortment [0, 1, 4] is 0.5054888935056671
# revenue of assortment [0, 3, 6] is 0.1970571741327295
# testing for offertimes 50, 42th instance
# revenue of assortment [0, 1] is 0.11368165007523263
# revenue of assortment [0, 3] is 0.10236303901406787
# revenue of assortment [0, 1, 3] is 0.18025805454111102
# testing for offertimes 50, 43th instance
# revenue of assortment [0, 3] is 0.09335325450464346
# revenue of assortment [0, 1, 4] is 0.5047880728738496
# revenue of assortment [0, 3, 6] is 0.17128272205414
# testing for offertimes 50, 44th instance
# revenue of assortment [0, 5] is 0.08948071756465735
# revenue of assortment [0, 2, 6] is 0.2005385463094852
# revenue of assortment [0, 3, 6] is 0.19787263031156527
# testing for offertimes 50, 45th instance
# revenue of assortment [0, 4] is 0.1696751251149186
# revenue of assortment [0, 5] is 0.08939394026751667
# revenue of assortment [0, 1, 6] is 0.30652991904944005
# testing for offertimes 50, 46th instance
# revenue of assortment [0, 5] is 0.08158654441356164
# revenue of assortment [0, 6] is 0.09118330939964163
# revenue of assortment [0, 8] is 0.3079472520035635
# testing for offertimes 50, 47th instance
# revenue of assortment [0, 1, 4] is 0.5053931784694407
# revenue of assortment [0, 2, 6] is 0.1986362255903569
# revenue of assortment [0, 5, 8] is 0.5152654236668421
# testing for offertimes 50, 48th instance
# revenue of assortment [0, 6] is 0.09155793753918282
# revenue of assortment [0, 1, 3] is 0.29213003744400234
# revenue of assortment [0, 1, 4] is 0.5078495642352203
# testing for offertimes 50, 49th instance
# revenue of assortment [0, 1] is 0.07830838828255102
# revenue of assortment [0, 1, 4] is 0.4149674834467849
# revenue of assortment [0, 3, 6] is 0.19624393497872974
# testing for offertimes 60, 0th instance
# revenue of assortment [0, 3] is 0.10251234258588615
# revenue of assortment [0, 5] is 0.08920732762618419
# testing for offertimes 60, 1th instance
# revenue of assortment [0, 5, 6] is 0.18614308747794733
# revenue of assortment [0, 5, 8] is 0.516053985862508
# testing for offertimes 60, 2th instance
# revenue of assortment [0, 2, 6] is 0.1986718670604833
# revenue of assortment [0, 5, 8] is 0.5152658100026812
# testing for offertimes 60, 3th instance
# revenue of assortment [0, 5] is 0.08773032905464846
# revenue of assortment [0, 6] is 0.09146269507543575
# testing for offertimes 60, 4th instance
# revenue of assortment [0, 3, 6] is 0.19832283318708693
# revenue of assortment [0, 5, 8] is 0.5152786994297838
# testing for offertimes 60, 5th instance
# revenue of assortment [0, 3] is 0.1030716125232909
# revenue of assortment [0, 1, 6] is 0.314470722954628
# testing for offertimes 60, 6th instance
# revenue of assortment [0, 5] is 0.08292192605301786
# revenue of assortment [0, 8] is 0.30824781898944636
# testing for offertimes 60, 7th instance
# revenue of assortment [0, 6] is 0.10120728259323945
# revenue of assortment [0, 3, 6] is 0.188179085976306
# testing for offertimes 60, 8th instance
# revenue of assortment [0, 5] is 0.08940974728204457
# revenue of assortment [0, 3, 6] is 0.19830983080792985
# testing for offertimes 60, 9th instance
# revenue of assortment [0, 1] is 0.06555946634707878
# revenue of assortment [0, 5, 6] is 0.184968868651562
# testing for offertimes 60, 10th instance
# revenue of assortment [0, 1, 6] is 0.3157679941526878
# revenue of assortment [0, 3, 6] is 0.19993655789808107
# testing for offertimes 60, 11th instance
# revenue of assortment [0, 3] is 0.10251708009850587
# revenue of assortment [0, 5, 8] is 0.5152573349296572
# testing for offertimes 60, 12th instance
# revenue of assortment [0, 1, 6] is 0.3150739343035177
# revenue of assortment [0, 2, 6] is 0.20042703521545266
# testing for offertimes 60, 13th instance
# revenue of assortment [0, 3] is 0.10251623420216555
# revenue of assortment [0, 8] is 0.31144187210470936
# testing for offertimes 60, 14th instance
# revenue of assortment [0, 1, 6] is 0.31464994869536717
# revenue of assortment [0, 5, 8] is 0.5152771827304965
# testing for offertimes 60, 15th instance
# revenue of assortment [0, 2] is 0.0941924339827203
# revenue of assortment [0, 5] is 0.08922000700613224
# testing for offertimes 60, 16th instance
# revenue of assortment [0, 2] is 0.09474775868770549
# revenue of assortment [0, 1, 6] is 0.3145488412958254
# testing for offertimes 60, 17th instance
# revenue of assortment [0, 1] is 0.06557890808064964
# revenue of assortment [0, 3] is 0.10231314224620444
# testing for offertimes 60, 18th instance
# revenue of assortment [0, 1] is 0.06614712061910571
# revenue of assortment [0, 3, 6] is 0.19775374036878637
# testing for offertimes 60, 19th instance
# revenue of assortment [0, 6] is 0.08459233613802673
# revenue of assortment [0, 5, 6] is 0.1619018574242843
# testing for offertimes 60, 20th instance
# revenue of assortment [0, 2] is 0.09409693761110197
# revenue of assortment [0, 3] is 0.10246017479945405
# testing for offertimes 60, 21th instance
# revenue of assortment [0, 5] is 0.08939534485236668
# revenue of assortment [0, 1, 6] is 0.3146415783304476
# testing for offertimes 60, 22th instance
# revenue of assortment [0, 2, 6] is 0.20057949007842993
# revenue of assortment [0, 3, 6] is 0.19899595736905362
# testing for offertimes 60, 23th instance
# revenue of assortment [0, 1] is 0.06561479011450237
# revenue of assortment [0, 2] is 0.0939952867332686
# testing for offertimes 60, 24th instance
# revenue of assortment [0, 1] is 0.06566002462895117
# revenue of assortment [0, 8] is 0.3114404905174266
# testing for offertimes 60, 25th instance
# revenue of assortment [0, 6] is 0.099344198319154
# revenue of assortment [0, 1, 6] is 0.30755983163235995
# testing for offertimes 60, 26th instance
# revenue of assortment [0, 5, 6] is 0.18468357195876062
# revenue of assortment [0, 8] is 0.3117777364289326
# testing for offertimes 60, 27th instance
# revenue of assortment [0, 3] is 0.10239485170366237
# revenue of assortment [0, 5, 6] is 0.18534610131654247
# testing for offertimes 60, 28th instance
# revenue of assortment [0, 1] is 0.06578837753013603
# revenue of assortment [0, 2, 6] is 0.198038475913
# testing for offertimes 60, 29th instance
# revenue of assortment [0, 5] is 0.0964302477185231
# revenue of assortment [0, 5, 6] is 0.18327989639758774
# testing for offertimes 60, 30th instance
# revenue of assortment [0, 3] is 0.10268618467599454
# revenue of assortment [0, 2, 6] is 0.19835909833703907
# testing for offertimes 60, 31th instance
# revenue of assortment [0, 1] is 0.06565687944501652
# revenue of assortment [0, 5] is 0.08917785642324666
# testing for offertimes 60, 32th instance
# revenue of assortment [0, 2] is 0.09419628105313207
# revenue of assortment [0, 8] is 0.3114424661828667
# testing for offertimes 60, 33th instance
# revenue of assortment [0, 1, 6] is 0.31446905926197954
# revenue of assortment [0, 5, 6] is 0.18774314381273002
# testing for offertimes 60, 34th instance
# revenue of assortment [0, 3, 6] is 0.1983204618492918
# revenue of assortment [0, 8] is 0.311451344080915
# testing for offertimes 60, 35th instance
# revenue of assortment [0, 3] is 0.0971126392544291
# revenue of assortment [0, 6] is 0.08950994871117987
# testing for offertimes 60, 36th instance
# revenue of assortment [0, 2, 6] is 0.19832000660490268
# revenue of assortment [0, 5, 6] is 0.18633292098354892
# testing for offertimes 60, 37th instance
# revenue of assortment [0, 1] is 0.06115985419800231
# revenue of assortment [0, 6] is 0.08786748595815733
# testing for offertimes 60, 38th instance
# revenue of assortment [0, 2] is 0.09419711861569909
# revenue of assortment [0, 5, 8] is 0.5152586747425055
# testing for offertimes 60, 39th instance
# revenue of assortment [0, 5] is 0.06876489924558285
# revenue of assortment [0, 5, 8] is 0.5024204511088095
# testing for offertimes 60, 40th instance
# revenue of assortment [0, 2] is 0.08901016083615623
# revenue of assortment [0, 6] is 0.09044441312904418
# testing for offertimes 60, 41th instance
# revenue of assortment [0, 1] is 0.06566070573829433
# revenue of assortment [0, 5, 8] is 0.5152542189715159
# testing for offertimes 60, 42th instance
# revenue of assortment [0, 6] is 0.09154529449787531
# revenue of assortment [0, 8] is 0.31137200045902147
# testing for offertimes 60, 43th instance
# revenue of assortment [0, 2, 6] is 0.19866923595710775
# revenue of assortment [0, 8] is 0.3114456286659818
# testing for offertimes 60, 44th instance
# revenue of assortment [0, 6] is 0.07719065958417384
# revenue of assortment [0, 2, 6] is 0.17541734872910222
# testing for offertimes 60, 45th instance
# revenue of assortment [0, 2] is 0.09479831624260449
# revenue of assortment [0, 3, 6] is 0.19816572069495442
# testing for offertimes 60, 46th instance
# revenue of assortment [0, 6] is 0.09156034040287168
# revenue of assortment [0, 5, 8] is 0.515099903389373
# testing for offertimes 60, 47th instance
# revenue of assortment [0, 1, 6] is 0.3146484244515213
# revenue of assortment [0, 8] is 0.31145067159658685
# testing for offertimes 60, 48th instance
# revenue of assortment [0, 3, 6] is 0.1980461060938935
# revenue of assortment [0, 5, 6] is 0.1879298251879103
# testing for offertimes 60, 49th instance
# revenue of assortment [0, 5] is 0.08928742741476321
# revenue of assortment [0, 2, 6] is 0.19865725392080114

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_mnl_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mnl_dist':all_mnl_distance_list[i],
                                    'true_best_rev':all_best_true_rev_list[i],'mnl_best_rev':all_best_rev_mnl_list[i],
                                    'mnl_best_rev_diff':all_mnl_best_rev_diff[i]})
    df_mnl_details1.to_csv('prediction/mnl/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        mnl_rank = all_mnl_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'mnl_rank':mnl_rank})
        df_rank.to_csv('prediction/mnl/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        mnl_rev = all_mnl_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'mnl_rev':mnl_rev})
        df_rev.to_csv('prediction/mnl/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
    
        mnl_runtime = all_mnl_pred_runtime[i][j]
        df_runtime = pd.DataFrame({'mnl_runtime':mnl_runtime})
        df_runtime.to_csv('prediction/mnl/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ## using sales fraction prediction
        ## record the choice probability prediction interval
        ''' true_prob = all_true_prob_list[i][j]
        df_true_prob = pd.DataFrame(true_prob)
        
        mnl_sales = all_mnl_sales_list[i][j]
        df_mnl_sales = pd.DataFrame(mnl_sales).T
 
        df_true_prob.to_csv('prediction/mnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_mnl_sales.to_csv('prediction/mnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/mnl/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## avg prediction mnl runtime 
all_mnl_pred_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    avg_mnl_pred_runtime_collection = []
    
    for j in range(pred_instance_size[i]): 
        avg_mnl_pred_runtime_collection.append(np.mean(np.array(all_mnl_pred_runtime[i][j]))) 
        
    all_mnl_pred_avg_runtime.append(np.mean(np.array(avg_mnl_pred_runtime_collection)))

avg_mnl_dist = []
avg_mnl_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    
    avg_mnl_dist.append(np.mean(all_mnl_distance_list[i]))
    avg_mnl_best_rev_diff.append(np.mean(all_mnl_best_rev_diff[i]))
    

df_mnl_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'avg_mnl_dist':avg_mnl_dist,'avg_mnl_best_rev_diff':avg_mnl_best_rev_diff,
                                   'avg_mnl_pred_runtime':all_mnl_pred_avg_runtime})
df_mnl_jd_summary.to_csv('prediction/mnl/jd_mnl_summary.csv')

# %%
df_mnl_jd_summary
# Out:
#    offertimes  avg_mnl_dist  avg_mnl_best_rev_diff  avg_mnl_pred_runtime
# 0          20          3.48               0.110001              0.225605
# 1          30          2.30               0.174229              0.223311
# 2          40          1.36               0.213639              0.239243
# 3          50          0.94               0.157176              0.241143
# 4          60          0.40               0.134218              0.253961
