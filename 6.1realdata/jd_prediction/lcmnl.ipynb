# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
import pyomo.environ as pyo
from pyomo.environ import *
import sys

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
#offertimes.to_csv('offertimes.csv')
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
#inc_prod_num.to_csv('inc_prod_num.csv')
choice_prob = raw_jd_choice['clicknum'] / raw_jd_choice.groupby('clickset')['clicknum'].transform('sum')
raw_jd_choice['choice prob'] = choice_prob

assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

# all purchase options in each assortment
purchaseset = raw_jd_choice['purchaseset']
purchaseset_list = []
for pset in purchaseset:
    num_lst = json.loads(pset)
    purchaseset_list.append(num_lst)
raw_jd_choice['purchaseset'] = purchaseset_list

purchasenum_list = raw_jd_choice['clicknum'].tolist()
jd_choice=pd.DataFrame({'clickset':clickset_list,'purchaseset':purchaseset_list,'purchasenum':purchasenum_list,'choice prob':choice_prob})

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
collection = []
for cset in clickset_list:
    if cset not in collection:
        collection.append(cset)
print('there are {} different assortments'.format(len(collection)))

assortment_info_df['assortments'] = collection
choice_collection = np.zeros((n,len(collection)))
global_num = 0
for i in range(len(collection)):
    local_num =0
    while(local_num < inc_prod_num[i]):
        if purchaseset_list[global_num][0] in collection[i]:
            choice_collection[purchaseset_list[global_num][0]][i] = choice_prob[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print('error!')
full_choice_collection = pd.DataFrame(choice_collection)
#full_choice_collection.to_csv('instances/full_instances/full_choice.csv')
# Out:
# there are 9 different products
# there are 134 different assortments

# %%
assortment_info_df_20 = assortment_info_df[(assortment_info_df['offer_times']>=20)]
assortments_20 = []
for i in range(len(assortment_info_df_20['assortments'])):
    assortments_20.append(assortment_info_df_20['assortments'][i])


jd_choice_20 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_20:
        jd_choice_20.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_20 = assortment_info_df_20['assortments']
choice_collection_20 = np.zeros((n,len(collection_20)))

frequency_collection_20 = np.zeros((n,len(collection_20)))

purchaseset_list_20 = jd_choice_20['purchaseset'].tolist()

inc_prod_num_20 = assortment_info_df_20['includ_prod_num']
choice_prob_20 = jd_choice_20['choice prob']
frequency_20 = jd_choice_20['purchasenum']

global_num = 0
for i in range(len(collection_20)):
    local_num =0
    while(local_num < inc_prod_num_20[i]):
        if purchaseset_list_20[global_num][0] in assortments_20[i]:
            choice_collection_20[purchaseset_list_20[global_num][0]][i] = choice_prob_20[global_num]
            frequency_collection_20[purchaseset_list_20[global_num][0]][i] = frequency_20[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_20[global_num])
            print(assortments_20[i])
            print('error!')
            break
#print(global_num)  

choice_check_20 = pd.DataFrame(choice_collection_20)
#choice_check_20.to_csv('instances/full_instances/full_20.csv')
frequency_collection_20 = frequency_collection_20.astype(int)
frequency_check_20 = pd.DataFrame(frequency_collection_20)
#frequency_check_20.to_csv('instances/full_instances/frequency_20.csv')

offer_times_20 = assortment_info_df_20['offer_times'].tolist()
print('the number of assortments with at least 20 purchases is',len(assortments_20))
# Out:
# the number of assortments with at least 20 purchases is 29

# %%
assortment_info_df_30 = assortment_info_df[(assortment_info_df['offer_times']>=30)]
assortments_30 = []
for i in range(len(assortment_info_df_30['assortments'])):
    assortments_30.append(assortment_info_df_30['assortments'][i])


jd_choice_30 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_30:
        jd_choice_30.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_30 = assortment_info_df_30['assortments']
choice_collection_30 = np.zeros((n,len(collection_30)))

frequency_collection_30 = np.zeros((n,len(collection_30)))

purchaseset_list_30 = jd_choice_30['purchaseset'].tolist()

inc_prod_num_30 = assortment_info_df_30['includ_prod_num']
choice_prob_30 = jd_choice_30['choice prob']
frequency_30 = jd_choice_30['purchasenum']

global_num = 0
for i in range(len(collection_30)):
    local_num =0
    while(local_num < inc_prod_num_30[i]):
        if purchaseset_list_30[global_num][0] in assortments_30[i]:
            choice_collection_30[purchaseset_list_30[global_num][0]][i] = choice_prob_30[global_num]
            frequency_collection_30[purchaseset_list_30[global_num][0]][i] = frequency_30[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_30[global_num])
            print(assortments_30[i])
            print('error!')
            break
#print(global_num)  

choice_check_30 = pd.DataFrame(choice_collection_30)
#choice_check_30.to_csv('instances/full_instances/full_30.csv')
frequency_collection_30 = frequency_collection_30.astype(int)
frequency_check_30 = pd.DataFrame(frequency_collection_30)
#frequency_check_30.to_csv('instances/full_instances/frequency_30.csv')

offer_times_30 = assortment_info_df_30['offer_times'].tolist()
print('the number of assortments with at least 30 purchases is',len(assortments_30))
# Out:
# the number of assortments with at least 30 purchases is 24

# %%
assortment_info_df_40 = assortment_info_df[(assortment_info_df['offer_times']>=40)]
assortments_40 = []
for i in range(len(assortment_info_df_40['assortments'])):
    assortments_40.append(assortment_info_df_40['assortments'][i])


jd_choice_40 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_40:
        jd_choice_40.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_40 = assortment_info_df_40['assortments']
choice_collection_40 = np.zeros((n,len(collection_40)))

frequency_collection_40 = np.zeros((n,len(collection_40)))

purchaseset_list_40 = jd_choice_40['purchaseset'].tolist()

inc_prod_num_40 = assortment_info_df_40['includ_prod_num']
choice_prob_40 = jd_choice_40['choice prob']
frequency_40 = jd_choice_40['purchasenum']

global_num = 0
for i in range(len(collection_40)):
    local_num =0
    while(local_num < inc_prod_num_40[i]):
        if purchaseset_list_40[global_num][0] in assortments_40[i]:
            choice_collection_40[purchaseset_list_40[global_num][0]][i] = choice_prob_40[global_num]
            frequency_collection_40[purchaseset_list_40[global_num][0]][i] = frequency_40[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_40[global_num])
            print(assortments_40[i])
            print('error!')
            break
#print(global_num)  

choice_check_40 = pd.DataFrame(choice_collection_40)
#choice_check_40.to_csv('instances/full_instances/full_40.csv')
frequency_collection_40 = frequency_collection_40.astype(int)
frequency_check_40 = pd.DataFrame(frequency_collection_40)
#frequency_check_40.to_csv('instances/full_instances/frequency_40.csv')

offer_times_40 = assortment_info_df_40['offer_times'].tolist()
print('the number of assortments with at least 40 purchases is',len(assortments_40))
# Out:
# the number of assortments with at least 40 purchases is 19

# %%
assortment_info_df_50 = assortment_info_df[(assortment_info_df['offer_times']>=50)]
assortments_50 = []
for i in range(len(assortment_info_df_50['assortments'])):
    assortments_50.append(assortment_info_df_50['assortments'][i])


jd_choice_50 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_50:
        jd_choice_50.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_50 = assortment_info_df_50['assortments']
choice_collection_50 = np.zeros((n,len(collection_50)))

frequency_collection_50 = np.zeros((n,len(collection_50)))

purchaseset_list_50 = jd_choice_50['purchaseset'].tolist()

inc_prod_num_50 = assortment_info_df_50['includ_prod_num']
choice_prob_50 = jd_choice_50['choice prob']
frequency_50 = jd_choice_50['purchasenum']

global_num = 0
for i in range(len(collection_50)):
    local_num =0
    while(local_num < inc_prod_num_50[i]):
        if purchaseset_list_50[global_num][0] in assortments_50[i]:
            choice_collection_50[purchaseset_list_50[global_num][0]][i] = choice_prob_50[global_num]
            frequency_collection_50[purchaseset_list_50[global_num][0]][i] = frequency_50[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_50[global_num])
            print(assortments_50[i])
            print('error!')
            break
#print(global_num)  

choice_check_50 = pd.DataFrame(choice_collection_50)
#choice_check_50.to_csv('instances/full_instances/full_50.csv')
frequency_collection_50 = frequency_collection_50.astype(int)
frequency_check_50 = pd.DataFrame(frequency_collection_50)
#frequency_check_50.to_csv('instances/full_instances/frequency_50.csv')

offer_times_50 = assortment_info_df_50['offer_times'].tolist()
print('the number of assortments with at least 50 purchases is',len(assortments_50))
# Out:
# the number of assortments with at least 50 purchases is 15

# %%
assortment_info_df_60 = assortment_info_df[(assortment_info_df['offer_times']>=60)]
assortments_60 = []
for i in range(len(assortment_info_df_60['assortments'])):
    assortments_60.append(assortment_info_df_60['assortments'][i])


jd_choice_60 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_60:
        jd_choice_60.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_60 = assortment_info_df_60['assortments']
choice_collection_60 = np.zeros((n,len(collection_60)))

frequency_collection_60 = np.zeros((n,len(collection_60)))

purchaseset_list_60 = jd_choice_60['purchaseset'].tolist()

inc_prod_num_60 = assortment_info_df_60['includ_prod_num']
choice_prob_60 = jd_choice_60['choice prob']
frequency_60 = jd_choice_60['purchasenum']

global_num = 0
for i in range(len(collection_60)):
    local_num =0
    while(local_num < inc_prod_num_60[i]):
        if purchaseset_list_60[global_num][0] in assortments_60[i]:
            choice_collection_60[purchaseset_list_60[global_num][0]][i] = choice_prob_60[global_num]
            frequency_collection_60[purchaseset_list_60[global_num][0]][i] = frequency_60[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_60[global_num])
            print(assortments_60[i])
            print('error!')
            break
#print(global_num)  

choice_check_60 = pd.DataFrame(choice_collection_60)
#choice_check_60.to_csv('instances/full_instances/full_60.csv')
frequency_collection_60 = frequency_collection_60.astype(int)
frequency_check_60 = pd.DataFrame(frequency_collection_60)
#frequency_check_60.to_csv('instances/full_instances/frequency_60.csv')

offer_times_60 = assortment_info_df_60['offer_times'].tolist()
print('the number of assortments with at least 60 purchases is',len(assortments_60))
# Out:
# the number of assortments with at least 60 purchases is 13

# %%
assortment_info_df_75 = assortment_info_df[(assortment_info_df['offer_times']>=75)]
assortments_75 = []
for i in range(len(assortment_info_df_75['assortments'])):
    assortments_75.append(assortment_info_df_75['assortments'][i])


jd_choice_75 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_75:
        jd_choice_75.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_75 = assortment_info_df_75['assortments']
choice_collection_75 = np.zeros((n,len(collection_75)))

frequency_collection_75 = np.zeros((n,len(collection_75)))

purchaseset_list_75 = jd_choice_75['purchaseset'].tolist()

inc_prod_num_75 = assortment_info_df_75['includ_prod_num']
choice_prob_75 = jd_choice_75['choice prob']
frequency_75 = jd_choice_75['purchasenum']

global_num = 0
for i in range(len(collection_75)):
    local_num =0
    while(local_num < inc_prod_num_75[i]):
        if purchaseset_list_75[global_num][0] in assortments_75[i]:
            choice_collection_75[purchaseset_list_75[global_num][0]][i] = choice_prob_75[global_num]
            frequency_collection_75[purchaseset_list_75[global_num][0]][i] = frequency_75[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_75[global_num])
            print(assortments_75[i])
            print('error!')
            break
#print(global_num)  

choice_check_75 = pd.DataFrame(choice_collection_75)
#choice_check_75.to_csv('instances/full_instances/full_75.csv')
frequency_collection_75 = frequency_collection_75.astype(int)
frequency_check_75 = pd.DataFrame(frequency_collection_75)
#frequency_check_75.to_csv('instances/full_instances/frequency_75.csv')

offer_times_75 = assortment_info_df_75['offer_times'].tolist()
print('the number of assortments with at least 75 purchases is',len(assortments_75))
# Out:
# the number of assortments with at least 75 purchases is 12

# %%
assortment_info_df_100 = assortment_info_df[(assortment_info_df['offer_times']>=100)]
assortments_100 = []
for i in range(len(assortment_info_df_100['assortments'])):
    assortments_100.append(assortment_info_df_100['assortments'][i])

jd_choice_100 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_100:
        jd_choice_100.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_100 = assortment_info_df_100['assortments']
choice_collection_100 = np.zeros((n,len(collection_100)))

frequency_collection_100 = np.zeros((n,len(collection_100)))

purchaseset_list_100 = jd_choice_100['purchaseset'].tolist()

inc_prod_num_100 = assortment_info_df_100['includ_prod_num']
choice_prob_100 = jd_choice_100['choice prob']
frequency_100 = jd_choice_100['purchasenum']

global_num=0
for i in range(len(collection_100)):
    local_num =0
    while(local_num < inc_prod_num_100[i]):
        if purchaseset_list_100[global_num][0] in assortments_100[i]:
            choice_collection_100[purchaseset_list_100[global_num][0]][i] = choice_prob_100[global_num]
            frequency_collection_100[purchaseset_list_100[global_num][0]][i] = frequency_100[global_num]
            global_num = global_num +1
            local_num = local_num +1

choice_check_100 = pd.DataFrame(choice_collection_100)
#choice_check_100.to_csv('instances/full_instances/full_100.csv')
frequency_collection_100 = frequency_collection_100.astype(int)
frequency_check_100 = pd.DataFrame(frequency_collection_100)
#frequency_check_100.to_csv('instances/full_instances/frequency_100.csv')

offer_times_100 = assortment_info_df_100['offer_times'].tolist()
print('the number of assortments with at least 100 purchases is',len(assortments_100))
# Out:
# the number of assortments with at least 100 purchases is 11

# %%
assortment_info_df_15 = assortment_info_df[(assortment_info_df['offer_times']>=15)]
assortments_15 = []
for i in range(len(assortment_info_df_15['assortments'])):
    assortments_15.append(assortment_info_df_15['assortments'][i])


jd_choice_15 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_15:
        jd_choice_15.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_15 = assortment_info_df_15['assortments']
choice_collection_15 = np.zeros((n,len(collection_15)))

frequency_collection_15 = np.zeros((n,len(collection_15)))

purchaseset_list_15 = jd_choice_15['purchaseset'].tolist()

inc_prod_num_15 = assortment_info_df_15['includ_prod_num']
choice_prob_15 = jd_choice_15['choice prob']
frequency_15 = jd_choice_15['purchasenum']

global_num = 0
for i in range(len(collection_15)):
    local_num =0
    while(local_num < inc_prod_num_15[i]):
        if purchaseset_list_15[global_num][0] in assortments_15[i]:
            choice_collection_15[purchaseset_list_15[global_num][0]][i] = choice_prob_15[global_num]
            frequency_collection_15[purchaseset_list_15[global_num][0]][i] = frequency_15[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_15[global_num])
            print(assortments_15[i])
            print('error!')
            break
#print(global_num)  

choice_check_15 = pd.DataFrame(choice_collection_15)
#choice_check_15.to_csv('instances/full_instances/full_15.csv')
frequency_collection_15 = frequency_collection_15.astype(int)
frequency_check_15 = pd.DataFrame(frequency_collection_15)
#frequency_check_15.to_csv('instances/full_instances/frequency_15.csv')

offer_times_15 = assortment_info_df_15['offer_times'].tolist()
print('the number of assortments with at least 15 purchases is',len(assortments_15))
# Out:
# the number of assortments with at least 15 purchases is 38

# %% [markdown]
# both MDM and RUM represent the data with approximately 99.8% confidence interval,  we set both z = 3.090232306167813 for both RUM and MDM, which corresponding to  99.8% confidence interval

# %%
confidence_level = 0.998
alpha = 1 - confidence_level
# Find z-score for the given confidence level
target_z_score = stats.norm.ppf(1 - alpha / 2)

stardard_error_20 = np.zeros(frequency_collection_20.shape)
for i in range(stardard_error_20.shape[0]):
    for j in range(stardard_error_20.shape[1]):
        if frequency_collection_20[i][j]!=0:
            stardard_error_20[i][j] = np.sqrt((1-choice_collection_20[i][j])/frequency_collection_20[i][j])
            
lb_20 = np.zeros(frequency_collection_20.shape)
ub_20 = np.zeros(frequency_collection_20.shape)
for i in range(lb_20.shape[0]):
    for j in range(lb_20.shape[1]):
        if frequency_collection_20[i][j]!=0:
            lb_20[i][j] = choice_collection_20[i][j] * (1-target_z_score*stardard_error_20[i][j]) 
            ub_20[i][j] = choice_collection_20[i][j] * (1+target_z_score*stardard_error_20[i][j])

stardard_error_30 = np.zeros(frequency_collection_30.shape)
for i in range(stardard_error_30.shape[0]):
    for j in range(stardard_error_30.shape[1]):
        if frequency_collection_30[i][j]!=0:
            stardard_error_30[i][j] = np.sqrt((1-choice_collection_30[i][j])/frequency_collection_30[i][j])
            
lb_30 = np.zeros(frequency_collection_30.shape)
ub_30 = np.zeros(frequency_collection_30.shape)
for i in range(lb_30.shape[0]):
    for j in range(lb_30.shape[1]):
        if frequency_collection_30[i][j]!=0:
            lb_30[i][j] = choice_collection_30[i][j] * (1-target_z_score*stardard_error_30[i][j]) 
            ub_30[i][j] = choice_collection_30[i][j] * (1+target_z_score*stardard_error_30[i][j])
            
stardard_error_40 = np.zeros(frequency_collection_40.shape)
for i in range(stardard_error_40.shape[0]):
    for j in range(stardard_error_40.shape[1]):
        if frequency_collection_40[i][j]!=0:
            stardard_error_40[i][j] = np.sqrt((1-choice_collection_40[i][j])/frequency_collection_40[i][j])
            
lb_40 = np.zeros(frequency_collection_40.shape)
ub_40 = np.zeros(frequency_collection_40.shape)
for i in range(lb_40.shape[0]):
    for j in range(lb_40.shape[1]):
        if frequency_collection_40[i][j]!=0:
            lb_40[i][j] = choice_collection_40[i][j] * (1-target_z_score*stardard_error_40[i][j]) 
            ub_40[i][j] = choice_collection_40[i][j] * (1+target_z_score*stardard_error_40[i][j])

stardard_error_50 = np.zeros(frequency_collection_50.shape)
for i in range(stardard_error_50.shape[0]):
    for j in range(stardard_error_50.shape[1]):
        if frequency_collection_50[i][j]!=0:
            stardard_error_50[i][j] = np.sqrt((1-choice_collection_50[i][j])/frequency_collection_50[i][j])
            
lb_50 = np.zeros(frequency_collection_50.shape)
ub_50 = np.zeros(frequency_collection_50.shape)
for i in range(lb_50.shape[0]):
    for j in range(lb_50.shape[1]):
        if frequency_collection_50[i][j]!=0:
            lb_50[i][j] = choice_collection_50[i][j] * (1-target_z_score*stardard_error_50[i][j]) 
            ub_50[i][j] = choice_collection_50[i][j] * (1+target_z_score*stardard_error_50[i][j])
            
stardard_error_60 = np.zeros(frequency_collection_60.shape)
for i in range(stardard_error_60.shape[0]):
    for j in range(stardard_error_60.shape[1]):
        if frequency_collection_60[i][j]!=0:
            stardard_error_60[i][j] = np.sqrt((1-choice_collection_60[i][j])/frequency_collection_60[i][j])
            
lb_60 = np.zeros(frequency_collection_60.shape)
ub_60 = np.zeros(frequency_collection_60.shape)
for i in range(lb_60.shape[0]):
    for j in range(lb_60.shape[1]):
        if frequency_collection_60[i][j]!=0:
            lb_60[i][j] = choice_collection_60[i][j] * (1-target_z_score*stardard_error_60[i][j]) 
            ub_60[i][j] = choice_collection_60[i][j] * (1+target_z_score*stardard_error_60[i][j])

# %% [markdown]
# ### full data with different offertimes

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_full_instance  = [choice_collection_20,choice_collection_30,choice_collection_40,choice_collection_50,choice_collection_60]
pred_full_lb = [lb_20,lb_30,lb_40,lb_50,lb_60]
pred_full_ub = [ub_20,ub_30,ub_40,ub_50,ub_60]

pred_full_collection = [collection_20,collection_30,collection_40,collection_50,collection_60]
pred_full_collection_size = [len(offer_times_20),len(offer_times_30),len(offer_times_40),len(offer_times_50),len(offer_times_60)]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
#pred_instance_size = [100,100,100,50,50]
pred_instance_size = [50,50,50,50,50]

price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

pred_full_offertimes = [offer_times_20,offer_times_30,offer_times_40,offer_times_50,offer_times_60]

# %% [markdown]
# train-test split

# %%
all_train_instances = []
all_train_collection = []
all_test_instance = []
all_test_collection = []
all_train_lb = []
all_train_ub = []
all_train_offertimes = []

for i in range(len(pred_instance_size)):
    train_instances_collection = []
    train_collection = []
    train_lb_collection = []
    train_ub_collection = []
    train_offertimes_collection = []
    
    test_instance_collection = []
    test_collection = []
    
    test_index_collection = []
    
    
    for j in range(pred_instance_size[i]):
        
        curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
        curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
        curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
        
        curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
        
        curr_train_collection = []
        curr_test_collection = []
        curr_offertimes_lst = []
        
        while(len(curr_train_collection)==0):
            
            chosen_test_idx = random.sample(range(len(pred_full_collection[i])),pred_test_collection_size[i])
            chosen_test_idx.sort()
            
            chosen_train_idx = [x for x in range(len(pred_full_collection[i])) if x not in chosen_test_idx ]
    
            for k in range(len(chosen_train_idx)):
                curr_train_collection.append(pred_full_collection[i][chosen_train_idx[k]])
                curr_train_instance[:,k] = pred_full_instance[i][:,chosen_train_idx[k]]
                curr_train_lb[:,k] = pred_full_lb[i][:,chosen_train_idx[k]]
                curr_train_ub[:,k] = pred_full_ub[i][:,chosen_train_idx[k]]
                
                curr_offertimes_lst.append(pred_full_offertimes[i][chosen_train_idx[k]])
                
            for k in range(len(chosen_test_idx)):
                curr_test_collection.append(pred_full_collection[i][chosen_test_idx[k]])
                curr_test_instance[:,k] = pred_full_instance[i][:,chosen_test_idx[k]]
                
            ## check if the training instance includes all the testing products in the test instance
            # ensure each test product has been offered at least  once
            new_lst_train = sum(curr_train_collection,[])
            unique_numbers_train = list(set(new_lst_train)) 
            
            new_lst_test = sum(curr_test_collection,[])
            unique_numbers_test = list(set(new_lst_test)) 
            
            for num in unique_numbers_test:
                if num not in unique_numbers_train:
                    #print('the unique train numbers',unique_numbers_train)
                    #print('the unique test numbers',unique_numbers_test)
                    curr_train_collection = []
                    curr_test_collection = []
                    curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                    curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                    curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                    curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                    curr_offertimes_lst = []
            if chosen_test_idx in test_index_collection:
                #print('check if exisits repeated indexes ')
                curr_train_collection = []
                curr_test_collection = []
                curr_train_instance = np.zeros((n,pred_train_collection_size[i]))
                curr_test_instance = np.zeros((n,pred_test_collection_size[i]))
                curr_train_lb = np.zeros((n,pred_train_collection_size[i]))
                curr_train_ub = np.zeros((n,pred_train_collection_size[i]))
                curr_offertimes_lst = []
            elif len(curr_test_collection)>0:
                test_index_collection.append(chosen_test_idx)
        #print('chosen training indexes',chosen_train_idx)
        #print('chosen testing indexes',chosen_test_idx)
        #print('curr train collection\n',curr_train_collection)
        #print('curr test collection\n',curr_test_collection)
        ''' df_train = pd.DataFrame(curr_train_instance)
        df_test = pd.DataFrame(curr_test_instance)
        df_offertimes = pd.DataFrame(curr_offertimes_lst)
        #print('curr train instance\n',df_train)
        #print('curr test instance\n',df_test)
        
        ## output the training and testing instance
        df_train.to_csv('instances/train_instances/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_test.to_csv('instances/test_instances/test_'+str(pred_offer_times_list[i])+'/test_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_offertimes.to_csv('instances/train_offertimes/train_'+str(pred_offer_times_list[i])+'/train_offertimes'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
         '''
        train_instances_collection.append(curr_train_instance)
        train_collection.append(curr_train_collection)
        train_lb_collection.append(curr_train_lb)
        train_ub_collection.append(curr_train_ub)
        train_offertimes_collection.append(curr_offertimes_lst)
                
        test_instance_collection.append(curr_test_instance)
        test_collection.append(curr_test_collection)
        
    all_train_instances.append(train_instances_collection)
    all_train_collection.append(train_collection)
    all_train_lb.append(train_lb_collection)
    all_train_ub.append(train_ub_collection)
    all_train_offertimes.append(train_offertimes_collection)
    all_test_instance.append(test_instance_collection)
    all_test_collection.append(test_collection)

# %%
pd.DataFrame(all_train_instances[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.735746  0.705128  0.647154  0.773333  0.738497  0.741758  0.736842
# 1  0.264254  0.000000  0.000000  0.000000  0.000000  0.000000  0.070175
# 2  0.000000  0.294872  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.352846  0.000000  0.000000  0.000000  0.192982
# 4  0.000000  0.000000  0.000000  0.226667  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.261503  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.258242  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...    14        15        16        17  \
# 0  0.745098  0.847826  0.846774  ...  0.75  0.692308  0.715447  0.791667
# 1  0.176471  0.130435  0.048387  ...  0.00  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.25  0.269231  0.211382  0.166667
# 4  0.078431  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 5  0.000000  0.021739  0.000000  ...  0.00  0.038462  0.000000  0.000000
# 6  0.000000  0.000000  0.104839  ...  0.00  0.000000  0.073171  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.00  0.000000  0.000000  0.041667
#
#         18        19        20        21        22        23
# 0  0.78125  0.822222  0.739130  0.642857  0.714286  0.688805
# 1  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.18750  0.022222  0.043478  0.035714  0.000000  0.000000
# 5  0.03125  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.00000  0.155556  0.000000  0.000000  0.142857  0.000000
# 7  0.00000  0.000000  0.217391  0.000000  0.142857  0.000000
# 8  0.00000  0.000000  0.000000  0.285714  0.000000  0.311195
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_test_instance[0][0])
# Out:
#          0      1         2         3         4
# 0  0.91442  0.625  0.686567  0.748744  0.757576
# 1  0.00000  0.000  0.000000  0.000000  0.000000
# 2  0.00000  0.000  0.000000  0.000000  0.000000
# 3  0.00000  0.275  0.000000  0.000000  0.000000
# 4  0.00000  0.000  0.000000  0.000000  0.000000
# 5  0.08558  0.000  0.044776  0.060302  0.000000
# 6  0.00000  0.000  0.268657  0.000000  0.121212
# 7  0.00000  0.100  0.000000  0.000000  0.000000
# 8  0.00000  0.000  0.000000  0.190955  0.121212

# %%
pd.DataFrame(all_train_lb[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.690626  0.545579  0.605049  0.712343  0.705724  0.683877  0.556603
# 1  0.219134  0.000000  0.000000  0.000000  0.000000  0.000000 -0.034380
# 2  0.000000  0.135323  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.310740  0.000000  0.000000  0.000000  0.031452
# 4  0.000000  0.000000  0.000000  0.165676  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.228729  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.200360  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.556516  0.684169  0.746813  ...  0.538426  0.412595  0.589726  0.535492
# 1  0.011509 -0.023013 -0.011162  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.038426  0.000414  0.097618 -0.068415
# 4 -0.037905  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5  0.000000 -0.044706  0.000000  ...  0.000000 -0.078085  0.000000  0.000000
# 6  0.000000  0.000000  0.019824  ...  0.000000  0.000000  0.000609  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000 -0.084382
#
#          18        19        20        21        22        23
# 0  0.555418  0.646098  0.456187  0.363030  0.478314  0.626481
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4 -0.025720 -0.045682 -0.087926 -0.072662  0.000000  0.000000
# 5 -0.063799  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000 -0.011405  0.000000  0.000000 -0.039925  0.000000
# 7  0.000000  0.000000 -0.048388  0.000000 -0.039925  0.000000
# 8  0.000000  0.000000  0.000000  0.021890  0.000000  0.248872
#
# [9 rows x 24 columns]

# %%
pd.DataFrame(all_train_ub[0][0])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.780866  0.864677  0.689260  0.834324  0.771271  0.799640  0.917081
# 1  0.309374  0.000000  0.000000  0.000000  0.000000  0.000000  0.174731
# 2  0.000000  0.454421  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.394951  0.000000  0.000000  0.000000  0.354513
# 4  0.000000  0.000000  0.000000  0.287657  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.294276  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.316123  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.933680  1.011484  0.946735  ...  0.961574  0.972020  0.841168  1.047841
# 1  0.341432  0.283882  0.107936  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.461574  0.538048  0.325146  0.401749
# 4  0.194768  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5  0.000000  0.088184  0.000000  ...  0.000000  0.155009  0.000000  0.000000
# 6  0.000000  0.000000  0.189853  ...  0.000000  0.000000  0.145732  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.167715
#
#          18        19        20        21        22        23
# 0  1.007082  0.998346  1.022074  0.922685  0.950257  0.751128
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.400720  0.090127  0.174883  0.144091  0.000000  0.000000
# 5  0.126299  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.000000  0.322516  0.000000  0.000000  0.325640  0.000000
# 7  0.000000  0.000000  0.483170  0.000000  0.325640  0.000000
# 8  0.000000  0.000000  0.000000  0.549538  0.000000  0.373519
#
# [9 rows x 24 columns]

# %%
all_test_collection[0][0]
# Out:
# [[0, 5], [0, 3, 7], [0, 5, 6], [0, 5, 8], [0, 6, 8]]

# %%
def expectation_step(v_values,data,collections,L,offer_times):
    n,m = data.shape

    # Pyomo model
    model = pyo.ConcreteModel()

    # Variables
    model.w = pyo.Var(range(L), domain=pyo.NonNegativeReals,bounds=(0.001,1))

    # Objective function
    model.obj = pyo.Objective(
        expr=sum(sum(offer_times[i] * data[j, i] * pyo.log(
            sum(model.w[l] * np.exp(v_values[l, j]) / sum(np.exp(v_values[l, k]) for k in collections[i]) for l in range(L))
        ) for j in collections[i]) for i in range(m)),
        sense=pyo.maximize
    )

    # Constraint: Sum of weights equals 1
    model.sum_weights_constraint = pyo.Constraint(expr=sum(model.w[l] for l in range(L)) == 1)

    # Solve the optimization problem
    solver = pyo.SolverFactory('ipopt')
    results = solver.solve(model)
    
    # Print optimization status
    #print("Optimization Status:", results.solver.status)
    if results.solver.status == pyo.SolverStatus.ok:
        #print('Optimal solution found!')
       
        #model.pprint()
    
        w_values = [model.w[l]() for l in range(L)]
        w_values = np.array(w_values)
        
        ''' print("Variable w =", [ model.w[l]() for l in range(L)])
        print("Objective Value =", model.obj()) '''
        
        return w_values,pyo.value(model.obj())
    else:
        print('No solution found or an error occurred.')

# %%
def maximization_step(weights,data,collections,offer_times):
    # Given data
    L = len(weights)
    n,m = data.shape
    
    # Create a ConcreteModel
    model = pyo.ConcreteModel()

    # Define decision variables
    model.v = pyo.Var(range(L), range(n), bounds=(-100, 100))

    # Define the objective function
    model.obj = pyo.Objective(
        expr=sum(sum(data[j][i] * offer_times[i] * pyo.log(sum(weights[l] * pyo.exp(model.v[l, j]) / sum(pyo.exp(model.v[l, k]) for k in collections[i]) for l in range(L))) for j in collections[i]) for i in range(m)),
        sense=pyo.maximize
    )
    
    # preference parameter of outside option 
    model.outsideopt_constraint = pyo.ConstraintList()
    for l in range(L):
        model.outsideopt_constraint.add(model.v[l,0] == 0)

    # Solve the model
    solver = pyo.SolverFactory('ipopt')
    results = solver.solve(model)

    # Print optimization status
    #print("Optimization Status:", results.solver.status)
    if results.solver.status == pyo.SolverStatus.ok:
        #print('Optimal solution found!')
        #model.write('lcmnl_maximizatioin.mps', io_options={'symbolic_solver_labels': True})
        #model.pprint()
    
        v_values = [[model.v[l, i]() for i in range(n)] for l in range(L)]
        v_values = np.array(v_values)

        # Print variable values and objective value
        ''' print("Variable v =", [[model.v[l, i]() for i in range(n)] for l in range(L)])
        print("Objective Value =", model.obj()) '''
        
        return v_values,model.obj()
    else:
        print('No solution found or an error occurred.')

# %%
# EM algorithm for solving the MLE of LC-MNL
def expectation_maximization(data, collections,offer_times, num_class, max_iterations):
    
    weights = np.ones(num_class)/num_class
    v_values,ll = maximization_step(weights,data,collections,offer_times)
    #print('initial loglikelihood values',ll)
    #print('intitial preference parameters',v_values)

    for i in range(max_iterations):
        curr_ll = ll
        weights,ll = expectation_step(v_values,data,collections,num_class,offer_times)
        #print(f'the loglikelihood after expectation at iteration {i} is {ll}')
        v_values,ll = maximization_step(weights,data,collections,offer_times)
        #print(f'the loglikelihood after maximization at iteration {i} is {ll}')
        
        ''' if ll - curr_ll < 0.001:
            print(f'{ll} at current iteration and {curr_ll} at last iteration  ')
            return weights, v_values,ll '''
        
    return   weights, v_values,ll

# %%
def collection_distribution_lcmnl(n,collection,num_mix,weights,parameters_v):
    
    
    collection_distribution = np.zeros((n,len(collection)))
    
    for i in range(len(collection)): 
        curr_total_v = np.zeros(num_mix) # the denominator for each class
        
        for j in range(len(collection[i])): 
            for k in range(num_mix):
                curr_total_v[k] = curr_total_v[k] + math.exp(parameters_v[k][collection[i][j]])
        #print('checking the weights of denominators',curr_total_v)
        
        for j in range(len(collection[i])):
            for k in range(num_mix):
                collection_distribution[collection[i][j]][i] = collection_distribution[collection[i][j]][i] + weights[k]*math.exp(parameters_v[k][collection[i][j]])/curr_total_v[k]
    
    return collection_distribution

# %%
## prediction for the current testing collection of assortments 
def lcmnl_prediction(curr_test_instance,curr_test_collection,price,weights,v_values,n):
    ''' true assortment ranking '''
    true_choice_prob = [] 
    true_revenue = []
    
    lcmnl_revenue = []
    lcmnl_sales = []
    
    # lc- mnl outofsample choice probability using EM estimators 
    
    estimated_oos_prob = collection_distribution_lcmnl(n,curr_test_collection,len(weights),weights,v_values)
    
    
    for k in range(len(curr_test_collection)):

        # true revenue and true choice probabilities for current testing assortment
        curr_revenue = np.dot(curr_test_instance[:,k],price)
        true_revenue.append(curr_revenue)
        true_choice_prob.append(curr_test_instance[:,k])
        curr_lcmnl_rev = np.dot(estimated_oos_prob[:,k],price)
        
        lcmnl_sales.append(estimated_oos_prob[:,k])
        lcmnl_revenue.append(curr_lcmnl_rev)
        print(f'revenue of assortment {curr_test_collection[k]} is {curr_lcmnl_rev}')
        
        ## record the runtime result
        
        
    return true_revenue,true_choice_prob,lcmnl_revenue,lcmnl_sales

# %%
def kendall_tau_distance(values1, values2):
    """Compute the Kendall tau distance."""
    num = len(values1)
    assert len(values2) == num, "Both lists have to be of equal length"
    i, j = np.meshgrid(np.arange(num), np.arange(num))
    a = np.argsort(values1)
    b = np.argsort(values2)
    ndisordered = np.logical_or(np.logical_and(a[i] < a[j], b[i] > b[j]), np.logical_and(a[i] > a[j], b[i] < b[j])).sum()
    return ndisordered/2

# %%
## record representability of all instances

## record the kendall tau distance between the predicted ranking of lcmnl and the truth
all_lcmnl_distance_list = []  

## record the true revenue of the predicted best assortment
all_best_true_rev_list = []
all_best_rev_lcmnl_list = []  

## record the difference in best assortment
all_lcmnl_best_rev_diff = []

## record all the true and predicted revenues
all_true_revenue_list = []
all_lcmnl_revenue_list = []

all_true_prob_list = [] 
all_lcmnl_sales_list = []

all_true_ranking = []
all_lcmnl_ranking = []

## record the runtime of lcmnl prediction
all_lcmnl_pred_runtime = []

num_class = 10
max_iterations = 50

for i in range(len(pred_full_collection)):
       
    # define as a container for quantity of the same collection size 
    # The following lists are of the same size as the instance size
    
    true_best_rev_collection = [] # a container for groundtruth best reveue 
    lcmnl_best_rev_collection = [] # a container for the best revenue predicted by robust lcmnl
    
    true_ranking_collection = [] # a container for groundtruth reveue ranking 
    lcmnl_ranking_collection = [] # a container for ranking by robust lcmnl
    
    lcmnl_distance_collection = [] # a container for kendall tau distance between true ranking and the ranking by robust lcmnl
   
    
    true_choice_prob_collection = []
    lcmnl_sales_frac_collection = []

    true_revenue_collection = []
    lcmnl_revenue_collection = []
    
    lcmnl_runtime_collection = []
    
    for j in range(pred_instance_size[i]):
        
        print(f'testing for offertimes {pred_offer_times_list[i]}, {j}th instance')
        
        starttime = time.time()
        weights, v_values,ll = expectation_maximization(all_train_instances[i][j],all_train_collection[i][j],all_train_offertimes[i][j], num_class, max_iterations)
        #lcmnl_choiceprob_100 = collection_distribution_lcmnl(n,collection_100,num_class,weights,v_values)
        lcmnl_mle_runtime = time.time()-starttime
        
        true_revenue,true_choice_prob,lcmnl_revenue,lcmnl_sales = lcmnl_prediction(all_test_instance[i][j],all_test_collection[i][j],price,weights,v_values,n)
        # the following lists are of the same size as number of testing assortments
        
        ll_timelst = [lcmnl_mle_runtime]* len(all_test_collection[i][j])
        #tolruntime = [x + y for x, y in zip(ll_timelst, lcmnl_runtime)]
        
        true_revenue_collection.append(true_revenue)
        true_choice_prob_collection.append(true_choice_prob)
        
        lcmnl_revenue_collection.append(lcmnl_revenue)   
        lcmnl_sales_frac_collection.append(lcmnl_sales)
        lcmnl_runtime_collection.append(ll_timelst)
         
        # true assortment ranking for test instance [i][j]
        curr_true_rank = np.argsort(-np.array(true_revenue))  
        true_ranking_collection.append(curr_true_rank)
        # true best assortment revenue for test instance [i][j]
        true_best_rev_collection.append(true_revenue[curr_true_rank[0]])
        
        # lb mdm assortment ranking for test instance [i][j] 
        curr_lcmnl_rank  = np.argsort(-np.array(lcmnl_revenue)) 
        lcmnl_ranking_collection.append(curr_lcmnl_rank)
        lcmnl_best_rev_collection.append(true_revenue[curr_lcmnl_rank[0]])
        
        
        #  lcmnl kendallTau Distance for current instance [i][j]
        curr_lcmnl_dist = kendall_tau_distance(curr_true_rank, curr_lcmnl_rank)
        lcmnl_distance_collection.append(curr_lcmnl_dist)
    
    
    # for each test instance [i][j] kendall tau distance is a number
    all_lcmnl_distance_list.append(lcmnl_distance_collection)
    
    # for each test instance [i][j] best revenue is a number
    all_best_true_rev_list.append(true_best_rev_collection) 
    all_best_rev_lcmnl_list.append(lcmnl_best_rev_collection)
    
    # for each test instance [i][j] best revenue difference is a number
    all_lcmnl_best_rev_diff.append((np.array(true_best_rev_collection) - np.array(lcmnl_best_rev_collection))/ np.array(true_best_rev_collection))
    
    # for each test instance [i][j], true revenue is a list of the same size as the number of testing assortments
    all_true_revenue_list.append(true_revenue_collection)
    
    all_lcmnl_revenue_list.append(lcmnl_revenue_collection)
    
    all_true_prob_list.append(true_choice_prob_collection)
    all_lcmnl_sales_list.append(lcmnl_sales_frac_collection)
 
    # for each test instance [i][j], true ranking is a list of the same size as the number of testing assortments
    all_true_ranking.append(true_ranking_collection)
    all_lcmnl_ranking.append(lcmnl_ranking_collection)

    ## for each test instance [i][j], runtime is a list of the same size as the number of testing assortments
    all_lcmnl_pred_runtime.append(lcmnl_runtime_collection)
# Out:
# testing for offertimes 20, 0th instance
# revenue of assortment [0, 5] is 0.2366801949515799
# revenue of assortment [0, 3, 7] is 0.14070854228965665
# revenue of assortment [0, 5, 6] is 0.13372543268155576
# revenue of assortment [0, 5, 8] is 0.4995833573355413
# revenue of assortment [0, 6, 8] is 0.35337151866559147
# testing for offertimes 20, 1th instance
# revenue of assortment [0, 3] is 0.11678386638278662
# revenue of assortment [0, 4] is 0.3184968185884979
# revenue of assortment [0, 1, 4] is 0.2743597628611625
# revenue of assortment [0, 3, 4] is 0.1544137555200275
# revenue of assortment [0, 5, 6] is 0.13984305882417788
# testing for offertimes 20, 2th instance
# revenue of assortment [0, 1, 8] is 0.4201637752588433
# revenue of assortment [0, 2, 6] is 0.1679956614275551
# revenue of assortment [0, 3, 4] is 0.139994361609066
# revenue of assortment [0, 4, 5] is 0.4216006170998869
# revenue of assortment [0, 5, 8] is 0.4787250113134153
# testing for offertimes 20, 3th instance
# revenue of assortment [0, 1] is 0.16441880379044535
# revenue of assortment [0, 4] is 0.3184729938923573
# revenue of assortment [0, 7] is 0.173209938300043
# revenue of assortment [0, 3, 4] is 0.16987878429620584
# revenue of assortment [0, 8] is 0.32590270359596174
# testing for offertimes 20, 4th instance
# revenue of assortment [0, 1, 8] is 0.3894928593532504
# revenue of assortment [0, 2, 3, 6] is 0.1662510822720505
# revenue of assortment [0, 3, 8] is 0.21974064646666858
# revenue of assortment [0, 5, 6] is 0.1715248913616229
# revenue of assortment [0, 6, 7] is 0.15208632217079274
# testing for offertimes 20, 5th instance
# revenue of assortment [0, 1] is 0.1717017253962537
# revenue of assortment [0, 1, 4] is 0.3307605681753435
# revenue of assortment [0, 2, 6] is 0.146523848536537
# revenue of assortment [0, 4, 7] is 0.25435560732937684
# revenue of assortment [0, 5, 6] is 0.13714203847428136
# testing for offertimes 20, 6th instance
# revenue of assortment [0, 4] is 0.3290362963153076
# revenue of assortment [0, 1, 3] is 0.1719722455810121
# revenue of assortment [0, 3, 7] is 0.13496085875661248
# revenue of assortment [0, 4, 8] is 0.4773230537402799
# revenue of assortment [0, 5, 8] is 0.4792971164973272
# testing for offertimes 20, 7th instance
# revenue of assortment [0, 1] is 0.1811720938295684
# revenue of assortment [0, 1, 6] is 0.23571183285415248
# revenue of assortment [0, 3, 6] is 0.14328778066384718
# revenue of assortment [0, 4, 5] is 0.4238573804819181
# revenue of assortment [0, 8] is 0.3671818423196262
# testing for offertimes 20, 8th instance
# revenue of assortment [0, 1] is 0.16693216052704737
# revenue of assortment [0, 7] is 0.1576436646380909
# revenue of assortment [0, 1, 8] is 0.2847713779335109
# revenue of assortment [0, 4, 6] is 0.20435994383191533
# revenue of assortment [0, 8] is 0.34520139374426023
# testing for offertimes 20, 9th instance
# revenue of assortment [0, 1] is 0.18142855516992834
# revenue of assortment [0, 1, 3] is 0.16866292564482122
# revenue of assortment [0, 2, 3, 6] is 0.16146449163577326
# revenue of assortment [0, 3, 5] is 0.15843305944868127
# revenue of assortment [0, 4, 8] is 0.45268121492983177
# testing for offertimes 20, 10th instance
# revenue of assortment [0, 1, 3] is 0.2105530236095546
# revenue of assortment [0, 2, 6] is 0.1514086777853744
# revenue of assortment [0, 3, 4] is 0.1876588287995952
# revenue of assortment [0, 3, 6] is 0.15472591460873153
# revenue of assortment [0, 5, 6] is 0.14450436471074218
# testing for offertimes 20, 11th instance
# revenue of assortment [0, 1, 3] is 0.1507540643938145
# revenue of assortment [0, 1, 7] is 0.22963386820334827
# revenue of assortment [0, 2, 6] is 0.14590219622423145
# revenue of assortment [0, 4, 6] is 0.17443714950117845
# revenue of assortment [0, 5, 6] is 0.1713493076583944
# testing for offertimes 20, 12th instance
# revenue of assortment [0, 1] is 0.24702801754656187
# revenue of assortment [0, 1, 5] is 0.3102417232729489
# revenue of assortment [0, 2, 3, 6] is 0.16419198314080002
# revenue of assortment [0, 3, 6] is 0.1414529937644699
# revenue of assortment [0, 6, 7] is 0.13843422232412275
# testing for offertimes 20, 13th instance
# revenue of assortment [0, 4] is 0.1318430948487928
# revenue of assortment [0, 6] is 0.10597746710850751
# revenue of assortment [0, 4, 5] is 0.22313102271683533
# revenue of assortment [0, 4, 8] is 0.45393908663790494
# revenue of assortment [0, 6, 8] is 0.3882361624341052
# testing for offertimes 20, 14th instance
# revenue of assortment [0, 4] is 0.29803927317159273
# revenue of assortment [0, 1, 5] is 0.3215439601632454
# revenue of assortment [0, 1, 6] is 0.21588638182423872
# revenue of assortment [0, 4, 8] is 0.38250897777613496
# revenue of assortment [0, 8] is 0.3816399257983007
# testing for offertimes 20, 15th instance
# revenue of assortment [0, 2, 3, 6] is 0.1656984136654941
# revenue of assortment [0, 3, 5] is 0.16060242497252897
# revenue of assortment [0, 4, 7] is 0.3263885806857863
# revenue of assortment [0, 4, 8] is 0.45454618494367716
# revenue of assortment [0, 6, 7] is 0.15465474935478574
# testing for offertimes 20, 16th instance
# revenue of assortment [0, 7] is 0.16586916803483312
# revenue of assortment [0, 1, 5] is 0.318725649660214
# revenue of assortment [0, 3, 7] is 0.1400840688227597
# revenue of assortment [0, 4, 6] is 0.21980675281441522
# revenue of assortment [0, 8] is 0.37456481564472277
# testing for offertimes 20, 17th instance
# revenue of assortment [0, 1, 8] is 0.39946346869265914
# revenue of assortment [0, 3, 4] is 0.13372790305084567
# revenue of assortment [0, 3, 5] is 0.17507651974203323
# revenue of assortment [0, 3, 7] is 0.14109841195993317
# revenue of assortment [0, 6, 8] is 0.3435418353793765
# testing for offertimes 20, 18th instance
# revenue of assortment [0, 2] is 0.11618079419858648
# revenue of assortment [0, 1, 3] is 0.16674536759598835
# revenue of assortment [0, 3, 4] is 0.17041097783104203
# revenue of assortment [0, 4, 8] is 0.4912570537368624
# revenue of assortment [0, 6, 8] is 0.3464137107229501
# testing for offertimes 20, 19th instance
# revenue of assortment [0, 6] is 0.10168537415787726
# revenue of assortment [0, 1, 8] is 0.42685698251301096
# revenue of assortment [0, 2, 3, 6] is 0.17290834854084858
# revenue of assortment [0, 4, 6] is 0.20420545766107454
# revenue of assortment [0, 5, 8] is 0.4848363490768179
# testing for offertimes 20, 20th instance
# revenue of assortment [0, 1, 7] is 0.26308193280035885
# revenue of assortment [0, 3, 6] is 0.14006372022791433
# revenue of assortment [0, 4, 7] is 0.34533078053886435
# revenue of assortment [0, 5, 6] is 0.1484262511592575
# revenue of assortment [0, 8] is 0.36056121551805514
# testing for offertimes 20, 21th instance
# revenue of assortment [0, 3] is 0.11202787982318928
# revenue of assortment [0, 1, 7] is 0.25247725788450204
# revenue of assortment [0, 2, 6] is 0.15869803320488196
# revenue of assortment [0, 4, 6] is 0.16165347341351416
# revenue of assortment [0, 4, 8] is 0.4492776979479809
# testing for offertimes 20, 22th instance
# revenue of assortment [0, 4] is 0.3009239125699921
# revenue of assortment [0, 6] is 0.08984187552505525
# revenue of assortment [0, 3, 5] is 0.17053789793501434
# revenue of assortment [0, 4, 6] is 0.13220652997406443
# revenue of assortment [0, 5, 6] is 0.16004441443707185
# testing for offertimes 20, 23th instance
# revenue of assortment [0, 1, 7] is 0.22694219810265925
# revenue of assortment [0, 1, 8] is 0.3948429511292765
# revenue of assortment [0, 3, 4] is 0.15188163014373762
# revenue of assortment [0, 3, 5] is 0.18498696230142436
# revenue of assortment [0, 6, 7] is 0.16909523462376144
# testing for offertimes 20, 24th instance
# revenue of assortment [0, 1] is 0.2027129422092226
# revenue of assortment [0, 2] is 0.12501964045570046
# revenue of assortment [0, 1, 5] is 0.30013923065343445
# revenue of assortment [0, 3, 4] is 0.16535145459610615
# revenue of assortment [0, 4, 8] is 0.4592353687776282
# testing for offertimes 20, 25th instance
# revenue of assortment [0, 1, 8] is 0.39450494255423585
# revenue of assortment [0, 3, 7] is 0.14443706883905053
# revenue of assortment [0, 3, 8] is 0.23781854048623846
# revenue of assortment [0, 4, 7] is 0.29307561025519385
# revenue of assortment [0, 6, 8] is 0.2964571655431517
# testing for offertimes 20, 26th instance
# revenue of assortment [0, 1] is 0.16518959509400147
# revenue of assortment [0, 6] is 0.08973185878800144
# revenue of assortment [0, 1, 3] is 0.16673765946929112
# revenue of assortment [0, 3, 5] is 0.17762969169027015
# revenue of assortment [0, 4, 5] is 0.40507691343432284
# testing for offertimes 20, 27th instance
# revenue of assortment [0, 7] is 0.17961193339289763
# revenue of assortment [0, 1, 3] is 0.17038759451746832
# revenue of assortment [0, 3, 6] is 0.14561066066563444
# revenue of assortment [0, 5, 6] is 0.14837792094006327
# revenue of assortment [0, 6, 8] is 0.34352720031026435
# testing for offertimes 20, 28th instance
# revenue of assortment [0, 1, 7] is 0.2369321234239492
# revenue of assortment [0, 1, 8] is 0.4443928846432169
# revenue of assortment [0, 3, 5] is 0.18778581272119618
# revenue of assortment [0, 3, 7] is 0.13955513970879857
# revenue of assortment [0, 6, 8] is 0.38049943022168525
# testing for offertimes 20, 29th instance
# revenue of assortment [0, 1, 4] is 0.2744641803572366
# revenue of assortment [0, 1, 7] is 0.23280465280104415
# revenue of assortment [0, 2, 6] is 0.1428160229132701
# revenue of assortment [0, 3, 6] is 0.14011033720812888
# revenue of assortment [0, 4, 6] is 0.1699357483652894
# testing for offertimes 20, 30th instance
# revenue of assortment [0, 1] is 0.16310933677146663
# revenue of assortment [0, 1, 8] is 0.3970389889243162
# revenue of assortment [0, 3, 8] is 0.14309003120034341
# revenue of assortment [0, 4, 8] is 0.47025940654674797
# revenue of assortment [0, 5, 8] is 0.5070106502934043
# testing for offertimes 20, 31th instance
# revenue of assortment [0, 3, 5] is 0.15639852880357524
# revenue of assortment [0, 4, 8] is 0.49390683197102725
# revenue of assortment [0, 6, 7] is 0.1535969820341558
# revenue of assortment [0, 6, 8] is 0.39590695657207275
# revenue of assortment [0, 8] is 0.3538069825731444
# testing for offertimes 20, 32th instance
# revenue of assortment [0, 5] is 0.2422764296128972
# revenue of assortment [0, 3, 5] is 0.1347263284178617
# revenue of assortment [0, 3, 6] is 0.14044616557003148
# revenue of assortment [0, 5, 6] is 0.1208769990975921
# revenue of assortment [0, 5, 8] is 0.47430318264970867
# testing for offertimes 20, 33th instance
# revenue of assortment [0, 2] is 0.1378081689302576
# revenue of assortment [0, 7] is 0.18215111114732696
# revenue of assortment [0, 2, 3, 6] is 0.1535236937308575
# revenue of assortment [0, 3, 4] is 0.18803362995737205
# revenue of assortment [0, 6, 8] is 0.37942163187322403
# testing for offertimes 20, 34th instance
# revenue of assortment [0, 7] is 0.15913203730221726
# revenue of assortment [0, 1, 7] is 0.21751733208310362
# revenue of assortment [0, 3, 5] is 0.16557689470079917
# revenue of assortment [0, 3, 6] is 0.14029368606011644
# revenue of assortment [0, 3, 7] is 0.14433508092169137
# testing for offertimes 20, 35th instance
# revenue of assortment [0, 1] is 0.17581830048494282
# revenue of assortment [0, 1, 7] is 0.22224172483639748
# revenue of assortment [0, 2, 3, 6] is 0.15330385649922323
# revenue of assortment [0, 3, 4] is 0.16413844603538813
# revenue of assortment [0, 6, 7] is 0.1573181613748045
# testing for offertimes 20, 36th instance
# revenue of assortment [0, 1, 6] is 0.21717059057183227
# revenue of assortment [0, 2, 6] is 0.15378658146619345
# revenue of assortment [0, 3, 6] is 0.14570612145588382
# revenue of assortment [0, 3, 8] is 0.30063299915932584
# revenue of assortment [0, 5, 8] is 0.5164744243837244
# testing for offertimes 20, 37th instance
# revenue of assortment [0, 1] is 0.15704624081895857
# revenue of assortment [0, 1, 3] is 0.23258380991829225
# revenue of assortment [0, 3, 8] is 0.3110612267754321
# revenue of assortment [0, 4, 5] is 0.4187674203026292
# revenue of assortment [0, 5, 8] is 0.47877953919963745
# testing for offertimes 20, 38th instance
# revenue of assortment [0, 3] is 0.1128767640077054
# revenue of assortment [0, 6] is 0.11074948742524464
# revenue of assortment [0, 3, 6] is 0.12248914276806556
# revenue of assortment [0, 3, 7] is 0.12156025615575518
# revenue of assortment [0, 6, 8] is 0.3856787142217437
# testing for offertimes 20, 39th instance
# revenue of assortment [0, 1, 4] is 0.3060412953685955
# revenue of assortment [0, 3, 6] is 0.14015728066124244
# revenue of assortment [0, 5, 8] is 0.5181218579085134
# revenue of assortment [0, 6, 7] is 0.15944609298139895
# revenue of assortment [0, 6, 8] is 0.36450605046790785
# testing for offertimes 20, 40th instance
# revenue of assortment [0, 2] is 0.12916087457377706
# revenue of assortment [0, 3] is 0.10962941150107222
# revenue of assortment [0, 4, 6] is 0.18854481498668263
# revenue of assortment [0, 6, 7] is 0.14172086438747009
# revenue of assortment [0, 6, 8] is 0.44389764059781883
# testing for offertimes 20, 41th instance
# revenue of assortment [0, 1] is 0.17690781594337648
# revenue of assortment [0, 1, 3] is 0.17974649130615689
# revenue of assortment [0, 1, 4] is 0.2807046021963969
# revenue of assortment [0, 2, 6] is 0.1482517391781275
# revenue of assortment [0, 5, 6] is 0.14954357792759904
# testing for offertimes 20, 42th instance
# revenue of assortment [0, 4] is 0.3543807746403072
# revenue of assortment [0, 6] is 0.09890126460327144
# revenue of assortment [0, 1, 4] is 0.2971997534889774
# revenue of assortment [0, 3, 8] is 0.3322454596828592
# revenue of assortment [0, 5, 8] is 0.5165605438958438
# testing for offertimes 20, 43th instance
# revenue of assortment [0, 3] is 0.10906812967923875
# revenue of assortment [0, 6] is 0.11247746730262381
# revenue of assortment [0, 1, 4] is 0.31401325588023804
# revenue of assortment [0, 1, 5] is 0.3121660928468902
# revenue of assortment [0, 1, 7] is 0.2403145043578711
# testing for offertimes 20, 44th instance
# revenue of assortment [0, 6] is 0.12161818104405331
# revenue of assortment [0, 1, 4] is 0.3546007161593059
# revenue of assortment [0, 3, 5] is 0.17803465467577823
# revenue of assortment [0, 4, 5] is 0.40498921461404724
# revenue of assortment [0, 4, 6] is 0.25053461015213924
# testing for offertimes 20, 45th instance
# revenue of assortment [0, 1, 5] is 0.3240819239050643
# revenue of assortment [0, 1, 6] is 0.21031384654775467
# revenue of assortment [0, 2, 6] is 0.15675010446349347
# revenue of assortment [0, 3, 4] is 0.17244736542034306
# revenue of assortment [0, 4, 7] is 0.24781554125370375
# testing for offertimes 20, 46th instance
# revenue of assortment [0, 1] is 0.21703501691220062
# revenue of assortment [0, 4] is 0.30623986751011256
# revenue of assortment [0, 1, 5] is 0.2915467065558293
# revenue of assortment [0, 1, 8] is 0.3971176935017119
# revenue of assortment [0, 3, 4] is 0.1337808161815137
# testing for offertimes 20, 47th instance
# revenue of assortment [0, 7] is 0.17066661542615952
# revenue of assortment [0, 1, 4] is 0.30972120762033395
# revenue of assortment [0, 1, 6] is 0.22212686882664429
# revenue of assortment [0, 2, 3, 6] is 0.16332764291861362
# revenue of assortment [0, 5, 8] is 0.47391337409778705
# testing for offertimes 20, 48th instance
# revenue of assortment [0, 4] is 0.31120446929976264
# revenue of assortment [0, 1, 4] is 0.30320130337908613
# revenue of assortment [0, 3, 5] is 0.15948148089454012
# revenue of assortment [0, 4, 8] is 0.4714500965475223
# revenue of assortment [0, 8] is 0.3491417747356485
# testing for offertimes 20, 49th instance
# revenue of assortment [0, 1] is 0.16186713532810315
# revenue of assortment [0, 7] is 0.17260864339291332
# revenue of assortment [0, 2, 3, 6] is 0.15947665106145725
# revenue of assortment [0, 3, 8] is 0.26661652090583166
# revenue of assortment [0, 6, 7] is 0.15533573148524232
# testing for offertimes 30, 0th instance
# revenue of assortment [0, 1] is 0.16415419453521501
# revenue of assortment [0, 5] is 0.11777364618388257
# revenue of assortment [0, 1, 3] is 0.198224515708597
# revenue of assortment [0, 1, 8] is 0.3991218424625038
# testing for offertimes 30, 1th instance
# revenue of assortment [0, 2] is 0.14112841703162424
# revenue of assortment [0, 6] is 0.10718131103126881
# revenue of assortment [0, 3, 4] is 0.16879374529472474
# revenue of assortment [0, 8] is 0.34396512632249976
# testing for offertimes 30, 2th instance
# revenue of assortment [0, 2, 6] is 0.20404776608717248
# revenue of assortment [0, 3, 7] is 0.1364948980792887
# revenue of assortment [0, 6, 7] is 0.1471189282699978
# revenue of assortment [0, 6, 8] is 0.41186711695830525
# testing for offertimes 30, 3th instance
# revenue of assortment [0, 1, 3] is 0.13458382914085232
# revenue of assortment [0, 4, 5] is 0.3993767854594071
# revenue of assortment [0, 5, 8] is 0.5501055021446546
# revenue of assortment [0, 6, 8] is 0.3999250950691079
# testing for offertimes 30, 4th instance
# revenue of assortment [0, 1, 3] is 0.16526715572196282
# revenue of assortment [0, 3, 4] is 0.1842939542653355
# revenue of assortment [0, 3, 7] is 0.16548092213354038
# revenue of assortment [0, 5, 8] is 0.4574301988540649
# testing for offertimes 30, 5th instance
# revenue of assortment [0, 1] is 0.16427603361163462
# revenue of assortment [0, 1, 8] is 0.37802546248388463
# revenue of assortment [0, 4, 6] is 0.22474789974701614
# revenue of assortment [0, 6, 7] is 0.1847177296546187
# testing for offertimes 30, 6th instance
# revenue of assortment [0, 1, 6] is 0.20193305438821088
# revenue of assortment [0, 2, 6] is 0.2072472971030728
# revenue of assortment [0, 5, 8] is 0.470594085943725
# revenue of assortment [0, 6, 7] is 0.1817837400759631
# testing for offertimes 30, 7th instance
# revenue of assortment [0, 2] is 0.15974080743997227
# revenue of assortment [0, 5] is 0.08311141826021672
# revenue of assortment [0, 1, 5] is 0.3154171370689519
# revenue of assortment [0, 8] is 0.344491482736585
# testing for offertimes 30, 8th instance
# revenue of assortment [0, 2] is 0.12288639352428693
# revenue of assortment [0, 3] is 0.10903562186572834
# revenue of assortment [0, 7] is 0.1832229009018046
# revenue of assortment [0, 1, 5] is 0.27890565720590743
# testing for offertimes 30, 9th instance
# revenue of assortment [0, 3] is 0.10459802693766578
# revenue of assortment [0, 6] is 0.1142188521648643
# revenue of assortment [0, 1, 5] is 0.308133742204643
# revenue of assortment [0, 8] is 0.3484867761497698
# testing for offertimes 30, 10th instance
# revenue of assortment [0, 5] is 0.07679916272958244
# revenue of assortment [0, 1, 4] is 0.2775671024400442
# revenue of assortment [0, 2, 6] is 0.2049051798748499
# revenue of assortment [0, 4, 6] is 0.12936712626217745
# testing for offertimes 30, 11th instance
# revenue of assortment [0, 1] is 0.17886116746716368
# revenue of assortment [0, 2] is 0.1492590745036489
# revenue of assortment [0, 4, 5] is 0.362999427252266
# revenue of assortment [0, 4, 6] is 0.2207848561962558
# testing for offertimes 30, 12th instance
# revenue of assortment [0, 6] is 0.10130671129643114
# revenue of assortment [0, 7] is 0.19686726876581886
# revenue of assortment [0, 3, 4] is 0.24095190825638058
# revenue of assortment [0, 4, 6] is 0.2288324206609444
# testing for offertimes 30, 13th instance
# revenue of assortment [0, 2] is 0.1532706484486002
# revenue of assortment [0, 3, 7] is 0.14065827794270316
# revenue of assortment [0, 5, 6] is 0.1363095480826817
# revenue of assortment [0, 6, 8] is 0.41919746902215915
# testing for offertimes 30, 14th instance
# revenue of assortment [0, 4] is 0.3175101854354027
# revenue of assortment [0, 7] is 0.17107883448857536
# revenue of assortment [0, 1, 7] is 0.24054780942724419
# revenue of assortment [0, 1, 8] is 0.4135444253378804
# testing for offertimes 30, 15th instance
# revenue of assortment [0, 7] is 0.16690275441103036
# revenue of assortment [0, 2, 6] is 0.20894679449537673
# revenue of assortment [0, 4, 6] is 0.16907105421863494
# revenue of assortment [0, 6, 7] is 0.14442781479771366
# testing for offertimes 30, 16th instance
# revenue of assortment [0, 4] is 0.3085146060185337
# revenue of assortment [0, 7] is 0.12788570026283072
# revenue of assortment [0, 3, 6] is 0.13931226423028598
# revenue of assortment [0, 4, 6] is 0.12184592761727724
# testing for offertimes 30, 17th instance
# revenue of assortment [0, 1, 5] is 0.3091874993608863
# revenue of assortment [0, 1, 8] is 0.4117925068795054
# revenue of assortment [0, 3, 7] is 0.13683185189513514
# revenue of assortment [0, 6, 7] is 0.13579864660925584
# testing for offertimes 30, 18th instance
# revenue of assortment [0, 1] is 0.17806129845323163
# revenue of assortment [0, 1, 6] is 0.21326928092411968
# revenue of assortment [0, 3, 6] is 0.1425645969469931
# revenue of assortment [0, 5, 6] is 0.1493765408430403
# testing for offertimes 30, 19th instance
# revenue of assortment [0, 1] is 0.19929473120698257
# revenue of assortment [0, 6] is 0.09074515502632251
# revenue of assortment [0, 1, 5] is 0.272443178093953
# revenue of assortment [0, 1, 8] is 0.39274480614421
# testing for offertimes 30, 20th instance
# revenue of assortment [0, 5] is 0.17890199870025894
# revenue of assortment [0, 7] is 0.10598865507955646
# revenue of assortment [0, 1, 6] is 0.2093452119865649
# revenue of assortment [0, 4, 6] is 0.2468228247773948
# testing for offertimes 30, 21th instance
# revenue of assortment [0, 7] is 0.11469931080966829
# revenue of assortment [0, 1, 4] is 0.4532513519244564
# revenue of assortment [0, 1, 6] is 0.23281626193044244
# revenue of assortment [0, 2, 6] is 0.20525267562108815
# testing for offertimes 30, 22th instance
# revenue of assortment [0, 4] is 0.28304982435486586
# revenue of assortment [0, 1, 8] is 0.39194941672671824
# revenue of assortment [0, 4, 5] is 0.3738149825538108
# revenue of assortment [0, 6, 7] is 0.1545873733072362
# testing for offertimes 30, 23th instance
# revenue of assortment [0, 1, 7] is 0.34253457547322913
# revenue of assortment [0, 3, 6] is 0.14166632279252764
# revenue of assortment [0, 4, 5] is 0.385963743114798
# revenue of assortment [0, 6, 7] is 0.19739136424698533
# testing for offertimes 30, 24th instance
# revenue of assortment [0, 3] is 0.11233130293844246
# revenue of assortment [0, 1, 3] is 0.12694550201892907
# revenue of assortment [0, 4, 5] is 0.4054051832098153
# revenue of assortment [0, 8] is 0.3079703412345004
# testing for offertimes 30, 25th instance
# revenue of assortment [0, 2] is 0.12696885068230032
# revenue of assortment [0, 3] is 0.10917558811442711
# revenue of assortment [0, 5] is 0.14247777668396622
# revenue of assortment [0, 6] is 0.10427367899172929
# testing for offertimes 30, 26th instance
# revenue of assortment [0, 6] is 0.10098996869058682
# revenue of assortment [0, 7] is 0.19742778508368997
# revenue of assortment [0, 1, 4] is 0.27373671779135617
# revenue of assortment [0, 4, 5] is 0.40976399252867557
# testing for offertimes 30, 27th instance
# revenue of assortment [0, 1, 4] is 0.33150322084602163
# revenue of assortment [0, 1, 6] is 0.246800996455045
# revenue of assortment [0, 3, 7] is 0.1528139857981466
# revenue of assortment [0, 5, 6] is 0.1664235760324735
# testing for offertimes 30, 28th instance
# revenue of assortment [0, 4] is 0.3215005091332564
# revenue of assortment [0, 1, 5] is 0.3403710524505613
# revenue of assortment [0, 1, 6] is 0.2272075872514734
# revenue of assortment [0, 1, 7] is 0.29364778143385495
# testing for offertimes 30, 29th instance
# revenue of assortment [0, 1, 3] is 0.1427584283666702
# revenue of assortment [0, 3, 6] is 0.13773116546431594
# revenue of assortment [0, 5, 6] is 0.12083181606833301
# revenue of assortment [0, 6, 8] is 0.3686171877642631
# testing for offertimes 30, 30th instance
# revenue of assortment [0, 4] is 0.2007478398056362
# revenue of assortment [0, 5] is 0.15628285520173835
# revenue of assortment [0, 4, 5] is 0.1954647922358006
# revenue of assortment [0, 4, 6] is 0.18024336774381597
# testing for offertimes 30, 31th instance
# revenue of assortment [0, 4] is 0.35291279703056466
# revenue of assortment [0, 5] is 0.17169572700614671
# revenue of assortment [0, 1, 6] is 0.20938543696458267
# revenue of assortment [0, 1, 8] is 0.3877199156312466
# testing for offertimes 30, 32th instance
# revenue of assortment [0, 3] is 0.10983497101361568
# revenue of assortment [0, 1, 8] is 0.37650156710198035
# revenue of assortment [0, 4, 6] is 0.12102777450791759
# revenue of assortment [0, 5, 6] is 0.12102770699631732
# testing for offertimes 30, 33th instance
# revenue of assortment [0, 3] is 0.11005735031892348
# revenue of assortment [0, 1, 3] is 0.14669585459156506
# revenue of assortment [0, 4, 5] is 0.3765568710183964
# revenue of assortment [0, 4, 6] is 0.1271830334215713
# testing for offertimes 30, 34th instance
# revenue of assortment [0, 1, 4] is 0.3611986669019953
# revenue of assortment [0, 1, 5] is 0.3210617699709491
# revenue of assortment [0, 1, 7] is 0.2458439931873719
# revenue of assortment [0, 4, 6] is 0.1894227920450543
# testing for offertimes 30, 35th instance
# revenue of assortment [0, 4] is 0.36787892808709266
# revenue of assortment [0, 1, 4] is 0.2888923935119495
# revenue of assortment [0, 3, 4] is 0.17211056961491086
# revenue of assortment [0, 4, 5] is 0.39137633759527024
# testing for offertimes 30, 36th instance
# revenue of assortment [0, 1] is 0.19202314822126826
# revenue of assortment [0, 2] is 0.1467809895895118
# revenue of assortment [0, 4] is 0.30566695395355775
# revenue of assortment [0, 1, 5] is 0.21494313857366268
# testing for offertimes 30, 37th instance
# revenue of assortment [0, 1] is 0.19217995375002536
# revenue of assortment [0, 3] is 0.10682880852104784
# revenue of assortment [0, 5, 6] is 0.1386154856958338
# revenue of assortment [0, 6, 7] is 0.18716366731526374
# testing for offertimes 30, 38th instance
# revenue of assortment [0, 6] is 0.11891657570732757
# revenue of assortment [0, 1, 3] is 0.16594821805691945
# revenue of assortment [0, 2, 6] is 0.20689626753944196
# revenue of assortment [0, 4, 6] is 0.1780014073561788
# testing for offertimes 30, 39th instance
# revenue of assortment [0, 4] is 0.31716890170303863
# revenue of assortment [0, 6] is 0.100446127472627
# revenue of assortment [0, 3, 4] is 0.17590889799116607
# revenue of assortment [0, 6, 7] is 0.14526770241011178
# testing for offertimes 30, 40th instance
# revenue of assortment [0, 4] is 0.29627083222424777
# revenue of assortment [0, 6] is 0.1041930720137674
# revenue of assortment [0, 1, 3] is 0.1588126933652418
# revenue of assortment [0, 8] is 0.3147846279624104
# testing for offertimes 30, 41th instance
# revenue of assortment [0, 1, 5] is 0.3160845430355704
# revenue of assortment [0, 1, 8] is 0.39220620602550216
# revenue of assortment [0, 2, 6] is 0.20638605686202616
# revenue of assortment [0, 4, 5] is 0.4289839363559484
# testing for offertimes 30, 42th instance
# revenue of assortment [0, 1, 4] is 0.27023156834018935
# revenue of assortment [0, 3, 6] is 0.14529414765808807
# revenue of assortment [0, 4, 5] is 0.41654131999280825
# revenue of assortment [0, 6, 8] is 0.40543085191734896
# testing for offertimes 30, 43th instance
# revenue of assortment [0, 4] is 0.34447176990388
# revenue of assortment [0, 7] is 0.10523861533150296
# revenue of assortment [0, 1, 6] is 0.2310295946074265
# revenue of assortment [0, 5, 8] is 0.5212225525733266
# testing for offertimes 30, 44th instance
# revenue of assortment [0, 1] is 0.27585152399560914
# revenue of assortment [0, 2] is 0.15179186416984705
# revenue of assortment [0, 1, 5] is 0.28790320500440225
# revenue of assortment [0, 1, 6] is 0.19162305802988674
# testing for offertimes 30, 45th instance
# revenue of assortment [0, 1, 6] is 0.1920567363518486
# revenue of assortment [0, 3, 4] is 0.13433597840358402
# revenue of assortment [0, 5, 6] is 0.12511780831862407
# revenue of assortment [0, 8] is 0.416145279174487
# testing for offertimes 30, 46th instance
# revenue of assortment [0, 3] is 0.10324406541329009
# revenue of assortment [0, 1, 6] is 0.19354386892289904
# revenue of assortment [0, 1, 8] is 0.3675845202849423
# revenue of assortment [0, 5, 6] is 0.1374981333114452
# testing for offertimes 30, 47th instance
# revenue of assortment [0, 4] is 0.36765251701560886
# revenue of assortment [0, 7] is 0.14963577271885242
# revenue of assortment [0, 1, 4] is 0.30689035278743454
# revenue of assortment [0, 3, 4] is 0.20784672204734667
# testing for offertimes 30, 48th instance
# revenue of assortment [0, 3, 6] is 0.1425548119499081
# revenue of assortment [0, 4, 5] is 0.33418612949724363
# revenue of assortment [0, 5, 6] is 0.18071107265480268
# revenue of assortment [0, 6, 8] is 0.4899705873066109
# testing for offertimes 30, 49th instance
# revenue of assortment [0, 6] is 0.10077007169018438
# revenue of assortment [0, 1, 4] is 0.2599572081536249
# revenue of assortment [0, 1, 7] is 0.3371778942391612
# revenue of assortment [0, 6, 7] is 0.1999380221487002
# testing for offertimes 40, 0th instance
# revenue of assortment [0, 7] is 0.1801395241604881
# revenue of assortment [0, 1, 5] is 0.32047219591861276
# revenue of assortment [0, 5, 8] is 0.5093114406914563
# testing for offertimes 40, 1th instance
# revenue of assortment [0, 7] is 0.16376627955540876
# revenue of assortment [0, 1, 3] is 0.14300736073965664
# revenue of assortment [0, 2, 6] is 0.20772246217894194
# testing for offertimes 40, 2th instance
# revenue of assortment [0, 3] is 0.10275260917170458
# revenue of assortment [0, 1, 4] is 0.3248218254909697
# revenue of assortment [0, 8] is 0.3491476523031172
# testing for offertimes 40, 3th instance
# revenue of assortment [0, 3] is 0.10550533142911267
# revenue of assortment [0, 1, 6] is 0.1958547559994322
# revenue of assortment [0, 3, 7] is 0.2063735908410356
# testing for offertimes 40, 4th instance
# revenue of assortment [0, 1, 3] is 0.16489396328116673
# revenue of assortment [0, 1, 5] is 0.32292900706183564
# revenue of assortment [0, 3, 4] is 0.1719404340571119
# testing for offertimes 40, 5th instance
# revenue of assortment [0, 2] is 0.14116376248938944
# revenue of assortment [0, 6] is 0.10944500133250169
# revenue of assortment [0, 1, 6] is 0.18396490286389588
# testing for offertimes 40, 6th instance
# revenue of assortment [0, 1, 3] is 0.1406423226648538
# revenue of assortment [0, 1, 5] is 0.33891791285539713
# revenue of assortment [0, 1, 6] is 0.14045023406329613
# testing for offertimes 40, 7th instance
# revenue of assortment [0, 3] is 0.0993222154437618
# revenue of assortment [0, 4] is 0.171685550053404
# revenue of assortment [0, 1, 6] is 0.2297864811786609
# testing for offertimes 40, 8th instance
# revenue of assortment [0, 1] is 0.15552759818968842
# revenue of assortment [0, 1, 3] is 0.1947569939781554
# revenue of assortment [0, 8] is 0.3231141340857223
# testing for offertimes 40, 9th instance
# revenue of assortment [0, 3] is 0.10989517392271544
# revenue of assortment [0, 1, 3] is 0.15759303082172882
# revenue of assortment [0, 3, 4] is 0.11567551563593707
# testing for offertimes 40, 10th instance
# revenue of assortment [0, 3] is 0.10263752632851256
# revenue of assortment [0, 1, 4] is 0.26642309354600435
# revenue of assortment [0, 5, 8] is 0.5057873662984744
# testing for offertimes 40, 11th instance
# revenue of assortment [0, 1] is 0.15590276319945168
# revenue of assortment [0, 3] is 0.10346726924742557
# revenue of assortment [0, 5, 8] is 0.5040016198706021
# testing for offertimes 40, 12th instance
# revenue of assortment [0, 1, 5] is 0.3364136962294386
# revenue of assortment [0, 2, 6] is 0.20953785560119245
# revenue of assortment [0, 4, 6] is 0.1435927590038465
# testing for offertimes 40, 13th instance
# revenue of assortment [0, 4] is 0.24956904409081934
# revenue of assortment [0, 5] is 0.17164656461638816
# revenue of assortment [0, 4, 6] is 0.21539336390309505
# testing for offertimes 40, 14th instance
# revenue of assortment [0, 3] is 0.10523330361703064
# revenue of assortment [0, 1, 6] is 0.20639101583809577
# revenue of assortment [0, 5, 6] is 0.15774609501192646
# testing for offertimes 40, 15th instance
# revenue of assortment [0, 6] is 0.09423963926078817
# revenue of assortment [0, 5, 6] is 0.1294717876506839
# revenue of assortment [0, 5, 8] is 0.5094935728503351
# testing for offertimes 40, 16th instance
# revenue of assortment [0, 5] is 0.08086727369835121
# revenue of assortment [0, 1, 6] is 0.19656257262780305
# revenue of assortment [0, 8] is 0.33885880473890173
# testing for offertimes 40, 17th instance
# revenue of assortment [0, 4] is 0.21204573195704607
# revenue of assortment [0, 1, 5] is 0.3481389987720535
# revenue of assortment [0, 5, 6] is 0.20801065431015323
# testing for offertimes 40, 18th instance
# revenue of assortment [0, 5] is 0.17679988912218017
# revenue of assortment [0, 7] is 0.16376154235649973
# revenue of assortment [0, 1, 5] is 0.3204726362733613
# testing for offertimes 40, 19th instance
# revenue of assortment [0, 2] is 0.14819180653130884
# revenue of assortment [0, 5] is 0.23832526072234256
# revenue of assortment [0, 5, 8] is 0.5777762852392091
# testing for offertimes 40, 20th instance
# revenue of assortment [0, 7] is 0.15582278470289607
# revenue of assortment [0, 1, 6] is 0.1979951345318918
# revenue of assortment [0, 5, 8] is 0.5127891405663603
# testing for offertimes 40, 21th instance
# revenue of assortment [0, 6] is 0.10914385414096363
# revenue of assortment [0, 1, 5] is 0.33232833842225973
# revenue of assortment [0, 3, 6] is 0.14271837969002246
# testing for offertimes 40, 22th instance
# revenue of assortment [0, 2] is 0.13237128752683516
# revenue of assortment [0, 6] is 0.10588860304700891
# revenue of assortment [0, 5, 8] is 0.5102281240437349
# testing for offertimes 40, 23th instance
# revenue of assortment [0, 3] is 0.10777370801868452
# revenue of assortment [0, 1, 3] is 0.1325026618555568
# revenue of assortment [0, 1, 4] is 0.2869382107466465
# testing for offertimes 40, 24th instance
# revenue of assortment [0, 1, 4] is 0.2903934748455031
# revenue of assortment [0, 3, 6] is 0.14636985723649007
# revenue of assortment [0, 3, 7] is 0.21663364729957835
# testing for offertimes 40, 25th instance
# revenue of assortment [0, 1] is 0.18234720748445815
# revenue of assortment [0, 1, 6] is 0.2367473122250809
# revenue of assortment [0, 3, 4] is 0.13532172966767866
# testing for offertimes 40, 26th instance
# revenue of assortment [0, 6] is 0.11417715177018697
# revenue of assortment [0, 1, 4] is 0.3009813099974591
# revenue of assortment [0, 4, 6] is 0.15408118749656904
# testing for offertimes 40, 27th instance
# revenue of assortment [0, 1] is 0.16441210303321777
# revenue of assortment [0, 3, 6] is 0.1427437660179808
# revenue of assortment [0, 8] is 0.3208292588926169
# testing for offertimes 40, 28th instance
# revenue of assortment [0, 1, 4] is 0.28583955400532973
# revenue of assortment [0, 3, 4] is 0.1380022456875664
# revenue of assortment [0, 8] is 0.3801304303793783
# testing for offertimes 40, 29th instance
# revenue of assortment [0, 6] is 0.10182396155239622
# revenue of assortment [0, 3, 4] is 0.17434551300328388
# revenue of assortment [0, 8] is 0.3384885816159518
# testing for offertimes 40, 30th instance
# revenue of assortment [0, 3] is 0.10794478553900685
# revenue of assortment [0, 1, 3] is 0.13991820742644784
# revenue of assortment [0, 4, 6] is 0.21530406720088818
# testing for offertimes 40, 31th instance
# revenue of assortment [0, 1] is 0.1864264571083253
# revenue of assortment [0, 6] is 0.08488582325108847
# revenue of assortment [0, 5, 6] is 0.08488584221884421
# testing for offertimes 40, 32th instance
# revenue of assortment [0, 1, 6] is 0.17477646216314568
# revenue of assortment [0, 3, 7] is 0.21754612053378566
# revenue of assortment [0, 5, 6] is 0.17780147265361554
# testing for offertimes 40, 33th instance
# revenue of assortment [0, 1, 3] is 0.16174760475325656
# revenue of assortment [0, 1, 6] is 0.1953243253770621
# revenue of assortment [0, 8] is 0.34534740118117546
# testing for offertimes 40, 34th instance
# revenue of assortment [0, 1, 3] is 0.14014002911713094
# revenue of assortment [0, 4, 6] is 0.1352893757414455
# revenue of assortment [0, 8] is 0.34421977640293355
# testing for offertimes 40, 35th instance
# revenue of assortment [0, 1, 4] is 0.4267890087352866
# revenue of assortment [0, 1, 6] is 0.21093676697829045
# revenue of assortment [0, 3, 6] is 0.13708060588245266
# testing for offertimes 40, 36th instance
# revenue of assortment [0, 2] is 0.15536091903774565
# revenue of assortment [0, 3] is 0.10282148333140768
# revenue of assortment [0, 1, 3] is 0.14617293546578292
# testing for offertimes 40, 37th instance
# revenue of assortment [0, 6] is 0.10188174902370811
# revenue of assortment [0, 2, 6] is 0.19560641534924295
# revenue of assortment [0, 5, 6] is 0.14638347727373324
# testing for offertimes 40, 38th instance
# revenue of assortment [0, 7] is 0.16596672382393057
# revenue of assortment [0, 1, 5] is 0.3187943311593141
# revenue of assortment [0, 5, 6] is 0.19988217125876828
# testing for offertimes 40, 39th instance
# revenue of assortment [0, 1, 5] is 0.32047276609879427
# revenue of assortment [0, 2, 6] is 0.2049265149124489
# revenue of assortment [0, 8] is 0.3166352658247826
# testing for offertimes 40, 40th instance
# revenue of assortment [0, 3] is 0.10663635881976052
# revenue of assortment [0, 6] is 0.10183651916089824
# revenue of assortment [0, 3, 7] is 0.20543271413551753
# testing for offertimes 40, 41th instance
# revenue of assortment [0, 4] is 0.3639340604761318
# revenue of assortment [0, 3, 4] is 0.13467424291010852
# revenue of assortment [0, 5, 6] is 0.12299938622686962
# testing for offertimes 40, 42th instance
# revenue of assortment [0, 5] is 0.18100926942320425
# revenue of assortment [0, 6] is 0.10364251104669407
# revenue of assortment [0, 1, 4] is 0.29843422387870594
# testing for offertimes 40, 43th instance
# revenue of assortment [0, 2] is 0.14618013335820665
# revenue of assortment [0, 7] is 0.1663359441874501
# revenue of assortment [0, 3, 6] is 0.14285788193242746
# testing for offertimes 40, 44th instance
# revenue of assortment [0, 2, 6] is 0.20925102836978718
# revenue of assortment [0, 3, 4] is 0.13583359521596947
# revenue of assortment [0, 4, 6] is 0.1396386277674796
# testing for offertimes 40, 45th instance
# revenue of assortment [0, 6] is 0.09809128917880973
# revenue of assortment [0, 3, 4] is 0.1513415051428183
# revenue of assortment [0, 5, 6] is 0.16603695669286708
# testing for offertimes 40, 46th instance
# revenue of assortment [0, 2] is 0.14934948720719365
# revenue of assortment [0, 5, 6] is 0.1229978204278881
# revenue of assortment [0, 5, 8] is 0.5201184883528182
# testing for offertimes 40, 47th instance
# revenue of assortment [0, 3] is 0.1026375002420946
# revenue of assortment [0, 4] is 0.29486496884204544
# revenue of assortment [0, 1, 4] is 0.31194034598346276
# testing for offertimes 40, 48th instance
# revenue of assortment [0, 3] is 0.10677309344381924
# revenue of assortment [0, 5] is 0.2663892685003663
# revenue of assortment [0, 1, 4] is 0.31934902714245816
# testing for offertimes 40, 49th instance
# revenue of assortment [0, 3] is 0.0991875939166763
# revenue of assortment [0, 1, 3] is 0.15800251782157004
# revenue of assortment [0, 3, 7] is 0.21088037001081406
# testing for offertimes 50, 0th instance
# revenue of assortment [0, 3] is 0.10175251984237939
# revenue of assortment [0, 6] is 0.11204582819873204
# revenue of assortment [0, 1, 3] is 0.15536098164197412
# testing for offertimes 50, 1th instance
# revenue of assortment [0, 3] is 0.10295680728706466
# revenue of assortment [0, 1, 3] is 0.23728212097187162
# revenue of assortment [0, 1, 6] is 0.25209721597636375
# testing for offertimes 50, 2th instance
# revenue of assortment [0, 4] is 0.4270926840505664
# revenue of assortment [0, 5] is 0.1041862455987757
# revenue of assortment [0, 8] is 0.31979406779299
# testing for offertimes 50, 3th instance
# revenue of assortment [0, 1] is 0.2396250715855303
# revenue of assortment [0, 1, 3] is 0.13977758554439393
# revenue of assortment [0, 1, 6] is 0.15555387770034712
# testing for offertimes 50, 4th instance
# revenue of assortment [0, 1] is 0.22345893733879768
# revenue of assortment [0, 1, 6] is 0.18964363865165246
# revenue of assortment [0, 2, 6] is 0.2034923258903145
# testing for offertimes 50, 5th instance
# revenue of assortment [0, 4] is 0.3419056297464035
# revenue of assortment [0, 5] is 0.10048883313944812
# revenue of assortment [0, 5, 8] is 0.5071283084647322
# testing for offertimes 50, 6th instance
# revenue of assortment [0, 3] is 0.08614734756887138
# revenue of assortment [0, 4] is 0.3733780508758742
# revenue of assortment [0, 5] is 0.27894476709197585
# testing for offertimes 50, 7th instance
# revenue of assortment [0, 5] is 0.08588001414055692
# revenue of assortment [0, 1, 6] is 0.23377712178572307
# revenue of assortment [0, 8] is 0.3089661707705592
# testing for offertimes 50, 8th instance
# revenue of assortment [0, 5] is 0.1265756114725356
# revenue of assortment [0, 2, 6] is 0.21225990688946028
# revenue of assortment [0, 5, 6] is 0.2486254981031006
# testing for offertimes 50, 9th instance
# revenue of assortment [0, 1, 3] is 0.16836991966583734
# revenue of assortment [0, 5, 6] is 0.1801482928192386
# revenue of assortment [0, 5, 8] is 0.509169206
# testing for offertimes 50, 10th instance
# revenue of assortment [0, 3] is 0.0999331691511637
# revenue of assortment [0, 1, 4] is 0.4797343538952471
# revenue of assortment [0, 5, 8] is 0.5093405777652256
# testing for offertimes 50, 11th instance
# revenue of assortment [0, 2] is 0.1603123965614289
# revenue of assortment [0, 5, 6] is 0.18501711144086166
# revenue of assortment [0, 5, 8] is 0.5096651010888307
# testing for offertimes 50, 12th instance
# revenue of assortment [0, 4] is 0.34377638469002336
# revenue of assortment [0, 5] is 0.11848464473940297
# revenue of assortment [0, 5, 6] is 0.15447335650832536
# testing for offertimes 50, 13th instance
# revenue of assortment [0, 1] is 0.18760604004597836
# revenue of assortment [0, 2] is 0.14029266364238382
# revenue of assortment [0, 5, 6] is 0.19352949551284343
# testing for offertimes 50, 14th instance
# revenue of assortment [0, 2] is 0.09541552263697224
# revenue of assortment [0, 1, 6] is 0.30862006857937
# revenue of assortment [0, 3, 6] is 0.19874305991533364
# testing for offertimes 50, 15th instance
# revenue of assortment [0, 1] is 0.12960132808064495
# revenue of assortment [0, 5] is 0.19962023067121198
# revenue of assortment [0, 1, 4] is 0.4361214133498589
# testing for offertimes 50, 16th instance
# revenue of assortment [0, 2, 6] is 0.20944538624839393
# revenue of assortment [0, 3, 6] is 0.1482073099625955
# revenue of assortment [0, 5, 6] is 0.20514442425978613
# testing for offertimes 50, 17th instance
# revenue of assortment [0, 6] is 0.12621216474943464
# revenue of assortment [0, 1, 4] is 0.5272048794574378
# revenue of assortment [0, 1, 6] is 0.21053461896996895
# testing for offertimes 50, 18th instance
# revenue of assortment [0, 6] is 0.1192745084470435
# revenue of assortment [0, 1, 4] is 0.5452305392895971
# revenue of assortment [0, 2, 6] is 0.21945524328823277
# testing for offertimes 50, 19th instance
# revenue of assortment [0, 6] is 0.09238344221244311
# revenue of assortment [0, 1, 4] is 0.4953299187817607
# revenue of assortment [0, 5, 6] is 0.19285234196057222
# testing for offertimes 50, 20th instance
# revenue of assortment [0, 1] is 0.1862443913649838
# revenue of assortment [0, 2] is 0.14749213918291376
# revenue of assortment [0, 1, 3] is 0.18832761809914728
# testing for offertimes 50, 21th instance
# revenue of assortment [0, 6] is 0.11936264935431698
# revenue of assortment [0, 1, 3] is 0.35513481774178635
# revenue of assortment [0, 3, 6] is 0.21235289422148151
# testing for offertimes 50, 22th instance
# revenue of assortment [0, 6] is 0.08920133181597033
# revenue of assortment [0, 3, 6] is 0.15069687107486532
# revenue of assortment [0, 5, 6] is 0.1673682021308801
# testing for offertimes 50, 23th instance
# revenue of assortment [0, 1, 3] is 0.3696315157514124
# revenue of assortment [0, 1, 6] is 0.38841615559265746
# revenue of assortment [0, 2, 6] is 0.21308545639322213
# testing for offertimes 50, 24th instance
# revenue of assortment [0, 1] is 0.19876034415840999
# revenue of assortment [0, 5] is 0.17096902872862868
# revenue of assortment [0, 2, 6] is 0.21798976691003644
# testing for offertimes 50, 25th instance
# revenue of assortment [0, 1, 6] is 0.30873309643503577
# revenue of assortment [0, 3, 6] is 0.19891197982715703
# revenue of assortment [0, 5, 8] is 0.515297304522742
# testing for offertimes 50, 26th instance
# revenue of assortment [0, 1, 4] is 0.4955363851973139
# revenue of assortment [0, 3, 6] is 0.14816668696706672
# revenue of assortment [0, 5, 8] is 0.5110379758599897
# testing for offertimes 50, 27th instance
# revenue of assortment [0, 4] is 0.26791385325865064
# revenue of assortment [0, 1, 3] is 0.3393534624532648
# revenue of assortment [0, 1, 6] is 0.3784906007883578
# testing for offertimes 50, 28th instance
# revenue of assortment [0, 3] is 0.09513202181345731
# revenue of assortment [0, 5] is 0.23563868224723455
# revenue of assortment [0, 3, 6] is 0.1198201526580348
# testing for offertimes 50, 29th instance
# revenue of assortment [0, 1] is 0.17363566856637025
# revenue of assortment [0, 1, 4] is 0.43914329344634995
# revenue of assortment [0, 2, 6] is 0.20261089903223023
# testing for offertimes 50, 30th instance
# revenue of assortment [0, 2] is 0.15528605160816544
# revenue of assortment [0, 3, 6] is 0.1481758741821379
# revenue of assortment [0, 8] is 0.317950659874484
# testing for offertimes 50, 31th instance
# revenue of assortment [0, 4] is 0.4119892112126928
# revenue of assortment [0, 1, 3] is 0.36066388387311266
# revenue of assortment [0, 3, 6] is 0.21457090243989765
# testing for offertimes 50, 32th instance
# revenue of assortment [0, 5] is 0.10403679234681118
# revenue of assortment [0, 2, 6] is 0.20497259061592452
# revenue of assortment [0, 8] is 0.3250203871077627
# testing for offertimes 50, 33th instance
# revenue of assortment [0, 3] is 0.10185285500851582
# revenue of assortment [0, 2, 6] is 0.2061619935950111
# revenue of assortment [0, 3, 6] is 0.11342800595549733
# testing for offertimes 50, 34th instance
# revenue of assortment [0, 3] is 0.10601690723643067
# revenue of assortment [0, 5] is 0.10680298410200319
# revenue of assortment [0, 5, 6] is 0.16816630301785934
# testing for offertimes 50, 35th instance
# revenue of assortment [0, 2] is 0.15725171477023148
# revenue of assortment [0, 5, 6] is 0.1674826611254874
# revenue of assortment [0, 8] is 0.319709307240005
# testing for offertimes 50, 36th instance
# revenue of assortment [0, 1] is 0.21246675253490094
# revenue of assortment [0, 6] is 0.13875024686048767
# revenue of assortment [0, 1, 6] is 0.21811030214162702
# testing for offertimes 50, 37th instance
# revenue of assortment [0, 5] is 0.10333286372247241
# revenue of assortment [0, 5, 6] is 0.17393364036666037
# revenue of assortment [0, 8] is 0.3215925832754688
# testing for offertimes 50, 38th instance
# revenue of assortment [0, 3] is 0.10372522234042512
# revenue of assortment [0, 5] is 0.22278823899588285
# revenue of assortment [0, 1, 4] is 0.5198599981213528
# testing for offertimes 50, 39th instance
# revenue of assortment [0, 5] is 0.10237708682525276
# revenue of assortment [0, 1, 3] is 0.16837098544644458
# revenue of assortment [0, 5, 8] is 0.509754211010445
# testing for offertimes 50, 40th instance
# revenue of assortment [0, 3] is 0.10995278543970656
# revenue of assortment [0, 1, 3] is 0.14209474963694882
# revenue of assortment [0, 8] is 0.3175748624941195
# testing for offertimes 50, 41th instance
# revenue of assortment [0, 2] is 0.1481186002975113
# revenue of assortment [0, 1, 4] is 0.5039772156777513
# revenue of assortment [0, 3, 6] is 0.14787836430608753
# testing for offertimes 50, 42th instance
# revenue of assortment [0, 1] is 0.1872238220988475
# revenue of assortment [0, 3] is 0.10991149402860968
# revenue of assortment [0, 1, 3] is 0.15283208614157337
# testing for offertimes 50, 43th instance
# revenue of assortment [0, 3] is 0.09650851586025547
# revenue of assortment [0, 1, 4] is 0.4921724343300904
# revenue of assortment [0, 3, 6] is 0.11221663051161704
# testing for offertimes 50, 44th instance
# revenue of assortment [0, 5] is 0.19790060156631178
# revenue of assortment [0, 2, 6] is 0.20716516493577103
# revenue of assortment [0, 3, 6] is 0.1498910987536261
# testing for offertimes 50, 45th instance
# revenue of assortment [0, 4] is 0.38139668738216903
# revenue of assortment [0, 5] is 0.14065973990581285
# revenue of assortment [0, 1, 6] is 0.2655468954931801
# testing for offertimes 50, 46th instance
# revenue of assortment [0, 5] is 0.1039884789558404
# revenue of assortment [0, 6] is 0.11946751236417212
# revenue of assortment [0, 8] is 0.31740295221892234
# testing for offertimes 50, 47th instance
# revenue of assortment [0, 1, 4] is 0.48156735037941445
# revenue of assortment [0, 2, 6] is 0.20576681713591008
# revenue of assortment [0, 5, 8] is 0.5088522772098052
# testing for offertimes 50, 48th instance
# revenue of assortment [0, 6] is 0.11814503055505224
# revenue of assortment [0, 1, 3] is 0.16940247668981778
# revenue of assortment [0, 1, 4] is 0.5087198696105095
# testing for offertimes 50, 49th instance
# revenue of assortment [0, 1] is 0.15164565399937827
# revenue of assortment [0, 1, 4] is 0.441466518090916
# revenue of assortment [0, 3, 6] is 0.15153386905176475
# testing for offertimes 60, 0th instance
# revenue of assortment [0, 3] is 0.10353419740629555
# revenue of assortment [0, 5] is 0.2769845736309979
# testing for offertimes 60, 1th instance
# revenue of assortment [0, 5, 6] is 0.18322775359716809
# revenue of assortment [0, 5, 8] is 0.5091563928494589
# testing for offertimes 60, 2th instance
# revenue of assortment [0, 2, 6] is 0.2140420677597131
# revenue of assortment [0, 5, 8] is 0.5109390681869014
# testing for offertimes 60, 3th instance
# revenue of assortment [0, 5] is 0.21009762005340807
# revenue of assortment [0, 6] is 0.11946682586500745
# testing for offertimes 60, 4th instance
# revenue of assortment [0, 3, 6] is 0.2153863829593578
# revenue of assortment [0, 5, 8] is 0.5097260219891071
# testing for offertimes 60, 5th instance
# revenue of assortment [0, 3] is 0.10458110350036366
# revenue of assortment [0, 1, 6] is 0.3020021815486434
# testing for offertimes 60, 6th instance
# revenue of assortment [0, 5] is 0.10040496062370811
# revenue of assortment [0, 8] is 0.31603794138266894
# testing for offertimes 60, 7th instance
# revenue of assortment [0, 6] is 0.11936843999740072
# revenue of assortment [0, 3, 6] is 0.2109719661536305
# testing for offertimes 60, 8th instance
# revenue of assortment [0, 5] is 0.25784255953124424
# revenue of assortment [0, 3, 6] is 0.21774332268959487
# testing for offertimes 60, 9th instance
# revenue of assortment [0, 1] is 0.17523090802390087
# revenue of assortment [0, 5, 6] is 0.15197150848462992
# testing for offertimes 60, 10th instance
# revenue of assortment [0, 1, 6] is 0.2964080679811781
# revenue of assortment [0, 3, 6] is 0.21175787565980306
# testing for offertimes 60, 11th instance
# revenue of assortment [0, 3] is 0.10731394637913118
# revenue of assortment [0, 5, 8] is 0.5105802969637355
# testing for offertimes 60, 12th instance
# revenue of assortment [0, 1, 6] is 0.3147236881631029
# revenue of assortment [0, 2, 6] is 0.2172633941262098
# testing for offertimes 60, 13th instance
# revenue of assortment [0, 3] is 0.11083889391848638
# revenue of assortment [0, 8] is 0.3212705297755852
# testing for offertimes 60, 14th instance
# revenue of assortment [0, 1, 6] is 0.32567432415143216
# revenue of assortment [0, 5, 8] is 0.5181688860397387
# testing for offertimes 60, 15th instance
# revenue of assortment [0, 2] is 0.1560663871717188
# revenue of assortment [0, 5] is 0.16258277311324956
# testing for offertimes 60, 16th instance
# revenue of assortment [0, 2] is 0.15698874791584377
# revenue of assortment [0, 1, 6] is 0.3061363559417336
# testing for offertimes 60, 17th instance
# revenue of assortment [0, 1] is 0.16315159191873735
# revenue of assortment [0, 3] is 0.11008107042430075
# testing for offertimes 60, 18th instance
# revenue of assortment [0, 1] is 0.1199830286483221
# revenue of assortment [0, 3, 6] is 0.21491807583904582
# testing for offertimes 60, 19th instance
# revenue of assortment [0, 6] is 0.0889410804789379
# revenue of assortment [0, 5, 6] is 0.18925425117620231
# testing for offertimes 60, 20th instance
# revenue of assortment [0, 2] is 0.160312499988767
# revenue of assortment [0, 3] is 0.11126016259811689
# testing for offertimes 60, 21th instance
# revenue of assortment [0, 5] is 0.1720172228675175
# revenue of assortment [0, 1, 6] is 0.30985380586227795
# testing for offertimes 60, 22th instance
# revenue of assortment [0, 2, 6] is 0.21383349592113696
# revenue of assortment [0, 3, 6] is 0.2186264740389042
# testing for offertimes 60, 23th instance
# revenue of assortment [0, 1] is 0.15083499369061673
# revenue of assortment [0, 2] is 0.15476798836398173
# testing for offertimes 60, 24th instance
# revenue of assortment [0, 1] is 0.1923495771756912
# revenue of assortment [0, 8] is 0.3140806885807663
# testing for offertimes 60, 25th instance
# revenue of assortment [0, 6] is 0.12924225587776633
# revenue of assortment [0, 1, 6] is 0.29820676934934703
# testing for offertimes 60, 26th instance
# revenue of assortment [0, 5, 6] is 0.17647660174061353
# revenue of assortment [0, 8] is 0.31810389578627063
# testing for offertimes 60, 27th instance
# revenue of assortment [0, 3] is 0.10986637647764669
# revenue of assortment [0, 5, 6] is 0.18876789680615785
# testing for offertimes 60, 28th instance
# revenue of assortment [0, 1] is 0.22418998567405202
# revenue of assortment [0, 2, 6] is 0.20382707445347414
# testing for offertimes 60, 29th instance
# revenue of assortment [0, 5] is 0.11983059181261628
# revenue of assortment [0, 5, 6] is 0.1668001785111751
# testing for offertimes 60, 30th instance
# revenue of assortment [0, 3] is 0.10240899801186497
# revenue of assortment [0, 2, 6] is 0.21409503117085374
# testing for offertimes 60, 31th instance
# revenue of assortment [0, 1] is 0.1041129819745176
# revenue of assortment [0, 5] is 0.17096902699324926
# testing for offertimes 60, 32th instance
# revenue of assortment [0, 2] is 0.15697003629876866
# revenue of assortment [0, 8] is 0.3192551822304302
# testing for offertimes 60, 33th instance
# revenue of assortment [0, 1, 6] is 0.31099207932211237
# revenue of assortment [0, 5, 6] is 0.2122642347961332
# testing for offertimes 60, 34th instance
# revenue of assortment [0, 3, 6] is 0.21438545822360558
# revenue of assortment [0, 8] is 0.3171374419267875
# testing for offertimes 60, 35th instance
# revenue of assortment [0, 3] is 0.10596460120448996
# revenue of assortment [0, 6] is 0.10313052825911528
# testing for offertimes 60, 36th instance
# revenue of assortment [0, 2, 6] is 0.20684692440758762
# revenue of assortment [0, 5, 6] is 0.21340106404935782
# testing for offertimes 60, 37th instance
# revenue of assortment [0, 1] is 0.1959435326134736
# revenue of assortment [0, 6] is 0.09123932752221489
# testing for offertimes 60, 38th instance
# revenue of assortment [0, 2] is 0.1584561221583712
# revenue of assortment [0, 5, 8] is 0.5092061470638852
# testing for offertimes 60, 39th instance
# revenue of assortment [0, 5] is 0.09972128058722887
# revenue of assortment [0, 5, 8] is 0.5074880280536448
# testing for offertimes 60, 40th instance
# revenue of assortment [0, 2] is 0.143185563309461
# revenue of assortment [0, 6] is 0.11937061234131255
# testing for offertimes 60, 41th instance
# revenue of assortment [0, 1] is 0.13224635024611497
# revenue of assortment [0, 5, 8] is 0.5181104295805544
# testing for offertimes 60, 42th instance
# revenue of assortment [0, 6] is 0.1194666015562753
# revenue of assortment [0, 8] is 0.3157660523246844
# testing for offertimes 60, 43th instance
# revenue of assortment [0, 2, 6] is 0.20630178158946025
# revenue of assortment [0, 8] is 0.31681450280038287
# testing for offertimes 60, 44th instance
# revenue of assortment [0, 6] is 0.11936510975268123
# revenue of assortment [0, 2, 6] is 0.2085057674477726
# testing for offertimes 60, 45th instance
# revenue of assortment [0, 2] is 0.15152736394492244
# revenue of assortment [0, 3, 6] is 0.21933914548726785
# testing for offertimes 60, 46th instance
# revenue of assortment [0, 6] is 0.11947409073458785
# revenue of assortment [0, 5, 8] is 0.5114426967427786
# testing for offertimes 60, 47th instance
# revenue of assortment [0, 1, 6] is 0.3256746357319674
# revenue of assortment [0, 8] is 0.31418390323987105
# testing for offertimes 60, 48th instance
# revenue of assortment [0, 3, 6] is 0.21645330762035916
# revenue of assortment [0, 5, 6] is 0.1989814938436628
# testing for offertimes 60, 49th instance
# revenue of assortment [0, 5] is 0.19731338356501313
# revenue of assortment [0, 2, 6] is 0.20740434045952483

# %%
## adding details 1
for i in range(len(pred_offer_times_list)):
    df_lcmnl_details1 = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'lcmnl_dist':all_lcmnl_distance_list[i],
                                    'true_best_rev':all_best_true_rev_list[i],'lcmnl_best_rev':all_best_rev_lcmnl_list[i],
                                    'lcmnl_best_rev_diff':all_lcmnl_best_rev_diff[i]})
    df_lcmnl_details1.to_csv('prediction/lcmnl/revenue_prediction/details1/'+str(pred_offer_times_list[i])+'.csv')

# %%
## adding details 2 about ranking, revenue, choice probability
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        
        true_rank = all_true_ranking[i][j]
        lcmnl_rank = all_lcmnl_ranking[i][j]
        df_rank = pd.DataFrame({'true_rank':true_rank,'lcmnl_rank':lcmnl_rank})
        df_rank.to_csv('prediction/lcmnl/revenue_prediction/details2/ranking/offertimes'+str(pred_offer_times_list[i])+'/rank_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        true_rev = all_true_revenue_list[i][j]
        lcmnl_rev = all_lcmnl_revenue_list[i][j]
        df_rev = pd.DataFrame({'true_rev':true_rev,'lcmnl_rev':lcmnl_rev})
        df_rev.to_csv('prediction/lcmnl/revenue_prediction/details2/revenue/offertimes'+str(pred_offer_times_list[i])+'/rev_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
    
        lcmnl_runtime = all_lcmnl_pred_runtime[i][j]
        df_runtime = pd.DataFrame({'lcmnl_runtime':lcmnl_runtime})
        df_runtime.to_csv('prediction/lcmnl/revenue_prediction/details2/runtime/offertimes'+str(pred_offer_times_list[i])+'/runtime_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        
        ## using sales fraction prediction
        ''' ## record the choice probability prediction interval
        true_prob = all_true_prob_list[i][j]
        df_true_prob = pd.DataFrame(true_prob)
        
        lcmnl_sales = all_lcmnl_sales_list[i][j]
        df_lcmnl_sales = pd.DataFrame(lcmnl_sales).T
 
        df_true_prob.to_csv('prediction/lcmnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/true/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')
        df_lcmnl_sales.to_csv('prediction/lcmnl/prob_prediction/offertimes'+str(pred_offer_times_list[i])+'/lcmnl/prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv') '''

# %%
## avg prediction lcmnl runtime 
all_lcmnl_pred_avg_runtime = []

for i in range(len(pred_offer_times_list)):
    avg_lcmnl_pred_runtime_collection = []
    
    for j in range(pred_instance_size[i]): 
        avg_lcmnl_pred_runtime_collection.append(np.mean(np.array(all_lcmnl_pred_runtime[i][j]))) 
        
    all_lcmnl_pred_avg_runtime.append(np.mean(np.array(avg_lcmnl_pred_runtime_collection)))

# %%
avg_lcmnl_dist = []
avg_lcmnl_best_rev_diff = []

for i in range(len(pred_offer_times_list)):
    
    avg_lcmnl_dist.append(np.mean(all_lcmnl_distance_list[i]))
    avg_lcmnl_best_rev_diff.append(np.mean(all_lcmnl_best_rev_diff[i]))
    

df_lcmnl_jd_summary = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'avg_lcmnl_dist':avg_lcmnl_dist,'avg_lcmnl_best_rev_diff':avg_lcmnl_best_rev_diff,
                                   'avg_lcmnl_pred_runtime':all_lcmnl_pred_avg_runtime})
df_lcmnl_jd_summary.to_csv('prediction/lcmnl/jd_lcmnl_summary.csv')

# %%
df_lcmnl_jd_summary
# Out:
#    offertimes  avg_lcmnl_dist  avg_lcmnl_best_rev_diff  avg_lcmnl_pred_runtime
# 0          20            2.68                 0.063396               37.683387
# 1          30            1.60                 0.081198               39.384488
# 2          40            0.84                 0.083484               38.719643
# 3          50            0.76                 0.083165               35.688646
# 4          60            0.40                 0.118200               36.631367
