# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('choices.xlsm')  
offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
#offertimes.to_csv('offertimes.csv')
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
#inc_prod_num.to_csv('inc_prod_num.csv')
choice_prob = raw_jd_choice['clicknum'] / raw_jd_choice.groupby('clickset')['clicknum'].transform('sum')
raw_jd_choice['choice prob'] = choice_prob

assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

# all purchase options in each assortment
purchaseset = raw_jd_choice['purchaseset']
purchaseset_list = []
for pset in purchaseset:
    num_lst = json.loads(pset)
    purchaseset_list.append(num_lst)
raw_jd_choice['purchaseset'] = purchaseset_list

purchasenum_list = raw_jd_choice['clicknum'].tolist()
jd_choice=pd.DataFrame({'clickset':clickset_list,'purchaseset':purchaseset_list,'purchasenum':purchasenum_list,'choice prob':choice_prob})

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
collection = []
for cset in clickset_list:
    if cset not in collection:
        collection.append(cset)
print('there are {} different assortments'.format(len(collection)))

assortment_info_df['assortments'] = collection
choice_collection = np.zeros((n,len(collection)))
global_num = 0
for i in range(len(collection)):
    local_num =0
    while(local_num < inc_prod_num[i]):
        if purchaseset_list[global_num][0] in collection[i]:
            choice_collection[purchaseset_list[global_num][0]][i] = choice_prob[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print('error!')
# Out:
# there are 9 different products
# there are 134 different assortments

# %%
assortment_info_df_15 = assortment_info_df[(assortment_info_df['offer_times']>=15)]
assortments_15 = []
for i in range(len(assortment_info_df_15['assortments'])):
    assortments_15.append(assortment_info_df_15['assortments'][i])


jd_choice_15 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_15:
        jd_choice_15.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_15 = assortment_info_df_15['assortments']
choice_collection_15 = np.zeros((n,len(collection_15)))

frequency_collection_15 = np.zeros((n,len(collection_15)))

purchaseset_list_15 = jd_choice_15['purchaseset'].tolist()

inc_prod_num_15 = assortment_info_df_15['includ_prod_num']
choice_prob_15 = jd_choice_15['choice prob']
frequency_15 = jd_choice_15['purchasenum']

global_num = 0
for i in range(len(collection_15)):
    local_num =0
    while(local_num < inc_prod_num_15[i]):
        if purchaseset_list_15[global_num][0] in assortments_15[i]:
            choice_collection_15[purchaseset_list_15[global_num][0]][i] = choice_prob_15[global_num]
            frequency_collection_15[purchaseset_list_15[global_num][0]][i] = frequency_15[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_15[global_num])
            print(assortments_15[i])
            print('error!')
            break

offer_times_15 = assortment_info_df_15['offer_times'].tolist()
print('the number of assortments with at least 15 purchases is',len(assortments_15))
# Out:
# the number of assortments with at least 15 purchases is 38

# %%
assortment_info_df_20 = assortment_info_df[(assortment_info_df['offer_times']>=20)]
assortments_20 = []
for i in range(len(assortment_info_df_20['assortments'])):
    assortments_20.append(assortment_info_df_20['assortments'][i])


jd_choice_20 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_20:
        jd_choice_20.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_20 = assortment_info_df_20['assortments']
choice_collection_20 = np.zeros((n,len(collection_20)))

frequency_collection_20 = np.zeros((n,len(collection_20)))

purchaseset_list_20 = jd_choice_20['purchaseset'].tolist()

inc_prod_num_20 = assortment_info_df_20['includ_prod_num']
choice_prob_20 = jd_choice_20['choice prob']
frequency_20 = jd_choice_20['purchasenum']

global_num = 0
for i in range(len(collection_20)):
    local_num =0
    while(local_num < inc_prod_num_20[i]):
        if purchaseset_list_20[global_num][0] in assortments_20[i]:
            choice_collection_20[purchaseset_list_20[global_num][0]][i] = choice_prob_20[global_num]
            frequency_collection_20[purchaseset_list_20[global_num][0]][i] = frequency_20[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_20[global_num])
            print(assortments_20[i])
            print('error!')
            break


offer_times_20 = assortment_info_df_20['offer_times'].tolist()
print('the number of assortments with at least 20 purchases is',len(assortments_20))
# Out:
# the number of assortments with at least 20 purchases is 29

# %%
assortment_info_df_30 = assortment_info_df[(assortment_info_df['offer_times']>=30)]
assortments_30 = []
for i in range(len(assortment_info_df_30['assortments'])):
    assortments_30.append(assortment_info_df_30['assortments'][i])


jd_choice_30 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_30:
        jd_choice_30.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_30 = assortment_info_df_30['assortments']
choice_collection_30 = np.zeros((n,len(collection_30)))

frequency_collection_30 = np.zeros((n,len(collection_30)))

purchaseset_list_30 = jd_choice_30['purchaseset'].tolist()

inc_prod_num_30 = assortment_info_df_30['includ_prod_num']
choice_prob_30 = jd_choice_30['choice prob']
frequency_30 = jd_choice_30['purchasenum']

global_num = 0
for i in range(len(collection_30)):
    local_num =0
    while(local_num < inc_prod_num_30[i]):
        if purchaseset_list_30[global_num][0] in assortments_30[i]:
            choice_collection_30[purchaseset_list_30[global_num][0]][i] = choice_prob_30[global_num]
            frequency_collection_30[purchaseset_list_30[global_num][0]][i] = frequency_30[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_30[global_num])
            print(assortments_30[i])
            print('error!')
            break



offer_times_30 = assortment_info_df_30['offer_times'].tolist()
print('the number of assortments with at least 30 purchases is',len(assortments_30))
# Out:
# the number of assortments with at least 30 purchases is 24

# %%
assortment_info_df_40 = assortment_info_df[(assortment_info_df['offer_times']>=40)]
assortments_40 = []
for i in range(len(assortment_info_df_40['assortments'])):
    assortments_40.append(assortment_info_df_40['assortments'][i])


jd_choice_40 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_40:
        jd_choice_40.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_40 = assortment_info_df_40['assortments']
choice_collection_40 = np.zeros((n,len(collection_40)))

frequency_collection_40 = np.zeros((n,len(collection_40)))

purchaseset_list_40 = jd_choice_40['purchaseset'].tolist()

inc_prod_num_40 = assortment_info_df_40['includ_prod_num']
choice_prob_40 = jd_choice_40['choice prob']
frequency_40 = jd_choice_40['purchasenum']

global_num = 0
for i in range(len(collection_40)):
    local_num =0
    while(local_num < inc_prod_num_40[i]):
        if purchaseset_list_40[global_num][0] in assortments_40[i]:
            choice_collection_40[purchaseset_list_40[global_num][0]][i] = choice_prob_40[global_num]
            frequency_collection_40[purchaseset_list_40[global_num][0]][i] = frequency_40[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_40[global_num])
            print(assortments_40[i])
            print('error!')
            break



offer_times_40 = assortment_info_df_40['offer_times'].tolist()
print('the number of assortments with at least 40 purchases is',len(assortments_40))
# Out:
# the number of assortments with at least 40 purchases is 19

# %%
assortment_info_df_50 = assortment_info_df[(assortment_info_df['offer_times']>=50)]
assortments_50 = []
for i in range(len(assortment_info_df_50['assortments'])):
    assortments_50.append(assortment_info_df_50['assortments'][i])


jd_choice_50 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_50:
        jd_choice_50.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_50 = assortment_info_df_50['assortments']
choice_collection_50 = np.zeros((n,len(collection_50)))

frequency_collection_50 = np.zeros((n,len(collection_50)))

purchaseset_list_50 = jd_choice_50['purchaseset'].tolist()

inc_prod_num_50 = assortment_info_df_50['includ_prod_num']
choice_prob_50 = jd_choice_50['choice prob']
frequency_50 = jd_choice_50['purchasenum']

global_num = 0
for i in range(len(collection_50)):
    local_num =0
    while(local_num < inc_prod_num_50[i]):
        if purchaseset_list_50[global_num][0] in assortments_50[i]:
            choice_collection_50[purchaseset_list_50[global_num][0]][i] = choice_prob_50[global_num]
            frequency_collection_50[purchaseset_list_50[global_num][0]][i] = frequency_50[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_50[global_num])
            print(assortments_50[i])
            print('error!')
            break


offer_times_50 = assortment_info_df_50['offer_times'].tolist()
print('the number of assortments with at least 50 purchases is',len(assortments_50))
# Out:
# the number of assortments with at least 50 purchases is 15

# %%
assortment_info_df_60 = assortment_info_df[(assortment_info_df['offer_times']>=60)]
assortments_60 = []
for i in range(len(assortment_info_df_60['assortments'])):
    assortments_60.append(assortment_info_df_60['assortments'][i])


jd_choice_60 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_60:
        jd_choice_60.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_60 = assortment_info_df_60['assortments']
choice_collection_60 = np.zeros((n,len(collection_60)))

frequency_collection_60 = np.zeros((n,len(collection_60)))

purchaseset_list_60 = jd_choice_60['purchaseset'].tolist()

inc_prod_num_60 = assortment_info_df_60['includ_prod_num']
choice_prob_60 = jd_choice_60['choice prob']
frequency_60 = jd_choice_60['purchasenum']

global_num = 0
for i in range(len(collection_60)):
    local_num =0
    while(local_num < inc_prod_num_60[i]):
        if purchaseset_list_60[global_num][0] in assortments_60[i]:
            choice_collection_60[purchaseset_list_60[global_num][0]][i] = choice_prob_60[global_num]
            frequency_collection_60[purchaseset_list_60[global_num][0]][i] = frequency_60[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_60[global_num])
            print(assortments_60[i])
            print('error!')
            break


offer_times_60 = assortment_info_df_60['offer_times'].tolist()
print('the number of assortments with at least 60 purchases is',len(assortments_60))
# Out:
# the number of assortments with at least 60 purchases is 13

# %%
''' def new_data_w_at_least_2_products(n,curr_collection,curr_choice_collection,curr_offertimes):
    
    pre_new_collection = []
    new_collection_indices = []
    new_offertimes = []
    
    for i in range(len(curr_collection)):
        if len(curr_collection[i])>2:
            pre_new_collection.append(curr_collection[i][1:])
            new_collection_indices.append(i)
            new_offertimes.append(curr_offertimes[i])
            
    # Reduce values of all elements by 1
    new_collection = [[element - 1 for element in sublist] for sublist in pre_new_collection]

    new_choice_collection = np.zeros((n-1,len(new_collection_indices)))
    for i in range(len(new_collection_indices)):
        new_choice_collection[:,i] = curr_choice_collection[1:,new_collection_indices[i]]/np.sum(curr_choice_collection[1:,new_collection_indices[i]])
            
    return new_collection,new_choice_collection,new_offertimes '''
# Out:
# ' def new_data_w_at_least_2_products(n,curr_collection,curr_choice_collection,curr_offertimes):\n    \n    pre_new_collection = []\n    new_collection_indices = []\n    new_offertimes = []\n    \n    for i in range(len(curr_collection)):\n        if len(curr_collection[i])>2:\n            pre_new_collection.append(curr_collection[i][1:])\n            new_collection_indices.append(i)\n            new_offertimes.append(curr_offertimes[i])\n            \n    # Reduce values of all elements by 1\n    new_collection = [[element - 1 for element in sublist] for sublist in pre_new_collection]\n\n    new_choice_collection = np.zeros((n-1,len(new_collection_indices)))\n    for i in range(len(new_collection_indices)):\n        new_choice_collection[:,i] = curr_choice_collection[1:,new_collection_indices[i]]/np.sum(curr_choice_collection[1:,new_collection_indices[i]])\n            \n    return new_collection,new_choice_collection,new_offertimes '

# %%
''' new_assortment_15,new_choice_collection_15,new_offer_times_15 = new_data_w_at_least_2_products(n,assortments_15,choice_collection_15,offer_times_15)
print('the new size of the collection with offertimes at least 15 is ',len(new_assortment_15))

new_assortment_20,new_choice_collection_20,new_offer_times_20 = new_data_w_at_least_2_products(n,assortments_20,choice_collection_20,offer_times_20)
print('the new size of the collection with offertimes at least 20 is ',len(new_assortment_20))

new_assortment_30,new_choice_collection_30,new_offer_times_30 = new_data_w_at_least_2_products(n,assortments_30,choice_collection_30,offer_times_30)
print('the new size of the collection with offertimes at least 30 is ',len(new_assortment_30))

new_assortment_40,new_choice_collection_40,new_offer_times_40 = new_data_w_at_least_2_products(n,assortments_40,choice_collection_40,offer_times_40)
print('the new size of the collection with offertimes at least 40 is ',len(new_assortment_40))

new_assortment_50,new_choice_collection_50,new_offer_times_50 = new_data_w_at_least_2_products(n,assortments_50,choice_collection_50,offer_times_50)
print('the new size of the collection with offertimes at least 50 is ',len(new_assortment_50))
 '''
# Out:
# " new_assortment_15,new_choice_collection_15,new_offer_times_15 = new_data_w_at_least_2_products(n,assortments_15,choice_collection_15,offer_times_15)\nprint('the new size of the collection with offertimes at least 15 is ',len(new_assortment_15))\n\nnew_assortment_20,new_choice_collection_20,new_offer_times_20 = new_data_w_at_least_2_products(n,assortments_20,choice_collection_20,offer_times_20)\nprint('the new size of the collection with offertimes at least 20 is ',len(new_assortment_20))\n\nnew_assortment_30,new_choice_collection_30,new_offer_times_30 = new_data_w_at_least_2_products(n,assortments_30,choice_collection_30,offer_times_30)\nprint('the new size of the collection with offertimes at least 30 is ',len(new_assortment_30))\n\nnew_assortment_40,new_choice_collection_40,new_offer_times_40 = new_data_w_at_least_2_products(n,assortments_40,choice_collection_40,offer_times_40)\nprint('the new size of the collection with offertimes at least 40 is ',len(new_assortment_40))\n\nnew_assortment_50,new_choice_collection_50,new_offer_times_50 = new_data_w_at_least_2_products(n,assortments_50,choice_collection_50,offer_times_50)\nprint('the new size of the collection with offertimes at least 50 is ',len(new_assortment_50))\n "

# %%
def collection_distribution_hev(n,collection):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    ''' rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n)) '''
    
    mu = np.random.uniform(-2,2,n)
    scales = np.random.uniform(0.04,2,n)
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_instance_size = [50,50,50,50,50]

all_full_collections = [assortments_20,assortments_30,assortments_40,assortments_50,assortments_60]
all_full_offertimes = [offer_times_20,offer_times_30,offer_times_40,offer_times_50,offer_times_60]
full_collection_size = [len(offer_times_20),len(offer_times_30),len(offer_times_40),len(offer_times_50),len(offer_times_60)]

# %%
# full instance generation 
all_full_instances = []
for i in range(len(pred_offer_times_list)):
    
    full_instances_collection = []
    
    for j in range(pred_instance_size[i]):
        # generate true hev instance
        true_hev_instance = collection_distribution_hev(n,all_full_collections[i])
        full_instances_collection.append(true_hev_instance)

    
    all_full_instances.append(full_instances_collection)

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.opt import SolverFactory

# %%
def expectation_step(v_values,data,collections,L,offer_times):
    
    n,m = data.shape

    # Pyomo model
    model = pyo.ConcreteModel()

    # Variables
    model.w = pyo.Var(range(L), domain=pyo.NonNegativeReals,bounds=(0.001,1))

    # Objective function
    model.obj = pyo.Objective(
        expr=sum(sum(offer_times[i] * data[j, i] * pyo.log(
            sum(model.w[l] * np.exp(v_values[l, j]) / sum(np.exp(v_values[l, k]) for k in collections[i]) for l in range(L))
        ) for j in collections[i]) for i in range(m)),
        sense=pyo.maximize
    )

    # Constraint: Sum of weights equals 1
    model.sum_weights_constraint = pyo.Constraint(expr=sum(model.w[l] for l in range(L)) == 1)

    # Solve the optimization problem
    solver = pyo.SolverFactory('ipopt')
    results = solver.solve(model)
    
    # Print optimization status
    #print("Optimization Status:", results.solver.status)
    if results.solver.status == pyo.SolverStatus.ok:
        #print('Optimal solution found!')
       
        #model.pprint()
    
        w_values = [model.w[l]() for l in range(L)]
        w_values = np.array(w_values)
        
        ''' print("Variable w =", [ model.w[l]() for l in range(L)])
        print("Objective Value =", model.obj()) '''
        
        return w_values,pyo.value(model.obj())
    else:
        print('No solution found or an error occurred.')

# %%
def maximization_step(weights,data,collections,offer_times):
    # Given data
    L = len(weights)
    n,m = data.shape
    
    # Create a ConcreteModel
    model = pyo.ConcreteModel()

    # Define decision variables
    model.v = pyo.Var(range(L), range(n), bounds=(-100, 100))

    # Define the objective function
    model.obj = pyo.Objective(
        expr=sum(sum(data[j][i] * offer_times[i] * pyo.log(sum(weights[l] * pyo.exp(model.v[l, j]) / sum(pyo.exp(model.v[l, k]) for k in collections[i]) for l in range(L))) for j in collections[i]) for i in range(m)),
        sense=pyo.maximize
    )
    model.outsideopt_constraint = pyo.ConstraintList()
    for l in range(L):
        model.outsideopt_constraint.add(model.v[l,0] == 0)

    # Solve the model
    solver = pyo.SolverFactory('ipopt')
    results = solver.solve(model)

    # Print optimization status
    #print("Optimization Status:", results.solver.status)
    if results.solver.status == pyo.SolverStatus.ok:
        #print('Optimal solution found!')
        #model.write('lcmnl2_maximizatioin.mps', io_options={'symbolic_solver_labels': True})
        #model.pprint()
    
        v_values = [[model.v[l, i]() for i in range(n)] for l in range(L)]
        v_values = np.array(v_values)

        # Print variable values and objective value
        ''' print("Variable v =", [[model.v[l, i]() for i in range(n)] for l in range(L)])
        print("Objective Value =", model.obj()) '''
        
        return v_values,model.obj()
    else:
        print('No solution found or an error occurred.')

# %%
# EM algorithm for solving the MLE of LC-MNL
def expectation_maximization(data, collections,offer_times, num_class, max_iterations):
    
    weights = np.ones(num_class)/num_class
    v_values,ll = maximization_step(weights,data,collections,offer_times)
    #print('initial loglikelihood values',ll)
    #print('intitial preference parameters',v_values)

    for i in range(max_iterations):
        curr_ll = ll
        weights,ll = expectation_step(v_values,data,collections,num_class,offer_times)
        #print(f'the loglikelihood after expectation at iteration {i} is {ll}')
        v_values,ll = maximization_step(weights,data,collections,offer_times)
        #print(f'the loglikelihood after maximization at iteration {i} is {ll}')
        
        ''' if ll - curr_ll < 0.001:
            print(f'{ll} at current iteration and {curr_ll} at last iteration  ')
            return weights, v_values,ll '''
        
    return   weights, v_values,ll

# %%
def collection_distribution_lcmnl2(n_num,collection,num_mix,weights,parameters_v):
    
    
    collection_distribution = np.zeros((n_num,len(collection)))
    
    for i in range(len(collection)): 
        curr_total_v = np.zeros(num_mix) # the denominator for each class
        
        for j in range(len(collection[i])): 
            for k in range(num_mix):
                curr_total_v[k] = curr_total_v[k] + math.exp(parameters_v[k][collection[i][j]])
        #print('checking the weights of denominators',curr_total_v)
        
        for j in range(len(collection[i])):
            for k in range(num_mix):
                collection_distribution[collection[i][j]][i] = collection_distribution[collection[i][j]][i] + weights[k]*math.exp(parameters_v[k][collection[i][j]])/curr_total_v[k]
    
    return collection_distribution

# %%
def deterministic_term(data,offertimes):
    dt = 0 
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            if data[i][j] >0:
                dt = dt + offertimes[j]*data[i][j]*np.log(data[i][j])
    return dt,dt/np.sum(offertimes)

# %%
## record the limit loss of all instances
# in average 
all_lcmnl2_limit_loss = []
all_lcmnl2_limit_prob = []
all_lcmnl2_limit_runtime = []

# EM algorithm parameters
max_iterations = 40
num_class = 2

for i in range(len(pred_offer_times_list)):
    

    ## define container for lcmnl2 limit 
    
    lcmnl2_limit_loss_collection =[]
    lcmnl2_limit_runtime_collection =[]
    lcmnl2_limit_probability_collection =[]
    
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
    
        starttime = time.time()
        weights, v_values,ll = expectation_maximization(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i], num_class, max_iterations)
        lcmnl2_runtime = time.time()-starttime
        
        lcmnl2_limit_prob = collection_distribution_lcmnl2(n,all_full_collections[i],num_class,weights,v_values)
        curr_deterministic_term, curr_avg_deterministic_term = deterministic_term(all_full_instances[i][j],all_full_offertimes[i])
        
        lcmnl2_limit_loss_collection.append(-ll/np.sum(all_full_offertimes[i]) + curr_avg_deterministic_term)
        lcmnl2_limit_probability_collection.append(lcmnl2_limit_prob)
        lcmnl2_limit_runtime_collection.append(lcmnl2_runtime)
        
        print('lcmnl2 kl loss is', lcmnl2_limit_loss_collection[-1])
        print('lcmnl2 kl runtime is', lcmnl2_runtime)
    
       
    ## for each train instance [i][j] limit loss result is a number
    all_lcmnl2_limit_loss.append(lcmnl2_limit_loss_collection)
    all_lcmnl2_limit_runtime.append(lcmnl2_limit_runtime_collection)
    ## for each train instance [i][j] limit probability is a matrix
    all_lcmnl2_limit_prob.append(lcmnl2_limit_probability_collection)
# Out:
# testing instance with offertimes 20 : 0th
# lcmnl2 kl loss is 0.0007817124319443591
# lcmnl2 kl runtime is 21.1424880027771
# testing instance with offertimes 20 : 1th
# lcmnl2 kl loss is 0.0004310917703163608
# lcmnl2 kl runtime is 21.086738109588623
# testing instance with offertimes 20 : 2th
# lcmnl2 kl loss is 0.0004250028882741841
# lcmnl2 kl runtime is 20.99343705177307
# testing instance with offertimes 20 : 3th
# lcmnl2 kl loss is 0.00011760946718841758
# lcmnl2 kl runtime is 22.032582998275757
# testing instance with offertimes 20 : 4th
# lcmnl2 kl loss is 0.0023623686743229344
# lcmnl2 kl runtime is 21.066503047943115
# testing instance with offertimes 20 : 5th
# lcmnl2 kl loss is 0.005961018075943625
# lcmnl2 kl runtime is 20.38515305519104
# testing instance with offertimes 20 : 6th
# lcmnl2 kl loss is 0.00035322147141081395
# lcmnl2 kl runtime is 20.945920944213867
# testing instance with offertimes 20 : 7th
# lcmnl2 kl loss is 0.0003237620579361611
# lcmnl2 kl runtime is 20.66809606552124
# testing instance with offertimes 20 : 8th
# lcmnl2 kl loss is 0.0005620134013086808
# lcmnl2 kl runtime is 20.93752121925354
# testing instance with offertimes 20 : 9th
# lcmnl2 kl loss is 0.0019564819097364072
# lcmnl2 kl runtime is 21.144196033477783
# testing instance with offertimes 20 : 10th
# lcmnl2 kl loss is 0.0016709541080266455
# lcmnl2 kl runtime is 21.25255298614502
# testing instance with offertimes 20 : 11th
# lcmnl2 kl loss is 0.0001058168275041016
# lcmnl2 kl runtime is 20.810834884643555
# testing instance with offertimes 20 : 12th
# lcmnl2 kl loss is 0.0010434690795649848
# lcmnl2 kl runtime is 21.23070788383484
# testing instance with offertimes 20 : 13th
# lcmnl2 kl loss is 0.00022457467101477668
# lcmnl2 kl runtime is 21.32326889038086
# testing instance with offertimes 20 : 14th
# lcmnl2 kl loss is 0.000731318923136659
# lcmnl2 kl runtime is 21.337336778640747
# testing instance with offertimes 20 : 15th
# lcmnl2 kl loss is 0.0005378785594821744
# lcmnl2 kl runtime is 21.168204069137573
# testing instance with offertimes 20 : 16th
# lcmnl2 kl loss is 0.001782830302830607
# lcmnl2 kl runtime is 21.164806127548218
# testing instance with offertimes 20 : 17th
# lcmnl2 kl loss is 0.0006149902527403661
# lcmnl2 kl runtime is 19.861046075820923
# testing instance with offertimes 20 : 18th
# lcmnl2 kl loss is 0.0005534341121880004
# lcmnl2 kl runtime is 18.872084140777588
# testing instance with offertimes 20 : 19th
# lcmnl2 kl loss is 5.2008439208106605e-05
# lcmnl2 kl runtime is 18.746227979660034
# testing instance with offertimes 20 : 20th
# lcmnl2 kl loss is 0.003725973247525105
# lcmnl2 kl runtime is 18.585501194000244
# testing instance with offertimes 20 : 21th
# lcmnl2 kl loss is 0.004089802515146901
# lcmnl2 kl runtime is 18.48610210418701
# testing instance with offertimes 20 : 22th
# lcmnl2 kl loss is 0.0021967903937524236
# lcmnl2 kl runtime is 18.89777708053589
# testing instance with offertimes 20 : 23th
# lcmnl2 kl loss is 0.00033069816975073163
# lcmnl2 kl runtime is 18.685518980026245
# testing instance with offertimes 20 : 24th
# lcmnl2 kl loss is 0.0014575091924767802
# lcmnl2 kl runtime is 18.623701095581055
# testing instance with offertimes 20 : 25th
# lcmnl2 kl loss is 0.0007352481975172465
# lcmnl2 kl runtime is 18.684413194656372
# testing instance with offertimes 20 : 26th
# lcmnl2 kl loss is 0.0016648386179844987
# lcmnl2 kl runtime is 18.143890857696533
# testing instance with offertimes 20 : 27th
# lcmnl2 kl loss is 0.001037371239059337
# lcmnl2 kl runtime is 18.85355520248413
# testing instance with offertimes 20 : 28th
# lcmnl2 kl loss is 0.0008737238171575568
# lcmnl2 kl runtime is 18.070513010025024
# testing instance with offertimes 20 : 29th
# lcmnl2 kl loss is 0.00264877067164504
# lcmnl2 kl runtime is 18.655504941940308
# testing instance with offertimes 20 : 30th
# lcmnl2 kl loss is 1.5990226818418662e-05
# lcmnl2 kl runtime is 19.37754797935486
# testing instance with offertimes 20 : 31th
# lcmnl2 kl loss is 0.000506769644321281
# lcmnl2 kl runtime is 18.413801193237305
# testing instance with offertimes 20 : 32th
# lcmnl2 kl loss is 0.0015943129368615194
# lcmnl2 kl runtime is 17.827894926071167
# testing instance with offertimes 20 : 33th
# lcmnl2 kl loss is 0.002399083918514955
# lcmnl2 kl runtime is 18.22289204597473
# testing instance with offertimes 20 : 34th
# lcmnl2 kl loss is 0.001380469653616545
# lcmnl2 kl runtime is 18.917919874191284
# testing instance with offertimes 20 : 35th
# lcmnl2 kl loss is 0.0060708529125477195
# lcmnl2 kl runtime is 18.243682146072388
# testing instance with offertimes 20 : 36th
# lcmnl2 kl loss is 0.001241741093948312
# lcmnl2 kl runtime is 18.736923217773438
# testing instance with offertimes 20 : 37th
# lcmnl2 kl loss is 0.001887502366597682
# lcmnl2 kl runtime is 18.382422924041748
# testing instance with offertimes 20 : 38th
# lcmnl2 kl loss is 0.0060107942801884695
# lcmnl2 kl runtime is 18.709940195083618
# testing instance with offertimes 20 : 39th
# lcmnl2 kl loss is 0.0003281053292594205
# lcmnl2 kl runtime is 18.35568904876709
# testing instance with offertimes 20 : 40th
# lcmnl2 kl loss is 0.0003518777291798836
# lcmnl2 kl runtime is 17.92268991470337
# testing instance with offertimes 20 : 41th
# lcmnl2 kl loss is 3.5724038818685244e-05
# lcmnl2 kl runtime is 19.890940189361572
# testing instance with offertimes 20 : 42th
# lcmnl2 kl loss is 0.0023094709178288486
# lcmnl2 kl runtime is 18.919512033462524
# testing instance with offertimes 20 : 43th
# lcmnl2 kl loss is 0.001374460582995507
# lcmnl2 kl runtime is 18.557535886764526
# testing instance with offertimes 20 : 44th
# lcmnl2 kl loss is 0.000662939504876614
# lcmnl2 kl runtime is 18.616066217422485
# testing instance with offertimes 20 : 45th
# lcmnl2 kl loss is 0.005253334835929269
# lcmnl2 kl runtime is 18.002861976623535
# testing instance with offertimes 20 : 46th
# lcmnl2 kl loss is 0.000635679229588737
# lcmnl2 kl runtime is 18.161645650863647
# testing instance with offertimes 20 : 47th
# lcmnl2 kl loss is 0.001036050243937492
# lcmnl2 kl runtime is 18.965571880340576
# testing instance with offertimes 20 : 48th
# lcmnl2 kl loss is 0.0036486379095661547
# lcmnl2 kl runtime is 18.685722827911377
# testing instance with offertimes 20 : 49th
# lcmnl2 kl loss is 0.0016956852940577805
# lcmnl2 kl runtime is 18.414289236068726
# testing instance with offertimes 30 : 0th
# lcmnl2 kl loss is 0.0005115537209051668
# lcmnl2 kl runtime is 19.579643964767456
# testing instance with offertimes 30 : 1th
# lcmnl2 kl loss is 0.0006950432547354612
# lcmnl2 kl runtime is 18.312288999557495
# testing instance with offertimes 30 : 2th
# lcmnl2 kl loss is 0.00018347055496792386
# lcmnl2 kl runtime is 17.632307052612305
# testing instance with offertimes 30 : 3th
# lcmnl2 kl loss is 0.0005761223467705134
# lcmnl2 kl runtime is 18.894103050231934
# testing instance with offertimes 30 : 4th
# lcmnl2 kl loss is 7.118901491393048e-05
# lcmnl2 kl runtime is 18.194923162460327
# testing instance with offertimes 30 : 5th
# lcmnl2 kl loss is 0.00022505318443188926
# lcmnl2 kl runtime is 18.363615036010742
# testing instance with offertimes 30 : 6th
# lcmnl2 kl loss is 0.00047625928965833175
# lcmnl2 kl runtime is 18.8125479221344
# testing instance with offertimes 30 : 7th
# lcmnl2 kl loss is 0.004056717076369315
# lcmnl2 kl runtime is 18.55669617652893
# testing instance with offertimes 30 : 8th
# lcmnl2 kl loss is 0.00024958635908878257
# lcmnl2 kl runtime is 18.382263660430908
# testing instance with offertimes 30 : 9th
# lcmnl2 kl loss is 0.002199878952748313
# lcmnl2 kl runtime is 18.75366520881653
# testing instance with offertimes 30 : 10th
# lcmnl2 kl loss is 0.0014262057120718596
# lcmnl2 kl runtime is 17.796876192092896
# testing instance with offertimes 30 : 11th
# lcmnl2 kl loss is 0.00014744964176383046
# lcmnl2 kl runtime is 18.968036890029907
# testing instance with offertimes 30 : 12th
# lcmnl2 kl loss is 0.00013070627496680753
# lcmnl2 kl runtime is 20.515187978744507
# testing instance with offertimes 30 : 13th
# lcmnl2 kl loss is 0.0008314879014051924
# lcmnl2 kl runtime is 18.187776803970337
# testing instance with offertimes 30 : 14th
# lcmnl2 kl loss is 1.1570122061321797e-05
# lcmnl2 kl runtime is 18.699530124664307
# testing instance with offertimes 30 : 15th
# lcmnl2 kl loss is 0.00019584715174369993
# lcmnl2 kl runtime is 18.975195169448853
# testing instance with offertimes 30 : 16th
# lcmnl2 kl loss is 6.504404606200165e-06
# lcmnl2 kl runtime is 19.73138976097107
# testing instance with offertimes 30 : 17th
# lcmnl2 kl loss is 0.0011525877794821282
# lcmnl2 kl runtime is 17.63263201713562
# testing instance with offertimes 30 : 18th
# lcmnl2 kl loss is 4.0022467198697065e-05
# lcmnl2 kl runtime is 19.291243076324463
# testing instance with offertimes 30 : 19th
# lcmnl2 kl loss is 0.00048271213674300206
# lcmnl2 kl runtime is 18.339229822158813
# testing instance with offertimes 30 : 20th
# lcmnl2 kl loss is 0.0003638414834106207
# lcmnl2 kl runtime is 17.92368793487549
# testing instance with offertimes 30 : 21th
# lcmnl2 kl loss is 3.6621444328144293e-06
# lcmnl2 kl runtime is 20.15179419517517
# testing instance with offertimes 30 : 22th
# lcmnl2 kl loss is 0.0004275446157752105
# lcmnl2 kl runtime is 18.623514890670776
# testing instance with offertimes 30 : 23th
# lcmnl2 kl loss is 0.0004464650333712017
# lcmnl2 kl runtime is 18.15738797187805
# testing instance with offertimes 30 : 24th
# lcmnl2 kl loss is 0.00064066568490595
# lcmnl2 kl runtime is 18.51306390762329
# testing instance with offertimes 30 : 25th
# lcmnl2 kl loss is 0.0006023906148640013
# lcmnl2 kl runtime is 18.227152109146118
# testing instance with offertimes 30 : 26th
# lcmnl2 kl loss is 0.000999067897819006
# lcmnl2 kl runtime is 18.410766124725342
# testing instance with offertimes 30 : 27th
# lcmnl2 kl loss is 0.00048378215793887236
# lcmnl2 kl runtime is 17.618201971054077
# testing instance with offertimes 30 : 28th
# lcmnl2 kl loss is 0.0012698316666761578
# lcmnl2 kl runtime is 17.621917963027954
# testing instance with offertimes 30 : 29th
# lcmnl2 kl loss is 0.0006289601682923918
# lcmnl2 kl runtime is 18.132015705108643
# testing instance with offertimes 30 : 30th
# lcmnl2 kl loss is 9.67648160465906e-05
# lcmnl2 kl runtime is 18.24752902984619
# testing instance with offertimes 30 : 31th
# lcmnl2 kl loss is 0.00025753837390252166
# lcmnl2 kl runtime is 18.135270833969116
# testing instance with offertimes 30 : 32th
# lcmnl2 kl loss is 0.000575907744090276
# lcmnl2 kl runtime is 18.67876887321472
# testing instance with offertimes 30 : 33th
# lcmnl2 kl loss is 0.0002467271887894862
# lcmnl2 kl runtime is 19.1233971118927
# testing instance with offertimes 30 : 34th
# lcmnl2 kl loss is 4.744803849288104e-05
# lcmnl2 kl runtime is 19.00031590461731
# testing instance with offertimes 30 : 35th
# lcmnl2 kl loss is 3.878899868109409e-05
# lcmnl2 kl runtime is 19.779330015182495
# testing instance with offertimes 30 : 36th
# lcmnl2 kl loss is 0.0028275396268157005
# lcmnl2 kl runtime is 19.390012979507446
# testing instance with offertimes 30 : 37th
# lcmnl2 kl loss is 0.00045400116338634167
# lcmnl2 kl runtime is 20.001760959625244
# testing instance with offertimes 30 : 38th
# lcmnl2 kl loss is 0.0005946380216403369
# lcmnl2 kl runtime is 20.069071054458618
# testing instance with offertimes 30 : 39th
# lcmnl2 kl loss is 0.0005779341880701727
# lcmnl2 kl runtime is 19.397872924804688
# testing instance with offertimes 30 : 40th
# lcmnl2 kl loss is 0.0003818271379465443
# lcmnl2 kl runtime is 19.85778307914734
# testing instance with offertimes 30 : 41th
# lcmnl2 kl loss is 0.0003631934164012307
# lcmnl2 kl runtime is 18.923855781555176
# testing instance with offertimes 30 : 42th
# lcmnl2 kl loss is 0.0004469732820314709
# lcmnl2 kl runtime is 19.382230043411255
# testing instance with offertimes 30 : 43th
# lcmnl2 kl loss is 0.0005001141043401436
# lcmnl2 kl runtime is 19.56450366973877
# testing instance with offertimes 30 : 44th
# lcmnl2 kl loss is 7.904149637705249e-05
# lcmnl2 kl runtime is 17.78210186958313
# testing instance with offertimes 30 : 45th
# lcmnl2 kl loss is 0.0006032471803220085
# lcmnl2 kl runtime is 18.419291973114014
# testing instance with offertimes 30 : 46th
# lcmnl2 kl loss is 0.0006977341730377562
# lcmnl2 kl runtime is 18.612541913986206
# testing instance with offertimes 30 : 47th
# lcmnl2 kl loss is 0.00039767945970758944
# lcmnl2 kl runtime is 19.027531147003174
# testing instance with offertimes 30 : 48th
# lcmnl2 kl loss is 0.0010053004169037205
# lcmnl2 kl runtime is 18.59847402572632
# testing instance with offertimes 30 : 49th
# lcmnl2 kl loss is 0.0003179793802837172
# lcmnl2 kl runtime is 18.03274917602539
# testing instance with offertimes 40 : 0th
# lcmnl2 kl loss is 0.0002200670969970675
# lcmnl2 kl runtime is 18.59465003013611
# testing instance with offertimes 40 : 1th
# lcmnl2 kl loss is 1.2272283813674623e-05
# lcmnl2 kl runtime is 18.6134352684021
# testing instance with offertimes 40 : 2th
# lcmnl2 kl loss is 0.00021570239557189286
# lcmnl2 kl runtime is 17.50294303894043
# testing instance with offertimes 40 : 3th
# lcmnl2 kl loss is 0.0002732417880977889
# lcmnl2 kl runtime is 18.302940845489502
# testing instance with offertimes 40 : 4th
# lcmnl2 kl loss is 0.002495542543634599
# lcmnl2 kl runtime is 18.322337865829468
# testing instance with offertimes 40 : 5th
# lcmnl2 kl loss is 0.00040282147977044325
# lcmnl2 kl runtime is 17.298925161361694
# testing instance with offertimes 40 : 6th
# lcmnl2 kl loss is 0.0025422001989194865
# lcmnl2 kl runtime is 17.593634843826294
# testing instance with offertimes 40 : 7th
# lcmnl2 kl loss is 9.110256689870422e-07
# lcmnl2 kl runtime is 21.44362235069275
# testing instance with offertimes 40 : 8th
# lcmnl2 kl loss is 0.00025007521056863435
# lcmnl2 kl runtime is 18.861374139785767
# testing instance with offertimes 40 : 9th
# lcmnl2 kl loss is 0.0001098258792785467
# lcmnl2 kl runtime is 18.03970503807068
# testing instance with offertimes 40 : 10th
# lcmnl2 kl loss is 0.00017438554616455715
# lcmnl2 kl runtime is 18.55430507659912
# testing instance with offertimes 40 : 11th
# lcmnl2 kl loss is 4.740139786230113e-05
# lcmnl2 kl runtime is 17.962167024612427
# testing instance with offertimes 40 : 12th
# lcmnl2 kl loss is 0.0001642105025292384
# lcmnl2 kl runtime is 18.243227005004883
# testing instance with offertimes 40 : 13th
# lcmnl2 kl loss is 2.17218631330951e-05
# lcmnl2 kl runtime is 17.9846670627594
# testing instance with offertimes 40 : 14th
# lcmnl2 kl loss is 0.0003514958096219045
# lcmnl2 kl runtime is 17.78383207321167
# testing instance with offertimes 40 : 15th
# lcmnl2 kl loss is 0.0014276271652927663
# lcmnl2 kl runtime is 18.80573010444641
# testing instance with offertimes 40 : 16th
# lcmnl2 kl loss is 0.0001484856936674328
# lcmnl2 kl runtime is 17.594522714614868
# testing instance with offertimes 40 : 17th
# lcmnl2 kl loss is 0.0015786250106534228
# lcmnl2 kl runtime is 18.47860598564148
# testing instance with offertimes 40 : 18th
# lcmnl2 kl loss is 0.0011452746025929494
# lcmnl2 kl runtime is 17.946765184402466
# testing instance with offertimes 40 : 19th
# lcmnl2 kl loss is 0.0006775629041478326
# lcmnl2 kl runtime is 18.652924060821533
# testing instance with offertimes 40 : 20th
# lcmnl2 kl loss is 0.00020506101014894362
# lcmnl2 kl runtime is 18.942685842514038
# testing instance with offertimes 40 : 21th
# lcmnl2 kl loss is 0.001474634428693694
# lcmnl2 kl runtime is 18.507728815078735
# testing instance with offertimes 40 : 22th
# lcmnl2 kl loss is 0.007141294911248763
# lcmnl2 kl runtime is 18.169804096221924
# testing instance with offertimes 40 : 23th
# lcmnl2 kl loss is 0.0004843651958201245
# lcmnl2 kl runtime is 19.18630576133728
# testing instance with offertimes 40 : 24th
# lcmnl2 kl loss is 0.0011705125512134207
# lcmnl2 kl runtime is 18.61852788925171
# testing instance with offertimes 40 : 25th
# lcmnl2 kl loss is 0.0007105414872350391
# lcmnl2 kl runtime is 17.368359327316284
# testing instance with offertimes 40 : 26th
# lcmnl2 kl loss is 0.002537341202738519
# lcmnl2 kl runtime is 17.756700038909912
# testing instance with offertimes 40 : 27th
# lcmnl2 kl loss is 0.000427139369769014
# lcmnl2 kl runtime is 18.469187259674072
# testing instance with offertimes 40 : 28th
# lcmnl2 kl loss is 0.0011183358550196365
# lcmnl2 kl runtime is 17.623559951782227
# testing instance with offertimes 40 : 29th
# lcmnl2 kl loss is 0.00023553723395663972
# lcmnl2 kl runtime is 18.005836248397827
# testing instance with offertimes 40 : 30th
# lcmnl2 kl loss is 0.001131697241212204
# lcmnl2 kl runtime is 18.7377872467041
# testing instance with offertimes 40 : 31th
# lcmnl2 kl loss is 0.0024389714264932416
# lcmnl2 kl runtime is 18.292131185531616
# testing instance with offertimes 40 : 32th
# lcmnl2 kl loss is 0.00011239969100695912
# lcmnl2 kl runtime is 18.61284112930298
# testing instance with offertimes 40 : 33th
# lcmnl2 kl loss is 0.0014315616578048918
# lcmnl2 kl runtime is 18.226981163024902
# testing instance with offertimes 40 : 34th
# lcmnl2 kl loss is 0.0006350412242470682
# lcmnl2 kl runtime is 18.31840205192566
# testing instance with offertimes 40 : 35th
# lcmnl2 kl loss is 4.451717607406591e-05
# lcmnl2 kl runtime is 20.869420766830444
# testing instance with offertimes 40 : 36th
# lcmnl2 kl loss is 0.00017300836631983785
# lcmnl2 kl runtime is 22.183258295059204
# testing instance with offertimes 40 : 37th
# lcmnl2 kl loss is 0.00017688954230421494
# lcmnl2 kl runtime is 21.90084481239319
# testing instance with offertimes 40 : 38th
# lcmnl2 kl loss is 0.00033664748895262386
# lcmnl2 kl runtime is 22.553670167922974
# testing instance with offertimes 40 : 39th
# lcmnl2 kl loss is 0.0006621799932679528
# lcmnl2 kl runtime is 24.32473921775818
# testing instance with offertimes 40 : 40th
# lcmnl2 kl loss is 0.0005077332138682111
# lcmnl2 kl runtime is 25.95674204826355
# testing instance with offertimes 40 : 41th
# lcmnl2 kl loss is 0.0002458458529768226
# lcmnl2 kl runtime is 26.198721885681152
# testing instance with offertimes 40 : 42th
# lcmnl2 kl loss is 0.00040853885976799287
# lcmnl2 kl runtime is 24.097820281982422
# testing instance with offertimes 40 : 43th
# lcmnl2 kl loss is 2.370070861901219e-06
# lcmnl2 kl runtime is 27.685847997665405
# testing instance with offertimes 40 : 44th
# lcmnl2 kl loss is 0.00026922203441792636
# lcmnl2 kl runtime is 23.299192667007446
# testing instance with offertimes 40 : 45th
# lcmnl2 kl loss is 2.4038915560131713e-05
# lcmnl2 kl runtime is 20.943411350250244
# testing instance with offertimes 40 : 46th
# lcmnl2 kl loss is 0.0003332959223241172
# lcmnl2 kl runtime is 24.07683491706848
# testing instance with offertimes 40 : 47th
# lcmnl2 kl loss is 0.0008581784868735287
# lcmnl2 kl runtime is 22.716636896133423
# testing instance with offertimes 40 : 48th
# lcmnl2 kl loss is 0.00030999690620725495
# lcmnl2 kl runtime is 22.256568908691406
# testing instance with offertimes 40 : 49th
# lcmnl2 kl loss is 0.0006789090548059429
# lcmnl2 kl runtime is 20.267024993896484
# testing instance with offertimes 50 : 0th
# lcmnl2 kl loss is 0.00036639230356461105
# lcmnl2 kl runtime is 23.460604906082153
# testing instance with offertimes 50 : 1th
# lcmnl2 kl loss is 0.0005377177978498349
# lcmnl2 kl runtime is 21.619317054748535
# testing instance with offertimes 50 : 2th
# lcmnl2 kl loss is 5.9250575033642505e-05
# lcmnl2 kl runtime is 25.082924842834473
# testing instance with offertimes 50 : 3th
# lcmnl2 kl loss is 0.001262736600825931
# lcmnl2 kl runtime is 23.54425024986267
# testing instance with offertimes 50 : 4th
# lcmnl2 kl loss is 0.0025428687530771876
# lcmnl2 kl runtime is 23.260250091552734
# testing instance with offertimes 50 : 5th
# lcmnl2 kl loss is 0.0008122172408993045
# lcmnl2 kl runtime is 23.58957314491272
# testing instance with offertimes 50 : 6th
# lcmnl2 kl loss is 0.0002409151771406437
# lcmnl2 kl runtime is 22.646605014801025
# testing instance with offertimes 50 : 7th
# lcmnl2 kl loss is 0.0003673767949072815
# lcmnl2 kl runtime is 23.939945936203003
# testing instance with offertimes 50 : 8th
# lcmnl2 kl loss is 0.0005521177718665893
# lcmnl2 kl runtime is 24.010509729385376
# testing instance with offertimes 50 : 9th
# lcmnl2 kl loss is 0.00027085796212311664
# lcmnl2 kl runtime is 29.829713821411133
# testing instance with offertimes 50 : 10th
# lcmnl2 kl loss is 0.00013628170719082178
# lcmnl2 kl runtime is 28.705026149749756
# testing instance with offertimes 50 : 11th
# lcmnl2 kl loss is 0.0002984660597515898
# lcmnl2 kl runtime is 33.710694789886475
# testing instance with offertimes 50 : 12th
# lcmnl2 kl loss is 0.00020347700668588153
# lcmnl2 kl runtime is 34.051143169403076
# testing instance with offertimes 50 : 13th
# lcmnl2 kl loss is 0.0003575491424548938
# lcmnl2 kl runtime is 34.45184516906738
# testing instance with offertimes 50 : 14th
# lcmnl2 kl loss is 0.0003201036511322197
# lcmnl2 kl runtime is 31.798521995544434
# testing instance with offertimes 50 : 15th
# lcmnl2 kl loss is 5.826091482141749e-06
# lcmnl2 kl runtime is 34.875463247299194
# testing instance with offertimes 50 : 16th
# lcmnl2 kl loss is 5.9013923525474965e-05
# lcmnl2 kl runtime is 30.59237504005432
# testing instance with offertimes 50 : 17th
# lcmnl2 kl loss is 8.774869677430353e-06
# lcmnl2 kl runtime is 20.36774778366089
# testing instance with offertimes 50 : 18th
# lcmnl2 kl loss is 0.0003704563586904852
# lcmnl2 kl runtime is 20.69234585762024
# testing instance with offertimes 50 : 19th
# lcmnl2 kl loss is 1.3200788260170349e-05
# lcmnl2 kl runtime is 22.425798177719116
# testing instance with offertimes 50 : 20th
# lcmnl2 kl loss is 0.00015282851360226557
# lcmnl2 kl runtime is 23.280661821365356
# testing instance with offertimes 50 : 21th
# lcmnl2 kl loss is 0.0009628099728416634
# lcmnl2 kl runtime is 24.68525218963623
# testing instance with offertimes 50 : 22th
# lcmnl2 kl loss is 0.000253527862821068
# lcmnl2 kl runtime is 24.471031665802002
# testing instance with offertimes 50 : 23th
# lcmnl2 kl loss is 1.6447330493662982e-06
# lcmnl2 kl runtime is 22.59156823158264
# testing instance with offertimes 50 : 24th
# lcmnl2 kl loss is 0.00020880235984099826
# lcmnl2 kl runtime is 26.473999977111816
# testing instance with offertimes 50 : 25th
# lcmnl2 kl loss is 0.0011422537749030681
# lcmnl2 kl runtime is 28.340917825698853
# testing instance with offertimes 50 : 26th
# lcmnl2 kl loss is 2.109256324922537e-05
# lcmnl2 kl runtime is 31.46532392501831
# testing instance with offertimes 50 : 27th
# lcmnl2 kl loss is 0.00015625089936754932
# lcmnl2 kl runtime is 37.03552484512329
# testing instance with offertimes 50 : 28th
# lcmnl2 kl loss is 0.00010343253861522239
# lcmnl2 kl runtime is 36.85790991783142
# testing instance with offertimes 50 : 29th
# lcmnl2 kl loss is 0.00034930130401067405
# lcmnl2 kl runtime is 34.310091972351074
# testing instance with offertimes 50 : 30th
# lcmnl2 kl loss is 0.0001787317261467969
# lcmnl2 kl runtime is 34.84195804595947
# testing instance with offertimes 50 : 31th
# lcmnl2 kl loss is 0.00028105593420535424
# lcmnl2 kl runtime is 38.38567590713501
# testing instance with offertimes 50 : 32th
# lcmnl2 kl loss is 5.7078270028543265e-05
# lcmnl2 kl runtime is 42.91500639915466
# testing instance with offertimes 50 : 33th
# lcmnl2 kl loss is 2.1479921464950813e-05
# lcmnl2 kl runtime is 35.11294102668762
# testing instance with offertimes 50 : 34th
# lcmnl2 kl loss is 7.289431103563171e-05
# lcmnl2 kl runtime is 31.962494134902954
# testing instance with offertimes 50 : 35th
# lcmnl2 kl loss is 0.0005005935436720454
# lcmnl2 kl runtime is 32.49618601799011
# testing instance with offertimes 50 : 36th
# lcmnl2 kl loss is 0.0003847594918108266
# lcmnl2 kl runtime is 32.9786741733551
# testing instance with offertimes 50 : 37th
# lcmnl2 kl loss is 0.00021229292737923178
# lcmnl2 kl runtime is 29.832513093948364
# testing instance with offertimes 50 : 38th
# lcmnl2 kl loss is 0.0016006015280277675
# lcmnl2 kl runtime is 32.31639909744263
# testing instance with offertimes 50 : 39th
# lcmnl2 kl loss is 0.000674900011771562
# lcmnl2 kl runtime is 36.94501614570618
# testing instance with offertimes 50 : 40th
# lcmnl2 kl loss is 0.0001957932934132378
# lcmnl2 kl runtime is 33.64111399650574
# testing instance with offertimes 50 : 41th
# lcmnl2 kl loss is 0.0001840041431124817
# lcmnl2 kl runtime is 33.94660687446594
# testing instance with offertimes 50 : 42th
# lcmnl2 kl loss is 0.0002715317987393995
# lcmnl2 kl runtime is 34.04073119163513
# testing instance with offertimes 50 : 43th
# lcmnl2 kl loss is 0.002798245658740761
# lcmnl2 kl runtime is 34.859883069992065
# testing instance with offertimes 50 : 44th
# lcmnl2 kl loss is 0.0009402979799341127
# lcmnl2 kl runtime is 33.622074127197266
# testing instance with offertimes 50 : 45th
# lcmnl2 kl loss is 0.00021211853982661122
# lcmnl2 kl runtime is 32.026546001434326
# testing instance with offertimes 50 : 46th
# lcmnl2 kl loss is 2.3748377309118496e-05
# lcmnl2 kl runtime is 35.70829200744629
# testing instance with offertimes 50 : 47th
# lcmnl2 kl loss is 4.0717234450926565e-05
# lcmnl2 kl runtime is 34.425135135650635
# testing instance with offertimes 50 : 48th
# lcmnl2 kl loss is 0.00011973769792028577
# lcmnl2 kl runtime is 35.491222858428955
# testing instance with offertimes 50 : 49th
# lcmnl2 kl loss is 1.7188710651871997e-05
# lcmnl2 kl runtime is 40.864426374435425
# testing instance with offertimes 60 : 0th
# lcmnl2 kl loss is 0.00032399587854492484
# lcmnl2 kl runtime is 36.27233386039734
# testing instance with offertimes 60 : 1th
# lcmnl2 kl loss is 0.00021596557023884078
# lcmnl2 kl runtime is 35.46670389175415
# testing instance with offertimes 60 : 2th
# lcmnl2 kl loss is 0.0003368499433653027
# lcmnl2 kl runtime is 34.12318396568298
# testing instance with offertimes 60 : 3th
# lcmnl2 kl loss is 0.0003187208868604685
# lcmnl2 kl runtime is 34.90564775466919
# testing instance with offertimes 60 : 4th
# lcmnl2 kl loss is 3.996091722707762e-05
# lcmnl2 kl runtime is 35.93813705444336
# testing instance with offertimes 60 : 5th
# lcmnl2 kl loss is 0.000648273158851187
# lcmnl2 kl runtime is 32.72905397415161
# testing instance with offertimes 60 : 6th
# lcmnl2 kl loss is 5.62145222575694e-05
# lcmnl2 kl runtime is 36.78938889503479
# testing instance with offertimes 60 : 7th
# lcmnl2 kl loss is 5.457751500959063e-05
# lcmnl2 kl runtime is 34.749534130096436
# testing instance with offertimes 60 : 8th
# lcmnl2 kl loss is 1.918777436948904e-05
# lcmnl2 kl runtime is 36.16468811035156
# testing instance with offertimes 60 : 9th
# lcmnl2 kl loss is 0.00011464693846474638
# lcmnl2 kl runtime is 33.40408897399902
# testing instance with offertimes 60 : 10th
# lcmnl2 kl loss is 3.3584806558795144e-05
# lcmnl2 kl runtime is 33.99141502380371
# testing instance with offertimes 60 : 11th
# lcmnl2 kl loss is 4.672096043378815e-13
# lcmnl2 kl runtime is 36.607003927230835
# testing instance with offertimes 60 : 12th
# lcmnl2 kl loss is 0.0003410094903943395
# lcmnl2 kl runtime is 36.461524963378906
# testing instance with offertimes 60 : 13th
# lcmnl2 kl loss is 7.07535783893154e-05
# lcmnl2 kl runtime is 32.82041811943054
# testing instance with offertimes 60 : 14th
# lcmnl2 kl loss is 5.5916489766993926e-05
# lcmnl2 kl runtime is 35.56554698944092
# testing instance with offertimes 60 : 15th
# lcmnl2 kl loss is 0.0002932773944397393
# lcmnl2 kl runtime is 36.672322034835815
# testing instance with offertimes 60 : 16th
# lcmnl2 kl loss is 0.0007220588662217309
# lcmnl2 kl runtime is 36.322951793670654
# testing instance with offertimes 60 : 17th
# lcmnl2 kl loss is 0.00011130039101958644
# lcmnl2 kl runtime is 35.80102276802063
# testing instance with offertimes 60 : 18th
# lcmnl2 kl loss is 0.00014785094366875917
# lcmnl2 kl runtime is 37.266075134277344
# testing instance with offertimes 60 : 19th
# lcmnl2 kl loss is 4.4911006051862046e-06
# lcmnl2 kl runtime is 38.793968200683594
# testing instance with offertimes 60 : 20th
# lcmnl2 kl loss is 1.654880599721853e-06
# lcmnl2 kl runtime is 36.89506697654724
# testing instance with offertimes 60 : 21th
# lcmnl2 kl loss is 1.2435892793316583e-06
# lcmnl2 kl runtime is 38.80036783218384
# testing instance with offertimes 60 : 22th
# lcmnl2 kl loss is 5.473330663252618e-06
# lcmnl2 kl runtime is 36.64637207984924
# testing instance with offertimes 60 : 23th
# lcmnl2 kl loss is 2.56047268106796e-05
# lcmnl2 kl runtime is 43.78637909889221
# testing instance with offertimes 60 : 24th
# lcmnl2 kl loss is 2.6199303790830353e-05
# lcmnl2 kl runtime is 41.366194009780884
# testing instance with offertimes 60 : 25th
# lcmnl2 kl loss is 0.00031005274199591426
# lcmnl2 kl runtime is 42.401012897491455
# testing instance with offertimes 60 : 26th
# lcmnl2 kl loss is 0.0002142380920525655
# lcmnl2 kl runtime is 40.3088538646698
# testing instance with offertimes 60 : 27th
# lcmnl2 kl loss is 0.0003889329571834521
# lcmnl2 kl runtime is 37.81109666824341
# testing instance with offertimes 60 : 28th
# lcmnl2 kl loss is 0.0005253631789589042
# lcmnl2 kl runtime is 37.874706983566284
# testing instance with offertimes 60 : 29th
# lcmnl2 kl loss is 0.0003585745779988714
# lcmnl2 kl runtime is 39.901747941970825
# testing instance with offertimes 60 : 30th
# lcmnl2 kl loss is 0.00013639758952888048
# lcmnl2 kl runtime is 44.77017617225647
# testing instance with offertimes 60 : 31th
# lcmnl2 kl loss is 0.0018149617674463325
# lcmnl2 kl runtime is 38.915756940841675
# testing instance with offertimes 60 : 32th
# lcmnl2 kl loss is 0.0007239087056424287
# lcmnl2 kl runtime is 40.591171979904175
# testing instance with offertimes 60 : 33th
# lcmnl2 kl loss is 4.403668246744097e-05
# lcmnl2 kl runtime is 41.19264316558838
# testing instance with offertimes 60 : 34th
# lcmnl2 kl loss is 0.0005225420630174948
# lcmnl2 kl runtime is 40.70626997947693
# testing instance with offertimes 60 : 35th
# lcmnl2 kl loss is 0.0010523321292296717
# lcmnl2 kl runtime is 36.1212100982666
# testing instance with offertimes 60 : 36th
# lcmnl2 kl loss is 0.0001317531606787048
# lcmnl2 kl runtime is 35.715304136276245
# testing instance with offertimes 60 : 37th
# lcmnl2 kl loss is 0.0006704097086303873
# lcmnl2 kl runtime is 33.864301919937134
# testing instance with offertimes 60 : 38th
# lcmnl2 kl loss is 0.00011875227772228936
# lcmnl2 kl runtime is 34.34329700469971
# testing instance with offertimes 60 : 39th
# lcmnl2 kl loss is 0.0001662969853992724
# lcmnl2 kl runtime is 34.61005091667175
# testing instance with offertimes 60 : 40th
# lcmnl2 kl loss is 0.00044681950178948604
# lcmnl2 kl runtime is 33.05342888832092
# testing instance with offertimes 60 : 41th
# lcmnl2 kl loss is 6.319600200144215e-06
# lcmnl2 kl runtime is 36.67233729362488
# testing instance with offertimes 60 : 42th
# lcmnl2 kl loss is 8.618746192251558e-05
# lcmnl2 kl runtime is 32.968093156814575
# testing instance with offertimes 60 : 43th
# lcmnl2 kl loss is 0.00013828440351465465
# lcmnl2 kl runtime is 34.81264305114746
# testing instance with offertimes 60 : 44th
# lcmnl2 kl loss is 1.5240800160021273e-05
# lcmnl2 kl runtime is 35.62922501564026
# testing instance with offertimes 60 : 45th
# lcmnl2 kl loss is 1.8226043947411341e-06
# lcmnl2 kl runtime is 38.27753806114197
# testing instance with offertimes 60 : 46th
# lcmnl2 kl loss is 0.0004832882644904557
# lcmnl2 kl runtime is 34.3515260219574
# testing instance with offertimes 60 : 47th
# lcmnl2 kl loss is 1.154588313581617e-05
# lcmnl2 kl runtime is 38.106285095214844
# testing instance with offertimes 60 : 48th
# lcmnl2 kl loss is 1.6073137268368676e-05
# lcmnl2 kl runtime is 35.843974113464355
# testing instance with offertimes 60 : 49th
# lcmnl2 kl loss is 0.0005349422355475086
# lcmnl2 kl runtime is 32.85643005371094

# %%
for i in range(len(pred_offer_times_list)):
    df_lcmnl2_loss = pd.DataFrame({'lcmnl2_kl_loss':all_lcmnl2_limit_loss[i],'lcmnl2_kl_time':all_lcmnl2_limit_runtime[i]})
    df_lcmnl2_loss.to_csv('lcmnl_2class/limit_loss/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save solution: kl limit probability 
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_prob = pd.DataFrame(all_lcmnl2_limit_prob[i][j])
        df_prob.to_csv('lcmnl_2class/limit_prob/offertimes'+str(pred_offer_times_list[i])+'/prob'+str(j)+'.csv')

# %%
# save kl loss 
lcmnl2_kl_loss_mean = [np.mean(all_lcmnl2_limit_loss[x]) for x in range(len(pred_offer_times_list)) ]
lcmnl2_kl_loss_se = [ np.std(all_lcmnl2_limit_loss[x])/np.sqrt(len(all_lcmnl2_limit_loss[x])) for x in range(len(pred_offer_times_list)) ]

lcmnl2_kl_time_mean = [np.mean(all_lcmnl2_limit_runtime[x]) for x in range(len(pred_offer_times_list)) ]
lcmnl2_kl_time_se = [ np.std(all_lcmnl2_limit_runtime[x])/np.sqrt(len(all_lcmnl2_limit_runtime[x])) for x in range(len(pred_offer_times_list)) ]

df_lcmnl2_kl_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'lcmnl2_kl_loss':lcmnl2_kl_loss_mean, 'lcmnl2_kl_loss_se':lcmnl2_kl_loss_se,
                                'lcmnl2_kl_time':lcmnl2_kl_time_mean, 'lcmnl2_kl_time_se':lcmnl2_kl_time_se,
                                  })
df_lcmnl2_kl_loss.to_csv('lcmnl_2class/lcmnl2_kl_summary_hev_outside.csv')
df_lcmnl2_kl_loss
# Out:
#    offertimes  collection_size  lcmnl2_kl_loss  lcmnl2_kl_loss_se  \
# 0          20               29        0.001556           0.000224
# 1          30               24        0.000601           0.000102
# 2          40               19        0.000771           0.000162
# 3          50               15        0.000419           0.000081
# 4          60               13        0.000258           0.000047
#
#    lcmnl2_kl_time  lcmnl2_kl_time_se
# 0       19.463635           0.176450
# 1       18.740461           0.102610
# 2       19.814958           0.368213
# 3       30.371597           0.809424
# 4       36.800769           0.402342

# %%
all_rep = []
rep_mean = []
for i in range(len(pred_instance_size)):
    rep_lst = []
    for j in range(pred_instance_size[i]):
        if all_lcmnl2_limit_loss[i][j] <1e-6:
            rep_lst.append(j)
    df_rep = pd.DataFrame(rep_lst)
    df_rep.to_csv('lcmnl_2class/representability/'+str(pred_offer_times_list[i])+'.csv')
    all_rep.append(rep_lst)
    rep_mean.append(len(rep_lst)/50)
rep_mean
# Out:
# [0.0, 0.0, 0.02, 0.0, 0.02]

# %%
df_rep = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,'lcmnl2_rep':rep_mean})
df_rep.to_csv('lcmnl_2class/lcmnl2_rep_summary_hev.csv')
df_rep
# Out:
#    offertimes  collection_size  lcmnl2_rep
# 0          20               29        0.00
# 1          30               24        0.00
# 2          40               19        0.02
# 3          50               15        0.00
# 4          60               13        0.02

# %%
error_instance_df = pd.read_csv('mccm_error_instance.csv')
error_i = error_instance_df['error_i'].tolist()
error_j = error_instance_df['error_j'].tolist()

# %%
def create_new_list(A, error_i, error_j):
    # Create a set of (i, j) pairs for fast lookup of error positions
    error_set = set(zip(error_i, error_j))
    
    # Create a new list of lists by excluding the elements that are in the error_set
    A_prime = []
    for i, row in enumerate(A):
        new_row = [elem for j, elem in enumerate(row) if (i, j) not in error_set]
        A_prime.append(new_row)
    
    return A_prime

# %%
new_all_lcmnl2_loss = create_new_list(all_lcmnl2_limit_loss,error_i,error_j)
new_all_lcmnl2_time = create_new_list(all_lcmnl2_limit_runtime,error_i,error_j)
new_all_lcmnl2_prob = create_new_list(all_lcmnl2_limit_prob,error_i,error_j)

# %%
for i in range(len(pred_offer_times_list)):
    df_lcmnl2_loss = pd.DataFrame({'lcmnl2_kl_loss':new_all_lcmnl2_loss[i],'lcmnl2_kl_time':new_all_lcmnl2_time[i]})
    df_lcmnl2_loss.to_csv('lcmnl_2class/limit_loss_new/'+str(pred_offer_times_list[i])+'.csv')

# %%
lcmnl2_kl_loss_mean = [np.mean(new_all_lcmnl2_loss[x]) for x in range(len(pred_offer_times_list)) ]
lcmnl2_kl_loss_se = [ np.std(new_all_lcmnl2_loss[x])/np.sqrt(len(new_all_lcmnl2_loss[x])) for x in range(len(pred_offer_times_list)) ]

lcmnl2_kl_time_mean = [np.mean(new_all_lcmnl2_time[x]) for x in range(len(pred_offer_times_list)) ]
lcmnl2_kl_time_se = [ np.std(new_all_lcmnl2_time[x])/np.sqrt(len(new_all_lcmnl2_time[x])) for x in range(len(pred_offer_times_list)) ]

df_lcmnl2_kl_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'lcmnl2_kl_loss':lcmnl2_kl_loss_mean, 'lcmnl2_kl_loss_se':lcmnl2_kl_loss_se,
                                'lcmnl2_kl_time':lcmnl2_kl_time_mean, 'lcmnl2_kl_time_se':lcmnl2_kl_time_se
                                  })
df_lcmnl2_kl_loss.to_csv('lcmnl_2class/lcmnl2_kl_summary_NEW.csv')
df_lcmnl2_kl_loss
# Out:
#    offertimes  collection_size  lcmnl2_kl_loss  lcmnl2_kl_loss_se  \
# 0          20               29        0.001556           0.000224
# 1          30               24        0.000618           0.000105
# 2          40               19        0.000743           0.000165
# 3          50               15        0.000394           0.000079
# 4          60               13        0.000290           0.000052
#
#    lcmnl2_kl_time  lcmnl2_kl_time_se
# 0       19.463635           0.176450
# 1       18.727742           0.106466
# 2       19.874720           0.381113
# 3       30.331907           0.824969
# 4       36.930910           0.456041

# %%
all_rep = []
rep_mean = []
for i in range(len(pred_instance_size)):
    rep_lst = []
    for j in range(len(new_all_lcmnl2_loss[i])):
        if new_all_lcmnl2_loss[i][j] <1e-6:
            rep_lst.append(j)
    df_rep = pd.DataFrame(rep_lst)
    df_rep.to_csv('lcmnl_2class/representability_new/'+str(pred_offer_times_list[i])+'.csv')
    all_rep.append(rep_lst)
    rep_mean.append(len(rep_lst)/len(new_all_lcmnl2_loss[i]))
rep_mean
# Out:
# [0.0, 0.0, 0.020833333333333332, 0.0, 0.023255813953488372]

# %%
df_rep = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,'lcmnl2_rep':rep_mean})
df_rep.to_csv('lcmnl_2class/lcmnl2_rep_summary_NEW.csv')
df_rep
# Out:
#    offertimes  collection_size  lcmnl2_rep
# 0          20               29    0.000000
# 1          30               24    0.000000
# 2          40               19    0.020833
# 3          50               15    0.000000
# 4          60               13    0.023256
