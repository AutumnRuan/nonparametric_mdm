# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('choices.xlsm')  
offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
#offertimes.to_csv('offertimes.csv')
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
#inc_prod_num.to_csv('inc_prod_num.csv')
choice_prob = raw_jd_choice['clicknum'] / raw_jd_choice.groupby('clickset')['clicknum'].transform('sum')
raw_jd_choice['choice prob'] = choice_prob

assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

# all purchase options in each assortment
purchaseset = raw_jd_choice['purchaseset']
purchaseset_list = []
for pset in purchaseset:
    num_lst = json.loads(pset)
    purchaseset_list.append(num_lst)
raw_jd_choice['purchaseset'] = purchaseset_list

purchasenum_list = raw_jd_choice['clicknum'].tolist()
jd_choice=pd.DataFrame({'clickset':clickset_list,'purchaseset':purchaseset_list,'purchasenum':purchasenum_list,'choice prob':choice_prob})

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
collection = []
for cset in clickset_list:
    if cset not in collection:
        collection.append(cset)
print('there are {} different assortments'.format(len(collection)))

assortment_info_df['assortments'] = collection
choice_collection = np.zeros((n,len(collection)))
global_num = 0
for i in range(len(collection)):
    local_num =0
    while(local_num < inc_prod_num[i]):
        if purchaseset_list[global_num][0] in collection[i]:
            choice_collection[purchaseset_list[global_num][0]][i] = choice_prob[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print('error!')
# Out:
# there are 9 different products
# there are 134 different assortments

# %%
assortment_info_df_15 = assortment_info_df[(assortment_info_df['offer_times']>=15)]
assortments_15 = []
for i in range(len(assortment_info_df_15['assortments'])):
    assortments_15.append(assortment_info_df_15['assortments'][i])


jd_choice_15 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_15:
        jd_choice_15.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_15 = assortment_info_df_15['assortments']
choice_collection_15 = np.zeros((n,len(collection_15)))

frequency_collection_15 = np.zeros((n,len(collection_15)))

purchaseset_list_15 = jd_choice_15['purchaseset'].tolist()

inc_prod_num_15 = assortment_info_df_15['includ_prod_num']
choice_prob_15 = jd_choice_15['choice prob']
frequency_15 = jd_choice_15['purchasenum']

global_num = 0
for i in range(len(collection_15)):
    local_num =0
    while(local_num < inc_prod_num_15[i]):
        if purchaseset_list_15[global_num][0] in assortments_15[i]:
            choice_collection_15[purchaseset_list_15[global_num][0]][i] = choice_prob_15[global_num]
            frequency_collection_15[purchaseset_list_15[global_num][0]][i] = frequency_15[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_15[global_num])
            print(assortments_15[i])
            print('error!')
            break

offer_times_15 = assortment_info_df_15['offer_times'].tolist()
print('the number of assortments with at least 15 purchases is',len(assortments_15))
# Out:
# the number of assortments with at least 15 purchases is 38

# %%
assortment_info_df_20 = assortment_info_df[(assortment_info_df['offer_times']>=20)]
assortments_20 = []
for i in range(len(assortment_info_df_20['assortments'])):
    assortments_20.append(assortment_info_df_20['assortments'][i])


jd_choice_20 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_20:
        jd_choice_20.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_20 = assortment_info_df_20['assortments']
choice_collection_20 = np.zeros((n,len(collection_20)))

frequency_collection_20 = np.zeros((n,len(collection_20)))

purchaseset_list_20 = jd_choice_20['purchaseset'].tolist()

inc_prod_num_20 = assortment_info_df_20['includ_prod_num']
choice_prob_20 = jd_choice_20['choice prob']
frequency_20 = jd_choice_20['purchasenum']

global_num = 0
for i in range(len(collection_20)):
    local_num =0
    while(local_num < inc_prod_num_20[i]):
        if purchaseset_list_20[global_num][0] in assortments_20[i]:
            choice_collection_20[purchaseset_list_20[global_num][0]][i] = choice_prob_20[global_num]
            frequency_collection_20[purchaseset_list_20[global_num][0]][i] = frequency_20[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_20[global_num])
            print(assortments_20[i])
            print('error!')
            break


offer_times_20 = assortment_info_df_20['offer_times'].tolist()
print('the number of assortments with at least 20 purchases is',len(assortments_20))
# Out:
# the number of assortments with at least 20 purchases is 29

# %%
assortment_info_df_30 = assortment_info_df[(assortment_info_df['offer_times']>=30)]
assortments_30 = []
for i in range(len(assortment_info_df_30['assortments'])):
    assortments_30.append(assortment_info_df_30['assortments'][i])


jd_choice_30 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_30:
        jd_choice_30.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_30 = assortment_info_df_30['assortments']
choice_collection_30 = np.zeros((n,len(collection_30)))

frequency_collection_30 = np.zeros((n,len(collection_30)))

purchaseset_list_30 = jd_choice_30['purchaseset'].tolist()

inc_prod_num_30 = assortment_info_df_30['includ_prod_num']
choice_prob_30 = jd_choice_30['choice prob']
frequency_30 = jd_choice_30['purchasenum']

global_num = 0
for i in range(len(collection_30)):
    local_num =0
    while(local_num < inc_prod_num_30[i]):
        if purchaseset_list_30[global_num][0] in assortments_30[i]:
            choice_collection_30[purchaseset_list_30[global_num][0]][i] = choice_prob_30[global_num]
            frequency_collection_30[purchaseset_list_30[global_num][0]][i] = frequency_30[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_30[global_num])
            print(assortments_30[i])
            print('error!')
            break



offer_times_30 = assortment_info_df_30['offer_times'].tolist()
print('the number of assortments with at least 30 purchases is',len(assortments_30))
# Out:
# the number of assortments with at least 30 purchases is 24

# %%
assortment_info_df_40 = assortment_info_df[(assortment_info_df['offer_times']>=40)]
assortments_40 = []
for i in range(len(assortment_info_df_40['assortments'])):
    assortments_40.append(assortment_info_df_40['assortments'][i])


jd_choice_40 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_40:
        jd_choice_40.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_40 = assortment_info_df_40['assortments']
choice_collection_40 = np.zeros((n,len(collection_40)))

frequency_collection_40 = np.zeros((n,len(collection_40)))

purchaseset_list_40 = jd_choice_40['purchaseset'].tolist()

inc_prod_num_40 = assortment_info_df_40['includ_prod_num']
choice_prob_40 = jd_choice_40['choice prob']
frequency_40 = jd_choice_40['purchasenum']

global_num = 0
for i in range(len(collection_40)):
    local_num =0
    while(local_num < inc_prod_num_40[i]):
        if purchaseset_list_40[global_num][0] in assortments_40[i]:
            choice_collection_40[purchaseset_list_40[global_num][0]][i] = choice_prob_40[global_num]
            frequency_collection_40[purchaseset_list_40[global_num][0]][i] = frequency_40[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_40[global_num])
            print(assortments_40[i])
            print('error!')
            break



offer_times_40 = assortment_info_df_40['offer_times'].tolist()
print('the number of assortments with at least 40 purchases is',len(assortments_40))
# Out:
# the number of assortments with at least 40 purchases is 19

# %%
assortment_info_df_50 = assortment_info_df[(assortment_info_df['offer_times']>=50)]
assortments_50 = []
for i in range(len(assortment_info_df_50['assortments'])):
    assortments_50.append(assortment_info_df_50['assortments'][i])


jd_choice_50 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_50:
        jd_choice_50.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_50 = assortment_info_df_50['assortments']
choice_collection_50 = np.zeros((n,len(collection_50)))

frequency_collection_50 = np.zeros((n,len(collection_50)))

purchaseset_list_50 = jd_choice_50['purchaseset'].tolist()

inc_prod_num_50 = assortment_info_df_50['includ_prod_num']
choice_prob_50 = jd_choice_50['choice prob']
frequency_50 = jd_choice_50['purchasenum']

global_num = 0
for i in range(len(collection_50)):
    local_num =0
    while(local_num < inc_prod_num_50[i]):
        if purchaseset_list_50[global_num][0] in assortments_50[i]:
            choice_collection_50[purchaseset_list_50[global_num][0]][i] = choice_prob_50[global_num]
            frequency_collection_50[purchaseset_list_50[global_num][0]][i] = frequency_50[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_50[global_num])
            print(assortments_50[i])
            print('error!')
            break


offer_times_50 = assortment_info_df_50['offer_times'].tolist()
print('the number of assortments with at least 50 purchases is',len(assortments_50))
# Out:
# the number of assortments with at least 50 purchases is 15

# %%
assortment_info_df_60 = assortment_info_df[(assortment_info_df['offer_times']>=60)]
assortments_60 = []
for i in range(len(assortment_info_df_60['assortments'])):
    assortments_60.append(assortment_info_df_60['assortments'][i])


jd_choice_60 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_60:
        jd_choice_60.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_60 = assortment_info_df_60['assortments']
choice_collection_60 = np.zeros((n,len(collection_60)))

frequency_collection_60 = np.zeros((n,len(collection_60)))

purchaseset_list_60 = jd_choice_60['purchaseset'].tolist()

inc_prod_num_60 = assortment_info_df_60['includ_prod_num']
choice_prob_60 = jd_choice_60['choice prob']
frequency_60 = jd_choice_60['purchasenum']

global_num = 0
for i in range(len(collection_60)):
    local_num =0
    while(local_num < inc_prod_num_60[i]):
        if purchaseset_list_60[global_num][0] in assortments_60[i]:
            choice_collection_60[purchaseset_list_60[global_num][0]][i] = choice_prob_60[global_num]
            frequency_collection_60[purchaseset_list_60[global_num][0]][i] = frequency_60[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_60[global_num])
            print(assortments_60[i])
            print('error!')
            break


offer_times_60 = assortment_info_df_60['offer_times'].tolist()
print('the number of assortments with at least 60 purchases is',len(assortments_60))
# Out:
# the number of assortments with at least 60 purchases is 13

# %%
''' def new_data_w_at_least_2_products(n,curr_collection,curr_choice_collection,curr_offertimes):
    
    pre_new_collection = []
    new_collection_indices = []
    new_offertimes = []
    
    for i in range(len(curr_collection)):
        if len(curr_collection[i])>2:
            pre_new_collection.append(curr_collection[i][1:])
            new_collection_indices.append(i)
            new_offertimes.append(curr_offertimes[i])
            
    # Reduce values of all elements by 1
    new_collection = [[element - 1 for element in sublist] for sublist in pre_new_collection]

    new_choice_collection = np.zeros((n-1,len(new_collection_indices)))
    for i in range(len(new_collection_indices)):
        new_choice_collection[:,i] = curr_choice_collection[1:,new_collection_indices[i]]/np.sum(curr_choice_collection[1:,new_collection_indices[i]])
            
    return new_collection,new_choice_collection,new_offertimes '''

# %%
''' new_assortment_15,new_choice_collection_15,new_offer_times_15 = new_data_w_at_least_2_products(n,assortments_15,choice_collection_15,offer_times_15)
print('the new size of the collection with offertimes at least 15 is ',len(new_assortment_15))

new_assortment_20,new_choice_collection_20,new_offer_times_20 = new_data_w_at_least_2_products(n,assortments_20,choice_collection_20,offer_times_20)
print('the new size of the collection with offertimes at least 20 is ',len(new_assortment_20))

new_assortment_30,new_choice_collection_30,new_offer_times_30 = new_data_w_at_least_2_products(n,assortments_30,choice_collection_30,offer_times_30)
print('the new size of the collection with offertimes at least 30 is ',len(new_assortment_30))

new_assortment_40,new_choice_collection_40,new_offer_times_40 = new_data_w_at_least_2_products(n,assortments_40,choice_collection_40,offer_times_40)
print('the new size of the collection with offertimes at least 40 is ',len(new_assortment_40))

new_assortment_50,new_choice_collection_50,new_offer_times_50 = new_data_w_at_least_2_products(n,assortments_50,choice_collection_50,offer_times_50)
print('the new size of the collection with offertimes at least 50 is ',len(new_assortment_50))
 '''
# Out:
# " new_assortment_15,new_choice_collection_15,new_offer_times_15 = new_data_w_at_least_2_products(n,assortments_15,choice_collection_15,offer_times_15)\nprint('the new size of the collection with offertimes at least 15 is ',len(new_assortment_15))\n\nnew_assortment_20,new_choice_collection_20,new_offer_times_20 = new_data_w_at_least_2_products(n,assortments_20,choice_collection_20,offer_times_20)\nprint('the new size of the collection with offertimes at least 20 is ',len(new_assortment_20))\n\nnew_assortment_30,new_choice_collection_30,new_offer_times_30 = new_data_w_at_least_2_products(n,assortments_30,choice_collection_30,offer_times_30)\nprint('the new size of the collection with offertimes at least 30 is ',len(new_assortment_30))\n\nnew_assortment_40,new_choice_collection_40,new_offer_times_40 = new_data_w_at_least_2_products(n,assortments_40,choice_collection_40,offer_times_40)\nprint('the new size of the collection with offertimes at least 40 is ',len(new_assortment_40))\n\nnew_assortment_50,new_choice_collection_50,new_offer_times_50 = new_data_w_at_least_2_products(n,assortments_50,choice_collection_50,offer_times_50)\nprint('the new size of the collection with offertimes at least 50 is ',len(new_assortment_50))\n "

# %%
def collection_distribution_hev(n,collection):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,) '''
    # generate deterministic utilities for products
    
    ''' rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,)
    scales = np.hstack((scale_0,scale_1n)) '''
    
    mu = np.random.uniform(-2,2,n)
    scales = np.random.uniform(0.04,2,n)
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_instance_size = [50,50,50,50,50]

# %%
all_full_collections = [assortments_20,assortments_30,assortments_40,assortments_50,assortments_60]
all_full_offertimes = [offer_times_20,offer_times_30,offer_times_40,offer_times_50,offer_times_60]
full_collection_size = [len(offer_times_20),len(offer_times_30),len(offer_times_40),len(offer_times_50),len(offer_times_60)]

# %%
# full instance generation 
all_full_instances = []
for i in range(len(pred_offer_times_list)):
    
    full_instances_collection = []
    
    for j in range(pred_instance_size[i]):
        # generate true hev instance
        true_hev_instance = collection_distribution_hev(n,all_full_collections[i])
        full_instances_collection.append(true_hev_instance)

    
    all_full_instances.append(full_instances_collection)

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm_feasibility')
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    lam_values = [lam[i].x for i in range(data.shape[1])]
    lam_values = np.array(lam_values)

    if (model.objVal> 0):
        #model.write("mdmfeas_out.sol")
        #model.write("mdmfeas_model.lp") 
        return [1,model.Runtime,lam_values]
    else:
        #model.write("mdminfeas_model.lp")
        #return [0, used_time]
        return [0,model.Runtime,lam_values]

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.001

    model = gp.Model('mdm_limit')
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{i}_{j}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}")

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    if model.Status == GRB.OPTIMAL:
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
        
        lam_values = [lam[i].x for i in range(m)]
        lam_values = np.array(lam_values)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print('mdm limit computation error')
        #model.write("mdmlimit_out.sol")
        #model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,x_values]

# %%
## record the limit loss of all instances

all_mdm_rep = []
all_mdm_rep_time = []

all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_lam = []
all_mdm_limit_runtime = []

all_mdm_infeasible_index = []


for i in range(len(pred_offer_times_list)):
    
    ## define contrainer for mdm representability
    mdm_rep_collection = []
    mdm_rep_time_collection = []
    mdm_infeasible_index_collection = []
    
    ## define container for mdm limit 
    mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[]
    mdm_limit_lam_collection =[]
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        # data pre-process
        row_data = row_assortment_data(all_full_instances[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_full_instances[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_time_collection.append(curr_rep_result[1])
        
        # check if representable
        if curr_rep_result[0] > 0:
            print(f'instance offertimes {pred_offer_times_list[i]}, {j}th is representable by mdm with runtime {curr_rep_result[1]}')
            mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(curr_rep_result[1])
            mdm_limit_probability_collection.append(all_full_instances[i][j])
            mdm_limit_lam_collection.append(curr_rep_result[2])
        else:
            print(f'instance offertimes {pred_offer_times_list[i]}, {j}th is NOT representable by mdm')
            mdm_infeasible_index_collection.append(j)
            curr_limit_result = mdm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_probability_collection.append(curr_limit_result[-1])
            mdm_limit_runtime_collection.append(curr_limit_result[1])
            mdm_limit_lam_collection.append(curr_limit_result[2])
            print(f'mdm 1-norm loss is {curr_limit_result[0]} with run time {curr_limit_result[1]}')
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_time_collection) 
    all_mdm_infeasible_index.append(mdm_infeasible_index_collection)     
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection)
    all_mdm_limit_lam.append(mdm_limit_lam_collection)
# Out:
# testing instance with offertimes 20 : 0th
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# instance offertimes 20, 0th is NOT representable by mdm
# mdm 1-norm loss is 0.23803717999999927 with run time 0.2905101776123047
# testing instance with offertimes 20 : 1th
# instance offertimes 20, 1th is NOT representable by mdm
# mdm 1-norm loss is 0.005697870000000421 with run time 0.24056386947631836
# testing instance with offertimes 20 : 2th
# instance offertimes 20, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.3826081400000002 with run time 0.2609868049621582
# testing instance with offertimes 20 : 3th
# instance offertimes 20, 3th is NOT representable by mdm
# mdm 1-norm loss is 0.08229073999999843 with run time 0.25838804244995117
# testing instance with offertimes 20 : 4th
# instance offertimes 20, 4th is NOT representable by mdm
# mdm 1-norm loss is 0.14058162000000465 with run time 0.46846699714660645
# testing instance with offertimes 20 : 5th
# instance offertimes 20, 5th is NOT representable by mdm
# mdm 1-norm loss is 3.5641496699999973 with run time 0.7006211280822754
# testing instance with offertimes 20 : 6th
# instance offertimes 20, 6th is NOT representable by mdm
# mdm 1-norm loss is 1.946040359999998 with run time 0.5657839775085449
# testing instance with offertimes 20 : 7th
# instance offertimes 20, 7th is representable by mdm with runtime 0.0005619525909423828
# testing instance with offertimes 20 : 8th
# instance offertimes 20, 8th is NOT representable by mdm
# mdm 1-norm loss is 0.5923111300000004 with run time 0.6734731197357178
# testing instance with offertimes 20 : 9th
# instance offertimes 20, 9th is NOT representable by mdm
# mdm 1-norm loss is 0.33043059999999946 with run time 0.25161004066467285
# testing instance with offertimes 20 : 10th
# instance offertimes 20, 10th is representable by mdm with runtime 0.0002560615539550781
# testing instance with offertimes 20 : 11th
# instance offertimes 20, 11th is NOT representable by mdm
# mdm 1-norm loss is 0.20581227999999852 with run time 0.23159098625183105
# testing instance with offertimes 20 : 12th
# instance offertimes 20, 12th is NOT representable by mdm
# mdm 1-norm loss is 1.2909672000000059 with run time 0.33915209770202637
# testing instance with offertimes 20 : 13th
# instance offertimes 20, 13th is NOT representable by mdm
# mdm 1-norm loss is 0.13870478000000172 with run time 0.24248409271240234
# testing instance with offertimes 20 : 14th
# instance offertimes 20, 14th is NOT representable by mdm
# mdm 1-norm loss is 0.01545127000000018 with run time 0.26891493797302246
# testing instance with offertimes 20 : 15th
# instance offertimes 20, 15th is NOT representable by mdm
# mdm 1-norm loss is 0.0645125699999981 with run time 0.43897509574890137
# testing instance with offertimes 20 : 16th
# instance offertimes 20, 16th is NOT representable by mdm
# mdm 1-norm loss is 0.05928950000000042 with run time 0.307981014251709
# testing instance with offertimes 20 : 17th
# instance offertimes 20, 17th is NOT representable by mdm
# mdm 1-norm loss is 0.3761256500000001 with run time 0.2515850067138672
# testing instance with offertimes 20 : 18th
# instance offertimes 20, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.09700149000000019 with run time 0.24479293823242188
# testing instance with offertimes 20 : 19th
# instance offertimes 20, 19th is NOT representable by mdm
# mdm 1-norm loss is 0.012502960000091925 with run time 0.2986259460449219
# testing instance with offertimes 20 : 20th
# instance offertimes 20, 20th is NOT representable by mdm
# mdm 1-norm loss is 4.035228680000001 with run time 0.5043041706085205
# testing instance with offertimes 20 : 21th
# instance offertimes 20, 21th is NOT representable by mdm
# mdm 1-norm loss is 0.46339885000000003 with run time 0.20238208770751953
# testing instance with offertimes 20 : 22th
# instance offertimes 20, 22th is NOT representable by mdm
# mdm 1-norm loss is 0.11528585999999985 with run time 0.5688400268554688
# testing instance with offertimes 20 : 23th
# instance offertimes 20, 23th is representable by mdm with runtime 0.0003800392150878906
# testing instance with offertimes 20 : 24th
# instance offertimes 20, 24th is NOT representable by mdm
# mdm 1-norm loss is 0.5807214600000046 with run time 0.293377161026001
# testing instance with offertimes 20 : 25th
# instance offertimes 20, 25th is NOT representable by mdm
# mdm 1-norm loss is 0.3039155599999989 with run time 0.2843780517578125
# testing instance with offertimes 20 : 26th
# instance offertimes 20, 26th is NOT representable by mdm
# mdm 1-norm loss is 0.676280079999985 with run time 0.37630701065063477
# testing instance with offertimes 20 : 27th
# instance offertimes 20, 27th is NOT representable by mdm
# mdm 1-norm loss is 0.07442020000000049 with run time 0.20312809944152832
# testing instance with offertimes 20 : 28th
# instance offertimes 20, 28th is NOT representable by mdm
# mdm 1-norm loss is 0.4700804899999945 with run time 0.3854711055755615
# testing instance with offertimes 20 : 29th
# instance offertimes 20, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.6022892999999996 with run time 0.3074018955230713
# testing instance with offertimes 20 : 30th
# instance offertimes 20, 30th is NOT representable by mdm
# mdm 1-norm loss is 0.05598962999999908 with run time 0.24014496803283691
# testing instance with offertimes 20 : 31th
# instance offertimes 20, 31th is NOT representable by mdm
# mdm 1-norm loss is 0.5661798299999985 with run time 0.24718618392944336
# testing instance with offertimes 20 : 32th
# instance offertimes 20, 32th is NOT representable by mdm
# mdm 1-norm loss is 0.11558505000000027 with run time 0.21259593963623047
# testing instance with offertimes 20 : 33th
# instance offertimes 20, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.5557518600000324 with run time 0.259293794631958
# testing instance with offertimes 20 : 34th
# instance offertimes 20, 34th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.10364699363708496
# testing instance with offertimes 20 : 35th
# instance offertimes 20, 35th is NOT representable by mdm
# mdm 1-norm loss is 0.44644165000000124 with run time 0.27480196952819824
# testing instance with offertimes 20 : 36th
# instance offertimes 20, 36th is NOT representable by mdm
# mdm 1-norm loss is 0.21936537999999925 with run time 1.1594338417053223
# testing instance with offertimes 20 : 37th
# instance offertimes 20, 37th is NOT representable by mdm
# mdm 1-norm loss is 0.8754122499999997 with run time 0.3914768695831299
# testing instance with offertimes 20 : 38th
# instance offertimes 20, 38th is NOT representable by mdm
# mdm 1-norm loss is 0.6897164199999994 with run time 0.4340810775756836
# testing instance with offertimes 20 : 39th
# instance offertimes 20, 39th is NOT representable by mdm
# mdm 1-norm loss is 0.410894109999998 with run time 0.24512505531311035
# testing instance with offertimes 20 : 40th
# instance offertimes 20, 40th is NOT representable by mdm
# mdm 1-norm loss is 1.105529710000001 with run time 0.41765904426574707
# testing instance with offertimes 20 : 41th
# instance offertimes 20, 41th is NOT representable by mdm
# mdm 1-norm loss is 0.11567578999999836 with run time 0.2527501583099365
# testing instance with offertimes 20 : 42th
# instance offertimes 20, 42th is NOT representable by mdm
# mdm 1-norm loss is 0.39598025999999903 with run time 0.22583317756652832
# testing instance with offertimes 20 : 43th
# instance offertimes 20, 43th is NOT representable by mdm
# mdm 1-norm loss is 0.8018888000000032 with run time 0.2633209228515625
# testing instance with offertimes 20 : 44th
# instance offertimes 20, 44th is NOT representable by mdm
# mdm 1-norm loss is 0.7804708200000009 with run time 0.3000919818878174
# testing instance with offertimes 20 : 45th
# instance offertimes 20, 45th is NOT representable by mdm
# mdm 1-norm loss is 1.659302680000001 with run time 0.3332338333129883
# testing instance with offertimes 20 : 46th
# instance offertimes 20, 46th is NOT representable by mdm
# mdm 1-norm loss is 0.15067071999999904 with run time 0.24200797080993652
# testing instance with offertimes 20 : 47th
# instance offertimes 20, 47th is NOT representable by mdm
# mdm 1-norm loss is 0.30604931999999774 with run time 0.31552791595458984
# testing instance with offertimes 20 : 48th
# instance offertimes 20, 48th is NOT representable by mdm
# mdm 1-norm loss is 2.9227897800000022 with run time 0.9466118812561035
# testing instance with offertimes 20 : 49th
# instance offertimes 20, 49th is NOT representable by mdm
# mdm 1-norm loss is 0.0409326799999995 with run time 0.22487187385559082
# testing instance with offertimes 30 : 0th
# instance offertimes 30, 0th is NOT representable by mdm
# mdm 1-norm loss is 0.2571313499999983 with run time 0.13520407676696777
# testing instance with offertimes 30 : 1th
# instance offertimes 30, 1th is NOT representable by mdm
# mdm 1-norm loss is 0.01442160000000015 with run time 0.11510705947875977
# testing instance with offertimes 30 : 2th
# instance offertimes 30, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.012945780000000687 with run time 0.12121796607971191
# testing instance with offertimes 30 : 3th
# instance offertimes 30, 3th is NOT representable by mdm
# mdm 1-norm loss is 0.37546043999997214 with run time 0.17009902000427246
# testing instance with offertimes 30 : 4th
# instance offertimes 30, 4th is NOT representable by mdm
# mdm 1-norm loss is 0.13067826999999949 with run time 0.19632220268249512
# testing instance with offertimes 30 : 5th
# instance offertimes 30, 5th is NOT representable by mdm
# mdm 1-norm loss is 0.2096498500000002 with run time 0.15889906883239746
# testing instance with offertimes 30 : 6th
# instance offertimes 30, 6th is NOT representable by mdm
# mdm 1-norm loss is 0.299063081950387 with run time 0.13903093338012695
# testing instance with offertimes 30 : 7th
# instance offertimes 30, 7th is NOT representable by mdm
# mdm 1-norm loss is 0.9432559700000007 with run time 0.16405892372131348
# testing instance with offertimes 30 : 8th
# instance offertimes 30, 8th is NOT representable by mdm
# mdm 1-norm loss is 0.5205891999999978 with run time 0.1506509780883789
# testing instance with offertimes 30 : 9th
# instance offertimes 30, 9th is NOT representable by mdm
# mdm 1-norm loss is 0.05736752999999978 with run time 0.11658787727355957
# testing instance with offertimes 30 : 10th
# instance offertimes 30, 10th is representable by mdm with runtime 0.0003719329833984375
# testing instance with offertimes 30 : 11th
# instance offertimes 30, 11th is NOT representable by mdm
# mdm 1-norm loss is 0.5691545600000006 with run time 0.17431402206420898
# testing instance with offertimes 30 : 12th
# instance offertimes 30, 12th is NOT representable by mdm
# mdm 1-norm loss is 2.1779999999986642e-05 with run time 0.14250397682189941
# testing instance with offertimes 30 : 13th
# instance offertimes 30, 13th is NOT representable by mdm
# mdm 1-norm loss is 2.1189740599999998 with run time 0.26802897453308105
# testing instance with offertimes 30 : 14th
# instance offertimes 30, 14th is NOT representable by mdm
# mdm 1-norm loss is 0.06666740999999805 with run time 0.12266802787780762
# testing instance with offertimes 30 : 15th
# instance offertimes 30, 15th is NOT representable by mdm
# mdm 1-norm loss is 0.05758199999999925 with run time 0.11760306358337402
# testing instance with offertimes 30 : 16th
# instance offertimes 30, 16th is NOT representable by mdm
# mdm 1-norm loss is 0.029200360000000147 with run time 0.14959406852722168
# testing instance with offertimes 30 : 17th
# instance offertimes 30, 17th is NOT representable by mdm
# mdm 1-norm loss is 0.38060900000000336 with run time 0.11625313758850098
# testing instance with offertimes 30 : 18th
# instance offertimes 30, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.03524025999999935 with run time 0.13308095932006836
# testing instance with offertimes 30 : 19th
# instance offertimes 30, 19th is NOT representable by mdm
# mdm 1-norm loss is 0.5568521199999977 with run time 0.22201108932495117
# testing instance with offertimes 30 : 20th
# instance offertimes 30, 20th is NOT representable by mdm
# mdm 1-norm loss is 1.2046853100000008 with run time 0.22533798217773438
# testing instance with offertimes 30 : 21th
# instance offertimes 30, 21th is NOT representable by mdm
# mdm 1-norm loss is 0.0012972299999998572 with run time 0.11435985565185547
# testing instance with offertimes 30 : 22th
# instance offertimes 30, 22th is NOT representable by mdm
# mdm 1-norm loss is 0.015118399999999994 with run time 0.11579394340515137
# testing instance with offertimes 30 : 23th
# instance offertimes 30, 23th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.06304001808166504
# testing instance with offertimes 30 : 24th
# instance offertimes 30, 24th is representable by mdm with runtime 0.00036597251892089844
# testing instance with offertimes 30 : 25th
# instance offertimes 30, 25th is NOT representable by mdm
# mdm 1-norm loss is 2.520357030000001 with run time 0.24507808685302734
# testing instance with offertimes 30 : 26th
# instance offertimes 30, 26th is NOT representable by mdm
# mdm 1-norm loss is 0.5666453799999983 with run time 0.13897919654846191
# testing instance with offertimes 30 : 27th
# instance offertimes 30, 27th is NOT representable by mdm
# mdm 1-norm loss is 0.692329059999997 with run time 0.14175820350646973
# testing instance with offertimes 30 : 28th
# instance offertimes 30, 28th is NOT representable by mdm
# mdm 1-norm loss is 0.49053354000005606 with run time 0.13422298431396484
# testing instance with offertimes 30 : 29th
# instance offertimes 30, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.45050499999999866 with run time 0.2740478515625
# testing instance with offertimes 30 : 30th
# instance offertimes 30, 30th is NOT representable by mdm
# mdm 1-norm loss is 0.16184232000000534 with run time 0.11749410629272461
# testing instance with offertimes 30 : 31th
# instance offertimes 30, 31th is NOT representable by mdm
# mdm 1-norm loss is 0.18601811000000038 with run time 0.1207578182220459
# testing instance with offertimes 30 : 32th
# instance offertimes 30, 32th is NOT representable by mdm
# mdm 1-norm loss is 0.004444239999999376 with run time 0.10939502716064453
# testing instance with offertimes 30 : 33th
# instance offertimes 30, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.5161810600000011 with run time 0.1950058937072754
# testing instance with offertimes 30 : 34th
# instance offertimes 30, 34th is NOT representable by mdm
# mdm 1-norm loss is 0.047084449999998786 with run time 0.11969494819641113
# testing instance with offertimes 30 : 35th
# instance offertimes 30, 35th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.06299495697021484
# testing instance with offertimes 30 : 36th
# instance offertimes 30, 36th is NOT representable by mdm
# mdm 1-norm loss is 1.6474767900000005 with run time 0.18279695510864258
# testing instance with offertimes 30 : 37th
# instance offertimes 30, 37th is NOT representable by mdm
# mdm 1-norm loss is 0.8280481700000055 with run time 0.24310803413391113
# testing instance with offertimes 30 : 38th
# instance offertimes 30, 38th is NOT representable by mdm
# mdm 1-norm loss is 0.00227799999999998 with run time 0.12950706481933594
# testing instance with offertimes 30 : 39th
# instance offertimes 30, 39th is NOT representable by mdm
# mdm 1-norm loss is 0.004715519999999697 with run time 0.12303304672241211
# testing instance with offertimes 30 : 40th
# instance offertimes 30, 40th is NOT representable by mdm
# mdm 1-norm loss is 0.28003818000000197 with run time 0.17113399505615234
# testing instance with offertimes 30 : 41th
# instance offertimes 30, 41th is NOT representable by mdm
# mdm 1-norm loss is 0.7063863599999984 with run time 0.15583395957946777
# testing instance with offertimes 30 : 42th
# instance offertimes 30, 42th is NOT representable by mdm
# mdm 1-norm loss is 0.5457863999999992 with run time 0.12528300285339355
# testing instance with offertimes 30 : 43th
# instance offertimes 30, 43th is NOT representable by mdm
# mdm 1-norm loss is 0.14786327999999913 with run time 0.14493584632873535
# testing instance with offertimes 30 : 44th
# instance offertimes 30, 44th is NOT representable by mdm
# mdm 1-norm loss is 0.07458019999999925 with run time 0.11690998077392578
# testing instance with offertimes 30 : 45th
# instance offertimes 30, 45th is NOT representable by mdm
# mdm 1-norm loss is 0.0041932799999997074 with run time 0.11967301368713379
# testing instance with offertimes 30 : 46th
# instance offertimes 30, 46th is NOT representable by mdm
# mdm 1-norm loss is 0.20562335999999967 with run time 0.12986993789672852
# testing instance with offertimes 30 : 47th
# instance offertimes 30, 47th is NOT representable by mdm
# mdm 1-norm loss is 1.6044911599999974 with run time 0.2364029884338379
# testing instance with offertimes 30 : 48th
# instance offertimes 30, 48th is NOT representable by mdm
# mdm 1-norm loss is 0.009838799999999828 with run time 0.11769795417785645
# testing instance with offertimes 30 : 49th
# instance offertimes 30, 49th is NOT representable by mdm
# mdm 1-norm loss is 0.08024092000000152 with run time 0.15038609504699707
# testing instance with offertimes 40 : 0th
# instance offertimes 40, 0th is representable by mdm with runtime 0.0003459453582763672
# testing instance with offertimes 40 : 1th
# instance offertimes 40, 1th is NOT representable by mdm
# mdm 1-norm loss is 0.006196199999999895 with run time 0.057188987731933594
# testing instance with offertimes 40 : 2th
# instance offertimes 40, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.016051199999999866 with run time 0.06035494804382324
# testing instance with offertimes 40 : 3th
# instance offertimes 40, 3th is NOT representable by mdm
# mdm 1-norm loss is 0.0067390000000003315 with run time 0.0824899673461914
# testing instance with offertimes 40 : 4th
# instance offertimes 40, 4th is NOT representable by mdm
# mdm 1-norm loss is 0.21075133000000013 with run time 0.11862707138061523
# testing instance with offertimes 40 : 5th
# instance offertimes 40, 5th is NOT representable by mdm
# mdm 1-norm loss is 0.3830446799999977 with run time 0.061859130859375
# testing instance with offertimes 40 : 6th
# instance offertimes 40, 6th is representable by mdm with runtime 0.00030112266540527344
# testing instance with offertimes 40 : 7th
# instance offertimes 40, 7th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.03517007827758789
# testing instance with offertimes 40 : 8th
# instance offertimes 40, 8th is NOT representable by mdm
# mdm 1-norm loss is 0.018126179999999822 with run time 0.056802988052368164
# testing instance with offertimes 40 : 9th
# instance offertimes 40, 9th is representable by mdm with runtime 0.0004839897155761719
# testing instance with offertimes 40 : 10th
# instance offertimes 40, 10th is NOT representable by mdm
# mdm 1-norm loss is 0.030441880000000233 with run time 0.07100582122802734
# testing instance with offertimes 40 : 11th
# instance offertimes 40, 11th is representable by mdm with runtime 0.00035500526428222656
# testing instance with offertimes 40 : 12th
# instance offertimes 40, 12th is NOT representable by mdm
# mdm 1-norm loss is 0.09528003000000086 with run time 0.06530189514160156
# testing instance with offertimes 40 : 13th
# instance offertimes 40, 13th is representable by mdm with runtime 0.0002968311309814453
# testing instance with offertimes 40 : 14th
# instance offertimes 40, 14th is representable by mdm with runtime 0.00011396408081054688
# testing instance with offertimes 40 : 15th
# instance offertimes 40, 15th is NOT representable by mdm
# mdm 1-norm loss is 0.13773819999999887 with run time 0.09548211097717285
# testing instance with offertimes 40 : 16th
# instance offertimes 40, 16th is NOT representable by mdm
# mdm 1-norm loss is 0.15709088000000065 with run time 0.06914997100830078
# testing instance with offertimes 40 : 17th
# instance offertimes 40, 17th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.03560614585876465
# testing instance with offertimes 40 : 18th
# instance offertimes 40, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.17656470000000002 with run time 0.09697699546813965
# testing instance with offertimes 40 : 19th
# instance offertimes 40, 19th is NOT representable by mdm
# mdm 1-norm loss is 0.03298220999999809 with run time 0.06977176666259766
# testing instance with offertimes 40 : 20th
# instance offertimes 40, 20th is NOT representable by mdm
# mdm 1-norm loss is 0.12719266000000048 with run time 0.08165502548217773
# testing instance with offertimes 40 : 21th
# instance offertimes 40, 21th is NOT representable by mdm
# mdm 1-norm loss is 0.08219348999999904 with run time 0.12549996376037598
# testing instance with offertimes 40 : 22th
# instance offertimes 40, 22th is NOT representable by mdm
# mdm 1-norm loss is 0.3341864600000027 with run time 0.14636993408203125
# testing instance with offertimes 40 : 23th
# instance offertimes 40, 23th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.03506302833557129
# testing instance with offertimes 40 : 24th
# instance offertimes 40, 24th is NOT representable by mdm
# mdm 1-norm loss is 0.01636400000000001 with run time 0.0653998851776123
# testing instance with offertimes 40 : 25th
# instance offertimes 40, 25th is representable by mdm with runtime 0.0002999305725097656
# testing instance with offertimes 40 : 26th
# instance offertimes 40, 26th is NOT representable by mdm
# mdm 1-norm loss is 0.527776050000001 with run time 0.07641196250915527
# testing instance with offertimes 40 : 27th
# instance offertimes 40, 27th is representable by mdm with runtime 0.0002999305725097656
# testing instance with offertimes 40 : 28th
# instance offertimes 40, 28th is NOT representable by mdm
# mdm 1-norm loss is 0.24968056000000327 with run time 0.060125112533569336
# testing instance with offertimes 40 : 29th
# instance offertimes 40, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.17914340999999728 with run time 0.09946298599243164
# testing instance with offertimes 40 : 30th
# instance offertimes 40, 30th is NOT representable by mdm
# mdm 1-norm loss is 0.9862367099999998 with run time 0.2130570411682129
# testing instance with offertimes 40 : 31th
# instance offertimes 40, 31th is NOT representable by mdm
# mdm 1-norm loss is 1.358452910000001 with run time 0.2334458827972412
# testing instance with offertimes 40 : 32th
# instance offertimes 40, 32th is NOT representable by mdm
# mdm 1-norm loss is 0.010354400000000564 with run time 0.06168103218078613
# testing instance with offertimes 40 : 33th
# instance offertimes 40, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.26418563999999767 with run time 0.06012606620788574
# testing instance with offertimes 40 : 34th
# instance offertimes 40, 34th is NOT representable by mdm
# mdm 1-norm loss is 0.010386239999996934 with run time 0.06331706047058105
# testing instance with offertimes 40 : 35th
# instance offertimes 40, 35th is NOT representable by mdm
# mdm 1-norm loss is 0.284648720000003 with run time 0.07338905334472656
# testing instance with offertimes 40 : 36th
# instance offertimes 40, 36th is representable by mdm with runtime 0.00027108192443847656
# testing instance with offertimes 40 : 37th
# instance offertimes 40, 37th is NOT representable by mdm
# mdm 1-norm loss is 0.5806199999999992 with run time 0.08823800086975098
# testing instance with offertimes 40 : 38th
# instance offertimes 40, 38th is NOT representable by mdm
# mdm 1-norm loss is 0.4423625799999996 with run time 0.0857541561126709
# testing instance with offertimes 40 : 39th
# instance offertimes 40, 39th is NOT representable by mdm
# mdm 1-norm loss is 0.17399825999999982 with run time 0.08614897727966309
# testing instance with offertimes 40 : 40th
# instance offertimes 40, 40th is NOT representable by mdm
# mdm 1-norm loss is 1.56318919 with run time 0.10496401786804199
# testing instance with offertimes 40 : 41th
# instance offertimes 40, 41th is NOT representable by mdm
# mdm 1-norm loss is 0.0009761199999993507 with run time 0.07001304626464844
# testing instance with offertimes 40 : 42th
# instance offertimes 40, 42th is representable by mdm with runtime 0.00034689903259277344
# testing instance with offertimes 40 : 43th
# instance offertimes 40, 43th is NOT representable by mdm
# mdm 1-norm loss is 0.0025659000000025647 with run time 0.059845924377441406
# testing instance with offertimes 40 : 44th
# instance offertimes 40, 44th is NOT representable by mdm
# mdm 1-norm loss is 0.11793600000000037 with run time 0.061553955078125
# testing instance with offertimes 40 : 45th
# instance offertimes 40, 45th is NOT representable by mdm
# mdm 1-norm loss is 0.002681279999999709 with run time 0.057672977447509766
# testing instance with offertimes 40 : 46th
# instance offertimes 40, 46th is NOT representable by mdm
# mdm 1-norm loss is 0.6710201499999999 with run time 0.06331586837768555
# testing instance with offertimes 40 : 47th
# instance offertimes 40, 47th is NOT representable by mdm
# mdm 1-norm loss is 0.09014625000000008 with run time 0.06246805191040039
# testing instance with offertimes 40 : 48th
# instance offertimes 40, 48th is NOT representable by mdm
# mdm 1-norm loss is 0.005487959999996664 with run time 0.06051206588745117
# testing instance with offertimes 40 : 49th
# instance offertimes 40, 49th is NOT representable by mdm
# mdm 1-norm loss is 0.6778729200000013 with run time 0.1384110450744629
# testing instance with offertimes 50 : 0th
# instance offertimes 50, 0th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.012995004653930664
# testing instance with offertimes 50 : 1th
# instance offertimes 50, 1th is representable by mdm with runtime 0.0002110004425048828
# testing instance with offertimes 50 : 2th
# instance offertimes 50, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.15366300000000016 with run time 0.027333974838256836
# testing instance with offertimes 50 : 3th
# instance offertimes 50, 3th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.016865968704223633
# testing instance with offertimes 50 : 4th
# instance offertimes 50, 4th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.012256860733032227
# testing instance with offertimes 50 : 5th
# instance offertimes 50, 5th is representable by mdm with runtime 0.00013899803161621094
# testing instance with offertimes 50 : 6th
# instance offertimes 50, 6th is NOT representable by mdm
# mdm 1-norm loss is 1.4107207499999983 with run time 0.03177309036254883
# testing instance with offertimes 50 : 7th
# instance offertimes 50, 7th is representable by mdm with runtime 0.0002579689025878906
# testing instance with offertimes 50 : 8th
# instance offertimes 50, 8th is NOT representable by mdm
# mdm 1-norm loss is 0.16765280999999957 with run time 0.029977083206176758
# testing instance with offertimes 50 : 9th
# instance offertimes 50, 9th is representable by mdm with runtime 0.00021314620971679688
# testing instance with offertimes 50 : 10th
# instance offertimes 50, 10th is NOT representable by mdm
# mdm 1-norm loss is 0.11937021000000103 with run time 0.030939102172851562
# testing instance with offertimes 50 : 11th
# instance offertimes 50, 11th is NOT representable by mdm
# mdm 1-norm loss is 0.22017182000000082 with run time 0.02850794792175293
# testing instance with offertimes 50 : 12th
# instance offertimes 50, 12th is representable by mdm with runtime 0.00033211708068847656
# testing instance with offertimes 50 : 13th
# instance offertimes 50, 13th is representable by mdm with runtime 0.00013899803161621094
# testing instance with offertimes 50 : 14th
# instance offertimes 50, 14th is NOT representable by mdm
# mdm 1-norm loss is 0.44195101999999997 with run time 0.03682899475097656
# testing instance with offertimes 50 : 15th
# instance offertimes 50, 15th is representable by mdm with runtime 0.00028514862060546875
# testing instance with offertimes 50 : 16th
# instance offertimes 50, 16th is representable by mdm with runtime 0.00010514259338378906
# testing instance with offertimes 50 : 17th
# instance offertimes 50, 17th is representable by mdm with runtime 0.0001571178436279297
# testing instance with offertimes 50 : 18th
# instance offertimes 50, 18th is representable by mdm with runtime 9.799003601074219e-05
# testing instance with offertimes 50 : 19th
# instance offertimes 50, 19th is representable by mdm with runtime 0.00023603439331054688
# testing instance with offertimes 50 : 20th
# instance offertimes 50, 20th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.012494087219238281
# testing instance with offertimes 50 : 21th
# instance offertimes 50, 21th is NOT representable by mdm
# mdm 1-norm loss is 0.001818380000000406 with run time 0.0455479621887207
# testing instance with offertimes 50 : 22th
# instance offertimes 50, 22th is NOT representable by mdm
# mdm 1-norm loss is 0.9051714000000046 with run time 0.08484387397766113
# testing instance with offertimes 50 : 23th
# instance offertimes 50, 23th is representable by mdm with runtime 0.00032901763916015625
# testing instance with offertimes 50 : 24th
# instance offertimes 50, 24th is representable by mdm with runtime 0.00016999244689941406
# testing instance with offertimes 50 : 25th
# instance offertimes 50, 25th is representable by mdm with runtime 0.0001900196075439453
# testing instance with offertimes 50 : 26th
# instance offertimes 50, 26th is representable by mdm with runtime 0.0001838207244873047
# testing instance with offertimes 50 : 27th
# instance offertimes 50, 27th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.01225900650024414
# testing instance with offertimes 50 : 28th
# instance offertimes 50, 28th is NOT representable by mdm
# mdm 1-norm loss is 1.6025103599999946 with run time 0.04529380798339844
# testing instance with offertimes 50 : 29th
# instance offertimes 50, 29th is NOT representable by mdm
# mdm 1-norm loss is 1.3905043199999976 with run time 0.04808783531188965
# testing instance with offertimes 50 : 30th
# instance offertimes 50, 30th is representable by mdm with runtime 0.00017714500427246094
# testing instance with offertimes 50 : 31th
# instance offertimes 50, 31th is NOT representable by mdm
# mdm 1-norm loss is 0.04663287000000044 with run time 0.026484012603759766
# testing instance with offertimes 50 : 32th
# instance offertimes 50, 32th is NOT representable by mdm
# mdm 1-norm loss is 0.42919866000000173 with run time 0.028037071228027344
# testing instance with offertimes 50 : 33th
# instance offertimes 50, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.10626428000000068 with run time 0.028789043426513672
# testing instance with offertimes 50 : 34th
# instance offertimes 50, 34th is NOT representable by mdm
# mdm 1-norm loss is 0.02433172000000093 with run time 0.028100967407226562
# testing instance with offertimes 50 : 35th
# instance offertimes 50, 35th is NOT representable by mdm
# mdm 1-norm loss is 0.04279487999999826 with run time 0.030852079391479492
# testing instance with offertimes 50 : 36th
# instance offertimes 50, 36th is NOT representable by mdm
# mdm 1-norm loss is 0.2180301300000012 with run time 0.04653120040893555
# testing instance with offertimes 50 : 37th
# instance offertimes 50, 37th is representable by mdm with runtime 0.00014090538024902344
# testing instance with offertimes 50 : 38th
# instance offertimes 50, 38th is NOT representable by mdm
# mdm 1-norm loss is 0.25235048999999726 with run time 0.028393983840942383
# testing instance with offertimes 50 : 39th
# instance offertimes 50, 39th is NOT representable by mdm
# mdm 1-norm loss is 0.11468015999999952 with run time 0.02849602699279785
# testing instance with offertimes 50 : 40th
# instance offertimes 50, 40th is NOT representable by mdm
# mdm 1-norm loss is 0.61470155 with run time 0.03128814697265625
# testing instance with offertimes 50 : 41th
# instance offertimes 50, 41th is representable by mdm with runtime 0.0003581047058105469
# testing instance with offertimes 50 : 42th
# instance offertimes 50, 42th is representable by mdm with runtime 0.0001418590545654297
# testing instance with offertimes 50 : 43th
# instance offertimes 50, 43th is representable by mdm with runtime 0.00012087821960449219
# testing instance with offertimes 50 : 44th
# instance offertimes 50, 44th is representable by mdm with runtime 0.00016999244689941406
# testing instance with offertimes 50 : 45th
# instance offertimes 50, 45th is NOT representable by mdm
# mdm 1-norm loss is 0.1489700700000001 with run time 0.03510904312133789
# testing instance with offertimes 50 : 46th
# instance offertimes 50, 46th is representable by mdm with runtime 0.0001518726348876953
# testing instance with offertimes 50 : 47th
# instance offertimes 50, 47th is NOT representable by mdm
# mdm 1-norm loss is 0.005974320000001004 with run time 0.02892899513244629
# testing instance with offertimes 50 : 48th
# instance offertimes 50, 48th is representable by mdm with runtime 0.00028395652770996094
# testing instance with offertimes 50 : 49th
# instance offertimes 50, 49th is representable by mdm with runtime 9.989738464355469e-05
# testing instance with offertimes 60 : 0th
# instance offertimes 60, 0th is representable by mdm with runtime 9.679794311523438e-05
# testing instance with offertimes 60 : 1th
# instance offertimes 60, 1th is representable by mdm with runtime 0.00012302398681640625
# testing instance with offertimes 60 : 2th
# instance offertimes 60, 2th is representable by mdm with runtime 0.00010919570922851562
# testing instance with offertimes 60 : 3th
# instance offertimes 60, 3th is NOT representable by mdm
# mdm 1-norm loss is 1.537733080000001 with run time 0.019743919372558594
# testing instance with offertimes 60 : 4th
# instance offertimes 60, 4th is representable by mdm with runtime 0.00017595291137695312
# testing instance with offertimes 60 : 5th
# instance offertimes 60, 5th is representable by mdm with runtime 0.00022101402282714844
# testing instance with offertimes 60 : 6th
# instance offertimes 60, 6th is representable by mdm with runtime 0.0001690387725830078
# testing instance with offertimes 60 : 7th
# instance offertimes 60, 7th is representable by mdm with runtime 0.0001678466796875
# testing instance with offertimes 60 : 8th
# instance offertimes 60, 8th is representable by mdm with runtime 0.0001690387725830078
# testing instance with offertimes 60 : 9th
# instance offertimes 60, 9th is representable by mdm with runtime 0.00016808509826660156
# testing instance with offertimes 60 : 10th
# instance offertimes 60, 10th is representable by mdm with runtime 0.00012803077697753906
# testing instance with offertimes 60 : 11th
# instance offertimes 60, 11th is representable by mdm with runtime 0.0001399517059326172
# testing instance with offertimes 60 : 12th
# instance offertimes 60, 12th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.007894039154052734
# testing instance with offertimes 60 : 13th
# instance offertimes 60, 13th is NOT representable by mdm
# mdm 1-norm loss is 0.044551829999999404 with run time 0.0235750675201416
# testing instance with offertimes 60 : 14th
# instance offertimes 60, 14th is representable by mdm with runtime 0.0002300739288330078
# testing instance with offertimes 60 : 15th
# instance offertimes 60, 15th is NOT representable by mdm
# mdm 1-norm loss is 0.024980280000000236 with run time 0.01805591583251953
# testing instance with offertimes 60 : 16th
# instance offertimes 60, 16th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.010956048965454102
# testing instance with offertimes 60 : 17th
# instance offertimes 60, 17th is representable by mdm with runtime 0.0001690387725830078
# testing instance with offertimes 60 : 18th
# instance offertimes 60, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.10698023999999971 with run time 0.0235440731048584
# testing instance with offertimes 60 : 19th
# instance offertimes 60, 19th is NOT representable by mdm
# mdm 1-norm loss is 0.003232080000001438 with run time 0.01871800422668457
# testing instance with offertimes 60 : 20th
# instance offertimes 60, 20th is representable by mdm with runtime 0.0001690387725830078
# testing instance with offertimes 60 : 21th
# instance offertimes 60, 21th is representable by mdm with runtime 0.00014090538024902344
# testing instance with offertimes 60 : 22th
# instance offertimes 60, 22th is representable by mdm with runtime 9.799003601074219e-05
# testing instance with offertimes 60 : 23th
# instance offertimes 60, 23th is representable by mdm with runtime 9.512901306152344e-05
# testing instance with offertimes 60 : 24th
# instance offertimes 60, 24th is representable by mdm with runtime 0.00012993812561035156
# testing instance with offertimes 60 : 25th
# instance offertimes 60, 25th is NOT representable by mdm
# mdm 1-norm loss is 2.190529460000001 with run time 0.04768204689025879
# testing instance with offertimes 60 : 26th
# instance offertimes 60, 26th is representable by mdm with runtime 0.0003750324249267578
# testing instance with offertimes 60 : 27th
# instance offertimes 60, 27th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.00880289077758789
# testing instance with offertimes 60 : 28th
# instance offertimes 60, 28th is representable by mdm with runtime 0.00013184547424316406
# testing instance with offertimes 60 : 29th
# instance offertimes 60, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.02399940000000033 with run time 0.024914026260375977
# testing instance with offertimes 60 : 30th
# instance offertimes 60, 30th is representable by mdm with runtime 0.0001571178436279297
# testing instance with offertimes 60 : 31th
# instance offertimes 60, 31th is representable by mdm with runtime 0.00022101402282714844
# testing instance with offertimes 60 : 32th
# instance offertimes 60, 32th is representable by mdm with runtime 0.0001728534698486328
# testing instance with offertimes 60 : 33th
# instance offertimes 60, 33th is representable by mdm with runtime 0.00011181831359863281
# testing instance with offertimes 60 : 34th
# instance offertimes 60, 34th is NOT representable by mdm
# mdm 1-norm loss is 0.17688351999999918 with run time 0.02000594139099121
# testing instance with offertimes 60 : 35th
# instance offertimes 60, 35th is NOT representable by mdm
# mdm 1-norm loss is 0.03577824000000182 with run time 0.017967939376831055
# testing instance with offertimes 60 : 36th
# instance offertimes 60, 36th is NOT representable by mdm
# mdm 1-norm loss is 0.06852239999999736 with run time 0.018481016159057617
# testing instance with offertimes 60 : 37th
# instance offertimes 60, 37th is NOT representable by mdm
# mdm 1-norm loss is 0.09800409000000093 with run time 0.02567315101623535
# testing instance with offertimes 60 : 38th
# instance offertimes 60, 38th is representable by mdm with runtime 0.00028514862060546875
# testing instance with offertimes 60 : 39th
# instance offertimes 60, 39th is NOT representable by mdm
# mdm 1-norm loss is 2.1459748500000018 with run time 0.022023916244506836
# testing instance with offertimes 60 : 40th
# instance offertimes 60, 40th is representable by mdm with runtime 0.00012683868408203125
# testing instance with offertimes 60 : 41th
# instance offertimes 60, 41th is representable by mdm with runtime 0.00012612342834472656
# testing instance with offertimes 60 : 42th
# instance offertimes 60, 42th is NOT representable by mdm
# mdm 1-norm loss is 0.002368449999999868 with run time 0.018078088760375977
# testing instance with offertimes 60 : 43th
# instance offertimes 60, 43th is representable by mdm with runtime 0.00019598007202148438
# testing instance with offertimes 60 : 44th
# instance offertimes 60, 44th is NOT representable by mdm
# mdm 1-norm loss is 0.0032711199999978288 with run time 0.018251895904541016
# testing instance with offertimes 60 : 45th
# instance offertimes 60, 45th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.007565975189208984
# testing instance with offertimes 60 : 46th
# instance offertimes 60, 46th is representable by mdm with runtime 0.00022411346435546875
# testing instance with offertimes 60 : 47th
# instance offertimes 60, 47th is representable by mdm with runtime 0.0001780986785888672
# testing instance with offertimes 60 : 48th
# instance offertimes 60, 48th is representable by mdm with runtime 0.0002148151397705078
# testing instance with offertimes 60 : 49th
# instance offertimes 60, 49th is NOT representable by mdm
# mdm 1-norm loss is 0.09871109999999979 with run time 0.030891895294189453

# %%
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep[i]})
    df_mdm_rep.to_csv('mdm/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
mdm_feasible_proportion_list = [np.sum(all_mdm_rep[x])/len(all_mdm_rep[x]) for x in range(len(pred_offer_times_list)) ]
mdm_rep_time_mean = [np.mean(all_mdm_rep_time[x]) for x in range(len(pred_offer_times_list)) ]
mdm_rep_time_se = [ np.std(all_mdm_rep_time[x])/np.sqrt(len(all_mdm_rep_time[x])) for x in range(len(pred_offer_times_list))  ]
mdm_rep_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                'mdm_rep':mdm_feasible_proportion_list,'mdm_rep_time':mdm_rep_time_mean,'mdm_rep_time_se':mdm_rep_time_se})
mdm_rep_summary.to_csv('mdm/mdm_rep_summary_hev_outside.csv')
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se
# 0          20               29     0.06      0.000626         0.000266
# 1          30               24     0.04      0.000417         0.000015
# 2          40               19     0.20      0.000347         0.000014
# 3          50               15     0.48      0.000235         0.000015
# 4          60               13     0.62      0.000185         0.000010

# %%
# save infeasibe indices 
for i in range(len(pred_offer_times_list)):
    df_mdm_rep_infeas = pd.DataFrame(all_mdm_infeasible_index[i])
    df_mdm_rep_infeas.to_csv('mdm/rep_infeasibility/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save 1norm loss 
mdm_1norm_loss_mean = [np.mean(all_mdm_limit_loss[x]) for x in range(len(pred_offer_times_list)) ]
mdm_1norm_loss_se = [ np.std(all_mdm_limit_loss[x])/np.sqrt(len(all_mdm_limit_loss[x])) for x in range(len(pred_offer_times_list)) ]

mdm_1norm_time_mean = [np.mean(all_mdm_limit_runtime[x]) for x in range(len(pred_offer_times_list)) ]
mdm_1norm_time_se = [ np.std(all_mdm_limit_runtime[x])/np.sqrt(len(all_mdm_limit_runtime[x])) for x in range(len(pred_offer_times_list)) ]

df_mdm_1norm_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'mdm_1norm_loss':mdm_1norm_loss_mean, 'mdm_1norm_loss_se':mdm_1norm_loss_se,
                                'mdm_1norm_time':mdm_1norm_time_mean, 'mdm_1norm_time_se':mdm_1norm_time_se,
                                  })
df_mdm_1norm_loss.to_csv('mdm/mdm_1norm_loss_summary_hev_outside.csv')
df_mdm_1norm_loss
# Out:
#    offertimes  collection_size  mdm_1norm_loss  mdm_1norm_loss_se  \
# 0          20               29        0.581575           0.120840
# 1          30               24        0.392669           0.078471
# 2          40               19        0.200613           0.047669
# 3          50               15        0.168349           0.052643
# 4          60               13        0.131230           0.066267
#
#    mdm_1norm_time  mdm_1norm_time_se
# 0        0.331020           0.028881
# 1        0.144770           0.007753
# 2        0.066256           0.006947
# 3        0.016434           0.002662
# 4        0.007761           0.001575

# %%
# save 1norm loss:
for i in range(len(pred_offer_times_list)):
    df_mdm_1norm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_1norm_loss':all_mdm_limit_loss[i],'mdm_1norm_runtime':all_mdm_limit_runtime[i]})
    df_mdm_1norm_loss.to_csv('mdm/limit_loss/1norm/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save 1norm solution: limit probability and lambdas for kl
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_prob = pd.DataFrame(all_mdm_limit_prob[i][j])
        df_lam = pd.DataFrame(all_mdm_limit_lam[i][j])
        df_prob.to_csv('mdm/limit_prob/1norm/offertimes'+str(pred_offer_times_list[i])+'/prob'+str(j)+'.csv')
        df_lam.to_csv('mdm/lamda_1norm/offertimes'+str(pred_offer_times_list[i])+'/lam'+str(j)+'.csv')

# %%
import pyomo.environ as pyo
from pyomo.environ import *

# %%
def mdm_kl_w_lam(lam,data,collection,offertimes):
    
    n, m = data.shape
    
    ind = [[] for i in range(n)]  ## keeps track of the assortments including product i

    for i in range(len(collection)):
        for j in collection[i]:
            ind[j].append(i)  ## assortment i includes product j
    
    model = pyo.ConcreteModel()
    model.x = pyo.Var(range(n), range(m), domain= pyo.NonNegativeReals)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            if j not in collection[i]:
                model.norm_constraint.add(model.x[j, i] == 0)
    
    model.mdm_constraint = pyo.ConstraintList()
    for i in range(n):
        for j in range(len(ind[i]) - 1):
            for k in range(j + 1, len(ind[i])):
                if lam[ind[i][j]] >= lam[ind[i][k]]:
                    model.mdm_constraint.add(model.x[i, ind[i][k]] - model.x[i, ind[i][j]]  >= 0)
                if lam[ind[i][j]] <= lam[ind[i][k]]:
                    model.mdm_constraint.add(model.x[i, ind[i][j]] - model.x[i, ind[i][k]]  >= 0)
    
    model.obj = pyo.Objective(expr= -sum( sum(offertimes[j] *data[i, j] * pyo.log(model.x[i, j]) for i in collection[j]) for j in range(m)),sense=pyo.minimize)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    
    try:
        # Your optimization solve code here
        results = solver.solve(model,tee=True)
        status = str(results.solver.status)
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            print("Solver found a solution.")
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            return [pyo.value(model.obj), x_values, results.solver.time]
        
        elif results.solver.status == pyo.SolverStatus.warning:
            print("Solver issued a warning.")
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            return [pyo.value(model.obj), x_values, results.solver.time]
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")
    
    except ValueError as e:
        print(f"Error: {e}")

# %%
def deterministic_term(data,offertimes):
    dt = 0 
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            if data[i][j] >0:
                dt = dt + offertimes[j]*data[i][j]*np.log(data[i][j])
    return dt,dt/np.sum(offertimes)

# %%
all_mdm_kl_loss = []
all_mdm_avg_kl_loss = []
all_mdm_kl_prob = []
all_mdm_2stage_time = []

all_dt = []
all_avg_dt = []

all_total_time = []

for i in range(len(pred_offer_times_list)):
    
    mdm_kl_loss_collection = []
    mdm_avg_kl_loss_collection = []
    dt_collection = []
    avg_dt_collection = []
    mdm_kl_prob_collection = []
    mdm_2stage_time_collection = []
    total_time_collection = []
    
    for j in range(pred_instance_size[i]):
        
        if all_mdm_rep[i][j] <1:
            # mdm non-representable instance (i,j)
            result = mdm_kl_w_lam(all_mdm_limit_lam[i][j],all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            
            dt,avg_dt = deterministic_term(all_full_instances[i][j],all_full_offertimes[i])
            
            dt_collection.append(dt)
            avg_dt_collection.append(avg_dt)
            
            mdm_kl_loss_collection.append(result[0]+dt)
            mdm_avg_kl_loss_collection.append(result[0]/np.sum(all_full_offertimes[i])+avg_dt)
            
            mdm_kl_prob_collection.append(result[1])
            mdm_2stage_time_collection.append(result[-1])
            
            total_time_collection.append(result[-1] + all_mdm_limit_runtime[i][j])
        else:
            # mdm representable instances (i,j)
            mdm_kl_loss_collection.append(0)
            mdm_avg_kl_loss_collection.append(0)
            mdm_kl_prob_collection.append(all_full_instances[i][j])
            total_time_collection.append(all_mdm_rep_time[i][j])

    all_mdm_kl_loss.append(mdm_kl_loss_collection) 
    all_mdm_avg_kl_loss.append(mdm_avg_kl_loss_collection)
    all_mdm_kl_prob.append(mdm_kl_prob_collection)
    all_total_time.append(total_time_collection)
        
    all_dt.append(dt_collection)
    all_avg_dt.append(avg_dt_collection)
# Out:
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:
-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  3.9256269e+03 2.22e-16 2.37e-04  -5.7 4.76e-05    -  1.00e+00 1.00e+00f  1
#   51  3.9256269e+03 2.22e-16 7.10e-06  -5.7 4.05e-06    -  1.00e+00 1.00e+00h  1
#   52  3.9256269e+03 2.22e-16 4.57e+01  -8.6 7.11e-05    -  7.99e-01 1.00e+00f  1
#   53  3.9256269e+03 1.11e-16 1.36e+01  -8.6 3.97e-05    -  9.29e-01 7.32e-01f  1
#   54  3.9256269e+03 2.22e-16 5.51e-05  -8.6 2.86e-05    -  1.00e+00 1.00e+00f  1
#   55  3.9256269e+03 2.22e-16 1.03e-05  -8.6 9.19e-06    -  1.00e+00 1.00e+00h  1
#   56  3.9256269e+03 2.22e-16 2.08e-06  -8.6 4.08e-06    -  1.00e+00 1.00e+00h  1
#   57  3.9256269e+03 2.22e-16 2.39e-07  -8.6 1.40e-06    -  1.00e+00 1.00e+00h  1
#   58  3.9256269e+03 1.11e-16 5.33e-09  -8.6 2.14e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 58
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.9256268928263335e+03    3.9256268928263335e+03
# Dual infeasibility......:   5.3279537786797654e-09    5.3279537786797654e-09
# Constraint violation....:   1.1102230246251565e-16    1.1102230246251565e-16
# Complementarity.........:   2.5120345609296002e-09    2.5120345609296002e-09
# Overall NLP error.......:   5.3279537786797654e-09    5.3279537786797654e-09
#
#
# Number of objective function evaluations             = 61
# Number of objective gradient evaluations             = 59
# Number of equality constraint evaluations            = 61
# Number of inequality constraint evaluations          = 61
# Number of equality constraint Jacobian evaluations   = 59
# Number of inequality constraint Jacobian evaluations = 59
# Number of Lagrangian Hessian evaluations             = 58
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.053
# Total CPU secs in NLP function evaluations           =      0.010
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      261
# Number of nonzeros in inequality constraint Jacobian.:     1114
# Number of nonzeros in Lagrangian Hessian.............:       70
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      261
#                      variables with only lower bounds:      261
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      210
# Total number of inequality constraints...............:      557
#         inequality constraints with only lower bounds:      557
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.5252585e+04 9.80e-01 1.71e+05  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.4003961e+04 9.63e-01 1.68e+05  -1.0 9.70e-01    -  1.13e-02 1.70e-02f  1
#    2  3.3996084e+04 9.63e-01 1.68e+05  -1.0 9.52e-01    -  4.17e-02 1.62e-04f  1
#    3  3.3931683e+04 9.62e-01 1.68e+05  -1.0 9.39e-01    -  2.84e-02 1.05e-03f  1
#    4  3.3181496e+04 9.48e-01 1.66e+05  -1.0 9.39e-01    -  4.47e-02 1.46e-02f  1
#    5  3.2620544e+04 9.31e-01 1.63e+05  -1.0 9.36e-01    -  5.50e-02 1.79e-02f  1
#    6  3.2521208e+04 9.27e-01 1.62e+05  -1.0 9.21e-01    -  9.29e-02 4.20e-03f  1
#    7  2.9797531e+04 7.47e-01 1.43e+05  -1.0 9.18e-01    -  6.85e-02 1.94e-01f  1
#    8  2.7937553e+04 5.70e-01 1.16e+05  -1.0 7.38e-01    -  1.48e-01 2.37e-01f  1
#    9  2.7250591e+04 5.17e-01 1.06e+05  -1.0 5.57e-01    -  4.33e-01 9.27e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.5536545e+04 3.86e-01 8.39e+04  -1.0 5.00e-01    -  1.17e-01 2.54e-01f  1
#   11  2.3594095e+04 2.68e-01 6.35e+04  -1.0 3.62e-01    -  1.72e-01 3.05e-01f  1
#   12  2.2153249e+04 2.08e-01 5.14e+04  -1.0 2.35e-01    -  2.43e-01 2.24e-01f  1
#   13  1.9361505e+04 1.07e-01 3.29e+04  -1.0 1.66e-01    -  4.43e-01 4.86e-01f  1
#   14  1.6657489e+04 5.56e-02 2.11e+04  -1.0 7.42e-02    -  1.43e-01 4.81e-01f  1
20e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.0368174e+03 2.22e-16 1.00e+06  -8.6 1.81e-02    -  3.74e-01 1.00e+00f  1
#   41  2.0365341e+03 2.22e-16 5.58e+05  -8.6 8.05e-03    -  4.43e-01 1.00e+00f  1
#   42  2.0364889e+03 2.22e-16 6.96e+04  -8.6 2.14e-03    -  8.75e-01 6.47e-01f  1
#   43  2.0364553e+03 2.22e-16 4.47e+04  -8.6 1.97e-03    -  3.57e-01 7.79e-01f  1
#   44  2.0364495e+03 2.22e-16 1.70e+04  -8.6 8.02e-04    -  6.20e-01 7.35e-01f  1
#   45  2.0364486e+03 1.11e-16 1.55e+03  -8.6 3.64e-04    -  9.11e-01 6.05e-01f  1
#   46  2.0364482e+03 2.22e-16 1.96e+02  -8.6 1.82e-04    -  8.90e-01 4.93e-01f  1
#   47  2.0364480e+03 2.22e-16 1.15e+02  -8.6 9.50e-05    -  5.12e-01 6.44e-01f  1
#   48  2.0364480e+03 2.22e-16 2.75e+01  -8.6 3.40e-05    -  7.65e-01 6.53e-01f  1
#   49  2.0364480e+03 2.22e-16 2.24e+01  -8.6 1.18e-05    -  7.97e-02 2.94e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  2.0364479e+03 2.22e-16 4.60e+01  -8.6 8.33e-06    -  5.29e-02 7.82e-01f  1
#   51  2.0364479e+03 2.22e-16 5.27e+01  -8.6 1.82e-06    -  6.72e-01 4.17e-01f  1
#   52  2.0364479e+03 1.11e-16 1.59e+01  -8.6 1.15e-06    -  7.51e-01 7.17e-01f  1
#   53  2.0364479e+03 2.22e-16 3.96e+00  -8.6 3.45e-07    -  8.51e-01 1.00e+00f  1
#   54  2.0364479e+03 2.22e-16 1.85e-12  -8.6 2.62e-09    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 54
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.0364479456784857e+03    2.0364479456784857e+03
# Dual infeasibility......:   1.8515884893132220e-12    1.8515884893132220e-12
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.9744682600416614e-09    2.9744682600416614e-09
# Overall NLP error.......:   2.9744682600416614e-09    2.9744682600416614e-09
#
#
# Number of objective function evaluations             = 55
# Number of objective gradient evaluations             = 55
# Number of equality constraint evaluations            = 55
# Number of inequality constraint evaluations          = 55
# Number of equality constraint Jacobian evaluations   = 55
# Number of inequality constraint Jacobian evaluations = 55
# Number of Lagrangian Hessian evaluations             = 54
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.130
# Total CPU secs in NLP function evaluations           =      0.012
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      261
# Number of nonzeros in inequality constraint Jacobian.:     1110
# Number of nonzeros in Lagrangian Hessian.............:       80
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      261
#                      variables with only lower bounds:      261
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      210
# Total number of inequality constraints...............:      555
#         inequality constraints with only lower bounds:      555
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.5252585e+04 9.80e-01 1.12e+05  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.2466713e+04 9.69e-01 1.23e+05  -1.0 9.44e-01    -  1.16e-02 1.15e-02f  1
#    2  3.2439353e+04 9.69e-01 1.23e+05  -1.0 9.25e-01    -  3.33e-02 1.50e-04f  1
#    3  3.1918455e+04 9.66e-01 1.23e+05  -1.0 8.93e-01    -  1.51e-02 2.93e-03f  1
#    4  3.1826760e+04 9.65e-01 1.23e+05  -1.0 8.99e-01    -  1.95e-02 5.23e-04f  1
#    5  3.0928081e+04 9.60e-01 1.23e+05  -1.0 8.92e-01    -  2.43e-02 5.32e-03f  1
#    6  3.0684196e+04 9.59e-01 1.23e+05  -1.0 8.00e-01    -  1.52e-02 1.49e-03f  1
#    7  2.9233502e+04 9.49e-01 1.22e+05  -1.0 8.00e-01    -  2.50e-02 9.80e-03f  1
#    8  2.7811651e+04 9.38e-01 1.22e+05  -1.0 7.98e-01    -  3.73e-02 1.21e-02f  1
#    9  2.6757196e+04 9.27e-01 1.21e+05  -1.0 7.93e-01    -  4.98e-02 1.10e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.
#   35  5.2536573e+03 2.22e-16 4.04e+06  -1.0 4.03e-02    -  4.32e-01 1.00e+00f  1
#   36  5.2536820e+03 2.22e-16 4.97e-01  -1.0 9.83e-03    -  1.00e+00 1.00e+00f  1
#   37  5.2506555e+03 2.22e-16 3.82e+06  -5.7 5.07e-02    -  5.55e-01 9.37e-01f  1
#   38  5.2500523e+03 2.22e-16 1.27e+06  -5.7 2.96e-02    -  7.15e-01 1.00e+00f  1
#   39  5.2499440e+03 2.22e-16 4.21e+05  -5.7 1.42e-02    -  6.68e-01 9.26e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.2499108e+03 2.22e-16 1.55e+05  -5.7 9.56e-03    -  6.31e-01 9.87e-01f  1
#   41  5.2499037e+03 2.22e-16 2.66e+04  -5.7 5.10e-03    -  8.29e-01 1.00e+00f  1
#   42  5.2499020e+03 2.22e-16 3.35e+03  -5.7 2.64e-03    -  8.74e-01 1.00e+00f  1
#   43  5.2499017e+03 1.11e-16 2.83e+02  -5.7 1.03e-03    -  9.16e-01 1.00e+00f  1
#   44  5.2499017e+03 2.22e-16 1.79e-05  -5.7 4.40e-04    -  1.00e+00 1.00e+00f  1
#   45  5.2499017e+03 1.11e-16 2.02e+01  -8.6 1.80e-04    -  8.52e-01 9.62e-01f  1
#   46  5.2499017e+03 2.22e-16 2.42e+00  -8.6 9.24e-05    -  9.02e-01 9.65e-01f  1
#   47  5.2499017e+03 2.22e-16 9.23e-02  -8.6 3.79e-05    -  9.65e-01 1.00e+00f  1
#   48  5.2499017e+03 2.22e-16 1.26e-08  -8.6 7.99e-06    -  1.00e+00 1.00e+00h  1
#   49  5.2499017e+03 2.22e-16 6.45e-11  -9.0 5.95e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 49
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.2499016900821834e+03    5.2499016900821834e+03
# Dual infeasibility......:   6.4487254673545236e-11    6.4487254673545236e-11
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   1.0060356685255585e-09    1.0060356685255585e-09
# Overall NLP error.......:   1.0060356685255585e-09    1.0060356685255585e-09
#
#
# Number of objective function evaluations             = 50
# Number of objective gradient evaluations             = 50
# Number of equality constraint evaluations            = 50
# Number of inequality constraint evaluations          = 50
# Number of equality constraint Jacobian evaluations   = 50
# Number of inequality constraint Jacobian evaluations = 50
# Number of Lagrangian Hessian evaluations             = 49
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.462
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      261
# Number of nonzeros in inequality constraint Jacobian.:     1110
# Number of nonzeros in Lagrangian Hessian.............:       80
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      261
#                      variables with only lower bounds:      261
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      210
# Total number of inequality constraints...............:      555
#         inequality constraints with only lower bounds:      555
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.5252585e+04 9.80e-01 1.03e+05  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.1900234e+04 9.62e-01 1.33e+05  -1.0 9.41e-01    -  1.16e-02 1.88e-02f  1
#    2  3.1863635e+04 9.61e-01 1.33e+05  -1.0 9.46e-01    -  3.46e-02 3.37e-04f  1
#    3  3.1355253e+04 9.57e-01 1.33e+05  -1.0 9.46e-01    -  2.16e-02 4.92e-03f  1
#    4  3.0931053e+04 9.52e-01 1.33e+05  -1.0 9.39e-01    -  1.34e-02 4.67e-03f  1
#    5  3.0810456e+04 9.51e-01 1.33e+05  -1.0 9.25e-01    -  1.88e-02 1.41e-03f  1
#    6  3.0533407e+04 9.48e-01 1.32e+05  -1.0 9.23e-01    -  1.27e-02 3.36e-03f  1
#    7  2.9571678e+04 9.35e-01 1.31e+05  -1.0 9.18e-01    -  5.46e-03 1.37e-02f  1
#    8  2.9409754e+04 9.32e-01 1.30e+05  -1.0 9.05e-01    -  4.89e-02 2.86e-03f  1
#    9  2.8803686e+04 9.21e-01 1.29e+05  -1.0 9.03e-01    -  6.89e-02 1.18e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.
#   26  4.1589490e+03 1.11e-16 9.64e+03  -5.7 2.48e-03    -  8.73e-01 1.00e+00f  1
#   27  4.1589479e+03 2.22e-16 6.59e-04  -5.7 7.48e-04    -  1.00e+00 1.00e+00f  1
#   28  4.1589477e+03 2.22e-16 9.61e-05  -5.7 1.62e-04    -  1.00e+00 1.00e+00f  1
#   29  4.1589476e+03 2.22e-16 3.93e-06  -5.7 2.85e-05    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.1589476e+03 1.11e-16 8.87e-08  -8.6 5.92e-06    -  1.00e+00 1.00e+00f  1
#   31  4.1589476e+03 1.11e-16 5.31e-12  -8.6 3.31e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 31
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.1589476247436942e+03    4.1589476247436942e+03
# Dual infeasibility......:   5.3085287971976247e-12    5.3085287971976247e-12
# Constraint violation....:   1.1102230246251565e-16    1.1102230246251565e-16
# Complementarity.........:   4.4973140412609581e-09    4.4973140412609581e-09
# Overall NLP error.......:   4.4973140412609581e-09    4.4973140412609581e-09
#
#
# Number of objective function evaluations             = 32
# Number of objective gradient evaluations             = 32
# Number of equality constraint evaluations            = 32
# Number of inequality constraint evaluations          = 32
# Number of equality constraint Jacobian evaluations   = 32
# Number of inequality constraint Jacobian evaluations = 32
# Number of Lagrangian Hessian evaluations             = 31
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.262
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Solver found a solution.

# %%
# record kl loss of MDM
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),
                                'mdm_kl_loss':all_mdm_kl_loss[i],
                                'avg_mdm_kl_loss':all_mdm_avg_kl_loss[i],
                                'mdm_kl_time':all_total_time[i]})
    df_mdm_loss.to_csv('mdm/limit_loss/kl/'+str(pred_offer_times_list[i])+'.csv')

# %%
avg_total_kl_loss = []
avg_total_kl_loss_se = []
avg_avg_kl_loss = []
avg_avg_kl_loss_se = []

avg_runtime = []
avg_runtime_se = []

for i in range(len(pred_offer_times_list)):
    avg_total_kl_loss.append(np.mean(all_mdm_kl_loss[i]))
    avg_total_kl_loss_se.append(np.std(all_mdm_kl_loss[i])/np.sqrt(len(all_mdm_kl_loss[i])))
    
    avg_avg_kl_loss.append(np.mean(all_mdm_avg_kl_loss[i]))
    avg_avg_kl_loss_se.append(np.std(all_mdm_avg_kl_loss[i])/np.sqrt(len(all_mdm_avg_kl_loss[i])))
    
    avg_runtime.append(np.mean(all_total_time[i]))
    avg_runtime_se.append(np.std(all_total_time[i])/np.sqrt(len(all_total_time[i])) )
    
df_mdm_kl = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                   'total_mdm_kl_loss':avg_total_kl_loss,'total_mdm_kl_loss_se':avg_total_kl_loss_se,
                                   'avg_mdm_kl_loss':avg_avg_kl_loss,'avg_mdm_kl_loss_se':avg_avg_kl_loss_se,
                                   'mdm_kl_time':avg_runtime,'mdm_kl_time_se':avg_runtime_se
                                   })
df_mdm_kl.to_csv('mdm/mdm_kl_summary_hev_outside.csv')
df_mdm_kl
# Out:
#    offertimes  collection_size  total_mdm_kl_loss  total_mdm_kl_loss_se  \
# 0          20               29           0.427186              0.134807
# 1          30               24           0.276829              0.186798
# 2          40               19           0.171184              0.081132
# 3          50               15           0.061671              0.042613
# 4          60               13           0.044580              0.030401
#
#    avg_mdm_kl_loss  avg_mdm_kl_loss_se  mdm_kl_time  mdm_kl_time_se
# 0         0.000056            0.000018     0.968717        0.043497
# 1         0.000037            0.000025     0.740404        0.026959
# 2         0.000023            0.000011     0.459254        0.034370
# 3         0.000009            0.000006     0.236248        0.032771
# 4         0.000006            0.000004     0.150208        0.027423

# %%
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se
# 0          20               29     0.06      0.000626         0.000266
# 1          30               24     0.04      0.000417         0.000015
# 2          40               19     0.20      0.000347         0.000014
# 3          50               15     0.48      0.000235         0.000015
# 4          60               13     0.62      0.000185         0.000010

# %%
## adding limit results
#ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_mdm_kl_prob[i][j])
        df_limit_prob.to_csv('mdm/limit_prob/kl/offertimes'+str(pred_offer_times_list[i])+'/kl_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_instance_size = [50,50,50,50,50]

# %%
df_mdm_rep_hev_summary = pd.read_csv('mdm/mdm_rep_summary_hev_outside.csv')
df_mdm_rep_hev_summary
# Out:
#    Unnamed: 0  offertimes  collection_size  mdm_rep  mdm_rep_time  \
# 0           0          20               29     0.06      0.000626
# 1           1          30               24     0.04      0.000417
# 2           2          40               19     0.20      0.000347
# 3           3          50               15     0.48      0.000235
# 4           4          60               13     0.62      0.000185
#
#    mdm_rep_time_se
# 0         0.000266
# 1         0.000015
# 2         0.000014
# 3         0.000015
# 4         0.000010

# %%
all_rep_approx = []
all_rep_approx_mean = []
for i in range(len(pred_offer_times_list)):
    rep_approx = []
    df_all_mdm_kl_loss = pd.read_csv('mdm/limit_loss/kl/'+str(pred_offer_times_list[i])+'.csv')
    mdm_avg_kl_loss_list = df_all_mdm_kl_loss['avg_mdm_kl_loss'].tolist()
    for j in range(pred_instance_size[i]):
        if mdm_avg_kl_loss_list[j]<1e-6:
            rep_approx.append(j)
    all_rep_approx.append(rep_approx)
    all_rep_approx_mean.append(len(rep_approx)/pred_instance_size[i])
all_rep_approx_mean
# Out:
# [0.26, 0.42, 0.56, 0.72, 0.86]

# %%
df_mdm_rep_hev_summary['mdm_rep_approx'] = all_rep_approx_mean
df_mdm_rep_hev_summary.to_csv('mdm/mdm_rep_summary_hev_outside.csv')

# %%
df_mdm_rep_hev_summary
# Out:
#    Unnamed: 0  offertimes  collection_size  mdm_rep  mdm_rep_time  \
# 0           0          20               29     0.06      0.000626
# 1           1          30               24     0.04      0.000417
# 2           2          40               19     0.20      0.000347
# 3           3          50               15     0.48      0.000235
# 4           4          60               13     0.62      0.000185
#
#    mdm_rep_time_se  mdm_rep_approx
# 0         0.000266            0.26
# 1         0.000015            0.42
# 2         0.000014            0.56
# 3         0.000015            0.72
# 4         0.000010            0.86

# %%
error_instance_df = pd.read_csv('mccm_error_instance.csv')
error_i = error_instance_df['error_i'].tolist()
error_j = error_instance_df['error_j'].tolist()

# %%
def create_new_list(A, error_i, error_j):
    # Create a set of (i, j) pairs for fast lookup of error positions
    error_set = set(zip(error_i, error_j))
    
    # Create a new list of lists by excluding the elements that are in the error_set
    A_prime = []
    for i, row in enumerate(A):
        new_row = [elem for j, elem in enumerate(row) if (i, j) not in error_set]
        A_prime.append(new_row)
    
    return A_prime

# %%
new_all_mdm_loss = create_new_list(all_mdm_avg_kl_loss,error_i,error_j)
new_all_mdm_time = create_new_list(all_total_time,error_i,error_j)
new_all_mdm_prob = create_new_list(all_mdm_kl_prob,error_i,error_j)

# %%
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'mdm_kl_loss':new_all_mdm_loss[i],'mdm_kl_time':new_all_mdm_time[i]})
    df_mdm_loss.to_csv('mdm/limit_loss_new/'+str(pred_offer_times_list[i])+'.csv')

# %%
mdm_kl_loss_mean = [np.mean(new_all_mdm_loss[x]) for x in range(len(pred_offer_times_list)) ]
mdm_kl_loss_se = [ np.std(new_all_mdm_loss[x])/np.sqrt(len(new_all_mdm_loss[x])) for x in range(len(pred_offer_times_list)) ]

mdm_kl_time_mean = [np.mean(new_all_mdm_time[x]) for x in range(len(pred_offer_times_list)) ]
mdm_kl_time_se = [ np.std(new_all_mdm_time[x])/np.sqrt(len(new_all_mdm_time[x])) for x in range(len(pred_offer_times_list)) ]

df_mdm_kl_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'mdm_kl_loss':mdm_kl_loss_mean, 'mdm_kl_loss_se':mdm_kl_loss_se,
                                'mdm_kl_time':mdm_kl_time_mean, 'mdm_kl_time_se':mdm_kl_time_se
                                  })
df_mdm_kl_loss.to_csv('mdm/mdm_kl_summary_NEW.csv')
df_mdm_kl_loss
# Out:
#    offertimes  collection_size  mdm_kl_loss  mdm_kl_loss_se  mdm_kl_time  \
# 0          20               29     0.000056        0.000018     0.968717
# 1          30               24     0.000038        0.000026     0.733593
# 2          40               19     0.000017        0.000009     0.463870
# 3          50               15     0.000009        0.000006     0.232494
# 4          60               13     0.000007        0.000005     0.174636
#
#    mdm_kl_time_se
# 0        0.043497
# 1        0.027524
# 2        0.034139
# 3        0.033224
# 4        0.030293

# %%
all_rep = []
rep_mean = []
for i in range(len(pred_instance_size)):
    rep_lst = []
    for j in range(len(new_all_mdm_loss[i])):
        if new_all_mdm_loss[i][j] <1e-6:
            rep_lst.append(j)
    df_rep = pd.DataFrame(rep_lst)
    df_rep.to_csv('mdm/representability_new/'+str(pred_offer_times_list[i])+'.csv')
    all_rep.append(rep_lst)
    rep_mean.append(len(rep_lst)/len(new_all_mdm_loss[i]))
rep_mean
# Out:
# [0.26, 0.4375, 0.5625, 0.7346938775510204, 0.8372093023255814]

# %%
df_rep = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,'mdm_rep':rep_mean})
df_rep.to_csv('mdm/mdm_rep_summary_NEW.csv')
df_rep
# Out:
#    offertimes  collection_size   mdm_rep
# 0          20               29  0.260000
# 1          30               24  0.437500
# 2          40               19  0.562500
# 3          50               15  0.734694
# 4          60               13  0.837209
