# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('choices.xlsm')  
offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
#offertimes.to_csv('offertimes.csv')
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
#inc_prod_num.to_csv('inc_prod_num.csv')
choice_prob = raw_jd_choice['clicknum'] / raw_jd_choice.groupby('clickset')['clicknum'].transform('sum')
raw_jd_choice['choice prob'] = choice_prob

assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

# all purchase options in each assortment
purchaseset = raw_jd_choice['purchaseset']
purchaseset_list = []
for pset in purchaseset:
    num_lst = json.loads(pset)
    purchaseset_list.append(num_lst)
raw_jd_choice['purchaseset'] = purchaseset_list

purchasenum_list = raw_jd_choice['clicknum'].tolist()
jd_choice=pd.DataFrame({'clickset':clickset_list,'purchaseset':purchaseset_list,'purchasenum':purchasenum_list,'choice prob':choice_prob})

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
collection = []
for cset in clickset_list:
    if cset not in collection:
        collection.append(cset)
print('there are {} different assortments'.format(len(collection)))

assortment_info_df['assortments'] = collection
choice_collection = np.zeros((n,len(collection)))
global_num = 0
for i in range(len(collection)):
    local_num =0
    while(local_num < inc_prod_num[i]):
        if purchaseset_list[global_num][0] in collection[i]:
            choice_collection[purchaseset_list[global_num][0]][i] = choice_prob[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print('error!')
# Out:
# there are 9 different products
# there are 134 different assortments

# %%
assortment_info_df_15 = assortment_info_df[(assortment_info_df['offer_times']>=15)]
assortments_15 = []
for i in range(len(assortment_info_df_15['assortments'])):
    assortments_15.append(assortment_info_df_15['assortments'][i])


jd_choice_15 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_15:
        jd_choice_15.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_15 = assortment_info_df_15['assortments']
choice_collection_15 = np.zeros((n,len(collection_15)))

frequency_collection_15 = np.zeros((n,len(collection_15)))

purchaseset_list_15 = jd_choice_15['purchaseset'].tolist()

inc_prod_num_15 = assortment_info_df_15['includ_prod_num']
choice_prob_15 = jd_choice_15['choice prob']
frequency_15 = jd_choice_15['purchasenum']

global_num = 0
for i in range(len(collection_15)):
    local_num =0
    while(local_num < inc_prod_num_15[i]):
        if purchaseset_list_15[global_num][0] in assortments_15[i]:
            choice_collection_15[purchaseset_list_15[global_num][0]][i] = choice_prob_15[global_num]
            frequency_collection_15[purchaseset_list_15[global_num][0]][i] = frequency_15[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_15[global_num])
            print(assortments_15[i])
            print('error!')
            break

offer_times_15 = assortment_info_df_15['offer_times'].tolist()
print('the number of assortments with at least 15 purchases is',len(assortments_15))
# Out:
# the number of assortments with at least 15 purchases is 38

# %%
assortment_info_df_20 = assortment_info_df[(assortment_info_df['offer_times']>=20)]
assortments_20 = []
for i in range(len(assortment_info_df_20['assortments'])):
    assortments_20.append(assortment_info_df_20['assortments'][i])


jd_choice_20 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_20:
        jd_choice_20.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_20 = assortment_info_df_20['assortments']
choice_collection_20 = np.zeros((n,len(collection_20)))

frequency_collection_20 = np.zeros((n,len(collection_20)))

purchaseset_list_20 = jd_choice_20['purchaseset'].tolist()

inc_prod_num_20 = assortment_info_df_20['includ_prod_num']
choice_prob_20 = jd_choice_20['choice prob']
frequency_20 = jd_choice_20['purchasenum']

global_num = 0
for i in range(len(collection_20)):
    local_num =0
    while(local_num < inc_prod_num_20[i]):
        if purchaseset_list_20[global_num][0] in assortments_20[i]:
            choice_collection_20[purchaseset_list_20[global_num][0]][i] = choice_prob_20[global_num]
            frequency_collection_20[purchaseset_list_20[global_num][0]][i] = frequency_20[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_20[global_num])
            print(assortments_20[i])
            print('error!')
            break


offer_times_20 = assortment_info_df_20['offer_times'].tolist()
print('the number of assortments with at least 20 purchases is',len(assortments_20))
# Out:
# the number of assortments with at least 20 purchases is 29

# %%
assortment_info_df_30 = assortment_info_df[(assortment_info_df['offer_times']>=30)]
assortments_30 = []
for i in range(len(assortment_info_df_30['assortments'])):
    assortments_30.append(assortment_info_df_30['assortments'][i])


jd_choice_30 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_30:
        jd_choice_30.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_30 = assortment_info_df_30['assortments']
choice_collection_30 = np.zeros((n,len(collection_30)))

frequency_collection_30 = np.zeros((n,len(collection_30)))

purchaseset_list_30 = jd_choice_30['purchaseset'].tolist()

inc_prod_num_30 = assortment_info_df_30['includ_prod_num']
choice_prob_30 = jd_choice_30['choice prob']
frequency_30 = jd_choice_30['purchasenum']

global_num = 0
for i in range(len(collection_30)):
    local_num =0
    while(local_num < inc_prod_num_30[i]):
        if purchaseset_list_30[global_num][0] in assortments_30[i]:
            choice_collection_30[purchaseset_list_30[global_num][0]][i] = choice_prob_30[global_num]
            frequency_collection_30[purchaseset_list_30[global_num][0]][i] = frequency_30[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_30[global_num])
            print(assortments_30[i])
            print('error!')
            break



offer_times_30 = assortment_info_df_30['offer_times'].tolist()
print('the number of assortments with at least 30 purchases is',len(assortments_30))
# Out:
# the number of assortments with at least 30 purchases is 24

# %%
assortment_info_df_40 = assortment_info_df[(assortment_info_df['offer_times']>=40)]
assortments_40 = []
for i in range(len(assortment_info_df_40['assortments'])):
    assortments_40.append(assortment_info_df_40['assortments'][i])


jd_choice_40 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_40:
        jd_choice_40.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_40 = assortment_info_df_40['assortments']
choice_collection_40 = np.zeros((n,len(collection_40)))

frequency_collection_40 = np.zeros((n,len(collection_40)))

purchaseset_list_40 = jd_choice_40['purchaseset'].tolist()

inc_prod_num_40 = assortment_info_df_40['includ_prod_num']
choice_prob_40 = jd_choice_40['choice prob']
frequency_40 = jd_choice_40['purchasenum']

global_num = 0
for i in range(len(collection_40)):
    local_num =0
    while(local_num < inc_prod_num_40[i]):
        if purchaseset_list_40[global_num][0] in assortments_40[i]:
            choice_collection_40[purchaseset_list_40[global_num][0]][i] = choice_prob_40[global_num]
            frequency_collection_40[purchaseset_list_40[global_num][0]][i] = frequency_40[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_40[global_num])
            print(assortments_40[i])
            print('error!')
            break



offer_times_40 = assortment_info_df_40['offer_times'].tolist()
print('the number of assortments with at least 40 purchases is',len(assortments_40))
# Out:
# the number of assortments with at least 40 purchases is 19

# %%
assortment_info_df_50 = assortment_info_df[(assortment_info_df['offer_times']>=50)]
assortments_50 = []
for i in range(len(assortment_info_df_50['assortments'])):
    assortments_50.append(assortment_info_df_50['assortments'][i])


jd_choice_50 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_50:
        jd_choice_50.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_50 = assortment_info_df_50['assortments']
choice_collection_50 = np.zeros((n,len(collection_50)))

frequency_collection_50 = np.zeros((n,len(collection_50)))

purchaseset_list_50 = jd_choice_50['purchaseset'].tolist()

inc_prod_num_50 = assortment_info_df_50['includ_prod_num']
choice_prob_50 = jd_choice_50['choice prob']
frequency_50 = jd_choice_50['purchasenum']

global_num = 0
for i in range(len(collection_50)):
    local_num =0
    while(local_num < inc_prod_num_50[i]):
        if purchaseset_list_50[global_num][0] in assortments_50[i]:
            choice_collection_50[purchaseset_list_50[global_num][0]][i] = choice_prob_50[global_num]
            frequency_collection_50[purchaseset_list_50[global_num][0]][i] = frequency_50[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_50[global_num])
            print(assortments_50[i])
            print('error!')
            break


offer_times_50 = assortment_info_df_50['offer_times'].tolist()
print('the number of assortments with at least 50 purchases is',len(assortments_50))
# Out:
# the number of assortments with at least 50 purchases is 15

# %%
def new_data_w_at_least_2_products(n,curr_collection,curr_choice_collection,curr_offertimes):
    
    pre_new_collection = []
    new_collection_indices = []
    new_offertimes = []
    
    for i in range(len(curr_collection)):
        if len(curr_collection[i])>2:
            pre_new_collection.append(curr_collection[i][1:])
            new_collection_indices.append(i)
            new_offertimes.append(curr_offertimes[i])
            
    # Reduce values of all elements by 1
    new_collection = [[element - 1 for element in sublist] for sublist in pre_new_collection]

    new_choice_collection = np.zeros((n-1,len(new_collection_indices)))
    for i in range(len(new_collection_indices)):
        new_choice_collection[:,i] = curr_choice_collection[1:,new_collection_indices[i]]/np.sum(curr_choice_collection[1:,new_collection_indices[i]])
            
    return new_collection,new_choice_collection,new_offertimes

# %%
new_assortment_15,new_choice_collection_15,new_offer_times_15 = new_data_w_at_least_2_products(n,assortments_15,choice_collection_15,offer_times_15)
print('the new size of the collection with offertimes at least 15 is ',len(new_assortment_15))

new_assortment_20,new_choice_collection_20,new_offer_times_20 = new_data_w_at_least_2_products(n,assortments_20,choice_collection_20,offer_times_20)
print('the new size of the collection with offertimes at least 20 is ',len(new_assortment_20))

new_assortment_30,new_choice_collection_30,new_offer_times_30 = new_data_w_at_least_2_products(n,assortments_30,choice_collection_30,offer_times_30)
print('the new size of the collection with offertimes at least 30 is ',len(new_assortment_30))

new_assortment_40,new_choice_collection_40,new_offer_times_40 = new_data_w_at_least_2_products(n,assortments_40,choice_collection_40,offer_times_40)
print('the new size of the collection with offertimes at least 40 is ',len(new_assortment_40))

new_assortment_50,new_choice_collection_50,new_offer_times_50 = new_data_w_at_least_2_products(n,assortments_50,choice_collection_50,offer_times_50)
print('the new size of the collection with offertimes at least 50 is ',len(new_assortment_50))
# Out:
# the new size of the collection with offertimes at least 15 is  30
# the new size of the collection with offertimes at least 20 is  21
# the new size of the collection with offertimes at least 30 is  16
# the new size of the collection with offertimes at least 40 is  11
# the new size of the collection with offertimes at least 50 is  7

# %%
def collection_distribution_hev(n,collection):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    ''' rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n)) '''
    
    mu = np.random.uniform(-2,2,n)
    scales = np.random.uniform(0.04,2,n)
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
pred_offer_times_list = [15,20,30,40,50]
pred_instance_size = [50,50,50,50,50]

# %%
all_full_collections = [new_assortment_15,new_assortment_20,new_assortment_30,new_assortment_40,new_assortment_50]
all_full_offertimes = [new_offer_times_15,new_offer_times_20,new_offer_times_30,new_offer_times_40,new_offer_times_50]
full_collection_size = [len(new_offer_times_15),len(new_offer_times_20),len(new_offer_times_30),len(new_offer_times_40),len(new_offer_times_50)]

# %%
# full instance generation 
all_full_instances = []
for i in range(len(pred_offer_times_list)):
    
    full_instances_collection = []
    
    for j in range(pred_instance_size[i]):
        # generate true hev instance
        true_hev_instance = collection_distribution_hev(n-1,all_full_collections[i])
        full_instances_collection.append(true_hev_instance)

    
    all_full_instances.append(full_instances_collection)

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm_feasibility')
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    lam_values = [lam[i].x for i in range(data.shape[1])]
    lam_values = np.array(lam_values)

    if (model.objVal> 0):
        #model.write("mdmfeas_out.sol")
        #model.write("mdmfeas_model.lp") 
        return [1,model.Runtime,lam_values]
    else:
        #model.write("mdminfeas_model.lp")
        #return [0, used_time]
        return [0,model.Runtime,lam_values]

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.001

    model = gp.Model('mdm_limit')
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{i}_{j}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}")

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    if model.Status == GRB.OPTIMAL:
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
        
        lam_values = [lam[i].x for i in range(m)]
        lam_values = np.array(lam_values)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print('mdm limit computation error')
        #model.write("mdmlimit_out.sol")
        #model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,x_values]

# %%
## record the limit loss of all instances

all_mdm_rep = []
all_mdm_rep_time = []

all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_lam = []
all_mdm_limit_runtime = []

all_mdm_infeasible_index = []


for i in range(len(pred_offer_times_list)):
    
    ## define contrainer for mdm representability
    mdm_rep_collection = []
    mdm_rep_time_collection = []
    mdm_infeasible_index_collection = []
    
    ## define container for mdm limit 
    mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[]
    mdm_limit_lam_collection =[]
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        # data pre-process
        row_data = row_assortment_data(all_full_instances[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_full_instances[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_time_collection.append(curr_rep_result[1])
        
        # check if representable
        if curr_rep_result[0] > 0:
            print(f'instance offertimes {pred_offer_times_list[i]}, {j}th is representable by mdm with runtime {curr_rep_result[1]}')
            mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(curr_rep_result[1])
            mdm_limit_probability_collection.append(all_full_instances[i][j])
            mdm_limit_lam_collection.append(curr_rep_result[2])
        else:
            print(f'instance offertimes {pred_offer_times_list[i]}, {j}th is NOT representable by mdm')
            mdm_infeasible_index_collection.append(j)
            curr_limit_result = mdm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_probability_collection.append(curr_limit_result[-1])
            mdm_limit_runtime_collection.append(curr_limit_result[1])
            mdm_limit_lam_collection.append(curr_limit_result[2])
            print(f'mdm 1-norm loss is {curr_limit_result[0]} with run time {curr_limit_result[1]}')
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_time_collection) 
    all_mdm_infeasible_index.append(mdm_infeasible_index_collection)     
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection)
    all_mdm_limit_lam.append(mdm_limit_lam_collection)
# Out:
# testing instance with offertimes 15 : 0th
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# instance offertimes 15, 0th is NOT representable by mdm
# mdm 1-norm loss is 0.03353025000000054 with run time 0.12135505676269531
# testing instance with offertimes 15 : 1th
# instance offertimes 15, 1th is NOT representable by mdm
# mdm 1-norm loss is 0.6561809999999978 with run time 0.16983985900878906
# testing instance with offertimes 15 : 2th
# instance offertimes 15, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.045255359999999696 with run time 0.08512115478515625
# testing instance with offertimes 15 : 3th
# instance offertimes 15, 3th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.05291390419006348
# testing instance with offertimes 15 : 4th
# instance offertimes 15, 4th is representable by mdm with runtime 0.0002999305725097656
# testing instance with offertimes 15 : 5th
# instance offertimes 15, 5th is representable by mdm with runtime 0.00013303756713867188
# testing instance with offertimes 15 : 6th
# instance offertimes 15, 6th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.04943084716796875
# testing instance with offertimes 15 : 7th
# instance offertimes 15, 7th is NOT representable by mdm
# mdm 1-norm loss is 0.10677760000000056 with run time 0.13596391677856445
# testing instance with offertimes 15 : 8th
# instance offertimes 15, 8th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.07716512680053711
# testing instance with offertimes 15 : 9th
# instance offertimes 15, 9th is NOT representable by mdm
# mdm 1-norm loss is 0.046003650000000236 with run time 0.0898590087890625
# testing instance with offertimes 15 : 10th
# instance offertimes 15, 10th is NOT representable by mdm
# mdm 1-norm loss is 0.28057390000000015 with run time 0.15185999870300293
# testing instance with offertimes 15 : 11th
# instance offertimes 15, 11th is representable by mdm with runtime 0.00032711029052734375
# testing instance with offertimes 15 : 12th
# instance offertimes 15, 12th is NOT representable by mdm
# mdm 1-norm loss is 0.09834599999999859 with run time 0.12827515602111816
# testing instance with offertimes 15 : 13th
# instance offertimes 15, 13th is NOT representable by mdm
# mdm 1-norm loss is 0.07015329000000035 with run time 0.13060903549194336
# testing instance with offertimes 15 : 14th
# instance offertimes 15, 14th is representable by mdm with runtime 0.00030303001403808594
# testing instance with offertimes 15 : 15th
# instance offertimes 15, 15th is NOT representable by mdm
# mdm 1-norm loss is 0.00046100000000013144 with run time 0.0977940559387207
# testing instance with offertimes 15 : 16th
# instance offertimes 15, 16th is representable by mdm with runtime 0.0003838539123535156
# testing instance with offertimes 15 : 17th
# instance offertimes 15, 17th is NOT representable by mdm
# mdm 1-norm loss is 0.2561667100000012 with run time 0.0953209400177002
# testing instance with offertimes 15 : 18th
# instance offertimes 15, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.2232681000000003 with run time 0.10329890251159668
# testing instance with offertimes 15 : 19th
# instance offertimes 15, 19th is NOT representable by mdm
# mdm 1-norm loss is 0.0021626999999999072 with run time 0.09136390686035156
# testing instance with offertimes 15 : 20th
# instance offertimes 15, 20th is representable by mdm with runtime 0.00034999847412109375
# testing instance with offertimes 15 : 21th
# instance offertimes 15, 21th is representable by mdm with runtime 0.00013303756713867188
# testing instance with offertimes 15 : 22th
# instance offertimes 15, 22th is NOT representable by mdm
# mdm 1-norm loss is 0.0071483399999996144 with run time 0.10126614570617676
# testing instance with offertimes 15 : 23th
# instance offertimes 15, 23th is representable by mdm with runtime 0.00033402442932128906
# testing instance with offertimes 15 : 24th
# instance offertimes 15, 24th is NOT representable by mdm
# mdm 1-norm loss is 0.28383297000000496 with run time 0.0979909896850586
# testing instance with offertimes 15 : 25th
# instance offertimes 15, 25th is NOT representable by mdm
# mdm 1-norm loss is 0.003985200000000183 with run time 0.07981014251708984
# testing instance with offertimes 15 : 26th
# instance offertimes 15, 26th is NOT representable by mdm
# mdm 1-norm loss is 0.15841085999999954 with run time 0.20547795295715332
# testing instance with offertimes 15 : 27th
# instance offertimes 15, 27th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.04268908500671387
# testing instance with offertimes 15 : 28th
# instance offertimes 15, 28th is NOT representable by mdm
# mdm 1-norm loss is 0.05256947999999952 with run time 0.10878610610961914
# testing instance with offertimes 15 : 29th
# instance offertimes 15, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.3454692000000013 with run time 0.11987590789794922
# testing instance with offertimes 15 : 30th
# instance offertimes 15, 30th is representable by mdm with runtime 0.0003440380096435547
# testing instance with offertimes 15 : 31th
# instance offertimes 15, 31th is NOT representable by mdm
# mdm 1-norm loss is 0.006594559999999862 with run time 0.07339596748352051
# testing instance with offertimes 15 : 32th
# instance offertimes 15, 32th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.04651808738708496
# testing instance with offertimes 15 : 33th
# instance offertimes 15, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.08467038000000116 with run time 0.12077903747558594
# testing instance with offertimes 15 : 34th
# instance offertimes 15, 34th is representable by mdm with runtime 0.0003371238708496094
# testing instance with offertimes 15 : 35th
# instance offertimes 15, 35th is NOT representable by mdm
# mdm 1-norm loss is 0.016229100000000198 with run time 0.0939629077911377
# testing instance with offertimes 15 : 36th
# instance offertimes 15, 36th is representable by mdm with runtime 0.0002880096435546875
# testing instance with offertimes 15 : 37th
# instance offertimes 15, 37th is representable by mdm with runtime 0.00013017654418945312
# testing instance with offertimes 15 : 38th
# instance offertimes 15, 38th is NOT representable by mdm
# mdm 1-norm loss is 0.10666850000000122 with run time 0.11313915252685547
# testing instance with offertimes 15 : 39th
# instance offertimes 15, 39th is representable by mdm with runtime 0.0003910064697265625
# testing instance with offertimes 15 : 40th
# instance offertimes 15, 40th is representable by mdm with runtime 0.0001289844512939453
# testing instance with offertimes 15 : 41th
# instance offertimes 15, 41th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.04306483268737793
# testing instance with offertimes 15 : 42th
# instance offertimes 15, 42th is NOT representable by mdm
# mdm 1-norm loss is 0.00010431999999991958 with run time 0.08540892601013184
# testing instance with offertimes 15 : 43th
# instance offertimes 15, 43th is NOT representable by mdm
# mdm 1-norm loss is 0.20710249999999947 with run time 0.10529708862304688
# testing instance with offertimes 15 : 44th
# instance offertimes 15, 44th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.0481569766998291
# testing instance with offertimes 15 : 45th
# instance offertimes 15, 45th is representable by mdm with runtime 0.00045990943908691406
# testing instance with offertimes 15 : 46th
# instance offertimes 15, 46th is representable by mdm with runtime 0.00015592575073242188
# testing instance with offertimes 15 : 47th
# instance offertimes 15, 47th is NOT representable by mdm
# mdm 1-norm loss is 0.24185745000000053 with run time 0.12147307395935059
# testing instance with offertimes 15 : 48th
# instance offertimes 15, 48th is NOT representable by mdm
# mdm 1-norm loss is 0.06259500000000005 with run time 0.07797908782958984
# testing instance with offertimes 15 : 49th
# instance offertimes 15, 49th is representable by mdm with runtime 0.0002779960632324219
# testing instance with offertimes 20 : 0th
# instance offertimes 20, 0th is representable by mdm with runtime 0.00010991096496582031
# testing instance with offertimes 20 : 1th
# instance offertimes 20, 1th is representable by mdm with runtime 0.00016117095947265625
# testing instance with offertimes 20 : 2th
# instance offertimes 20, 2th is representable by mdm with runtime 0.00020194053649902344
# testing instance with offertimes 20 : 3th
# instance offertimes 20, 3th is representable by mdm with runtime 0.00017499923706054688
# testing instance with offertimes 20 : 4th
# instance offertimes 20, 4th is representable by mdm with runtime 0.00015401840209960938
# testing instance with offertimes 20 : 5th
# instance offertimes 20, 5th is representable by mdm with runtime 0.00015020370483398438
# testing instance with offertimes 20 : 6th
# instance offertimes 20, 6th is representable by mdm with runtime 0.00018596649169921875
# testing instance with offertimes 20 : 7th
# instance offertimes 20, 7th is representable by mdm with runtime 0.00014090538024902344
# testing instance with offertimes 20 : 8th
# instance offertimes 20, 8th is representable by mdm with runtime 9.894371032714844e-05
# testing instance with offertimes 20 : 9th
# instance offertimes 20, 9th is representable by mdm with runtime 0.00010800361633300781
# testing instance with offertimes 20 : 10th
# instance offertimes 20, 10th is representable by mdm with runtime 0.0001289844512939453
# testing instance with offertimes 20 : 11th
# instance offertimes 20, 11th is representable by mdm with runtime 9.489059448242188e-05
# testing instance with offertimes 20 : 12th
# instance offertimes 20, 12th is representable by mdm with runtime 9.584426879882812e-05
# testing instance with offertimes 20 : 13th
# instance offertimes 20, 13th is representable by mdm with runtime 0.00027489662170410156
# testing instance with offertimes 20 : 14th
# instance offertimes 20, 14th is representable by mdm with runtime 0.00013589859008789062
# testing instance with offertimes 20 : 15th
# instance offertimes 20, 15th is representable by mdm with runtime 0.0001049041748046875
# testing instance with offertimes 20 : 16th
# instance offertimes 20, 16th is representable by mdm with runtime 0.00015497207641601562
# testing instance with offertimes 20 : 17th
# instance offertimes 20, 17th is representable by mdm with runtime 0.00011301040649414062
# testing instance with offertimes 20 : 18th
# instance offertimes 20, 18th is representable by mdm with runtime 0.00010180473327636719
# testing instance with offertimes 20 : 19th
# instance offertimes 20, 19th is representable by mdm with runtime 0.00010800361633300781
# testing instance with offertimes 20 : 20th
# instance offertimes 20, 20th is representable by mdm with runtime 9.393692016601562e-05
# testing instance with offertimes 20 : 21th
# instance offertimes 20, 21th is representable by mdm with runtime 9.703636169433594e-05
# testing instance with offertimes 20 : 22th
# instance offertimes 20, 22th is representable by mdm with runtime 9.489059448242188e-05
# testing instance with offertimes 20 : 23th
# instance offertimes 20, 23th is representable by mdm with runtime 0.00010013580322265625
# testing instance with offertimes 20 : 24th
# instance offertimes 20, 24th is representable by mdm with runtime 9.489059448242188e-05
# testing instance with offertimes 20 : 25th
# instance offertimes 20, 25th is representable by mdm with runtime 9.202957153320312e-05
# testing instance with offertimes 20 : 26th
# instance offertimes 20, 26th is representable by mdm with runtime 0.0001690387725830078
# testing instance with offertimes 20 : 27th
# instance offertimes 20, 27th is representable by mdm with runtime 0.00013709068298339844
# testing instance with offertimes 20 : 28th
# instance offertimes 20, 28th is representable by mdm with runtime 0.00010204315185546875
# testing instance with offertimes 20 : 29th
# instance offertimes 20, 29th is representable by mdm with runtime 0.00022292137145996094
# testing instance with offertimes 20 : 30th
# instance offertimes 20, 30th is representable by mdm with runtime 0.0001251697540283203
# testing instance with offertimes 20 : 31th
# instance offertimes 20, 31th is representable by mdm with runtime 0.0001010894775390625
# testing instance with offertimes 20 : 32th
# instance offertimes 20, 32th is representable by mdm with runtime 9.918212890625e-05
# testing instance with offertimes 20 : 33th
# instance offertimes 20, 33th is representable by mdm with runtime 9.512901306152344e-05
# testing instance with offertimes 20 : 34th
# instance offertimes 20, 34th is representable by mdm with runtime 0.00010800361633300781
# testing instance with offertimes 20 : 35th
# instance offertimes 20, 35th is representable by mdm with runtime 0.00013399124145507812
# testing instance with offertimes 20 : 36th
# instance offertimes 20, 36th is representable by mdm with runtime 9.608268737792969e-05
# testing instance with offertimes 20 : 37th
# instance offertimes 20, 37th is representable by mdm with runtime 0.00010704994201660156
# testing instance with offertimes 20 : 38th
# instance offertimes 20, 38th is representable by mdm with runtime 0.00013709068298339844
# testing instance with offertimes 20 : 39th
# instance offertimes 20, 39th is representable by mdm with runtime 0.00019097328186035156
# testing instance with offertimes 20 : 40th
# instance offertimes 20, 40th is representable by mdm with runtime 0.00013399124145507812
# testing instance with offertimes 20 : 41th
# instance offertimes 20, 41th is representable by mdm with runtime 0.00013685226440429688
# testing instance with offertimes 20 : 42th
# instance offertimes 20, 42th is representable by mdm with runtime 0.00015401840209960938
# testing instance with offertimes 20 : 43th
# instance offertimes 20, 43th is representable by mdm with runtime 0.00011396408081054688
# testing instance with offertimes 20 : 44th
# instance offertimes 20, 44th is representable by mdm with runtime 0.00010800361633300781
# testing instance with offertimes 20 : 45th
# instance offertimes 20, 45th is representable by mdm with runtime 9.799003601074219e-05
# testing instance with offertimes 20 : 46th
# instance offertimes 20, 46th is representable by mdm with runtime 9.703636169433594e-05
# testing instance with offertimes 20 : 47th
# instance offertimes 20, 47th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.013906002044677734
# testing instance with offertimes 20 : 48th
# instance offertimes 20, 48th is NOT representable by mdm
# mdm 1-norm loss is 0.24973599999999985 with run time 0.029460906982421875
# testing instance with offertimes 20 : 49th
# instance offertimes 20, 49th is representable by mdm with runtime 0.00024700164794921875
# testing instance with offertimes 30 : 0th
# instance offertimes 30, 0th is representable by mdm with runtime 0.00014901161193847656
# testing instance with offertimes 30 : 1th
# instance offertimes 30, 1th is representable by mdm with runtime 0.00012993812561035156
# testing instance with offertimes 30 : 2th
# instance offertimes 30, 2th is representable by mdm with runtime 9.989738464355469e-05
# testing instance with offertimes 30 : 3th
# instance offertimes 30, 3th is representable by mdm with runtime 0.00014090538024902344
# testing instance with offertimes 30 : 4th
# instance offertimes 30, 4th is representable by mdm with runtime 0.00012111663818359375
# testing instance with offertimes 30 : 5th
# instance offertimes 30, 5th is representable by mdm with runtime 0.00014281272888183594
# testing instance with offertimes 30 : 6th
# instance offertimes 30, 6th is representable by mdm with runtime 0.000102996826171875
# testing instance with offertimes 30 : 7th
# instance offertimes 30, 7th is representable by mdm with runtime 9.512901306152344e-05
# testing instance with offertimes 30 : 8th
# instance offertimes 30, 8th is representable by mdm with runtime 9.298324584960938e-05
# testing instance with offertimes 30 : 9th
# instance offertimes 30, 9th is representable by mdm with runtime 8.702278137207031e-05
# testing instance with offertimes 30 : 10th
# instance offertimes 30, 10th is representable by mdm with runtime 8.916854858398438e-05
# testing instance with offertimes 30 : 11th
# instance offertimes 30, 11th is representable by mdm with runtime 8.487701416015625e-05
# testing instance with offertimes 30 : 12th
# instance offertimes 30, 12th is representable by mdm with runtime 8.392333984375e-05
# testing instance with offertimes 30 : 13th
# instance offertimes 30, 13th is representable by mdm with runtime 0.00011682510375976562
# testing instance with offertimes 30 : 14th
# instance offertimes 30, 14th is representable by mdm with runtime 0.00013399124145507812
# testing instance with offertimes 30 : 15th
# instance offertimes 30, 15th is representable by mdm with runtime 0.00011205673217773438
# testing instance with offertimes 30 : 16th
# instance offertimes 30, 16th is representable by mdm with runtime 0.00013899803161621094
# testing instance with offertimes 30 : 17th
# instance offertimes 30, 17th is representable by mdm with runtime 0.00012612342834472656
# testing instance with offertimes 30 : 18th
# instance offertimes 30, 18th is representable by mdm with runtime 9.894371032714844e-05
# testing instance with offertimes 30 : 19th
# instance offertimes 30, 19th is representable by mdm with runtime 9.489059448242188e-05
# testing instance with offertimes 30 : 20th
# instance offertimes 30, 20th is representable by mdm with runtime 8.606910705566406e-05
# testing instance with offertimes 30 : 21th
# instance offertimes 30, 21th is representable by mdm with runtime 8.392333984375e-05
# testing instance with offertimes 30 : 22th
# instance offertimes 30, 22th is representable by mdm with runtime 8.106231689453125e-05
# testing instance with offertimes 30 : 23th
# instance offertimes 30, 23th is representable by mdm with runtime 8.58306884765625e-05
# testing instance with offertimes 30 : 24th
# instance offertimes 30, 24th is representable by mdm with runtime 8.606910705566406e-05
# testing instance with offertimes 30 : 25th
# instance offertimes 30, 25th is representable by mdm with runtime 8.606910705566406e-05
# testing instance with offertimes 30 : 26th
# instance offertimes 30, 26th is representable by mdm with runtime 8.511543273925781e-05
# testing instance with offertimes 30 : 27th
# instance offertimes 30, 27th is representable by mdm with runtime 0.00019979476928710938
# testing instance with offertimes 30 : 28th
# instance offertimes 30, 28th is representable by mdm with runtime 0.0001621246337890625
# testing instance with offertimes 30 : 29th
# instance offertimes 30, 29th is representable by mdm with runtime 0.00011301040649414062
# testing instance with offertimes 30 : 30th
# instance offertimes 30, 30th is representable by mdm with runtime 0.00014901161193847656
# testing instance with offertimes 30 : 31th
# instance offertimes 30, 31th is representable by mdm with runtime 0.00014400482177734375
# testing instance with offertimes 30 : 32th
# instance offertimes 30, 32th is representable by mdm with runtime 0.0001621246337890625
# testing instance with offertimes 30 : 33th
# instance offertimes 30, 33th is representable by mdm with runtime 0.0001289844512939453
# testing instance with offertimes 30 : 34th
# instance offertimes 30, 34th is representable by mdm with runtime 0.00011110305786132812
# testing instance with offertimes 30 : 35th
# instance offertimes 30, 35th is representable by mdm with runtime 0.00014591217041015625
# testing instance with offertimes 30 : 36th
# instance offertimes 30, 36th is representable by mdm with runtime 0.0001437664031982422
# testing instance with offertimes 30 : 37th
# instance offertimes 30, 37th is representable by mdm with runtime 0.00017380714416503906
# testing instance with offertimes 30 : 38th
# instance offertimes 30, 38th is representable by mdm with runtime 0.00011014938354492188
# testing instance with offertimes 30 : 39th
# instance offertimes 30, 39th is representable by mdm with runtime 0.00016307830810546875
# testing instance with offertimes 30 : 40th
# instance offertimes 30, 40th is representable by mdm with runtime 0.00012302398681640625
# testing instance with offertimes 30 : 41th
# instance offertimes 30, 41th is representable by mdm with runtime 9.489059448242188e-05
# testing instance with offertimes 30 : 42th
# instance offertimes 30, 42th is NOT representable by mdm
# mdm 1-norm loss is 1.2707999999999993 with run time 0.025640010833740234
# testing instance with offertimes 30 : 43th
# instance offertimes 30, 43th is representable by mdm with runtime 0.0003249645233154297
# testing instance with offertimes 30 : 44th
# instance offertimes 30, 44th is representable by mdm with runtime 0.0001399517059326172
# testing instance with offertimes 30 : 45th
# instance offertimes 30, 45th is representable by mdm with runtime 0.0001938343048095703
# testing instance with offertimes 30 : 46th
# instance offertimes 30, 46th is representable by mdm with runtime 9.393692016601562e-05
# testing instance with offertimes 30 : 47th
# instance offertimes 30, 47th is representable by mdm with runtime 9.512901306152344e-05
# testing instance with offertimes 30 : 48th
# instance offertimes 30, 48th is representable by mdm with runtime 8.487701416015625e-05
# testing instance with offertimes 30 : 49th
# instance offertimes 30, 49th is representable by mdm with runtime 9.703636169433594e-05
# testing instance with offertimes 40 : 0th
# instance offertimes 40, 0th is representable by mdm with runtime 8.58306884765625e-05
# testing instance with offertimes 40 : 1th
# instance offertimes 40, 1th is representable by mdm with runtime 0.00010991096496582031
# testing instance with offertimes 40 : 2th
# instance offertimes 40, 2th is representable by mdm with runtime 0.00010776519775390625
# testing instance with offertimes 40 : 3th
# instance offertimes 40, 3th is representable by mdm with runtime 0.0001239776611328125
# testing instance with offertimes 40 : 4th
# instance offertimes 40, 4th is representable by mdm with runtime 8.0108642578125e-05
# testing instance with offertimes 40 : 5th
# instance offertimes 40, 5th is representable by mdm with runtime 9.393692016601562e-05
# testing instance with offertimes 40 : 6th
# instance offertimes 40, 6th is representable by mdm with runtime 0.0001671314239501953
# testing instance with offertimes 40 : 7th
# instance offertimes 40, 7th is representable by mdm with runtime 0.0001049041748046875
# testing instance with offertimes 40 : 8th
# instance offertimes 40, 8th is representable by mdm with runtime 8.893013000488281e-05
# testing instance with offertimes 40 : 9th
# instance offertimes 40, 9th is representable by mdm with runtime 0.0001308917999267578
# testing instance with offertimes 40 : 10th
# instance offertimes 40, 10th is representable by mdm with runtime 8.606910705566406e-05
# testing instance with offertimes 40 : 11th
# instance offertimes 40, 11th is representable by mdm with runtime 9.584426879882812e-05
# testing instance with offertimes 40 : 12th
# instance offertimes 40, 12th is representable by mdm with runtime 7.915496826171875e-05
# testing instance with offertimes 40 : 13th
# instance offertimes 40, 13th is representable by mdm with runtime 0.0001049041748046875
# testing instance with offertimes 40 : 14th
# instance offertimes 40, 14th is representable by mdm with runtime 7.987022399902344e-05
# testing instance with offertimes 40 : 15th
# instance offertimes 40, 15th is representable by mdm with runtime 7.605552673339844e-05
# testing instance with offertimes 40 : 16th
# instance offertimes 40, 16th is representable by mdm with runtime 7.605552673339844e-05
# testing instance with offertimes 40 : 17th
# instance offertimes 40, 17th is representable by mdm with runtime 7.486343383789062e-05
# testing instance with offertimes 40 : 18th
# instance offertimes 40, 18th is representable by mdm with runtime 7.700920104980469e-05
# testing instance with offertimes 40 : 19th
# instance offertimes 40, 19th is representable by mdm with runtime 7.796287536621094e-05
# testing instance with offertimes 40 : 20th
# instance offertimes 40, 20th is representable by mdm with runtime 0.0001201629638671875
# testing instance with offertimes 40 : 21th
# instance offertimes 40, 21th is representable by mdm with runtime 7.891654968261719e-05
# testing instance with offertimes 40 : 22th
# instance offertimes 40, 22th is representable by mdm with runtime 8.416175842285156e-05
# testing instance with offertimes 40 : 23th
# instance offertimes 40, 23th is representable by mdm with runtime 0.00010609626770019531
# testing instance with offertimes 40 : 24th
# instance offertimes 40, 24th is representable by mdm with runtime 0.0001277923583984375
# testing instance with offertimes 40 : 25th
# instance offertimes 40, 25th is representable by mdm with runtime 0.00011396408081054688
# testing instance with offertimes 40 : 26th
# instance offertimes 40, 26th is representable by mdm with runtime 8.0108642578125e-05
# testing instance with offertimes 40 : 27th
# instance offertimes 40, 27th is representable by mdm with runtime 0.00015997886657714844
# testing instance with offertimes 40 : 28th
# instance offertimes 40, 28th is representable by mdm with runtime 0.00013518333435058594
# testing instance with offertimes 40 : 29th
# instance offertimes 40, 29th is representable by mdm with runtime 0.00012803077697753906
# testing instance with offertimes 40 : 30th
# instance offertimes 40, 30th is representable by mdm with runtime 0.00011706352233886719
# testing instance with offertimes 40 : 31th
# instance offertimes 40, 31th is representable by mdm with runtime 0.00011706352233886719
# testing instance with offertimes 40 : 32th
# instance offertimes 40, 32th is representable by mdm with runtime 8.702278137207031e-05
# testing instance with offertimes 40 : 33th
# instance offertimes 40, 33th is representable by mdm with runtime 7.605552673339844e-05
# testing instance with offertimes 40 : 34th
# instance offertimes 40, 34th is representable by mdm with runtime 0.00011801719665527344
# testing instance with offertimes 40 : 35th
# instance offertimes 40, 35th is representable by mdm with runtime 7.891654968261719e-05
# testing instance with offertimes 40 : 36th
# instance offertimes 40, 36th is representable by mdm with runtime 7.581710815429688e-05
# testing instance with offertimes 40 : 37th
# instance offertimes 40, 37th is representable by mdm with runtime 7.510185241699219e-05
# testing instance with offertimes 40 : 38th
# instance offertimes 40, 38th is representable by mdm with runtime 7.486343383789062e-05
# testing instance with offertimes 40 : 39th
# instance offertimes 40, 39th is representable by mdm with runtime 7.414817810058594e-05
# testing instance with offertimes 40 : 40th
# instance offertimes 40, 40th is representable by mdm with runtime 9.083747863769531e-05
# testing instance with offertimes 40 : 41th
# instance offertimes 40, 41th is representable by mdm with runtime 0.0001289844512939453
# testing instance with offertimes 40 : 42th
# instance offertimes 40, 42th is representable by mdm with runtime 0.00011205673217773438
# testing instance with offertimes 40 : 43th
# instance offertimes 40, 43th is representable by mdm with runtime 0.00011396408081054688
# testing instance with offertimes 40 : 44th
# instance offertimes 40, 44th is representable by mdm with runtime 0.0001659393310546875
# testing instance with offertimes 40 : 45th
# instance offertimes 40, 45th is representable by mdm with runtime 0.00012302398681640625
# testing instance with offertimes 40 : 46th
# instance offertimes 40, 46th is representable by mdm with runtime 0.00010204315185546875
# testing instance with offertimes 40 : 47th
# instance offertimes 40, 47th is representable by mdm with runtime 8.20159912109375e-05
# testing instance with offertimes 40 : 48th
# instance offertimes 40, 48th is representable by mdm with runtime 7.891654968261719e-05
# testing instance with offertimes 40 : 49th
# instance offertimes 40, 49th is representable by mdm with runtime 7.700920104980469e-05
# testing instance with offertimes 50 : 0th
# instance offertimes 50, 0th is representable by mdm with runtime 0.00010895729064941406
# testing instance with offertimes 50 : 1th
# instance offertimes 50, 1th is representable by mdm with runtime 7.009506225585938e-05
# testing instance with offertimes 50 : 2th
# instance offertimes 50, 2th is representable by mdm with runtime 7.009506225585938e-05
# testing instance with offertimes 50 : 3th
# instance offertimes 50, 3th is representable by mdm with runtime 6.794929504394531e-05
# testing instance with offertimes 50 : 4th
# instance offertimes 50, 4th is representable by mdm with runtime 6.699562072753906e-05
# testing instance with offertimes 50 : 5th
# instance offertimes 50, 5th is representable by mdm with runtime 6.985664367675781e-05
# testing instance with offertimes 50 : 6th
# instance offertimes 50, 6th is representable by mdm with runtime 6.794929504394531e-05
# testing instance with offertimes 50 : 7th
# instance offertimes 50, 7th is representable by mdm with runtime 9.202957153320312e-05
# testing instance with offertimes 50 : 8th
# instance offertimes 50, 8th is representable by mdm with runtime 7.796287536621094e-05
# testing instance with offertimes 50 : 9th
# instance offertimes 50, 9th is representable by mdm with runtime 6.985664367675781e-05
# testing instance with offertimes 50 : 10th
# instance offertimes 50, 10th is representable by mdm with runtime 7.891654968261719e-05
# testing instance with offertimes 50 : 11th
# instance offertimes 50, 11th is representable by mdm with runtime 0.00013208389282226562
# testing instance with offertimes 50 : 12th
# instance offertimes 50, 12th is representable by mdm with runtime 9.703636169433594e-05
# testing instance with offertimes 50 : 13th
# instance offertimes 50, 13th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 14th
# instance offertimes 50, 14th is representable by mdm with runtime 6.818771362304688e-05
# testing instance with offertimes 50 : 15th
# instance offertimes 50, 15th is representable by mdm with runtime 0.000102996826171875
# testing instance with offertimes 50 : 16th
# instance offertimes 50, 16th is representable by mdm with runtime 0.0001239776611328125
# testing instance with offertimes 50 : 17th
# instance offertimes 50, 17th is representable by mdm with runtime 8.606910705566406e-05
# testing instance with offertimes 50 : 18th
# instance offertimes 50, 18th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 19th
# instance offertimes 50, 19th is representable by mdm with runtime 8.58306884765625e-05
# testing instance with offertimes 50 : 20th
# instance offertimes 50, 20th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 21th
# instance offertimes 50, 21th is representable by mdm with runtime 7.987022399902344e-05
# testing instance with offertimes 50 : 22th
# instance offertimes 50, 22th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 23th
# instance offertimes 50, 23th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 24th
# instance offertimes 50, 24th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 25th
# instance offertimes 50, 25th is representable by mdm with runtime 6.914138793945312e-05
# testing instance with offertimes 50 : 26th
# instance offertimes 50, 26th is representable by mdm with runtime 6.699562072753906e-05
# testing instance with offertimes 50 : 27th
# instance offertimes 50, 27th is representable by mdm with runtime 6.794929504394531e-05
# testing instance with offertimes 50 : 28th
# instance offertimes 50, 28th is representable by mdm with runtime 6.818771362304688e-05
# testing instance with offertimes 50 : 29th
# instance offertimes 50, 29th is representable by mdm with runtime 6.699562072753906e-05
# testing instance with offertimes 50 : 30th
# instance offertimes 50, 30th is representable by mdm with runtime 7.104873657226562e-05
# testing instance with offertimes 50 : 31th
# instance offertimes 50, 31th is representable by mdm with runtime 9.894371032714844e-05
# testing instance with offertimes 50 : 32th
# instance offertimes 50, 32th is representable by mdm with runtime 0.0002269744873046875
# testing instance with offertimes 50 : 33th
# instance offertimes 50, 33th is representable by mdm with runtime 0.00010895729064941406
# testing instance with offertimes 50 : 34th
# instance offertimes 50, 34th is representable by mdm with runtime 7.510185241699219e-05
# testing instance with offertimes 50 : 35th
# instance offertimes 50, 35th is representable by mdm with runtime 7.104873657226562e-05
# testing instance with offertimes 50 : 36th
# instance offertimes 50, 36th is representable by mdm with runtime 0.00011897087097167969
# testing instance with offertimes 50 : 37th
# instance offertimes 50, 37th is representable by mdm with runtime 0.00012803077697753906
# testing instance with offertimes 50 : 38th
# instance offertimes 50, 38th is representable by mdm with runtime 8.0108642578125e-05
# testing instance with offertimes 50 : 39th
# instance offertimes 50, 39th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 40th
# instance offertimes 50, 40th is representable by mdm with runtime 7.796287536621094e-05
# testing instance with offertimes 50 : 41th
# instance offertimes 50, 41th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 42th
# instance offertimes 50, 42th is representable by mdm with runtime 7.009506225585938e-05
# testing instance with offertimes 50 : 43th
# instance offertimes 50, 43th is representable by mdm with runtime 7.009506225585938e-05
# testing instance with offertimes 50 : 44th
# instance offertimes 50, 44th is representable by mdm with runtime 6.699562072753906e-05
# testing instance with offertimes 50 : 45th
# instance offertimes 50, 45th is representable by mdm with runtime 6.699562072753906e-05
# testing instance with offertimes 50 : 46th
# instance offertimes 50, 46th is representable by mdm with runtime 6.604194641113281e-05
# testing instance with offertimes 50 : 47th
# instance offertimes 50, 47th is representable by mdm with runtime 6.580352783203125e-05
# testing instance with offertimes 50 : 48th
# instance offertimes 50, 48th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 49th
# instance offertimes 50, 49th is representable by mdm with runtime 8.20159912109375e-05

# %%
# Out:
# [30, 21, 16, 11, 7]

# %%
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep[i]})
    df_mdm_rep.to_csv('mdm/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
mdm_feasible_proportion_list = [np.sum(all_mdm_rep[x])/len(all_mdm_rep[x]) for x in range(len(pred_offer_times_list)) ]
mdm_rep_time_mean = [np.mean(all_mdm_rep_time[x]) for x in range(len(pred_offer_times_list)) ]
mdm_rep_time_se = [ np.std(all_mdm_rep_time[x])/np.sqrt(len(all_mdm_rep_time[x])) for x in range(len(pred_offer_times_list))  ]
mdm_rep_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                'mdm_rep':mdm_feasible_proportion_list,'mdm_rep_time':mdm_rep_time_mean,'mdm_rep_time_se':mdm_rep_time_se})
mdm_rep_summary.to_csv('mdm/mdm_rep_summary_hev_no_outside.csv')
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se
# 0          15               30     0.34      0.000661         0.000312
# 1          20               21     0.96      0.000133         0.000006
# 2          30               16     0.98      0.000126         0.000007
# 3          40               11     1.00      0.000100         0.000004
# 4          50                7     1.00      0.000083         0.000004

# %%
# save infeasibe indices 
for i in range(len(pred_offer_times_list)):
    df_mdm_rep_infeas = pd.DataFrame(all_mdm_infeasible_index[i])
    df_mdm_rep_infeas.to_csv('mdm/rep_infeasibility/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save 1norm loss 
mdm_1norm_loss_mean = [np.mean(all_mdm_limit_loss[x]) for x in range(len(pred_offer_times_list)) ]
mdm_1norm_loss_se = [ np.std(all_mdm_limit_loss[x])/np.sqrt(len(all_mdm_limit_loss[x])) for x in range(len(pred_offer_times_list)) ]

mdm_1norm_time_mean = [np.mean(all_mdm_limit_runtime[x]) for x in range(len(pred_offer_times_list)) ]
mdm_1norm_time_se = [ np.std(all_mdm_limit_runtime[x])/np.sqrt(len(all_mdm_limit_runtime[x])) for x in range(len(pred_offer_times_list)) ]

df_mdm_1norm_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'mdm_1norm_loss':mdm_1norm_loss_mean, 'mdm_1norm_loss_se':mdm_1norm_loss_se,
                                'mdm_1norm_time':mdm_1norm_time_mean, 'mdm_1norm_time_se':mdm_1norm_time_se,
                                  })
df_mdm_1norm_loss.to_csv('mdm/mdm_1norm_loss_summary_hev_no_outside.csv')
df_mdm_1norm_loss
# Out:
#    offertimes  collection_size  mdm_1norm_loss  mdm_1norm_loss_se  \
# 0          15               30        0.067922           0.017634
# 1          20               21        0.004995           0.004945
# 2          30               16        0.025416           0.025161
# 3          40               11        0.000000           0.000000
# 4          50                7        0.000000           0.000000
#
#    mdm_1norm_time  mdm_1norm_time_se
# 0        0.065400           0.007813
# 1        0.000993           0.000637
# 2        0.000633           0.000505
# 3        0.000100           0.000004
# 4        0.000083           0.000004

# %%
# save 1norm loss:
for i in range(len(pred_offer_times_list)):
    df_mdm_1norm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_1norm_loss':all_mdm_limit_loss[i],'mdm_1norm_runtime':all_mdm_limit_runtime[i]})
    df_mdm_1norm_loss.to_csv('mdm/limit_loss/1norm/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save 1norm solution: limit probability and lambdas for kl
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_prob = pd.DataFrame(all_mdm_limit_prob[i][j])
        df_lam = pd.DataFrame(all_mdm_limit_lam[i][j])
        df_prob.to_csv('mdm/limit_prob/1norm/offertimes'+str(pred_offer_times_list[i])+'/prob'+str(j)+'.csv')
        df_lam.to_csv('mdm/lamda_1norm/offertimes'+str(pred_offer_times_list[i])+'/lam'+str(j)+'.csv')

# %%
import pyomo.environ as pyo
from pyomo.environ import *

# %%
def mdm_kl_w_lam(lam,data,collection,offertimes):
    
    n, m = data.shape
    
    ind = [[] for i in range(n)]  ## keeps track of the assortments including product i

    for i in range(len(collection)):
        for j in collection[i]:
            ind[j].append(i)  ## assortment i includes product j
    
    model = pyo.ConcreteModel()
    model.x = pyo.Var(range(n), range(m), domain= pyo.NonNegativeReals)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            if j not in collection[i]:
                model.norm_constraint.add(model.x[j, i] == 0)
    
    model.mdm_constraint = pyo.ConstraintList()
    for i in range(n):
        for j in range(len(ind[i]) - 1):
            for k in range(j + 1, len(ind[i])):
                if lam[ind[i][j]] >= lam[ind[i][k]]:
                    model.mdm_constraint.add(model.x[i, ind[i][k]] - model.x[i, ind[i][j]]  >= 0)
                if lam[ind[i][j]] <= lam[ind[i][k]]:
                    model.mdm_constraint.add(model.x[i, ind[i][j]] - model.x[i, ind[i][k]]  >= 0)
    
    model.obj = pyo.Objective(expr= -sum( sum(offertimes[j] *data[i, j] * pyo.log(model.x[i, j]) for i in collection[j]) for j in range(m)),sense=pyo.minimize)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    
    try:
        # Your optimization solve code here
        results = solver.solve(model,tee=True)
        status = str(results.solver.status)
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            print("Solver found a solution.")
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            return [pyo.value(model.obj), x_values, results.solver.time]
        
        elif results.solver.status == pyo.SolverStatus.warning:
            print("Solver issued a warning.")
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            return [pyo.value(model.obj), x_values, results.solver.time]
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")
    
    except ValueError as e:
        print(f"Error: {e}")

# %%
def deterministic_term(data,offertimes):
    dt = 0 
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            if data[i][j] >0:
                dt = dt + offertimes[j]*data[i][j]*np.log(data[i][j])
    return dt,dt/np.sum(offertimes)

# %%
all_mdm_kl_loss = []
all_mdm_avg_kl_loss = []
all_mdm_kl_prob = []
all_mdm_2stage_time = []

all_dt = []
all_avg_dt = []

all_total_time = []

for i in range(len(pred_offer_times_list)):
    
    mdm_kl_loss_collection = []
    mdm_avg_kl_loss_collection = []
    dt_collection = []
    avg_dt_collection = []
    mdm_kl_prob_collection = []
    mdm_2stage_time_collection = []
    total_time_collection = []
    
    for j in range(pred_instance_size[i]):
        
        if all_mdm_rep[i][j] <1:
            # mdm non-representable instance (i,j)
            result = mdm_kl_w_lam(all_mdm_limit_lam[i][j],all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            
            dt,avg_dt = deterministic_term(all_full_instances[i][j],all_full_offertimes[i])
            
            dt_collection.append(dt)
            avg_dt_collection.append(avg_dt)
            
            mdm_kl_loss_collection.append(result[0]+dt)
            mdm_avg_kl_loss_collection.append(result[0]/np.sum(all_full_offertimes[i])+avg_dt)
            
            mdm_kl_prob_collection.append(result[1])
            mdm_2stage_time_collection.append(result[-1])
            
            total_time_collection.append(result[-1] + all_mdm_limit_runtime[i][j])
        else:
            # mdm representable instances (i,j)
            mdm_kl_loss_collection.append(0)
            mdm_avg_kl_loss_collection.append(0)
            mdm_kl_prob_collection.append(all_full_instances[i][j])
            total_time_collection.append(all_mdm_rep_time[i][j])

    all_mdm_kl_loss.append(mdm_kl_loss_collection) 
    all_mdm_avg_kl_loss.append(mdm_avg_kl_loss_collection)
    all_mdm_kl_prob.append(mdm_kl_prob_collection)
    all_total_time.append(total_time_collection)
        
    all_dt.append(dt_collection)
    all_avg_dt.append(avg_dt_collection)
# Out:
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 2.07e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.2225667e+03 9.64e-01 2.20e+04  -1.0 9.15e-01    -  1.20e-02 1.64e-02f  1
#    2  6.2171794e+03 9.64e-01 2.20e+04  -1.0 9.17e-01    -  3.66e-02 2.09e-04f  1
#    3  6.1423010e+03 9.61e-01 2.19e+04  -1.0 9.11e-01    -  1.80e-02 2.77e-03f  1
#    4  6.0693754e+03 9.58e-01 2.19e+04  -1.0 8.96e-01    -  9.55e-03 2.78e-03f  1
#    5  6.0137538e+03 9.57e-01 2.18e+04  -1.0 8.48e-01    -  2.26e-02 1.98e-03f  1
#    6  5.9399075e+03 9.54e-01 2.18e+04  -1.0 8.80e-01    -  1.44e-02 2.34e-03f  1
#    7  5.8295344e+03 9.51e-01 2.19e+04  -1.0 8.56e-01    -  2.84e-03 3.11e-03f  1
#    8  5.6806434e+03 9.47e-01 2.21e+04  -1.0 8.80e-01    -  4.97e-05 4.54e-03f  1
#    9  5.5387825e+03 9.42e-01 2.21e+04  -1.0 9.33e-01    -  4.50e-03 4.98e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.4290949e+03 9.38e-01 2.21e+04  -1.0 1.02e+00    -  7.01e-03 4.19e-03f  1
#   11  5.4028035e+03 9.37e-01 2.20e+04  -1.0 1.05e+00    -  1.33e-02 1.04e-03f  1
#   12  5.2743456e+03 9.32e-01 2.20e+04  -1.0 1.01e+00    -  3.64e-03 5.33e-03f  1
#   13  5.2707184e+03 9.32e-01 2.20e+04  -1.0 7.68e-01    -  8.50e-03 1.52e-04f  1
#   14  5.0489432e+03 9.23e-01 2.21e+04  -1.0 7.29e-01    -  5.38e-03 1.00e-02f  1
#   15  4.9328414e+03 9.17e-01 2.21e+04  -1.0 7.12e-01    -  5.40e-03 5.99e-03f  1
#   16  4.9251348e+03 9.17e-01 2.21e+04  -1.0 6.70e-01    -  5.72e-04 4.07e-04f  1
#   17  4.9058747e+03 9.16e-01 2.20e+04  -1.0 6.78e-01    -  2.08e-02 1.02e-03f  1
#   18  4.8401842e+03 9.13e-01 2.20e+04  -1.0 6.88e-01    -  1.29e-03 3.50e-03f  1
#   19  4.8377594e+03 9.13e-01 2.20e+04  -1.0 6.54e-01    -  3.59e-03 1.27e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  4.7270124e+03 9.07e-01 2.19e+04  -1.0 7.79e-01    -  8.54e-05 6.12e-03f  1
#   21  4.6859433e+03 9.05e-01 2.18e+04  -1.0 9.78e-01    -  3.80e-03 2.48e-03f  1
#   22  4.1812006e+03 8.71e-01 2.15e+04  -1.0 9.79e-01    -  8.08e-03 3.75e-02f  1
#   23  3.4108955e+03 7.90e-01 2.04e+04  -1.0 9.22e-01    -  4.75e-02 9.31e-02f  1
#   24  2.5285019e+03 6.25e-01 1.69e+04  -1.0 8.30e-01    -  2.32e-02 2.08e-01f  1
#   25  1.8021617e+03 3.91e-01 1.09e+04  -1.0 6.57e-01    -  3.37e-01 3.75e-01f  1
#   26  1.5411072e+03 2.73e-01 7.62e+03  -1.0 4.08e-01    -  2.54e-01 3.00e-01f  1
#   27  1.4626365e+03 2.34e-01 6.53e+03  -1.0 2.82e-01    -  2.34e-01 1.43e-01f  1
#   28  1.3248424e+03 1.60e-01 4.46e+03  -1.0 2.44e-01    -  7.17e-02 3.18e-01f  1
#   29  1.3003797e+03 1.47e-01 4.09e+03  -1.0 1.60e-01    -  1.45e-01 8.25e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.2382188e+03 1.11e-01 3.09e+03  -1.0 1.52e-01    -  1.43e-01 2.46e-01f  1
#   31  1.2172000e+03 9.90e-02 2.76e+03  -1.0 1.09e-01    -  8.48e-02 1.05e-01f  1
#   32  1.1635137e+03 7.01e-02 2.36e+03  -1.0 9.34e-02    -  1.17e-01 2.92e-01f  1
#   33  1.1105431e+03 4.27e-02 1.90e+03  -1.0 8.58e-02    -  2.42e-01 3.91e-01f  1
#   34  1.0425041e+03 1.06e-02 1.76e+03  -1.0 1.12e-01    -  2.68e-01 7.53e-01f  1
#   35  1.0006883e+03 1.05e-04 1.71e+03  -1.0 1.60e-01    -  3.16e-01 9.90e-01h  1
#   36  9.6949303e+02 7.56e-08 3.78e+04  -1.0 1.67e-01    -  5.92e-01 9.99e-01h  1
#   37  9.3658123e+02 1.88e-08 2.86e+06  -1.0 2.73e-01    -  4.43e-01 7.51e-01f  1
#   38  9.2074330e+02 9.11e-09 4.08e+06  -1.0 1.76e-01    -  4.68e-02 5.16e-01f  1
#   39  9.1177654e+02 5.53e-09 3.39e+06  -1.0 1.54e-01    -  2.28e-01 3.92e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.0118691e+02 3.52e-09 2.38e+06  -1.0 1.80e-01    -  3.12e-01 3.65e-01f  1
#   41  8.8387258e+02 1.74e-09 2.15e+06  -1.0 2.48e-01    -  1.78e-01 5.04e-01f  1
#   42  8.7723571e+02 7.76e-10 1.77e+06  -1.0 1.64e-01    -  2.23e-01 5.55e-01f  1
#   43  8.7592296e+02 1.02e-10 6.50e+05  -1.0 8.75e-02    -  6.49e-01 8.69e-01f  1
#   44  8.7596938e+02 2.22e-16 3.70e+00  -1.0 1.42e-02    -  1.00e+00 1.00e+00f  1
#   45  8.7516075e+02 2.22e-16 2.96e+06  -5.7 4.04e-02    -  7.04e-01 1.00e+00f  1
#   46  8.7496868e+02 2.22e-16 6.65e+05  -5.7 2.15e-02    -  7.75e-01 1.00e+00f  1
#   47  8.7492779e+02 2.22e-16 1.18e+05  -5.7 1.24e-02    -  8.23e-01 1.00e+00f  1
#   48  8.7491967e+02 2.22e-16 2.02e+04  -5.7 6.53e-03    -  8.28e-01 1.00e+00f  1
#   49  8.7491812e+02 2.22e-16 1.44e+03  -5.7 2.90e-03    -  9.29e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  8.7491783e+02 2.22e-16 1.30e+02  -5.7 1.20e-03    -  9.10e-01 1.00e+00f  1
#   51  8.7491779e+02 1.11e-16 2.43e-05  -5.7 3.01e-04    -  1.00e+00 1.00e+00f  1
#   52  8.7491779e+02 1.11e-16 2.70e-06  -5.7 8.64e-05    -  1.00e+00 1.00e+00f  1
#   53  8.7491779e+02 0.00e+00 9.15e+00  -8.6 6.42e-05    -  9.50e-01 1.00e+00f  1
#   54  8.7491779e+02 2.22e-16 4.32e-07  -8.6 3.30e-05    -  1.00e+00 1.00e+00h  1
#   55  8.7491779e+02 1.11e-16 3.85e-08  -8.6 9.87e-06    -  1.00e+00 1.00e+00h  1
#   56  8.7491779e+02 2.22e-16 3.57e-10  -8.6 9.51e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 56
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.7491778911384688e+02    8.7491778911384688e+02
# Dual infeasibility......:   3.5711255540082415e-10    3.5711255540082415e-10
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.5945245676200894e-09    2.5945245676200894e-09
# Overall NLP error.......:   2.5945245676200894e-09    2.5945245676200894e-09
#
#
# Number of objective function evaluations             = 57
# Number of objective gradient evaluations             = 57
# Number of equality constraint evaluations            = 57
# Number of inequality constraint evaluations          = 57
# Number of equality constraint Jacobian evaluations   = 57
# Number of inequality constraint Jacobian evaluations = 57
# Number of Lagrangian Hessian evaluations             = 56
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.367
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 2.07e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.4879270e+03 9.69e-01 2.13e+04  -1.0 9.64e-01    -  1.13e-02 1.16e-02f  1
#    2  6.4848081e+03 9.69e-01 2.13e+04  -1.0 9.48e-01    -  3.54e-02 1.39e-04f  1
#    3  6.4318213e+03 9.67e-01 2.13e+04  -1.0 9.47e-01    -  1.54e-02 1.88e-03f  1
#    4  6.3016523e+03 9.63e-01 2.13e+04  -1.0 9.42e-01    -  8.65e-03 3.83e-03f  1
#    5  6.2221077e+03 9.61e-01 2.12e+04  -1.0 9.30e-01    -  4.59e-03 2.11e-03f  1
#    6  6.1503490e+03 9.59e-01 2.12e+04  -1.0 9.16e-01    -  5.73e-03 1.94e-03f  1
#    7  6.0586023e+03 9.57e-01 2.12e+04  -1.0 8.66e-01    -  7.87e-03 2.64e-03f  1
#    8  6.0089431e+03 9.55e-01 2.12e+04  -1.0 8.16e-01    -  6.89e-03 1.44e-03f  1
#    9  5.7852681e+03 9.48e-01 2.12e+04  -1.0 8.24e-01    -  2.73e-03 7.20e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.7328946e+03 9.47e-01 2.12e+04  -1.0 8.73e-01    -  1.45e-02 1.87e-03f  1
#   11  5.6406527e+03 9.43e-01 2.12e+04  -1.0 9.03e-01    -  1.50e-02 3.39e-03f  1
#   12  5.6312463e+03 9.43e-01 2.12e+04  -1.0 7.78e-01    -  3.56e-05 3.42e-04f  1
#   13  5.6254705e+03 9.43e-01 2.11e+04  -1.0 8.49e-01    -  3.29e-04 2.10e-04f  1
#   14  5.6123754e+03 9.42e-01 2.11e+04  -1.0 7.83e-01    -  6.56e-06 4.62e-04f  1
#   15  5.6115239e+03 9.42e-01 2.11e+04  -1.0 6.83e-01    -  1.12e-04 2.69e-05f  1
#   16  5.5897277e+03 9.42e-01 2.11e+04  -1.0 7.42e-01    -  1.53e-05 7.43e-04f  1
#   17  5.5861324e+03 9.42e-01 2.11e+04  -1.0 6.98e-01    -  3.83e-04 1.15e-04f  1
#   18  5.5818045e+03 9.41e-01 2.11e+04  -1.0 6.98e-01    -  1.02e-05 1.33e-04f  1
#   19  5.5759773e+03 9.41e-01 2.11e+04  -1.0 7.18e-01    -  5.79e-04 1.78e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  5.5196294e+03 9.40e-01 2.11e+04  -1.0 7.07e-01    -  3.52e-04 1.74e-03f  1
#   21  5.3651936e+03 9.35e-01 2.12e+04  -1.0 7.04e-01    -  1.96e-03 5.12e-03f  1
#   22  5.3013173e+03 9.33e-01 2.12e+04  -1.0 6.91e-01    -  5.56e-03 2.31e-03f  1
#   23  5.2323161e+03 9.30e-01 2.11e+04  -1.0 7.38e-01    -  2.70e-03 2.71e-03f  1
#   24  4.9649208e+03 9.19e-01 2.13e+04  -1.0 7.61e-01    -  5.09e-03 1.21e-02f  1
#   25  4.9624662e+03 9.19e-01 2.13e+04  -1.0 7.44e-01    -  2.15e-02 1.24e-04f  1
#   26  4.9401589e+03 9.18e-01 2.13e+04  -1.0 1.68e+00    -  1.26e-03 1.03e-03f  1
#   27  4.8728633e+03 9.15e-01 2.12e+04  -1.0 1.48e+00    -  1.03e-03 3.32e-03f  1
#   28  4.8719682e+03 9.15e-01 2.12e+04  -1.0 1.02e+00    -  2.12e-03 4.81e-05f  1
#   29  4.8678836e+03 9.14e-01 2.12e+04  -1.0 1.52e+00    -  1.26e-03 2.44e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.8059833e+03 9.11e-01 2.11e+04  -1.0 1.12e+00    -  8.16e-04 3.58e-03f  1
#   31  4.7646115e+03 9.09e-01 2.11e+04  -1.0 9.02e-01    -  3.51e-03 2.34e-03f  1
#   32  4.5426374e+03 8.96e-01 2.09e+04  -1.0 8.62e-01    -  4.89e-03 1.38e-02f  1
#   33  4.5318153e+03 8.96e-01 2.09e+04  -1.0 9.25e-01    -  2.21e-02 7.54e-04f  1
#   34  4.4586132e+03 8.91e-01 2.07e+04  -1.0 9.42e-01    -  7.48e-03 5.28e-03f  1
#   35  4.4573250e+03 8.91e-01 2.07e+04  -1.0 8.49e-01    -  3.99e-04 9.46e-05f  1
#   36  4.4550113e+03 8.91e-01 2.07e+04  -1.0 7.14e-01    -  2.05e-04 1.63e-04f  1
#   37  4.4517272e+03 8.91e-01 2.07e+04  -1.0 6.92e-01    -  4.06e-04 2.29e-04f  1
#   38  4.4508318e+03 8.91e-01 2.07e+04  -1.0 6.20e-01    -  3.70e-04 6.04e-05f  1
#   39  4.4253861e+03 8.89e-01 2.07e+04  -1.0 6.32e-01    -  8.41e-05 1.74e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  4.4199394e+03 8.89e-01 2.07e+04  -1.0 6.14e-01    -  2.02e-03 3.70e-04f  1
#   41  4.3317672e+03 8.83e-01 2.06e+04  -1.0 6.20e-01    -  2.58e-03 6.19e-03f  1
#   42  4.1862040e+03 8.73e-01 2.04e+04  -1.0 6.14e-01    -  6.39e-03 1.11e-02f  1
#   43  3.6359486e+03 8.25e-01 2.01e+04  -1.0 6.12e-01    -  1.79e-02 5.49e-02f  1
#   44  3.5324392e+03 8.14e-01 1.98e+04  -1.0 5.74e-01    -  9.91e-02 1.36e-02f  1
#   45  3.1221041e+03 7.61e-01 1.87e+04  -1.0 5.66e-01    -  5.38e-02 6.54e-02f  1
#   46  2.2111473e+03 5.73e-01 1.48e+04  -1.0 5.28e-01    -  6.90e-02 2.47e-01f  1
#   47  1.6886740e+03 4.01e-01 1.05e+04  -1.0 3.96e-01    -  2.11e-01 3.01e-01f  1
#   48  1.4570040e+03 3.03e-01 7.92e+03  -1.0 2.79e-01    -  3.72e-01 2.45e-01f  1
#   49  1.3481774e+03 2.51e-01 6.57e+03  -1.0 2.13e-01    -  3.37e-01 1.71e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.0660572e+03 9.82e-02 2.63e+03  -1.0 1.75e-01    -  8.08e-02 6.08e-01f  1
#   51  9.7198865e+02 4.11e-02 2.60e+03  -1.0 7.28e-02    -  3.55e-01 5.82e-01f  1
#   52  9.3239169e+02 1.67e-02 3.09e+03  -1.0 3.91e-02    -  1.37e-01 5.92e-01f  1
#   53  9.0725580e+02 2.10e-03 2.58e+03  -1.0 4.19e-02    -  4.01e-01 8.75e-01h  1
#   54  8.9871296e+02 2.00e-05 2.65e+03  -1.0 9.90e-02    -  4.23e-01 9.90e-01h  1
#   55  8.9644314e+02 1.58e-05 1.10e+05  -1.0 1.86e-01    -  4.51e-01 2.10e-01f  3
#   56  8.8086397e+02 6.68e-06 2.19e+05  -1.0 2.55e-01    -  1.13e-01 5.77e-01f  1
#   57  8.7276875e+02 4.20e-06 2.78e+05  -1.0 2.47e-01    -  2.58e-01 3.71e-01f  1
#   58  8.5597327e+02 1.84e-06 7.90e+05  -1.0 1.76e-01    -  1.87e-01 5.63e-01f  1
#   59  8.4170594e+02 1.11e-06 1.25e+06  -1.0 3.10e-01    -  1.51e-01 3.94e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  8.2809760e+02 7.72e-07 1.48e+06  -1.0 3.13e-01    -  1.55e-01 3.07e-01f  1
#   61  7.7632001e+02 3.39e-07 2.70e+06  -1.0 3.53e-01    -  1.01e-01 5.61e-01f  1
#   62  7.5421262e+02 2.53e-07 2.14e+06  -1.0 3.96e-01    -  2.31e-01 2.52e-01f  1
#   63  7.3596405e+02 1.66e-07 1.14e+06  -1.0 3.66e-01    -  3.98e-01 3.44e-01f  1
#   64  7.2476356e+02 2.61e-08 7.85e+05  -1.0 2.01e-01    -  6.77e-01 8.43e-01f  1
#   65  7.2455491e+02 0.00e+00 8.55e+00  -1.0 3.44e-02    -  1.00e+00 1.00e+00f  1
#   66  7.2390022e+02 2.22e-16 2.77e+06  -5.7 4.26e-02    -  7.22e-01 1.00e+00f  1
#   67  7.2372632e+02 1.11e-16 6.02e+05  -5.7 1.48e-02    -  7.83e-01 1.00e+00f  1
#   68  7.2368176e+02 2.22e-16 9.75e+04  -5.7 9.85e-03    -  8.38e-01 1.00e+00f  1
#   69  7.2367472e+02 2.22e-16 9.93e+03  -5.7 4.19e-03    -  8.98e-01 8.08e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  7.2367188e+02 2.22e-16 6.97e+02  -5.7 2.14e-03    -  9.30e-01 1.00e+00f  1
#   71  7.2367158e+02 2.22e-16 6.82e-03  -5.7 4.51e-04    -  1.00e+00 1.00e+00f  1
#   72  7.2367157e+02 2.22e-16 1.95e-04  -5.7 1.57e-04    -  1.00e+00 1.00e+00f  1
#   73  7.2367157e+02 2.22e-16 1.13e-06  -5.7 2.11e-05    -  1.00e+00 1.00e+00h  1
#   74  7.2367156e+02 1.11e-16 3.90e-02  -8.6 7.81e-06    -  1.00e+00 1.00e+00f  1
#   75  7.2367156e+02 2.22e-16 8.60e-12  -8.6 5.79e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 75
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.2367155962555501e+02    7.2367155962555501e+02
# Dual infeasibility......:   8.6041352453037877e-12    8.6041352453037877e-12
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   3.2221748023128902e-09    3.2221748023128902e-09
# Overall NLP error.......:   3.2221748023128902e-09    3.2221748023128902e-09
#
#
# Number of objective function evaluations             = 78
# Number of objective gradient evaluations             = 76
# Number of equality constraint evaluations            = 78
# Number of inequality constraint evaluations          = 78
# Number of equality constraint Jacobian evaluations   = 76
# Number of inequality constraint Jacobian evaluations = 76
# Number of Lagrangian Hessian evaluations             = 75
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.445
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      562
# Number of nonzeros in Lagrangian Hessian.............:       63
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      281
#         inequality constraints with only lower bounds:      281
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.65e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.4100165e+03 9.69e-01 1.83e+04  -1.0 9.69e-01    -  1.13e-02 1.16e-02f  1
#    2  6.4058313e+03 9.69e-01 1.83e+04  -1.0 9.56e-01    -  3.63e-02 1.42e-04f  1
#    3  6.3260617e+03 9.66e-01 1.83e+04  -1.0 9.50e-01    -  1.41e-02 2.38e-03f  1
#    4  6.2297548e+03 9.64e-01 1.82e+04  -1.0 9.34e-01    -  2.23e-02 2.63e-03f  1
#    5  6.0179563e+03 9.58e-01 1.82e+04  -1.0 8.67e-01    -  9.68e-03 5.75e-03f  1
#    6  5.9968009e+03 9.58e-01 1.82e+04  -1.0 7.96e-01    -  1.25e-02 5.96e-04f  1
#    7  5.8855250e+03 9.54e-01 1.82e+04  -1.0 8.57e-01    -  8.99e-03 3.23e-03f  1
#    8  5.7250307e+03 9.50e-01 1.82e+04  -1.0 9.01e-01    -  2.99e-03 5.09e-03f  1
#    9  5.7021694e+03 9.49e-01 1.82e+04  -1.0 7.43e-01    -  6.58e-03 7.24e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.5468997e+03 9.44e-01 1.82e+04  -1.0 1.04e+00    -  3.90e-03 5.23e-03f  1
#   11  5.5424724e+03 9.44e-01 1.82e+04  -1.0 6.82e-01    -  6.97e-03 1.52e-04f  1
#   12  5.4321834e+03 9.40e-01 1.82e+04  -1.0 7.76e-01    -  2.65e-03 3.69e-03f  1
#   13  5.4082944e+03 9.40e-01 1.82e+04  -1.0 9.24e-01    -  4.60e-04 8.16e-04f  1
#   14  5.3957946e+03 9.39e-01 1.82e+04  -1.0 9.09e-01    -  1.00e-03 4.32e-04f  1
#   15  5.3725962e+03 9.38e-01 1.82e+04  -1.0 8.22e-01    -  3.58e-05 8.67e-04f  1
#   16  5.3648938e+03 9.38e-01 1.82e+04  -1.0 9.89e-01    -  1.52e-03 3.03e-04f  1
#   17  5.2755785e+03 9.34e-01 1.81e+04  -1.0 9.00e-01    -  5.57e-04 4.00e-03f  1
#   18  5.2563885e+03 9.33e-01 1.81e+04  -1.0 9.60e-01    -  8.53e-04 9.58e-04f  1
#   19  5.2560663e+03 9.33e-01 1.81e+04  -1.0 9.43e-01    -  9.89e-05 1.42e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  5.2546861e+03 9.33e-01 1.81e+04  -1.0 9.14e-01    -  2.39e-04 4.88e-05f  1
#   21  5.2428275e+03 9.33e-01 1.81e+04  -1.0 9.79e-01    -  9.73e-05 4.18e-04f  1
#   22  5.2395193e+03 9.33e-01 1.81e+04  -1.0 9.75e-01    -  4.68e-04 1.12e-04f  1
#   23  5.1560496e+03 9.30e-01 1.81e+04  -1.0 9.61e-01    -  5.32e-05 2.96e-03f  1
#   24  5.0584108e+03 9.27e-01 1.81e+04  -1.0 9.49e-01    -  2.21e-03 3.72e-03f  1
#   25  5.0072704e+03 9.25e-01 1.81e+04  -1.0 9.64e-01    -  1.55e-03 2.09e-03f  1
#   26  4.9672272e+03 9.23e-01 1.80e+04  -1.0 9.63e-01    -  9.41e-05 1.89e-03f  1
#   27  4.9547223e+03 9.22e-01 1.80e+04  -1.0 9.61e-01    -  2.72e-03 6.00e-04f  1
#   28  4.9031576e+03 9.20e-01 1.80e+04  -1.0 9.60e-01    -  2.50e-03 2.53e-03f  1
#   29  4.7844950e+03 9.14e-01 1.79e+04  -1.0 9.58e-01    -  4.88e-03 6.35e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.6770156e+03 9.08e-01 1.78e+04  -1.0 9.52e-01    -  3.62e-03 6.31e-03f  1
#   31  4.6680531e+03 9.08e-01 1.78e+04  -1.0 9.46e-01    -  8.39e-03 5.44e-04f  1
#   32  4.6508162e+03 9.07e-01 1.78e+04  -1.0 9.45e-01    -  4.68e-03 1.03e-03f  1
#   33  4.6107752e+03 9.05e-01 1.77e+04  -1.0 9.44e-01    -  6.32e-05 2.41e-03f  1
#   34  4.5986560e+03 9.04e-01 1.77e+04  -1.0 9.42e-01    -  3.38e-03 7.15e-04f  1
#   35  4.3967613e+03 8.92e-01 1.76e+04  -1.0 9.41e-01    -  2.24e-03 1.33e-02f  1
#   36  4.1938825e+03 8.78e-01 1.73e+04  -1.0 9.29e-01    -  1.05e-02 1.61e-02f  1
#   37  4.1622013e+03 8.75e-01 1.73e+04  -1.0 9.14e-01    -  1.56e-02 2.75e-03f  1
#   38  4.0958182e+03 8.70e-01 1.72e+04  -1.0 9.11e-01    -  1.41e-02 6.01e-03f  1
#   39  4.0838086e+03 8.69e-01 1.72e+04  -1.0 9.06e-01    -  1.10e-03 1.10e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  3.9789225e+03 8.61e-01 1.70e+04  -1.0 9.05e-01    -  1.88e-04 9.94e-03f  1
#   41  3.9773706e+03 8.60e-01 1.70e+04  -1.0 8.96e-01    -  5.13e-03 1.55e-04f  1
#   42  3.5040778e+03 8.12e-01 1.62e+04  -1.0 8.96e-01    -  2.03e-04 5.68e-02f  1
#   43  2.7030200e+03 6.83e-01 1.40e+04  -1.0 8.45e-01    -  5.16e-02 1.59e-01f  1
#   44  1.2395333e+03 1.63e-01 4.30e+03  -1.0 7.11e-01    -  2.83e-01 7.61e-01f  1
#   45  1.1889685e+03 1.35e-01 3.55e+03  -1.0 1.70e-01    -  2.48e-01 1.75e-01f  1
#   46  1.0756979e+03 6.75e-02 1.78e+03  -1.0 1.40e-01    -  5.06e-01 4.99e-01f  1
#   47  1.0179043e+03 3.28e-02 9.21e+02  -1.0 7.05e-02    -  3.77e-01 5.14e-01f  1
#   48  9.9043098e+02 1.89e-02 1.22e+03  -1.0 8.97e-02    -  1.52e-01 4.24e-01f  1
#   49  9.7685072e+02 1.21e-02 7.25e+02  -1.0 7.56e-02    -  4.02e-01 3.61e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  9.6526205e+02 6.65e-03 6.11e+02  -1.0 6.40e-02    -  2.05e-01 4.50e-01f  1
#   51  9.6202608e+02 5.26e-03 1.12e+03  -1.0 6.07e-02    -  5.47e-01 2.08e-01f  1
#   52  9.5177000e+02 7.64e-04 2.17e+03  -1.0 5.74e-02    -  4.13e-01 8.55e-01h  1
#   53  9.4764527e+02 5.93e-04 7.36e+03  -1.0 7.23e-02    -  7.32e-02 2.24e-01f  1
#   54  9.1212837e+02 3.91e-04 1.76e+04  -1.0 4.47e-01    -  7.53e-02 3.42e-01f  1
#   55  8.9382016e+02 3.03e-04 1.01e+04  -1.0 3.14e-01    -  2.74e-01 2.26e-01f  1
#   56  8.6406840e+02 1.62e-04 2.26e+04  -1.0 2.98e-01    -  2.82e-01 4.65e-01f  1
#   57  8.4330181e+02 1.03e-04 4.97e+04  -1.0 4.03e-01    -  1.58e-01 3.61e-01f  1
#   58  8.3768300e+02 8.25e-05 4.91e+04  -1.0 1.89e-01    -  1.68e-01 2.03e-01f  1
#   59  8.3417456e+02 6.20e-05 1.69e+04  -1.0 2.15e-01    -  3.08e-01 2.49e-01f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  8.2975038e+02 1.89e-06 4.32e+03  -1.0 1.51e-01    -  9.61e-01 9.69e-01h  1
#   61  8.2970331e+02 1.68e-06 8.58e+06  -1.0 3.91e-02    -  1.00e+00 1.14e-01h  1
#   62  8.2966702e+02 7.68e-08 7.09e+05  -1.0 3.41e-02    -  1.00e+00 9.54e-01h  1
#   63  8.2966737e+02 5.77e-08 8.78e+06  -1.0 7.41e-03    -  1.00e+00 2.48e-01f  3
#   64  8.2968560e+02 3.09e-14 1.53e-01  -1.0 4.97e-03    -  1.00e+00 1.00e+00h  1
#   65  8.2753497e+02 1.15e-13 7.66e+06  -8.6 4.21e-02    -  7.36e-01 1.00e+00f  1
#   66  8.2722896e+02 2.22e-16 8.38e+05  -8.6 1.99e-02    -  8.91e-01 1.00e+00f  1
#   67  8.2719963e+02 2.22e-16 1.32e+05  -8.6 1.01e-02    -  8.43e-01 1.00e+00f  1
#   68  8.2719537e+02 2.22e-16 1.13e+04  -8.6 3.62e-03    -  9.14e-01 1.00e+00f  1
#   69  8.2719458e+02 2.22e-16 2.78e+02  -8.6 1.49e-03    -  9.75e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  8.2719451e+02 2.22e-16 4.06e+01  -8.6 3.08e-04    -  8.54e-01 8.24e-01f  1
#   71  8.2719450e+02 2.22e-16 1.69e+01  -8.6 6.81e-05    -  7.64e-01 5.87e-01f  1
#   72  8.2719449e+02 1.11e-16 4.19e+01  -8.6 2.87e-05    -  2.06e-01 1.00e+00f  1
#   73  8.2719449e+02 1.11e-16 1.61e+01  -8.6 6.39e-08    -  6.44e-01 6.03e-01f  1
#   74  8.2719449e+02 2.22e-16 1.19e+00  -8.6 2.55e-08    -  9.52e-01 9.20e-01f  1
#   75  8.2719449e+02 2.22e-16 7.45e-14  -8.6 2.05e-09    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 75
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.2719449468479047e+02    8.2719449468479047e+02
# Dual infeasibility......:   7.4457847197517778e-14    7.4457847197517778e-14
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.6080977577653795e-09    2.6080977577653795e-09
# Overall NLP error.......:   2.6080977577653795e-09    2.6080977577653795e-09
#
#
# Number of objective function evaluations             = 79
# Number of objective gradient evaluations             = 76
# Number of equality constraint evaluations            = 79
# Number of inequality constraint evaluations          = 79
# Number of equality constraint Jacobian evaluations   = 76
# Number of inequality constraint Jacobian evaluations = 76
# Number of Lagrangian Hessian evaluations             = 75
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.438
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      554
# Number of nonzeros in Lagrangian Hessian.............:       67
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      277
#         inequality constraints with only lower bounds:      277
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 2.45e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.6162873e+03 9.66e-01 2.42e+04  -1.0 9.69e-01    -  1.13e-02 1.38e-02f  1
#    2  6.6142103e+03 9.66e-01 2.42e+04  -1.0 9.56e-01    -  2.29e-02 1.62e-04f  1
#    3  6.5800373e+03 9.64e-01 2.42e+04  -1.0 9.55e-01    -  2.54e-02 2.14e-03f  1
#    4  6.4983611e+03 9.60e-01 2.41e+04  -1.0 9.47e-01    -  8.90e-03 4.11e-03f  1
#    5  6.4709854e+03 9.59e-01 2.41e+04  -1.0 8.88e-01    -  9.69e-03 1.10e-03f  1
#    6  6.4521304e+03 9.59e-01 2.41e+04  -1.0 7.24e-01    -  1.11e-02 4.06e-04f  1
#    7  6.0904784e+03 9.51e-01 2.56e+04  -1.0 6.43e-01    -  1.03e-02 8.14e-03f  1
#    8  5.8272869e+03 9.44e-01 2.61e+04  -1.0 4.99e-01    -  4.75e-03 6.93e-03f  1
#    9  5.7887854e+03 9.43e-01 2.61e+04  -1.0 4.83e-01    -  5.03e-03 1.13e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.7838071e+03 9.43e-01 2.61e+04  -1.0 4.99e-01    -  4.50e-03 1.49e-04f  1
#   11  5.7506561e+03 9.42e-01 2.60e+04  -1.0 5.83e-01    -  1.79e-04 1.01e-03f  1
#   12  5.7418236e+03 9.42e-01 2.60e+04  -1.0 7.71e-01    -  2.74e-04 2.64e-04f  1
#   13  5.6649542e+03 9.40e-01 2.60e+04  -1.0 9.35e-01    -  3.19e-04 2.32e-03f  1
#   14  5.6209011e+03 9.39e-01 2.60e+04  -1.0 9.69e-01    -  2.63e-03 1.38e-03f  1
#   15  5.5800296e+03 9.37e-01 2.60e+04  -1.0 9.70e-01    -  4.04e-03 1.29e-03f  1
#   16  5.4695051e+03 9.34e-01 2.59e+04  -1.0 9.68e-01    -  5.87e-03 3.63e-03f  1
#   17  5.1867115e+03 9.24e-01 2.61e+04  -1.0 9.65e-01    -  9.09e-03 1.07e-02f  1
#   18  5.1841159e+03 9.24e-01 2.61e+04  -1.0 9.51e-01    -  1.42e-02 1.10e-04f  1
#   19  5.1738579e+03 9.23e-01 2.61e+04  -1.0 6.33e-01    -  6.24e-04 4.39e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  5.0964873e+03 9.20e-01 2.60e+04  -1.0 6.36e-01    -  1.03e-03 3.39e-03f  1
#   21  4.8189764e+03 9.08e-01 2.58e+04  -1.0 6.35e-01    -  3.63e-03 1.38e-02f  1
#   22  4.6490564e+03 8.98e-01 2.56e+04  -1.0 6.38e-01    -  1.62e-02 1.01e-02f  1
#   23  4.6473918e+03 8.98e-01 2.56e+04  -1.0 6.34e-01    -  1.80e-02 1.06e-04f  1
#   24  4.5703387e+03 8.94e-01 2.54e+04  -1.0 6.33e-01    -  7.52e-04 4.94e-03f  1
#   25  4.3364026e+03 8.79e-01 2.51e+04  -1.0 6.32e-01    -  5.84e-03 1.69e-02f  1
#   26  4.2855019e+03 8.75e-01 2.50e+04  -1.0 6.23e-01    -  5.22e-02 4.11e-03f  1
#   27  4.2808127e+03 8.75e-01 2.50e+04  -1.0 6.20e-01    -  8.52e-03 3.88e-04f  1
#   28  4.2739095e+03 8.74e-01 2.50e+04  -1.0 6.04e-01    -  2.07e-05 5.52e-04f  1
#   29  4.2549236e+03 8.73e-01 2.49e+04  -1.0 6.04e-01    -  9.44e-04 1.53e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.1232425e+03 8.63e-01 2.47e+04  -1.0 6.03e-01    -  2.32e-03 1.12e-02f  1
#   31  3.2666498e+03 7.73e-01 2.43e+04  -1.0 5.96e-01    -  1.38e-02 1.04e-01f  1
#   32  2.6536906e+03 6.68e-01 2.15e+04  -1.0 5.34e-01    -  1.18e-01 1.36e-01f  1
#   33  1.5716110e+03 3.35e-01 1.17e+04  -1.0 4.61e-01    -  3.72e-01 4.99e-01f  1
#   34  1.2785171e+03 1.95e-01 6.86e+03  -1.0 2.31e-01    -  1.51e-01 4.19e-01f  1
#   35  1.0429976e+03 6.02e-02 4.20e+03  -1.0 1.35e-01    -  3.97e-01 6.91e-01f  1
#   36  1.0181751e+03 4.49e-02 4.42e+03  -1.0 4.19e-02    -  6.42e-02 2.55e-01f  1
#   37  1.0047119e+03 3.64e-02 2.30e+03  -1.0 3.12e-02    -  3.67e-01 1.88e-01f  1
#   38  9.8896536e+02 2.66e-02 1.92e+03  -1.0 2.57e-02    -  2.20e-01 2.70e-01f  1
#   39  9.5908371e+02 8.10e-03 2.26e+03  -1.0 2.10e-02    -  2.86e-01 6.95e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.5435148e+02 5.70e-03 1.57e+03  -1.0 3.09e-02    -  4.02e-01 2.97e-01f  1
#   41  9.4290117e+02 1.88e-03 7.77e+02  -1.0 8.81e-02    -  3.23e-01 6.71e-01f  1
#   42  9.3587988e+02 1.20e-03 1.43e+03  -1.0 2.11e-01    -  5.71e-01 3.58e-01f  1
#   43  9.2122997e+02 8.33e-04 1.77e+03  -1.0 1.60e-01    -  8.69e-02 3.08e-01f  1
#   44  8.4025526e+02 2.22e-04 1.17e+04  -1.0 2.45e-01    -  5.75e-02 7.34e-01f  1
#   45  7.5053397e+02 1.69e-04 1.63e+04  -1.0 5.50e-01    -  1.08e-01 2.40e-01f  1
#   46  7.2037633e+02 1.57e-04 7.39e+03  -1.0 5.10e-01    -  1.66e-01 6.86e-02f  1
#   47  6.9312583e+02 1.48e-04 4.85e+03  -1.0 5.41e-01    -  8.56e-02 5.99e-02f  1
#   48  6.1339198e+02 1.24e-04 1.42e+04  -1.0 6.01e-01    -  4.67e-02 1.58e-01f  1
#   49  5.2183170e+02 9.62e-05 2.55e+04  -1.0 6.16e-01    -  9.43e-02 2.26e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  4.8702069e+02 8.04e-05 1.73e+04  -1.0 4.31e-01    -  1.92e-01 1.63e-01f  1
#   51  4.7264414e+02 6.88e-05 1.86e+04  -1.0 3.27e-01    -  3.43e-01 1.45e-01f  1
#   52  4.5542656e+02 3.74e-05 1.17e+05  -1.0 3.60e-01    -  1.00e+00 4.56e-01f  1
#   53  4.5223631e+02 2.22e-16 6.71e+00  -1.0 1.20e-01    -  1.00e+00 1.00e+00h  1
#   54  4.4996458e+02 2.22e-16 1.24e+05  -3.8 3.43e-02    -  8.12e-01 1.00e+00f  1
#   55  4.4970331e+02 2.22e-16 4.01e+04  -3.8 1.54e-02    -  6.78e-01 1.00e+00f  1
#   56  4.4965544e+02 1.11e-16 7.09e+03  -3.8 6.66e-03    -  8.23e-01 1.00e+00f  1
#   57  4.4964648e+02 2.22e-16 1.98e+01  -3.8 3.61e-03    -  9.97e-01 1.00e+00f  1
#   58  4.4964515e+02 1.11e-16 2.09e-01  -3.8 1.16e-03    -  1.00e+00 1.00e+00f  1
#   59  4.4964500e+02 2.22e-16 1.49e-02  -3.8 2.75e-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  4.4964483e+02 2.22e-16 1.02e+03  -5.7 4.70e-04    -  9.51e-01 1.00e+00f  1
#   61  4.4964480e+02 2.22e-16 1.75e-02  -5.7 1.05e-04    -  1.00e+00 1.00e+00f  1
#   62  4.4964479e+02 2.22e-16 2.93e-03  -5.7 3.14e-05    -  1.00e+00 1.00e+00f  1
#   63  4.4964479e+02 2.22e-16 3.24e-04  -5.7 1.00e-05    -  1.00e+00 1.00e+00f  1
#   64  4.4964479e+02 2.22e-16 8.91e-06  -5.7 1.18e-06    -  1.00e+00 1.00e+00h  1
#   65  4.4964479e+02 2.22e-16 2.49e+01  -8.6 3.42e-05    -  9.04e-01 1.00e+00f  1
#   66  4.4964479e+02 2.22e-16 5.59e+00  -8.6 2.26e-05    -  7.51e-01 1.00e+00f  1
#   67  4.4964478e+02 2.22e-16 1.31e+00  -8.6 1.06e-05    -  1.00e+00 7.75e-01f  1
#   68  4.4964478e+02 2.22e-16 1.92e-05  -8.6 8.37e-06    -  1.00e+00 1.00e+00f  1
#   69  4.4964478e+02 2.22e-16 2.80e-06  -8.6 3.19e-06    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  4.4964478e+02 2.22e-16 3.26e-07  -8.6 1.09e-06    -  1.00e+00 1.00e+00h  1
#   71  4.4964478e+02 2.22e-16 7.55e-09  -8.6 1.66e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 71
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.4964478467500101e+02    4.4964478467500101e+02
# Dual infeasibility......:   7.5547566012285707e-09    7.5547566012285707e-09
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.5119686518304576e-09    2.5119686518304576e-09
# Overall NLP error.......:   7.5547566012285707e-09    7.5547566012285707e-09
#
#
# Number of objective function evaluations             = 72
# Number of objective gradient evaluations             = 72
# Number of equality constraint evaluations            = 72
# Number of inequality constraint evaluations          = 72
# Number of equality constraint Jacobian evaluations   = 72
# Number of inequality constraint Jacobian evaluations = 72
# Number of Lagrangian Hessian evaluations             = 71
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.419
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 2.06e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.3506835e+03 9.68e-01 2.14e+04  -1.0 9.66e-01    -  1.13e-02 1.26e-02f  1
#    2  6.3469152e+03 9.67e-01 2.14e+04  -1.0 9.54e-01    -  3.41e-02 1.28e-04f  1
#    3  6.2515875e+03 9.65e-01 2.13e+04  -1.0 9.48e-01    -  1.45e-02 3.01e-03f  1
#    4  6.1624347e+03 9.62e-01 2.13e+04  -1.0 9.31e-01    -  2.58e-02 2.76e-03f  1
#    5  6.0218789e+03 9.58e-01 2.12e+04  -1.0 8.37e-01    -  1.50e-02 4.19e-03f  1
#    6  5.9381174e+03 9.55e-01 2.12e+04  -1.0 8.23e-01    -  1.29e-02 2.54e-03f  1
#    7  5.7342776e+03 9.49e-01 2.13e+04  -1.0 9.08e-01    -  1.32e-02 6.83e-03f  1
#    8  5.7014168e+03 9.48e-01 2.12e+04  -1.0 9.69e-01    -  1.19e-02 1.10e-03f  1
#    9  5.5368658e+03 9.42e-01 2.14e+04  -1.0 9.79e-01    -  3.15e-03 5.80e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.5326523e+03 9.42e-01 2.14e+04  -1.0 6.70e-01    -  3.65e-05 1.47e-04f  1
#   11  5.5297196e+03 9.42e-01 2.14e+04  -1.0 7.52e-01    -  1.22e-04 9.76e-05f  1
#   12  5.5226489e+03 9.42e-01 2.14e+04  -1.0 8.08e-01    -  3.92e-04 2.31e-04f  1
#   13  5.4944847e+03 9.41e-01 2.14e+04  -1.0 8.92e-01    -  6.69e-04 9.08e-04f  1
#   14  5.3788142e+03 9.37e-01 2.16e+04  -1.0 9.37e-01    -  5.35e-04 3.92e-03f  1
#   15  5.3656163e+03 9.37e-01 2.16e+04  -1.0 7.38e-01    -  5.91e-05 4.93e-04f  1
#   16  5.3646852e+03 9.37e-01 2.16e+04  -1.0 8.72e-01    -  3.02e-03 3.37e-05f  1
#   17  5.1885370e+03 9.30e-01 2.18e+04  -1.0 8.16e-01    -  2.06e-04 6.95e-03f  1
#   18  5.1308316e+03 9.28e-01 2.17e+04  -1.0 7.99e-01    -  2.07e-03 2.50e-03f  1
#   19  5.1214619e+03 9.28e-01 2.17e+04  -1.0 7.43e-01    -  6.09e-03 4.18e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  5.0040086e+03 9.22e-01 2.17e+04  -1.0 6.81e-01    -  3.90e-03 5.66e-03f  1
#   21  4.9100196e+03 9.18e-01 2.16e+04  -1.0 7.12e-01    -  6.64e-03 4.99e-03f  1
#   22  4.8499216e+03 9.15e-01 2.15e+04  -1.0 7.33e-01    -  1.16e-02 3.40e-03f  1
#   23  4.6548914e+03 9.04e-01 2.13e+04  -1.0 7.11e-01    -  1.67e-02 1.21e-02f  1
#   24  4.5770384e+03 8.99e-01 2.13e+04  -1.0 6.23e-01    -  1.00e-02 5.12e-03f  1
#   25  4.4893611e+03 8.94e-01 2.12e+04  -1.0 6.20e-01    -  4.17e-03 6.08e-03f  1
#   26  4.4366523e+03 8.90e-01 2.11e+04  -1.0 6.53e-01    -  6.16e-04 3.92e-03f  1
#   27  4.4310882e+03 8.90e-01 2.11e+04  -1.0 6.77e-01    -  3.29e-03 4.29e-04f  1
#   28  4.2653736e+03 8.77e-01 2.08e+04  -1.0 6.93e-01    -  2.80e-03 1.37e-02f  1
#   29  4.0638221e+03 8.61e-01 2.05e+04  -1.0 6.86e-01    -  1.61e-02 1.92e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.0614004e+03 8.60e-01 2.05e+04  -1.0 6.55e-01    -  1.02e-02 2.50e-04f  1
#   31  4.0476198e+03 8.59e-01 2.04e+04  -1.0 5.92e-01    -  3.89e-04 1.37e-03f  1
#   32  4.0332105e+03 8.58e-01 2.04e+04  -1.0 5.93e-01    -  1.50e-03 1.45e-03f  1
#   33  4.0307498e+03 8.58e-01 2.04e+04  -1.0 5.91e-01    -  2.73e-03 2.49e-04f  1
#   34  3.8807436e+03 8.44e-01 2.01e+04  -1.0 5.95e-01    -  2.83e-03 1.60e-02f  1
#   35  3.5175784e+03 8.04e-01 1.94e+04  -1.0 5.86e-01    -  1.87e-02 4.70e-02f  1
#   36  2.2486070e+03 5.57e-01 1.53e+04  -1.0 5.58e-01    -  1.16e-01 3.08e-01f  1
#   37  1.2313392e+03 1.32e-01 4.02e+03  -1.0 3.86e-01    -  5.35e-01 7.62e-01f  1
#   38  1.1512294e+03 8.49e-02 2.72e+03  -1.0 9.19e-02    -  3.04e-01 3.58e-01f  1
#   39  1.0870143e+03 4.53e-02 2.40e+03  -1.0 5.91e-02    -  2.74e-01 4.67e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.0357036e+03 1.27e-02 2.56e+03  -1.0 3.18e-02    -  2.08e-01 7.20e-01f  1
#   41  1.0288047e+03 8.56e-03 2.14e+03  -1.0 1.48e-02    -  2.25e-01 3.26e-01f  1
#   42  1.0131305e+03 8.46e-05 1.87e+03  -1.0 1.79e-02    -  3.56e-01 9.90e-01h  1
#   43  1.0114424e+03 6.34e-05 1.38e+04  -1.0 3.16e-02    -  3.75e-01 2.50e-01f  3
#   44  1.0010008e+03 3.17e-05 4.37e+04  -1.0 7.33e-02    -  1.66e-01 5.00e-01f  2
#   45  9.8257894e+02 1.59e-05 9.68e+04  -1.0 1.47e-01    -  2.48e-01 5.00e-01f  2
#   46  9.5432790e+02 2.03e-06 2.80e+05  -1.0 2.39e-01    -  4.06e-01 8.72e-01f  1
#   47  9.4770133e+02 1.21e-06 7.95e+04  -1.0 1.71e-01    -  4.30e-01 4.02e-01f  1
#   48  9.1412986e+02 3.24e-07 2.33e+06  -1.0 2.74e-01    -  1.09e-01 7.32e-01f  1
#   49  8.9916440e+02 2.28e-07 2.39e+06  -1.0 4.21e-01    -  1.70e-01 2.97e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  8.8109951e+02 1.41e-07 2.14e+06  -1.0 4.31e-01    -  2.63e-01 3.82e-01f  1
#   51  8.6869508e+02 5.99e-08 1.73e+06  -1.0 2.51e-01    -  4.01e-01 5.74e-01f  1
#   52  8.6660225e+02 2.17e-08 2.93e+05  -1.0 1.55e-01    -  9.16e-01 6.38e-01f  1
#   53  8.6648817e+02 1.09e-08 3.82e+05  -1.0 3.84e-02    -  1.00e+00 5.00e-01f  2
#   54  8.6647733e+02 1.11e-16 3.06e-02  -1.0 1.08e-02    -  1.00e+00 1.00e+00h  1
#   55  8.6591710e+02 2.22e-16 2.06e+06  -8.6 4.55e-02    -  7.94e-01 1.00e+00f  1
#   56  8.6574310e+02 2.22e-16 4.80e+05  -8.6 2.14e-02    -  7.68e-01 1.00e+00f  1
#   57  8.6571885e+02 2.22e-16 6.29e+04  -8.6 7.50e-03    -  8.69e-01 1.00e+00f  1
#   58  8.6571429e+02 2.22e-16 6.61e+03  -8.6 3.97e-03    -  8.95e-01 1.00e+00f  1
#   59  8.6571358e+02 2.22e-16 8.34e+02  -8.6 2.40e-03    -  8.74e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  8.6571347e+02 2.22e-16 9.02e+01  -8.6 9.66e-04    -  8.92e-01 1.00e+00f  1
#   61  8.6571345e+02 2.22e-16 4.22e+00  -8.6 4.33e-04    -  9.53e-01 1.00e+00f  1
#   62  8.6571344e+02 2.22e-16 4.90e-02  -8.6 2.37e-04    -  9.88e-01 1.00e+00f  1
#   63  8.6571344e+02 2.22e-16 3.47e-06  -8.6 1.24e-04    -  1.00e+00 1.00e+00f  1
#   64  8.6571344e+02 2.22e-16 8.87e-07  -8.6 6.26e-05    -  1.00e+00 1.00e+00f  1
#   65  8.6571344e+02 2.22e-16 2.20e-07  -8.6 3.11e-05    -  1.00e+00 1.00e+00h  1
#   66  8.6571344e+02 2.22e-16 5.29e-08  -8.6 1.53e-05    -  1.00e+00 1.00e+00h  1
#   67  8.6571344e+02 1.11e-16 1.14e-08  -8.6 7.10e-06    -  1.00e+00 1.00e+00h  1
#   68  8.6571344e+02 2.22e-16 3.54e-09  -9.0 3.96e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 68
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.6571343942752389e+02    8.6571343942752389e+02
# Dual infeasibility......:   3.5448085223282912e-09    3.5448085223282912e-09
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   1.9741828324368202e-09    1.9741828324368202e-09
# Overall NLP error.......:   3.5448085223282912e-09    3.5448085223282912e-09
#
#
# Number of objective function evaluations             = 74
# Number of objective gradient evaluations             = 69
# Number of equality constraint evaluations            = 74
# Number of inequality constraint evaluations          = 74
# Number of equality constraint Jacobian evaluations   = 69
# Number of inequality constraint Jacobian evaluations = 69
# Number of Lagrangian Hessian evaluations             = 68
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.411
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.90e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.3130674e+03 9.66e-01 2.07e+04  -1.0 9.46e-01    -  1.16e-02 1.48e-02f  1
#    2  6.3092630e+03 9.65e-01 2.07e+04  -1.0 9.44e-01    -  3.91e-02 1.44e-04f  1
#    3  6.2527542e+03 9.64e-01 2.07e+04  -1.0 9.31e-01    -  2.53e-02 1.61e-03f  1
#    4  6.0672857e+03 9.59e-01 2.08e+04  -1.0 8.81e-01    -  1.45e-02 5.25e-03f  1
#    5  5.9773347e+03 9.56e-01 2.08e+04  -1.0 7.83e-01    -  2.91e-02 2.59e-03f  1
#    6  5.6444507e+03 9.46e-01 2.09e+04  -1.0 6.43e-01    -  2.21e-02 1.05e-02f  1
#    7  5.3062915e+03 9.33e-01 2.10e+04  -1.0 6.57e-01    -  2.97e-02 1.37e-02f  1
#    8  5.2631852e+03 9.32e-01 2.09e+04  -1.0 5.21e-01    -  3.10e-02 1.89e-03f  1
#    9  4.9180640e+03 9.15e-01 2.11e+04  -1.0 5.17e-01    -  1.20e-02 1.73e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.2257476e+03 8.69e-01 2.18e+04  -1.0 5.02e-01    -  5.24e-02 5.10e-02f  1
#   11  3.5641415e+03 7.98e-01 2.08e+04  -1.0 4.45e-01    -  1.79e-01 8.18e-02f  1
#   12  3.0618237e+03 7.17e-01 1.90e+04  -1.0 4.07e-01    -  9.11e-02 1.01e-01f  1
#   13  2.2860861e+03 5.25e-01 1.43e+04  -1.0 3.66e-01    -  1.30e-01 2.68e-01f  1
#   14  1.9787534e+03 4.18e-01 1.14e+04  -1.0 2.68e-01    -  2.70e-01 2.04e-01f  1
#   15  1.3078081e+03 9.54e-02 5.02e+03  -1.0 2.18e-01    -  4.80e-01 7.72e-01f  1
#   16  1.2660927e+03 7.49e-02 2.88e+03  -1.0 9.86e-02    -  3.84e-01 2.15e-01f  1
#   17  1.2269462e+03 5.63e-02 2.18e+03  -1.0 9.95e-02    -  2.44e-01 2.48e-01f  1
#   18  1.1834461e+03 3.65e-02 1.99e+03  -1.0 9.96e-02    -  1.51e-01 3.51e-01f  1
#   19  1.1237150e+03 1.13e-02 1.94e+03  -1.0 1.48e-01    -  3.05e-01 6.91e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0865344e+03 1.71e-03 1.28e+03  -1.0 2.44e-01    -  5.15e-01 8.48e-01f  1
#   21  1.0854417e+03 1.60e-03 1.30e+03  -1.0 1.42e-01    -  2.74e-01 6.69e-02f  1
# ...
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.3186505e+03 9.50e-01 2.53e+04  -1.0 9.14e-01    -  1.30e-02 1.61e-03f  1
#   11  4.9831307e+03 9.39e-01 2.67e+04  -1.0 9.06e-01    -  2.71e-04 1.15e-02f  1
#   12  4.9400469e+03 9.37e-01 2.67e+04  -1.0 8.10e-01    -  5.18e-02 1.72e-03f  1
#   13  4.4454503e+03 9.15e-01 2.83e+04  -1.0 5.36e-01    -  3.84e-02 2.39e-02f  1
#   14  3.9275138e+03 8.81e-01 2.87e+04  -1.0 4.68e-01    -  2.24e-01 3.75e-02f  1
#   15  1.6636465e+03 4.03e-01 3.34e+04  -1.0 4.49e-01    -  9.75e-02 5.43e-01f  1
#   16  1.0590647e+03 7.08e-02 6.05e+03  -1.0 2.06e-01    -  7.78e-01 8.24e-01f  1
#   17  1.0311094e+03 5.34e-02 4.56e+03  -1.0 8.31e-02    -  3.43e-01 2.47e-01f  1
#   18  9.9592638e+02 3.13e-02 4.16e+03  -1.0 9.63e-02    -  1.25e-01 4.12e-01f  1
#   19  9.8070003e+02 2.22e-02 3.07e+03  -1.0 1.12e-01    -  2.64e-01 2.90e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  9.6370604e+02 1.22e-02 2.90e+03  -1.0 1.16e-01    -  1.78e-01 4.52e-01f  1
#   21  9.4364223e+02 1.21e-04 1.42e+03  -1.0 9.96e-02    -  3.46e-01 9.90e-01h  1
#   22  9.4106722e+02 2.39e-07 3.53e+04  -1.0 8.37e-03    -  5.59e-01 9.98e-01h  1
#   23  9.3203127e+02 0.00e+00 5.69e+06  -1.0 1.97e-02    -  2.89e-01 1.00e+00f  1
#   24  9.1215012e+02 2.22e-16 3.37e+06  -1.0 4.50e-01    -  4.25e-01 4.79e-01f  1
#   25  6.8268766e+02 1.11e-16 4.24e+06  -1.0 3.94e-01    -  3.51e-02 1.00e+00f  1
#   26  6.3975358e+02 2.22e-16 3.22e+06  -1.0 6.78e-01    -  2.40e-01 1.01e-01f  1
#   27  5.8827155e+02 2.22e-16 2.38e+06  -1.0 8.61e-01    -  2.61e-01 1.25e-01f  1
#   28  5.2830217e+02 2.22e-16 1.67e+06  -1.0 7.68e-01    -  3.00e-01 1.99e-01f  1
#   29  5.0707991e+02 2.22e-16 2.52e+02  -1.0 4.74e-01    -  1.00e+00 4.15e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  5.0213186e+02 2.22e-16 7.49e+06  -3.8 1.32e-01    -  2.49e-01 1.00e+00f  1
#   31  5.0197908e+02 1.11e-16 1.97e+06  -3.8 1.49e-02    -  7.38e-01 1.00e+00f  1
#   32  5.0195503e+02 0.00e+00 7.57e+04  -3.8 2.30e-03    -  9.61e-01 1.00e+00f  1
#   33  5.0194660e+02 1.11e-16 4.11e+00  -3.8 8.70e-04    -  1.00e+00 1.00e+00f  1
#   34  5.0194509e+02 2.22e-16 6.00e-01  -3.8 4.17e-04    -  1.00e+00 1.00e+00f  1
#   35  5.0194488e+02 1.11e-16 4.25e-02  -3.8 1.58e-04    -  1.00e+00 1.00e+00f  1
#   36  5.0194481e+02 2.22e-16 2.53e+01  -5.7 9.90e-05    -  9.98e-01 1.00e+00f  1
#   37  5.0194481e+02 1.11e-16 1.47e-03  -5.7 3.29e-05    -  1.00e+00 1.00e+00f  1
#   38  5.0194481e+02 2.22e-16 3.59e-05  -5.7 1.55e-05    -  1.00e+00 1.00e+00f  1
#   39  5.0194481e+02 1.11e-16 2.25e-08  -5.7 3.45e-07    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.0194481e+02 1.11e-16 2.03e+01  -8.6 1.53e-05    -  8.90e-01 1.00e+00f  1
#   41  5.0194481e+02 2.22e-16 1.90e-07  -8.6 3.18e-05    -  1.00e+00 1.00e+00f  1
#   42  5.0194481e+02 2.22e-16 4.87e-08  -8.6 1.60e-05    -  1.00e+00 1.00e+00h  1
#   43  5.0194481e+02 2.22e-16 1.10e-08  -8.6 7.65e-06    -  1.00e+00 1.00e+00h  1
#   44  5.0194481e+02 1.11e-16 3.44e-09  -9.0 4.04e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 44
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.0194480657431700e+02    5.0194480657431700e+02
# Dual infeasibility......:   3.4374756698729711e-09    3.4374756698729711e-09
# Constraint violation....:   1.1102230246251565e-16    1.1102230246251565e-16
# Complementarity.........:   2.5463696340627298e-09    2.5463696340627298e-09
# Overall NLP error.......:   3.4374756698729711e-09    3.4374756698729711e-09
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 45
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 45
# Number of equality constraint Jacobian evaluations   = 45
# Number of inequality constraint Jacobian evaluations = 45
# Number of Lagrangian Hessian evaluations             = 44
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.268
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      168
# Number of nonzeros in inequality constraint Jacobian.:      212
# Number of nonzeros in Lagrangian Hessian.............:       43
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      168
#                      variables with only lower bounds:      168
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      146
# Total number of inequality constraints...............:      106
#         inequality constraints with only lower bounds:      106
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.1801397e+03 9.80e-01 1.87e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.7836124e+03 9.69e-01 1.86e+04  -1.0 9.65e-01    -  1.13e-02 1.09e-02f  1
#    2  5.7804168e+03 9.69e-01 1.86e+04  -1.0 9.53e-01    -  3.60e-02 1.17e-04f  1
#    3  5.7065875e+03 9.67e-01 1.86e+04  -1.0 9.29e-01    -  1.21e-02 2.39e-03f  1
#    4  5.6608591e+03 9.66e-01 1.86e+04  -1.0 9.02e-01    -  1.76e-02 1.35e-03f  1
#    5  5.4923228e+03 9.61e-01 1.87e+04  -1.0 8.64e-01    -  1.29e-02 4.86e-03f  1
#    6  5.2548367e+03 9.54e-01 1.88e+04  -1.0 7.83e-01    -  1.03e-02 7.66e-03f  1
#    7  5.1938953e+03 9.51e-01 1.88e+04  -1.0 7.36e-01    -  2.20e-02 2.12e-03f  1
#    8  5.1077263e+03 9.49e-01 1.88e+04  -1.0 6.17e-01    -  3.13e-02 3.01e-03f  1
#    9  4.6820179e+03 9.32e-01 2.04e+04  -1.0 5.21e-01    -  4.14e-02 1.75e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.8958006e+03 8.83e-01 2.33e+04  -1.0 5.29e-01    -  3.74e-02 5.25e-02f  1
#   11  3.5179454e+03 8.47e-01 2.27e+04  -1.0 5.26e-01    -  2.80e-01 4.10e-02f  1
#   12  3.3179399e+03 8.23e-01 2.22e+04  -1.0 4.32e-01    -  2.85e-01 2.79e-02f  1
#   13  1.4260320e+03 2.88e-01 1.40e+04  -1.0 4.21e-01    -  2.78e-01 6.51e-01f  1
#   14  1.3448089e+03 2.43e-01 1.18e+04  -1.0 1.48e-01    -  4.57e-01 1.54e-01f  1
#   15  1.2298969e+03 1.74e-01 8.48e+03  -1.0 1.26e-01    -  3.22e-01 2.83e-01f  1
#   16  1.1037237e+03 9.19e-02 4.47e+03  -1.0 9.01e-02    -  1.59e-01 4.73e-01f  1
#   17  1.0927543e+03 8.41e-02 4.09e+03  -1.0 4.81e-02    -  1.23e-01 8.49e-02f  1
#   18  1.0609758e+03 6.34e-02 3.08e+03  -1.0 4.66e-02    -  2.64e-01 2.46e-01f  1
#   19  1.0248928e+03 3.98e-02 1.94e+03  -1.0 3.69e-02    -  2.45e-01 3.72e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  9.9675392e+02 2.25e-02 1.10e+03  -1.0 2.70e-02    -  2.96e-01 4.34e-01f  1
#   21  9.5721284e+02 2.24e-04 8.55e+02  -1.0 2.15e-02    -  2.99e-01 9.90e-01h  1
#   22  9.4534344e+02 1.27e-06 1.60e+04  -1.0 2.37e-02    -  6.27e-01 9.94e-01h  1
#   23  9.1959859e+02 1.11e-16 3.00e+06  -1.0 8.53e-02    -  3.09e-01 1.00e+00f  1
#   24  8.6344747e+02 1.11e-16 7.15e+06  -1.0 2.06e-01    -  1.72e-01 1.00e+00f  1
#   25  7.5452508e+02 2.22e-16 5.91e+06  -1.0 3.93e-01    -  1.73e-01 8.15e-01f  1
#   26  7.0565804e+02 2.22e-16 4.47e+06  -1.0 4.23e-01    -  2.43e-01 5.64e-01f  1
#   27  6.9377364e+02 1.11e-16 2.54e+06  -1.0 2.99e-01    -  4.33e-01 3.26e-01f  1
#   28  6.8873869e+02 1.11e-16 7.19e+05  -1.0 1.47e-01    -  7.16e-01 1.00e+00f  1
#   29  6.8767322e+02 2.22e-16 6.56e+01  -1.0 2.55e-02    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  6.8725506e+02 2.22e-16 3.01e+06  -5.7 2.55e-02    -  6.99e-01 1.00e+00f  1
#   31  6.8716583e+02 1.11e-16 4.97e+05  -5.7 9.20e-03    -  8.35e-01 1.00e+00f  1
#   32  6.8715120e+02 2.22e-16 2.78e+04  -5.7 3.54e-03    -  9.44e-01 1.00e+00f  1
#   33  6.8714768e+02 0.00e+00 2.48e+02  -5.7 1.98e-03    -  9.91e-01 1.00e+00f  1
#   34  6.8714723e+02 2.22e-16 4.20e-02  -5.7 9.60e-04    -  1.00e+00 1.00e+00f  1
#   35  6.8714720e+02 2.22e-16 3.22e-03  -5.7 3.72e-04    -  1.00e+00 1.00e+00f  1
#   36  6.8714720e+02 0.00e+00 3.40e-05  -5.7 7.78e-05    -  1.00e+00 1.00e+00f  1
#   37  6.8714720e+02 1.11e-16 1.29e-08  -5.7 3.73e-06    -  1.00e+00 1.00e+00h  1
#   38  6.8714719e+02 1.11e-16 4.63e-07  -8.6 6.87e-06    -  1.00e+00 1.00e+00f  1
#   39  6.8714719e+02 2.22e-16 8.56e-13  -8.6 2.98e-08    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 39
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.8714719462785570e+02    6.8714719462785570e+02
# Dual infeasibility......:   8.5574497090795790e-13    8.5574497090795790e-13
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.5060495608525558e-09    2.5060495608525558e-09
# Overall NLP error.......:   2.5060495608525558e-09    2.5060495608525558e-09
#
#
# Number of objective function evaluations             = 40
# Number of objective gradient evaluations             = 40
# Number of equality constraint evaluations            = 40
# Number of inequality constraint evaluations          = 40
# Number of equality constraint Jacobian evaluations   = 40
# Number of inequality constraint Jacobian evaluations = 40
# Number of Lagrangian Hessian evaluations             = 39
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.261
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      128
# Number of nonzeros in inequality constraint Jacobian.:      120
# Number of nonzeros in Lagrangian Hessian.............:       32
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      128
#                      variables with only lower bounds:      128
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      112
# Total number of inequality constraints...............:       60
#         inequality constraints with only lower bounds:       60
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.5998882e+03 9.80e-01 1.90e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.9237316e+03 9.62e-01 2.16e+04  -1.0 7.75e-01    -  1.45e-02 1.88e-02f  1
#    2  4.9204980e+03 9.61e-01 2.16e+04  -1.0 8.73e-01    -  6.48e-02 1.43e-04f  1
#    3  4.8318493e+03 9.58e-01 2.16e+04  -1.0 8.71e-01    -  1.83e-02 3.46e-03f  1
#    4  4.7269633e+03 9.54e-01 2.16e+04  -1.0 8.73e-01    -  2.61e-02 4.33e-03f  1
#    5  4.5556281e+03 9.47e-01 2.16e+04  -1.0 8.50e-01    -  4.40e-02 7.76e-03f  1
#    6  4.5188548e+03 9.45e-01 2.16e+04  -1.0 6.81e-01    -  1.77e-02 1.68e-03f  1
#    7  4.3479582e+03 9.37e-01 2.15e+04  -1.0 6.57e-01    -  2.48e-02 8.24e-03f  1
#    8  4.2547740e+03 9.33e-01 2.15e+04  -1.0 6.44e-01    -  3.29e-02 4.96e-03f  1
#    9  4.0803347e+03 9.23e-01 2.15e+04  -1.0 5.63e-01    -  4.11e-02 9.78e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.5096762e+03 8.82e-01 2.25e+04  -1.0 4.96e-01    -  8.76e-04 4.45e-02f  1
#   11  2.3614679e+03 7.09e-01 2.25e+04  -1.0 4.54e-01    -  9.07e-02 1.97e-01f  1
#   12  1.1898333e+03 2.47e-01 9.33e+03  -1.0 3.63e-01    -  6.13e-01 6.52e-01f  1
#   13  1.0646425e+03 1.66e-01 6.27e+03  -1.0 1.30e-01    -  4.45e-01 3.28e-01f  1
#   14  9.7143938e+02 9.98e-02 3.78e+03  -1.0 8.59e-02    -  5.20e-01 3.98e-01f  1
#   15  9.2063092e+02 6.18e-02 2.34e+03  -1.0 5.33e-02    -  2.74e-01 3.81e-01f  1
#   16  9.0001717e+02 4.59e-02 1.74e+03  -1.0 3.25e-02    -  9.20e-02 2.57e-01f  1
#   17  8.7138384e+02 2.36e-02 8.94e+02  -1.0 2.57e-02    -  2.63e-01 4.86e-01f  1
#   18  8.4119583e+02 2.35e-04 7.03e+02  -1.0 1.62e-02    -  3.52e-01 9.90e-01h  1
#   19  8.3846236e+02 1.38e-06 1.84e+04  -1.0 9.92e-03    -  5.51e-01 9.94e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.2716637e+02 0.00e+00 3.07e+06  -1.0 4.40e-02    -  2.59e-01 1.00e+00f  1
#   21  7.8406848e+02 1.11e-16 7.67e+06  -1.0 1.66e-01    -  1.38e-01 1.00e+00f  1
#   22  7.4658949e+02 2.22e-16 4.98e+06  -1.0 2.68e-01    -  3.51e-01 1.00e+00f  1
#   23  7.4033870e+02 1.11e-16 2.37e+06  -1.0 1.61e-01    -  5.25e-01 1.00e+00f  1
#   24  7.4031329e+02 2.22e-16 4.13e-02  -1.0 8.54e-03    -  1.00e+00 1.00e+00f  1
#   25  7.4000027e+02 1.84e-40 9.77e+05  -8.6 3.18e-02    -  9.02e-01 1.00e+00f  1
#   26  7.3994653e+02 1.11e-16 1.69e+05  -8.6 1.12e-02    -  8.27e-01 1.00e+00f  1
#   27  7.3993916e+02 2.22e-16 6.56e+03  -8.6 4.08e-03    -  9.61e-01 1.00e+00f  1
#   28  7.3993835e+02 1.11e-16 8.53e+01  -8.6 1.92e-03    -  9.87e-01 1.00e+00f  1
#   29  7.3993831e+02 2.22e-16 6.25e-05  -8.6 5.73e-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  7.3993831e+02 2.22e-16 1.04e-06  -8.6 6.18e-05    -  1.00e+00 1.00e+00f  1
#   31  7.3993831e+02 2.22e-16 2.90e-10  -8.6 9.99e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 31
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.3993831387689988e+02    7.3993831387689988e+02
# Dual infeasibility......:   2.8959189185063172e-10    2.8959189185063172e-10
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.6894958230567213e-09    2.6894958230567213e-09
# Overall NLP error.......:   2.6894958230567213e-09    2.6894958230567213e-09
#
#
# Number of objective function evaluations             = 32
# Number of objective gradient evaluations             = 32
# Number of equality constraint evaluations            = 32
# Number of inequality constraint evaluations          = 32
# Number of equality constraint Jacobian evaluations   = 32
# Number of inequality constraint Jacobian evaluations = 32
# Number of Lagrangian Hessian evaluations             = 31
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.231
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Solver found a solution.

# %%
# record kl loss of MDM
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),
                                'mdm_kl_loss':all_mdm_kl_loss[i],
                                'avg_mdm_kl_loss':all_mdm_avg_kl_loss[i],
                                'mdm_kl_time':all_total_time[i]})
    df_mdm_loss.to_csv('mdm/limit_loss/kl/'+str(pred_offer_times_list[i])+'.csv')

# %%
avg_total_kl_loss = []
avg_total_kl_loss_se = []
avg_avg_kl_loss = []
avg_avg_kl_loss_se = []

avg_runtime = []
avg_runtime_se = []

for i in range(len(pred_offer_times_list)):
    avg_total_kl_loss.append(np.mean(all_mdm_kl_loss[i]))
    avg_total_kl_loss_se.append(np.std(all_mdm_kl_loss[i])/np.sqrt(len(all_mdm_kl_loss[i])))
    
    avg_avg_kl_loss.append(np.mean(all_mdm_avg_kl_loss[i]))
    avg_avg_kl_loss_se.append(np.std(all_mdm_avg_kl_loss[i])/np.sqrt(len(all_mdm_avg_kl_loss[i])))
    
    avg_runtime.append(np.mean(all_total_time[i]))
    avg_runtime_se.append(np.std(all_total_time[i])/np.sqrt(len(all_total_time[i])) )
    
df_mdm_kl = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                   'total_mdm_kl_loss':avg_total_kl_loss,'total_mdm_kl_loss_se':avg_total_kl_loss_se,
                                   'avg_mdm_kl_loss':avg_avg_kl_loss,'avg_mdm_kl_loss_se':avg_avg_kl_loss_se,
                                   'mdm_kl_time':avg_runtime,'mdm_kl_time_se':avg_runtime_se
                                   })
df_mdm_kl.to_csv('mdm/mdm_kl_summary_hev_no_outside.csv')
df_mdm_kl
# Out:
#    offertimes  collection_size  total_mdm_kl_loss  total_mdm_kl_loss_se  \
# 0          15               30           0.015703              0.004945
# 1          20               21           0.000205              0.000203
# 2          30               16           0.001432              0.001418
# 3          40               11           0.000000              0.000000
# 4          50                7           0.000000              0.000000
#
#    avg_mdm_kl_loss  avg_mdm_kl_loss_se  mdm_kl_time  mdm_kl_time_se
# 0     1.051749e-05        3.312371e-06     0.408903        0.042297
# 1     1.526438e-07        1.511096e-07     0.016579        0.011495
# 2     1.177891e-06        1.166052e-06     0.007814        0.007614
# 3     0.000000e+00        0.000000e+00     0.000100        0.000004
# 4     0.000000e+00        0.000000e+00     0.000083        0.000004

# %%
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se
# 0          15               30     0.34      0.000661         0.000312
# 1          20               21     0.96      0.000133         0.000006
# 2          30               16     0.98      0.000126         0.000007
# 3          40               11     1.00      0.000100         0.000004
# 4          50                7     1.00      0.000083         0.000004

# %%
## adding limit results
#ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_mdm_kl_prob[i][j])
        df_limit_prob.to_csv('mdm/limit_prob/kl/offertimes'+str(pred_offer_times_list[i])+'/kl_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
pred_offer_times_list = [15,20,30,40,50]
pred_instance_size = [50,50,50,50,50]

# %%
df_mdm_rep_hev_summary = pd.read_csv('mdm/mdm_rep_summary_hev_no_outside.csv')
df_mdm_rep_hev_summary
# Out:
#    Unnamed: 0  offertimes  collection_size  mdm_rep  mdm_rep_time  \
# 0           0          15               30     0.34      0.000661
# 1           1          20               21     0.96      0.000133
# 2           2          30               16     0.98      0.000126
# 3           3          40               11     1.00      0.000100
# 4           4          50                7     1.00      0.000083
#
#    mdm_rep_time_se
# 0         0.000312
# 1         0.000006
# 2         0.000007
# 3         0.000004
# 4         0.000004

# %%
all_rep_approx = []
all_rep_approx_mean = []
for i in range(len(pred_offer_times_list)):
    rep_approx = []
    df_all_mdm_kl_loss = pd.read_csv('mdm/limit_loss/kl/'+str(pred_offer_times_list[i])+'.csv')
    mdm_avg_kl_loss_list = df_all_mdm_kl_loss['avg_mdm_kl_loss'].tolist()
    for j in range(pred_instance_size[i]):
        if mdm_avg_kl_loss_list[j]<1e-6:
            rep_approx.append(j)
    all_rep_approx.append(rep_approx)
    all_rep_approx_mean.append(len(rep_approx)/pred_instance_size[i])
all_rep_approx_mean
# Out:
# [0.66, 0.98, 0.98, 1.0, 1.0]

# %%
df_mdm_rep_hev_summary['mdm_rep_approx'] = all_rep_approx_mean
df_mdm_rep_hev_summary.to_csv('mdm/mdm_rep_summary_hev_no_outside.csv')

# %%
df_mdm_rep_hev_summary
# Out:
#    Unnamed: 0  offertimes  collection_size  mdm_rep  mdm_rep_time  \
# 0           0          15               30     0.34      0.000661
# 1           1          20               21     0.96      0.000133
# 2           2          30               16     0.98      0.000126
# 3           3          40               11     1.00      0.000100
# 4           4          50                7     1.00      0.000083
#
#    mdm_rep_time_se  mdm_rep_approx
# 0         0.000312            0.66
# 1         0.000006            0.98
# 2         0.000007            0.98
# 3         0.000004            1.00
# 4         0.000004            1.00

# %%
pred_offer_times_list = [15,20,30,40,50]
pred_instance_size = [50,50,50,50,50]

# %%
all_mdm_kl_loss = []
all_mdm_kl_runtime = []

for i in range(len(pred_offer_times_list)):
    df_mdm_kl = pd.read_csv('mdm/limit_loss/kl/'+str(pred_offer_times_list[i])+'.csv')
    all_mdm_kl_loss.append(df_mdm_kl['avg_mdm_kl_loss'].tolist())
    all_mdm_kl_runtime.append(df_mdm_kl['mdm_kl_time'].tolist())

# %%
def create_new_list(A, error_i, error_j):
    # Create a set of (i, j) pairs for fast lookup of error positions
    error_set = set(zip(error_i, error_j))
    
    # Create a new list of lists by excluding the elements that are in the error_set
    A_prime = []
    for i, row in enumerate(A):
        new_row = [elem for j, elem in enumerate(row) if (i, j) not in error_set]
        A_prime.append(new_row)
    
    return A_prime

error_instance_df = pd.read_csv('mccm_error_instance.csv')
error_i_raw = error_instance_df['error_i'].tolist()
error_j_raw = error_instance_df['error_j'].tolist()

error_i = []
error_j = []
for x in range(len(error_i_raw)):
    if error_i_raw[x]<=1:
        error_i.append(error_i_raw[x])
        error_j.append(error_j_raw[x])

new_all_mdm_loss = create_new_list(all_mdm_kl_loss,error_i,error_j)
new_all_mdm_time = create_new_list(all_mdm_kl_runtime,error_i,error_j)


for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'mdm_kl_loss':new_all_mdm_loss[i],'mdm_kl_time':new_all_mdm_time[i]})
    df_mdm_loss.to_csv('mdm/limit_loss_new/'+str(pred_offer_times_list[i])+'.csv')

mdm_kl_loss_mean = [np.mean(new_all_mdm_loss[x]) for x in range(len(pred_offer_times_list)) ]
mdm_kl_loss_se = [ np.std(new_all_mdm_loss[x])/np.sqrt(len(new_all_mdm_loss[x])) for x in range(len(pred_offer_times_list)) ]

mdm_kl_time_mean = [np.mean(new_all_mdm_time[x]) for x in range(len(pred_offer_times_list)) ]
mdm_kl_time_se = [ np.std(new_all_mdm_time[x])/np.sqrt(len(new_all_mdm_time[x])) for x in range(len(pred_offer_times_list)) ]

df_mdm_kl_loss = pd.DataFrame({'offertimes':pred_offer_times_list,
                                  'mdm_kl_loss':mdm_kl_loss_mean, 'mdm_kl_loss_se':mdm_kl_loss_se,
                                'mdm_kl_time':mdm_kl_time_mean, 'mdm_kl_time_se':mdm_kl_time_se
                                  })
df_mdm_kl_loss.to_csv('mdm/mdm_kl_summary_NEW.csv')
print(df_mdm_kl_loss)

all_rep = []
rep_mean = []
for i in range(len(pred_instance_size)):
    rep_lst = []
    for j in range(len(new_all_mdm_loss[i])):
        if new_all_mdm_loss[i][j] <1e-6:
            rep_lst.append(j)
    df_rep = pd.DataFrame(rep_lst)
    df_rep.to_csv('mdm/representability_new/'+str(pred_offer_times_list[i])+'.csv')
    all_rep.append(rep_lst)
    rep_mean.append(len(rep_lst)/len(new_all_mdm_loss[i]))
print(rep_mean)

df_rep = pd.DataFrame({'offertimes':pred_offer_times_list,'mdm_rep':rep_mean})
df_rep.to_csv('mdm/mdm_rep_summary_NEW.csv')
print(df_rep)
# Out:
#    offertimes   mdm_kl_loss  mdm_kl_loss_se  mdm_kl_time  mdm_kl_time_se
# 0          15  1.051749e-05    3.312371e-06     0.408903        0.042297
# 1          20  1.623870e-07    1.606502e-07     0.017628        0.012213
# 2          30  1.177891e-06    1.166052e-06     0.007814        0.007614
# 3          40  0.000000e+00    0.000000e+00     0.000100        0.000004
# 4          50  0.000000e+00    0.000000e+00     0.000083        0.000004
# [0.66, 0.9787234042553191, 0.98, 1.0, 1.0]
#    offertimes   mdm_rep
# 0          15  0.660000
# 1          20  0.978723
# 2          30  0.980000
# 3          40  1.000000
# 4          50  1.000000
