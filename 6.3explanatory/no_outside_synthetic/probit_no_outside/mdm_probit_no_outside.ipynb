# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import cvxpy as cp
from tkinter import _flatten
import copy
import time
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('choices.xlsm')  
offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
#offertimes.to_csv('offertimes.csv')
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
#inc_prod_num.to_csv('inc_prod_num.csv')
choice_prob = raw_jd_choice['clicknum'] / raw_jd_choice.groupby('clickset')['clicknum'].transform('sum')
raw_jd_choice['choice prob'] = choice_prob

assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

# all purchase options in each assortment
purchaseset = raw_jd_choice['purchaseset']
purchaseset_list = []
for pset in purchaseset:
    num_lst = json.loads(pset)
    purchaseset_list.append(num_lst)
raw_jd_choice['purchaseset'] = purchaseset_list

purchasenum_list = raw_jd_choice['clicknum'].tolist()
jd_choice=pd.DataFrame({'clickset':clickset_list,'purchaseset':purchaseset_list,'purchasenum':purchasenum_list,'choice prob':choice_prob})

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
collection = []
for cset in clickset_list:
    if cset not in collection:
        collection.append(cset)
print('there are {} different assortments'.format(len(collection)))

assortment_info_df['assortments'] = collection
choice_collection = np.zeros((n,len(collection)))
global_num = 0
for i in range(len(collection)):
    local_num =0
    while(local_num < inc_prod_num[i]):
        if purchaseset_list[global_num][0] in collection[i]:
            choice_collection[purchaseset_list[global_num][0]][i] = choice_prob[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print('error!')
# Out:
# there are 9 different products
# there are 134 different assortments

# %%
assortment_info_df_15 = assortment_info_df[(assortment_info_df['offer_times']>=15)]
assortments_15 = []
for i in range(len(assortment_info_df_15['assortments'])):
    assortments_15.append(assortment_info_df_15['assortments'][i])


jd_choice_15 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_15:
        jd_choice_15.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_15 = assortment_info_df_15['assortments']
choice_collection_15 = np.zeros((n,len(collection_15)))

frequency_collection_15 = np.zeros((n,len(collection_15)))

purchaseset_list_15 = jd_choice_15['purchaseset'].tolist()

inc_prod_num_15 = assortment_info_df_15['includ_prod_num']
choice_prob_15 = jd_choice_15['choice prob']
frequency_15 = jd_choice_15['purchasenum']

global_num = 0
for i in range(len(collection_15)):
    local_num =0
    while(local_num < inc_prod_num_15[i]):
        if purchaseset_list_15[global_num][0] in assortments_15[i]:
            choice_collection_15[purchaseset_list_15[global_num][0]][i] = choice_prob_15[global_num]
            frequency_collection_15[purchaseset_list_15[global_num][0]][i] = frequency_15[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_15[global_num])
            print(assortments_15[i])
            print('error!')
            break

offer_times_15 = assortment_info_df_15['offer_times'].tolist()
print('the number of assortments with at least 15 purchases is',len(assortments_15))
# Out:
# the number of assortments with at least 15 purchases is 38

# %%
assortment_info_df_20 = assortment_info_df[(assortment_info_df['offer_times']>=20)]
assortments_20 = []
for i in range(len(assortment_info_df_20['assortments'])):
    assortments_20.append(assortment_info_df_20['assortments'][i])


jd_choice_20 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_20:
        jd_choice_20.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_20 = assortment_info_df_20['assortments']
choice_collection_20 = np.zeros((n,len(collection_20)))

frequency_collection_20 = np.zeros((n,len(collection_20)))

purchaseset_list_20 = jd_choice_20['purchaseset'].tolist()

inc_prod_num_20 = assortment_info_df_20['includ_prod_num']
choice_prob_20 = jd_choice_20['choice prob']
frequency_20 = jd_choice_20['purchasenum']

global_num = 0
for i in range(len(collection_20)):
    local_num =0
    while(local_num < inc_prod_num_20[i]):
        if purchaseset_list_20[global_num][0] in assortments_20[i]:
            choice_collection_20[purchaseset_list_20[global_num][0]][i] = choice_prob_20[global_num]
            frequency_collection_20[purchaseset_list_20[global_num][0]][i] = frequency_20[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_20[global_num])
            print(assortments_20[i])
            print('error!')
            break


offer_times_20 = assortment_info_df_20['offer_times'].tolist()
print('the number of assortments with at least 20 purchases is',len(assortments_20))
# Out:
# the number of assortments with at least 20 purchases is 29

# %%
assortment_info_df_30 = assortment_info_df[(assortment_info_df['offer_times']>=30)]
assortments_30 = []
for i in range(len(assortment_info_df_30['assortments'])):
    assortments_30.append(assortment_info_df_30['assortments'][i])


jd_choice_30 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_30:
        jd_choice_30.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_30 = assortment_info_df_30['assortments']
choice_collection_30 = np.zeros((n,len(collection_30)))

frequency_collection_30 = np.zeros((n,len(collection_30)))

purchaseset_list_30 = jd_choice_30['purchaseset'].tolist()

inc_prod_num_30 = assortment_info_df_30['includ_prod_num']
choice_prob_30 = jd_choice_30['choice prob']
frequency_30 = jd_choice_30['purchasenum']

global_num = 0
for i in range(len(collection_30)):
    local_num =0
    while(local_num < inc_prod_num_30[i]):
        if purchaseset_list_30[global_num][0] in assortments_30[i]:
            choice_collection_30[purchaseset_list_30[global_num][0]][i] = choice_prob_30[global_num]
            frequency_collection_30[purchaseset_list_30[global_num][0]][i] = frequency_30[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_30[global_num])
            print(assortments_30[i])
            print('error!')
            break



offer_times_30 = assortment_info_df_30['offer_times'].tolist()
print('the number of assortments with at least 30 purchases is',len(assortments_30))
# Out:
# the number of assortments with at least 30 purchases is 24

# %%
assortment_info_df_40 = assortment_info_df[(assortment_info_df['offer_times']>=40)]
assortments_40 = []
for i in range(len(assortment_info_df_40['assortments'])):
    assortments_40.append(assortment_info_df_40['assortments'][i])


jd_choice_40 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_40:
        jd_choice_40.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_40 = assortment_info_df_40['assortments']
choice_collection_40 = np.zeros((n,len(collection_40)))

frequency_collection_40 = np.zeros((n,len(collection_40)))

purchaseset_list_40 = jd_choice_40['purchaseset'].tolist()

inc_prod_num_40 = assortment_info_df_40['includ_prod_num']
choice_prob_40 = jd_choice_40['choice prob']
frequency_40 = jd_choice_40['purchasenum']

global_num = 0
for i in range(len(collection_40)):
    local_num =0
    while(local_num < inc_prod_num_40[i]):
        if purchaseset_list_40[global_num][0] in assortments_40[i]:
            choice_collection_40[purchaseset_list_40[global_num][0]][i] = choice_prob_40[global_num]
            frequency_collection_40[purchaseset_list_40[global_num][0]][i] = frequency_40[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_40[global_num])
            print(assortments_40[i])
            print('error!')
            break



offer_times_40 = assortment_info_df_40['offer_times'].tolist()
print('the number of assortments with at least 40 purchases is',len(assortments_40))
# Out:
# the number of assortments with at least 40 purchases is 19

# %%
assortment_info_df_50 = assortment_info_df[(assortment_info_df['offer_times']>=50)]
assortments_50 = []
for i in range(len(assortment_info_df_50['assortments'])):
    assortments_50.append(assortment_info_df_50['assortments'][i])


jd_choice_50 = pd.DataFrame(columns=jd_choice.columns)

num = 0
for i in range(len(jd_choice)):
    if jd_choice['clickset'][i] in assortments_50:
        jd_choice_50.loc[num] = jd_choice.loc[i]
        num = num+1 

collection_50 = assortment_info_df_50['assortments']
choice_collection_50 = np.zeros((n,len(collection_50)))

frequency_collection_50 = np.zeros((n,len(collection_50)))

purchaseset_list_50 = jd_choice_50['purchaseset'].tolist()

inc_prod_num_50 = assortment_info_df_50['includ_prod_num']
choice_prob_50 = jd_choice_50['choice prob']
frequency_50 = jd_choice_50['purchasenum']

global_num = 0
for i in range(len(collection_50)):
    local_num =0
    while(local_num < inc_prod_num_50[i]):
        if purchaseset_list_50[global_num][0] in assortments_50[i]:
            choice_collection_50[purchaseset_list_50[global_num][0]][i] = choice_prob_50[global_num]
            frequency_collection_50[purchaseset_list_50[global_num][0]][i] = frequency_50[global_num]
            global_num = global_num +1
            local_num = local_num +1
        else:
            print(purchaseset_list_50[global_num])
            print(assortments_50[i])
            print('error!')
            break


offer_times_50 = assortment_info_df_50['offer_times'].tolist()
print('the number of assortments with at least 50 purchases is',len(assortments_50))
# Out:
# the number of assortments with at least 50 purchases is 15

# %%
def new_data_w_at_least_2_products(n,curr_collection,curr_choice_collection,curr_offertimes):
    
    pre_new_collection = []
    new_collection_indices = []
    new_offertimes = []
    
    for i in range(len(curr_collection)):
        if len(curr_collection[i])>2:
            pre_new_collection.append(curr_collection[i][1:])
            new_collection_indices.append(i)
            new_offertimes.append(curr_offertimes[i])
            
    # Reduce values of all elements by 1
    new_collection = [[element - 1 for element in sublist] for sublist in pre_new_collection]

    new_choice_collection = np.zeros((n-1,len(new_collection_indices)))
    for i in range(len(new_collection_indices)):
        new_choice_collection[:,i] = curr_choice_collection[1:,new_collection_indices[i]]/np.sum(curr_choice_collection[1:,new_collection_indices[i]])
            
    return new_collection,new_choice_collection,new_offertimes

# %%
new_assortment_15,new_choice_collection_15,new_offer_times_15 = new_data_w_at_least_2_products(n,assortments_15,choice_collection_15,offer_times_15)
print('the new size of the collection with offertimes at least 15 is ',len(new_assortment_15))

new_assortment_20,new_choice_collection_20,new_offer_times_20 = new_data_w_at_least_2_products(n,assortments_20,choice_collection_20,offer_times_20)
print('the new size of the collection with offertimes at least 20 is ',len(new_assortment_20))

new_assortment_30,new_choice_collection_30,new_offer_times_30 = new_data_w_at_least_2_products(n,assortments_30,choice_collection_30,offer_times_30)
print('the new size of the collection with offertimes at least 30 is ',len(new_assortment_30))

new_assortment_40,new_choice_collection_40,new_offer_times_40 = new_data_w_at_least_2_products(n,assortments_40,choice_collection_40,offer_times_40)
print('the new size of the collection with offertimes at least 40 is ',len(new_assortment_40))

new_assortment_50,new_choice_collection_50,new_offer_times_50 = new_data_w_at_least_2_products(n,assortments_50,choice_collection_50,offer_times_50)
print('the new size of the collection with offertimes at least 50 is ',len(new_assortment_50))
# Out:
# the new size of the collection with offertimes at least 15 is  30
# the new size of the collection with offertimes at least 20 is  21
# the new size of the collection with offertimes at least 30 is  16
# the new size of the collection with offertimes at least 40 is  11
# the new size of the collection with offertimes at least 50 is  7

# %%
def generate_negatively_correlated_covariance_matrix(n):
    # Generate a random correlation matrix with negative correlations
    correlation_matrix = np.random.uniform(low=-0.9, high=-0.1, size=(n, n))
    np.fill_diagonal(correlation_matrix, 1)  # Set diagonal elements to 1
    correlation_matrix = (correlation_matrix + correlation_matrix.T) / 2  # Ensure symmetry

    # Ensure the correlation matrix is valid for Cholesky decomposition
    cholesky_success = False
    while not cholesky_success:
        try:
            # Perform Cholesky decomposition
            cholesky_matrix = np.linalg.cholesky(correlation_matrix)
            cholesky_success = True
        except np.linalg.LinAlgError:
            # If Cholesky decomposition fails, adjust the correlation matrix slightly
            correlation_matrix += np.eye(n) * 0.01  # Adjust diagonal elements slightly

    # Generate random standard deviations
    standard_deviations = np.random.uniform(0.5, 2, size=n)
    
    ''' variance_outsideopt = np.random.uniform(30,40)
    variance_products = np.random.uniform(0.5,2,size=n-1)
    standard_deviations = np.hstack((variance_outsideopt,variance_products)) '''
    # Construct diagonal matrix from standard deviations
    diagonal_matrix = np.diag(standard_deviations)
    #diagonal_matrix = np.eye(n)

    # Calculate the covariance matrix using Cholesky decomposition and diagonal matrix
    covariance_matrix = cholesky_matrix @ diagonal_matrix @ cholesky_matrix.T

    return covariance_matrix

# %%
def is_positive_semidefinite(matrix):
    """
    Check if a matrix is positive semidefinite.
    
    Args:
        matrix (numpy.ndarray): The matrix to check.
        
    Returns:
        bool: True if the matrix is positive semidefinite, False otherwise.
    """
    # Check if the matrix is symmetric
    if not np.allclose(matrix, matrix.T):
        return False
    
    # Check if all eigenvalues are non-negative
    eigvals, _ = np.linalg.eig(matrix)
    return np.all(eigvals >= 0)

# %%
def collection_distribution_prob_neg(n,collection):
    # generate mean 
    mu = np.random.uniform(-2,2,n)
   
    # generate covariance matrix with positive correlation
    neg_cov = generate_negatively_correlated_covariance_matrix(n)
    if is_positive_semidefinite(neg_cov): 
        sample_size = 10000
        utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    else:
        print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 
        
        
        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
pred_offer_times_list = [15,20,30,40,50]
pred_instance_size = [50,50,50,50,50]

# %%
all_full_collections = [new_assortment_15,new_assortment_20,new_assortment_30,new_assortment_40,new_assortment_50]
all_full_offertimes = [new_offer_times_15,new_offer_times_20,new_offer_times_30,new_offer_times_40,new_offer_times_50]
full_collection_size = [len(new_offer_times_15),len(new_offer_times_20),len(new_offer_times_30),len(new_offer_times_40),len(new_offer_times_50)]

# %%
# full instance generation 
all_full_instances = []
for i in range(len(pred_offer_times_list)):
    
    full_instances_collection = []
    
    for j in range(pred_instance_size[i]):
        # generate true hev instance
        true_hev_instance = collection_distribution_prob_neg(n-1,all_full_collections[i])
        full_instances_collection.append(true_hev_instance)

    
    all_full_instances.append(full_instances_collection)

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm_feasibility')
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    lam_values = [lam[i].x for i in range(data.shape[1])]
    lam_values = np.array(lam_values)

    if (model.objVal> 0):
        #model.write("mdmfeas_out.sol")
        #model.write("mdmfeas_model.lp") 
        return [1,model.Runtime,lam_values]
    else:
        #model.write("mdminfeas_model.lp")
        #return [0, used_time]
        return [0,model.Runtime,lam_values]

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.001

    model = gp.Model('mdm_limit')
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{i}_{j}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}")

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    if model.Status == GRB.OPTIMAL:
        x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
        x_values = np.array(x_values)
        
        lam_values = [lam[i].x for i in range(m)]
        lam_values = np.array(lam_values)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print('mdm limit computation error')
        #model.write("mdmlimit_out.sol")
        #model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,x_values]

# %%
## record the limit loss of all instances

all_mdm_rep = []
all_mdm_rep_time = []

all_mdm_limit_loss = []
all_mdm_limit_prob = []
all_mdm_limit_lam = []
all_mdm_limit_runtime = []

all_mdm_infeasible_index = []


for i in range(len(pred_offer_times_list)):
    
    ## define contrainer for mdm representability
    mdm_rep_collection = []
    mdm_rep_time_collection = []
    mdm_infeasible_index_collection = []
    
    ## define container for mdm limit 
    mdm_limit_loss_collection =[]
    mdm_limit_runtime_collection =[]
    mdm_limit_probability_collection =[]
    mdm_limit_lam_collection =[]
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        # data pre-process
        row_data = row_assortment_data(all_full_instances[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result = mdm_feasibility(all_full_instances[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection.append(curr_rep_result[0])
        mdm_rep_time_collection.append(curr_rep_result[1])
        
        # check if representable
        if curr_rep_result[0] > 0:
            print(f'instance offertimes {pred_offer_times_list[i]}, {j}th is representable by mdm with runtime {curr_rep_result[1]}')
            mdm_limit_loss_collection.append(0)
            mdm_limit_runtime_collection.append(curr_rep_result[1])
            mdm_limit_probability_collection.append(all_full_instances[i][j])
            mdm_limit_lam_collection.append(curr_rep_result[2])
        else:
            print(f'instance offertimes {pred_offer_times_list[i]}, {j}th is NOT representable by mdm')
            mdm_infeasible_index_collection.append(j)
            curr_limit_result = mdm_limit(all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            mdm_limit_loss_collection.append(curr_limit_result[0])
            mdm_limit_probability_collection.append(curr_limit_result[-1])
            mdm_limit_runtime_collection.append(curr_limit_result[1])
            mdm_limit_lam_collection.append(curr_limit_result[2])
            print(f'mdm 1-norm loss is {curr_limit_result[0]} with run time {curr_limit_result[1]}')
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep.append(mdm_rep_collection)
    all_mdm_rep_time.append(mdm_rep_time_collection) 
    all_mdm_infeasible_index.append(mdm_infeasible_index_collection)     
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss.append(mdm_limit_loss_collection)
    all_mdm_limit_runtime.append(mdm_limit_runtime_collection)
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob.append(mdm_limit_probability_collection)
    all_mdm_limit_lam.append(mdm_limit_lam_collection)
# Out:
# testing instance with offertimes 15 : 0th
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# instance offertimes 15, 0th is NOT representable by mdm
# mdm 1-norm loss is 0.09871019999999975 with run time 0.15989089012145996
# testing instance with offertimes 15 : 1th
# instance offertimes 15, 1th is NOT representable by mdm
# mdm 1-norm loss is 0.030590999999999723 with run time 0.13698792457580566
# testing instance with offertimes 15 : 2th
# instance offertimes 15, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.10985489999999962 with run time 0.10903501510620117
# testing instance with offertimes 15 : 3th
# instance offertimes 15, 3th is representable by mdm with runtime 0.0002989768981933594
# testing instance with offertimes 15 : 4th
# instance offertimes 15, 4th is NOT representable by mdm
# mdm 1-norm loss is 0.10630080000000147 with run time 0.15639996528625488
# testing instance with offertimes 15 : 5th
# instance offertimes 15, 5th is representable by mdm with runtime 0.0004968643188476562
# testing instance with offertimes 15 : 6th
# instance offertimes 15, 6th is representable by mdm with runtime 0.0006928443908691406
# testing instance with offertimes 15 : 7th
# instance offertimes 15, 7th is NOT representable by mdm
# mdm 1-norm loss is 0.05674800000000005 with run time 0.08899688720703125
# testing instance with offertimes 15 : 8th
# instance offertimes 15, 8th is NOT representable by mdm
# mdm 1-norm loss is 0.08008649999999942 with run time 0.10667800903320312
# testing instance with offertimes 15 : 9th
# instance offertimes 15, 9th is NOT representable by mdm
# mdm 1-norm loss is 0.08454100000000057 with run time 0.10157299041748047
# testing instance with offertimes 15 : 10th
# instance offertimes 15, 10th is NOT representable by mdm
# mdm 1-norm loss is 0.19030032000000058 with run time 0.09313201904296875
# testing instance with offertimes 15 : 11th
# instance offertimes 15, 11th is representable by mdm with runtime 0.00029397010803222656
# testing instance with offertimes 15 : 12th
# instance offertimes 15, 12th is NOT representable by mdm
# mdm 1-norm loss is 0.04876860000000044 with run time 0.07897186279296875
# testing instance with offertimes 15 : 13th
# instance offertimes 15, 13th is representable by mdm with runtime 0.0002989768981933594
# testing instance with offertimes 15 : 14th
# instance offertimes 15, 14th is representable by mdm with runtime 0.00013113021850585938
# testing instance with offertimes 15 : 15th
# instance offertimes 15, 15th is NOT representable by mdm
# mdm 1-norm loss is 0.03291408000000019 with run time 0.08411502838134766
# testing instance with offertimes 15 : 16th
# instance offertimes 15, 16th is NOT representable by mdm
# mdm 1-norm loss is 0.18927900000000203 with run time 0.1781320571899414
# testing instance with offertimes 15 : 17th
# instance offertimes 15, 17th is representable by mdm with runtime 0.0003650188446044922
# testing instance with offertimes 15 : 18th
# instance offertimes 15, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.14602648000000001 with run time 0.10504007339477539
# testing instance with offertimes 15 : 19th
# instance offertimes 15, 19th is NOT representable by mdm
# mdm 1-norm loss is 0.08486880000000044 with run time 0.1299290657043457
# testing instance with offertimes 15 : 20th
# instance offertimes 15, 20th is NOT representable by mdm
# mdm 1-norm loss is 0.022506749999999964 with run time 0.08033013343811035
# testing instance with offertimes 15 : 21th
# instance offertimes 15, 21th is representable by mdm with runtime 0.00035119056701660156
# testing instance with offertimes 15 : 22th
# instance offertimes 15, 22th is NOT representable by mdm
# mdm 1-norm loss is 0.05770380000000059 with run time 0.07842206954956055
# testing instance with offertimes 15 : 23th
# instance offertimes 15, 23th is NOT representable by mdm
# mdm 1-norm loss is 0.022894559999999974 with run time 0.10542082786560059
# testing instance with offertimes 15 : 24th
# instance offertimes 15, 24th is NOT representable by mdm
# mdm 1-norm loss is 0.08953637000000089 with run time 0.10968995094299316
# testing instance with offertimes 15 : 25th
# instance offertimes 15, 25th is representable by mdm with runtime 0.0004918575286865234
# testing instance with offertimes 15 : 26th
# instance offertimes 15, 26th is representable by mdm with runtime 0.00018596649169921875
# testing instance with offertimes 15 : 27th
# instance offertimes 15, 27th is NOT representable by mdm
# mdm 1-norm loss is 0.013997040000000193 with run time 0.11139798164367676
# testing instance with offertimes 15 : 28th
# instance offertimes 15, 28th is NOT representable by mdm
# mdm 1-norm loss is 0.07380000000000031 with run time 0.0945580005645752
# testing instance with offertimes 15 : 29th
# instance offertimes 15, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.059599050000000126 with run time 0.10405802726745605
# testing instance with offertimes 15 : 30th
# instance offertimes 15, 30th is representable by mdm with runtime 0.0002989768981933594
# testing instance with offertimes 15 : 31th
# instance offertimes 15, 31th is representable by mdm with runtime 0.00016307830810546875
# testing instance with offertimes 15 : 32th
# instance offertimes 15, 32th is representable by mdm with runtime 0.00017881393432617188
# testing instance with offertimes 15 : 33th
# instance offertimes 15, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.06178409999999755 with run time 0.08699798583984375
# testing instance with offertimes 15 : 34th
# instance offertimes 15, 34th is representable by mdm with runtime 0.00035500526428222656
# testing instance with offertimes 15 : 35th
# instance offertimes 15, 35th is representable by mdm with runtime 0.0003180503845214844
# testing instance with offertimes 15 : 36th
# instance offertimes 15, 36th is representable by mdm with runtime 0.00020003318786621094
# testing instance with offertimes 15 : 37th
# instance offertimes 15, 37th is NOT representable by mdm
# mdm 1-norm loss is 0.17571063000000117 with run time 0.15383386611938477
# testing instance with offertimes 15 : 38th
# instance offertimes 15, 38th is representable by mdm with runtime 0.0003609657287597656
# testing instance with offertimes 15 : 39th
# instance offertimes 15, 39th is NOT representable by mdm
# mdm 1-norm loss is 0.04500000000000004 with run time 0.10364603996276855
# testing instance with offertimes 15 : 40th
# instance offertimes 15, 40th is NOT representable by mdm
# mdm 1-norm loss is 0.022859999999999953 with run time 0.1592409610748291
# testing instance with offertimes 15 : 41th
# instance offertimes 15, 41th is representable by mdm with runtime 0.0003299713134765625
# testing instance with offertimes 15 : 42th
# instance offertimes 15, 42th is representable by mdm with runtime 0.0001709461212158203
# testing instance with offertimes 15 : 43th
# instance offertimes 15, 43th is NOT representable by mdm
# mdm 1-norm loss is 0.018912960000000284 with run time 0.07890200614929199
# testing instance with offertimes 15 : 44th
# instance offertimes 15, 44th is representable by mdm with runtime 0.0004839897155761719
# testing instance with offertimes 15 : 45th
# instance offertimes 15, 45th is NOT representable by mdm
# mdm 1-norm loss is 0.14637494999999986 with run time 0.08525800704956055
# testing instance with offertimes 15 : 46th
# instance offertimes 15, 46th is NOT representable by mdm
# mdm 1-norm loss is 0.2582596400000065 with run time 0.13739585876464844
# testing instance with offertimes 15 : 47th
# instance offertimes 15, 47th is NOT representable by mdm
# mdm 1-norm loss is 0.0867824999999993 with run time 0.09840703010559082
# testing instance with offertimes 15 : 48th
# instance offertimes 15, 48th is NOT representable by mdm
# mdm 1-norm loss is 0.035060480000000074 with run time 0.1259911060333252
# testing instance with offertimes 15 : 49th
# instance offertimes 15, 49th is NOT representable by mdm
# mdm 1-norm loss is 0.04903679999999971 with run time 0.11763405799865723
# testing instance with offertimes 20 : 0th
# instance offertimes 20, 0th is representable by mdm with runtime 0.00047016143798828125
# testing instance with offertimes 20 : 1th
# instance offertimes 20, 1th is representable by mdm with runtime 0.00014281272888183594
# testing instance with offertimes 20 : 2th
# instance offertimes 20, 2th is NOT representable by mdm
# mdm 1-norm loss is 0.44880000000000164 with run time 0.06492900848388672
# testing instance with offertimes 20 : 3th
# instance offertimes 20, 3th is NOT representable by mdm
# mdm 1-norm loss is 0.012800000000002143 with run time 0.057157039642333984
# testing instance with offertimes 20 : 4th
# instance offertimes 20, 4th is representable by mdm with runtime 0.0008139610290527344
# testing instance with offertimes 20 : 5th
# instance offertimes 20, 5th is representable by mdm with runtime 0.0002510547637939453
# testing instance with offertimes 20 : 6th
# instance offertimes 20, 6th is representable by mdm with runtime 0.0004010200500488281
# testing instance with offertimes 20 : 7th
# instance offertimes 20, 7th is representable by mdm with runtime 0.00022602081298828125
# testing instance with offertimes 20 : 8th
# instance offertimes 20, 8th is representable by mdm with runtime 0.0001399517059326172
# testing instance with offertimes 20 : 9th
# instance offertimes 20, 9th is representable by mdm with runtime 0.00020599365234375
# testing instance with offertimes 20 : 10th
# instance offertimes 20, 10th is representable by mdm with runtime 0.00024390220642089844
# testing instance with offertimes 20 : 11th
# instance offertimes 20, 11th is representable by mdm with runtime 0.00019502639770507812
# testing instance with offertimes 20 : 12th
# instance offertimes 20, 12th is representable by mdm with runtime 0.00018095970153808594
# testing instance with offertimes 20 : 13th
# instance offertimes 20, 13th is representable by mdm with runtime 0.0002090930938720703
# testing instance with offertimes 20 : 14th
# instance offertimes 20, 14th is representable by mdm with runtime 0.00012087821960449219
# testing instance with offertimes 20 : 15th
# instance offertimes 20, 15th is representable by mdm with runtime 0.00016188621520996094
# testing instance with offertimes 20 : 16th
# instance offertimes 20, 16th is representable by mdm with runtime 0.002229928970336914
# testing instance with offertimes 20 : 17th
# instance offertimes 20, 17th is representable by mdm with runtime 0.00021195411682128906
# testing instance with offertimes 20 : 18th
# instance offertimes 20, 18th is NOT representable by mdm
# mdm 1-norm loss is 0.0031999999999996476 with run time 0.03679394721984863
# testing instance with offertimes 20 : 19th
# instance offertimes 20, 19th is representable by mdm with runtime 0.0001571178436279297
# testing instance with offertimes 20 : 20th
# instance offertimes 20, 20th is representable by mdm with runtime 0.00017881393432617188
# testing instance with offertimes 20 : 21th
# instance offertimes 20, 21th is representable by mdm with runtime 0.0003440380096435547
# testing instance with offertimes 20 : 22th
# instance offertimes 20, 22th is representable by mdm with runtime 0.00034999847412109375
# testing instance with offertimes 20 : 23th
# instance offertimes 20, 23th is representable by mdm with runtime 0.00028014183044433594
# testing instance with offertimes 20 : 24th
# instance offertimes 20, 24th is representable by mdm with runtime 0.0003337860107421875
# testing instance with offertimes 20 : 25th
# instance offertimes 20, 25th is NOT representable by mdm
# mdm 1-norm loss is 0.05599999999999958 with run time 0.03741002082824707
# testing instance with offertimes 20 : 26th
# instance offertimes 20, 26th is representable by mdm with runtime 0.00021505355834960938
# testing instance with offertimes 20 : 27th
# instance offertimes 20, 27th is representable by mdm with runtime 0.00022912025451660156
# testing instance with offertimes 20 : 28th
# instance offertimes 20, 28th is representable by mdm with runtime 0.0005099773406982422
# testing instance with offertimes 20 : 29th
# instance offertimes 20, 29th is representable by mdm with runtime 0.00032806396484375
# testing instance with offertimes 20 : 30th
# instance offertimes 20, 30th is representable by mdm with runtime 0.0002300739288330078
# testing instance with offertimes 20 : 31th
# instance offertimes 20, 31th is representable by mdm with runtime 0.0001990795135498047
# testing instance with offertimes 20 : 32th
# instance offertimes 20, 32th is representable by mdm with runtime 0.0002510547637939453
# testing instance with offertimes 20 : 33th
# instance offertimes 20, 33th is representable by mdm with runtime 0.00015592575073242188
# testing instance with offertimes 20 : 34th
# instance offertimes 20, 34th is representable by mdm with runtime 0.00014209747314453125
# testing instance with offertimes 20 : 35th
# instance offertimes 20, 35th is representable by mdm with runtime 0.0002582073211669922
# testing instance with offertimes 20 : 36th
# instance offertimes 20, 36th is representable by mdm with runtime 0.00015401840209960938
# testing instance with offertimes 20 : 37th
# instance offertimes 20, 37th is representable by mdm with runtime 0.00014901161193847656
# testing instance with offertimes 20 : 38th
# instance offertimes 20, 38th is representable by mdm with runtime 0.0002410411834716797
# testing instance with offertimes 20 : 39th
# instance offertimes 20, 39th is representable by mdm with runtime 0.0002219676971435547
# testing instance with offertimes 20 : 40th
# instance offertimes 20, 40th is representable by mdm with runtime 0.0002849102020263672
# testing instance with offertimes 20 : 41th
# instance offertimes 20, 41th is representable by mdm with runtime 0.00016498565673828125
# testing instance with offertimes 20 : 42th
# instance offertimes 20, 42th is representable by mdm with runtime 0.00016379356384277344
# testing instance with offertimes 20 : 43th
# instance offertimes 20, 43th is representable by mdm with runtime 0.0002129077911376953
# testing instance with offertimes 20 : 44th
# instance offertimes 20, 44th is representable by mdm with runtime 0.0001590251922607422
# testing instance with offertimes 20 : 45th
# instance offertimes 20, 45th is representable by mdm with runtime 0.00015091896057128906
# testing instance with offertimes 20 : 46th
# instance offertimes 20, 46th is representable by mdm with runtime 0.00015687942504882812
# testing instance with offertimes 20 : 47th
# instance offertimes 20, 47th is representable by mdm with runtime 0.00015091896057128906
# testing instance with offertimes 20 : 48th
# instance offertimes 20, 48th is representable by mdm with runtime 0.0001571178436279297
# testing instance with offertimes 20 : 49th
# instance offertimes 20, 49th is representable by mdm with runtime 0.00014495849609375
# testing instance with offertimes 30 : 0th
# instance offertimes 30, 0th is representable by mdm with runtime 0.0004029273986816406
# testing instance with offertimes 30 : 1th
# instance offertimes 30, 1th is representable by mdm with runtime 0.0003209114074707031
# testing instance with offertimes 30 : 2th
# instance offertimes 30, 2th is representable by mdm with runtime 0.00023698806762695312
# testing instance with offertimes 30 : 3th
# instance offertimes 30, 3th is representable by mdm with runtime 0.00023603439331054688
# testing instance with offertimes 30 : 4th
# instance offertimes 30, 4th is representable by mdm with runtime 0.0001590251922607422
# testing instance with offertimes 30 : 5th
# instance offertimes 30, 5th is representable by mdm with runtime 0.0001518726348876953
# testing instance with offertimes 30 : 6th
# instance offertimes 30, 6th is representable by mdm with runtime 0.00021910667419433594
# testing instance with offertimes 30 : 7th
# instance offertimes 30, 7th is representable by mdm with runtime 0.00015401840209960938
# testing instance with offertimes 30 : 8th
# instance offertimes 30, 8th is representable by mdm with runtime 0.00023102760314941406
# testing instance with offertimes 30 : 9th
# instance offertimes 30, 9th is representable by mdm with runtime 0.0002970695495605469
# testing instance with offertimes 30 : 10th
# instance offertimes 30, 10th is representable by mdm with runtime 0.0001800060272216797
# testing instance with offertimes 30 : 11th
# instance offertimes 30, 11th is representable by mdm with runtime 0.0001590251922607422
# testing instance with offertimes 30 : 12th
# instance offertimes 30, 12th is representable by mdm with runtime 0.00025010108947753906
# testing instance with offertimes 30 : 13th
# instance offertimes 30, 13th is representable by mdm with runtime 0.0001499652862548828
# testing instance with offertimes 30 : 14th
# instance offertimes 30, 14th is representable by mdm with runtime 0.00016999244689941406
# testing instance with offertimes 30 : 15th
# instance offertimes 30, 15th is representable by mdm with runtime 0.0001900196075439453
# testing instance with offertimes 30 : 16th
# instance offertimes 30, 16th is representable by mdm with runtime 0.00013399124145507812
# testing instance with offertimes 30 : 17th
# instance offertimes 30, 17th is representable by mdm with runtime 0.0004169940948486328
# testing instance with offertimes 30 : 18th
# instance offertimes 30, 18th is representable by mdm with runtime 0.0002200603485107422
# testing instance with offertimes 30 : 19th
# instance offertimes 30, 19th is representable by mdm with runtime 0.0002319812774658203
# testing instance with offertimes 30 : 20th
# instance offertimes 30, 20th is representable by mdm with runtime 0.00020313262939453125
# testing instance with offertimes 30 : 21th
# instance offertimes 30, 21th is representable by mdm with runtime 0.0004260540008544922
# testing instance with offertimes 30 : 22th
# instance offertimes 30, 22th is representable by mdm with runtime 0.0003509521484375
# testing instance with offertimes 30 : 23th
# instance offertimes 30, 23th is representable by mdm with runtime 0.00022602081298828125
# testing instance with offertimes 30 : 24th
# instance offertimes 30, 24th is representable by mdm with runtime 0.00025391578674316406
# testing instance with offertimes 30 : 25th
# instance offertimes 30, 25th is representable by mdm with runtime 0.00021600723266601562
# testing instance with offertimes 30 : 26th
# instance offertimes 30, 26th is NOT representable by mdm
# mdm 1-norm loss is 0.07649999999999725 with run time 0.019066810607910156
# testing instance with offertimes 30 : 27th
# instance offertimes 30, 27th is representable by mdm with runtime 0.00028896331787109375
# testing instance with offertimes 30 : 28th
# instance offertimes 30, 28th is representable by mdm with runtime 0.00015282630920410156
# testing instance with offertimes 30 : 29th
# instance offertimes 30, 29th is NOT representable by mdm
# mdm 1-norm loss is 0.04800000000000112 with run time 0.016401052474975586
# testing instance with offertimes 30 : 30th
# instance offertimes 30, 30th is representable by mdm with runtime 0.00013709068298339844
# testing instance with offertimes 30 : 31th
# instance offertimes 30, 31th is representable by mdm with runtime 0.00010204315185546875
# testing instance with offertimes 30 : 32th
# instance offertimes 30, 32th is representable by mdm with runtime 0.00012087821960449219
# testing instance with offertimes 30 : 33th
# instance offertimes 30, 33th is representable by mdm with runtime 0.0002281665802001953
# testing instance with offertimes 30 : 34th
# instance offertimes 30, 34th is representable by mdm with runtime 0.00014281272888183594
# testing instance with offertimes 30 : 35th
# instance offertimes 30, 35th is representable by mdm with runtime 0.0001361370086669922
# testing instance with offertimes 30 : 36th
# instance offertimes 30, 36th is representable by mdm with runtime 0.00010180473327636719
# testing instance with offertimes 30 : 37th
# instance offertimes 30, 37th is NOT representable by mdm
# mdm 1-norm loss is 0.21200000000000296 with run time 0.02491593360900879
# testing instance with offertimes 30 : 38th
# instance offertimes 30, 38th is representable by mdm with runtime 0.0002999305725097656
# testing instance with offertimes 30 : 39th
# instance offertimes 30, 39th is representable by mdm with runtime 0.00023508071899414062
# testing instance with offertimes 30 : 40th
# instance offertimes 30, 40th is representable by mdm with runtime 0.00017499923706054688
# testing instance with offertimes 30 : 41th
# instance offertimes 30, 41th is representable by mdm with runtime 0.0001430511474609375
# testing instance with offertimes 30 : 42th
# instance offertimes 30, 42th is representable by mdm with runtime 0.00018095970153808594
# testing instance with offertimes 30 : 43th
# instance offertimes 30, 43th is representable by mdm with runtime 0.0002129077911376953
# testing instance with offertimes 30 : 44th
# instance offertimes 30, 44th is representable by mdm with runtime 0.00014281272888183594
# testing instance with offertimes 30 : 45th
# instance offertimes 30, 45th is representable by mdm with runtime 0.00010704994201660156
# testing instance with offertimes 30 : 46th
# instance offertimes 30, 46th is representable by mdm with runtime 9.083747863769531e-05
# testing instance with offertimes 30 : 47th
# instance offertimes 30, 47th is representable by mdm with runtime 8.893013000488281e-05
# testing instance with offertimes 30 : 48th
# instance offertimes 30, 48th is representable by mdm with runtime 8.821487426757812e-05
# testing instance with offertimes 30 : 49th
# instance offertimes 30, 49th is NOT representable by mdm
# mdm 1-norm loss is 0.1984000000000006 with run time 0.02078104019165039
# testing instance with offertimes 40 : 0th
# instance offertimes 40, 0th is representable by mdm with runtime 0.0002739429473876953
# testing instance with offertimes 40 : 1th
# instance offertimes 40, 1th is representable by mdm with runtime 9.202957153320312e-05
# testing instance with offertimes 40 : 2th
# instance offertimes 40, 2th is representable by mdm with runtime 9.202957153320312e-05
# testing instance with offertimes 40 : 3th
# instance offertimes 40, 3th is representable by mdm with runtime 9.012222290039062e-05
# testing instance with offertimes 40 : 4th
# instance offertimes 40, 4th is representable by mdm with runtime 0.000102996826171875
# testing instance with offertimes 40 : 5th
# instance offertimes 40, 5th is representable by mdm with runtime 0.00011992454528808594
# testing instance with offertimes 40 : 6th
# instance offertimes 40, 6th is representable by mdm with runtime 0.00011086463928222656
# testing instance with offertimes 40 : 7th
# instance offertimes 40, 7th is representable by mdm with runtime 0.00018095970153808594
# testing instance with offertimes 40 : 8th
# instance offertimes 40, 8th is representable by mdm with runtime 9.512901306152344e-05
# testing instance with offertimes 40 : 9th
# instance offertimes 40, 9th is representable by mdm with runtime 8.392333984375e-05
# testing instance with offertimes 40 : 10th
# instance offertimes 40, 10th is representable by mdm with runtime 8.0108642578125e-05
# testing instance with offertimes 40 : 11th
# instance offertimes 40, 11th is representable by mdm with runtime 0.0001380443572998047
# testing instance with offertimes 40 : 12th
# instance offertimes 40, 12th is representable by mdm with runtime 0.000225067138671875
# testing instance with offertimes 40 : 13th
# instance offertimes 40, 13th is representable by mdm with runtime 0.00023293495178222656
# testing instance with offertimes 40 : 14th
# instance offertimes 40, 14th is representable by mdm with runtime 0.00013709068298339844
# testing instance with offertimes 40 : 15th
# instance offertimes 40, 15th is representable by mdm with runtime 0.0001049041748046875
# testing instance with offertimes 40 : 16th
# instance offertimes 40, 16th is representable by mdm with runtime 0.00010204315185546875
# testing instance with offertimes 40 : 17th
# instance offertimes 40, 17th is representable by mdm with runtime 9.298324584960938e-05
# testing instance with offertimes 40 : 18th
# instance offertimes 40, 18th is representable by mdm with runtime 0.00011491775512695312
# testing instance with offertimes 40 : 19th
# instance offertimes 40, 19th is representable by mdm with runtime 9.107589721679688e-05
# testing instance with offertimes 40 : 20th
# instance offertimes 40, 20th is representable by mdm with runtime 8.821487426757812e-05
# testing instance with offertimes 40 : 21th
# instance offertimes 40, 21th is representable by mdm with runtime 0.00015401840209960938
# testing instance with offertimes 40 : 22th
# instance offertimes 40, 22th is representable by mdm with runtime 9.012222290039062e-05
# testing instance with offertimes 40 : 23th
# instance offertimes 40, 23th is representable by mdm with runtime 8.106231689453125e-05
# testing instance with offertimes 40 : 24th
# instance offertimes 40, 24th is representable by mdm with runtime 7.891654968261719e-05
# testing instance with offertimes 40 : 25th
# instance offertimes 40, 25th is representable by mdm with runtime 8.082389831542969e-05
# testing instance with offertimes 40 : 26th
# instance offertimes 40, 26th is representable by mdm with runtime 0.0001201629638671875
# testing instance with offertimes 40 : 27th
# instance offertimes 40, 27th is representable by mdm with runtime 0.0001461505889892578
# testing instance with offertimes 40 : 28th
# instance offertimes 40, 28th is representable by mdm with runtime 0.00021791458129882812
# testing instance with offertimes 40 : 29th
# instance offertimes 40, 29th is representable by mdm with runtime 0.00016808509826660156
# testing instance with offertimes 40 : 30th
# instance offertimes 40, 30th is representable by mdm with runtime 0.00017189979553222656
# testing instance with offertimes 40 : 31th
# instance offertimes 40, 31th is representable by mdm with runtime 0.00013899803161621094
# testing instance with offertimes 40 : 32th
# instance offertimes 40, 32th is representable by mdm with runtime 0.0001399517059326172
# testing instance with offertimes 40 : 33th
# instance offertimes 40, 33th is NOT representable by mdm
# mdm 1-norm loss is 0.0 with run time 0.003409862518310547
# testing instance with offertimes 40 : 34th
# instance offertimes 40, 34th is representable by mdm with runtime 0.00015091896057128906
# testing instance with offertimes 40 : 35th
# instance offertimes 40, 35th is representable by mdm with runtime 0.0001220703125
# testing instance with offertimes 40 : 36th
# instance offertimes 40, 36th is representable by mdm with runtime 0.0001270771026611328
# testing instance with offertimes 40 : 37th
# instance offertimes 40, 37th is representable by mdm with runtime 0.00022792816162109375
# testing instance with offertimes 40 : 38th
# instance offertimes 40, 38th is representable by mdm with runtime 0.0001678466796875
# testing instance with offertimes 40 : 39th
# instance offertimes 40, 39th is representable by mdm with runtime 0.00012493133544921875
# testing instance with offertimes 40 : 40th
# instance offertimes 40, 40th is representable by mdm with runtime 0.00024199485778808594
# testing instance with offertimes 40 : 41th
# instance offertimes 40, 41th is representable by mdm with runtime 0.00016689300537109375
# testing instance with offertimes 40 : 42th
# instance offertimes 40, 42th is representable by mdm with runtime 0.00013184547424316406
# testing instance with offertimes 40 : 43th
# instance offertimes 40, 43th is representable by mdm with runtime 0.00012803077697753906
# testing instance with offertimes 40 : 44th
# instance offertimes 40, 44th is representable by mdm with runtime 0.00010991096496582031
# testing instance with offertimes 40 : 45th
# instance offertimes 40, 45th is representable by mdm with runtime 0.00014591217041015625
# testing instance with offertimes 40 : 46th
# instance offertimes 40, 46th is NOT representable by mdm
# mdm 1-norm loss is 0.23200000000000137 with run time 0.010357141494750977
# testing instance with offertimes 40 : 47th
# instance offertimes 40, 47th is representable by mdm with runtime 0.00013899803161621094
# testing instance with offertimes 40 : 48th
# instance offertimes 40, 48th is representable by mdm with runtime 0.00011515617370605469
# testing instance with offertimes 40 : 49th
# instance offertimes 40, 49th is representable by mdm with runtime 8.797645568847656e-05
# testing instance with offertimes 50 : 0th
# instance offertimes 50, 0th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 1th
# instance offertimes 50, 1th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 2th
# instance offertimes 50, 2th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 3th
# instance offertimes 50, 3th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 4th
# instance offertimes 50, 4th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 5th
# instance offertimes 50, 5th is representable by mdm with runtime 0.00012183189392089844
# testing instance with offertimes 50 : 6th
# instance offertimes 50, 6th is representable by mdm with runtime 0.00010204315185546875
# testing instance with offertimes 50 : 7th
# instance offertimes 50, 7th is representable by mdm with runtime 0.0001239776611328125
# testing instance with offertimes 50 : 8th
# instance offertimes 50, 8th is representable by mdm with runtime 8.487701416015625e-05
# testing instance with offertimes 50 : 9th
# instance offertimes 50, 9th is representable by mdm with runtime 7.510185241699219e-05
# testing instance with offertimes 50 : 10th
# instance offertimes 50, 10th is representable by mdm with runtime 8.416175842285156e-05
# testing instance with offertimes 50 : 11th
# instance offertimes 50, 11th is representable by mdm with runtime 9.608268737792969e-05
# testing instance with offertimes 50 : 12th
# instance offertimes 50, 12th is representable by mdm with runtime 0.0001239776611328125
# testing instance with offertimes 50 : 13th
# instance offertimes 50, 13th is representable by mdm with runtime 0.00022292137145996094
# testing instance with offertimes 50 : 14th
# instance offertimes 50, 14th is representable by mdm with runtime 0.00011897087097167969
# testing instance with offertimes 50 : 15th
# instance offertimes 50, 15th is representable by mdm with runtime 0.0001201629638671875
# testing instance with offertimes 50 : 16th
# instance offertimes 50, 16th is representable by mdm with runtime 0.00010204315185546875
# testing instance with offertimes 50 : 17th
# instance offertimes 50, 17th is representable by mdm with runtime 7.700920104980469e-05
# testing instance with offertimes 50 : 18th
# instance offertimes 50, 18th is representable by mdm with runtime 0.00010895729064941406
# testing instance with offertimes 50 : 19th
# instance offertimes 50, 19th is representable by mdm with runtime 0.0001068115234375
# testing instance with offertimes 50 : 20th
# instance offertimes 50, 20th is representable by mdm with runtime 0.00011992454528808594
# testing instance with offertimes 50 : 21th
# instance offertimes 50, 21th is representable by mdm with runtime 9.393692016601562e-05
# testing instance with offertimes 50 : 22th
# instance offertimes 50, 22th is representable by mdm with runtime 0.00011992454528808594
# testing instance with offertimes 50 : 23th
# instance offertimes 50, 23th is representable by mdm with runtime 0.00011420249938964844
# testing instance with offertimes 50 : 24th
# instance offertimes 50, 24th is representable by mdm with runtime 0.00011491775512695312
# testing instance with offertimes 50 : 25th
# instance offertimes 50, 25th is representable by mdm with runtime 0.00010800361633300781
# testing instance with offertimes 50 : 26th
# instance offertimes 50, 26th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 27th
# instance offertimes 50, 27th is representable by mdm with runtime 7.104873657226562e-05
# testing instance with offertimes 50 : 28th
# instance offertimes 50, 28th is representable by mdm with runtime 9.417533874511719e-05
# testing instance with offertimes 50 : 29th
# instance offertimes 50, 29th is representable by mdm with runtime 0.00017499923706054688
# testing instance with offertimes 50 : 30th
# instance offertimes 50, 30th is representable by mdm with runtime 0.00011086463928222656
# testing instance with offertimes 50 : 31th
# instance offertimes 50, 31th is representable by mdm with runtime 0.00012803077697753906
# testing instance with offertimes 50 : 32th
# instance offertimes 50, 32th is representable by mdm with runtime 0.00011181831359863281
# testing instance with offertimes 50 : 33th
# instance offertimes 50, 33th is representable by mdm with runtime 7.891654968261719e-05
# testing instance with offertimes 50 : 34th
# instance offertimes 50, 34th is representable by mdm with runtime 7.700920104980469e-05
# testing instance with offertimes 50 : 35th
# instance offertimes 50, 35th is representable by mdm with runtime 7.295608520507812e-05
# testing instance with offertimes 50 : 36th
# instance offertimes 50, 36th is representable by mdm with runtime 7.104873657226562e-05
# testing instance with offertimes 50 : 37th
# instance offertimes 50, 37th is representable by mdm with runtime 7.200241088867188e-05
# testing instance with offertimes 50 : 38th
# instance offertimes 50, 38th is representable by mdm with runtime 0.0001671314239501953
# testing instance with offertimes 50 : 39th
# instance offertimes 50, 39th is representable by mdm with runtime 0.00016307830810546875
# testing instance with offertimes 50 : 40th
# instance offertimes 50, 40th is representable by mdm with runtime 0.0001220703125
# testing instance with offertimes 50 : 41th
# instance offertimes 50, 41th is representable by mdm with runtime 7.987022399902344e-05
# testing instance with offertimes 50 : 42th
# instance offertimes 50, 42th is representable by mdm with runtime 8.893013000488281e-05
# testing instance with offertimes 50 : 43th
# instance offertimes 50, 43th is representable by mdm with runtime 9.202957153320312e-05
# testing instance with offertimes 50 : 44th
# instance offertimes 50, 44th is representable by mdm with runtime 0.00018095970153808594
# testing instance with offertimes 50 : 45th
# instance offertimes 50, 45th is representable by mdm with runtime 9.202957153320312e-05
# testing instance with offertimes 50 : 46th
# instance offertimes 50, 46th is representable by mdm with runtime 8.20159912109375e-05
# testing instance with offertimes 50 : 47th
# instance offertimes 50, 47th is representable by mdm with runtime 7.915496826171875e-05
# testing instance with offertimes 50 : 48th
# instance offertimes 50, 48th is representable by mdm with runtime 7.104873657226562e-05
# testing instance with offertimes 50 : 49th
# instance offertimes 50, 49th is representable by mdm with runtime 0.00013208389282226562

# %%
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep[i]})
    df_mdm_rep.to_csv('mdm/representability/'+str(pred_offer_times_list[i])+'.csv')

# %%
mdm_feasible_proportion_list = [np.sum(all_mdm_rep[x])/len(all_mdm_rep[x]) for x in range(len(pred_offer_times_list)) ]
mdm_rep_time_mean = [np.mean(all_mdm_rep_time[x]) for x in range(len(pred_offer_times_list)) ]
mdm_rep_time_se = [ np.std(all_mdm_rep_time[x])/np.sqrt(len(all_mdm_rep_time[x])) for x in range(len(pred_offer_times_list))  ]
mdm_rep_summary = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                'mdm_rep':mdm_feasible_proportion_list,'mdm_rep_time':mdm_rep_time_mean,'mdm_rep_time_se':mdm_rep_time_se})
mdm_rep_summary.to_csv('mdm/mdm_rep_summary_probit_no_outside.csv')
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se
# 0          15               30     0.40      0.000380         0.000033
# 1          20               21     0.92      0.000282         0.000043
# 2          30               16     0.92      0.000211         0.000013
# 3          40               11     0.96      0.000138         0.000007
# 4          50                7     1.00      0.000104         0.000005

# %%
# save infeasibe indices 
for i in range(len(pred_offer_times_list)):
    df_mdm_rep_infeas = pd.DataFrame(all_mdm_infeasible_index[i])
    df_mdm_rep_infeas.to_csv('mdm/rep_infeasibility/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save 1norm loss 
mdm_1norm_loss_mean = [np.mean(all_mdm_limit_loss[x]) for x in range(len(pred_offer_times_list)) ]
mdm_1norm_loss_se = [ np.std(all_mdm_limit_loss[x])/np.sqrt(len(all_mdm_limit_loss[x])) for x in range(len(pred_offer_times_list)) ]

mdm_1norm_time_mean = [np.mean(all_mdm_limit_runtime[x]) for x in range(len(pred_offer_times_list)) ]
mdm_1norm_time_se = [ np.std(all_mdm_limit_runtime[x])/np.sqrt(len(all_mdm_limit_runtime[x])) for x in range(len(pred_offer_times_list)) ]

df_mdm_1norm_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'mdm_1norm_loss':mdm_1norm_loss_mean, 'mdm_1norm_loss_se':mdm_1norm_loss_se,
                                'mdm_1norm_time':mdm_1norm_time_mean, 'mdm_1norm_time_se':mdm_1norm_time_se,
                                  })
df_mdm_1norm_loss.to_csv('mdm/mdm_1norm_loss_summary_probit_no_outside.csv')
df_mdm_1norm_loss
# Out:
#    offertimes  collection_size  mdm_1norm_loss  mdm_1norm_loss_se  \
# 0          15               30        0.049976           0.008682
# 1          20               21        0.010416           0.008929
# 2          30               16        0.010698           0.005890
# 3          40               11        0.004640           0.004593
# 4          50                7        0.000000           0.000000
#
#    mdm_1norm_time  mdm_1norm_time_se
# 0        0.067331           0.008302
# 1        0.004183           0.001936
# 2        0.001811           0.000781
# 3        0.000404           0.000211
# 4        0.000104           0.000005

# %%
# save 1norm loss:
for i in range(len(pred_offer_times_list)):
    df_mdm_1norm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_1norm_loss':all_mdm_limit_loss[i],'mdm_1norm_runtime':all_mdm_limit_runtime[i]})
    df_mdm_1norm_loss.to_csv('mdm/limit_loss/1norm/'+str(pred_offer_times_list[i])+'.csv')

# %%
# save 1norm solution: limit probability and lambdas for kl
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_prob = pd.DataFrame(all_mdm_limit_prob[i][j])
        df_lam = pd.DataFrame(all_mdm_limit_lam[i][j])
        df_prob.to_csv('mdm/limit_prob/1norm/offertimes'+str(pred_offer_times_list[i])+'/prob'+str(j)+'.csv')
        df_lam.to_csv('mdm/lamda_1norm/offertimes'+str(pred_offer_times_list[i])+'/lam'+str(j)+'.csv')

# %%
import pyomo.environ as pyo
from pyomo.environ import *

# %%
def mdm_kl_w_lam(lam,data,collection,offertimes):
    
    n, m = data.shape
    
    ind = [[] for i in range(n)]  ## keeps track of the assortments including product i

    for i in range(len(collection)):
        for j in collection[i]:
            ind[j].append(i)  ## assortment i includes product j
    
    model = pyo.ConcreteModel()
    model.x = pyo.Var(range(n), range(m), domain= pyo.NonNegativeReals)
    
    model.norm_constraint = pyo.ConstraintList()
    for i in range(len(collection)):
        model.norm_constraint.add(sum(model.x[k, i] for k in collection[i]) == 1)
        for j in range(n):
            if j not in collection[i]:
                model.norm_constraint.add(model.x[j, i] == 0)
    
    model.mdm_constraint = pyo.ConstraintList()
    for i in range(n):
        for j in range(len(ind[i]) - 1):
            for k in range(j + 1, len(ind[i])):
                if lam[ind[i][j]] >= lam[ind[i][k]]:
                    model.mdm_constraint.add(model.x[i, ind[i][k]] - model.x[i, ind[i][j]]  >= 0)
                if lam[ind[i][j]] <= lam[ind[i][k]]:
                    model.mdm_constraint.add(model.x[i, ind[i][j]] - model.x[i, ind[i][k]]  >= 0)
    
    model.obj = pyo.Objective(expr= -sum( sum(offertimes[j] *data[i, j] * pyo.log(model.x[i, j]) for i in collection[j]) for j in range(m)),sense=pyo.minimize)
    
    solver = pyo.SolverFactory('ipopt')  # You can change the solver as needed
    solver.options['max_iter'] = 10000
    
    try:
        # Your optimization solve code here
        results = solver.solve(model,tee=True)
        status = str(results.solver.status)
        # Access the optimal solution
        if status == pyo.SolverStatus.ok:
            print("Solver found a solution.")
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            return [pyo.value(model.obj), x_values, results.solver.time]
        
        elif results.solver.status == pyo.SolverStatus.warning:
            print("Solver issued a warning.")
            x_values = [[model.x[i, j].value for j in range(m)] for i in range(n)]
            x_values = np.array(x_values)
            
            return [pyo.value(model.obj), x_values, results.solver.time]
        # Check if the solver status is an error
        if results.solver.status != pyo.SolverStatus.ok:
            raise ValueError(f"Solver failed with status: {results.solver.status}")
    
    except ValueError as e:
        print(f"Error: {e}")

# %%
def deterministic_term(data,offertimes):
    dt = 0 
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            if data[i][j] >0:
                dt = dt + offertimes[j]*data[i][j]*np.log(data[i][j])
    return dt,dt/np.sum(offertimes)

# %%
all_mdm_kl_loss = []
all_mdm_avg_kl_loss = []
all_mdm_kl_prob = []
all_mdm_2stage_time = []

all_dt = []
all_avg_dt = []

all_total_time = []

for i in range(len(pred_offer_times_list)):
    
    mdm_kl_loss_collection = []
    mdm_avg_kl_loss_collection = []
    dt_collection = []
    avg_dt_collection = []
    mdm_kl_prob_collection = []
    mdm_2stage_time_collection = []
    total_time_collection = []
    
    for j in range(pred_instance_size[i]):
        
        if all_mdm_rep[i][j] <1:
            # mdm non-representable instance (i,j)
            result = mdm_kl_w_lam(all_mdm_limit_lam[i][j],all_full_instances[i][j],all_full_collections[i],all_full_offertimes[i])
            
            dt,avg_dt = deterministic_term(all_full_instances[i][j],all_full_offertimes[i])
            
            dt_collection.append(dt)
            avg_dt_collection.append(avg_dt)
            
            mdm_kl_loss_collection.append(result[0]+dt)
            mdm_avg_kl_loss_collection.append(result[0]/np.sum(all_full_offertimes[i])+avg_dt)
            
            mdm_kl_prob_collection.append(result[1])
            mdm_2stage_time_collection.append(result[-1])
            
            total_time_collection.append(result[-1] + all_mdm_limit_runtime[i][j])
        else:
            # mdm representable instances (i,j)
            mdm_kl_loss_collection.append(0)
            mdm_avg_kl_loss_collection.append(0)
            mdm_kl_prob_collection.append(all_full_instances[i][j])
            total_time_collection.append(all_mdm_rep_time[i][j])

    all_mdm_kl_loss.append(mdm_kl_loss_collection) 
    all_mdm_avg_kl_loss.append(mdm_avg_kl_loss_collection)
    all_mdm_kl_prob.append(mdm_kl_prob_collection)
    all_total_time.append(total_time_collection)
        
    all_dt.append(dt_collection)
    all_avg_dt.append(avg_dt_collection)
# Out:
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.98e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.8516058e+03 9.56e-01 2.32e+04  -1.0 7.53e-01    -  1.49e-02 2.42e-02f  1
#    2  5.8410731e+03 9.56e-01 2.32e+04  -1.0 8.59e-01    -  3.60e-02 4.07e-04f  1
#    3  5.7383142e+03 9.52e-01 2.31e+04  -1.0 8.58e-01    -  2.97e-02 4.13e-03f  1
#    4  5.6975317e+03 9.50e-01 2.31e+04  -1.0 8.29e-01    -  4.07e-02 1.64e-03f  1
#    5  5.5595243e+03 9.45e-01 2.30e+04  -1.0 8.23e-01    -  5.00e-02 5.66e-03f  1
#    6  5.3205947e+03 9.35e-01 2.31e+04  -1.0 8.19e-01    -  1.55e-02 1.02e-02f  1
#    7  5.1521567e+03 9.28e-01 2.31e+04  -1.0 8.90e-01    -  2.27e-02 7.97e-03f  1
#    8  4.8746120e+03 9.14e-01 2.32e+04  -1.0 8.73e-01    -  1.84e-02 1.50e-02f  1
#    9  4.7542518e+03 9.07e-01 2.31e+04  -1.0 8.47e-01    -  4.49e-02 7.49e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.7111011e+03 9.05e-01 2.30e+04  -1.0 5.14e-01    -  2.94e-02 2.78e-03f  1
#   11  4.1563646e+03 8.64e-01 2.32e+04  -1.0 5.02e-01    -  6.78e-02 4.45e-02f  1
#   12  3.3112683e+03 7.64e-01 2.22e+04  -1.0 4.62e-01    -  1.04e-01 1.16e-01f  1
#   13  2.4531802e+03 5.81e-01 1.77e+04  -1.0 4.09e-01    -  5.92e-01 2.40e-01f  1
#   14  1.7303589e+03 3.18e-01 9.94e+03  -1.0 3.12e-01    -  2.30e-01 4.52e-01f  1
#   15  1.4306804e+03 1.69e-01 5.32e+03  -1.0 1.71e-01    -  4.57e-01 4.67e-01f  1
#   16  1.3368233e+03 1.20e-01 3.77e+03  -1.0 9.02e-02    -  1.24e-01 2.92e-01f  1
#   17  1.2955068e+03 9.88e-02 3.10e+03  -1.0 9.47e-02    -  9.48e-02 1.77e-01f  1
#   18  1.2326659e+03 6.60e-02 2.07e+03  -1.0 1.03e-01    -  1.04e-01 3.32e-01f  1
#   19  1.2004723e+03 5.00e-02 1.57e+03  -1.0 1.16e-01    -  2.70e-01 2.41e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.1084121e+03 3.57e-03 1.18e+03  -1.0 1.26e-01    -  3.15e-01 9.29e-01f  1
#   21  1.0908660e+03 6.45e-04 1.36e+03  -1.0 1.05e-01    -  3.50e-01 8.20e-01f  1
#   22  1.0709746e+03 5.48e-06 6.09e+03  -1.0 1.23e-01    -  5.91e-01 9.92e-01h  1
#   23  1.0632761e+03 4.66e-06 3.05e+05  -1.0 1.77e-01    -  3.54e-01 1.50e-01f  1
#   24  1.0105589e+03 1.11e-16 1.37e+06  -1.0 2.70e-01    -  1.68e-01 1.00e+00f  1
#   25  9.9950551e+02 1.11e-16 4.70e+06  -1.0 1.39e-01    -  4.88e-01 1.00e+00f  1
#   26  9.9895206e+02 1.11e-16 1.16e+06  -1.0 7.26e-02    -  7.53e-01 1.00e+00f  1
#   27  9.9908728e+02 2.22e-16 3.16e-01  -1.0 3.81e-02    -  1.00e+00 1.00e+00f  1
#   28  9.9831516e+02 2.22e-16 2.41e+06  -8.6 3.85e-02    -  7.59e-01 1.00e+00f  1
#   29  9.9812772e+02 2.22e-16 7.03e+05  -8.6 2.58e-02    -  7.08e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.9809167e+02 2.22e-16 1.24e+05  -8.6 1.07e-02    -  8.24e-01 1.00e+00f  1
#   31  9.9808475e+02 2.22e-16 1.05e+04  -8.6 5.02e-03    -  9.15e-01 1.00e+00f  1
#   32  9.9808350e+02 1.11e-16 1.33e+03  -8.6 2.12e-03    -  8.73e-01 1.00e+00f  1
#   33  9.9808331e+02 2.22e-16 1.75e+01  -8.6 9.76e-04    -  9.87e-01 1.00e+00f  1
#   34  9.9808328e+02 2.22e-16 2.59e-05  -8.6 5.47e-04    -  1.00e+00 1.00e+00f  1
#   35  9.9808327e+02 2.22e-16 5.37e-06  -8.6 2.50e-04    -  1.00e+00 1.00e+00f  1
#   36  9.9808327e+02 2.22e-16 6.09e-07  -8.6 8.40e-05    -  1.00e+00 1.00e+00f  1
#   37  9.9808327e+02 2.22e-16 1.31e-08  -8.6 1.23e-05    -  1.00e+00 1.00e+00h  1
#   38  9.9808327e+02 2.22e-16 9.69e-12  -9.0 3.35e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 38
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.9808327273975465e+02    9.9808327273975465e+02
# Dual infeasibility......:   9.6888532332296463e-12    9.6888532332296463e-12
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   9.1451674616655476e-10    9.1451674616655476e-10
# Overall NLP error.......:   9.1451674616655476e-10    9.1451674616655476e-10
#
#
# Number of objective function evaluations             = 39
# Number of objective gradient evaluations             = 39
# Number of equality constraint evaluations            = 39
# Number of inequality constraint evaluations          = 39
# Number of equality constraint Jacobian evaluations   = 39
# Number of inequality constraint Jacobian evaluations = 39
# Number of Lagrangian Hessian evaluations             = 38
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.350
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.48e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.9698993e+03 9.60e-01 2.04e+04  -1.0 8.04e-01    -  1.39e-02 2.07e-02f  1
#    2  5.9612528e+03 9.59e-01 2.04e+04  -1.0 8.77e-01    -  3.45e-02 3.04e-04f  1
#    3  5.9306673e+03 9.59e-01 2.04e+04  -1.0 7.84e-01    -  1.94e-02 9.14e-04f  1
#    4  5.7248332e+03 9.52e-01 2.03e+04  -1.0 7.87e-01    -  1.12e-02 6.29e-03f  1
#    5  5.6481204e+03 9.50e-01 2.03e+04  -1.0 8.38e-01    -  1.90e-02 2.55e-03f  1
#    6  5.4911046e+03 9.45e-01 2.02e+04  -1.0 8.56e-01    -  1.41e-02 5.61e-03f  1
#    7  5.3700968e+03 9.40e-01 2.01e+04  -1.0 8.82e-01    -  6.02e-03 4.71e-03f  1
#    8  5.2386942e+03 9.35e-01 2.00e+04  -1.0 8.65e-01    -  8.39e-03 5.66e-03f  1
#    9  5.2026586e+03 9.33e-01 2.00e+04  -1.0 6.97e-01    -  9.25e-03 1.63e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.9985412e+03 9.24e-01 1.98e+04  -1.0 6.87e-01    -  6.71e-03 1.01e-02f  1
#   11  4.9371580e+03 9.21e-01 1.98e+04  -1.0 6.92e-01    -  2.12e-02 3.33e-03f  1
#   12  4.7634280e+03 9.12e-01 1.96e+04  -1.0 6.67e-01    -  3.09e-02 1.02e-02f  1
#   13  4.6335810e+03 9.04e-01 1.95e+04  -1.0 6.37e-01    -  2.01e-02 8.31e-03f  1
#   14  4.5253779e+03 8.97e-01 1.93e+04  -1.0 6.48e-01    -  3.24e-02 7.52e-03f  1
#   15  4.3934699e+03 8.88e-01 1.92e+04  -1.0 6.78e-01    -  2.74e-02 9.76e-03f  1
#   16  4.1419818e+03 8.69e-01 1.89e+04  -1.0 6.82e-01    -  1.87e-02 2.15e-02f  1
#   17  3.8056809e+03 8.38e-01 1.85e+04  -1.0 6.75e-01    -  2.89e-02 3.58e-02f  1
#   18  2.7985401e+03 6.88e-01 1.65e+04  -1.0 6.52e-01    -  9.15e-02 1.79e-01f  1
#   19  2.6364125e+03 6.53e-01 1.57e+04  -1.0 5.35e-01    -  3.60e-01 5.13e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.5549165e+03 2.88e-01 7.49e+03  -1.0 5.07e-01    -  3.89e-01 5.59e-01f  1
#   21  1.4057325e+03 2.13e-01 5.56e+03  -1.0 2.25e-01    -  2.50e-01 2.59e-01f  1
#   22  1.1598012e+03 7.36e-02 1.93e+03  -1.0 1.63e-01    -  1.41e-01 6.54e-01f  1
#   23  1.1226102e+03 5.08e-02 1.33e+03  -1.0 7.18e-02    -  2.54e-01 3.11e-01f  1
#   24  1.0678492e+03 1.65e-02 1.02e+03  -1.0 6.01e-02    -  3.72e-01 6.74e-01f  1
#   25  1.0394391e+03 1.64e-04 7.52e+02  -1.0 4.74e-02    -  3.36e-01 9.90e-01h  1
#   26  1.0346237e+03 6.74e-07 2.28e+04  -1.0 5.98e-02    -  6.10e-01 9.96e-01h  1
#   27  1.0276656e+03 1.11e-16 3.62e+06  -1.0 8.64e-02    -  3.87e-01 1.00e+00f  1
#   28  1.0123870e+03 1.11e-16 6.04e+06  -1.0 1.14e-01    -  2.13e-01 1.00e+00f  1
#   29  1.0032723e+03 1.11e-16 4.19e+06  -1.0 1.03e-01    -  3.07e-01 7.41e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.9551748e+02 1.11e-16 2.50e+06  -1.0 9.66e-02    -  4.02e-01 9.31e-01f  1
#   31  9.9206867e+02 1.11e-16 1.50e+06  -1.0 9.66e-02    -  4.00e-01 1.00e+00f  1
#   32  9.9177081e+02 2.22e-16 4.52e-01  -1.0 5.48e-02    -  1.00e+00 1.00e+00f  1
#   33  9.9121038e+02 2.22e-16 2.47e+06  -8.6 3.08e-02    -  7.53e-01 1.00e+00f  1
#   34  9.9108375e+02 1.11e-16 6.79e+05  -8.6 2.18e-02    -  7.25e-01 1.00e+00f  1
#   35  9.9106122e+02 2.22e-16 8.53e+04  -8.6 8.94e-03    -  8.74e-01 1.00e+00f  1
#   36  9.9105530e+02 2.22e-16 1.40e+04  -8.6 5.91e-03    -  8.36e-01 1.00e+00f  1
#   37  9.9105404e+02 2.22e-16 7.92e+02  -8.6 3.06e-03    -  9.44e-01 1.00e+00f  1
#   38  9.9105376e+02 2.22e-16 1.60e+01  -8.6 1.31e-03    -  9.80e-01 1.00e+00f  1
#   39  9.9105371e+02 2.22e-16 2.50e-05  -8.6 4.12e-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.9105370e+02 2.22e-16 6.39e-06  -8.6 1.63e-04    -  1.00e+00 1.00e+00f  1
#   41  9.9105370e+02 2.22e-16 1.46e-06  -8.6 7.80e-05    -  1.00e+00 1.00e+00f  1
#   42  9.9105370e+02 2.22e-16 2.58e-07  -8.6 3.28e-05    -  1.00e+00 1.00e+00f  1
#   43  9.9105370e+02 2.22e-16 1.93e-08  -8.6 8.97e-06    -  1.00e+00 1.00e+00h  1
#   44  9.9105370e+02 2.22e-16 1.96e-10  -9.0 9.04e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 44
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.9105369881139632e+02    9.9105369881139632e+02
# Dual infeasibility......:   1.9624164794184544e-10    1.9624164794184544e-10
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   1.0206382920974374e-09    1.0206382920974374e-09
# Overall NLP error.......:   1.0206382920974374e-09    1.0206382920974374e-09
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 45
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 45
# Number of equality constraint Jacobian evaluations   = 45
# Number of inequality constraint Jacobian evaluations = 45
# Number of Lagrangian Hessian evaluations             = 44
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.414
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.54e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.9337621e+03 9.56e-01 2.22e+04  -1.0 8.09e-01    -  1.38e-02 2.44e-02f  1
#    2  5.9256902e+03 9.56e-01 2.22e+04  -1.0 8.93e-01    -  4.64e-02 3.62e-04f  1
#    3  5.8501268e+03 9.53e-01 2.22e+04  -1.0 8.57e-01    -  1.24e-02 3.15e-03f  1
#    4  5.7776236e+03 9.50e-01 2.21e+04  -1.0 8.89e-01    -  1.15e-02 2.87e-03f  1
#    5  5.6850852e+03 9.47e-01 2.21e+04  -1.0 7.43e-01    -  9.07e-03 3.32e-03f  1
#    6  5.5793432e+03 9.43e-01 2.20e+04  -1.0 6.93e-01    -  1.71e-02 3.73e-03f  1
#    7  5.2974251e+03 9.33e-01 2.18e+04  -1.0 7.03e-01    -  2.26e-02 1.10e-02f  1
#    8  5.1245637e+03 9.25e-01 2.17e+04  -1.0 7.08e-01    -  2.34e-02 7.97e-03f  1
#    9  5.0763290e+03 9.23e-01 2.16e+04  -1.0 4.98e-01    -  7.83e-02 2.33e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.2787173e+03 8.75e-01 2.27e+04  -1.0 4.89e-01    -  2.44e-01 5.24e-02f  1
#   11  2.8459363e+03 6.82e-01 2.11e+04  -1.0 4.49e-01    -  1.44e-01 2.21e-01f  1
#   12  2.2861206e+03 5.39e-01 1.68e+04  -1.0 3.48e-01    -  2.08e-01 2.10e-01f  1
#   13  1.3788220e+03 1.58e-01 5.22e+03  -1.0 2.75e-01    -  4.99e-01 7.06e-01f  1
#   14  1.2632589e+03 9.54e-02 3.15e+03  -1.0 8.13e-02    -  4.31e-01 3.97e-01f  1
#   15  1.2280287e+03 7.67e-02 2.53e+03  -1.0 7.29e-02    -  3.21e-01 1.96e-01f  1
#   16  1.1927275e+03 5.81e-02 1.92e+03  -1.0 1.04e-01    -  1.66e-01 2.42e-01f  1
#   17  1.1434755e+03 3.25e-02 1.34e+03  -1.0 1.39e-01    -  2.35e-01 4.40e-01f  1
#   18  1.0883907e+03 5.47e-03 2.25e+03  -1.0 1.95e-01    -  2.73e-01 8.32e-01f  1
#   19  1.0814241e+03 3.57e-03 1.48e+03  -1.0 2.08e-01    -  3.92e-01 3.47e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0737180e+03 1.08e-03 6.40e+02  -1.0 1.26e-01    -  4.68e-01 6.98e-01h  1
#   21  1.0562061e+03 9.81e-06 7.98e+03  -1.0 1.50e-01    -  1.13e-01 9.91e-01h  1
#   22  1.0477650e+03 4.90e-06 5.37e+04  -1.0 5.85e-02    -  5.64e-01 5.00e-01f  2
#   23  1.0164254e+03 3.02e-06 1.35e+05  -1.0 2.87e-01    -  2.78e-01 3.84e-01f  1
#   24  9.6256856e+02 1.48e-06 9.66e+05  -1.0 3.30e-01    -  1.05e-01 5.11e-01f  1
#   25  9.3798026e+02 5.90e-07 1.73e+06  -1.0 1.93e-01    -  2.18e-01 6.01e-01f  1
#   26  9.3608194e+02 4.10e-07 1.70e+06  -1.0 1.15e-01    -  2.06e-01 3.05e-01f  2
#   27  9.3553978e+02 3.59e-07 2.84e+06  -1.0 1.08e-01    -  1.00e+00 1.25e-01f  4
#   28  9.3380646e+02 1.11e-16 2.57e+05  -1.0 7.32e-02    -  8.30e-01 1.00e+00h  1
#   29  9.3377886e+02 2.22e-16 5.80e-03  -1.0 6.43e-03    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.3292049e+02 1.11e-16 2.69e+06  -8.6 2.82e-02    -  7.31e-01 1.00e+00f  1
#   31  9.3264694e+02 2.22e-16 1.00e+06  -8.6 2.18e-02    -  6.26e-01 1.00e+00f  1
#   32  9.3258591e+02 2.22e-16 3.39e+05  -8.6 1.40e-02    -  6.63e-01 1.00e+00f  1
#   33  9.3257330e+02 2.22e-16 4.42e+04  -8.6 6.28e-03    -  8.70e-01 1.00e+00f  1
#   34  9.3257042e+02 2.22e-16 6.11e+03  -8.6 3.98e-03    -  8.62e-01 1.00e+00f  1
#   35  9.3256991e+02 2.22e-16 6.90e+02  -8.6 2.18e-03    -  8.87e-01 1.00e+00f  1
#   36  9.3256984e+02 2.22e-16 7.07e+01  -8.6 9.85e-04    -  8.98e-01 1.00e+00f  1
#   37  9.3256983e+02 2.22e-16 2.92e-01  -8.6 2.48e-04    -  9.96e-01 1.00e+00f  1
#   38  9.3256983e+02 1.11e-16 2.51e-06  -8.6 9.40e-05    -  1.00e+00 1.00e+00f  1
#   39  9.3256983e+02 2.22e-16 1.16e-07  -8.6 2.02e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.3256983e+02 2.22e-16 2.92e-10  -8.6 1.01e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 40
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.3256983293373855e+02    9.3256983293373855e+02
# Dual infeasibility......:   2.9234798548167859e-10    2.9234798548167859e-10
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.6092602213783425e-09    2.6092602213783425e-09
# Overall NLP error.......:   2.6092602213783425e-09    2.6092602213783425e-09
#
#
# Number of objective function evaluations             = 46
# Number of objective gradient evaluations             = 41
# Number of equality constraint evaluations            = 46
# Number of inequality constraint evaluations          = 46
# Number of equality constraint Jacobian evaluations   = 41
# Number of inequality constraint Jacobian evaluations = 41
# Number of Lagrangian Hessian evaluations             = 40
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.356
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.66e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.9199861e+03 9.59e-01 2.02e+04  -1.0 8.08e-01    -  1.38e-02 2.19e-02f  1
#    2  5.9120860e+03 9.58e-01 2.02e+04  -1.0 9.01e-01    -  4.11e-02 2.79e-04f  1
#    3  5.8121552e+03 9.55e-01 2.02e+04  -1.0 9.00e-01    -  4.11e-02 3.57e-03f  1
#    4  5.6319070e+03 9.48e-01 2.01e+04  -1.0 8.96e-01    -  4.64e-02 6.88e-03f  1
#    5  5.5893269e+03 9.47e-01 2.01e+04  -1.0 7.58e-01    -  3.34e-02 1.64e-03f  1
#    6  5.2679832e+03 9.34e-01 2.00e+04  -1.0 7.06e-01    -  1.87e-02 1.31e-02f  1
#    7  5.0992551e+03 9.27e-01 1.99e+04  -1.0 6.23e-01    -  5.31e-02 7.94e-03f  1
#    8  5.0111698e+03 9.23e-01 1.98e+04  -1.0 5.64e-01    -  1.27e-02 4.47e-03f  1
#    9  4.8985287e+03 9.17e-01 1.97e+04  -1.0 9.15e-01    -  2.51e-03 6.22e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.8326580e+03 9.14e-01 1.96e+04  -1.0 9.80e-01    -  2.61e-02 3.89e-03f  1
#   11  4.7091709e+03 9.06e-01 1.95e+04  -1.0 8.93e-01    -  2.12e-02 7.76e-03f  1
#   12  4.6788446e+03 9.05e-01 1.95e+04  -1.0 8.20e-01    -  1.56e-02 1.96e-03f  1
#   13  4.5505018e+03 8.97e-01 1.93e+04  -1.0 8.76e-01    -  1.93e-02 8.79e-03f  1
#   14  4.4959206e+03 8.93e-01 1.92e+04  -1.0 7.83e-01    -  4.78e-03 4.03e-03f  1
#   15  4.3208381e+03 8.80e-01 1.90e+04  -1.0 8.71e-01    -  7.86e-03 1.41e-02f  1
#   16  4.3035068e+03 8.79e-01 1.90e+04  -1.0 8.51e-01    -  3.33e-02 1.50e-03f  1
#   17  4.0416992e+03 8.57e-01 1.86e+04  -1.0 7.98e-01    -  6.74e-03 2.50e-02f  1
#   18  3.9884350e+03 8.52e-01 1.85e+04  -1.0 7.77e-01    -  1.65e-03 5.84e-03f  1
#   19  3.9812331e+03 8.51e-01 1.85e+04  -1.0 5.70e-01    -  2.38e-02 8.08e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.8393765e+03 8.37e-01 1.82e+04  -1.0 5.43e-01    -  1.14e-02 1.68e-02f  1
#   21  3.8338226e+03 8.37e-01 1.82e+04  -1.0 5.18e-01    -  1.41e-02 6.99e-04f  1
#   22  3.7977376e+03 8.33e-01 1.81e+04  -1.0 5.06e-01    -  3.28e-03 4.60e-03f  1
#   23  3.7960132e+03 8.33e-01 1.81e+04  -1.0 4.81e-01    -  3.31e-04 2.24e-04f  1
#   24  3.7420314e+03 8.27e-01 1.79e+04  -1.0 4.94e-01    -  2.84e-04 7.09e-03f  1
#   25  3.7066418e+03 8.23e-01 1.79e+04  -1.0 5.20e-01    -  4.10e-03 4.76e-03f  1
#   26  3.6330167e+03 8.14e-01 1.77e+04  -1.0 5.60e-01    -  1.46e-03 1.03e-02f  1
#   27  3.5102084e+03 7.99e-01 1.74e+04  -1.0 5.20e-01    -  1.47e-02 1.86e-02f  1
#   28  3.5078647e+03 7.99e-01 1.73e+04  -1.0 5.04e-01    -  2.83e-02 3.76e-04f  1
#   29  3.4627182e+03 7.93e-01 1.72e+04  -1.0 5.04e-01    -  1.58e-03 7.34e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  3.4149191e+03 7.87e-01 1.71e+04  -1.0 5.00e-01    -  5.37e-03 8.04e-03f  1
#   31  3.4069216e+03 7.86e-01 1.71e+04  -1.0 4.96e-01    -  2.67e-03 1.38e-03f  1
#   32  3.1178642e+03 7.42e-01 1.62e+04  -1.0 4.96e-01    -  1.17e-02 5.52e-02f  1
#   33  2.5211661e+03 6.20e-01 1.37e+04  -1.0 4.68e-01    -  4.16e-02 1.64e-01f  1
#   34  1.7273397e+03 3.59e-01 8.18e+03  -1.0 3.91e-01    -  1.97e-01 4.21e-01f  1
#   35  1.4890231e+03 2.50e-01 5.70e+03  -1.0 2.27e-01    -  4.92e-01 3.05e-01f  1
#   36  1.3213812e+03 1.62e-01 3.69e+03  -1.0 1.58e-01    -  2.03e-01 3.53e-01f  1
#   37  1.1821197e+03 8.04e-02 2.20e+03  -1.0 1.02e-01    -  2.12e-01 5.03e-01f  1
#   38  1.1490375e+03 6.00e-02 1.37e+03  -1.0 5.13e-02    -  3.49e-01 2.53e-01f  1
#   39  1.0980429e+03 2.80e-02 1.32e+03  -1.0 4.31e-02    -  2.73e-01 5.34e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.0693376e+03 9.90e-03 1.21e+03  -1.0 3.69e-02    -  2.99e-01 6.46e-01f  1
#   41  1.0521834e+03 9.81e-05 1.35e+03  -1.0 4.23e-02    -  3.44e-01 9.90e-01h  1
#   42  1.0484347e+03 1.05e-08 3.28e+04  -1.0 5.54e-02    -  6.68e-01 1.00e+00h  1
#   43  1.0416845e+03 6.72e-09 4.54e+05  -1.0 1.49e-01    -  3.14e-01 3.58e-01f  1
#   44  1.0346253e+03 4.84e-09 4.97e+05  -1.0 1.74e-01    -  2.55e-01 2.80e-01f  1
#   45  1.0181097e+03 2.34e-09 1.63e+06  -1.0 2.22e-01    -  2.43e-01 5.16e-01f  1
#   46  1.0064547e+03 5.14e-10 2.99e+06  -1.0 1.68e-01    -  1.02e-01 7.81e-01f  1
#   47  1.0050005e+03 8.18e-11 5.79e+05  -1.0 6.10e-02    -  8.11e-01 8.41e-01f  1
#   48  1.0051905e+03 1.11e-16 5.72e-01  -1.0 3.65e-02    -  1.00e+00 1.00e+00f  1
#   49  1.0040702e+03 2.22e-16 2.78e+06  -8.6 4.36e-02    -  7.22e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.0037751e+03 1.11e-16 1.55e+06  -8.6 2.22e-02    -  4.44e-01 1.00e+00f  1
#   51  1.0037045e+03 2.22e-16 3.50e+05  -8.6 1.32e-02    -  7.74e-01 1.00e+00f  1
#   52  1.0036817e+03 2.22e-16 5.07e+04  -8.6 9.84e-03    -  8.55e-01 1.00e+00f  1
#   53  1.0036766e+03 2.22e-16 7.39e+03  -8.6 4.80e-03    -  8.54e-01 1.00e+00f  1
#   54  1.0036755e+03 1.11e-16 1.44e+03  -8.6 1.90e-03    -  8.05e-01 1.00e+00f  1
#   55  1.0036752e+03 2.22e-16 3.09e+01  -8.6 6.29e-04    -  9.79e-01 1.00e+00f  1
#   56  1.0036752e+03 1.11e-16 4.83e-01  -8.6 2.54e-04    -  9.84e-01 1.00e+00f  1
#   57  1.0036752e+03 2.22e-16 8.59e-07  -8.6 3.95e-05    -  1.00e+00 1.00e+00f  1
#   58  1.0036752e+03 2.22e-16 1.06e-09  -8.6 1.30e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 58
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0036752062526467e+03    1.0036752062526467e+03
# Dual infeasibility......:   1.0637380570555418e-09    1.0637380570555418e-09
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.6399247872740864e-09    2.6399247872740864e-09
# Overall NLP error.......:   2.6399247872740864e-09    2.6399247872740864e-09
#
#
# Number of objective function evaluations             = 59
# Number of objective gradient evaluations             = 59
# Number of equality constraint evaluations            = 59
# Number of inequality constraint evaluations          = 59
# Number of equality constraint Jacobian evaluations   = 59
# Number of inequality constraint Jacobian evaluations = 59
# Number of Lagrangian Hessian evaluations             = 58
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.408
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.62e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.9434666e+03 9.58e-01 2.16e+04  -1.0 8.34e-01    -  1.33e-02 2.22e-02f  1
#    2  5.9391580e+03 9.58e-01 2.16e+04  -1.0 9.09e-01    -  4.12e-02 1.67e-04f  1
#    3  5.8759233e+03 9.56e-01 2.16e+04  -1.0 8.91e-01    -  2.68e-02 2.26e-03f  1
#    4  5.7547844e+03 9.52e-01 2.15e+04  -1.0 7.83e-01    -  2.33e-02 4.29e-03f  1
#    5  5.5733546e+03 9.45e-01 2.14e+04  -1.0 7.33e-01    -  1.75e-02 6.67e-03f  1
#    6  5.4268134e+03 9.40e-01 2.13e+04  -1.0 7.51e-01    -  2.10e-02 5.87e-03f  1
#    7  5.2495231e+03 9.33e-01 2.12e+04  -1.0 7.52e-01    -  3.14e-02 7.65e-03f  1
#    8  5.1932401e+03 9.30e-01 2.11e+04  -1.0 5.22e-01    -  8.52e-03 2.46e-03f  1
#    9  4.9369944e+03 9.19e-01 2.12e+04  -1.0 5.10e-01    -  2.03e-02 1.25e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.2692154e+03 8.77e-01 2.17e+04  -1.0 4.79e-01    -  1.06e-01 4.56e-02f  1
#   11  3.6140307e+03 8.12e-01 2.09e+04  -1.0 4.48e-01    -  2.13e-01 7.34e-02f  1
#   12  2.2854558e+03 5.51e-01 1.60e+04  -1.0 4.15e-01    -  2.34e-01 3.21e-01f  1
#   13  1.2642285e+03 1.16e-01 3.74e+03  -1.0 2.82e-01    -  7.43e-01 7.90e-01f  1
#   14  1.2261002e+03 9.32e-02 3.01e+03  -1.0 6.99e-02    -  1.15e-01 1.96e-01f  1
#   15  1.1968444e+03 7.54e-02 2.43e+03  -1.0 5.86e-02    -  9.63e-02 1.91e-01f  1
#   16  1.1689215e+03 5.81e-02 1.88e+03  -1.0 4.83e-02    -  1.82e-01 2.29e-01f  1
#   17  1.1201842e+03 2.75e-02 1.75e+03  -1.0 3.83e-02    -  1.07e-01 5.27e-01f  1
#   18  1.0963152e+03 1.25e-02 1.88e+03  -1.0 2.36e-02    -  2.70e-01 5.44e-01f  1
#   19  1.0748966e+03 1.24e-04 1.98e+03  -1.0 3.25e-02    -  1.69e-01 9.90e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.0714886e+03 2.72e-07 4.53e+04  -1.0 3.88e-02    -  4.19e-01 9.98e-01h  1
#   21  1.0654654e+03 0.00e+00 3.20e+06  -1.0 3.30e-02    -  5.89e-01 1.00e+00f  1
#   22  1.0409640e+03 1.11e-16 3.65e+06  -1.0 9.31e-02    -  3.21e-01 1.00e+00f  1
#   23  9.9497817e+02 1.11e-16 2.90e+06  -1.0 2.27e-01    -  2.04e-01 1.00e+00f  1
#   24  9.8077798e+02 2.22e-16 1.76e+06  -1.0 1.63e-01    -  3.94e-01 7.31e-01f  1
#   25  9.7720253e+02 1.11e-16 8.74e+05  -1.0 8.24e-02    -  5.03e-01 8.77e-01f  1
#   26  9.7713307e+02 1.11e-16 7.56e-01  -1.0 6.20e-02    -  1.00e+00 1.00e+00f  1
#   27  9.7636862e+02 2.22e-16 3.46e+06  -5.7 4.03e-02    -  6.54e-01 1.00e+00f  1
#   28  9.7621511e+02 2.22e-16 6.45e+05  -5.7 1.70e-02    -  8.14e-01 1.00e+00f  1
#   29  9.7617993e+02 1.11e-16 1.02e+05  -5.7 1.20e-02    -  8.42e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  9.7617374e+02 2.22e-16 1.07e+04  -5.7 4.89e-03    -  8.95e-01 1.00e+00f  1
#   31  9.7617265e+02 2.22e-16 1.01e+02  -5.7 1.70e-03    -  9.91e-01 1.00e+00f  1
#   32  9.7617239e+02 2.22e-16 4.12e+00  -5.7 7.98e-04    -  9.59e-01 1.00e+00f  1
#   33  9.7617237e+02 2.22e-16 1.09e-05  -5.7 2.26e-04    -  1.00e+00 1.00e+00f  1
#   34  9.7617237e+02 2.22e-16 3.51e-01  -8.6 3.54e-05    -  9.98e-01 1.00e+00f  1
#   35  9.7617237e+02 2.22e-16 1.75e-10  -8.6 8.24e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 35
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.7617236674118760e+02    9.7617236674118760e+02
# Dual infeasibility......:   1.7529504482749123e-10    1.7529504482749123e-10
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.5997035365726988e-09    2.5997035365726988e-09
# Overall NLP error.......:   2.5997035365726988e-09    2.5997035365726988e-09
#
#
# Number of objective function evaluations             = 36
# Number of objective gradient evaluations             = 36
# Number of equality constraint evaluations            = 36
# Number of inequality constraint evaluations          = 36
# Number of equality constraint Jacobian evaluations   = 36
# Number of inequality constraint Jacobian evaluations = 36
# Number of Lagrangian Hessian evaluations             = 35
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.352
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 1.46e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.1056011e+03 9.63e-01 1.89e+04  -1.0 8.36e-01    -  1.33e-02 1.73e-02f  1
#    2  6.0995242e+03 9.63e-01 1.89e+04  -1.0 9.07e-01    -  4.08e-02 2.04e-04f  1
#    3  6.0100518e+03 9.60e-01 1.88e+04  -1.0 9.10e-01    -  1.98e-02 2.86e-03f  1
#    4  5.9352191e+03 9.58e-01 1.88e+04  -1.0 7.79e-01    -  1.37e-02 2.32e-03f  1
#    5  5.8267996e+03 9.55e-01 1.88e+04  -1.0 8.03e-01    -  1.05e-02 3.42e-03f  1
#    6  5.7031644e+03 9.51e-01 1.87e+04  -1.0 8.29e-01    -  1.19e-02 4.22e-03f  1
#    7  5.5602269e+03 9.46e-01 1.87e+04  -1.0 9.12e-01    -  4.29e-03 5.30e-03f  1
#    8  5.5401940e+03 9.45e-01 1.86e+04  -1.0 7.49e-01    -  4.01e-03 7.46e-04f  1
#    9  5.4739547e+03 9.42e-01 1.86e+04  -1.0 6.89e-01    -  8.21e-03 2.51e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.4324848e+03 9.41e-01 1.86e+04  -1.0 8.29e-01    -  5.18e-03 1.56e-03f  1
#   11  5.2842331e+03 9.35e-01 1.85e+04  -1.0 8.41e-01    -  3.13e-03 5.95e-03f  1
#   12  5.2504355e+03 9.34e-01 1.85e+04  -1.0 6.80e-01    -  9.12e-03 1.43e-03f  1
#   13  5.0830459e+03 9.27e-01 1.83e+04  -1.0 6.84e-01    -  5.31e-03 7.57e-03f  1
#   14  4.9016720e+03 9.18e-01 1.82e+04  -1.0 6.96e-01    -  3.41e-04 9.38e-03f  1
#   15  4.8658886e+03 9.16e-01 1.82e+04  -1.0 7.07e-01    -  4.68e-03 2.02e-03f  1
#   16  4.8356089e+03 9.15e-01 1.81e+04  -1.0 7.10e-01    -  6.06e-03 1.75e-03f  1
#   17  4.7995139e+03 9.13e-01 1.81e+04  -1.0 7.15e-01    -  1.23e-03 2.12e-03f  1
#   18  4.6865067e+03 9.07e-01 1.80e+04  -1.0 7.54e-01    -  2.81e-03 7.01e-03f  1
#   19  4.5283229e+03 8.97e-01 1.78e+04  -1.0 7.64e-01    -  8.35e-03 1.09e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  4.4827719e+03 8.94e-01 1.77e+04  -1.0 7.26e-01    -  1.80e-02 3.40e-03f  1
#   21  4.3156345e+03 8.82e-01 1.75e+04  -1.0 7.28e-01    -  3.02e-02 1.35e-02f  1
#   22  4.2060265e+03 8.73e-01 1.73e+04  -1.0 8.61e-01    -  1.12e-02 9.87e-03f  1
#   23  4.1719580e+03 8.70e-01 1.73e+04  -1.0 8.95e-01    -  4.68e-02 3.26e-03f  1
#   24  4.1476588e+03 8.68e-01 1.72e+04  -1.0 7.33e-01    -  9.88e-04 2.39e-03f  1
#   25  4.1161147e+03 8.65e-01 1.72e+04  -1.0 7.33e-01    -  2.16e-03 3.18e-03f  1
#   26  4.1095608e+03 8.65e-01 1.72e+04  -1.0 7.33e-01    -  3.09e-03 6.66e-04f  1
#   27  4.0832797e+03 8.62e-01 1.71e+04  -1.0 7.33e-01    -  3.66e-03 2.70e-03f  1
#   28  3.9583306e+03 8.51e-01 1.69e+04  -1.0 7.33e-01    -  5.91e-03 1.36e-02f  1
#   29  3.7449868e+03 8.28e-01 1.65e+04  -1.0 7.30e-01    -  2.37e-02 2.66e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  3.6863490e+03 8.21e-01 1.63e+04  -1.0 7.21e-01    -  2.60e-02 8.29e-03f  1
#   31  3.5341916e+03 8.02e-01 1.60e+04  -1.0 7.16e-01    -  2.44e-03 2.35e-02f  1
#   32  3.3733780e+03 7.79e-01 1.55e+04  -1.0 7.03e-01    -  2.85e-02 2.84e-02f  1
#   33  3.3704231e+03 7.79e-01 1.55e+04  -1.0 6.82e-01    -  1.26e-02 5.67e-04f  1
#   34  3.1822361e+03 7.49e-01 1.49e+04  -1.0 6.80e-01    -  6.01e-03 3.86e-02f  1
#   35  1.5290174e+03 2.52e-01 8.97e+03  -1.0 5.85e-01    -  1.49e-01 6.64e-01f  1
#   36  1.4065768e+03 1.88e-01 6.72e+03  -1.0 1.93e-01    -  4.37e-01 2.52e-01f  1
#   37  1.2689470e+03 1.11e-01 3.96e+03  -1.0 1.42e-01    -  2.72e-01 4.12e-01f  1
#   38  1.1927411e+03 6.71e-02 2.40e+03  -1.0 8.27e-02    -  1.13e-01 3.95e-01f  1
#   39  1.0934004e+03 2.20e-02 2.35e+03  -1.0 1.25e-01    -  8.08e-02 6.72e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.0736157e+03 1.66e-02 1.29e+03  -1.0 1.83e-01    -  4.22e-01 2.46e-01f  1
#   41  1.0294252e+03 2.54e-03 6.57e+02  -1.0 1.79e-01    -  5.57e-01 8.47e-01f  1
#   42  1.0216095e+03 2.44e-05 2.78e+03  -1.0 4.14e-02    -  2.71e-01 9.90e-01h  1
#   43  1.0180437e+03 1.80e-05 5.46e+04  -1.0 9.88e-02    -  4.08e-01 2.61e-01f  2
#   44  1.0022881e+03 6.00e-06 1.89e+05  -1.0 1.69e-01    -  2.59e-01 6.67e-01f  1
#   45  9.9574277e+02 3.45e-06 3.67e+05  -1.0 1.89e-01    -  2.35e-01 4.25e-01f  1
#   46  9.9083795e+02 2.07e-06 5.30e+05  -1.0 1.50e-01    -  2.51e-01 4.00e-01f  2
#   47  9.8150252e+02 9.78e-07 1.04e+06  -1.0 1.48e-01    -  2.51e-01 5.28e-01f  1
#   48  9.7318552e+02 1.11e-16 3.39e+06  -1.0 1.30e-01    -  1.70e-01 1.00e+00f  1
#   49  9.7258712e+02 2.22e-16 3.46e+06  -1.0 8.98e-02    -  5.22e-01 9.75e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  9.7241909e+02 2.22e-16 8.75e-01  -1.0 1.04e-01    -  1.00e+00 1.00e+00f  1
#   51  9.7169871e+02 2.22e-16 2.76e+06  -5.7 3.61e-02    -  7.24e-01 1.00e+00f  1
#   52  9.7153296e+02 2.22e-16 6.95e+05  -5.7 2.40e-02    -  7.48e-01 1.00e+00f  1
#   53  9.7149268e+02 2.22e-16 1.01e+05  -5.7 1.28e-02    -  8.54e-01 1.00e+00f  1
#   54  9.7148384e+02 2.22e-16 8.15e+03  -5.7 5.54e-03    -  9.19e-01 1.00e+00f  1
#   55  9.7148197e+02 2.22e-16 9.07e+02  -5.7 2.46e-03    -  8.89e-01 1.00e+00f  1
#   56  9.7148165e+02 1.11e-16 2.25e-04  -5.7 7.89e-04    -  1.00e+00 1.00e+00f  1
#   57  9.7148161e+02 2.22e-16 1.34e-05  -5.7 1.70e-04    -  1.00e+00 1.00e+00f  1
#   58  9.7148161e+02 2.22e-16 2.50e-07  -8.6 2.55e-05    -  1.00e+00 1.00e+00f  1
#   59  9.7148161e+02 2.22e-16 6.18e-11  -8.6 2.75e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 59
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.7148160581738091e+02    9.7148160581738091e+02
# Dual infeasibility......:   6.1812951682118021e-11    6.1812951682118021e-11
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   2.5227938193476397e-09    2.5227938193476397e-09
# Overall NLP error.......:   2.5227938193476397e-09    2.5227938193476397e-09
#
#
# Number of objective function evaluations             = 62
# Number of objective gradient evaluations             = 60
# Number of equality constraint evaluations            = 62
# Number of inequality constraint evaluations          = 62
# Number of equality constraint Jacobian evaluations   = 60
# Number of inequality constraint Jacobian evaluations = 60
# Number of Lagrangian Hessian evaluations             = 59
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.433
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      240
# Number of nonzeros in inequality constraint Jacobian.:      550
# Number of nonzeros in Lagrangian Hessian.............:       68
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      240
#                      variables with only lower bounds:      240
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      202
# Total number of inequality constraints...............:      275
#         inequality constraints with only lower bounds:      275
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8755206e+03 9.80e-01 2.03e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.1094754e+03 9.60e-01 2.25e+04  -1.0 8.70e-01    -  1.27e-02 2.04e-02f  1
#    2  6.1029862e+03 9.60e-01 2.25e+04  -1.0 9.25e-01    -  4.22e-02 2.84e-04f  1
#    3  6.0424566e+03 9.57e-01 2.24e+04  -1.0 9.04e-01    -  2.05e-02 2.43e-03f  1
#    4  5.9729808e+03 9.55e-01 2.24e+04  -1.0 8.82e-01    -  1.53e-02 2.50e-03f  1
#    5  5.8510429e+03 9.51e-01 2.23e+04  -1.0 8.78e-01    -  2.55e-03 4.14e-03f  1
#    6  5.7948985e+03 9.49e-01 2.22e+04  -1.0 8.46e-01    -  1.58e-02 1.92e-03f  1
#    7  5.7149412e+03 9.47e-01 2.22e+04  -1.0 6.51e-01    -  8.25e-03 2.52e-03f  1
#    8  5.5482753e+03 9.41e-01 2.23e+04  -1.0 6.97e-01    -  1.32e-03 5.69e-03f  1
#    9  5.4830928e+03 9.39e-01 2.23e+04  -1.0 5.98e-01    -  5.62e-03 2.38e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.3585852e+03 9.35e-01 2.23e+04  -1.0 5.96e-01    -  8.72e-03 4.85e-03f  1
#   11  5.2479258e+03 9.30e-01 2.23e+04  -1.0 5.64e-01    -  7.88e-03 4.66e-03f  1
#   12  5.1853239e+03 9.28e-01 2.22e+04  -1.0 5.41e-01    -  8.41e-03 2.79e-03f  1
#   13  4.9779685e+03 9.18e-01 2.22e+04  -1.0 5.86e-01    -  8.70e-03 1.03e-02f  1
#   14  4.9553956e+03 9.17e-01 2.21e+04  -1.0 7.58e-01    -  5.22e-03 1.25e-03f  1
#   15  4.9087755e+03 9.15e-01 2.21e+04  -1.0 7.55e-01    -  2.98e-03 2.66e-03f  1
#   16  4.6532919e+03 9.00e-01 2.19e+04  -1.0 7.64e-01    -  3.31e-03 1.61e-02f  1
#   17  4.6328886e+03 8.99e-01 2.18e+04  -1.0 8.29e-01    -  3.13e-02 1.42e-03f  1
#   18  4.5406934e+03 8.93e-01 2.17e+04  -1.0 8.82e-01    -  5.59e-02 6.62e-03f  1
#   19  4.5373046e+03 8.92e-01 2.17e+04  -1.0 6.34e-01    -  1.07e-03 2.53e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  4.5325094e+03 8.92e-01 2.17e+04  -1.0 5.94e-01    -  4.68e-05 3.54e-04f  1
#   21  4.5310973e+03 8.92e-01 2.17e+04  -1.0 7.39e-01    -  4.12e-04 1.07e-04f  1
#   22  4.5207418e+03 8.91e-01 2.17e+04  -1.0 7.01e-01    -  4.79e-06 7.76e-04f  1
#   23  4.5012573e+03 8.90e-01 2.17e+04  -1.0 6.31e-01    -  8.18e-04 1.43e-03f  1
#   24  4.4715060e+03 8.88e-01 2.16e+04  -1.0 6.46e-01    -  7.41e-04 2.18e-03f  1
#   25  4.4505302e+03 8.87e-01 2.16e+04  -1.0 7.18e-01    -  2.26e-03 1.54e-03f  1
#   26  4.2868196e+03 8.75e-01 2.14e+04  -1.0 7.88e-01    -  3.41e-03 1.29e-02f  1
#   27  4.2191346e+03 8.70e-01 2.13e+04  -1.0 8.35e-01    -  1.56e-02 5.87e-03f  1
#   28  4.2043377e+03 8.69e-01 2.13e+04  -1.0 8.47e-01    -  1.73e-02 1.33e-03f  1
#   29  4.0824689e+03 8.59e-01 2.11e+04  -1.0 7.02e-01    -  8.37e-03 1.15e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.0812300e+03 8.59e-01 2.11e+04  -1.0 6.66e-01    -  8.20e-03 1.23e-04f  1
#   31  4.0766076e+03 8.59e-01 2.11e+04  -1.0 8.59e-01    -  3.34e-04 4.41e-04f  1
#   32  4.0669346e+03 8.58e-01 2.10e+04  -1.0 6.32e-01    -  1.11e-04 9.43e-04f  1
#   33  4.0621890e+03 8.57e-01 2.10e+04  -1.0 7.05e-01    -  1.55e-03 4.62e-04f  1
#   34  4.0018915e+03 8.52e-01 2.09e+04  -1.0 6.37e-01    -  1.08e-03 6.10e-03f  1
#   35  3.9812338e+03 8.50e-01 2.09e+04  -1.0 5.98e-01    -  7.00e-03 2.15e-03f  1
#   36  3.8207947e+03 8.35e-01 2.06e+04  -1.0 5.99e-01    -  1.10e-02 1.78e-02f  1
#   37  3.7714008e+03 8.30e-01 2.04e+04  -1.0 5.88e-01    -  1.83e-02 5.99e-03f  1
#   38  3.6392741e+03 8.16e-01 2.01e+04  -1.0 5.85e-01    -  3.71e-02 1.71e-02f  1
#   39  3.6367684e+03 8.16e-01 2.01e+04  -1.0 5.79e-01    -  2.17e-03 3.46e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  3.6158214e+03 8.13e-01 2.01e+04  -1.0 6.43e-01    -  2.37e-04 2.91e-03f  1
#   41  3.4919931e+03 7.99e-01 1.97e+04  -1.0 6.82e-01    -  2.32e-03 1.81e-02f  1
#   42  3.3434349e+03 7.79e-01 1.93e+04  -1.0 6.89e-01    -  2.12e-02 2.43e-02f  1
#   43  3.3417302e+03 7.79e-01 1.93e+04  -1.0 6.50e-01    -  3.18e-02 3.00e-04f  1
#   44  1.0867214e+03 4.59e-02 1.06e+04  -1.0 5.43e-01    -  6.36e-03 9.41e-01f  1
#   45  1.0606368e+03 2.93e-02 8.79e+03  -1.0 3.23e-02    -  1.96e-01 3.61e-01f  1
#   46  1.0489268e+03 2.19e-02 6.95e+03  -1.0 2.06e-02    -  2.15e-01 2.55e-01f  1
#   47  1.0273429e+03 8.14e-03 5.44e+03  -1.0 2.27e-02    -  2.38e-01 6.27e-01f  1
#   48  1.0196342e+03 3.55e-03 3.50e+03  -1.0 3.16e-02    -  3.80e-01 5.64e-01h  1
#   49  1.0122477e+03 3.46e-05 2.88e+03  -1.0 6.23e-02    -  3.98e-01 9.90e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.0097067e+03 1.11e-16 1.07e+05  -1.0 1.04e-01    -  6.11e-01 1.00e+00h  1
#   51  1.0041702e+03 1.11e-16 5.77e+06  -1.0 7.76e-02    -  4.13e-01 1.00e+00f  1
#   52  9.9325927e+02 1.11e-16 4.10e+06  -1.0 1.31e-01    -  2.89e-01 8.13e-01f  1
#   53  9.7855117e+02 1.11e-16 2.88e+06  -1.0 1.30e-01    -  2.97e-01 9.38e-01f  1
#   54  9.3431025e+02 1.11e-16 2.42e+06  -1.0 1.90e-01    -  1.62e-01 7.06e-01f  1
#   55  9.1203271e+02 2.22e-16 1.76e+06  -1.0 2.28e-01    -  2.72e-01 3.94e-01f  1
#   56  8.9613264e+02 2.22e-16 1.31e+06  -1.0 2.01e-01    -  2.56e-01 4.74e-01f  1
#   57  8.8041444e+02 2.22e-16 1.02e+06  -1.0 2.31e-01    -  2.24e-01 6.33e-01f  1
#   58  8.7954046e+02 2.22e-16 1.90e+05  -1.0 7.12e-02    -  8.13e-01 7.71e-01f  1
#   59  8.7939431e+02 2.22e-16 7.29e-01  -1.0 2.60e-02    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  8.7877918e+02 2.22e-16 2.49e+06  -5.7 3.16e-02    -  7.51e-01 1.00e+00f  1
#   61  8.7859492e+02 2.22e-16 9.21e+05  -5.7 1.91e-02    -  6.31e-01 1.00e+00f  1
# ...
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      128
# Number of nonzeros in inequality constraint Jacobian.:      120
# Number of nonzeros in Lagrangian Hessian.............:       32
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      128
#                      variables with only lower bounds:      128
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      112
# Total number of inequality constraints...............:       60
#         inequality constraints with only lower bounds:       60
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.5998882e+03 9.80e-01 1.67e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.4175348e+03 9.45e-01 2.73e+04  -1.0 7.09e-01    -  1.60e-02 3.54e-02f  1
#    2  4.4129425e+03 9.45e-01 2.73e+04  -1.0 8.21e-01    -  1.16e-01 2.37e-04f  1
#    3  4.2915093e+03 9.39e-01 2.71e+04  -1.0 6.77e-01    -  3.39e-02 6.19e-03f  1
#    4  4.0428809e+03 9.25e-01 2.70e+04  -1.0 6.26e-01    -  5.50e-02 1.47e-02f  1
#    5  3.9346579e+03 9.19e-01 2.68e+04  -1.0 6.03e-01    -  1.06e-01 7.43e-03f  1
#    6  3.6153645e+03 8.95e-01 2.66e+04  -1.0 5.30e-01    -  5.04e-02 2.59e-02f  1
#    7  3.3188347e+03 8.67e-01 2.60e+04  -1.0 5.00e-01    -  2.12e-02 3.16e-02f  1
#    8  3.1071419e+03 8.42e-01 2.54e+04  -1.0 4.55e-01    -  1.36e-01 2.85e-02f  1
#    9  2.2805910e+03 6.91e-01 2.23e+04  -1.0 4.32e-01    -  2.69e-02 1.79e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.3583755e+03 3.45e-01 1.19e+04  -1.0 3.56e-01    -  5.51e-01 5.02e-01f  1
#   11  1.1153121e+03 2.00e-01 6.96e+03  -1.0 1.78e-01    -  5.57e-01 4.19e-01f  1
#   12  1.0147706e+03 1.32e-01 4.57e+03  -1.0 1.04e-01    -  2.74e-01 3.43e-01f  1
#   13  9.5065067e+02 8.48e-02 2.95e+03  -1.0 7.23e-02    -  2.18e-01 3.56e-01f  1
#   14  9.1333773e+02 5.65e-02 1.96e+03  -1.0 4.84e-02    -  1.15e-01 3.34e-01f  1
#   15  8.4249254e+02 5.64e-04 3.91e+02  -1.0 3.51e-02    -  3.56e-01 9.90e-01f  1
#   16  8.4059084e+02 4.67e-06 7.37e+03  -1.0 1.28e-02    -  5.67e-01 9.92e-01h  1
#   17  8.3857759e+02 2.33e-06 1.25e+05  -1.0 3.73e-02    -  4.30e-01 5.00e-01f  2
#   18  8.2796657e+02 1.11e-16 2.09e+06  -1.0 8.60e-02    -  2.35e-01 1.00e+00f  1
#   19  8.1880627e+02 1.11e-16 5.89e+06  -1.0 1.49e-01    -  3.15e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  8.1829901e+02 1.11e-16 2.17e+05  -1.0 6.14e-02    -  9.63e-01 1.00e+00f  1
#   21  8.1831039e+02 1.11e-16 1.66e-02  -1.0 1.09e-02    -  1.00e+00 1.00e+00f  1
#   22  8.1788259e+02 1.11e-16 1.04e+06  -8.6 3.17e-02    -  8.96e-01 1.00e+00f  1
#   23  8.1782501e+02 1.11e-16 1.20e+05  -8.6 1.36e-02    -  8.85e-01 1.00e+00f  1
#   24  8.1781554e+02 1.11e-16 5.40e+03  -8.6 7.32e-03    -  9.55e-01 1.00e+00f  1
#   25  8.1781382e+02 2.22e-16 1.23e+02  -8.6 3.39e-03    -  9.77e-01 1.00e+00f  1
#   26  8.1781344e+02 1.11e-16 1.52e+00  -8.6 9.82e-04    -  9.88e-01 1.00e+00f  1
#   27  8.1781338e+02 1.11e-16 2.04e-06  -8.6 1.28e-04    -  1.00e+00 1.00e+00f  1
#   28  8.1781338e+02 2.22e-16 1.26e-09  -8.6 4.16e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 28
#
#                                    (scaled)                 (unscaled)
# Objective...............:   8.1781337605836575e+02    8.1781337605836575e+02
# Dual infeasibility......:   1.2575686702639805e-09    1.2575686702639805e-09
# Constraint violation....:   2.2204460492503131e-16    2.2204460492503131e-16
# Complementarity.........:   4.1002594883255644e-09    4.1002594883255644e-09
# Overall NLP error.......:   4.1002594883255644e-09    4.1002594883255644e-09
#
#
# Number of objective function evaluations             = 30
# Number of objective gradient evaluations             = 29
# Number of equality constraint evaluations            = 30
# Number of inequality constraint evaluations          = 30
# Number of equality constraint Jacobian evaluations   = 29
# Number of inequality constraint Jacobian evaluations = 29
# Number of Lagrangian Hessian evaluations             = 28
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.304
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       88
# Number of nonzeros in inequality constraint Jacobian.:       56
# Number of nonzeros in Lagrangian Hessian.............:       22
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:       88
#                      variables with only lower bounds:       88
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       77
# Total number of inequality constraints...............:       28
#         inequality constraints with only lower bounds:       28
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.8262194e+03 9.80e-01 1.95e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.8343831e+03 9.42e-01 2.76e+04  -1.0 7.91e-01    -  1.41e-02 3.92e-02f  1
#    2  3.8306345e+03 9.41e-01 2.75e+04  -1.0 8.86e-01    -  8.98e-02 2.96e-04f  1
#    3  3.7911857e+03 9.39e-01 2.75e+04  -1.0 8.27e-01    -  1.72e-02 2.66e-03f  1
#    4  3.7191548e+03 9.34e-01 2.74e+04  -1.0 7.72e-01    -  1.71e-02 4.90e-03f  1
#    5  3.6291346e+03 9.28e-01 2.73e+04  -1.0 7.40e-01    -  2.34e-02 6.48e-03f  1
#    6  3.5694164e+03 9.24e-01 2.72e+04  -1.0 7.38e-01    -  5.00e-02 4.38e-03f  1
#    7  3.3655698e+03 9.10e-01 2.73e+04  -1.0 6.98e-01    -  1.84e-02 1.56e-02f  1
#    8  3.2830085e+03 9.03e-01 2.72e+04  -1.0 6.74e-01    -  2.20e-02 7.24e-03f  1
#    9  2.4200450e+03 7.89e-01 2.97e+04  -1.0 6.87e-01    -  3.36e-02 1.26e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  8.5399312e+02 5.75e-02 8.94e+03  -1.0 6.52e-01    -  4.29e-01 9.27e-01f  1
#   11  7.6451727e+02 1.10e-02 1.71e+03  -1.0 1.51e-01    -  7.17e-01 8.09e-01f  1
#   12  7.4458965e+02 6.32e-03 2.51e+03  -1.0 1.80e-01    -  1.57e-01 4.26e-01f  1
#   13  7.2832651e+02 2.01e-03 2.67e+03  -1.0 1.58e-01    -  1.92e-01 6.81e-01f  1
#   14  7.3100591e+02 1.92e-05 2.24e+03  -1.0 6.03e-02    -  5.30e-01 9.90e-01h  1
#   15  7.2745290e+02 9.59e-06 9.38e+03  -1.0 5.93e-02    -  4.83e-01 5.00e-01f  2
#   16  7.2423763e+02 4.79e-06 1.72e+05  -1.0 3.11e-02    -  3.15e-01 5.00e-01f  2
#   17  7.0715109e+02 1.16e-08 1.35e+06  -1.0 3.82e-02    -  1.58e-01 9.98e-01f  1
#   18  6.6083113e+02 1.11e-16 7.60e+06  -1.0 1.68e-01    -  1.66e-01 1.00e+00f  1
#   19  6.5139969e+02 1.11e-16 4.91e+06  -1.0 1.24e-01    -  3.63e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  6.4885194e+02 0.00e+00 3.55e+06  -1.0 8.99e-02    -  2.77e-01 1.00e+00f  1
#   21  6.4870572e+02 2.22e-16 4.26e-01  -1.0 4.13e-02    -  1.00e+00 1.00e+00f  1
#   22  6.4853374e+02 1.11e-16 1.33e+06  -8.6 2.75e-02    -  8.67e-01 1.00e+00f  1
#   23  6.4848678e+02 2.22e-16 1.06e+05  -8.6 1.65e-02    -  9.20e-01 1.00e+00f  1
#   24  6.4847498e+02 1.11e-16 3.58e+03  -8.6 8.63e-03    -  9.66e-01 1.00e+00f  1
#   25  6.4847233e+02 1.11e-16 3.54e+01  -8.6 4.46e-03    -  9.90e-01 1.00e+00f  1
#   26  6.4847187e+02 1.02e-56 4.13e-04  -8.6 2.07e-03    -  1.00e+00 1.00e+00f  1
#   27  6.4847181e+02 1.02e-56 6.80e-05  -8.6 7.39e-04    -  1.00e+00 1.00e+00f  1
#   28  6.4847180e+02 0.00e+00 1.18e-03  -8.6 1.68e-04    -  9.62e-01 1.00e+00f  1
#   29  6.4847180e+02 1.11e-16 8.84e-05  -8.6 9.41e-05    -  9.94e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  6.4847180e+02 2.22e-16 3.43e-07  -8.6 5.28e-05    -  1.00e+00 1.00e+00f  1
#   31  6.4847180e+02 3.19e-58 8.65e-08  -8.6 2.65e-05    -  1.00e+00 1.00e+00f  1
#   32  6.4847180e+02 2.22e-16 2.10e-08  -8.6 1.30e-05    -  1.00e+00 1.00e+00h  1
#   33  6.4847180e+02 4.59e-41 5.44e-09  -9.0 6.63e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 33
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.4847179784797379e+02    6.4847179784797379e+02
# Dual infeasibility......:   5.4354227918271639e-09    5.4354227918271639e-09
# Constraint violation....:   4.5917748078995606e-41    4.5917748078995606e-41
# Complementarity.........:   6.1099729706710519e-09    6.1099729706710519e-09
# Overall NLP error.......:   6.1099729706710519e-09    6.1099729706710519e-09
#
#
# Number of objective function evaluations             = 36
# Number of objective gradient evaluations             = 34
# Number of equality constraint evaluations            = 36
# Number of inequality constraint evaluations          = 36
# Number of equality constraint Jacobian evaluations   = 34
# Number of inequality constraint Jacobian evaluations = 34
# Number of Lagrangian Hessian evaluations             = 33
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.255
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Solver found a solution.
# Ipopt 3.12.12: max_iter=10000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.12, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       88
# Number of nonzeros in inequality constraint Jacobian.:       56
# Number of nonzeros in Lagrangian Hessian.............:       22
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:       88
#                      variables with only lower bounds:       88
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       77
# Total number of inequality constraints...............:       28
#         inequality constraints with only lower bounds:       28
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.8262194e+03 9.80e-01 1.77e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.0495953e+03 9.53e-01 2.39e+04  -1.0 7.83e-01    -  1.43e-02 2.71e-02f  1
#    2  4.0458393e+03 9.53e-01 2.39e+04  -1.0 8.72e-01    -  7.47e-02 2.30e-04f  1
#    3  3.9695649e+03 9.49e-01 2.38e+04  -1.0 8.57e-01    -  3.61e-02 4.56e-03f  1
#    4  3.8975096e+03 9.45e-01 2.37e+04  -1.0 7.90e-01    -  5.49e-02 4.24e-03f  1
#    5  3.7700569e+03 9.38e-01 2.36e+04  -1.0 6.91e-01    -  2.11e-02 7.20e-03f  1
#    6  3.5721449e+03 9.26e-01 2.38e+04  -1.0 6.93e-01    -  2.08e-02 1.23e-02f  1
#    7  3.5105086e+03 9.23e-01 2.37e+04  -1.0 5.07e-01    -  4.46e-02 4.24e-03f  1
#    8  2.6642725e+03 8.37e-01 2.68e+04  -1.0 4.72e-01    -  2.94e-02 9.30e-02f  1
#    9  7.4133536e+02 1.41e-02 1.23e+04  -1.0 4.27e-01    -  4.75e-01 9.83e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.3210480e+02 5.42e-03 4.72e+03  -1.0 7.39e-03    -  4.65e-01 6.15e-01f  1
#   11  7.2664976e+02 3.09e-04 3.07e+03  -1.0 3.38e-03    -  2.98e-01 9.43e-01h  1
#   12  7.2622597e+02 2.12e-06 1.56e+04  -1.0 1.28e-03    -  5.00e-01 9.93e-01h  1
#   13  7.2600759e+02 0.00e+00 1.12e+06  -1.0 2.52e-03    -  6.45e-01 1.00e+00h  1
#   14  7.2523772e+02 3.67e-40 4.47e+06  -1.0 7.71e-03    -  4.38e-01 1.00e+00f  1
#   15  7.2299894e+02 2.22e-16 2.40e+06  -1.0 1.60e-02    -  4.64e-01 1.00e+00f  1
#   16  7.1827779e+02 2.22e-16 2.18e+06  -1.0 8.00e-02    -  8.97e-02 2.28e-01f  1
#   17  7.0143766e+02 1.11e-16 1.92e+06  -1.0 1.62e-01    -  1.19e-01 3.52e-01f  1
#   18  6.5802796e+02 2.22e-16 1.58e+06  -1.0 2.04e-01    -  1.78e-01 1.00e+00f  1
#   19  6.4907819e+02 2.22e-16 8.21e+05  -1.0 2.03e-01    -  4.81e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  6.4852388e+02 1.11e-16 1.63e+00  -1.0 4.85e-02    -  1.00e+00 1.00e+00f  1
#   21  6.4839336e+02 1.11e-16 8.05e+05  -5.7 1.79e-02    -  9.20e-01 1.00e+00f  1
#   22  6.4837641e+02 2.22e-16 2.80e+04  -5.7 6.95e-03    -  9.65e-01 1.00e+00f  1
#   23  6.4837277e+02 0.00e+00 2.09e+03  -5.7 2.68e-03    -  9.25e-01 1.00e+00f  1
#   24  6.4837162e+02 2.22e-16 9.82e+01  -5.7 1.25e-03    -  9.53e-01 1.00e+00f  1
#   25  6.4837137e+02 2.22e-16 2.49e-05  -5.7 2.99e-04    -  1.00e+00 1.00e+00f  1
#   26  6.4837136e+02 1.11e-16 1.01e-07  -5.7 1.87e-05    -  1.00e+00 1.00e+00f  1
#   27  6.4837136e+02 0.00e+00 2.80e-09  -8.6 2.38e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 27
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.4837135595489906e+02    6.4837135595489906e+02
# Dual infeasibility......:   2.8020027738159039e-09    2.8020027738159039e-09
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   3.6192230868198563e-09    3.6192230868198563e-09
# Overall NLP error.......:   3.6192230868198563e-09    3.6192230868198563e-09
#
#
# Number of objective function evaluations             = 28
# Number of objective gradient evaluations             = 28
# Number of equality constraint evaluations            = 28
# Number of inequality constraint evaluations          = 28
# Number of equality constraint Jacobian evaluations   = 28
# Number of inequality constraint Jacobian evaluations = 28
# Number of Lagrangian Hessian evaluations             = 27
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.244
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# Solver found a solution.

# %%
# record kl loss of MDM
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),
                                'mdm_kl_loss':all_mdm_kl_loss[i],
                                'avg_mdm_kl_loss':all_mdm_avg_kl_loss[i],
                                'mdm_kl_time':all_total_time[i]})
    df_mdm_loss.to_csv('mdm/limit_loss/kl/'+str(pred_offer_times_list[i])+'.csv')

# %%
avg_total_kl_loss = []
avg_total_kl_loss_se = []
avg_avg_kl_loss = []
avg_avg_kl_loss_se = []

avg_runtime = []
avg_runtime_se = []

for i in range(len(pred_offer_times_list)):
    avg_total_kl_loss.append(np.mean(all_mdm_kl_loss[i]))
    avg_total_kl_loss_se.append(np.std(all_mdm_kl_loss[i])/np.sqrt(len(all_mdm_kl_loss[i])))
    
    avg_avg_kl_loss.append(np.mean(all_mdm_avg_kl_loss[i]))
    avg_avg_kl_loss_se.append(np.std(all_mdm_avg_kl_loss[i])/np.sqrt(len(all_mdm_avg_kl_loss[i])))
    
    avg_runtime.append(np.mean(all_total_time[i]))
    avg_runtime_se.append(np.std(all_total_time[i])/np.sqrt(len(all_total_time[i])) )
    
df_mdm_kl = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                   'total_mdm_kl_loss':avg_total_kl_loss,'total_mdm_kl_loss_se':avg_total_kl_loss_se,
                                   'avg_mdm_kl_loss':avg_avg_kl_loss,'avg_mdm_kl_loss_se':avg_avg_kl_loss_se,
                                   'mdm_kl_time':avg_runtime,'mdm_kl_time_se':avg_runtime_se
                                   })
df_mdm_kl.to_csv('mdm/mdm_kl_summary_probit_no_outside.csv')
df_mdm_kl
# Out:
#    offertimes  collection_size  total_mdm_kl_loss  total_mdm_kl_loss_se  \
# 0          15               30           0.002150              0.000530
# 1          20               21           0.000348              0.000341
# 2          30               16           0.000086              0.000055
# 3          40               11           0.000046              0.000045
# 4          50                7           0.000000              0.000000
#
#    avg_mdm_kl_loss  avg_mdm_kl_loss_se  mdm_kl_time  mdm_kl_time_se
# 0     1.440239e-06        3.547313e-07     0.353410        0.041509
# 1     2.591848e-07        2.538913e-07     0.033321        0.015904
# 2     7.055753e-08        4.485695e-08     0.033341        0.015939
# 3     4.383647e-08        4.339584e-08     0.013588        0.009322
# 4     0.000000e+00        0.000000e+00     0.000104        0.000005

# %%
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se
# 0          15               30     0.40      0.000380         0.000033
# 1          20               21     0.92      0.000282         0.000043
# 2          30               16     0.92      0.000211         0.000013
# 3          40               11     0.96      0.000138         0.000007
# 4          50                7     1.00      0.000104         0.000005

# %%
## adding limit results
#ins_idx = list(range(pred_instance_size[0]))
for i in range(len(pred_offer_times_list)):
    for j in range(pred_instance_size[i]):
        df_limit_prob = pd.DataFrame(all_mdm_kl_prob[i][j])
        df_limit_prob.to_csv('mdm/limit_prob/kl/offertimes'+str(pred_offer_times_list[i])+'/kl_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_rep_approx = []
all_rep_approx_mean = []
for i in range(len(pred_offer_times_list)):
    rep_approx = []
    for j in range(pred_instance_size[i]):
        if all_mdm_avg_kl_loss[i][j]<1e-6:
            rep_approx.append(j)
    df_rep_approx = pd.DataFrame(rep_approx)
    df_rep_approx.to_csv('mdm/representability_approx/'+str(pred_offer_times_list[i])+'.csv')
    all_rep_approx_mean.append(len(rep_approx)/pred_instance_size[i])
    all_rep_approx.append(rep_approx)
all_rep_approx_mean
# Out:
# [0.72, 0.98, 0.96, 0.98, 1.0]

# %%
mdm_rep_summary['mdm_rep_approx'] = all_rep_approx_mean
mdm_rep_summary
# Out:
#    offertimes  collection_size  mdm_rep  mdm_rep_time  mdm_rep_time_se  \
# 0          15               30     0.40      0.000380         0.000033
# 1          20               21     0.92      0.000282         0.000043
# 2          30               16     0.92      0.000211         0.000013
# 3          40               11     0.96      0.000138         0.000007
# 4          50                7     1.00      0.000104         0.000005
#
#    mdm_rep_approx
# 0            0.72
# 1            0.98
# 2            0.96
# 3            0.98
# 4            1.00

# %%
mdm_rep_summary.to_csv('mdm/mdm_rep_summary_probit_no_outside.csv')

# %%
error_instance_df = pd.read_csv('mccm_error_instance.csv')
error_i_raw = error_instance_df['error_i'].tolist()
error_j_raw = error_instance_df['error_j'].tolist()

# %%
error_i = []
error_j = []
for x in range(len(error_i_raw)):
    if error_i_raw[x]<=1:
        error_i.append(error_i_raw[x])
        error_j.append(error_j_raw[x])

# %%
def create_new_list(A, error_i, error_j):
    # Create a set of (i, j) pairs for fast lookup of error positions
    error_set = set(zip(error_i, error_j))
    
    # Create a new list of lists by excluding the elements that are in the error_set
    A_prime = []
    for i, row in enumerate(A):
        new_row = [elem for j, elem in enumerate(row) if (i, j) not in error_set]
        A_prime.append(new_row)
    
    return A_prime

# %%
new_all_mdm_loss = create_new_list(all_mdm_avg_kl_loss,error_i,error_j)
new_all_mdm_time = create_new_list(all_total_time,error_i,error_j)


for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'mdm_kl_loss':new_all_mdm_loss[i],'mdm_kl_time':new_all_mdm_time[i]})
    df_mdm_loss.to_csv('mdm/limit_loss_new/'+str(pred_offer_times_list[i])+'.csv')

mdm_kl_loss_mean = [np.mean(new_all_mdm_loss[x]) for x in range(len(pred_offer_times_list)) ]
mdm_kl_loss_se = [ np.std(new_all_mdm_loss[x])/np.sqrt(len(new_all_mdm_loss[x])) for x in range(len(pred_offer_times_list)) ]

mdm_kl_time_mean = [np.mean(new_all_mdm_time[x]) for x in range(len(pred_offer_times_list)) ]
mdm_kl_time_se = [ np.std(new_all_mdm_time[x])/np.sqrt(len(new_all_mdm_time[x])) for x in range(len(pred_offer_times_list)) ]

df_mdm_kl_loss = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,
                                  'mdm_kl_loss':mdm_kl_loss_mean, 'mdm_kl_loss_se':mdm_kl_loss_se,
                                'mdm_kl_time':mdm_kl_time_mean, 'mdm_kl_time_se':mdm_kl_time_se
                                  })
df_mdm_kl_loss.to_csv('mdm/mdm_kl_summary_NEW.csv')
df_mdm_kl_loss
# Out:
#    offertimes  collection_size   mdm_kl_loss  mdm_kl_loss_se  mdm_kl_time  \
# 0          15               30  1.469632e-06    3.607509e-07     0.360619
# 1          20               21  2.879832e-07    2.817746e-07     0.036984
# 2          30               16  7.055753e-08    4.485695e-08     0.033341
# 3          40               11  4.383647e-08    4.339584e-08     0.013588
# 4          50                7  0.000000e+00    0.000000e+00     0.000104
#
#    mdm_kl_time_se
# 0        0.041725
# 1        0.017587
# 2        0.015939
# 3        0.009322
# 4        0.000005

# %%
all_rep = []
rep_mean = []
for i in range(len(pred_instance_size)):
    rep_lst = []
    for j in range(len(new_all_mdm_loss[i])):
        if new_all_mdm_loss[i][j] <1e-6:
            rep_lst.append(j)
    df_rep = pd.DataFrame(rep_lst)
    df_rep.to_csv('mdm/representability_new/'+str(pred_offer_times_list[i])+'.csv')
    all_rep.append(rep_lst)
    rep_mean.append(len(rep_lst)/len(new_all_mdm_loss[i]))
rep_mean
# Out:
# [0.7142857142857143, 0.9777777777777777, 0.96, 0.98, 1.0]

# %%
df_rep = pd.DataFrame({'offertimes':pred_offer_times_list,'collection_size':full_collection_size,'mdm_rep':rep_mean})
df_rep.to_csv('mdm/mdm_rep_summary_NEW.csv')
df_rep
# Out:
#    offertimes  collection_size   mdm_rep
# 0          15               30  0.714286
# 1          20               21  0.977778
# 2          30               16  0.960000
# 3          40               11  0.980000
# 4          50                7  1.000000
