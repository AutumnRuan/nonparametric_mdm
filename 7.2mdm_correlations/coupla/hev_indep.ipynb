# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import copy
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)

# %%
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def collection_distribution_hev(n,collection,price):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    ''' rho = -0.5 # prices and utilities are negatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n))
    
    scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n)) '''
    
    mu = np.random.uniform(-2,2,n)
    scales = np.random.uniform(0.04,2,n)
    
    sample_size = 10000
    utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    # generate covariance matrix with positive correlation
    # neg_cov = generate_negatively_correlated_covariance_matrix(n)
    # if is_positive_semidefinite(neg_cov): 
    #     sample_size = 10000
    #     utility_samples = np.random.multivariate_normal(mu,neg_cov,size=sample_size)
    # else:
    #     print('Negative correlation matrix error')
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [100,100,100,100,100]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
def filter_probability(whole_choice_collection,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
 
        
    return choice_collection

# %%
## generate 50 random full instances 
pred_full_instance_indep = []

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    indep_curr_whole_instance = collection_distribution_hev(n,jd_collection,price)

    pred_full_instance_indep.append(indep_curr_whole_instance)
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance
# generating 50 th instance
# generating 51 th instance
# generating 52 th instance
# generating 53 th instance
# generating 54 th instance
# generating 55 th instance
# generating 56 th instance
# generating 57 th instance
# generating 58 th instance
# generating 59 th instance
# generating 60 th instance
# generating 61 th instance
# generating 62 th instance
# generating 63 th instance
# generating 64 th instance
# generating 65 th instance
# generating 66 th instance
# generating 67 th instance
# generating 68 th instance
# generating 69 th instance
# generating 70 th instance
# generating 71 th instance
# generating 72 th instance
# generating 73 th instance
# generating 74 th instance
# generating 75 th instance
# generating 76 th instance
# generating 77 th instance
# generating 78 th instance
# generating 79 th instance
# generating 80 th instance
# generating 81 th instance
# generating 82 th instance
# generating 83 th instance
# generating 84 th instance
# generating 85 th instance
# generating 86 th instance
# generating 87 th instance
# generating 88 th instance
# generating 89 th instance
# generating 90 th instance
# generating 91 th instance
# generating 92 th instance
# generating 93 th instance
# generating 94 th instance
# generating 95 th instance
# generating 96 th instance
# generating 97 th instance
# generating 98 th instance
# generating 99 th instance

# %%
# full instance generation for indep gaussian 
all_full_instances_indep = []
 
for i in range(len(pred_offer_times_list)):
    
    full_instances_indep = []

    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection_indep = filter_probability(pred_full_instance_indep[j],all_full_assortment_index[i])
        full_instances_indep.append(curr_choice_collection_indep)
     
    all_full_instances_indep.append(full_instances_indep)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonnegative_descending(arr):
    row_indexes_sorted_desc_nonnegative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-negative values
        nonnegative_row = row[row >= 0]  # Consider only non-negative values
        unique_elements, unique_indexes = np.unique(nonnegative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonnegative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonnegative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm')
    #model.setParam(gp.GRB.Param.TimeLimit, 60)
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    if model.status == gp.GRB.OPTIMAL:
        #print('Optimal solution found!')
        eps_value = eps.x
        if eps_value>0:
            return [1,model.Runtime]
        else:
            #model.write("mdminfeas_model.lp")
        
            return [0,model.Runtime]
    else:
        print('MDM feasibility formulation error')

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.01

    model = gp.Model()
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")
    ''' abs_vars = {}
    for i in range(n):
        for j in range(m):
            abs_vars[i, j] = model.addVar(vtype=GRB.CONTINUOUS, name=f"abs_{i}_{j}") '''

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{j}_{0}")
                #model.addConstr(abs_vars[j, i] == 0, name=f"abs_forcing_zero_{j}_{0}")
            else:
                model.addConstr(x[j, i] - data[j, i] <= abs_vars[j, i], name=f"abs_const1_{j}_{i}")
                model.addConstr(-x[j, i] + data[j, i] <= abs_vars[j, i], name=f"abs_const2_{j}_{i}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    ''' for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}") '''

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
    x_values = np.array(x_values)
    
    lam_values = [lam[i].x for i in range(m)]
    lam_values = np.array(lam_values)

    if model.Status == GRB.OPTIMAL:
        print("Gurobi optimization status:", model.status)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print("Gurobi optimization status:", model.status)
        model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,lam_values,x_values]

# %%
## record representability of all instances
all_mdm_rep_indep = []
all_mdm_rep_time_indep = []

## record the limit loss of all instances
all_mdm_limit_loss_indep = []
all_mdm_limit_prob_indep = []
all_mdm_limit_runtime_indep = []

all_mdm_limit_lam_indep = []


for i in range(len(pred_offer_times_list)):

    ## define container for mdm representability check
    mdm_rep_collection_indep =[]
    mdm_rep_runtime_collection_indep =[]
    
    ## define container for mdm limit 
    mdm_limit_loss_collection_indep =[]
    mdm_limit_runtime_collection_indep =[]
    mdm_limit_probability_collection_indep =[]
    mdm_limit_lam_collection_indep = []
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        ####### mdm representability check ##########
        
        row_data = row_assortment_data(all_full_instances_indep[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonnegative_descending(row_data)
        ## representability check of MDM
        curr_rep_result_indep = mdm_feasibility(all_full_instances_indep[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection_indep.append(curr_rep_result_indep[0])
        mdm_rep_runtime_collection_indep.append(curr_rep_result_indep[1])
        
        # check if representable
        if curr_rep_result_indep[0] > 0:
            mdm_limit_loss_collection_indep.append(0)
            mdm_limit_runtime_collection_indep.append(curr_rep_result_indep[1])
            mdm_limit_probability_collection_indep.append(all_full_instances_indep[i][j])
        else:
            # not representable # limit and prediction
            #mdm_limit(data,collection,perm_collection,produts_notin_collection)
            curr_limit_result_indep = mdm_limit(all_full_instances_indep[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            curr_limit_prob = curr_limit_result_indep[-1]
            mdm_limit_probability_collection_indep.append(curr_limit_prob)
            mdm_limit_loss_collection_indep.append(curr_limit_result_indep[0])
            mdm_limit_runtime_collection_indep.append(curr_limit_result_indep[1])
            mdm_limit_lam_collection_indep.append(curr_limit_result_indep[2])
        print('the limit loss is', mdm_limit_loss_collection_indep[-1])
        print('the runtime is', mdm_limit_runtime_collection_indep[-1])   
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep_indep.append(mdm_rep_collection_indep)
    all_mdm_rep_time_indep.append(mdm_rep_runtime_collection_indep)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss_indep.append(mdm_limit_loss_collection_indep)
    all_mdm_limit_runtime_indep.append(mdm_limit_runtime_collection_indep)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob_indep.append(mdm_limit_probability_collection_indep)
    
    all_mdm_limit_lam_indep.append(mdm_limit_lam_collection_indep)
# Out:
# testing instance with offertimes 20 : 0th
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# Gurobi optimization status: 2
# the limit loss is 0.23803718000000054
# the runtime is 0.24168014526367188
# testing instance with offertimes 20 : 1th
# Gurobi optimization status: 2
# the limit loss is 0.005697869999999929
# the runtime is 0.19816303253173828
# testing instance with offertimes 20 : 2th
# Gurobi optimization status: 2
# the limit loss is 0.3826081400000011
# the runtime is 0.2364640235900879
# testing instance with offertimes 20 : 3th
# Gurobi optimization status: 2
# the limit loss is 0.08229073999999954
# the runtime is 0.26821112632751465
# testing instance with offertimes 20 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.14058162000000518
# the runtime is 0.47646403312683105
# testing instance with offertimes 20 : 5th
# Gurobi optimization status: 2
# the limit loss is 3.564149669999998
# the runtime is 0.6326980590820312
# testing instance with offertimes 20 : 6th
# Gurobi optimization status: 2
# the limit loss is 1.9460403599999971
# the runtime is 0.6816699504852295
# testing instance with offertimes 20 : 7th
# the limit loss is 0
# the runtime is 0.0002391338348388672
# testing instance with offertimes 20 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.592311130000002
# the runtime is 0.8258600234985352
# testing instance with offertimes 20 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.33043059999999946
# the runtime is 0.25954484939575195
# testing instance with offertimes 20 : 10th
# the limit loss is 0
# the runtime is 0.0001709461212158203
# testing instance with offertimes 20 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.20581227999999852
# the runtime is 0.2174680233001709
# testing instance with offertimes 20 : 12th
# Gurobi optimization status: 2
# the limit loss is 1.2909672000000059
# the runtime is 0.3328280448913574
# testing instance with offertimes 20 : 13th
# Gurobi optimization status: 2
# the limit loss is 0.13870478000000172
# the runtime is 0.2411060333251953
# testing instance with offertimes 20 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.015451269999999705
# the runtime is 0.6052231788635254
# testing instance with offertimes 20 : 15th
# Gurobi optimization status: 2
# the limit loss is 0.06451256999999987
# the runtime is 0.3025369644165039
# testing instance with offertimes 20 : 16th
# Gurobi optimization status: 2
# the limit loss is 0.0592894999999997
# the runtime is 0.3694570064544678
# testing instance with offertimes 20 : 17th
# Gurobi optimization status: 2
# the limit loss is 0.3761256500000002
# the runtime is 0.27104997634887695
# testing instance with offertimes 20 : 18th
# Gurobi optimization status: 2
# the limit loss is 0.09700149000000119
# the runtime is 0.18291807174682617
# testing instance with offertimes 20 : 19th
# Gurobi optimization status: 2
# the limit loss is 0.01250295999999955
# the runtime is 0.24762988090515137
# testing instance with offertimes 20 : 20th
# Gurobi optimization status: 2
# the limit loss is 4.035228680000004
# the runtime is 0.6662278175354004
# testing instance with offertimes 20 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.46339885000000003
# the runtime is 0.1855480670928955
# testing instance with offertimes 20 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.11528585999999981
# the runtime is 0.7871420383453369
# testing instance with offertimes 20 : 23th
# the limit loss is 0
# the runtime is 0.0002429485321044922
# testing instance with offertimes 20 : 24th
# Gurobi optimization status: 2
# the limit loss is 0.5807214600000048
# the runtime is 0.3551170825958252
# testing instance with offertimes 20 : 25th
# Gurobi optimization status: 2
# the limit loss is 0.30391555999999853
# the runtime is 0.3428938388824463
# testing instance with offertimes 20 : 26th
# Gurobi optimization status: 2
# the limit loss is 0.6762800799999994
# the runtime is 0.28715085983276367
# testing instance with offertimes 20 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.07442020000000049
# the runtime is 0.2196509838104248
# testing instance with offertimes 20 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.4700804899999965
# the runtime is 0.50856614112854
# testing instance with offertimes 20 : 29th
# Gurobi optimization status: 2
# the limit loss is 0.6022892999999996
# the runtime is 0.28154993057250977
# testing instance with offertimes 20 : 30th
# Gurobi optimization status: 2
# the limit loss is 0.055989629999999915
# the runtime is 0.19749999046325684
# testing instance with offertimes 20 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.5661798299999968
# the runtime is 0.31031084060668945
# testing instance with offertimes 20 : 32th
# Gurobi optimization status: 2
# the limit loss is 0.11558505000000027
# the runtime is 0.1979842185974121
# testing instance with offertimes 20 : 33th
# Gurobi optimization status: 2
# the limit loss is 0.5557518599999984
# the runtime is 0.23850798606872559
# testing instance with offertimes 20 : 34th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.11372590065002441
# testing instance with offertimes 20 : 35th
# Gurobi optimization status: 2
# the limit loss is 0.4464416500000007
# the runtime is 0.22855615615844727
# testing instance with offertimes 20 : 36th
# Gurobi optimization status: 2
# the limit loss is 0.21936537999999933
# the runtime is 1.0565459728240967
# testing instance with offertimes 20 : 37th
# Gurobi optimization status: 2
# the limit loss is 0.8754122499999997
# the runtime is 0.3973212242126465
# testing instance with offertimes 20 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.6897164199999992
# the runtime is 0.3512248992919922
# testing instance with offertimes 20 : 39th
# Gurobi optimization status: 2
# the limit loss is 0.410894109999998
# the runtime is 0.2424929141998291
# testing instance with offertimes 20 : 40th
# Gurobi optimization status: 2
# the limit loss is 1.105529710000001
# the runtime is 0.6013190746307373
# testing instance with offertimes 20 : 41th
# Gurobi optimization status: 2
# the limit loss is 0.11567578999999846
# the runtime is 0.2587921619415283
# testing instance with offertimes 20 : 42th
# Gurobi optimization status: 2
# the limit loss is 0.3959802599999991
# the runtime is 0.20784902572631836
# testing instance with offertimes 20 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.8018888000000032
# the runtime is 0.2700011730194092
# testing instance with offertimes 20 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.7804708200000009
# the runtime is 0.2950620651245117
# testing instance with offertimes 20 : 45th
# Gurobi optimization status: 2
# the limit loss is 1.6593026800000101
# the runtime is 0.5504679679870605
# testing instance with offertimes 20 : 46th
# Gurobi optimization status: 2
# the limit loss is 0.15067071999999904
# the runtime is 0.25737595558166504
# testing instance with offertimes 20 : 47th
# Gurobi optimization status: 2
# the limit loss is 0.3060493199999971
# the runtime is 0.32318902015686035
# testing instance with offertimes 20 : 48th
# Gurobi optimization status: 2
# the limit loss is 2.9227897799999996
# the runtime is 1.9228789806365967
# testing instance with offertimes 20 : 49th
# Gurobi optimization status: 2
# the limit loss is 0.04093268000000039
# the runtime is 0.321591854095459
# testing instance with offertimes 20 : 50th
# Gurobi optimization status: 2
# the limit loss is 0.2571313500000001
# the runtime is 0.21315217018127441
# testing instance with offertimes 20 : 51th
# Gurobi optimization status: 2
# the limit loss is 0.4685322300000004
# the runtime is 0.4320869445800781
# testing instance with offertimes 20 : 52th
# Gurobi optimization status: 2
# the limit loss is 0.05329253000000035
# the runtime is 0.21746110916137695
# testing instance with offertimes 20 : 53th
# Gurobi optimization status: 2
# the limit loss is 0.9369221999999989
# the runtime is 0.4966559410095215
# testing instance with offertimes 20 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.17562005999999933
# the runtime is 0.2338390350341797
# testing instance with offertimes 20 : 55th
# Gurobi optimization status: 2
# the limit loss is 0.20964985000000103
# the runtime is 0.31620287895202637
# testing instance with offertimes 20 : 56th
# Gurobi optimization status: 2
# the limit loss is 0.39385577999999777
# the runtime is 0.3518259525299072
# testing instance with offertimes 20 : 57th
# Gurobi optimization status: 2
# the limit loss is 1.1255356600000006
# the runtime is 0.5896639823913574
# testing instance with offertimes 20 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.520589199999998
# the runtime is 0.27945995330810547
# testing instance with offertimes 20 : 59th
# Gurobi optimization status: 2
# the limit loss is 0.5151130499999994
# the runtime is 0.5941340923309326
# testing instance with offertimes 20 : 60th
# Gurobi optimization status: 2
# the limit loss is 0.16805006000000042
# the runtime is 0.2513260841369629
# testing instance with offertimes 20 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.8498726099999971
# the runtime is 0.6191699504852295
# testing instance with offertimes 20 : 62th
# Gurobi optimization status: 2
# the limit loss is 0.00652449999999977
# the runtime is 0.19169187545776367
# testing instance with offertimes 20 : 63th
# Gurobi optimization status: 2
# the limit loss is 2.1429513200000065
# the runtime is 0.7813141345977783
# testing instance with offertimes 20 : 64th
# Gurobi optimization status: 2
# the limit loss is 0.06666740999999805
# the runtime is 0.19448304176330566
# testing instance with offertimes 20 : 65th
# Gurobi optimization status: 2
# the limit loss is 0.05880011999999851
# the runtime is 0.27266693115234375
# testing instance with offertimes 20 : 66th
# Gurobi optimization status: 2
# the limit loss is 0.033796659999999305
# the runtime is 0.2981600761413574
# testing instance with offertimes 20 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.38060900000000336
# the runtime is 0.20773601531982422
# testing instance with offertimes 20 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.04286508999999935
# the runtime is 0.2028369903564453
# testing instance with offertimes 20 : 69th
# Gurobi optimization status: 2
# the limit loss is 0.6202927100000001
# the runtime is 0.607323169708252
# testing instance with offertimes 20 : 70th
# Gurobi optimization status: 2
# the limit loss is 1.27125698
# the runtime is 0.6047861576080322
# testing instance with offertimes 20 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.016716430000000795
# the runtime is 0.24851608276367188
# testing instance with offertimes 20 : 72th
# Gurobi optimization status: 2
# the limit loss is 0.02255208000000021
# the runtime is 0.23122715950012207
# testing instance with offertimes 20 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.11353421211242676
# testing instance with offertimes 20 : 74th
# Gurobi optimization status: 2
# the limit loss is 0.19946699999999903
# the runtime is 0.1811070442199707
# testing instance with offertimes 20 : 75th
# Gurobi optimization status: 2
# the limit loss is 2.906585910000002
# the runtime is 0.5804409980773926
# testing instance with offertimes 20 : 76th
# Gurobi optimization status: 2
# the limit loss is 0.5747558799999991
# the runtime is 0.2505152225494385
# testing instance with offertimes 20 : 77th
# Gurobi optimization status: 2
# the limit loss is 0.824802659999997
# the runtime is 0.2653050422668457
# testing instance with offertimes 20 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.511205899999995
# the runtime is 0.24033808708190918
# testing instance with offertimes 20 : 79th
# Gurobi optimization status: 2
# the limit loss is 0.5143307599999974
# the runtime is 0.9607949256896973
# testing instance with offertimes 20 : 80th
# Gurobi optimization status: 2
# the limit loss is 0.16226598000000536
# the runtime is 0.18916606903076172
# testing instance with offertimes 20 : 81th
# Gurobi optimization status: 2
# the limit loss is 0.24897044000000032
# the runtime is 0.24208402633666992
# testing instance with offertimes 20 : 82th
# Gurobi optimization status: 2
# the limit loss is 0.022566239999999786
# the runtime is 0.2432880401611328
# testing instance with offertimes 20 : 83th
# Gurobi optimization status: 2
# the limit loss is 0.7282249600000019
# the runtime is 0.9297099113464355
# testing instance with offertimes 20 : 84th
# Gurobi optimization status: 2
# the limit loss is 0.22491238999999877
# the runtime is 0.22063708305358887
# testing instance with offertimes 20 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.10758399963378906
# testing instance with offertimes 20 : 86th
# Gurobi optimization status: 2
# the limit loss is 2.0784418699999994
# the runtime is 0.5535979270935059
# testing instance with offertimes 20 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.8680798100000038
# the runtime is 0.4593210220336914
# testing instance with offertimes 20 : 88th
# Gurobi optimization status: 2
# the limit loss is 0.34806605999999957
# the runtime is 0.6211400032043457
# testing instance with offertimes 20 : 89th
# Gurobi optimization status: 2
# the limit loss is 0.07348717999999946
# the runtime is 0.19602108001708984
# testing instance with offertimes 20 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.28003817999999864
# the runtime is 0.27068495750427246
# testing instance with offertimes 20 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.8408438299999986
# the runtime is 0.3759181499481201
# testing instance with offertimes 20 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.9411111200000001
# the runtime is 0.26706600189208984
# testing instance with offertimes 20 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.15009431999999903
# the runtime is 0.24631404876708984
# testing instance with offertimes 20 : 94th
# Gurobi optimization status: 2
# the limit loss is 0.08433587999999817
# the runtime is 0.2617530822753906
# testing instance with offertimes 20 : 95th
# Gurobi optimization status: 2
# the limit loss is 0.14671455999999924
# the runtime is 0.1993091106414795
# testing instance with offertimes 20 : 96th
# Gurobi optimization status: 2
# the limit loss is 0.47315407999999964
# the runtime is 0.22669482231140137
# testing instance with offertimes 20 : 97th
# Gurobi optimization status: 2
# the limit loss is 1.913984879999999
# the runtime is 0.8034770488739014
# testing instance with offertimes 20 : 98th
# Gurobi optimization status: 2
# the limit loss is 0.02691039999999984
# the runtime is 0.23399877548217773
# testing instance with offertimes 20 : 99th
# Gurobi optimization status: 2
# the limit loss is 0.08154663999999898
# the runtime is 0.2385261058807373
# testing instance with offertimes 30 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.12476661999999977
# the runtime is 0.16277408599853516
# testing instance with offertimes 30 : 1th
# Gurobi optimization status: 2
# the limit loss is 0.0010853699999986755
# the runtime is 0.10474801063537598
# testing instance with offertimes 30 : 2th
# Gurobi optimization status: 2
# the limit loss is 0.3303165399999997
# the runtime is 0.13180208206176758
# testing instance with offertimes 30 : 3th
# Gurobi optimization status: 2
# the limit loss is 0.06331712000000064
# the runtime is 0.19985198974609375
# testing instance with offertimes 30 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.003831840000000397
# the runtime is 0.22452282905578613
# testing instance with offertimes 30 : 5th
# Gurobi optimization status: 2
# the limit loss is 3.305471749999998
# the runtime is 0.40136098861694336
# testing instance with offertimes 30 : 6th
# Gurobi optimization status: 2
# the limit loss is 1.8956186999999975
# the runtime is 0.4322829246520996
# testing instance with offertimes 30 : 7th
# the limit loss is 0
# the runtime is 0.00033593177795410156
# testing instance with offertimes 30 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.486414170000001
# the runtime is 0.29552698135375977
# testing instance with offertimes 30 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.33043059999999946
# the runtime is 0.15891599655151367
# testing instance with offertimes 30 : 10th
# the limit loss is 0
# the runtime is 0.0002970695495605469
# testing instance with offertimes 30 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.20581227999999852
# the runtime is 0.12848997116088867
# testing instance with offertimes 30 : 12th
# Gurobi optimization status: 2
# the limit loss is 0.037390980000005826
# the runtime is 0.14297199249267578
# testing instance with offertimes 30 : 13th
# Gurobi optimization status: 2
# the limit loss is 0.0569441900000007
# the runtime is 0.11822700500488281
# testing instance with offertimes 30 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.007816570000000541
# the runtime is 0.2216639518737793
# testing instance with offertimes 30 : 15th
# Gurobi optimization status: 2
# the limit loss is 0.06451256999999641
# the runtime is 0.17609405517578125
# testing instance with offertimes 30 : 16th
# Gurobi optimization status: 2
# the limit loss is 0.049336019999999675
# the runtime is 0.21286392211914062
# testing instance with offertimes 30 : 17th
# Gurobi optimization status: 2
# the limit loss is 0.3751996500000016
# the runtime is 0.12854504585266113
# testing instance with offertimes 30 : 18th
# Gurobi optimization status: 2
# the limit loss is 0.06807393000000027
# the runtime is 0.14192509651184082
# testing instance with offertimes 30 : 19th
# Gurobi optimization status: 2
# the limit loss is 0.012495999999999551
# the runtime is 0.13971805572509766
# testing instance with offertimes 30 : 20th
# Gurobi optimization status: 2
# the limit loss is 2.806184060000002
# the runtime is 0.23448514938354492
# testing instance with offertimes 30 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.423945570000003
# the runtime is 0.15077900886535645
# testing instance with offertimes 30 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.10822421999999998
# the runtime is 0.6980860233306885
# testing instance with offertimes 30 : 23th
# the limit loss is 0
# the runtime is 0.00042700767517089844
# testing instance with offertimes 30 : 24th
# Gurobi optimization status: 2
# the limit loss is 0.5649361800000048
# the runtime is 0.1673450469970703
# testing instance with offertimes 30 : 25th
# Gurobi optimization status: 2
# the limit loss is 0.2769870999999989
# the runtime is 0.16668105125427246
# testing instance with offertimes 30 : 26th
# Gurobi optimization status: 2
# the limit loss is 0.45415528000000016
# the runtime is 0.14825201034545898
# testing instance with offertimes 30 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.06467904000000073
# the runtime is 0.11015796661376953
# testing instance with offertimes 30 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.3586940899999946
# the runtime is 0.15359783172607422
# testing instance with offertimes 30 : 29th
# Gurobi optimization status: 2
# the limit loss is 0.4415211399999998
# the runtime is 0.16400504112243652
# testing instance with offertimes 30 : 30th
# Gurobi optimization status: 2
# the limit loss is 0.03746580999999934
# the runtime is 0.11581897735595703
# testing instance with offertimes 30 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.33931666999999965
# the runtime is 0.11070799827575684
# testing instance with offertimes 30 : 32th
# Gurobi optimization status: 2
# the limit loss is 0.11558505000000027
# the runtime is 0.11825704574584961
# testing instance with offertimes 30 : 33th
# Gurobi optimization status: 2
# the limit loss is 0.06628493999999953
# the runtime is 0.11470603942871094
# testing instance with offertimes 30 : 34th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.060508012771606445
# testing instance with offertimes 30 : 35th
# Gurobi optimization status: 2
# the limit loss is 0.39357765000000045
# the runtime is 0.13423418998718262
# testing instance with offertimes 30 : 36th
# Gurobi optimization status: 2
# the limit loss is 0.18382973999999921
# the runtime is 0.31145405769348145
# testing instance with offertimes 30 : 37th
# Gurobi optimization status: 2
# the limit loss is 0.6332891000000025
# the runtime is 0.21145391464233398
# testing instance with offertimes 30 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.5173739999999987
# the runtime is 0.1046910285949707
# testing instance with offertimes 30 : 39th
# Gurobi optimization status: 2
# the limit loss is 0.26554359999999766
# the runtime is 0.12262892723083496
# testing instance with offertimes 30 : 40th
# Gurobi optimization status: 2
# the limit loss is 1.066471600000002
# the runtime is 0.2571070194244385
# testing instance with offertimes 30 : 41th
# Gurobi optimization status: 2
# the limit loss is 0.10982436999999898
# the runtime is 0.12081694602966309
# testing instance with offertimes 30 : 42th
# Gurobi optimization status: 2
# the limit loss is 0.03178199999999993
# the runtime is 0.1376490592956543
# testing instance with offertimes 30 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.21864212999999988
# the runtime is 0.13899707794189453
# testing instance with offertimes 30 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.7804708200000009
# the runtime is 0.17101192474365234
# testing instance with offertimes 30 : 45th
# Gurobi optimization status: 2
# the limit loss is 1.5723691200000003
# the runtime is 0.1951439380645752
# testing instance with offertimes 30 : 46th
# Gurobi optimization status: 2
# the limit loss is 0.1329356799999994
# the runtime is 0.10632586479187012
# testing instance with offertimes 30 : 47th
# Gurobi optimization status: 2
# the limit loss is 0.2404037399999993
# the runtime is 0.11395096778869629
# testing instance with offertimes 30 : 48th
# Gurobi optimization status: 2
# the limit loss is 2.7511885800000013
# the runtime is 1.3838179111480713
# testing instance with offertimes 30 : 49th
# Gurobi optimization status: 2
# the limit loss is 0.04093268000000039
# the runtime is 0.11325693130493164
# testing instance with offertimes 30 : 50th
# Gurobi optimization status: 2
# the limit loss is 0.25713134999999954
# the runtime is 0.1527700424194336
# testing instance with offertimes 30 : 51th
# Gurobi optimization status: 2
# the limit loss is 0.01442160000000015
# the runtime is 0.09938693046569824
# testing instance with offertimes 30 : 52th
# Gurobi optimization status: 2
# the limit loss is 0.012945780000000687
# the runtime is 0.10254597663879395
# testing instance with offertimes 30 : 53th
# Gurobi optimization status: 2
# the limit loss is 0.3754604400000017
# the runtime is 0.1738719940185547
# testing instance with offertimes 30 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.13067826999999774
# the runtime is 0.15447497367858887
# testing instance with offertimes 30 : 55th
# Gurobi optimization status: 2
# the limit loss is 0.209649850000001
# the runtime is 0.16982817649841309
# testing instance with offertimes 30 : 56th
# Gurobi optimization status: 2
# the limit loss is 0.2990630799999968
# the runtime is 0.16536307334899902
# testing instance with offertimes 30 : 57th
# Gurobi optimization status: 2
# the limit loss is 0.9432559700000007
# the runtime is 0.29093503952026367
# testing instance with offertimes 30 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.520589199999998
# the runtime is 0.15140199661254883
# testing instance with offertimes 30 : 59th
# Gurobi optimization status: 2
# the limit loss is 0.05736752999999978
# the runtime is 0.1562180519104004
# testing instance with offertimes 30 : 60th
# the limit loss is 0
# the runtime is 0.0003070831298828125
# testing instance with offertimes 30 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.5691545600000016
# the runtime is 0.18465900421142578
# testing instance with offertimes 30 : 62th
# Gurobi optimization status: 2
# the limit loss is 2.1635297619882903e-05
# the runtime is 0.09947705268859863
# testing instance with offertimes 30 : 63th
# Gurobi optimization status: 2
# the limit loss is 2.11897406
# the runtime is 0.46481990814208984
# testing instance with offertimes 30 : 64th
# Gurobi optimization status: 2
# the limit loss is 0.06666740999999805
# the runtime is 0.14875388145446777
# testing instance with offertimes 30 : 65th
# Gurobi optimization status: 2
# the limit loss is 0.05758199999999917
# the runtime is 0.16333413124084473
# testing instance with offertimes 30 : 66th
# Gurobi optimization status: 2
# the limit loss is 0.029200360000000147
# the runtime is 0.15055608749389648
# testing instance with offertimes 30 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.38060900000000336
# the runtime is 0.17451810836791992
# testing instance with offertimes 30 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.03524025999999935
# the runtime is 0.16224193572998047
# testing instance with offertimes 30 : 69th
# Gurobi optimization status: 2
# the limit loss is 0.556852119999998
# the runtime is 0.21921706199645996
# testing instance with offertimes 30 : 70th
# Gurobi optimization status: 2
# the limit loss is 1.2046853099999997
# the runtime is 0.24510407447814941
# testing instance with offertimes 30 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.0012972299999998572
# the runtime is 0.1167290210723877
# testing instance with offertimes 30 : 72th
# Gurobi optimization status: 2
# the limit loss is 0.015118399999999994
# the runtime is 0.11329293251037598
# testing instance with offertimes 30 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.07364892959594727
# testing instance with offertimes 30 : 74th
# the limit loss is 0
# the runtime is 0.0003139972686767578
# testing instance with offertimes 30 : 75th
# Gurobi optimization status: 2
# the limit loss is 2.5203570300000013
# the runtime is 0.2299799919128418
# testing instance with offertimes 30 : 76th
# Gurobi optimization status: 2
# the limit loss is 0.5666453799999985
# the runtime is 0.23764300346374512
# testing instance with offertimes 30 : 77th
# Gurobi optimization status: 2
# the limit loss is 0.692329059999997
# the runtime is 0.1400761604309082
# testing instance with offertimes 30 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.49053353999999905
# the runtime is 0.13694381713867188
# testing instance with offertimes 30 : 79th
# Gurobi optimization status: 2
# the limit loss is 0.4505049999999993
# the runtime is 0.25330185890197754
# testing instance with offertimes 30 : 80th
# Gurobi optimization status: 2
# the limit loss is 0.16184232000000534
# the runtime is 0.1106259822845459
# testing instance with offertimes 30 : 81th
# Gurobi optimization status: 2
# the limit loss is 0.18601811000000038
# the runtime is 0.11174607276916504
# testing instance with offertimes 30 : 82th
# Gurobi optimization status: 2
# the limit loss is 0.004444239999999376
# the runtime is 0.08840703964233398
# testing instance with offertimes 30 : 83th
# Gurobi optimization status: 2
# the limit loss is 0.5161810600000015
# the runtime is 0.20760607719421387
# testing instance with offertimes 30 : 84th
# Gurobi optimization status: 2
# the limit loss is 0.047084449999998564
# the runtime is 0.09674692153930664
# testing instance with offertimes 30 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.06389689445495605
# testing instance with offertimes 30 : 86th
# Gurobi optimization status: 2
# the limit loss is 1.6474767900000011
# the runtime is 0.13154196739196777
# testing instance with offertimes 30 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.8280481700000069
# the runtime is 0.37955689430236816
# testing instance with offertimes 30 : 88th
# Gurobi optimization status: 2
# the limit loss is 0.0022780000000001675
# the runtime is 0.14843988418579102
# testing instance with offertimes 30 : 89th
# Gurobi optimization status: 2
# the limit loss is 0.004715519999999697
# the runtime is 0.09876108169555664
# testing instance with offertimes 30 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.2800381799999973
# the runtime is 0.11998796463012695
# testing instance with offertimes 30 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.7063863599999984
# the runtime is 0.16737103462219238
# testing instance with offertimes 30 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.5457863999999992
# the runtime is 0.1244969367980957
# testing instance with offertimes 30 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.14786327999999913
# the runtime is 0.25691986083984375
# testing instance with offertimes 30 : 94th
# Gurobi optimization status: 2
# the limit loss is 0.0745802000000002
# the runtime is 0.1484389305114746
# testing instance with offertimes 30 : 95th
# Gurobi optimization status: 2
# the limit loss is 0.0041932799999997074
# the runtime is 0.12336111068725586
# testing instance with offertimes 30 : 96th
# Gurobi optimization status: 2
# the limit loss is 0.20562335999999967
# the runtime is 0.1467599868774414
# testing instance with offertimes 30 : 97th
# Gurobi optimization status: 2
# the limit loss is 1.604491159999998
# the runtime is 0.25989603996276855
# testing instance with offertimes 30 : 98th
# Gurobi optimization status: 2
# the limit loss is 0.009838800000000028
# the runtime is 0.13247895240783691
# testing instance with offertimes 30 : 99th
# Gurobi optimization status: 2
# the limit loss is 0.08024092000000058
# the runtime is 0.15239405632019043
# testing instance with offertimes 40 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.0953986200000002
# the runtime is 0.06566405296325684
# testing instance with offertimes 40 : 1th
# the limit loss is 0
# the runtime is 0.00028705596923828125
# testing instance with offertimes 40 : 2th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03589797019958496
# testing instance with offertimes 40 : 3th
# the limit loss is 0
# the runtime is 0.00038909912109375
# testing instance with offertimes 40 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.002377590000000398
# the runtime is 0.07926392555236816
# testing instance with offertimes 40 : 5th
# Gurobi optimization status: 2
# the limit loss is 3.29580583
# the runtime is 0.14269185066223145
# testing instance with offertimes 40 : 6th
# Gurobi optimization status: 2
# the limit loss is 0.49020281999999904
# the runtime is 0.08439993858337402
# testing instance with offertimes 40 : 7th
# the limit loss is 0
# the runtime is 0.0002980232238769531
# testing instance with offertimes 40 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.0850607999999991
# the runtime is 0.06644392013549805
# testing instance with offertimes 40 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.3304305999999995
# the runtime is 0.08308911323547363
# testing instance with offertimes 40 : 10th
# the limit loss is 0
# the runtime is 0.0002949237823486328
# testing instance with offertimes 40 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.03646603999999862
# the runtime is 0.0637052059173584
# testing instance with offertimes 40 : 12th
# Gurobi optimization status: 2
# the limit loss is 0.03400403000000435
# the runtime is 0.07909893989562988
# testing instance with offertimes 40 : 13th
# Gurobi optimization status: 2
# the limit loss is 0.055206440000000086
# the runtime is 0.0574190616607666
# testing instance with offertimes 40 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.00684393000000039
# the runtime is 0.07368302345275879
# testing instance with offertimes 40 : 15th
# Gurobi optimization status: 2
# the limit loss is 0.035414399999997064
# the runtime is 0.058673858642578125
# testing instance with offertimes 40 : 16th
# Gurobi optimization status: 2
# the limit loss is 0.049336019999999745
# the runtime is 0.09382915496826172
# testing instance with offertimes 40 : 17th
# the limit loss is 0
# the runtime is 0.0002961158752441406
# testing instance with offertimes 40 : 18th
# Gurobi optimization status: 2
# the limit loss is 0.0013666499999998658
# the runtime is 0.05218005180358887
# testing instance with offertimes 40 : 19th
# Gurobi optimization status: 2
# the limit loss is 0.0029200000000928206
# the runtime is 0.06604504585266113
# testing instance with offertimes 40 : 20th
# Gurobi optimization status: 2
# the limit loss is 2.769375260000002
# the runtime is 0.16751599311828613
# testing instance with offertimes 40 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.2220929399999997
# the runtime is 0.06616902351379395
# testing instance with offertimes 40 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.08201321999999991
# the runtime is 0.08762907981872559
# testing instance with offertimes 40 : 23th
# the limit loss is 0
# the runtime is 0.00030303001403808594
# testing instance with offertimes 40 : 24th
# Gurobi optimization status: 2
# the limit loss is 0.40779282000000217
# the runtime is 0.0899820327758789
# testing instance with offertimes 40 : 25th
# Gurobi optimization status: 2
# the limit loss is 0.1806791999999987
# the runtime is 0.0720670223236084
# testing instance with offertimes 40 : 26th
# Gurobi optimization status: 2
# the limit loss is 0.14119200000000032
# the runtime is 0.05244898796081543
# testing instance with offertimes 40 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.06467904000000073
# the runtime is 0.07013988494873047
# testing instance with offertimes 40 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.2757020899999967
# the runtime is 0.07651400566101074
# testing instance with offertimes 40 : 29th
# Gurobi optimization status: 2
# the limit loss is 0.09284328000000061
# the runtime is 0.0676109790802002
# testing instance with offertimes 40 : 30th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03308606147766113
# testing instance with offertimes 40 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.2829709999999987
# the runtime is 0.05498194694519043
# testing instance with offertimes 40 : 32th
# Gurobi optimization status: 2
# the limit loss is 0.007686899999999702
# the runtime is 0.05561399459838867
# testing instance with offertimes 40 : 33th
# Gurobi optimization status: 2
# the limit loss is 0.024728219999999773
# the runtime is 0.05316805839538574
# testing instance with offertimes 40 : 34th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03475499153137207
# testing instance with offertimes 40 : 35th
# Gurobi optimization status: 2
# the limit loss is 0.025043200000000248
# the runtime is 0.05091500282287598
# testing instance with offertimes 40 : 36th
# Gurobi optimization status: 2
# the limit loss is 0.11949887999999984
# the runtime is 0.11423897743225098
# testing instance with offertimes 40 : 37th
# Gurobi optimization status: 2
# the limit loss is 0.03968909999999999
# the runtime is 0.07647490501403809
# testing instance with offertimes 40 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.517373999999997
# the runtime is 0.08885812759399414
# testing instance with offertimes 40 : 39th
# Gurobi optimization status: 2
# the limit loss is 0.26554359999999766
# the runtime is 0.06557416915893555
# testing instance with offertimes 40 : 40th
# Gurobi optimization status: 2
# the limit loss is 0.23033111999999994
# the runtime is 0.06175994873046875
# testing instance with offertimes 40 : 41th
# Gurobi optimization status: 2
# the limit loss is 0.07764356999999876
# the runtime is 0.06883120536804199
# testing instance with offertimes 40 : 42th
# the limit loss is 0
# the runtime is 0.0003600120544433594
# testing instance with offertimes 40 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.08019899999999694
# the runtime is 0.06315088272094727
# testing instance with offertimes 40 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.7804708200000036
# the runtime is 0.10116291046142578
# testing instance with offertimes 40 : 45th
# Gurobi optimization status: 2
# the limit loss is 1.3723391500000006
# the runtime is 0.07852602005004883
# testing instance with offertimes 40 : 46th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03389596939086914
# testing instance with offertimes 40 : 47th
# the limit loss is 0
# the runtime is 0.0003368854522705078
# testing instance with offertimes 40 : 48th
# Gurobi optimization status: 2
# the limit loss is 2.3759210800000012
# the runtime is 0.4421260356903076
# testing instance with offertimes 40 : 49th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.034863948822021484
# testing instance with offertimes 40 : 50th
# Gurobi optimization status: 2
# the limit loss is 0.15571919999999995
# the runtime is 0.05778789520263672
# testing instance with offertimes 40 : 51th
# Gurobi optimization status: 2
# the limit loss is 0.014421600000000333
# the runtime is 0.057153940200805664
# testing instance with offertimes 40 : 52th
# Gurobi optimization status: 2
# the limit loss is 0.012945780000000674
# the runtime is 0.05398917198181152
# testing instance with offertimes 40 : 53th
# Gurobi optimization status: 2
# the limit loss is 0.1349327600000014
# the runtime is 0.0916128158569336
# testing instance with offertimes 40 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.12137736999999967
# the runtime is 0.06385397911071777
# testing instance with offertimes 40 : 55th
# Gurobi optimization status: 2
# the limit loss is 0.07887294999999733
# the runtime is 0.08207988739013672
# testing instance with offertimes 40 : 56th
# Gurobi optimization status: 2
# the limit loss is 0.1035201200000006
# the runtime is 0.06923794746398926
# testing instance with offertimes 40 : 57th
# Gurobi optimization status: 2
# the limit loss is 0.07264001000000089
# the runtime is 0.12648510932922363
# testing instance with offertimes 40 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.38834799999999875
# the runtime is 0.07814192771911621
# testing instance with offertimes 40 : 59th
# Gurobi optimization status: 2
# the limit loss is 0.03368223999999982
# the runtime is 0.06955099105834961
# testing instance with offertimes 40 : 60th
# the limit loss is 0
# the runtime is 0.00029206275939941406
# testing instance with offertimes 40 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.12328601999999973
# the runtime is 0.06756186485290527
# testing instance with offertimes 40 : 62th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.029619932174682617
# testing instance with offertimes 40 : 63th
# Gurobi optimization status: 2
# the limit loss is 1.9382022199999995
# the runtime is 0.13025784492492676
# testing instance with offertimes 40 : 64th
# Gurobi optimization status: 2
# the limit loss is 0.007049069999999782
# the runtime is 0.055711984634399414
# testing instance with offertimes 40 : 65th
# Gurobi optimization status: 2
# the limit loss is 0.0540770399999992
# the runtime is 0.04983878135681152
# testing instance with offertimes 40 : 66th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.08435797691345215
# testing instance with offertimes 40 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.21226907000000653
# the runtime is 0.07560300827026367
# testing instance with offertimes 40 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.011154419999999362
# the runtime is 0.06545591354370117
# testing instance with offertimes 40 : 69th
# Gurobi optimization status: 2
# the limit loss is 0.2914413399999994
# the runtime is 0.08218193054199219
# testing instance with offertimes 40 : 70th
# Gurobi optimization status: 2
# the limit loss is 0.7982806400000003
# the runtime is 0.0643928050994873
# testing instance with offertimes 40 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.04068493843078613
# testing instance with offertimes 40 : 72th
# Gurobi optimization status: 2
# the limit loss is 0.008039999999999594
# the runtime is 0.053884029388427734
# testing instance with offertimes 40 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03574085235595703
# testing instance with offertimes 40 : 74th
# the limit loss is 0
# the runtime is 0.00033211708068847656
# testing instance with offertimes 40 : 75th
# Gurobi optimization status: 2
# the limit loss is 2.4694845300000017
# the runtime is 0.1022341251373291
# testing instance with offertimes 40 : 76th
# Gurobi optimization status: 2
# the limit loss is 0.5286620499999982
# the runtime is 0.06569600105285645
# testing instance with offertimes 40 : 77th
# Gurobi optimization status: 2
# the limit loss is 0.6442944999999967
# the runtime is 0.07570409774780273
# testing instance with offertimes 40 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.17552807999999923
# the runtime is 0.05384206771850586
# testing instance with offertimes 40 : 79th
# Gurobi optimization status: 2
# the limit loss is 0.15354008999999966
# the runtime is 0.09182906150817871
# testing instance with offertimes 40 : 80th
# Gurobi optimization status: 2
# the limit loss is 0.16184232000000534
# the runtime is 0.06053614616394043
# testing instance with offertimes 40 : 81th
# Gurobi optimization status: 2
# the limit loss is 0.13496777000000126
# the runtime is 0.07284402847290039
# testing instance with offertimes 40 : 82th
# Gurobi optimization status: 2
# the limit loss is 0.004444239999999376
# the runtime is 0.051542043685913086
# testing instance with offertimes 40 : 83th
# Gurobi optimization status: 2
# the limit loss is 0.38976366000000134
# the runtime is 0.07764291763305664
# testing instance with offertimes 40 : 84th
# Gurobi optimization status: 2
# the limit loss is 0.008716500000000007
# the runtime is 0.06616997718811035
# testing instance with offertimes 40 : 85th
# the limit loss is 0
# the runtime is 0.0003800392150878906
# testing instance with offertimes 40 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.6630997999999997
# the runtime is 0.06080007553100586
# testing instance with offertimes 40 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.4034613300000027
# the runtime is 0.06396102905273438
# testing instance with offertimes 40 : 88th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.037574052810668945
# testing instance with offertimes 40 : 89th
# the limit loss is 0
# the runtime is 0.0002930164337158203
# testing instance with offertimes 40 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.12098345999999988
# the runtime is 0.07859301567077637
# testing instance with offertimes 40 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.06581114999999682
# the runtime is 0.06452703475952148
# testing instance with offertimes 40 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.5457863999999992
# the runtime is 0.07107901573181152
# testing instance with offertimes 40 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03848910331726074
# testing instance with offertimes 40 : 94th
# Gurobi optimization status: 2
# the limit loss is 0.03250520000000022
# the runtime is 0.06671810150146484
# testing instance with offertimes 40 : 95th
# the limit loss is 0
# the runtime is 0.00029397010803222656
# testing instance with offertimes 40 : 96th
# the limit loss is 0
# the runtime is 0.00017595291137695312
# testing instance with offertimes 40 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.7140178799999972
# the runtime is 0.06703615188598633
# testing instance with offertimes 40 : 98th
# Gurobi optimization status: 2
# the limit loss is 0.009838799999999828
# the runtime is 0.0552220344543457
# testing instance with offertimes 40 : 99th
# Gurobi optimization status: 2
# the limit loss is 0.019959700000000795
# the runtime is 0.08719611167907715
# testing instance with offertimes 50 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.034678619999998765
# the runtime is 0.028483152389526367
# testing instance with offertimes 50 : 1th
# the limit loss is 0
# the runtime is 0.00028014183044433594
# testing instance with offertimes 50 : 2th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.015045166015625
# testing instance with offertimes 50 : 3th
# the limit loss is 0
# the runtime is 0.0001709461212158203
# testing instance with offertimes 50 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.002377590000000398
# the runtime is 0.031152009963989258
# testing instance with offertimes 50 : 5th
# Gurobi optimization status: 2
# the limit loss is 2.6863620499999943
# the runtime is 0.05544686317443848
# testing instance with offertimes 50 : 6th
# Gurobi optimization status: 2
# the limit loss is 0.4902028199999965
# the runtime is 0.03248286247253418
# testing instance with offertimes 50 : 7th
# the limit loss is 0
# the runtime is 0.00027108192443847656
# testing instance with offertimes 50 : 8th
# the limit loss is 0
# the runtime is 0.00010991096496582031
# testing instance with offertimes 50 : 9th
# the limit loss is 0
# the runtime is 0.00010514259338378906
# testing instance with offertimes 50 : 10th
# the limit loss is 0
# the runtime is 0.0001270771026611328
# testing instance with offertimes 50 : 11th
# the limit loss is 0
# the runtime is 0.00013113021850585938
# testing instance with offertimes 50 : 12th
# Gurobi optimization status: 2
# the limit loss is 0.00815121000000815
# the runtime is 0.04252481460571289
# testing instance with offertimes 50 : 13th
# the limit loss is 0
# the runtime is 0.00014710426330566406
# testing instance with offertimes 50 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.006322469999999805
# the runtime is 0.03169989585876465
# testing instance with offertimes 50 : 15th
# Gurobi optimization status: 2
# the limit loss is 0.035414399999997064
# the runtime is 0.02827000617980957
# testing instance with offertimes 50 : 16th
# Gurobi optimization status: 2
# the limit loss is 0.017077769999999846
# the runtime is 0.03364896774291992
# testing instance with offertimes 50 : 17th
# the limit loss is 0
# the runtime is 0.0002980232238769531
# testing instance with offertimes 50 : 18th
# the limit loss is 0
# the runtime is 0.0001361370086669922
# testing instance with offertimes 50 : 19th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.019537925720214844
# testing instance with offertimes 50 : 20th
# Gurobi optimization status: 2
# the limit loss is 1.3559196600000027
# the runtime is 0.03461194038391113
# testing instance with offertimes 50 : 21th
# the limit loss is 0
# the runtime is 0.00016880035400390625
# testing instance with offertimes 50 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.03710555999999997
# the runtime is 0.03875613212585449
# testing instance with offertimes 50 : 23th
# the limit loss is 0
# the runtime is 0.0002880096435546875
# testing instance with offertimes 50 : 24th
# Gurobi optimization status: 2
# the limit loss is 0.40779282000000444
# the runtime is 0.030109882354736328
# testing instance with offertimes 50 : 25th
# the limit loss is 0
# the runtime is 0.00015091896057128906
# testing instance with offertimes 50 : 26th
# the limit loss is 0
# the runtime is 0.00012803077697753906
# testing instance with offertimes 50 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.06467904000000073
# the runtime is 0.031195878982543945
# testing instance with offertimes 50 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.035781349999998484
# the runtime is 0.02980780601501465
# testing instance with offertimes 50 : 29th
# the limit loss is 0
# the runtime is 0.00013303756713867188
# testing instance with offertimes 50 : 30th
# the limit loss is 0
# the runtime is 0.00011301040649414062
# testing instance with offertimes 50 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.2551225999999982
# the runtime is 0.027987003326416016
# testing instance with offertimes 50 : 32th
# the limit loss is 0
# the runtime is 0.0002639293670654297
# testing instance with offertimes 50 : 33th
# the limit loss is 0
# the runtime is 0.00010895729064941406
# testing instance with offertimes 50 : 34th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.019418954849243164
# testing instance with offertimes 50 : 35th
# the limit loss is 0
# the runtime is 0.00012993812561035156
# testing instance with offertimes 50 : 36th
# Gurobi optimization status: 2
# the limit loss is 0.11949887999999964
# the runtime is 0.03603696823120117
# testing instance with offertimes 50 : 37th
# Gurobi optimization status: 2
# the limit loss is 0.03968909999999999
# the runtime is 0.028638124465942383
# testing instance with offertimes 50 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.5173739999999994
# the runtime is 0.03649401664733887
# testing instance with offertimes 50 : 39th
# the limit loss is 0
# the runtime is 0.00028896331787109375
# testing instance with offertimes 50 : 40th
# Gurobi optimization status: 2
# the limit loss is 0.02014020000000005
# the runtime is 0.031160831451416016
# testing instance with offertimes 50 : 41th
# Gurobi optimization status: 2
# the limit loss is 0.07764356999999983
# the runtime is 0.03827810287475586
# testing instance with offertimes 50 : 42th
# the limit loss is 0
# ...
# Gurobi optimization status: 2
# the limit loss is 0.24175535999999914
# the runtime is 0.03863787651062012
# testing instance with offertimes 50 : 70th
# Gurobi optimization status: 2
# the limit loss is 0.48275778000000036
# the runtime is 0.03149700164794922
# testing instance with offertimes 50 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.023602008819580078
# testing instance with offertimes 50 : 72th
# the limit loss is 0
# the runtime is 0.00013899803161621094
# testing instance with offertimes 50 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.018994808197021484
# testing instance with offertimes 50 : 74th
# the limit loss is 0
# the runtime is 0.000141143798828125
# testing instance with offertimes 50 : 75th
# Gurobi optimization status: 2
# the limit loss is 2.4694845300000017
# the runtime is 0.04067587852478027
# testing instance with offertimes 50 : 76th
# Gurobi optimization status: 2
# the limit loss is 0.5247004499999992
# the runtime is 0.03142809867858887
# testing instance with offertimes 50 : 77th
# Gurobi optimization status: 2
# the limit loss is 0.5697836999999976
# the runtime is 0.030799150466918945
# testing instance with offertimes 50 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.17552807999999923
# the runtime is 0.028152942657470703
# testing instance with offertimes 50 : 79th
# Gurobi optimization status: 2
# the limit loss is 0.08689176000000028
# the runtime is 0.039771080017089844
# testing instance with offertimes 50 : 80th
# Gurobi optimization status: 2
# the limit loss is 0.16184232000000534
# the runtime is 0.028975963592529297
# testing instance with offertimes 50 : 81th
# the limit loss is 0
# the runtime is 0.0001380443572998047
# testing instance with offertimes 50 : 82th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.015399932861328125
# testing instance with offertimes 50 : 83th
# Gurobi optimization status: 2
# the limit loss is 0.38376846000000137
# the runtime is 0.03311491012573242
# testing instance with offertimes 50 : 84th
# the limit loss is 0
# the runtime is 0.00030303001403808594
# testing instance with offertimes 50 : 85th
# the limit loss is 0
# the runtime is 0.00010395050048828125
# testing instance with offertimes 50 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.5375743999999997
# the runtime is 0.033677101135253906
# testing instance with offertimes 50 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.2780368800000027
# the runtime is 0.0325770378112793
# testing instance with offertimes 50 : 88th
# the limit loss is 0
# the runtime is 0.0002830028533935547
# testing instance with offertimes 50 : 89th
# the limit loss is 0
# the runtime is 0.0002720355987548828
# testing instance with offertimes 50 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.004391459999999517
# the runtime is 0.03843283653259277
# testing instance with offertimes 50 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.06581114999999682
# the runtime is 0.029805898666381836
# testing instance with offertimes 50 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.4116551999999999
# the runtime is 0.02924799919128418
# testing instance with offertimes 50 : 93th
# the limit loss is 0
# the runtime is 0.0001609325408935547
# testing instance with offertimes 50 : 94th
# the limit loss is 0
# the runtime is 0.000125885009765625
# testing instance with offertimes 50 : 95th
# the limit loss is 0
# the runtime is 0.00010204315185546875
# testing instance with offertimes 50 : 96th
# the limit loss is 0
# the runtime is 0.00013184547424316406
# testing instance with offertimes 50 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.24845507999999722
# the runtime is 0.03634500503540039
# testing instance with offertimes 50 : 98th
# the limit loss is 0
# the runtime is 0.00028586387634277344
# testing instance with offertimes 50 : 99th
# Gurobi optimization status: 2
# the limit loss is 0.019959700000000795
# the runtime is 0.0360867977142334
# testing instance with offertimes 60 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.034678619999998765
# the runtime is 0.017333984375
# testing instance with offertimes 60 : 1th
# the limit loss is 0
# the runtime is 0.00013899803161621094
# testing instance with offertimes 60 : 2th
# the limit loss is 0
# the runtime is 0.000102996826171875
# testing instance with offertimes 60 : 3th
# the limit loss is 0
# the runtime is 0.0001239776611328125
# testing instance with offertimes 60 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.002377590000000398
# the runtime is 0.01919078826904297
# testing instance with offertimes 60 : 5th
# Gurobi optimization status: 2
# the limit loss is 2.5804192399999994
# the runtime is 0.021680831909179688
# testing instance with offertimes 60 : 6th
# Gurobi optimization status: 2
# the limit loss is 0.49020281999999904
# the runtime is 0.023426055908203125
# testing instance with offertimes 60 : 7th
# the limit loss is 0
# the runtime is 0.00030112266540527344
# testing instance with offertimes 60 : 8th
# the limit loss is 0
# the runtime is 9.918212890625e-05
# testing instance with offertimes 60 : 9th
# the limit loss is 0
# the runtime is 9.083747863769531e-05
# testing instance with offertimes 60 : 10th
# the limit loss is 0
# the runtime is 9.489059448242188e-05
# testing instance with offertimes 60 : 11th
# the limit loss is 0
# the runtime is 0.00011396408081054688
# testing instance with offertimes 60 : 12th
# Gurobi optimization status: 2
# the limit loss is 0.007698560000009309
# the runtime is 0.02781391143798828
# testing instance with offertimes 60 : 13th
# the limit loss is 0
# the runtime is 0.00013399124145507812
# testing instance with offertimes 60 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.008672952651977539
# testing instance with offertimes 60 : 15th
# Gurobi optimization status: 2
# the limit loss is 0.035414399999997064
# the runtime is 0.016569852828979492
# testing instance with offertimes 60 : 16th
# the limit loss is 0
# the runtime is 0.00012803077697753906
# testing instance with offertimes 60 : 17th
# the limit loss is 0
# the runtime is 0.00012302398681640625
# testing instance with offertimes 60 : 18th
# the limit loss is 0
# the runtime is 0.00010895729064941406
# testing instance with offertimes 60 : 19th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007997989654541016
# testing instance with offertimes 60 : 20th
# the limit loss is 0
# the runtime is 0.0001609325408935547
# testing instance with offertimes 60 : 21th
# the limit loss is 0
# the runtime is 0.0001289844512939453
# testing instance with offertimes 60 : 22th
# the limit loss is 0
# the runtime is 0.00010180473327636719
# testing instance with offertimes 60 : 23th
# the limit loss is 0
# the runtime is 0.00010895729064941406
# testing instance with offertimes 60 : 24th
# the limit loss is 0
# the runtime is 8.606910705566406e-05
# testing instance with offertimes 60 : 25th
# the limit loss is 0
# the runtime is 0.00013208389282226562
# testing instance with offertimes 60 : 26th
# the limit loss is 0
# the runtime is 9.799003601074219e-05
# testing instance with offertimes 60 : 27th
# the limit loss is 0
# the runtime is 8.893013000488281e-05
# testing instance with offertimes 60 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.035781349999998484
# the runtime is 0.016332149505615234
# testing instance with offertimes 60 : 29th
# the limit loss is 0
# the runtime is 0.00013494491577148438
# testing instance with offertimes 60 : 30th
# the limit loss is 0
# the runtime is 0.00010514259338378906
# testing instance with offertimes 60 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.2551225999999982
# the runtime is 0.01923990249633789
# testing instance with offertimes 60 : 32th
# the limit loss is 0
# the runtime is 0.0001361370086669922
# testing instance with offertimes 60 : 33th
# the limit loss is 0
# the runtime is 9.894371032714844e-05
# testing instance with offertimes 60 : 34th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.008677005767822266
# testing instance with offertimes 60 : 35th
# the limit loss is 0
# the runtime is 0.00019216537475585938
# testing instance with offertimes 60 : 36th
# the limit loss is 0
# the runtime is 0.00011301040649414062
# testing instance with offertimes 60 : 37th
# the limit loss is 0
# the runtime is 0.00012683868408203125
# testing instance with offertimes 60 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.5173739999999987
# the runtime is 0.026051998138427734
# testing instance with offertimes 60 : 39th
# the limit loss is 0
# the runtime is 0.0002880096435546875
# testing instance with offertimes 60 : 40th
# Gurobi optimization status: 2
# the limit loss is 0.02014020000000005
# the runtime is 0.016509056091308594
# testing instance with offertimes 60 : 41th
# Gurobi optimization status: 2
# the limit loss is 0.07669154999999926
# the runtime is 0.01833796501159668
# testing instance with offertimes 60 : 42th
# the limit loss is 0
# the runtime is 0.0001289844512939453
# testing instance with offertimes 60 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.08019900000000063
# the runtime is 0.019279003143310547
# testing instance with offertimes 60 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.7326124200000026
# the runtime is 0.03410482406616211
# testing instance with offertimes 60 : 45th
# Gurobi optimization status: 2
# the limit loss is 1.0860478000000053
# the runtime is 0.0231778621673584
# testing instance with offertimes 60 : 46th
# the limit loss is 0
# the runtime is 0.00012803077697753906
# testing instance with offertimes 60 : 47th
# the limit loss is 0
# the runtime is 9.894371032714844e-05
# testing instance with offertimes 60 : 48th
# Gurobi optimization status: 2
# the limit loss is 1.2372318000000007
# the runtime is 0.043057918548583984
# testing instance with offertimes 60 : 49th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.011367082595825195
# testing instance with offertimes 60 : 50th
# the limit loss is 0
# the runtime is 0.00013113021850585938
# testing instance with offertimes 60 : 51th
# the limit loss is 0
# the runtime is 9.894371032714844e-05
# testing instance with offertimes 60 : 52th
# Gurobi optimization status: 2
# the limit loss is 0.006206580000000816
# the runtime is 0.015997886657714844
# testing instance with offertimes 60 : 53th
# Gurobi optimization status: 2
# the limit loss is 0.13320270000000015
# the runtime is 0.01827406883239746
# testing instance with offertimes 60 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007573843002319336
# testing instance with offertimes 60 : 55th
# the limit loss is 0
# the runtime is 0.00018405914306640625
# testing instance with offertimes 60 : 56th
# Gurobi optimization status: 2
# the limit loss is 0.05720191999999809
# the runtime is 0.018167972564697266
# testing instance with offertimes 60 : 57th
# Gurobi optimization status: 2
# the limit loss is 0.020698370000001964
# the runtime is 0.0225980281829834
# testing instance with offertimes 60 : 58th
# the limit loss is 0
# the runtime is 0.00022792816162109375
# testing instance with offertimes 60 : 59th
# Gurobi optimization status: 2
# the limit loss is 0.03368223999999982
# the runtime is 0.017046213150024414
# testing instance with offertimes 60 : 60th
# the limit loss is 0
# the runtime is 0.00016498565673828125
# testing instance with offertimes 60 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.037704420000000634
# the runtime is 0.01711297035217285
# testing instance with offertimes 60 : 62th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.008137941360473633
# testing instance with offertimes 60 : 63th
# Gurobi optimization status: 2
# the limit loss is 0.9841603199999986
# the runtime is 0.025330066680908203
# testing instance with offertimes 60 : 64th
# Gurobi optimization status: 2
# the limit loss is 0.007049069999999782
# the runtime is 0.017605066299438477
# testing instance with offertimes 60 : 65th
# Gurobi optimization status: 2
# the limit loss is 0.0540770399999992
# the runtime is 0.018301010131835938
# testing instance with offertimes 60 : 66th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007873058319091797
# testing instance with offertimes 60 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.014798270000006183
# the runtime is 0.028610944747924805
# testing instance with offertimes 60 : 68th
# the limit loss is 0
# the runtime is 0.00013709068298339844
# testing instance with offertimes 60 : 69th
# Gurobi optimization status: 2
# the limit loss is 0.17351567999999978
# the runtime is 0.022597074508666992
# testing instance with offertimes 60 : 70th
# Gurobi optimization status: 2
# the limit loss is 0.4827577799999992
# the runtime is 0.020930051803588867
# testing instance with offertimes 60 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.010879993438720703
# testing instance with offertimes 60 : 72th
# the limit loss is 0
# the runtime is 0.00014591217041015625
# testing instance with offertimes 60 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.008239030838012695
# testing instance with offertimes 60 : 74th
# the limit loss is 0
# the runtime is 0.00014209747314453125
# testing instance with offertimes 60 : 75th
# Gurobi optimization status: 2
# the limit loss is 2.4694845300000017
# the runtime is 0.022036075592041016
# testing instance with offertimes 60 : 76th
# Gurobi optimization status: 2
# the limit loss is 0.5247004499999992
# the runtime is 0.018033981323242188
# testing instance with offertimes 60 : 77th
# Gurobi optimization status: 2
# the limit loss is 0.40717181999999896
# the runtime is 0.016421794891357422
# testing instance with offertimes 60 : 78th
# the limit loss is 0
# the runtime is 0.00012683868408203125
# testing instance with offertimes 60 : 79th
# the limit loss is 0
# the runtime is 9.799003601074219e-05
# testing instance with offertimes 60 : 80th
# Gurobi optimization status: 2
# the limit loss is 0.16184232000000534
# the runtime is 0.015843868255615234
# testing instance with offertimes 60 : 81th
# the limit loss is 0
# the runtime is 0.0001881122589111328
# testing instance with offertimes 60 : 82th
# the limit loss is 0
# the runtime is 9.799003601074219e-05
# testing instance with offertimes 60 : 83th
# the limit loss is 0
# the runtime is 9.393692016601562e-05
# testing instance with offertimes 60 : 84th
# the limit loss is 0
# the runtime is 0.00010704994201660156
# testing instance with offertimes 60 : 85th
# the limit loss is 0
# the runtime is 0.00015282630920410156
# testing instance with offertimes 60 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.5375743999999997
# the runtime is 0.017499923706054688
# testing instance with offertimes 60 : 87th
# the limit loss is 0
# the runtime is 0.00024390220642089844
# testing instance with offertimes 60 : 88th
# the limit loss is 0
# the runtime is 0.00013303756713867188
# testing instance with offertimes 60 : 89th
# the limit loss is 0
# the runtime is 0.00011301040649414062
# testing instance with offertimes 60 : 90th
# the limit loss is 0
# the runtime is 9.799003601074219e-05
# testing instance with offertimes 60 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.06581114999999682
# the runtime is 0.018069028854370117
# testing instance with offertimes 60 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.4116551999999999
# the runtime is 0.01857781410217285
# testing instance with offertimes 60 : 93th
# the limit loss is 0
# the runtime is 0.00022101402282714844
# testing instance with offertimes 60 : 94th
# the limit loss is 0
# the runtime is 0.00018405914306640625
# testing instance with offertimes 60 : 95th
# the limit loss is 0
# the runtime is 0.00010585784912109375
# testing instance with offertimes 60 : 96th
# the limit loss is 0
# the runtime is 0.0001239776611328125
# testing instance with offertimes 60 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.24845507999999722
# the runtime is 0.019828081130981445
# testing instance with offertimes 60 : 98th
# the limit loss is 0
# the runtime is 0.00012803077697753906
# testing instance with offertimes 60 : 99th
# Gurobi optimization status: 2
# the limit loss is 0.0017996200000009992
# the runtime is 0.018435001373291016

# %%
## adding rep results for indep
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep_indep[i], 'mdm_rep_time':all_mdm_rep_time_indep[i]})
    df_mdm_rep.to_csv('indep/representability/'+str(pred_offer_times_list[i])+'.csv')

## adding limit results
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_loss':all_mdm_limit_loss_indep[i], 'mdm_limit_time':all_mdm_limit_runtime_indep[i]})
    df_mdm_loss.to_csv('indep/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
            df_limit_prob = pd.DataFrame(all_mdm_limit_prob_indep[i][j])
            df_limit_prob.to_csv('indep/limit/prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss_indep = []
for i in range(len(pred_offer_times_list)):
    avg_loss_collection_indep = []
    for j in range(pred_instance_size[i]):
        avg_loss_collection_indep.append(all_mdm_limit_loss_indep[i][j]/sum(all_full_offertimes[i]))
    all_avg_loss_indep.append(avg_loss_collection_indep)

avg_mdm_rep_indep = []
avg_mdm_rep_runtime_indep = []
avg_mdm_rep_runtime__se_indep = []

avg_total_limit_loss_indep = []
avg_toal_limit_loss_se_indep = []
avg_mdm_limit_runtime_indep = []

#avg_loss = []
avg_loss_se_indep = []
avg_limit_runtime_se_indep = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_rep_indep.append(np.mean(all_mdm_rep_indep[i]))
    avg_mdm_rep_runtime_indep.append(np.mean(all_mdm_rep_time_indep[i]))
    avg_mdm_rep_runtime__se_indep.append(np.std(all_mdm_rep_time_indep[i])/np.sqrt(len(all_mdm_rep_time_indep[i])))
    
    avg_total_limit_loss_indep.append(np.mean(all_mdm_limit_loss_indep[i]))
    avg_mdm_limit_runtime_indep.append(np.mean(all_mdm_limit_runtime_indep[i]))
    avg_toal_limit_loss_se_indep.append(np.std(all_mdm_limit_loss_indep[i])/np.sqrt(len(all_mdm_limit_loss_indep[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se_indep.append(np.std(all_avg_loss_indep[i])/np.sqrt(len(all_avg_loss_indep[i])))
    avg_limit_runtime_se_indep.append(np.std(all_mdm_limit_runtime_indep[i])/np.sqrt(len(all_mdm_limit_runtime_indep[i])))

avg_loss_indep = []
for i in range(len(avg_total_limit_loss_indep)):
    avg_loss_indep.append(avg_total_limit_loss_indep[i]/sum(all_full_offertimes[i]))

df_mdm_limit_indep = pd.DataFrame({'offertimes':pred_offer_times_list,
                                   'collection_size':full_collection_size,
                                   'indep_rep':avg_mdm_rep_indep,'indep_rep_runtime':avg_mdm_rep_runtime_indep,'indep_rep_runtime_se':avg_mdm_rep_runtime__se_indep,
                                   'indep_total_loss':avg_total_limit_loss_indep,'indep_total_loss_se':avg_toal_limit_loss_se_indep,
                                   'indep_avg_loss':avg_loss_indep,'indep_avg_loss_se':avg_loss_se_indep,
                                   'indep_limit_runtime':avg_mdm_limit_runtime_indep,'indep_limit_runtime_se':avg_limit_runtime_se_indep
                                   })
df_mdm_limit_indep.to_csv('indep/indep_limit_summary.csv')
df_mdm_limit_indep
# Out:
#    offertimes  collection_size  indep_rep  indep_rep_runtime  \
# 0          20               29       0.03           0.000337
# 1          30               24       0.05           0.000382
# 2          40               19       0.14           0.000335
# 3          50               15       0.39           0.000203
# 4          60               13       0.55           0.000157
#
#    indep_rep_runtime_se  indep_total_loss  indep_total_loss_se  \
# 0              0.000012          0.546409             0.074680
# 1              0.000006          0.420489             0.065269
# 2              0.000008          0.267636             0.058305
# 3              0.000008          0.175779             0.043782
# 4              0.000006          0.140255             0.041082
#
#    indep_avg_loss  indep_avg_loss_se  indep_limit_runtime  \
# 0        0.000071           0.000010             0.364822
# 1        0.000056           0.000009             0.176604
# 2        0.000036           0.000008             0.063629
# 3        0.000024           0.000006             0.020611
# 4        0.000020           0.000006             0.008363
#
#    indep_limit_runtime_se
# 0                0.026073
# 1                0.015508
# 2                0.004993
# 3                0.001989
# 4                0.001021
