# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import gurobipy as gp
from gurobipy import GRB
import itertools
from itertools import combinations
from itertools import permutations
from random import choice
import json
import copy
import scipy.stats as stats
from scipy.stats import gumbel_r

# %%
np.random.seed(1)

# %%
random.seed(1)

# %%
raw_jd_choice = pd.read_excel('data_processing/choices.xlsm')  
jd_offertimes = raw_jd_choice.groupby('clickset')['clicknum'].sum()[raw_jd_choice.clickset.unique()]
inc_prod_num = raw_jd_choice['clickset'].value_counts()[raw_jd_choice.clickset.unique()]
assortment_info_df = pd.DataFrame({'assortments':raw_jd_choice.clickset.unique(),'offer_times':jd_offertimes,'includ_prod_num':inc_prod_num})

# extended assortments with outside option 
# transfer to list
clickset = raw_jd_choice['clickset']
clickset_list = []
for cset in clickset:
    num_lst = json.loads(cset)
    #clickset_list.append(num_lst+[0])
    clickset_list.append([0]+num_lst)
raw_jd_choice['clickset'] = clickset_list

n = 9 # product size top 8 products and outside option
print('there are {} different products'.format(n))
jd_collection = []
for cset in clickset_list:
    if cset not in jd_collection:
        jd_collection.append(cset)
print('there are {} different assortments'.format(len(jd_collection)))
print('check offertimes',len(jd_offertimes))
# Out:
# there are 9 different products
# there are 134 different assortments
# check offertimes 134

# %%
def collection_distribution_hev(n,collection,price):
    # generate mean 
    ''' mu_0 = np.random.uniform(2,3)
    mu_1n = np.random.uniform(-3,-2,n-1) '''
    # generate deterministic utilities for products
    
    ''' rho = -0.5 # prices and utilities are posatively correlated
    price_mean = np.mean(price[1:]) 
    price_std = np.std(price[1:])
    
    z = np.zeros(len(price[1:]))
    for i in range(len(z)):
        z[i] = (price[1:][i] - price_mean)/price_std
        
    mu_1n = np.zeros(len(z))
    normal_rvs = np.random.randn(len(mu_1n))
    for i in range(len(mu_1n)):
        mu_1n[i] = rho*z[i] + np.sqrt(1-rho**2)*normal_rvs[i] 
    ## deterministic utility of the outside option is strictly greater than the utilities of the products
    mu_0 = np.max(mu_1n) + 1
    # np.random.uniform(-2,2,n-1)
    mu = np.hstack((mu_0,mu_1n)) '''
    
    
    
    ''' scale_0 = 10
    scale_1n = np.random.uniform(0.04,1,n-1)
    scales = np.hstack((scale_0,scale_1n)) '''
    
    mu = np.random.uniform(-2,2,n)
    scales = np.random.uniform(0.04,2,n)
    
    sample_size = 10000
    
    # generate comonotonic rvs
    utility_samples1 = []
    for _ in range(sample_size):
        uniform_rv = np.random.uniform(0,1)
        U = uniform_rv*np.ones(n)
        utility_samples1.append( mu - scales * np.log(-np.log(U)))
    utility_samples = np.array(utility_samples1)
    
    #utility_samples = np.array([gumbel_r.rvs(loc=mu, scale=scales) for _ in range(sample_size)])
    
    collection_distribution = np.zeros((n,len(collection)))
    for i in range(len(collection)):
        curr_assortment = collection[i]
        curr_population = [[] for _ in range(sample_size)] 

        for j in range(sample_size):
            for k in curr_assortment:
                curr_population[j].append(utility_samples[j][k])
                # each sub list records only the utilities of products in the current assortment
                
        frequency = [0]*len(curr_assortment)
        for j in range(sample_size):
            max_index = np.argmax(np.array(curr_population[j]))
            # product is chosen iff the utility of the product is max in the assortment
            frequency[max_index] = frequency[max_index] +1 
            # update the frequency of product to be chosen
            
        prob = np.array(frequency)/np.sum(frequency)
        for j in range(len(curr_assortment)):
            collection_distribution[curr_assortment[j]][i] = prob[j]
            
    return collection_distribution

# %%
pred_offer_times_list = [20,30,40,50,60]
pred_test_collection_size = [5,4,3,3,2]
pred_train_collection_size = [24,20,16,12,11]
pred_instance_size = [100,100,100,100,100]
price = np.array([0,1.041,0.456,0.391,1.657,1.174,0.474,0.67,1.522])

# %%
def filter_collection_offertimes(whole_collection,whole_offertimes,least_offetimes):
    
    collection = []
    offertimes = []
    assortment_index = []
    
    for i in range(len(whole_offertimes)):
        if whole_offertimes[i]>=least_offetimes:
            collection.append(whole_collection[i])
            offertimes.append(whole_offertimes[i])
            assortment_index.append(i)
            
    return collection,offertimes,assortment_index

# %%
all_full_collections = []
all_full_offertimes = []
all_full_assortment_index = []
full_collection_size = []
for i in range(len(pred_offer_times_list)):
    collection, offertimes, assortment_index = filter_collection_offertimes(jd_collection,jd_offertimes,pred_offer_times_list[i])
    all_full_collections.append(collection)
    all_full_offertimes.append(offertimes)
    all_full_assortment_index.append(assortment_index)
    full_collection_size.append(len(assortment_index))
    print("number of assortments with offertimes {} is {}".format(pred_offer_times_list[i], len(assortment_index)))
# Out:
# number of assortments with offertimes 20 is 29
# number of assortments with offertimes 30 is 24
# number of assortments with offertimes 40 is 19
# number of assortments with offertimes 50 is 15
# number of assortments with offertimes 60 is 13

# %%
def filter_probability(whole_choice_collection,assortment_index):
    
    choice_collection = np.zeros((whole_choice_collection.shape[0],len(assortment_index)))
    
    for i in range(len(assortment_index)):
        choice_collection[:,i] = whole_choice_collection[:,assortment_index[i]]
 
        
    return choice_collection

# %%
## generate 50 random full instances 
pred_full_instance_pos = []

for j in range(pred_instance_size[0]):
    print(f'generating {j} th instance')
    # full instance generation 
    pos_curr_whole_instance = collection_distribution_hev(n,jd_collection,price)

    pred_full_instance_pos.append(pos_curr_whole_instance)
# Out:
# generating 0 th instance
# generating 1 th instance
# generating 2 th instance
# generating 3 th instance
# generating 4 th instance
# generating 5 th instance
# generating 6 th instance
# generating 7 th instance
# generating 8 th instance
# generating 9 th instance
# generating 10 th instance
# generating 11 th instance
# generating 12 th instance
# generating 13 th instance
# generating 14 th instance
# generating 15 th instance
# generating 16 th instance
# generating 17 th instance
# generating 18 th instance
# generating 19 th instance
# generating 20 th instance
# generating 21 th instance
# generating 22 th instance
# generating 23 th instance
# generating 24 th instance
# generating 25 th instance
# generating 26 th instance
# generating 27 th instance
# generating 28 th instance
# generating 29 th instance
# generating 30 th instance
# generating 31 th instance
# generating 32 th instance
# generating 33 th instance
# generating 34 th instance
# generating 35 th instance
# generating 36 th instance
# generating 37 th instance
# generating 38 th instance
# generating 39 th instance
# generating 40 th instance
# generating 41 th instance
# generating 42 th instance
# generating 43 th instance
# generating 44 th instance
# generating 45 th instance
# generating 46 th instance
# generating 47 th instance
# generating 48 th instance
# generating 49 th instance
# generating 50 th instance
# generating 51 th instance
# generating 52 th instance
# generating 53 th instance
# generating 54 th instance
# generating 55 th instance
# generating 56 th instance
# generating 57 th instance
# generating 58 th instance
# generating 59 th instance
# generating 60 th instance
# generating 61 th instance
# generating 62 th instance
# generating 63 th instance
# generating 64 th instance
# generating 65 th instance
# generating 66 th instance
# generating 67 th instance
# generating 68 th instance
# generating 69 th instance
# generating 70 th instance
# generating 71 th instance
# generating 72 th instance
# generating 73 th instance
# generating 74 th instance
# generating 75 th instance
# generating 76 th instance
# generating 77 th instance
# generating 78 th instance
# generating 79 th instance
# generating 80 th instance
# generating 81 th instance
# generating 82 th instance
# generating 83 th instance
# generating 84 th instance
# generating 85 th instance
# generating 86 th instance
# generating 87 th instance
# generating 88 th instance
# generating 89 th instance
# generating 90 th instance
# generating 91 th instance
# generating 92 th instance
# generating 93 th instance
# generating 94 th instance
# generating 95 th instance
# generating 96 th instance
# generating 97 th instance
# generating 98 th instance
# generating 99 th instance

# %%
# full instance generation for pos gaussian 
all_full_instances_pos = []
 
for i in range(len(pred_offer_times_list)):
    
    full_instances_pos = []

    print(f'check assortment index for offertimes {pred_offer_times_list[i]}')
    for j in range(pred_instance_size[i]):
        # filter choice probability and purchase frequency of each produt in each assortment
        curr_choice_collection_pos = filter_probability(pred_full_instance_pos[j],all_full_assortment_index[i])
        full_instances_pos.append(curr_choice_collection_pos)
     
    all_full_instances_pos.append(full_instances_pos)
# Out:
# check assortment index for offertimes 20
# check assortment index for offertimes 30
# check assortment index for offertimes 40
# check assortment index for offertimes 50
# check assortment index for offertimes 60

# %%
def row_assortment_data(data,collection):
    pre_data = copy.deepcopy(data)
    
    for j in range(data.shape[0]):
        for i in range(len(collection)):
            if j not in collection[i]:
                pre_data[j][i] = -1
    
    return pre_data

def find_indexes_nonposative_descending(arr):
    row_indexes_sorted_desc_nonposative = []
    row_indexes_positive_same_value = []

    for row in arr:
        # Find indexes with non-posative values
        nonposative_row = row[row >= 0]  # Consider only non-posative values
        unique_elements, unique_indexes = np.unique(nonposative_row, return_index=True)
        sorted_indexes_desc = np.nonzero(row >= 0)[0][unique_indexes][np.argsort(-unique_elements)]

        row_indexes_sorted_desc_nonposative.append(sorted_indexes_desc)

        # Keep all indexes of elements with positive and same values
        positive_values = unique_elements[unique_elements > 0]
        positive_same_value_indexes = [np.where(row == val)[0] for val in positive_values if np.count_nonzero(row == val) > 1]
        row_indexes_positive_same_value.append(positive_same_value_indexes)

    return row_indexes_sorted_desc_nonposative, row_indexes_positive_same_value

# %%
def mdm_feasibility(data,ranking,equal):
      
    ub = 100

    model = gp.Model('mdm')
    #model.setParam(gp.GRB.Param.TimeLimit, 60)
    model.setParam('OutputFlag', 0)
    eps = model.addVar(name='eps')
    lam = model.addVars(data.shape[1],name = 'lam')
    
    model.addConstr(eps<=ub ) # just give an upper bound (+ve) for eps, o.w., the problem is unbounded
    
    #for i in range(ranking.shape[0]): # from each product 
    for i in range(len(ranking)): # from each product 
        for j in range(len(ranking[i])-1): # the ranking of assortment in product i 
            model.addConstr(lam [ranking[i][j+1]] - lam[ranking[i][j]]-  eps >=0)
    
    for i in range(len(equal)):
        if len(equal[i])>0:
            for j in range(len(equal[i][0])-1):
                model.addConstr(lam[equal[i][0][j]]-lam[equal[i][0][j+1]]==0)
    
    model.setObjective(eps,GRB.MAXIMIZE)
    model.optimize()
    
     # Access the optimal solution
    if model.status == gp.GRB.OPTIMAL:
        #print('Optimal solution found!')
        eps_value = eps.x
        if eps_value>0:
            return [1,model.Runtime]
        else:
            #model.write("mdminfeas_model.lp")
        
            return [0,model.Runtime]
    else:
        print('MDM feasibility formulation error')

# %%
def mdm_limit(data, collection,offer_times):
    n, m = data.shape

    prod_in_ass = [[] for _ in range(n)]
    for i, assort in enumerate(collection):
        for j in assort:
            prod_in_ass[j].append(i)

    eps = 0.01

    model = gp.Model()
    model.setParam('OutputFlag', 0)
    lam = model.addVars(m, vtype=GRB.CONTINUOUS, lb=0.0, name="lam")
    x = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="x")
    delta = model.addVars(m, m, vtype=GRB.BINARY, name="delta")
    
    # Define auxiliary binary variables for absolute value terms
    abs_vars = model.addVars(n, m, vtype=GRB.CONTINUOUS, lb=0.0, name="abs")
    ''' abs_vars = {}
    for i in range(n):
        for j in range(m):
            abs_vars[i, j] = model.addVar(vtype=GRB.CONTINUOUS, name=f"abs_{i}_{j}") '''

    # Add constraints
    for j in range(m):
        model.addConstr(sum(x[i, j] for i in range(n)) == 1, name=f"normalization_{j}")

    for i in range(len(collection)):
        for j in range(n):
            if j not in collection[i]:
                model.addConstr(x[j, i] == 0, name=f"forcing_zero_{j}_{0}")
                #model.addConstr(abs_vars[j, i] == 0, name=f"abs_forcing_zero_{j}_{0}")
            else:
                model.addConstr(x[j, i] - data[j, i] <= abs_vars[j, i], name=f"abs_const1_{j}_{i}")
                model.addConstr(-x[j, i] + data[j, i] <= abs_vars[j, i], name=f"abs_const2_{j}_{i}")
    
    for i in range(m):
        model.addConstr(lam[i] <= 1, name=f"lam_bound_{i}")

    for i in range(len(prod_in_ass)):
        if len(prod_in_ass[i]) > 0:
            for j in prod_in_ass[i]:
                for k in prod_in_ass[i]:
                    if j != k:
                        model.addConstr(lam[j] - lam[k] + delta[j, k] >= 0, name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(lam[j] - lam[k] - 1 + delta[j, k] + eps * delta[j, k] <= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] + 1 >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - 1 + delta[k, j] <= 0,
                                        name=f"pro_{i}_aspair_{i}_{j}_{k}")
                        
                        model.addConstr(x[i, j] - x[i, k] + delta[j, k] + delta[k, j] >= 0,
                                        name=f"pro_{i}_aspair_{j}_{k}")
                        model.addConstr(x[i, j] - x[i, k] - delta[j, k] - delta[k, j] <= 0,
                                        name=f"ppro_{i}_aspair_{j}_{k}")

    # Add linear constraints to represent absolute value terms
    ''' for i in range(n):
        for j in range(m):
            model.addConstr(x[i, j] - data[i, j] <= abs_vars[i, j], name=f"abs_const1_{i}_{j}")
            model.addConstr(-x[i, j] + data[i, j] <= abs_vars[i, j], name=f"abs_const2_{i}_{j}") '''

    # Define the modified objective function using auxiliary variables
    obj = (sum(offer_times[j]*data[i, j] * abs_vars[i, j] for i in range(n) for j in range(m)))
    #obj = (sum(offer_times[j]*data[i][j] * abs_vars[i, j] for i in range(n) for j in range(m))/sum(offer_times))

    model.setObjective(obj, GRB.MINIMIZE)

    # Set Gurobi parameters if needed
    model.optimize()
    
    x_values = [[x[i, j].X for j in range(m)] for i in range(n)]
    x_values = np.array(x_values)
    
    lam_values = [lam[i].x for i in range(m)]
    lam_values = np.array(lam_values)

    if model.Status == GRB.OPTIMAL:
        print("Gurobi optimization status:", model.status)
        return [model.objVal, model.Runtime,lam_values,x_values]
    else:
        print("Gurobi optimization status:", model.status)
        model.write("mdmlimit_model.lp") 
        #return [model.objVal, model.Runtime,lam_values,x_values]

# %%
## record representability of all instances
all_mdm_rep_pos = []
all_mdm_rep_time_pos = []

## record the limit loss of all instances
all_mdm_limit_loss_pos = []
all_mdm_limit_prob_pos = []
all_mdm_limit_runtime_pos = []

all_mdm_limit_lam_pos = []


for i in range(len(pred_offer_times_list)):

    ## define container for mdm representability check
    mdm_rep_collection_pos =[]
    mdm_rep_runtime_collection_pos =[]
    
    ## define container for mdm limit 
    mdm_limit_loss_collection_pos =[]
    mdm_limit_runtime_collection_pos =[]
    mdm_limit_probability_collection_pos =[]
    mdm_limit_lam_collection_pos = []
       
    for j in range(pred_instance_size[i]):
        print(f'testing instance with offertimes {pred_offer_times_list[i]} : {j}th ')
        ####### mdm representability check ##########
        
        row_data = row_assortment_data(all_full_instances_pos[i][j],all_full_collections[i])
        ## find the decreasing ranking and equal sequence of the assortment in the data
        rank, equal = find_indexes_nonposative_descending(row_data)
        ## representability check of MDM
        curr_rep_result_pos = mdm_feasibility(all_full_instances_pos[i][j],rank,equal)
      
        # return [1/0,model.Runtime] # 1: representable 0: non-representable
        mdm_rep_collection_pos.append(curr_rep_result_pos[0])
        mdm_rep_runtime_collection_pos.append(curr_rep_result_pos[1])
        
        # check if representable
        if curr_rep_result_pos[0] > 0:
            
            mdm_limit_loss_collection_pos.append(0)
            mdm_limit_runtime_collection_pos.append(curr_rep_result_pos[1])
            mdm_limit_probability_collection_pos.append(all_full_instances_pos[i][j])
        else:
            # not representable # limit and prediction
            #mdm_limit(data,collection,perm_collection,produts_notin_collection)
            curr_limit_result_pos = mdm_limit(all_full_instances_pos[i][j],all_full_collections[i],all_full_offertimes[i])
            # return [model.objVal, model.Runtime,lam_values,x_values]
            curr_limit_prob = curr_limit_result_pos[-1]
            mdm_limit_probability_collection_pos.append(curr_limit_prob)
            mdm_limit_loss_collection_pos.append(curr_limit_result_pos[0])
            mdm_limit_runtime_collection_pos.append(curr_limit_result_pos[1])
            mdm_limit_lam_collection_pos.append(curr_limit_result_pos[2])
        print('the limit loss is', mdm_limit_loss_collection_pos[-1])
        print('the runtime is', mdm_limit_runtime_collection_pos[-1])   
    
    ## for each train instance [i][j] representability result is a number
    all_mdm_rep_pos.append(mdm_rep_collection_pos)
    all_mdm_rep_time_pos.append(mdm_rep_runtime_collection_pos)
    
    ## for each train instance [i][j] limit loss result is a number
    all_mdm_limit_loss_pos.append(mdm_limit_loss_collection_pos)
    all_mdm_limit_runtime_pos.append(mdm_limit_runtime_collection_pos)
    
    ## for each train instance [i][j] limit probability is a matrix
    all_mdm_limit_prob_pos.append(mdm_limit_probability_collection_pos)
    
    all_mdm_limit_lam_pos.append(mdm_limit_lam_collection_pos)
# Out:
# testing instance with offertimes 20 : 0th
# Academic license - for non-commercial use only - expires 2024-12-10
# Using license file /Users/autumn/gurobi.lic
# Gurobi optimization status: 2
# the limit loss is 3.8152642969418817
# the runtime is 1.0884780883789062
# testing instance with offertimes 20 : 1th
# Gurobi optimization status: 2
# the limit loss is 1.326152500000001
# the runtime is 0.2389359474182129
# testing instance with offertimes 20 : 2th
# Gurobi optimization status: 2
# the limit loss is 7.822248460000004
# the runtime is 2.389840841293335
# testing instance with offertimes 20 : 3th
# Gurobi optimization status: 2
# the limit loss is 0.10320735999999876
# the runtime is 0.36475706100463867
# testing instance with offertimes 20 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.010283129999999965
# the runtime is 0.21753811836242676
# testing instance with offertimes 20 : 5th
# Gurobi optimization status: 2
# the limit loss is 0.8283452600000007
# the runtime is 0.26250791549682617
# testing instance with offertimes 20 : 6th
# Gurobi optimization status: 2
# the limit loss is 14.208778780000012
# the runtime is 1.2005159854888916
# testing instance with offertimes 20 : 7th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 8th
# Gurobi optimization status: 2
# the limit loss is 1.0376588100000033
# the runtime is 0.4087338447570801
# testing instance with offertimes 20 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.8994477899999984
# the runtime is 0.37592387199401855
# testing instance with offertimes 20 : 10th
# Gurobi optimization status: 2
# the limit loss is 9.28053114
# the runtime is 1.3614239692687988
# testing instance with offertimes 20 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.795476520000001
# the runtime is 0.4373030662536621
# testing instance with offertimes 20 : 12th
# Gurobi optimization status: 2
# the limit loss is 0.7549265400000003
# the runtime is 0.37865209579467773
# testing instance with offertimes 20 : 13th
# Gurobi optimization status: 2
# the limit loss is 35.62837764
# the runtime is 1.406816005706787
# testing instance with offertimes 20 : 14th
# Gurobi optimization status: 2
# the limit loss is 1.121542750000002
# the runtime is 0.658519983291626
# testing instance with offertimes 20 : 15th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.07141685485839844
# testing instance with offertimes 20 : 16th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 17th
# Gurobi optimization status: 2
# the limit loss is 3.376022080000024
# the runtime is 0.5614440441131592
# testing instance with offertimes 20 : 18th
# Gurobi optimization status: 2
# the limit loss is 5.770939899999999
# the runtime is 0.4097738265991211
# testing instance with offertimes 20 : 19th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 20th
# Gurobi optimization status: 2
# the limit loss is 10.29692381
# the runtime is 1.465191125869751
# testing instance with offertimes 20 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.06954837999999976
# the runtime is 0.5491969585418701
# testing instance with offertimes 20 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.0025806000000002877
# the runtime is 0.1550920009613037
# testing instance with offertimes 20 : 23th
# Gurobi optimization status: 2
# the limit loss is 0.40210920000000017
# the runtime is 0.20310711860656738
# testing instance with offertimes 20 : 24th
# Gurobi optimization status: 2
# the limit loss is 9.416566449999998
# the runtime is 1.7281899452209473
# testing instance with offertimes 20 : 25th
# Gurobi optimization status: 2
# the limit loss is 8.25556736
# the runtime is 0.461561918258667
# testing instance with offertimes 20 : 26th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.07318806648254395
# testing instance with offertimes 20 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.730589050000001
# the runtime is 0.9804468154907227
# testing instance with offertimes 20 : 29th
# Gurobi optimization status: 2
# the limit loss is 2.267183779999997
# the runtime is 0.41864514350891113
# testing instance with offertimes 20 : 30th
# Gurobi optimization status: 2
# the limit loss is 10.497692280000003
# the runtime is 0.3704719543457031
# testing instance with offertimes 20 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.11370721000000245
# the runtime is 0.25135302543640137
# testing instance with offertimes 20 : 32th
# Gurobi optimization status: 2
# the limit loss is 4.9799856400000015
# the runtime is 0.3187239170074463
# testing instance with offertimes 20 : 33th
# Gurobi optimization status: 2
# the limit loss is 0.12544469999999908
# the runtime is 0.1621401309967041
# testing instance with offertimes 20 : 34th
# Gurobi optimization status: 2
# the limit loss is 7.234353030000003
# the runtime is 0.6731879711151123
# testing instance with offertimes 20 : 35th
# Gurobi optimization status: 2
# the limit loss is 7.695753289999994
# the runtime is 2.1362459659576416
# testing instance with offertimes 20 : 36th
# Gurobi optimization status: 2
# the limit loss is 6.204780370000001
# the runtime is 0.7484040260314941
# testing instance with offertimes 20 : 37th
# Gurobi optimization status: 2
# the limit loss is 7.928832200000003
# the runtime is 0.41675901412963867
# testing instance with offertimes 20 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.0981900691986084
# testing instance with offertimes 20 : 39th
# Gurobi optimization status: 2
# the limit loss is 3.6525393999999998
# the runtime is 1.0410690307617188
# testing instance with offertimes 20 : 40th
# Gurobi optimization status: 2
# the limit loss is 1.6569072000000002
# the runtime is 0.2917780876159668
# testing instance with offertimes 20 : 41th
# Gurobi optimization status: 2
# the limit loss is 10.623946999999998
# the runtime is 1.9758391380310059
# testing instance with offertimes 20 : 42th
# Gurobi optimization status: 2
# the limit loss is 0.16687880000000013
# the runtime is 0.18218207359313965
# testing instance with offertimes 20 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.07781410217285156
# testing instance with offertimes 20 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.18887715000000033
# the runtime is 0.3190948963165283
# testing instance with offertimes 20 : 45th
# Gurobi optimization status: 2
# the limit loss is 1.3990312900000006
# the runtime is 0.2837049961090088
# testing instance with offertimes 20 : 46th
# Gurobi optimization status: 2
# the limit loss is 24.54351239
# the runtime is 1.6245639324188232
# testing instance with offertimes 20 : 47th
# Gurobi optimization status: 2
# the limit loss is 2.726342159999999
# the runtime is 0.2586820125579834
# testing instance with offertimes 20 : 48th
# Gurobi optimization status: 2
# the limit loss is 0.09694021999999804
# the runtime is 0.2164440155029297
# testing instance with offertimes 20 : 49th
# Gurobi optimization status: 2
# the limit loss is 8.061353190000002
# the runtime is 1.121711015701294
# testing instance with offertimes 20 : 50th
# Gurobi optimization status: 2
# the limit loss is 11.208155559999996
# the runtime is 1.064249038696289
# testing instance with offertimes 20 : 51th
# Gurobi optimization status: 2
# the limit loss is 10.857528360000002
# the runtime is 0.4328289031982422
# testing instance with offertimes 20 : 52th
# Gurobi optimization status: 2
# the limit loss is 15.674606399999995
# the runtime is 0.7789089679718018
# testing instance with offertimes 20 : 53th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 54th
# Gurobi optimization status: 2
# the limit loss is 5.333318540000001
# the runtime is 2.8403921127319336
# testing instance with offertimes 20 : 55th
# Gurobi optimization status: 2
# the limit loss is 21.795005619999998
# the runtime is 0.9100480079650879
# testing instance with offertimes 20 : 56th
# Gurobi optimization status: 2
# the limit loss is 6.8374230599999954
# the runtime is 0.5785830020904541
# testing instance with offertimes 20 : 57th
# Gurobi optimization status: 2
# the limit loss is 0.11002867999999988
# the runtime is 0.2449960708618164
# testing instance with offertimes 20 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.06022672999999862
# the runtime is 0.4762887954711914
# testing instance with offertimes 20 : 59th
# Gurobi optimization status: 2
# the limit loss is 0.0486559999999996
# the runtime is 0.25070786476135254
# testing instance with offertimes 20 : 60th
# Gurobi optimization status: 2
# the limit loss is 0.24007112999999772
# the runtime is 0.3167569637298584
# testing instance with offertimes 20 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.7728960000000005
# the runtime is 0.15322399139404297
# testing instance with offertimes 20 : 62th
# Gurobi optimization status: 2
# the limit loss is 33.938063039999996
# the runtime is 0.7536790370941162
# testing instance with offertimes 20 : 63th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.10054206848144531
# testing instance with offertimes 20 : 64th
# Gurobi optimization status: 2
# the limit loss is 8.081766120000001
# the runtime is 0.9807538986206055
# testing instance with offertimes 20 : 65th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.07137703895568848
# testing instance with offertimes 20 : 66th
# Gurobi optimization status: 2
# the limit loss is 3.220459950000002
# the runtime is 0.4988858699798584
# testing instance with offertimes 20 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.43898131000000007
# the runtime is 0.2908508777618408
# testing instance with offertimes 20 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.9886962700000012
# the runtime is 0.3685948848724365
# testing instance with offertimes 20 : 69th
# Gurobi optimization status: 2
# the limit loss is 2.059887549999999
# the runtime is 1.7962028980255127
# testing instance with offertimes 20 : 70th
# Gurobi optimization status: 2
# the limit loss is 0.1668670599999994
# the runtime is 0.30319905281066895
# testing instance with offertimes 20 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.11884904000000004
# the runtime is 0.18508100509643555
# testing instance with offertimes 20 : 72th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.24710514000000042
# the runtime is 0.3434269428253174
# testing instance with offertimes 20 : 74th
# Gurobi optimization status: 2
# the limit loss is 1.0578574900000006
# the runtime is 1.8050408363342285
# testing instance with offertimes 20 : 75th
# Gurobi optimization status: 2
# the limit loss is 1.9440418300000033
# the runtime is 0.21946001052856445
# testing instance with offertimes 20 : 76th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 77th
# Gurobi optimization status: 2
# the limit loss is 5.1311413
# the runtime is 0.47699785232543945
# testing instance with offertimes 20 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.0076824400000034335
# the runtime is 0.18764114379882812
# testing instance with offertimes 20 : 79th
# Gurobi optimization status: 2
# the limit loss is 6.853806399999996
# the runtime is 3.1431970596313477
# testing instance with offertimes 20 : 80th
# Gurobi optimization status: 2
# the limit loss is 2.6026479900000035
# the runtime is 2.286564826965332
# testing instance with offertimes 20 : 81th
# Gurobi optimization status: 2
# the limit loss is 15.923861590000001
# the runtime is 2.0834310054779053
# testing instance with offertimes 20 : 82th
# Gurobi optimization status: 2
# the limit loss is 1.0167386400000005
# the runtime is 0.16095304489135742
# testing instance with offertimes 20 : 83th
# Gurobi optimization status: 2
# the limit loss is 2.1872267999999995
# the runtime is 0.34056806564331055
# testing instance with offertimes 20 : 84th
# Gurobi optimization status: 2
# the limit loss is 4.928571580000006
# the runtime is 2.442902088165283
# testing instance with offertimes 20 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.13982711999999997
# the runtime is 0.1883220672607422
# testing instance with offertimes 20 : 86th
# Gurobi optimization status: 2
# the limit loss is 2.1462077800000015
# the runtime is 0.41382503509521484
# testing instance with offertimes 20 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.022975160000000095
# the runtime is 0.16166186332702637
# testing instance with offertimes 20 : 88th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 89th
# Gurobi optimization status: 2
# the limit loss is 1.833732239999999
# the runtime is 0.3822510242462158
# testing instance with offertimes 20 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.005304000000049461
# the runtime is 0.3230130672454834
# testing instance with offertimes 20 : 91th
# Gurobi optimization status: 2
# the limit loss is 5.450581409999998
# the runtime is 0.5909090042114258
# testing instance with offertimes 20 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.017256560000000493
# the runtime is 0.30018186569213867
# testing instance with offertimes 20 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.3504984300000012
# the runtime is 0.3187241554260254
# testing instance with offertimes 20 : 94th
# Gurobi optimization status: 2
# the limit loss is 17.554445760000004
# the runtime is 2.4757678508758545
# testing instance with offertimes 20 : 95th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 96th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 20 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.5512723199999995
# the runtime is 0.5049519538879395
# testing instance with offertimes 20 : 98th
# Gurobi optimization status: 2
# the limit loss is 0.060778050000001096
# the runtime is 0.3358731269836426
# testing instance with offertimes 20 : 99th
# Gurobi optimization status: 2
# the limit loss is 12.512319999999995
# the runtime is 0.9803071022033691
# testing instance with offertimes 30 : 0th
# Gurobi optimization status: 2
# the limit loss is 1.0659456600000006
# the runtime is 0.162841796875
# testing instance with offertimes 30 : 1th
# Gurobi optimization status: 2
# the limit loss is 1.165370100000001
# the runtime is 0.12992501258850098
# testing instance with offertimes 30 : 2th
# Gurobi optimization status: 2
# the limit loss is 2.3104419999999974
# the runtime is 0.5156989097595215
# testing instance with offertimes 30 : 3th
# Gurobi optimization status: 2
# the limit loss is 0.10320735999999876
# the runtime is 0.19632196426391602
# testing instance with offertimes 30 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.09576702117919922
# testing instance with offertimes 30 : 5th
# Gurobi optimization status: 2
# the limit loss is 0.5933432000000006
# the runtime is 0.14811205863952637
# testing instance with offertimes 30 : 6th
# Gurobi optimization status: 2
# the limit loss is 12.501023790000012
# the runtime is 0.8074500560760498
# testing instance with offertimes 30 : 7th
# Gurobi optimization status: 2
# the limit loss is 0.12950000000000128
# the runtime is 0.44113707542419434
# testing instance with offertimes 30 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.8686358100000007
# the runtime is 0.13278603553771973
# testing instance with offertimes 30 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.8920517899999983
# the runtime is 0.2836019992828369
# testing instance with offertimes 30 : 10th
# Gurobi optimization status: 2
# the limit loss is 9.237462400000002
# the runtime is 1.768151044845581
# testing instance with offertimes 30 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.003138119999999985
# the runtime is 0.17935419082641602
# testing instance with offertimes 30 : 12th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 13th
# Gurobi optimization status: 2
# the limit loss is 33.20796704
# the runtime is 0.6366779804229736
# testing instance with offertimes 30 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.13770000000000182
# the runtime is 0.2366621494293213
# testing instance with offertimes 30 : 15th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 16th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 17th
# Gurobi optimization status: 2
# the limit loss is 1.7180633500000062
# the runtime is 0.21311283111572266
# testing instance with offertimes 30 : 18th
# Gurobi optimization status: 2
# the limit loss is 5.0202559700000045
# the runtime is 0.17757487297058105
# testing instance with offertimes 30 : 19th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 20th
# Gurobi optimization status: 2
# the limit loss is 6.817054850000002
# the runtime is 0.9731910228729248
# testing instance with offertimes 30 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.05432467000000018
# the runtime is 0.14809298515319824
# testing instance with offertimes 30 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.045974016189575195
# testing instance with offertimes 30 : 23th
# Gurobi optimization status: 2
# the limit loss is 0.15177599999999997
# the runtime is 0.08893918991088867
# testing instance with offertimes 30 : 24th
# Gurobi optimization status: 2
# the limit loss is 7.006970689999993
# the runtime is 0.3607809543609619
# testing instance with offertimes 30 : 25th
# Gurobi optimization status: 2
# the limit loss is 7.5485565900000005
# the runtime is 0.22693610191345215
# testing instance with offertimes 30 : 26th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.12030816078186035
# testing instance with offertimes 30 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.53248754
# the runtime is 0.3084549903869629
# testing instance with offertimes 30 : 29th
# Gurobi optimization status: 2
# the limit loss is 2.267183779999997
# the runtime is 0.15423798561096191
# testing instance with offertimes 30 : 30th
# Gurobi optimization status: 2
# the limit loss is 7.559373320000006
# the runtime is 0.1567699909210205
# testing instance with offertimes 30 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.09944796000000204
# the runtime is 0.1462709903717041
# testing instance with offertimes 30 : 32th
# Gurobi optimization status: 2
# the limit loss is 2.2054409999999995
# the runtime is 0.1533668041229248
# testing instance with offertimes 30 : 33th
# Gurobi optimization status: 2
# the limit loss is 0.12544469999999908
# the runtime is 0.09824895858764648
# testing instance with offertimes 30 : 34th
# Gurobi optimization status: 2
# the limit loss is 6.912157040000003
# the runtime is 0.3259749412536621
# testing instance with offertimes 30 : 35th
# Gurobi optimization status: 2
# the limit loss is 5.689903109999994
# the runtime is 0.3533351421356201
# testing instance with offertimes 30 : 36th
# Gurobi optimization status: 2
# the limit loss is 5.754009070000003
# the runtime is 0.20947813987731934
# testing instance with offertimes 30 : 37th
# Gurobi optimization status: 2
# the limit loss is 6.587910920000003
# the runtime is 0.1923511028289795
# testing instance with offertimes 30 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.04573702812194824
# testing instance with offertimes 30 : 39th
# Gurobi optimization status: 2
# the limit loss is 3.4521980000000028
# the runtime is 0.43593621253967285
# testing instance with offertimes 30 : 40th
# Gurobi optimization status: 2
# the limit loss is 1.6569072000000002
# the runtime is 0.15359091758728027
# testing instance with offertimes 30 : 41th
# Gurobi optimization status: 2
# the limit loss is 7.936498240000001
# the runtime is 0.8774969577789307
# testing instance with offertimes 30 : 42th
# Gurobi optimization status: 2
# the limit loss is 0.16687880000000013
# the runtime is 0.10525703430175781
# testing instance with offertimes 30 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.05658292770385742
# testing instance with offertimes 30 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.06091499328613281
# testing instance with offertimes 30 : 45th
# Gurobi optimization status: 2
# the limit loss is 1.0524309699999996
# the runtime is 0.14130187034606934
# testing instance with offertimes 30 : 46th
# Gurobi optimization status: 2
# the limit loss is 23.166766139999996
# the runtime is 0.5856709480285645
# testing instance with offertimes 30 : 47th
# Gurobi optimization status: 2
# the limit loss is 2.7263421599999993
# the runtime is 0.15349197387695312
# testing instance with offertimes 30 : 48th
# Gurobi optimization status: 2
# the limit loss is 0.09694021999999804
# the runtime is 0.12277102470397949
# testing instance with offertimes 30 : 49th
# Gurobi optimization status: 2
# the limit loss is 4.039153190000001
# the runtime is 0.28990602493286133
# testing instance with offertimes 30 : 50th
# Gurobi optimization status: 2
# the limit loss is 8.739419380000001
# the runtime is 0.4469480514526367
# testing instance with offertimes 30 : 51th
# Gurobi optimization status: 2
# the limit loss is 10.802193080000002
# the runtime is 0.25578904151916504
# testing instance with offertimes 30 : 52th
# Gurobi optimization status: 2
# the limit loss is 9.935538530000008
# the runtime is 0.2817721366882324
# testing instance with offertimes 30 : 53th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.9095911799999998
# the runtime is 0.3238098621368408
# testing instance with offertimes 30 : 55th
# Gurobi optimization status: 2
# the limit loss is 19.811892059999995
# the runtime is 0.22700190544128418
# testing instance with offertimes 30 : 56th
# Gurobi optimization status: 2
# the limit loss is 6.837423059999994
# the runtime is 0.6048891544342041
# testing instance with offertimes 30 : 57th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.053880929946899414
# testing instance with offertimes 30 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.04087313000000055
# the runtime is 0.21866488456726074
# testing instance with offertimes 30 : 59th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 60th
# Gurobi optimization status: 2
# the limit loss is 0.23684912999999752
# the runtime is 0.12102198600769043
# testing instance with offertimes 30 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.7728960000000005
# the runtime is 0.0817418098449707
# testing instance with offertimes 30 : 62th
# Gurobi optimization status: 2
# the limit loss is 30.91866303999999
# the runtime is 0.28301000595092773
# testing instance with offertimes 30 : 63th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.05552387237548828
# testing instance with offertimes 30 : 64th
# Gurobi optimization status: 2
# the limit loss is 6.41974878
# the runtime is 0.33445286750793457
# testing instance with offertimes 30 : 65th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 66th
# Gurobi optimization status: 2
# the limit loss is 1.4609599500000008
# the runtime is 0.19124507904052734
# testing instance with offertimes 30 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.33462850999999993
# the runtime is 0.1880788803100586
# testing instance with offertimes 30 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.9733100499999993
# the runtime is 0.26933813095092773
# testing instance with offertimes 30 : 69th
# Gurobi optimization status: 2
# the limit loss is 2.0561192299999993
# the runtime is 0.5178611278533936
# testing instance with offertimes 30 : 70th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.10115480422973633
# testing instance with offertimes 30 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.06714201000000003
# the runtime is 0.10725593566894531
# testing instance with offertimes 30 : 72th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.21170796000000042
# the runtime is 0.20599603652954102
# testing instance with offertimes 30 : 74th
# Gurobi optimization status: 2
# the limit loss is 0.7992740399999994
# the runtime is 0.6648271083831787
# testing instance with offertimes 30 : 75th
# Gurobi optimization status: 2
# the limit loss is 1.2765875800000017
# the runtime is 0.13877391815185547
# testing instance with offertimes 30 : 76th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 77th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.007674190000003427
# the runtime is 0.13409209251403809
# testing instance with offertimes 30 : 79th
# Gurobi optimization status: 2
# the limit loss is 5.4834064
# the runtime is 0.2853429317474365
# testing instance with offertimes 30 : 80th
# Gurobi optimization status: 2
# the limit loss is 0.05442488000000111
# the runtime is 0.6922690868377686
# testing instance with offertimes 30 : 81th
# Gurobi optimization status: 2
# the limit loss is 10.54138064
# the runtime is 0.7471680641174316
# testing instance with offertimes 30 : 82th
# Gurobi optimization status: 2
# the limit loss is 0.0005452799999999962
# the runtime is 0.08312296867370605
# testing instance with offertimes 30 : 83th
# Gurobi optimization status: 2
# the limit loss is 2.1872267999999995
# the runtime is 0.18396997451782227
# testing instance with offertimes 30 : 84th
# Gurobi optimization status: 2
# the limit loss is 4.151053900000005
# the runtime is 1.0657861232757568
# testing instance with offertimes 30 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.06102800369262695
# testing instance with offertimes 30 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.048026700000000984
# the runtime is 0.10496997833251953
# testing instance with offertimes 30 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.05942511558532715
# testing instance with offertimes 30 : 88th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 89th
# Gurobi optimization status: 2
# the limit loss is 1.1383778400000006
# the runtime is 0.13640689849853516
# testing instance with offertimes 30 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.005255040000000001
# the runtime is 0.12425899505615234
# testing instance with offertimes 30 : 91th
# Gurobi optimization status: 2
# the limit loss is 4.226170049999994
# the runtime is 0.1460731029510498
# testing instance with offertimes 30 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.017256560000000493
# the runtime is 0.1809849739074707
# testing instance with offertimes 30 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.318964320000001
# the runtime is 0.14271903038024902
# testing instance with offertimes 30 : 94th
# Gurobi optimization status: 2
# the limit loss is 13.541660479999999
# the runtime is 0.34374499320983887
# testing instance with offertimes 30 : 95th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 96th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.11191631999999932
# the runtime is 0.2036728858947754
# testing instance with offertimes 30 : 98th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 30 : 99th
# Gurobi optimization status: 2
# the limit loss is 11.015359069999997
# the runtime is 0.5148088932037354
# testing instance with offertimes 40 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.27533771999999945
# the runtime is 0.06332111358642578
# testing instance with offertimes 40 : 1th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.028615951538085938
# testing instance with offertimes 40 : 2th
# Gurobi optimization status: 2
# the limit loss is 1.1787575999999986
# the runtime is 0.10302400588989258
# testing instance with offertimes 40 : 3th
# Gurobi optimization status: 2
# the limit loss is 0.01379999999999848
# the runtime is 0.1003260612487793
# testing instance with offertimes 40 : 4th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.025899171829223633
# testing instance with offertimes 40 : 5th
# Gurobi optimization status: 2
# the limit loss is 0.36260560000000025
# the runtime is 0.08288192749023438
# testing instance with offertimes 40 : 6th
# Gurobi optimization status: 2
# the limit loss is 12.496193070000011
# the runtime is 0.2836170196533203
# testing instance with offertimes 40 : 7th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.028549909591674805
# testing instance with offertimes 40 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.04931583999999998
# the runtime is 0.05897688865661621
# testing instance with offertimes 40 : 10th
# Gurobi optimization status: 2
# the limit loss is 6.066512959999997
# the runtime is 0.15502214431762695
# testing instance with offertimes 40 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.003138119999999989
# the runtime is 0.18160390853881836
# testing instance with offertimes 40 : 12th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 13th
# Gurobi optimization status: 2
# the limit loss is 25.199298730000002
# the runtime is 0.2266530990600586
# testing instance with offertimes 40 : 14th
# Gurobi optimization status: 2
# the limit loss is 0.13770000000000182
# the runtime is 0.09004402160644531
# testing instance with offertimes 40 : 15th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 16th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 17th
# Gurobi optimization status: 2
# the limit loss is 1.435748250000001
# the runtime is 0.10464286804199219
# testing instance with offertimes 40 : 18th
# Gurobi optimization status: 2
# the limit loss is 2.307071250000001
# the runtime is 0.08593988418579102
# testing instance with offertimes 40 : 19th
# Gurobi optimization status: 2
# the limit loss is 13.959961819999997
# the runtime is 0.1862928867340088
# testing instance with offertimes 40 : 20th
# Gurobi optimization status: 2
# the limit loss is 4.039830490000001
# the runtime is 0.09542608261108398
# testing instance with offertimes 40 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.026304989999999834
# the runtime is 0.21837401390075684
# testing instance with offertimes 40 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.025901079177856445
# testing instance with offertimes 40 : 23th
# Gurobi optimization status: 2
# the limit loss is 0.15177599999999997
# the runtime is 0.0484929084777832
# testing instance with offertimes 40 : 24th
# Gurobi optimization status: 2
# the limit loss is 5.273802249999996
# the runtime is 0.10949182510375977
# testing instance with offertimes 40 : 25th
# Gurobi optimization status: 2
# the limit loss is 6.50074175
# the runtime is 0.11974596977233887
# testing instance with offertimes 40 : 26th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.02716994285583496
# testing instance with offertimes 40 : 28th
# Gurobi optimization status: 2
# the limit loss is 0.4407818600000001
# the runtime is 0.230604887008667
# testing instance with offertimes 40 : 29th
# Gurobi optimization status: 2
# the limit loss is 1.464807379999999
# the runtime is 0.05649995803833008
# testing instance with offertimes 40 : 30th
# Gurobi optimization status: 2
# the limit loss is 0.40582944000000065
# the runtime is 0.04656386375427246
# testing instance with offertimes 40 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.09944796000000204
# the runtime is 0.09324789047241211
# testing instance with offertimes 40 : 32th
# Gurobi optimization status: 2
# the limit loss is 0.8029529999999988
# the runtime is 0.05997300148010254
# testing instance with offertimes 40 : 33th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 34th
# Gurobi optimization status: 2
# the limit loss is 3.30050818
# the runtime is 0.15131688117980957
# testing instance with offertimes 40 : 35th
# Gurobi optimization status: 2
# the limit loss is 1.1872484699999977
# the runtime is 0.09927201271057129
# testing instance with offertimes 40 : 36th
# Gurobi optimization status: 2
# the limit loss is 5.636939140000002
# the runtime is 0.13214802742004395
# testing instance with offertimes 40 : 37th
# Gurobi optimization status: 2
# the limit loss is 6.5879109200000014
# the runtime is 0.09289193153381348
# testing instance with offertimes 40 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03160595893859863
# testing instance with offertimes 40 : 39th
# Gurobi optimization status: 2
# the limit loss is 0.0025980000000032917
# the runtime is 0.09316301345825195
# testing instance with offertimes 40 : 40th
# Gurobi optimization status: 2
# the limit loss is 0.7296239700000003
# the runtime is 0.05158114433288574
# testing instance with offertimes 40 : 41th
# Gurobi optimization status: 2
# the limit loss is 2.8546804800000003
# the runtime is 0.2572050094604492
# testing instance with offertimes 40 : 42th
# Gurobi optimization status: 2
# the limit loss is 0.16687880000000013
# the runtime is 0.06450986862182617
# testing instance with offertimes 40 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.027157068252563477
# testing instance with offertimes 40 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.0345311164855957
# testing instance with offertimes 40 : 45th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 46th
# Gurobi optimization status: 2
# the limit loss is 18.888131799999996
# the runtime is 0.13433003425598145
# testing instance with offertimes 40 : 47th
# Gurobi optimization status: 2
# the limit loss is 2.726342159999999
# the runtime is 0.09664392471313477
# testing instance with offertimes 40 : 48th
# Gurobi optimization status: 2
# the limit loss is 0.09694021999999804
# the runtime is 0.08761715888977051
# testing instance with offertimes 40 : 49th
# Gurobi optimization status: 2
# the limit loss is 2.3814736500000038
# the runtime is 0.28888392448425293
# testing instance with offertimes 40 : 50th
# Gurobi optimization status: 2
# the limit loss is 0.6779445900000008
# the runtime is 0.09085488319396973
# testing instance with offertimes 40 : 51th
# Gurobi optimization status: 2
# the limit loss is 10.735552440000001
# the runtime is 0.16556596755981445
# testing instance with offertimes 40 : 52th
# Gurobi optimization status: 2
# the limit loss is 6.069957410000005
# the runtime is 0.09974503517150879
# testing instance with offertimes 40 : 53th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.23667810000000297
# the runtime is 0.1116340160369873
# testing instance with offertimes 40 : 55th
# Gurobi optimization status: 2
# the limit loss is 19.81189205999999
# the runtime is 0.14754819869995117
# testing instance with offertimes 40 : 56th
# Gurobi optimization status: 2
# the limit loss is 4.35581854000001
# the runtime is 0.25044703483581543
# testing instance with offertimes 40 : 57th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.02654099464416504
# testing instance with offertimes 40 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.027220580000000348
# the runtime is 0.10274910926818848
# testing instance with offertimes 40 : 59th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 60th
# Gurobi optimization status: 2
# the limit loss is 0.21721874999999966
# the runtime is 0.09051704406738281
# testing instance with offertimes 40 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.7728960000000005
# the runtime is 0.05835103988647461
# testing instance with offertimes 40 : 62th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 63th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.026421070098876953
# testing instance with offertimes 40 : 64th
# Gurobi optimization status: 2
# the limit loss is 6.419748780000003
# the runtime is 0.1685960292816162
# testing instance with offertimes 40 : 65th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 66th
# Gurobi optimization status: 2
# the limit loss is 1.3389421500000007
# the runtime is 0.07490396499633789
# testing instance with offertimes 40 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.2795757099999998
# the runtime is 0.1800389289855957
# testing instance with offertimes 40 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.16472941999999854
# the runtime is 0.07644295692443848
# testing instance with offertimes 40 : 69th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 70th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.02790689468383789
# testing instance with offertimes 40 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.06714201000000003
# the runtime is 0.05391383171081543
# testing instance with offertimes 40 : 72th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.20271479999999975
# the runtime is 0.1063990592956543
# testing instance with offertimes 40 : 74th
# Gurobi optimization status: 2
# the limit loss is 0.028380600000000557
# the runtime is 0.30660104751586914
# testing instance with offertimes 40 : 75th
# Gurobi optimization status: 2
# the limit loss is 0.9488470800000027
# the runtime is 0.09274697303771973
# testing instance with offertimes 40 : 76th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 77th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.007674190000003384
# the runtime is 0.06280183792114258
# testing instance with offertimes 40 : 79th
# Gurobi optimization status: 2
# the limit loss is 5.47079624
# the runtime is 0.20918607711791992
# testing instance with offertimes 40 : 80th
# Gurobi optimization status: 2
# the limit loss is 9.12e-06
# the runtime is 0.12408900260925293
# testing instance with offertimes 40 : 81th
# Gurobi optimization status: 2
# the limit loss is 6.717558479999999
# the runtime is 0.10336899757385254
# testing instance with offertimes 40 : 82th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 83th
# Gurobi optimization status: 2
# the limit loss is 2.1872267999999995
# the runtime is 0.07256317138671875
# testing instance with offertimes 40 : 84th
# Gurobi optimization status: 2
# the limit loss is 0.030131080000005063
# the runtime is 0.167708158493042
# testing instance with offertimes 40 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.04046893119812012
# testing instance with offertimes 40 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.048026700000000984
# the runtime is 0.05907392501831055
# testing instance with offertimes 40 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03573894500732422
# testing instance with offertimes 40 : 88th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 89th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.035253047943115234
# testing instance with offertimes 40 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.034490108489990234
# testing instance with offertimes 40 : 91th
# Gurobi optimization status: 2
# the limit loss is 3.538549250000001
# the runtime is 0.08008503913879395
# testing instance with offertimes 40 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.017256560000000493
# the runtime is 0.09720206260681152
# testing instance with offertimes 40 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.31896432000000186
# the runtime is 0.06617307662963867
# testing instance with offertimes 40 : 94th
# Gurobi optimization status: 2
# the limit loss is 13.320867839999998
# the runtime is 0.17957401275634766
# testing instance with offertimes 40 : 95th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 96th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03985095024108887
# testing instance with offertimes 40 : 98th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 40 : 99th
# Gurobi optimization status: 2
# the limit loss is 8.921994159999999
# the runtime is 0.15788793563842773
# testing instance with offertimes 50 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.018949031829833984
# testing instance with offertimes 50 : 1th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.01733708381652832
# testing instance with offertimes 50 : 2th
# Gurobi optimization status: 2
# the limit loss is 0.03955199999999894
# the runtime is 0.0642540454864502
# testing instance with offertimes 50 : 3th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 4th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 5th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 6th
# Gurobi optimization status: 2
# the limit loss is 3.7164829200000096
# the runtime is 0.06633591651916504
# testing instance with offertimes 50 : 7th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.013501882553100586
# testing instance with offertimes 50 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.04931583999999998
# the runtime is 0.02855396270751953
# testing instance with offertimes 50 : 10th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 11th
# Gurobi optimization status: 2
# the limit loss is 0.0005768399999999819
# the runtime is 0.07491898536682129
# testing instance with offertimes 50 : 12th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 13th
# Gurobi optimization status: 2
# the limit loss is 14.810354250000001
# the runtime is 0.07230806350708008
# testing instance with offertimes 50 : 14th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 15th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 16th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 17th
# Gurobi optimization status: 2
# the limit loss is 0.9365466000000015
# the runtime is 0.04427504539489746
# testing instance with offertimes 50 : 18th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.016469955444335938
# testing instance with offertimes 50 : 19th
# Gurobi optimization status: 2
# the limit loss is 7.011684
# the runtime is 0.038330078125
# testing instance with offertimes 50 : 20th
# Gurobi optimization status: 2
# the limit loss is 4.023594030000001
# the runtime is 0.04966402053833008
# testing instance with offertimes 50 : 21th
# Gurobi optimization status: 2
# the limit loss is 0.026128589999999802
# the runtime is 0.08852291107177734
# testing instance with offertimes 50 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.015438079833984375
# testing instance with offertimes 50 : 23th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.020752906799316406
# testing instance with offertimes 50 : 24th
# Gurobi optimization status: 2
# the limit loss is 1.0167999999999981
# the runtime is 0.03925514221191406
# testing instance with offertimes 50 : 25th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.015233993530273438
# testing instance with offertimes 50 : 26th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.015796899795532227
# testing instance with offertimes 50 : 28th
# Gurobi optimization status: 2
# the limit loss is 7.96e-06
# the runtime is 0.07574892044067383
# testing instance with offertimes 50 : 29th
# Gurobi optimization status: 2
# the limit loss is 0.30485481999999836
# the runtime is 0.04801797866821289
# testing instance with offertimes 50 : 30th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.01584792137145996
# testing instance with offertimes 50 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.09944796000000204
# the runtime is 0.048490047454833984
# testing instance with offertimes 50 : 32th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.014549016952514648
# testing instance with offertimes 50 : 33th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 34th
# Gurobi optimization status: 2
# the limit loss is 3.29897728
# the runtime is 0.05843210220336914
# testing instance with offertimes 50 : 35th
# Gurobi optimization status: 2
# the limit loss is 0.01683747
# the runtime is 0.040969133377075195
# testing instance with offertimes 50 : 36th
# Gurobi optimization status: 2
# the limit loss is 2.6286620700000007
# the runtime is 0.03654313087463379
# testing instance with offertimes 50 : 37th
# Gurobi optimization status: 2
# the limit loss is 0.037115320000003414
# the runtime is 0.03961014747619629
# testing instance with offertimes 50 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.019868850708007812
# testing instance with offertimes 50 : 39th
# Gurobi optimization status: 2
# the limit loss is 0.0010455000000000186
# the runtime is 0.04880404472351074
# testing instance with offertimes 50 : 40th
# Gurobi optimization status: 2
# the limit loss is 0.7296239700000003
# the runtime is 0.04313087463378906
# testing instance with offertimes 50 : 41th
# Gurobi optimization status: 2
# the limit loss is 2.08780268
# the runtime is 0.14766407012939453
# testing instance with offertimes 50 : 42th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.014320135116577148
# testing instance with offertimes 50 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.016030073165893555
# testing instance with offertimes 50 : 45th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 46th
# Gurobi optimization status: 2
# the limit loss is 14.097881600000001
# the runtime is 0.06133913993835449
# testing instance with offertimes 50 : 47th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.01775383949279785
# testing instance with offertimes 50 : 48th
# Gurobi optimization status: 2
# the limit loss is 0.09694021999999804
# the runtime is 0.04526495933532715
# testing instance with offertimes 50 : 49th
# Gurobi optimization status: 2
# the limit loss is 2.381082650000004
# the runtime is 0.03464698791503906
# testing instance with offertimes 50 : 50th
# Gurobi optimization status: 2
# the limit loss is 0.03564138999999877
# the runtime is 0.0473630428314209
# testing instance with offertimes 50 : 51th
# Gurobi optimization status: 2
# the limit loss is 1.5874724400000015
# the runtime is 0.05158400535583496
# testing instance with offertimes 50 : 52th
# Gurobi optimization status: 2
# the limit loss is 3.320884610000003
# the runtime is 0.03448796272277832
# testing instance with offertimes 50 : 53th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.034691010000000376
# the runtime is 0.05380606651306152
# testing instance with offertimes 50 : 55th
# Gurobi optimization status: 2
# the limit loss is 14.033700239999996
# the runtime is 0.06089496612548828
# testing instance with offertimes 50 : 56th
# Gurobi optimization status: 2
# the limit loss is 2.5102874799999997
# the runtime is 0.08318591117858887
# testing instance with offertimes 50 : 57th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 58th
# Gurobi optimization status: 2
# the limit loss is 0.02280277999999979
# the runtime is 0.03247404098510742
# testing instance with offertimes 50 : 59th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 60th
# Gurobi optimization status: 2
# the limit loss is 0.022044750000001063
# the runtime is 0.033822059631347656
# testing instance with offertimes 50 : 61th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.01587700843811035
# testing instance with offertimes 50 : 62th
# Gurobi optimization status: 2
# the limit loss is 30.918655999999995
# the runtime is 0.0672140121459961
# testing instance with offertimes 50 : 63th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 64th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 65th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 66th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.015869140625
# testing instance with offertimes 50 : 67th
# Gurobi optimization status: 2
# the limit loss is 0.19367403000000014
# the runtime is 0.04262185096740723
# testing instance with offertimes 50 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.11059711999999863
# the runtime is 0.031907081604003906
# testing instance with offertimes 50 : 69th
# Gurobi optimization status: 2
# the limit loss is 1.2237220800000024
# the runtime is 0.05791187286376953
# testing instance with offertimes 50 : 70th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 71th
# Gurobi optimization status: 2
# the limit loss is 0.06714201000000003
# the runtime is 0.02933502197265625
# testing instance with offertimes 50 : 72th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.014855146408081055
# testing instance with offertimes 50 : 74th
# Gurobi optimization status: 2
# the limit loss is 0.007416269999999184
# the runtime is 0.03771686553955078
# testing instance with offertimes 50 : 75th
# Gurobi optimization status: 2
# the limit loss is 0.008347080000000734
# the runtime is 0.03255796432495117
# testing instance with offertimes 50 : 76th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 77th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 78th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.022452831268310547
# testing instance with offertimes 50 : 79th
# Gurobi optimization status: 2
# the limit loss is 0.01758364
# the runtime is 0.09078192710876465
# testing instance with offertimes 50 : 80th
# Gurobi optimization status: 2
# the limit loss is 9.116865796403433e-06
# the runtime is 0.04672980308532715
# testing instance with offertimes 50 : 81th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 82th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 83th
# Gurobi optimization status: 2
# the limit loss is 2.1872267999999995
# the runtime is 0.0549468994140625
# testing instance with offertimes 50 : 84th
# Gurobi optimization status: 2
# the limit loss is 0.00024108
# the runtime is 0.08161306381225586
# testing instance with offertimes 50 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.020395994186401367
# testing instance with offertimes 50 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.016366004943847656
# testing instance with offertimes 50 : 87th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.014446020126342773
# testing instance with offertimes 50 : 88th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 89th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 90th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.028603076934814453
# testing instance with offertimes 50 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.02666020393371582
# testing instance with offertimes 50 : 92th
# Gurobi optimization status: 2
# the limit loss is 8.150842697458821e-06
# the runtime is 0.031000137329101562
# testing instance with offertimes 50 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.31894272000000184
# the runtime is 0.030506134033203125
# testing instance with offertimes 50 : 94th
# Gurobi optimization status: 2
# the limit loss is 9.67686144
# the runtime is 0.05373191833496094
# testing instance with offertimes 50 : 95th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 96th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.016971826553344727
# testing instance with offertimes 50 : 98th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 50 : 99th
# Gurobi optimization status: 2
# the limit loss is 0.07286788969743312
# the runtime is 0.03742098808288574
# testing instance with offertimes 60 : 0th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007696866989135742
# testing instance with offertimes 60 : 1th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007089853286743164
# testing instance with offertimes 60 : 2th
# Gurobi optimization status: 2
# the limit loss is 0.03955199999999894
# the runtime is 0.0740361213684082
# testing instance with offertimes 60 : 3th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 4th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 5th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 6th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 7th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 8th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.0075571537017822266
# testing instance with offertimes 60 : 9th
# Gurobi optimization status: 2
# the limit loss is 0.04931583999999998
# the runtime is 0.03803610801696777
# testing instance with offertimes 60 : 10th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 11th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 12th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 13th
# Gurobi optimization status: 2
# the limit loss is 2.74522689
# the runtime is 0.02086496353149414
# testing instance with offertimes 60 : 14th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 15th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 16th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 17th
# Gurobi optimization status: 2
# the limit loss is 0.4328062500000023
# the runtime is 0.016843080520629883
# testing instance with offertimes 60 : 18th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.008529901504516602
# testing instance with offertimes 60 : 19th
# Gurobi optimization status: 2
# the limit loss is 7.011684
# the runtime is 0.024760961532592773
# testing instance with offertimes 60 : 20th
# Gurobi optimization status: 2
# the limit loss is 0.00013731000000002382
# the runtime is 0.0455780029296875
# testing instance with offertimes 60 : 21th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 22th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.0075380802154541016
# testing instance with offertimes 60 : 23th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 24th
# Gurobi optimization status: 2
# the limit loss is 1.0167999999999981
# the runtime is 0.027219057083129883
# testing instance with offertimes 60 : 25th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 26th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 27th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.010308980941772461
# testing instance with offertimes 60 : 28th
# Gurobi optimization status: 2
# the limit loss is 7.96e-06
# the runtime is 0.034655094146728516
# testing instance with offertimes 60 : 29th
# Gurobi optimization status: 2
# the limit loss is 0.30485481999999875
# the runtime is 0.019422054290771484
# testing instance with offertimes 60 : 30th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 31th
# Gurobi optimization status: 2
# the limit loss is 0.09944796000000204
# the runtime is 0.01736593246459961
# testing instance with offertimes 60 : 32th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007539033889770508
# testing instance with offertimes 60 : 33th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 34th
# Gurobi optimization status: 2
# the limit loss is 3.29897728
# the runtime is 0.029172897338867188
# testing instance with offertimes 60 : 35th
# Gurobi optimization status: 2
# the limit loss is 0.01683747
# the runtime is 0.01590704917907715
# testing instance with offertimes 60 : 36th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.0076770782470703125
# testing instance with offertimes 60 : 37th
# Gurobi optimization status: 2
# the limit loss is 0.037115320000003414
# the runtime is 0.017827987670898438
# testing instance with offertimes 60 : 38th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.010133028030395508
# testing instance with offertimes 60 : 39th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 40th
# Gurobi optimization status: 2
# the limit loss is 0.7296239700000003
# the runtime is 0.017514944076538086
# testing instance with offertimes 60 : 41th
# Gurobi optimization status: 2
# the limit loss is 1.9282026799999994
# the runtime is 0.07419705390930176
# testing instance with offertimes 60 : 42th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 43th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.008022785186767578
# testing instance with offertimes 60 : 44th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007203102111816406
# testing instance with offertimes 60 : 45th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 46th
# Gurobi optimization status: 2
# the limit loss is 14.097881600000001
# the runtime is 0.03986001014709473
# testing instance with offertimes 60 : 47th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007302045822143555
# testing instance with offertimes 60 : 48th
# Gurobi optimization status: 2
# the limit loss is 0.09694021999999804
# the runtime is 0.017427921295166016
# testing instance with offertimes 60 : 49th
# Gurobi optimization status: 2
# the limit loss is 0.18811249999999918
# the runtime is 0.020692825317382812
# testing instance with offertimes 60 : 50th
# Gurobi optimization status: 2
# the limit loss is 0.006537189999999281
# the runtime is 0.028373003005981445
# testing instance with offertimes 60 : 51th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.0077130794525146484
# testing instance with offertimes 60 : 52th
# Gurobi optimization status: 2
# the limit loss is 3.2883448999999967
# the runtime is 0.030170202255249023
# testing instance with offertimes 60 : 53th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 54th
# Gurobi optimization status: 2
# the limit loss is 0.028214519999999885
# the runtime is 0.04591703414916992
# testing instance with offertimes 60 : 55th
# Gurobi optimization status: 2
# the limit loss is 7.263809279999998
# the runtime is 0.02855992317199707
# testing instance with offertimes 60 : 56th
# Gurobi optimization status: 2
# the limit loss is 2.3404844799999998
# the runtime is 0.05957317352294922
# testing instance with offertimes 60 : 57th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 58th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 59th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 60th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.010404825210571289
# testing instance with offertimes 60 : 61th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 62th
# Gurobi optimization status: 2
# the limit loss is 30.918655999999995
# the runtime is 0.04897189140319824
# testing instance with offertimes 60 : 63th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 64th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 65th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 66th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.03124403953552246
# testing instance with offertimes 60 : 67th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 68th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007769107818603516
# testing instance with offertimes 60 : 69th
# Gurobi optimization status: 2
# the limit loss is 1.2237220800000024
# the runtime is 0.05231308937072754
# testing instance with offertimes 60 : 70th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 71th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 72th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 73th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.010900020599365234
# testing instance with offertimes 60 : 74th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 75th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007477998733520508
# testing instance with offertimes 60 : 76th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 77th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 78th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 79th
# Gurobi optimization status: 2
# the limit loss is 0.01758364
# the runtime is 0.04102492332458496
# testing instance with offertimes 60 : 80th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 81th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 82th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 83th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.011148214340209961
# testing instance with offertimes 60 : 84th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 85th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007283210754394531
# testing instance with offertimes 60 : 86th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.009155988693237305
# testing instance with offertimes 60 : 87th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 88th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 89th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 90th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 91th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007542848587036133
# testing instance with offertimes 60 : 92th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.007792949676513672
# testing instance with offertimes 60 : 93th
# Gurobi optimization status: 2
# the limit loss is 0.31894272000000184
# the runtime is 0.017141103744506836
# testing instance with offertimes 60 : 94th
# Gurobi optimization status: 2
# the limit loss is 9.67686144
# the runtime is 0.04591798782348633
# testing instance with offertimes 60 : 95th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 96th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 97th
# Gurobi optimization status: 2
# the limit loss is 0.0
# the runtime is 0.028687000274658203
# testing instance with offertimes 60 : 98th
# the limit loss is 0
# the runtime is 0
# testing instance with offertimes 60 : 99th
# the limit loss is 0
# the runtime is 0

# %%
## adding rep results for pos
for i in range(len(pred_offer_times_list)):
    df_mdm_rep = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_rep':all_mdm_rep_pos[i], 'mdm_rep_time':all_mdm_rep_time_pos[i]})
    df_mdm_rep.to_csv('pos/representability/'+str(pred_offer_times_list[i])+'.csv')

## adding limit results
for i in range(len(pred_offer_times_list)):
    df_mdm_loss = pd.DataFrame({'ins_idx':list(range(pred_instance_size[i])),'mdm_loss':all_mdm_limit_loss_pos[i], 'mdm_limit_time':all_mdm_limit_runtime_pos[i]})
    df_mdm_loss.to_csv('pos/limit/'+str(pred_offer_times_list[i])+'.csv')
    
    for j in range(pred_instance_size[i]):
            df_limit_prob = pd.DataFrame(all_mdm_limit_prob_pos[i][j])
            df_limit_prob.to_csv('pos/limit/prob/offertimes'+str(pred_offer_times_list[i])+'/limit_prob_'+str(pred_offer_times_list[i])+'_'+str(j)+'.csv')

# %%
all_avg_loss_pos = []
for i in range(len(pred_offer_times_list)):
    avg_loss_collection_pos = []
    for j in range(pred_instance_size[i]):
        avg_loss_collection_pos.append(all_mdm_limit_loss_pos[i][j]/sum(all_full_offertimes[i]))
    all_avg_loss_pos.append(avg_loss_collection_pos)

avg_mdm_rep_pos = []
avg_mdm_rep_runtime_pos = []
avg_mdm_rep_runtime_se_pos = []

avg_total_limit_loss_pos = []
avg_toal_limit_loss_se_pos = []
avg_mdm_limit_runtime_pos = []

#avg_loss = []
avg_loss_se_pos = []
avg_limit_runtime_se_pos = []

for i in range(len(pred_offer_times_list)):
    avg_mdm_rep_pos.append(np.mean(all_mdm_rep_pos[i]))
    avg_mdm_rep_runtime_pos.append(np.mean(all_mdm_rep_time_pos[i]))
    avg_mdm_rep_runtime_se_pos.append(np.std(all_mdm_rep_time_pos[i])/np.sqrt(len(all_mdm_rep_time_pos[i])))
    
    avg_total_limit_loss_pos.append(np.mean(all_mdm_limit_loss_pos[i]))
    avg_mdm_limit_runtime_pos.append(np.mean(all_mdm_limit_runtime_pos[i]))
    avg_toal_limit_loss_se_pos.append(np.std(all_mdm_limit_loss_pos[i])/np.sqrt(len(all_mdm_limit_loss_pos[i])))
    
    #avg_loss = np.mean(all_avg_loss[i])
    avg_loss_se_pos.append(np.std(all_avg_loss_pos[i])/np.sqrt(len(all_avg_loss_pos[i])))
    avg_limit_runtime_se_pos.append(np.std(all_mdm_limit_runtime_pos[i])/np.sqrt(len(all_mdm_limit_runtime_pos[i])))

avg_loss_pos = []
for i in range(len(avg_total_limit_loss_pos)):
    avg_loss_pos.append(avg_total_limit_loss_pos[i]/sum(all_full_offertimes[i]))

df_mdm_limit_pos = pd.DataFrame({'offertimes':pred_offer_times_list,
                                 'collection_size':full_collection_size,
                                   'pos_rep':avg_mdm_rep_pos,'pos_rep_runtime':avg_mdm_rep_runtime_pos,'pos_rep_runtime_se':avg_mdm_rep_runtime_se_pos,
                                   'pos_total_loss':avg_total_limit_loss_pos,'pos_total_loss_se':avg_toal_limit_loss_se_pos,
                                   'pos_avg_loss':avg_loss_pos,'pos_avg_loss_se':avg_loss_se_pos,
                                   'pos_limit_runtime':avg_mdm_limit_runtime_pos,'pos_limit_runtime_se':avg_limit_runtime_se_pos
                                   })
df_mdm_limit_pos.to_csv('pos/pos_limit_summary.csv')
df_mdm_limit_pos
# Out:
#    offertimes  collection_size  pos_rep  pos_rep_runtime  pos_rep_runtime_se  \
# 0          20               29     0.10         0.000312            0.000011
# 1          30               24     0.15         0.000377            0.000012
# 2          40               19     0.20         0.000324            0.000009
# 3          50               15     0.30         0.000218            0.000009
# 4          60               13     0.48         0.000168            0.000005
#
#    pos_total_loss  pos_total_loss_se  pos_avg_loss  pos_avg_loss_se  \
# 0        4.206145           0.669515      0.000549         0.000087
# 1        3.280138           0.595731      0.000436         0.000079
# 2        2.201853           0.453980      0.000299         0.000062
# 3        1.237821           0.405866      0.000172         0.000056
# 4        0.871767           0.362797      0.000123         0.000051
#
#    pos_limit_runtime  pos_limit_runtime_se
# 0           0.642977              0.070480
# 1           0.240994              0.027063
# 2           0.084032              0.007429
# 3           0.028430              0.002758
# 4           0.011931              0.001705
